# %% [markdown]
# # Evaluation and Comparison of Non-Boosted ML Models in Behavior-Based Malware Detection
#
#
# ## Notebook: MLP Training
#
# ***
#
# **What is the objective of this file?**
#
# To train the model using the Train Split (Statically Split).

# %% [markdown]
# ## Checklist
#
# - Ensure that you have the proper dataset files that you intend to use (i.e., whether the lite dataset or full version).
#     - The datasets it will use points to `/Official Development/Dataset/IB` & `/Official Development/Dataset/TB`.
#     - You can run the `/Official Development/Dataset [OFFICIAL] Oliveira Dataset Notebook.ipynb file` or unzip one of the zipped folders in the `/Official Development/Dataset/Processed` towards the two aforementioned folders.
# - Ensure that you have installed the necessary libraries needed to execute the training process.
#     - You can view the list of the specific versions in the thesis document or through the `.sh` or `.bat` files in the repository's home directory.

# %% [markdown]
# # 1. MLP Training Setup
#
# Setting training environment parameters.

# %% [markdown]
# ## 1.0. Tuning Settings
#
# 1. What will the output filename be?
# 2. Will you train a tuned model?
# 3. What hyperparameter values will you use?
#
# For no. 3, the value looks like
# `{'task_type': 'CPU', 'objective': 'Logloss', 'n_estimators': 50, 'max_depth': 11, 'learning_rate': 0.1, 'l2_leaf_reg': 2, 'grow_policy': 'SymmetricTree', 'bootstrap_type': 'Bayesian', 'boosting_type': 'Ordered', 'auto_class_weights': 'Balanced'}`
# which is obtained as part of the results of the associated tuning file to this file.
#
# Alternatively, you can just point a file directly to it (overrides the manual setup if not empty).
#
# **Do not include the custom hyperparameter values for `random_state`, `thread_count`, `verbose`, `cat_features`, and `nan_mode` as the values for these are hardcoded to the notebook.**

# %%
MODEL_FILENAME = "RYZEN3b" # <== Set the prefix for the filename of the output file (don't include file extension)
TUNED_TRAINING = False # <== Set as True if you'll be training a tuned model.

# These parameters are mostly default valued parameters for MLPoost except some that are mentioned in the paper (e.g., Ordered Boosting, Symmeteric Tree); Set as None for truly defaults.
TB_HYPERPARAMS = None # None or like "{'task_type': 'CPU', 'objective':'Logloss', 'grow_policy': 'SymmetricTree', 'bootstrap_type': 'Bayesian', 'boosting_type': 'Ordered'}"
IB_HYPERPARAMS = None # None or like "{'task_type': 'CPU', 'objective':'Logloss', 'grow_policy': 'SymmetricTree', 'bootstrap_type': 'Bayesian', 'boosting_type': 'Ordered'}"

TB_HYPERPARAMS_FILE = "./Outputs/MLP/Tuning/Manual/RYZEN3b_MLP_TB.tune" # <== Empty string or Pointing a .tune file overrides the value set above.
IB_HYPERPARAMS_FILE = "./Outputs/MLP/Tuning/Manual/RYZEN3b_MLP_IB.tune" # <== Empty string or Pointing a .tune file overrides the value set above.

STATIC_SPLIT = 0.3 # <== To achieve the 70:30 Static Split
RANDOM_SEED = 1 # <== Must be the same throughout the entire study (acts as a controlled variable), hence let's just settle with 1.

# %% [markdown]
# # ⚠️Warning
#
# **Be careful of modifying the code beyond this point as it was designed to run autonomously based on the parameters set above.**

# %% [markdown]
# ## 1.1. Loading Libraries

# %%
#Python Libraries
import time
from datetime import datetime
import json

#Data/Dataset Libraries
import pandas as pd
import numpy as np

#Model Selection
from sklearn.model_selection import train_test_split

#Metrics (for in-training testing only)
from sklearn.metrics import classification_report, accuracy_score, balanced_accuracy_score, f1_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import precision_score, recall_score, roc_auc_score

#Visualization
from matplotlib import pyplot as plt

#GBDT Models
# import lightgbm
from sklearn.neural_network import MLPClassifier

#File Writing Library (exclusive for use on LightGBM)
from joblib import dump, load

# %% [markdown]
# ## 1.2. Logging and Diagnostics

# %%
if TUNED_TRAINING:
    MODEL_FILENAME = "TUNED_" + MODEL_FILENAME
    if len(TB_HYPERPARAMS_FILE) != 0:
        f = open(TB_HYPERPARAMS_FILE, "r")
        TB_HYPERPARAMS = f.readline()
        f.close()
    if len(IB_HYPERPARAMS_FILE) != 0:
        f = open(IB_HYPERPARAMS_FILE, "r")
        IB_HYPERPARAMS = f.readline()
        f.close()
    TB_HYPERPARAMS = TB_HYPERPARAMS.replace('\'', '\"')#.replace("False", "\"False\"").replace("True", "\"True\"")
    TB_HYPERPARAMS = json.loads(str(TB_HYPERPARAMS))
    print("Parsed TB Hyperparams:", TB_HYPERPARAMS)
    print("")
    IB_HYPERPARAMS = IB_HYPERPARAMS.replace('\'', '\"')#.replace("False", "\"False\"").replace("True", "\"True\"")
    IB_HYPERPARAMS = json.loads(str(IB_HYPERPARAMS))
    print("Parsed IB Hyperparams:", IB_HYPERPARAMS)
else:
    if TB_HYPERPARAMS != None:
        TB_HYPERPARAMS = TB_HYPERPARAMS.replace('\'', '\"').replace("False", "\"False\"").replace("True", "\"True\"")
        TB_HYPERPARAMS = json.loads(str(TB_HYPERPARAMS))
    else:
        TB_HYPERPARAMS = None
    if IB_HYPERPARAMS != None:
        IB_HYPERPARAMS = IB_HYPERPARAMS.replace('\'', '\"').replace("False", "\"False\"").replace("True", "\"True\"")
        IB_HYPERPARAMS = json.loads(str(IB_HYPERPARAMS))
    else:
        IB_HYPERPARAMS = None

start = end = 0
LOG_FILENAME = "MLP_Training_Log.txt"
def logging(message):
    log = open(LOG_FILENAME, "a")
    log.write(message)
    log.close()
def start_time():
    global start
    start = time.time()
def end_time(process):
    global start
    elapse = time.time()-start
    start = 0
    printout = f"{str(datetime.now())}@{MODEL_FILENAME}: {process} - {round(elapse, 6)}s\n"
    logging(printout)
    return round(elapse, 6)

# %% [markdown]
# ## 1.3. Loading Datasets
#
# Note that it will use the files in `/Official Development/Dataset/IB` & `/Official Development/Dataset/TB`.

# %% [markdown]
# ### 1.3.1. Setting filenames

# %%
#Setting filenames of files
TB_Train = "../../Dataset/TB/LGBM_TB.csv" # <== Location for Time-based Train Split for MLPoost
#TB_Test = "../../Dataset/TB/TB_Test_MLP.csv" # <== Location for Time-based Test Split for MLPoost
IB_Train = "../../Dataset/IB/LGBM_IB.csv" # <== Location for Instance-based Train Split for MLPoost
#IB_Test = "../../Dataset/IB/IB_Test_MLP.csv" # <== Location for Instance-based Test Split for MLPoost

# %% [markdown]
# ### 1.3.2. Loading datasets to DataFrames

# %%
#Loading datasets to DataFrames
tb_train = pd.read_csv(TB_Train, low_memory=False).fillna("NaN")
ib_train = pd.read_csv(IB_Train, low_memory=False).fillna("NaN")

print("Dataset Sizes")
print("TB Train Size:", tb_train.shape)
print("IB Train Size:", ib_train.shape)
# Out:
# Dataset Sizes
# TB Train Size: (72296, 101)
# IB Train Size: (72296, 101)

# %% [markdown]
# ### 1.3.3. Previewing datasets

# %%
#Previewing Time-based Dataset
tb_train.head()
# Out:
#    malware  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  t_8  ...  t_90  t_91  \
# 0        1  198  172  117  275  208  286  208  187  208  ...   215   198
# 1        1   82  240  117  240  117  240  117  240  117  ...   209   260
# 2        1   82  240  117  240  117  240  117  240  117  ...   141   260
# 3        1   82  240  117  240  117  240  117   16  228  ...   230   240
# 4        1   82  240  117  240  117  240  117  240  117  ...   159   224
#
#    t_92  t_93  t_94  t_95  t_96  t_97  t_98  t_99
# 0   228   297     2   140    81     8   199   264
# 1    40   209   260   141   260   141   260   141
# 2   141   260   141   260   141   260   141   260
# 3   117   225    89   208   215   192    89   133
# 4    82   260   141   260   141   260   141   260
#
# [5 rows x 101 columns]

# %%
#Previewing Instance-based Dataset
ib_train.head()
# Out:
#    malware  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  t_8  ...  t_90  t_91  \
# 0        1  198  172  117  275  208  286  187  240   71  ...   307   307
# 1        1   82  240  117  172   16   11  274  158  215  ...   307   307
# 2        1   82  240  117  172   16   11  274  158  215  ...   307   307
# 3        1   82  240  117   16  228  208   71   56  172  ...   307   307
# 4        1   82  240  117  172   16   11  274  158  215  ...   307   307
#
#    t_92  t_93  t_94  t_95  t_96  t_97  t_98  t_99
# 0   307   307   307   307   307   307   307   307
# 1   307   307   307   307   307   307   307   307
# 2   307   307   307   307   307   307   307   307
# 3   307   307   307   307   307   307   307   307
# 4   307   307   307   307   307   307   307   307
#
# [5 rows x 101 columns]

# %% [markdown]
# ### 1.3.4. Statically Splitting the Train Split
#
# Train Split --> Training and Validation Split
#
# However only Training Split will be used.

# %%
#Static splitting of Train Split of Time-based
X_tb = tb_train.iloc[:,1:101] #All rows, 2nd to last column
y_tb = tb_train.iloc[:,0] #All rows, first column only
X_tb_training, X_tb_validate, y_tb_training, y_tb_validate = train_test_split(X_tb, y_tb, test_size=STATIC_SPLIT, shuffle=True, random_state=1)

#Static splitting of Train Split of Instance-based
X_ib = ib_train.iloc[:,1:101] #All rows, 2nd to last column
y_ib = ib_train.iloc[:,0] #All rows, first column only
X_ib_training, X_ib_validate, y_ib_training, y_ib_validate = train_test_split(X_ib, y_ib, test_size=STATIC_SPLIT, shuffle=True, random_state=1)

# %% [markdown]
# # 2. Model Training

# %% [markdown]
# ## 2.1. Setting up the Model

# %%
def get_indexes():
    indexes = []
    for i in range(100):
        indexes.append(f"t_{i}")
    return indexes

def setup_model(HYPERPARAMS, TYPE):
    global TUNED_TRAINING
    indexes = get_indexes()
    metric=['Logloss', 'AUC', 'Precision']
    train_dir = f"./Outputs/MLP/{MODEL_FILENAME}_MLP_{TYPE}_TRAINDIR"
    if HYPERPARAMS == None:
        return MLPClassifier(random_state=RANDOM_SEED, verbose=1, learning_rate='adaptive')
    return MLPClassifier(**HYPERPARAMS, random_state=RANDOM_SEED, verbose=1, learning_rate='adaptive')

# %% [markdown]
# ## 2.2. Training on Time-Based Behaviors

# %% [markdown]
# ### 2.2.1 Training Model

# %%
#Training Model
start_time()
tb_MLP = setup_model(TB_HYPERPARAMS, "TB")
tb_MLP.fit(X_tb_training, y_tb_training)
end_time("MLP_TB")

#Saving Model as file
import pickle
# Save
with open("Outputs/MLP/"+MODEL_FILENAME+"_MLP_TB.model", 'wb') as fid:
    pickle.dump(tb_MLP, fid)    
# load
# with open('my_dumped_classifier.pkl', 'rb') as fid:
#     tb_MLP = cPickle.load(fid)
# Out:
# Iteration 1, loss = 1.30808503
# Iteration 2, loss = 0.37362482
# Iteration 3, loss = 0.28722434
# Iteration 4, loss = 0.22386182
# Iteration 5, loss = 0.19318821
# Iteration 6, loss = 0.17052466
# Iteration 7, loss = 0.28645495
# Iteration 8, loss = 0.19504608
# Iteration 9, loss = 0.15783373
# Iteration 10, loss = 0.48160592
# Iteration 11, loss = 0.17178177
# Iteration 12, loss = 0.13769412
# Iteration 13, loss = 0.10755610
# Iteration 14, loss = 0.16943044
# Iteration 15, loss = 0.09874985
# Iteration 16, loss = 0.16817196
# Iteration 17, loss = 0.09186793
# Iteration 18, loss = 0.07764000
# Iteration 19, loss = 0.07609109
# Iteration 20, loss = 0.07885194
# Iteration 21, loss = 0.10856366
# Iteration 22, loss = 0.06762242
# Iteration 23, loss = 0.19515998
# Iteration 24, loss = 0.08412190
# Iteration 25, loss = 0.06735198
# Iteration 26, loss = 0.05392698
# Iteration 27, loss = 0.04830513
# Iteration 28, loss = 0.06193627
# Iteration 29, loss = 0.10452534
# Iteration 30, loss = 0.05379667
# Iteration 31, loss = 0.03965564
# Iteration 32, loss = 0.04236357
# Iteration 33, loss = 0.03656770
# Iteration 34, loss = 0.03435723
# Iteration 35, loss = 0.03277984
# Iteration 36, loss = 0.02770930
# Iteration 37, loss = 0.04087148
# Iteration 38, loss = 0.03106794
# Iteration 39, loss = 0.03139205
# Iteration 40, loss = 0.03250664
# Iteration 41, loss = 0.02593871
# Iteration 42, loss = 0.02754802
# Iteration 43, loss = 0.02552053
# Iteration 44, loss = 0.02567455
# Iteration 45, loss = 0.02438701
# Iteration 46, loss = 0.02163454
# Iteration 47, loss = 0.02418060
# Iteration 48, loss = 0.02189256
# Iteration 49, loss = 0.02343489
# Iteration 50, loss = 0.02035875
# Iteration 51, loss = 0.01912705
# Iteration 52, loss = 0.01990201
# Iteration 53, loss = 0.01695215
# Iteration 54, loss = 0.01996993
# Iteration 55, loss = 0.01861904
# Iteration 56, loss = 0.01787301
# Iteration 57, loss = 0.01715702
# Iteration 58, loss = 0.01600653
# Iteration 59, loss = 0.01548450
# Iteration 60, loss = 0.01608527
# Iteration 61, loss = 0.01721638
# Iteration 62, loss = 0.02060635
# Iteration 63, loss = 0.02795673
# Iteration 64, loss = 0.01581500
# Iteration 65, loss = 0.01519690
# Iteration 66, loss = 0.01513046
# Iteration 67, loss = 0.01373871
# Iteration 68, loss = 0.01312439
# Iteration 69, loss = 0.01404477
# Iteration 70, loss = 0.01357985
# Iteration 71, loss = 0.01464773
# Iteration 72, loss = 0.01510036
# Iteration 73, loss = 0.01434715
# Iteration 74, loss = 0.01423928
# Iteration 75, loss = 0.01341998
# Iteration 76, loss = 0.01308166
# Iteration 77, loss = 0.01464775
# Iteration 78, loss = 0.01206809
# Iteration 79, loss = 0.01125913
# Iteration 80, loss = 0.01157847
# Iteration 81, loss = 0.01070019
# Iteration 82, loss = 0.01044065
# Iteration 83, loss = 0.01168853
# Iteration 84, loss = 0.01117128
# Iteration 85, loss = 0.01303828
# Iteration 86, loss = 0.00834840
# Iteration 87, loss = 0.01226132
# Iteration 88, loss = 0.01036375
# Iteration 89, loss = 0.01167169
# Iteration 90, loss = 0.01200646
# Iteration 91, loss = 0.01098409
# Iteration 92, loss = 0.01041255
# Iteration 93, loss = 0.00948453
# Iteration 94, loss = 0.00927254
# Iteration 95, loss = 0.00909865
# Iteration 96, loss = 0.01169155
# Iteration 97, loss = 0.01006126
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %% [markdown]
# ### 2.2.2. Checking Performance
#
# Using the split for validation for a bit of internal checking of performance (i.e., not official)

# %%
y_pred = tb_MLP.predict(X_tb_validate)
print("MLP_TB")
print(classification_report(y_tb_validate, y_pred, digits=4))
print("AUC-ROC:", roc_auc_score(y_tb_validate, y_pred))
print(classification_report(y_tb_validate, y_pred, digits=4), file=open("Outputs/MLP/"+MODEL_FILENAME+"_MLP_TB_ClassReport.txt", mode='w'))
print("AUC-ROC:", roc_auc_score(y_tb_validate, y_pred), file=open("Outputs/MLP/"+MODEL_FILENAME+"_MLP_TB_ClassReport.txt", mode='a'))
disp = ConfusionMatrixDisplay(confusion_matrix(y_tb_validate, y_pred))
disp.plot()
plt.savefig("Outputs/MLP/"+MODEL_FILENAME+"_MLP_TB_"+"_ConfMatrix.png")
# Out:
# MLP_TB
#               precision    recall  f1-score   support
#
#            0     0.9939    0.9909    0.9924     10772
#            1     0.9910    0.9940    0.9925     10917
#
#     accuracy                         0.9924     21689
#    macro avg     0.9925    0.9924    0.9924     21689
# weighted avg     0.9924    0.9924    0.9924     21689
#
# AUC-ROC: 0.9924283612353565

# %% [markdown]
# ### 2.2.3. Preview of the Tree
#
# *How can it be a tree if there is no proof of a tree?*

# %%
# tree = tb_MLP.plot_tree(0, MLPoost.Pool(X_tb_training, y_tb_training, cat_features=get_indexes(), feature_names=list(X_tb_training.columns)))
# tree.save("Outputs/MLP/"+MODEL_FILENAME+"_MLP_TREE/TB_Tree"+".svg")
# display(tree)

# %% [markdown]
# ## 2.3. Training on Instance-Based Behaviors

# %% [markdown]
# ### 2.3.1 Training Model

# %%
#Training Model
start_time()
ib_MLP = setup_model(IB_HYPERPARAMS, "IB")
ib_MLP.fit(X_ib_training, y_ib_training)
end_time("MLP_IB")

#Saving Model as file
import pickle
# Save
with open("Outputs/MLP/"+MODEL_FILENAME+"_MLP_TB.model", 'wb') as fid:
    pickle.dump(ib_MLP, fid)    
# load
# with open('my_dumped_classifier.pkl', 'rb') as fid:
#     ib_MLP = cPickle.load(fid)
# Out:
# Iteration 1, loss = 2.11712916
# Iteration 2, loss = 0.69149489
# Iteration 3, loss = 0.53053212
# Iteration 4, loss = 0.29548269
# Iteration 5, loss = 0.46405255
# Iteration 6, loss = 0.30424842
# Iteration 7, loss = 0.29268075
# Iteration 8, loss = 0.38610416
# Iteration 9, loss = 0.35692824
# Iteration 10, loss = 0.72275468
# Iteration 11, loss = 0.28688359
# Iteration 12, loss = 0.57047420
# Iteration 13, loss = 0.25320319
# Iteration 14, loss = 0.28733755
# Iteration 15, loss = 0.51066078
# Iteration 16, loss = 0.26300728
# Iteration 17, loss = 0.29216827
# Iteration 18, loss = 0.18182355
# Iteration 19, loss = 0.45077560
# Iteration 20, loss = 0.20355658
# Iteration 21, loss = 0.46285955
# Iteration 22, loss = 0.18382508
# Iteration 23, loss = 0.35010617
# Iteration 24, loss = 0.43337392
# Iteration 25, loss = 0.20913830
# Iteration 26, loss = 0.16964763
# Iteration 27, loss = 0.46932546
# Iteration 28, loss = 0.24395256
# Iteration 29, loss = 0.18994075
# Iteration 30, loss = 0.17818233
# Iteration 31, loss = 0.12012565
# Iteration 32, loss = 0.44691324
# Iteration 33, loss = 0.17468080
# Iteration 34, loss = 0.39024774
# Iteration 35, loss = 0.16585479
# Iteration 36, loss = 0.13003721
# Iteration 37, loss = 0.09973020
# Iteration 38, loss = 0.30718465
# Iteration 39, loss = 0.10151356
# Iteration 40, loss = 0.23173270
# Iteration 41, loss = 0.10526874
# Iteration 42, loss = 0.07955660
# Iteration 43, loss = 0.08509562
# Iteration 44, loss = 0.08596848
# Iteration 45, loss = 0.10695734
# Iteration 46, loss = 0.16212369
# Iteration 47, loss = 0.08365802
# Iteration 48, loss = 0.21254963
# Iteration 49, loss = 0.08603718
# Iteration 50, loss = 0.17943710
# Iteration 51, loss = 0.07645967
# Iteration 52, loss = 0.07594990
# Iteration 53, loss = 0.06850295
# Iteration 54, loss = 0.07379849
# Iteration 55, loss = 0.07881886
# Iteration 56, loss = 0.06628791
# Iteration 57, loss = 0.08442358
# Iteration 58, loss = 0.06469917
# Iteration 59, loss = 0.06300360
# Iteration 60, loss = 0.07751680
# Iteration 61, loss = 0.14213470
# Iteration 62, loss = 0.08010790
# Iteration 63, loss = 0.07637181
# Iteration 64, loss = 0.05665182
# Iteration 65, loss = 0.06427284
# Iteration 66, loss = 0.06679538
# Iteration 67, loss = 0.05781414
# Iteration 68, loss = 0.06084690
# Iteration 69, loss = 0.06090482
# Iteration 70, loss = 0.05236083
# Iteration 71, loss = 0.05109985
# Iteration 72, loss = 0.05514938
# Iteration 73, loss = 0.05057095
# Iteration 74, loss = 0.04781811
# Iteration 75, loss = 0.04459689
# Iteration 76, loss = 0.04473472
# Iteration 77, loss = 0.04633821
# Iteration 78, loss = 0.04401619
# Iteration 79, loss = 0.04431966
# Iteration 80, loss = 0.04863730
# Iteration 81, loss = 0.04293458
# Iteration 82, loss = 0.04125382
# Iteration 83, loss = 0.04649071
# Iteration 84, loss = 0.04151012
# Iteration 85, loss = 0.06256712
# Iteration 86, loss = 0.04386931
# Iteration 87, loss = 0.04372791
# Iteration 88, loss = 0.04247617
# Iteration 89, loss = 0.04222495
# Iteration 90, loss = 0.04147612
# Iteration 91, loss = 0.04059508
# Iteration 92, loss = 0.04784054
# Iteration 93, loss = 0.04272070
# Iteration 94, loss = 0.04220122
# Iteration 95, loss = 0.04332303
# Iteration 96, loss = 0.04204660
# Iteration 97, loss = 0.04237286
# Iteration 98, loss = 0.04069281
# Iteration 99, loss = 0.04039610
# Iteration 100, loss = 0.04044066
# Iteration 101, loss = 0.04063400
# Iteration 102, loss = 0.03980223
# Iteration 103, loss = 0.04575868
# Iteration 104, loss = 0.04008321
# Iteration 105, loss = 0.04046519
# Iteration 106, loss = 0.04026182
# Iteration 107, loss = 0.15085964
# Iteration 108, loss = 0.14869585
# Iteration 109, loss = 0.12726437
# Iteration 110, loss = 0.11451088
# Iteration 111, loss = 0.10555033
# Iteration 112, loss = 0.09810552
# Iteration 113, loss = 0.09398929
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %% [markdown]
# ### 2.3.2. Checking Performance
#
# Using the split for validation for a bit of internal checking of performance (i.e., not official)

# %%
y_pred = ib_MLP.predict(X_ib_validate)
print("MLP_IB")
print(classification_report(y_ib_validate, y_pred, digits=4))
print("AUC-ROC:", roc_auc_score(y_ib_validate, y_pred))
print(classification_report(y_ib_validate, y_pred, digits=4), file=open("Outputs/MLP/"+MODEL_FILENAME+"_MLP_IB_ClassReport.txt", mode='w'))
print("AUC-ROC:", roc_auc_score(y_ib_validate, y_pred), file=open("Outputs/MLP/"+MODEL_FILENAME+"_MLP_IB_ClassReport.txt", mode='a'))
disp = ConfusionMatrixDisplay(confusion_matrix(y_ib_validate, y_pred))
disp.plot()
plt.savefig("Outputs/MLP/"+MODEL_FILENAME+"_MLP_IB_"+"_ConfMatrix.png")
# Out:
# MLP_IB
#               precision    recall  f1-score   support
#
#            0     0.9732    0.9862    0.9796     10772
#            1     0.9862    0.9732    0.9796     10917
#
#     accuracy                         0.9796     21689
#    macro avg     0.9797    0.9797    0.9796     21689
# weighted avg     0.9797    0.9796    0.9796     21689
#
# AUC-ROC: 0.9796644837029606

# %% [markdown]
# ### 2.3.3. Preview of the Tree
#
# *How can it be a tree if there is no proof of a tree?*

# %%
# tree = ib_MLP.plot_tree(0, MLPoost.Pool(X_ib_training, y_ib_training, cat_features=get_indexes(), feature_names=list(X_ib_training.columns)))
# tree.save("Outputs/MLP/"+MODEL_FILENAME+"_MLP_TREE/IB_Tree"+".svg")
# tree
