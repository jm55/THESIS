# %% [markdown]
# # Visualizing Stratified K-Folds

# %%
K = 5
DYNAMIC_SPLIT = 1/K # <== Expected validation ratio. Training ratio will be 1-(1/K). Just for when needed to view.
RANDOM_SEED = 1 # <==  <== Must be the same throughout the entire study (acts as a controlled variable), hence let's just settle with 1.

# %%
#Python Libraries
import time
from datetime import datetime
import os
import json

#Data/Dataset Libraries
import pandas as pd
import numpy as np

#Model Selection
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV

#Metrics (for in-tuning testing only)
from sklearn.metrics import classification_report, accuracy_score, balanced_accuracy_score, f1_score
from sklearn.metrics import precision_score, recall_score, roc_auc_score

#Visualization
from matplotlib import pyplot as plt

#GBDT Models
import lightgbm
# import catboost

#File Writing Library (exclusive for use on LightGBM)
from joblib import dump, load

start = end = 0
LOG_FILENAME = "LGBM_Tuning_Log.txt"
def logging(message):
    log = open(LOG_FILENAME, "a")
    log.write(message)
    log.close()
def start_time():
    global start
    start = time.time()
def end_time(process):
    global start
    elapse = time.time()-start
    start = 0
    printout = f"{str(datetime.now())}@{OUTPUT_FILENAME}: {process} - {round(elapse, 6)}s\n"
    logging(printout)
    return round(elapse, 6)
def print_to_file(label, output):
    global OUTPUT_FILENAME
    filename = OUTPUT_FILENAME + "_" + label + ".tune"
    with open("Outputs/" + filename, 'w') as f:
        f.write(str(output))
        f.close()

# %%
def get_strat_kfold():
    global K
    return StratifiedKFold(n_splits=K, shuffle=True, random_state=1)

#K-folds sample visualization
def kfolds_vis(dataset, filename:str):
    global K
    X = dataset.iloc[:,1:] #All rows, 2nd to last column
    y = dataset.iloc[:,0] #All rows, first column only
    fig, ax = plt.subplots(figsize=(10,K+1), dpi=300)
    train = plot_cv_indices(get_strat_kfold(), X, y, ax, K)
    plt.savefig(f'{filename}.png')
    plt.show()

#K-folds sample visualization (inner workings)
def plot_cv_indices(cv, X, y, ax, n_splits, lw=25):
    #From: https://scikit-learn.org/stable/auto_examples/model_selection/plot_cv_indices.html
    for ii, (tr, tt) in enumerate(cv.split(X=X, y=y)):
        print(f"Fold {ii}: Train={len(tr)},  Test={len(tt)}")
        indices = np.array([np.nan] * len(X))
        indices[tt], indices[tr] = 1,0
        ax.scatter(range(len(indices)), [ii] * len(indices), c=indices, marker="_", 
                   lw=lw, cmap=plt.cm.Paired, vmin=0, vmax=1)
    #ax.scatter(range(len(X)), [ii] * len(X), c=y, marker="_", lw=lw, cmap=plt.cm.Paired)
    yticklabels = list(range(n_splits))
    ax.set(yticks=np.arange(n_splits), yticklabels=yticklabels, xlabel="Dataset Subsample", ylabel="CV iteration", ylim=[n_splits,-1], xlim=[0, X.shape[0]])
    ax.set_title("{}".format(type(cv).__name__))
    return ax

# %%
#Setting filenames of files
TB_Train_LGBM = "../Dataset/TB/LGBM_TB.csv" # <== Location for Time-based Train Split for LightGBM
#TB_Test_LGBM = "../Dataset/TB/LGBM_TB_Test.csv" # <== Location for Time-based Test Split for LightGBM
IB_Train_LGBM = "../Dataset/IB/LGBM_IB.csv" # <== Location for Instance-based Train Split for LightGBM
#IB_Test_LGBM = "../Dataset/IB/LGBM_IB_Test.csv" # <== Location for Instance-based Test Split for LightGBM

#Setting filenames of files
TB_Train_CATB = "../Dataset/TB/CATB_TB.csv" # <== Location for Time-based Train Split for LightGBM
#TB_Test_CATB = "../Dataset/TB/CATB_TB_Test.csv" # <== Location for Time-based Test Split for LightGBM
IB_Train_CATB = "../Dataset/IB/CATB_IB.csv" # <== Location for Instance-based Train Split for LightGBM
#IB_Test_CATB = "../Dataset/IB/CATB_IB_Test.csv" # <== Location for Instance-based Test Split for LightGBM

# %%
#Loading datasets to DataFrames
tb_train = pd.read_csv(TB_Train_LGBM, low_memory=False).fillna("NaN")
ib_train = pd.read_csv(IB_Train_LGBM, low_memory=False).fillna("NaN")

print("Dataset Sizes")
print("TB Train Size:", tb_train.shape)
print("IB Train Size:", ib_train.shape)

display(tb_train.head())
display(ib_train.head())
# Out:
# Dataset Sizes
# TB Train Size: (72296, 101)
# IB Train Size: (72296, 101)
#    malware  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  t_8  ...  t_90  t_91  \
# 0        1  198  172  117  275  208  286  208  187  208  ...   215   198
# 1        1   82  240  117  240  117  240  117  240  117  ...   209   260
# 2        1   82  240  117  240  117  240  117  240  117  ...   141   260
# 3        1   82  240  117  240  117  240  117   16  228  ...   230   240
# 4        1   82  240  117  240  117  240  117  240  117  ...   159   224
#
#    t_92  t_93  t_94  t_95  t_96  t_97  t_98  t_99
# 0   228   297     2   140    81     8   199   264
# 1    40   209   260   141   260   141   260   141
# 2   141   260   141   260   141   260   141   260
# 3   117   225    89   208   215   192    89   133
# 4    82   260   141   260   141   260   141   260
#
# [5 rows x 101 columns]
#    malware  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  t_8  ...  t_90  t_91  \
# 0        1  198  172  117  275  208  286  187  240   71  ...   307   307
# 1        1   82  240  117  172   16   11  274  158  215  ...   307   307
# 2        1   82  240  117  172   16   11  274  158  215  ...   307   307
# 3        1   82  240  117   16  228  208   71   56  172  ...   307   307
# 4        1   82  240  117  172   16   11  274  158  215  ...   307   307
#
#    t_92  t_93  t_94  t_95  t_96  t_97  t_98  t_99
# 0   307   307   307   307   307   307   307   307
# 1   307   307   307   307   307   307   307   307
# 2   307   307   307   307   307   307   307   307
# 3   307   307   307   307   307   307   307   307
# 4   307   307   307   307   307   307   307   307
#
# [5 rows x 101 columns]

# %%
print("Stratified K-Folds Split at",K,"splits.")
print("LGBM TB/TB_Encoded Dataset")
kfolds_vis(tb_train, "LGBM TB-TB_Encoded")
print("LGBM IB/IB_Encoded Dataset")
kfolds_vis(ib_train, "LGBM IB-IB_Encoded")
# Out:
# Stratified K-Folds Split at 5 splits.
# LGBM TB/TB_Encoded Dataset
# Fold 0: Train=57836,  Test=14460
# Fold 1: Train=57837,  Test=14459
# Fold 2: Train=57837,  Test=14459
# Fold 3: Train=57837,  Test=14459
# Fold 4: Train=57837,  Test=14459
# LGBM IB/IB_Encoded Dataset
# Fold 0: Train=57836,  Test=14460
# Fold 1: Train=57837,  Test=14459
# Fold 2: Train=57837,  Test=14459
# Fold 3: Train=57837,  Test=14459
# Fold 4: Train=57837,  Test=14459

# %%
#Loading datasets to DataFrames
tb_train = pd.read_csv(TB_Train_CATB, low_memory=False).fillna("NaN")
ib_train = pd.read_csv(IB_Train_CATB, low_memory=False).fillna("NaN")

print("Dataset Sizes")
print("TB Train Size:", tb_train.shape)
print("IB Train Size:", ib_train.shape)

display(tb_train.head())
display(ib_train.head())
# Out:
# Dataset Sizes
# TB Train Size: (72296, 101)
# IB Train Size: (72296, 101)
#    malware                      t_0              t_1                     t_2  \
# 0        1            GetSystemInfo  LdrGetDllHandle  LdrGetProcedureAddress
# 1        1  GetSystemTimeAsFileTime       LdrLoadDll  LdrGetProcedureAddress
# 2        1  GetSystemTimeAsFileTime       LdrLoadDll  LdrGetProcedureAddress
# 3        1  GetSystemTimeAsFileTime       LdrLoadDll  LdrGetProcedureAddress
# 4        1  GetSystemTimeAsFileTime       LdrLoadDll  LdrGetProcedureAddress
#
#                    t_3                      t_4           t_5  \
# 0  GetSystemDirectoryW  NtAllocateVirtualMemory  SetErrorMode
# 1           LdrLoadDll   LdrGetProcedureAddress    LdrLoadDll
# 2           LdrLoadDll   LdrGetProcedureAddress    LdrLoadDll
# 3           LdrLoadDll   LdrGetProcedureAddress    LdrLoadDll
# 4           LdrLoadDll   LdrGetProcedureAddress    LdrLoadDll
#
#                        t_6                          t_7  \
# 0  NtAllocateVirtualMemory          NtFreeVirtualMemory
# 1   LdrGetProcedureAddress                   LdrLoadDll
# 2   LdrGetProcedureAddress                   LdrLoadDll
# 3   LdrGetProcedureAddress  SetUnhandledExceptionFilter
# 4   LdrGetProcedureAddress                   LdrLoadDll
#
#                        t_8  ...              t_90           t_91  \
# 0  NtAllocateVirtualMemory  ...           NtClose  GetSystemInfo
# 1   LdrGetProcedureAddress  ...     RegEnumKeyExW  RegOpenKeyExW
# 2   LdrGetProcedureAddress  ...  RegQueryValueExW  RegOpenKeyExW
# 3   NtProtectVirtualMemory  ...      GetUserNameW     LdrLoadDll
# 4   LdrGetProcedureAddress  ...  NtDelayExecution    EnumWindows
#
#                       t_92           t_93               t_94  \
# 0   NtProtectVirtualMemory   NtCreateFile      FindResourceW
# 1         RegQueryInfoKeyW  RegEnumKeyExW      RegOpenKeyExW
# 2         RegQueryValueExW  RegOpenKeyExW   RegQueryValueExW
# 3   LdrGetProcedureAddress    DrawTextExW  NtDuplicateObject
# 4  GetSystemTimeAsFileTime  RegOpenKeyExW   RegQueryValueExW
#
#                       t_95              t_96              t_97  \
# 0           SizeofResource      LoadResource       GetFileSize
# 1         RegQueryValueExW     RegOpenKeyExW  RegQueryValueExW
# 2            RegOpenKeyExW  RegQueryValueExW     RegOpenKeyExW
# 3  NtAllocateVirtualMemory           NtClose  NtCreateThreadEx
# 4            RegOpenKeyExW  RegQueryValueExW     RegOpenKeyExW
#
#                 t_98              t_99
# 0     SetFilePointer        NtReadFile
# 1      RegOpenKeyExW  RegQueryValueExW
# 2   RegQueryValueExW     RegOpenKeyExW
# 3  NtDuplicateObject    NtResumeThread
# 4   RegQueryValueExW     RegOpenKeyExW
#
# [5 rows x 101 columns]
#    malware                      t_0              t_1                     t_2  \
# 0        1            GetSystemInfo  LdrGetDllHandle  LdrGetProcedureAddress
# 1        1  GetSystemTimeAsFileTime       LdrLoadDll  LdrGetProcedureAddress
# 2        1  GetSystemTimeAsFileTime       LdrLoadDll  LdrGetProcedureAddress
# 3        1  GetSystemTimeAsFileTime       LdrLoadDll  LdrGetProcedureAddress
# 4        1  GetSystemTimeAsFileTime       LdrLoadDll  LdrGetProcedureAddress
#
#                            t_3                          t_4  \
# 0          GetSystemDirectoryW      NtAllocateVirtualMemory
# 1              LdrGetDllHandle  SetUnhandledExceptionFilter
# 2              LdrGetDllHandle  SetUnhandledExceptionFilter
# 3  SetUnhandledExceptionFilter       NtProtectVirtualMemory
# 4              LdrGetDllHandle  SetUnhandledExceptionFilter
#
#                        t_5                         t_6              t_7  \
# 0             SetErrorMode         NtFreeVirtualMemory       LdrLoadDll
# 1     CryptAcquireContextW                   NtOpenKey  NtQueryValueKey
# 2     CryptAcquireContextW                   NtOpenKey  NtQueryValueKey
# 3  NtAllocateVirtualMemory  GetSystemWindowsDirectoryW    CreateActCtxW
# 4     CryptAcquireContextW                   NtOpenKey  NtQueryValueKey
#
#                           t_8  ... t_90 t_91 t_92 t_93 t_94 t_95 t_96 t_97  \
# 0  GetSystemWindowsDirectoryW  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1                     NtClose  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2                     NtClose  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3             LdrGetDllHandle  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4                     NtClose  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#   t_98 t_99
# 0  NaN  NaN
# 1  NaN  NaN
# 2  NaN  NaN
# 3  NaN  NaN
# 4  NaN  NaN
#
# [5 rows x 101 columns]

# %%
print("Stratified K-Folds Split at",K,"splits.")
print("CATB TB/TB_Encoded Dataset")
kfolds_vis(tb_train, "CATB TB-TB_Encoded")
print("CATB IB/IB_Encoded Dataset")
kfolds_vis(ib_train, "CATB IB-IB_Encoded")
# Out:
# Stratified K-Folds Split at 5 splits.
# CATB TB/TB_Encoded Dataset
# Fold 0: Train=57836,  Test=14460
# Fold 1: Train=57837,  Test=14459
# Fold 2: Train=57837,  Test=14459
# Fold 3: Train=57837,  Test=14459
# Fold 4: Train=57837,  Test=14459
# CATB IB/IB_Encoded Dataset
# Fold 0: Train=57836,  Test=14460
# Fold 1: Train=57837,  Test=14459
# Fold 2: Train=57837,  Test=14459
# Fold 3: Train=57837,  Test=14459
# Fold 4: Train=57837,  Test=14459
