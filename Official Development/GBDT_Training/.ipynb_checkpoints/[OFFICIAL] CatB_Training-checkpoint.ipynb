# %% [markdown]
# # Evaluation and Comparison of Boosted ML Models in Behavior-Based Malware Detection
#
#
# ## Notebook: CatBoost Training
#
# ***
#
# **What is the objective of this file?**
#
# To train the model using the Train Split (Statically Split).

# %% [markdown]
# ## Checklist
#
# - Ensure that you have the proper dataset files that you intend to use (i.e., whether the lite dataset or full version).
#     - The datasets it will use points to `/Official Development/Dataset/IB` & `/Official Development/Dataset/TB`.
#     - You can run the `/Official Development/Dataset [OFFICIAL] Oliveira Dataset Notebook.ipynb file` or unzip one of the zipped folders in the `/Official Development/Dataset/Processed` towards the two aforementioned folders.
# - Ensure that you have installed the necessary libraries needed to execute the training process.
#     - You can view the list of the specific versions in the thesis document or through the `.sh` or `.bat` files in the repository's home directory.

# %% [markdown]
# # 1. CatB Training Setup
#
# Setting training environment parameters.

# %% [markdown]
# ## 1.0. Tuning Settings
#
# 1. What will the output filename be?
# 2. Will you train a tuned model?
# 3. What hyperparameter values will you use?
#
# For no. 3, the value looks like
# `{'task_type': 'CPU', 'objective': 'Logloss', 'n_estimators': 50, 'max_depth': 11, 'learning_rate': 0.1, 'l2_leaf_reg': 2, 'grow_policy': 'SymmetricTree', 'bootstrap_type': 'Bayesian', 'boosting_type': 'Ordered', 'auto_class_weights': 'Balanced'}`
# which is obtained as part of the results of the associated tuning file to this file.
#
# Alternatively, you can just point a file directly to it (overrides the manual setup if not empty).
#
# **Do not include the custom hyperparameter values for `random_state`, `thread_count`, `verbose`, `cat_features`, and `nan_mode` as the values for these are hardcoded to the notebook.**

# %%
MODEL_FILENAME = "RYZEN2b" # <== Set the prefix for the filename of the output file (don't include file extension)
TUNED_TRAINING = True # <== Set as True if you'll be training a tuned model.

# These parameters are mostly default valued parameters for CatBoost except some that are mentioned in the paper (e.g., Ordered Boosting, Symmeteric Tree); Set as None for truly defaults.
TB_HYPERPARAMS = None # None or like "{'task_type': 'CPU', 'objective':'Logloss', 'grow_policy': 'SymmetricTree', 'bootstrap_type': 'Bayesian', 'boosting_type': 'Ordered'}"
IB_HYPERPARAMS = None # None or like "{'task_type': 'CPU', 'objective':'Logloss', 'grow_policy': 'SymmetricTree', 'bootstrap_type': 'Bayesian', 'boosting_type': 'Ordered'}"

TB_HYPERPARAMS_FILE = "./Outputs/CATB/Tuning/RYZEN2b_CATB_TB.tune" # <== Empty string or Pointing a .tune file overrides the value set above.
IB_HYPERPARAMS_FILE = "./Outputs/CATB/Tuning/RYZEN2b_CATB_IB.tune" # <== Empty string or Pointing a .tune file overrides the value set above.

STATIC_SPLIT = 0.3 # <== To achieve the 70:30 Static Split
RANDOM_SEED = 1 # <== Must be the same throughout the entire study (acts as a controlled variable), hence let's just settle with 1.

# %% [markdown]
# # ⚠️Warning
#
# **Be careful of modifying the code beyond this point as it was designed to run autonomously based on the parameters set above.**

# %% [markdown]
# ## 1.1. Loading Libraries

# %%
#Python Libraries
import time
from datetime import datetime
import json

#Data/Dataset Libraries
import pandas as pd
import numpy as np

#Model Selection
from sklearn.model_selection import train_test_split

#Metrics (for in-training testing only)
from sklearn.metrics import classification_report, accuracy_score, balanced_accuracy_score, f1_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import precision_score, recall_score, roc_auc_score

#Visualization
from matplotlib import pyplot as plt

#GBDT Models
# import lightgbm
import catboost

#File Writing Library (exclusive for use on LightGBM)
from joblib import dump, load

# %% [markdown]
# ## 1.2. Logging and Diagnostics

# %%
if TUNED_TRAINING:
    MODEL_FILENAME = "TUNED_" + MODEL_FILENAME
    if len(TB_HYPERPARAMS_FILE) != 0:
        f = open(TB_HYPERPARAMS_FILE, "r")
        TB_HYPERPARAMS = f.readline()
        f.close()
    if len(IB_HYPERPARAMS_FILE) != 0:
        f = open(IB_HYPERPARAMS_FILE, "r")
        IB_HYPERPARAMS = f.readline()
        f.close()
    TB_HYPERPARAMS = TB_HYPERPARAMS.replace('\'', '\"')#.replace("False", "\"False\"").replace("True", "\"True\"")
    TB_HYPERPARAMS = json.loads(str(TB_HYPERPARAMS))
    print("Parsed TB Hyperparams:", TB_HYPERPARAMS)
    print("")
    IB_HYPERPARAMS = IB_HYPERPARAMS.replace('\'', '\"')#.replace("False", "\"False\"").replace("True", "\"True\"")
    IB_HYPERPARAMS = json.loads(str(IB_HYPERPARAMS))
    print("Parsed IB Hyperparams:", IB_HYPERPARAMS)
else:
    if TB_HYPERPARAMS != None:
        TB_HYPERPARAMS = TB_HYPERPARAMS.replace('\'', '\"').replace("False", "\"False\"").replace("True", "\"True\"")
        TB_HYPERPARAMS = json.loads(str(TB_HYPERPARAMS))
    else:
        TB_HYPERPARAMS = None
    if IB_HYPERPARAMS != None:
        IB_HYPERPARAMS = IB_HYPERPARAMS.replace('\'', '\"').replace("False", "\"False\"").replace("True", "\"True\"")
        IB_HYPERPARAMS = json.loads(str(IB_HYPERPARAMS))
    else:
        IB_HYPERPARAMS = None

start = end = 0
LOG_FILENAME = "CATB_Training_Log.txt"
def logging(message):
    log = open(LOG_FILENAME, "a")
    log.write(message)
    log.close()
def start_time():
    global start
    start = time.time()
def end_time(process):
    global start
    elapse = time.time()-start
    start = 0
    printout = f"{str(datetime.now())}@{MODEL_FILENAME}: {process} - {round(elapse, 6)}s\n"
    logging(printout)
    return round(elapse, 6)
# Out:
# Parsed TB Hyperparams: {'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'gpu_cat_features_storage': 'CpuPinnedMemory', 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2, 'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100, 'objective': 'Logloss', 'task_type': 'GPU'}
#
# Parsed IB Hyperparams: {'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'gpu_cat_features_storage': 'CpuPinnedMemory', 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2, 'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100, 'objective': 'Logloss', 'task_type': 'GPU'}

# %% [markdown]
# ## 1.3. Loading Datasets
#
# Note that it will use the files in `/Official Development/Dataset/IB` & `/Official Development/Dataset/TB`.

# %% [markdown]
# ### 1.3.1. Setting filenames

# %%
#Setting filenames of files
TB_Train = "../Dataset/TB/CATB_TB.csv" # <== Location for Time-based Train Split for CatBoost
#TB_Test = "../Dataset/TB/TB_Test_CATB.csv" # <== Location for Time-based Test Split for CatBoost
IB_Train = "../Dataset/IB/CATB_IB.csv" # <== Location for Instance-based Train Split for CatBoost
#IB_Test = "../Dataset/IB/IB_Test_CATB.csv" # <== Location for Instance-based Test Split for CatBoost

# %% [markdown]
# ### 1.3.2. Loading datasets to DataFrames

# %%
#Loading datasets to DataFrames
tb_train = pd.read_csv(TB_Train, low_memory=False).fillna("NaN")
ib_train = pd.read_csv(IB_Train, low_memory=False).fillna("NaN")

print("Dataset Sizes")
print("TB Train Size:", tb_train.shape)
print("IB Train Size:", ib_train.shape)
# Out:
# Dataset Sizes
# TB Train Size: (72298, 101)
# IB Train Size: (72298, 101)

# %% [markdown]
# ### 1.3.3. Previewing datasets

# %%
#Previewing Time-based Dataset
tb_train.head()
# Out:
#    malware                      t_0             t_1                      t_2  \
# 0        1            RegOpenKeyExA       NtOpenKey          NtQueryValueKey
# 1        1  GetSystemTimeAsFileTime      LdrLoadDll   LdrGetProcedureAddress
# 2        1  GetSystemTimeAsFileTime  NtCreateMutant  GetSystemTimeAsFileTime
# 3        1  GetSystemTimeAsFileTime      LdrLoadDll   LdrGetProcedureAddress
# 4        1             SetErrorMode   OleInitialize          LdrGetDllHandle
#
#            t_3                     t_4              t_5  \
# 0      NtClose               NtOpenKey  NtQueryValueKey
# 1   LdrLoadDll  LdrGetProcedureAddress       LdrLoadDll
# 2  NtOpenKeyEx              NtQueryKey      NtOpenKeyEx
# 3   LdrLoadDll  LdrGetProcedureAddress       LdrLoadDll
# 4   LdrLoadDll  LdrGetProcedureAddress       LdrLoadDll
#
#                       t_6                     t_7                     t_8  \
# 0                 NtClose   NtQueryAttributesFile             LoadStringA
# 1  LdrGetProcedureAddress              LdrLoadDll  LdrGetProcedureAddress
# 2              LdrLoadDll  LdrGetProcedureAddress           RegOpenKeyExW
# 3  LdrGetProcedureAddress              LdrLoadDll  LdrGetProcedureAddress
# 4  LdrGetProcedureAddress              LdrLoadDll  LdrGetProcedureAddress
#
#    ...                    t_90                        t_91  \
# 0  ...  LdrGetProcedureAddress  GetSystemWindowsDirectoryW
# 1  ...        RegQueryInfoKeyW               RegEnumKeyExW
# 2  ...           GetSystemInfo                     NtClose
# 3  ...        RegQueryValueExW               RegOpenKeyExW
# 4  ...           RegOpenKeyExW            RegQueryValueExW
#
#                    t_92              t_93                 t_94  \
# 0          NtCreateFile   NtCreateSection   NtMapViewOfSection
# 1         RegOpenKeyExW  RegQueryValueExW        RegOpenKeyExW
# 2  NtUnmapViewOfSection           NtClose        RegOpenKeyExW
# 3      RegQueryValueExW     RegOpenKeyExW     RegQueryValueExW
# 4           RegCloseKey    NtCreateMutant  GetNativeSystemInfo
#
#                          t_95              t_96                     t_97  \
# 0                     NtClose  GetSystemMetrics  NtAllocateVirtualMemory
# 1            RegQueryValueExW     RegOpenKeyExW         RegQueryValueExW
# 2                 RegCloseKey     RegOpenKeyExW         RegQueryValueExW
# 3               RegOpenKeyExW  RegQueryValueExW            RegOpenKeyExW
# 4  GetSystemWindowsDirectoryW           NtClose               LdrLoadDll
#
#                      t_98                        t_99
# 0           CreateActCtxW  GetSystemWindowsDirectoryW
# 1           RegOpenKeyExW            RegQueryValueExW
# 2             RegCloseKey                  NtOpenFile
# 3        RegQueryValueExW               RegOpenKeyExW
# 4  LdrGetProcedureAddress                  LdrLoadDll
#
# [5 rows x 101 columns]

# %%
#Previewing Instance-based Dataset
ib_train.head()
# Out:
#    malware                      t_0             t_1                     t_2  \
# 0        1            RegOpenKeyExA       NtOpenKey         NtQueryValueKey
# 1        1  GetSystemTimeAsFileTime      LdrLoadDll  LdrGetProcedureAddress
# 2        1  GetSystemTimeAsFileTime  NtCreateMutant             NtOpenKeyEx
# 3        1  GetSystemTimeAsFileTime      LdrLoadDll  LdrGetProcedureAddress
# 4        1             SetErrorMode   OleInitialize         LdrGetDllHandle
#
#                t_3                          t_4                     t_5  \
# 0          NtClose        NtQueryAttributesFile             LoadStringA
# 1  LdrGetDllHandle  SetUnhandledExceptionFilter    CryptAcquireContextW
# 2       NtQueryKey                   LdrLoadDll  LdrGetProcedureAddress
# 3  LdrGetDllHandle  SetUnhandledExceptionFilter    CryptAcquireContextW
# 4       LdrLoadDll       LdrGetProcedureAddress           NtOpenSection
#
#                        t_6               t_7                     t_8  ...  \
# 0  NtAllocateVirtualMemory   LdrGetDllHandle  LdrGetProcedureAddress  ...
# 1                NtOpenKey   NtQueryValueKey                 NtClose  ...
# 2            RegOpenKeyExW  RegQueryInfoKeyW           RegEnumKeyExW  ...
# 3                NtOpenKey   NtQueryValueKey                 NtClose  ...
# 4       NtMapViewOfSection     RegOpenKeyExW        RegQueryValueExW  ...
#
#   t_90 t_91 t_92 t_93 t_94 t_95 t_96 t_97 t_98 t_99
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 101 columns]

# %% [markdown]
# ### 1.3.4. Statically Splitting the Train Split
#
# Train Split --> Training and Validation Split
#
# However only Training Split will be used.

# %%
#Static splitting of Train Split of Time-based
X_tb = tb_train.iloc[:,1:101] #All rows, 2nd to last column
y_tb = tb_train.iloc[:,0] #All rows, first column only
X_tb_training, X_tb_validate, y_tb_training, y_tb_validate = train_test_split(X_tb, y_tb, test_size=STATIC_SPLIT, shuffle=True, random_state=1)

#Static splitting of Train Split of Instance-based
X_ib = ib_train.iloc[:,1:101] #All rows, 2nd to last column
y_ib = ib_train.iloc[:,0] #All rows, first column only
X_ib_training, X_ib_validate, y_ib_training, y_ib_validate = train_test_split(X_ib, y_ib, test_size=STATIC_SPLIT, shuffle=True, random_state=1)

# %% [markdown]
# # 2. Model Training

# %% [markdown]
# ## 2.1. Setting up the Model

# %%
def get_indexes():
    indexes = []
    for i in range(100):
        indexes.append(f"t_{i}")
    return indexes

def setup_model(HYPERPARAMS, TYPE):
    global TUNED_TRAINING
    indexes = get_indexes()
    metric=['Logloss', 'AUC', 'Precision']
    train_dir = f"Outputs/CATB/{MODEL_FILENAME}_CATB_{TYPE}_TRAINDIR"
    if HYPERPARAMS == None:
        return catboost.CatBoostClassifier(random_state=RANDOM_SEED, thread_count=-1, verbose=1, cat_features=indexes, 
                                           nan_mode='Min', custom_metric=metric, train_dir=train_dir, one_hot_max_size=256)
    return catboost.CatBoostClassifier(**HYPERPARAMS, random_state=RANDOM_SEED, thread_count=-1, verbose=1, cat_features=indexes, 
                                       nan_mode='Min', custom_metric=metric, train_dir=train_dir, one_hot_max_size=256)

# %% [markdown]
# ## 2.2. Training on Time-Based Behaviors

# %% [markdown]
# ### 2.2.1 Training Model

# %%
#Training Model
start_time()
tb_catb = setup_model(TB_HYPERPARAMS, "TB")
tb_catb.fit(X_tb_training, y_tb_training, plot=True, eval_set=catboost.Pool(X_tb_validate, label=y_tb_validate, cat_features=get_indexes()), save_snapshot=True, snapshot_interval=60)
end_time("CATB_TB")

#Saving Model as file
tb_catb.save_model("Outputs/CATB/"+MODEL_FILENAME+"_CATB_TB.model", format="json")
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Default metric period is 5 because AUC is/are not implemented for GPU
# 0:	learn: 0.4305644	test: 0.4308692	best: 0.4308692 (0)	total: 701ms	remaining: 1m 9s
# 1:	total: 1.26s	remaining: 1m 1s
# 2:	total: 1.81s	remaining: 58.4s
# 3:	total: 2.35s	remaining: 56.5s
# 4:	total: 2.9s	remaining: 55s
# 5:	learn: 0.0758031	test: 0.0777098	best: 0.0777098 (5)	total: 3.44s	remaining: 53.9s
# 6:	total: 3.99s	remaining: 53s
# 7:	total: 4.53s	remaining: 52.1s
# 8:	total: 5.06s	remaining: 51.1s
# 9:	total: 5.59s	remaining: 50.4s
# 10:	learn: 0.0369820	test: 0.0403171	best: 0.0403171 (10)	total: 6.12s	remaining: 49.5s
# 11:	total: 6.65s	remaining: 48.8s
# 12:	total: 7.18s	remaining: 48s
# 13:	total: 7.73s	remaining: 47.5s
# 14:	total: 8.26s	remaining: 46.8s
# 15:	learn: 0.0280716	test: 0.0322035	best: 0.0322035 (15)	total: 8.79s	remaining: 46.1s
# 16:	total: 9.31s	remaining: 45.4s
# 17:	total: 9.82s	remaining: 44.8s
# 18:	total: 10.3s	remaining: 44.1s
# 19:	total: 10.9s	remaining: 43.5s
# 20:	learn: 0.0250155	test: 0.0295404	best: 0.0295404 (20)	total: 11.4s	remaining: 42.8s
# 21:	total: 11.9s	remaining: 42.2s
# 22:	total: 12.4s	remaining: 41.6s
# 23:	total: 12.9s	remaining: 40.9s
# 24:	total: 13.5s	remaining: 40.4s
# 25:	learn: 0.0236085	test: 0.0284349	best: 0.0284349 (25)	total: 14s	remaining: 39.8s
# 26:	total: 14.5s	remaining: 39.2s
# 27:	total: 15s	remaining: 38.6s
# 28:	total: 15.5s	remaining: 38s
# 29:	total: 16s	remaining: 37.4s
# 30:	learn: 0.0223698	test: 0.0275759	best: 0.0275759 (30)	total: 16.6s	remaining: 36.9s
# 31:	total: 17.1s	remaining: 36.3s
# 32:	total: 17.6s	remaining: 35.7s
# 33:	total: 18.1s	remaining: 35.1s
# 34:	total: 18.6s	remaining: 34.6s
# 35:	learn: 0.0213569	test: 0.0269097	best: 0.0269097 (35)	total: 19.1s	remaining: 34s
# 36:	total: 19.6s	remaining: 33.5s
# 37:	total: 20.2s	remaining: 32.9s
# 38:	total: 20.7s	remaining: 32.3s
# 39:	total: 21.2s	remaining: 31.8s
# 40:	learn: 0.0207377	test: 0.0264760	best: 0.0264760 (40)	total: 21.7s	remaining: 31.3s
# 41:	total: 22.2s	remaining: 30.7s
# 42:	total: 22.7s	remaining: 30.2s
# 43:	total: 23.3s	remaining: 29.6s
# 44:	total: 23.8s	remaining: 29.1s
# 45:	learn: 0.0202183	test: 0.0261806	best: 0.0261806 (45)	total: 24.3s	remaining: 28.5s
# 46:	total: 24.8s	remaining: 28s
# 47:	total: 25.3s	remaining: 27.5s
# 48:	total: 25.9s	remaining: 26.9s
# 49:	total: 26.4s	remaining: 26.4s
# 50:	learn: 0.0195929	test: 0.0257680	best: 0.0257680 (50)	total: 26.9s	remaining: 25.8s
# 51:	total: 27.4s	remaining: 25.3s
# 52:	total: 27.9s	remaining: 24.8s
# 53:	total: 28.4s	remaining: 24.2s
# 54:	total: 29s	remaining: 23.7s
# 55:	learn: 0.0192763	test: 0.0255966	best: 0.0255966 (55)	total: 29.5s	remaining: 23.2s
# 56:	total: 30s	remaining: 22.6s
# 57:	total: 30.5s	remaining: 22.1s
# 58:	total: 31s	remaining: 21.6s
# 59:	total: 31.5s	remaining: 21s
# 60:	learn: 0.0189413	test: 0.0254354	best: 0.0254354 (60)	total: 32s	remaining: 20.5s
# 61:	total: 32.6s	remaining: 20s
# 62:	total: 33.1s	remaining: 19.4s
# 63:	total: 33.6s	remaining: 18.9s
# 64:	total: 34.1s	remaining: 18.4s
# 65:	learn: 0.0187993	test: 0.0253451	best: 0.0253451 (65)	total: 34.6s	remaining: 17.8s
# 66:	total: 35.1s	remaining: 17.3s
# 67:	total: 35.7s	remaining: 16.8s
# 68:	total: 36.2s	remaining: 16.3s
# 69:	total: 36.7s	remaining: 15.7s
# 70:	learn: 0.0185247	test: 0.0251976	best: 0.0251976 (70)	total: 37.2s	remaining: 15.2s
# 71:	total: 37.8s	remaining: 14.7s
# 72:	total: 38.3s	remaining: 14.2s
# 73:	total: 38.8s	remaining: 13.6s
# 74:	total: 39.3s	remaining: 13.1s
# 75:	learn: 0.0180556	test: 0.0248778	best: 0.0248778 (75)	total: 39.9s	remaining: 12.6s
# 76:	total: 40.4s	remaining: 12.1s
# 77:	total: 40.9s	remaining: 11.5s
# 78:	total: 41.4s	remaining: 11s
# 79:	total: 41.9s	remaining: 10.5s
# 80:	learn: 0.0176056	test: 0.0247137	best: 0.0247137 (80)	total: 42.5s	remaining: 9.96s
# 81:	total: 43s	remaining: 9.43s
# 82:	total: 43.5s	remaining: 8.91s
# 83:	total: 44s	remaining: 8.38s
# 84:	total: 44.5s	remaining: 7.86s
# 85:	learn: 0.0172206	test: 0.0244752	best: 0.0244752 (85)	total: 45s	remaining: 7.33s
# 86:	total: 45.6s	remaining: 6.81s
# 87:	total: 46.1s	remaining: 6.28s
# 88:	total: 46.6s	remaining: 5.76s
# 89:	total: 47.1s	remaining: 5.24s
# 90:	learn: 0.0164923	test: 0.0239985	best: 0.0239985 (90)	total: 47.7s	remaining: 4.71s
# 91:	total: 48.2s	remaining: 4.19s
# 92:	total: 48.7s	remaining: 3.66s
# 93:	total: 49.2s	remaining: 3.14s
# 94:	total: 49.7s	remaining: 2.62s
# 95:	learn: 0.0163339	test: 0.0239210	best: 0.0239210 (95)	total: 50.2s	remaining: 2.09s
# 96:	total: 50.7s	remaining: 1.57s
# 97:	total: 51.2s	remaining: 1.04s
# 98:	total: 51.8s	remaining: 523ms
# 99:	learn: 0.0162671	test: 0.0238680	best: 0.0238680 (99)	total: 52.3s	remaining: 0us
# bestTest = 0.02386801875
# bestIteration = 99

# %% [markdown]
# ### 2.2.2. Checking Performance
#
# Using the split for validation for a bit of internal checking of performance (i.e., not official)

# %%
y_pred = tb_catb.predict(X_tb_validate)
print("CATB_TB")
print(classification_report(y_tb_validate, y_pred, digits=4))
print(classification_report(y_tb_validate, y_pred, digits=4), file=open("Outputs/CATB/"+MODEL_FILENAME+"_CATB_TB_ClassReport.txt", mode='w'))
disp = ConfusionMatrixDisplay(confusion_matrix(y_tb_validate, y_pred))
disp.plot()
plt.savefig("Outputs/CATB/"+MODEL_FILENAME+"_CATB_TB_"+"_ConfMatrix.png")
# Out:
# CATB_TB
#               precision    recall  f1-score   support
#
#            0     0.9993    0.9896    0.9944     10842
#            1     0.9897    0.9993    0.9944     10848
#
#     accuracy                         0.9944     21690
#    macro avg     0.9945    0.9944    0.9944     21690
# weighted avg     0.9945    0.9944    0.9944     21690

# %% [markdown]
# ### 2.2.3. Preview of the Tree
#
# *How can it be a tree if there is no proof of a tree?*

# %%
tree = tb_catb.plot_tree(0, catboost.Pool(X_tb_training, y_tb_training, cat_features=get_indexes(), feature_names=list(X_tb_training.columns)))
tree.save("Outputs/CATB/"+MODEL_FILENAME+"_CATB_TREE/TB_Tree"+".svg")
display(tree)

# %% [markdown]
# ## 2.3. Training on Instance-Based Behaviors

# %% [markdown]
# ### 2.3.1 Training Model

# %%
#Training Model
start_time()
ib_catb = setup_model(IB_HYPERPARAMS, "IB")
ib_catb.fit(X_ib_training, y_ib_training, plot=True, eval_set=catboost.Pool(X_ib_validate, label=y_ib_validate, cat_features=get_indexes()), save_snapshot=True, snapshot_interval=60)
end_time("CATB_IB")

#Saving Model as file
ib_catb.save_model("Outputs/CATB/"+MODEL_FILENAME+"_CATB_IB.model", format="json")
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Default metric period is 5 because AUC is/are not implemented for GPU
# 0:	learn: 0.4384655	test: 0.4396288	best: 0.4396288 (0)	total: 531ms	remaining: 52.6s
# 1:	total: 983ms	remaining: 48.1s
# 2:	total: 1.45s	remaining: 46.7s
# 3:	total: 1.88s	remaining: 45.2s
# 4:	total: 2.32s	remaining: 44.1s
# 5:	learn: 0.0842512	test: 0.0858868	best: 0.0858868 (5)	total: 2.75s	remaining: 43.2s
# 6:	total: 3.19s	remaining: 42.3s
# 7:	total: 3.62s	remaining: 41.6s
# 8:	total: 4.05s	remaining: 41s
# 9:	total: 4.49s	remaining: 40.4s
# 10:	learn: 0.0398266	test: 0.0423627	best: 0.0423627 (10)	total: 4.92s	remaining: 39.8s
# 11:	total: 5.35s	remaining: 39.3s
# 12:	total: 5.78s	remaining: 38.7s
# 13:	total: 6.21s	remaining: 38.2s
# 14:	total: 6.64s	remaining: 37.6s
# 15:	learn: 0.0305973	test: 0.0339871	best: 0.0339871 (15)	total: 7.09s	remaining: 37.2s
# 16:	total: 7.52s	remaining: 36.7s
# 17:	total: 7.95s	remaining: 36.2s
# 18:	total: 8.37s	remaining: 35.7s
# 19:	total: 8.81s	remaining: 35.2s
# 20:	learn: 0.0271338	test: 0.0309321	best: 0.0309321 (20)	total: 9.24s	remaining: 34.8s
# 21:	total: 9.67s	remaining: 34.3s
# 22:	total: 10.1s	remaining: 33.8s
# 23:	total: 10.5s	remaining: 33.4s
# 24:	total: 11s	remaining: 33s
# 25:	learn: 0.0255941	test: 0.0299658	best: 0.0299658 (25)	total: 11.4s	remaining: 32.5s
# 26:	total: 11.9s	remaining: 32s
# 27:	total: 12.3s	remaining: 31.6s
# 28:	total: 12.7s	remaining: 31.2s
# 29:	total: 13.2s	remaining: 30.7s
# 30:	learn: 0.0248789	test: 0.0296600	best: 0.0296600 (30)	total: 13.6s	remaining: 30.3s
# 31:	total: 14s	remaining: 29.8s
# 32:	total: 14.5s	remaining: 29.4s
# 33:	total: 14.9s	remaining: 29s
# 34:	total: 15.4s	remaining: 28.6s
# 35:	learn: 0.0241238	test: 0.0293217	best: 0.0293217 (35)	total: 15.8s	remaining: 28.1s
# 36:	total: 16.2s	remaining: 27.7s
# 37:	total: 16.7s	remaining: 27.2s
# 38:	total: 17.1s	remaining: 26.8s
# 39:	total: 17.6s	remaining: 26.3s
# 40:	learn: 0.0227539	test: 0.0281938	best: 0.0281938 (40)	total: 18s	remaining: 25.9s
# 41:	total: 18.5s	remaining: 25.5s
# 42:	total: 18.9s	remaining: 25s
# 43:	total: 19.3s	remaining: 24.6s
# 44:	total: 19.8s	remaining: 24.2s
# 45:	learn: 0.0221692	test: 0.0277851	best: 0.0277851 (45)	total: 20.2s	remaining: 23.7s
# 46:	total: 20.7s	remaining: 23.3s
# 47:	total: 21.1s	remaining: 22.9s
# 48:	total: 21.6s	remaining: 22.5s
# 49:	total: 22s	remaining: 22s
# 50:	learn: 0.0216504	test: 0.0275184	best: 0.0275184 (50)	total: 22.5s	remaining: 21.6s
# 51:	total: 23s	remaining: 21.2s
# 52:	total: 23.4s	remaining: 20.7s
# 53:	total: 23.8s	remaining: 20.3s
# 54:	total: 24.3s	remaining: 19.8s
# 55:	learn: 0.0214260	test: 0.0275709	best: 0.0275184 (50)	total: 24.7s	remaining: 19.4s
# 56:	total: 25.1s	remaining: 19s
# 57:	total: 25.6s	remaining: 18.5s
# 58:	total: 26s	remaining: 18.1s
# 59:	total: 26.4s	remaining: 17.6s
# 60:	learn: 0.0210487	test: 0.0273976	best: 0.0273976 (60)	total: 26.9s	remaining: 17.2s
# 61:	total: 27.3s	remaining: 16.7s
# 62:	total: 27.8s	remaining: 16.3s
# 63:	total: 28.2s	remaining: 15.8s
# 64:	total: 28.6s	remaining: 15.4s
# 65:	learn: 0.0209230	test: 0.0273747	best: 0.0273747 (65)	total: 29s	remaining: 15s
# 66:	total: 29.5s	remaining: 14.5s
# 67:	total: 29.9s	remaining: 14.1s
# 68:	total: 30.3s	remaining: 13.6s
# 69:	total: 30.8s	remaining: 13.2s
# 70:	learn: 0.0206647	test: 0.0272740	best: 0.0272740 (70)	total: 31.2s	remaining: 12.7s
# 71:	total: 31.6s	remaining: 12.3s
# 72:	total: 32s	remaining: 11.8s
# 73:	total: 32.5s	remaining: 11.4s
# 74:	total: 32.9s	remaining: 11s
# 75:	learn: 0.0205690	test: 0.0272493	best: 0.0272493 (75)	total: 33.3s	remaining: 10.5s
# 76:	total: 33.8s	remaining: 10.1s
# 77:	total: 34.2s	remaining: 9.64s
# 78:	total: 34.6s	remaining: 9.2s
# 79:	total: 35s	remaining: 8.76s
# 80:	learn: 0.0204725	test: 0.0272175	best: 0.0272175 (80)	total: 35.5s	remaining: 8.32s
# 81:	total: 35.9s	remaining: 7.88s
# 82:	total: 36.3s	remaining: 7.44s
# 83:	total: 36.8s	remaining: 7s
# 84:	total: 37.2s	remaining: 6.56s
# 85:	learn: 0.0204231	test: 0.0272357	best: 0.0272175 (80)	total: 37.6s	remaining: 6.13s
# 86:	total: 38.1s	remaining: 5.69s
# 87:	total: 38.5s	remaining: 5.25s
# 88:	total: 38.9s	remaining: 4.81s
# 89:	total: 39.3s	remaining: 4.37s
# 90:	learn: 0.0203357	test: 0.0272039	best: 0.0272039 (90)	total: 39.8s	remaining: 3.93s
# 91:	total: 40.2s	remaining: 3.5s
# 92:	total: 40.6s	remaining: 3.06s
# 93:	total: 41.1s	remaining: 2.62s
# 94:	total: 41.5s	remaining: 2.18s
# 95:	learn: 0.0203021	test: 0.0272294	best: 0.0272039 (90)	total: 41.9s	remaining: 1.75s
# 96:	total: 42.3s	remaining: 1.31s
# 97:	total: 42.8s	remaining: 873ms
# 98:	total: 43.2s	remaining: 436ms
# 99:	learn: 0.0199302	test: 0.0270112	best: 0.0270112 (99)	total: 43.6s	remaining: 0us
# bestTest = 0.02701115483
# bestIteration = 99

# %% [markdown]
# ### 2.3.2. Checking Performance
#
# Using the split for validation for a bit of internal checking of performance (i.e., not official)

# %%
y_pred = ib_catb.predict(X_ib_validate)
print("CATB_IB")
print(classification_report(y_ib_validate, y_pred, digits=4))
print(classification_report(y_ib_validate, y_pred, digits=4), file=open("Outputs/CATB/"+MODEL_FILENAME+"_CATB_IB_ClassReport.txt", mode='w'))
disp = ConfusionMatrixDisplay(confusion_matrix(y_ib_validate, y_pred))
disp.plot()
plt.savefig("Outputs/CATB/"+MODEL_FILENAME+"_CATB_IB_"+"_ConfMatrix.png")
# Out:
# CATB_IB
#               precision    recall  f1-score   support
#
#            0     0.9985    0.9897    0.9941     10842
#            1     0.9898    0.9985    0.9941     10848
#
#     accuracy                         0.9941     21690
#    macro avg     0.9941    0.9941    0.9941     21690
# weighted avg     0.9941    0.9941    0.9941     21690

# %% [markdown]
# ### 2.3.3. Preview of the Tree
#
# *How can it be a tree if there is no proof of a tree?*

# %%
tree = ib_catb.plot_tree(0, catboost.Pool(X_ib_training, y_ib_training, cat_features=get_indexes(), feature_names=list(X_ib_training.columns)))
tree.save("Outputs/CATB/"+MODEL_FILENAME+"_CATB_TREE/IB_Tree"+".svg")
tree

# %%
logging("\n")
