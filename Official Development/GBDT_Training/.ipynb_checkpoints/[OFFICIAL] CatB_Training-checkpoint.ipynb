# %% [markdown]
# # Evaluation and Comparison of Boosted ML Models in Behavior-Based Malware Detection
#
#
# ## Notebook: CatBoost Training
#
# ***
#
# **What is the objective of this file?**
#
# To train the model using the Train Split (Statically Split).

# %% [markdown]
# ## Checklist
#
# - Ensure that you have the proper dataset files that you intend to use (i.e., whether the lite dataset or full version).
#     - The datasets it will use points to `/Official Development/Dataset/IB` & `/Official Development/Dataset/TB`.
#     - You can run the `/Official Development/Dataset [OFFICIAL] Oliveira Dataset Notebook.ipynb file` or unzip one of the zipped folders in the `/Official Development/Dataset/Processed` towards the two aforementioned folders.
# - Ensure that you have installed the necessary libraries needed to execute the training process.
#     - You can view the list of the specific versions in the thesis document or through the `.sh` or `.bat` files in the repository's home directory.

# %% [markdown]
# # 1. CatB Training Setup
#
# Setting training environment parameters.

# %% [markdown]
# ## 1.0. Tuning Settings
#
# 1. What will the output filename be?
# 2. Will you train a tuned model?
# 3. What hyperparameter values will you use?
#
# For no. 3, the value looks like
# `{'task_type': 'CPU', 'objective': 'Logloss', 'n_estimators': 50, 'max_depth': 11, 'learning_rate': 0.1, 'l2_leaf_reg': 2, 'grow_policy': 'SymmetricTree', 'bootstrap_type': 'Bayesian', 'boosting_type': 'Ordered', 'auto_class_weights': 'Balanced'}`
# which is obtained as part of the results of the associated tuning file to this file.
#
# Alternatively, you can just point a file directly to it (overrides the manual setup if not empty).
#
# **Do not include the custom hyperparameter values for `random_state`, `thread_count`, `verbose`, `cat_features`, and `nan_mode` as the values for these are hardcoded to the notebook.**

# %%
MODEL_FILENAME = "RYZEN3b" # <== Set the prefix for the filename of the output file (don't include file extension)
TUNED_TRAINING = True # <== Set as True if you'll be training a tuned model.

# These parameters are mostly default valued parameters for CatBoost except some that are mentioned in the paper (e.g., Ordered Boosting, Symmeteric Tree); Set as None for truly defaults.
TB_HYPERPARAMS = None # None or like "{'task_type': 'CPU', 'objective':'Logloss', 'grow_policy': 'SymmetricTree', 'bootstrap_type': 'Bayesian', 'boosting_type': 'Ordered'}"
IB_HYPERPARAMS = None # None or like "{'task_type': 'CPU', 'objective':'Logloss', 'grow_policy': 'SymmetricTree', 'bootstrap_type': 'Bayesian', 'boosting_type': 'Ordered'}"

TB_HYPERPARAMS_FILE = "./Outputs/CATB/Tuning/RYZEN3b_CATB_TB.tune" # <== Empty string or Pointing a .tune file overrides the value set above.
IB_HYPERPARAMS_FILE = "./Outputs/CATB/Tuning/RYZEN3b_CATB_IB.tune" # <== Empty string or Pointing a .tune file overrides the value set above.

STATIC_SPLIT = 0.3 # <== To achieve the 70:30 Static Split
RANDOM_SEED = 1 # <== Must be the same throughout the entire study (acts as a controlled variable), hence let's just settle with 1.

# %% [markdown]
# # ⚠️Warning
#
# **Be careful of modifying the code beyond this point as it was designed to run autonomously based on the parameters set above.**

# %% [markdown]
# ## 1.1. Loading Libraries

# %%
#Python Libraries
import time
from datetime import datetime
import json

#Data/Dataset Libraries
import pandas as pd
import numpy as np

#Model Selection
from sklearn.model_selection import train_test_split

#Metrics (for in-training testing only)
from sklearn.metrics import classification_report, accuracy_score, balanced_accuracy_score, f1_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import precision_score, recall_score, roc_auc_score

#Visualization
from matplotlib import pyplot as plt

#GBDT Models
# import lightgbm
import catboost

#File Writing Library (exclusive for use on LightGBM)
from joblib import dump, load

# %% [markdown]
# ## 1.2. Logging and Diagnostics

# %%
if TUNED_TRAINING:
    MODEL_FILENAME = "TUNED_" + MODEL_FILENAME
    if len(TB_HYPERPARAMS_FILE) != 0:
        f = open(TB_HYPERPARAMS_FILE, "r")
        TB_HYPERPARAMS = f.readline()
        f.close()
    if len(IB_HYPERPARAMS_FILE) != 0:
        f = open(IB_HYPERPARAMS_FILE, "r")
        IB_HYPERPARAMS = f.readline()
        f.close()
    TB_HYPERPARAMS = TB_HYPERPARAMS.replace('\'', '\"')#.replace("False", "\"False\"").replace("True", "\"True\"")
    TB_HYPERPARAMS = json.loads(str(TB_HYPERPARAMS))
    print("Parsed TB Hyperparams:", TB_HYPERPARAMS)
    print("")
    IB_HYPERPARAMS = IB_HYPERPARAMS.replace('\'', '\"')#.replace("False", "\"False\"").replace("True", "\"True\"")
    IB_HYPERPARAMS = json.loads(str(IB_HYPERPARAMS))
    print("Parsed IB Hyperparams:", IB_HYPERPARAMS)
else:
    if TB_HYPERPARAMS != None:
        TB_HYPERPARAMS = TB_HYPERPARAMS.replace('\'', '\"').replace("False", "\"False\"").replace("True", "\"True\"")
        TB_HYPERPARAMS = json.loads(str(TB_HYPERPARAMS))
    else:
        TB_HYPERPARAMS = None
    if IB_HYPERPARAMS != None:
        IB_HYPERPARAMS = IB_HYPERPARAMS.replace('\'', '\"').replace("False", "\"False\"").replace("True", "\"True\"")
        IB_HYPERPARAMS = json.loads(str(IB_HYPERPARAMS))
    else:
        IB_HYPERPARAMS = None

start = end = 0
LOG_FILENAME = "CATB_Training_Log.txt"
def logging(message):
    log = open(LOG_FILENAME, "a")
    log.write(message)
    log.close()
def start_time():
    global start
    start = time.time()
def end_time(process):
    global start
    elapse = time.time()-start
    start = 0
    printout = f"{str(datetime.now())}@{MODEL_FILENAME}: {process} - {round(elapse, 6)}s\n"
    logging(printout)
    return round(elapse, 6)
# Out:
# Parsed TB Hyperparams: {'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'gpu_cat_features_storage': 'CpuPinnedMemory', 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 1, 'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 500, 'objective': 'Logloss', 'task_type': 'GPU'}
#
# Parsed IB Hyperparams: {'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'gpu_cat_features_storage': 'CpuPinnedMemory', 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 1, 'learning_rate': 0.2, 'max_depth': 10, 'n_estimators': 100, 'objective': 'Logloss', 'task_type': 'GPU'}

# %% [markdown]
# ## 1.3. Loading Datasets
#
# Note that it will use the files in `/Official Development/Dataset/IB` & `/Official Development/Dataset/TB`.

# %% [markdown]
# ### 1.3.1. Setting filenames

# %%
#Setting filenames of files
TB_Train = "../Dataset/TB/CATB_TB.csv" # <== Location for Time-based Train Split for CatBoost
#TB_Test = "../Dataset/TB/TB_Test_CATB.csv" # <== Location for Time-based Test Split for CatBoost
IB_Train = "../Dataset/IB/CATB_IB.csv" # <== Location for Instance-based Train Split for CatBoost
#IB_Test = "../Dataset/IB/IB_Test_CATB.csv" # <== Location for Instance-based Test Split for CatBoost

# %% [markdown]
# ### 1.3.2. Loading datasets to DataFrames

# %%
#Loading datasets to DataFrames
tb_train = pd.read_csv(TB_Train, low_memory=False).fillna("NaN")
ib_train = pd.read_csv(IB_Train, low_memory=False).fillna("NaN")

print("Dataset Sizes")
print("TB Train Size:", tb_train.shape)
print("IB Train Size:", ib_train.shape)
# Out:
# Dataset Sizes
# TB Train Size: (72298, 101)
# IB Train Size: (72298, 101)

# %% [markdown]
# ### 1.3.3. Previewing datasets

# %%
#Previewing Time-based Dataset
tb_train.head()
# Out:
#    malware                      t_0             t_1                      t_2  \
# 0        1            RegOpenKeyExA       NtOpenKey          NtQueryValueKey
# 1        1  GetSystemTimeAsFileTime      LdrLoadDll   LdrGetProcedureAddress
# 2        1  GetSystemTimeAsFileTime  NtCreateMutant  GetSystemTimeAsFileTime
# 3        1  GetSystemTimeAsFileTime      LdrLoadDll   LdrGetProcedureAddress
# 4        1             SetErrorMode   OleInitialize          LdrGetDllHandle
#
#            t_3                     t_4              t_5  \
# 0      NtClose               NtOpenKey  NtQueryValueKey
# 1   LdrLoadDll  LdrGetProcedureAddress       LdrLoadDll
# 2  NtOpenKeyEx              NtQueryKey      NtOpenKeyEx
# 3   LdrLoadDll  LdrGetProcedureAddress       LdrLoadDll
# 4   LdrLoadDll  LdrGetProcedureAddress       LdrLoadDll
#
#                       t_6                     t_7                     t_8  \
# 0                 NtClose   NtQueryAttributesFile             LoadStringA
# 1  LdrGetProcedureAddress              LdrLoadDll  LdrGetProcedureAddress
# 2              LdrLoadDll  LdrGetProcedureAddress           RegOpenKeyExW
# 3  LdrGetProcedureAddress              LdrLoadDll  LdrGetProcedureAddress
# 4  LdrGetProcedureAddress              LdrLoadDll  LdrGetProcedureAddress
#
#    ...                    t_90                        t_91  \
# 0  ...  LdrGetProcedureAddress  GetSystemWindowsDirectoryW
# 1  ...        RegQueryInfoKeyW               RegEnumKeyExW
# 2  ...           GetSystemInfo                     NtClose
# 3  ...        RegQueryValueExW               RegOpenKeyExW
# 4  ...           RegOpenKeyExW            RegQueryValueExW
#
#                    t_92              t_93                 t_94  \
# 0          NtCreateFile   NtCreateSection   NtMapViewOfSection
# 1         RegOpenKeyExW  RegQueryValueExW        RegOpenKeyExW
# 2  NtUnmapViewOfSection           NtClose        RegOpenKeyExW
# 3      RegQueryValueExW     RegOpenKeyExW     RegQueryValueExW
# 4           RegCloseKey    NtCreateMutant  GetNativeSystemInfo
#
#                          t_95              t_96                     t_97  \
# 0                     NtClose  GetSystemMetrics  NtAllocateVirtualMemory
# 1            RegQueryValueExW     RegOpenKeyExW         RegQueryValueExW
# 2                 RegCloseKey     RegOpenKeyExW         RegQueryValueExW
# 3               RegOpenKeyExW  RegQueryValueExW            RegOpenKeyExW
# 4  GetSystemWindowsDirectoryW           NtClose               LdrLoadDll
#
#                      t_98                        t_99
# 0           CreateActCtxW  GetSystemWindowsDirectoryW
# 1           RegOpenKeyExW            RegQueryValueExW
# 2             RegCloseKey                  NtOpenFile
# 3        RegQueryValueExW               RegOpenKeyExW
# 4  LdrGetProcedureAddress                  LdrLoadDll
#
# [5 rows x 101 columns]

# %%
#Previewing Instance-based Dataset
ib_train.head()
# Out:
#    malware                      t_0             t_1                     t_2  \
# 0        1            RegOpenKeyExA       NtOpenKey         NtQueryValueKey
# 1        1  GetSystemTimeAsFileTime      LdrLoadDll  LdrGetProcedureAddress
# 2        1  GetSystemTimeAsFileTime  NtCreateMutant             NtOpenKeyEx
# 3        1  GetSystemTimeAsFileTime      LdrLoadDll  LdrGetProcedureAddress
# 4        1             SetErrorMode   OleInitialize         LdrGetDllHandle
#
#                t_3                          t_4                     t_5  \
# 0          NtClose        NtQueryAttributesFile             LoadStringA
# 1  LdrGetDllHandle  SetUnhandledExceptionFilter    CryptAcquireContextW
# 2       NtQueryKey                   LdrLoadDll  LdrGetProcedureAddress
# 3  LdrGetDllHandle  SetUnhandledExceptionFilter    CryptAcquireContextW
# 4       LdrLoadDll       LdrGetProcedureAddress           NtOpenSection
#
#                        t_6               t_7                     t_8  ...  \
# 0  NtAllocateVirtualMemory   LdrGetDllHandle  LdrGetProcedureAddress  ...
# 1                NtOpenKey   NtQueryValueKey                 NtClose  ...
# 2            RegOpenKeyExW  RegQueryInfoKeyW           RegEnumKeyExW  ...
# 3                NtOpenKey   NtQueryValueKey                 NtClose  ...
# 4       NtMapViewOfSection     RegOpenKeyExW        RegQueryValueExW  ...
#
#   t_90 t_91 t_92 t_93 t_94 t_95 t_96 t_97 t_98 t_99
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 101 columns]

# %% [markdown]
# ### 1.3.4. Statically Splitting the Train Split
#
# Train Split --> Training and Validation Split
#
# However only Training Split will be used.

# %%
#Static splitting of Train Split of Time-based
X_tb = tb_train.iloc[:,1:101] #All rows, 2nd to last column
y_tb = tb_train.iloc[:,0] #All rows, first column only
X_tb_training, X_tb_validate, y_tb_training, y_tb_validate = train_test_split(X_tb, y_tb, test_size=STATIC_SPLIT, shuffle=True, random_state=1)

#Static splitting of Train Split of Instance-based
X_ib = ib_train.iloc[:,1:101] #All rows, 2nd to last column
y_ib = ib_train.iloc[:,0] #All rows, first column only
X_ib_training, X_ib_validate, y_ib_training, y_ib_validate = train_test_split(X_ib, y_ib, test_size=STATIC_SPLIT, shuffle=True, random_state=1)

# %% [markdown]
# # 2. Model Training

# %% [markdown]
# ## 2.1. Setting up the Model

# %%
def get_indexes():
    indexes = []
    for i in range(100):
        indexes.append(f"t_{i}")
    return indexes

def setup_model(HYPERPARAMS, TYPE):
    global TUNED_TRAINING
    indexes = get_indexes()
    metric=['Logloss', 'AUC', 'Precision']
    train_dir = f"Outputs/CATB/{MODEL_FILENAME}_CATB_{TYPE}_TRAINDIR"
    if HYPERPARAMS == None:
        return catboost.CatBoostClassifier(random_state=RANDOM_SEED, thread_count=-1, verbose=1, cat_features=indexes, 
                                           nan_mode='Min', custom_metric=metric, train_dir=train_dir, one_hot_max_size=256)
    return catboost.CatBoostClassifier(**HYPERPARAMS, random_state=RANDOM_SEED, thread_count=-1, verbose=1, cat_features=indexes, 
                                       nan_mode='Min', custom_metric=metric, train_dir=train_dir, one_hot_max_size=256)

# %% [markdown]
# ## 2.2. Training on Time-Based Behaviors

# %% [markdown]
# ### 2.2.1 Training Model

# %%
#Training Model
start_time()
tb_catb = setup_model(TB_HYPERPARAMS, "TB")
tb_catb.fit(X_tb_training, y_tb_training, plot=True, eval_set=catboost.Pool(X_tb_validate, label=y_tb_validate, cat_features=get_indexes()), save_snapshot=True, snapshot_interval=60)
end_time("CATB_TB")

#Saving Model as file
tb_catb.save_model("Outputs/CATB/"+MODEL_FILENAME+"_CATB_TB.model", format="json")
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Default metric period is 5 because AUC is/are not implemented for GPU
# 0:	learn: 0.4233485	test: 0.4237113	best: 0.4237113 (0)	total: 680ms	remaining: 5m 39s
# 1:	total: 1.22s	remaining: 5m 3s
# 2:	total: 1.76s	remaining: 4m 51s
# 3:	total: 2.29s	remaining: 4m 44s
# 4:	total: 2.83s	remaining: 4m 40s
# 5:	learn: 0.0764688	test: 0.0782590	best: 0.0782590 (5)	total: 3.37s	remaining: 4m 37s
# 6:	total: 3.9s	remaining: 4m 34s
# 7:	total: 4.43s	remaining: 4m 32s
# 8:	total: 4.95s	remaining: 4m 29s
# 9:	total: 5.47s	remaining: 4m 27s
# 10:	learn: 0.0392311	test: 0.0421832	best: 0.0421832 (10)	total: 5.99s	remaining: 4m 26s
# 11:	total: 6.51s	remaining: 4m 24s
# 12:	total: 7.03s	remaining: 4m 23s
# 13:	total: 7.56s	remaining: 4m 22s
# 14:	total: 8.08s	remaining: 4m 21s
# 15:	learn: 0.0292596	test: 0.0329479	best: 0.0329479 (15)	total: 8.6s	remaining: 4m 20s
# 16:	total: 9.11s	remaining: 4m 18s
# 17:	total: 9.63s	remaining: 4m 17s
# 18:	total: 10.1s	remaining: 4m 16s
# 19:	total: 10.7s	remaining: 4m 15s
# 20:	learn: 0.0251606	test: 0.0294153	best: 0.0294153 (20)	total: 11.2s	remaining: 4m 15s
# 21:	total: 11.7s	remaining: 4m 14s
# 22:	total: 12.2s	remaining: 4m 13s
# 23:	total: 12.7s	remaining: 4m 12s
# 24:	total: 13.2s	remaining: 4m 11s
# 25:	learn: 0.0234990	test: 0.0281239	best: 0.0281239 (25)	total: 13.7s	remaining: 4m 10s
# 26:	total: 14.3s	remaining: 4m 9s
# 27:	total: 14.8s	remaining: 4m 8s
# 28:	total: 15.3s	remaining: 4m 8s
# 29:	total: 15.8s	remaining: 4m 7s
# 30:	learn: 0.0221878	test: 0.0272996	best: 0.0272996 (30)	total: 16.3s	remaining: 4m 6s
# 31:	total: 16.8s	remaining: 4m 5s
# 32:	total: 17.3s	remaining: 4m 5s
# 33:	total: 17.8s	remaining: 4m 4s
# 34:	total: 18.3s	remaining: 4m 3s
# 35:	learn: 0.0210726	test: 0.0265130	best: 0.0265130 (35)	total: 18.9s	remaining: 4m 3s
# 36:	total: 19.4s	remaining: 4m 2s
# 37:	total: 19.9s	remaining: 4m 1s
# 38:	total: 20.4s	remaining: 4m
# 39:	total: 20.9s	remaining: 4m
# 40:	learn: 0.0206974	test: 0.0262490	best: 0.0262490 (40)	total: 21.4s	remaining: 3m 59s
# 41:	total: 22s	remaining: 3m 59s
# 42:	total: 22.5s	remaining: 3m 59s
# 43:	total: 23s	remaining: 3m 58s
# 44:	total: 23.6s	remaining: 3m 58s
# 45:	learn: 0.0197645	test: 0.0256364	best: 0.0256364 (45)	total: 24.1s	remaining: 3m 57s
# 46:	total: 24.6s	remaining: 3m 57s
# 47:	total: 25.1s	remaining: 3m 56s
# 48:	total: 25.6s	remaining: 3m 56s
# 49:	total: 26.2s	remaining: 3m 55s
# 50:	learn: 0.0192975	test: 0.0253428	best: 0.0253428 (50)	total: 26.7s	remaining: 3m 54s
# 51:	total: 27.2s	remaining: 3m 54s
# 52:	total: 27.7s	remaining: 3m 53s
# 53:	total: 28.2s	remaining: 3m 52s
# 54:	total: 28.7s	remaining: 3m 52s
# 55:	learn: 0.0188832	test: 0.0250520	best: 0.0250520 (55)	total: 29.2s	remaining: 3m 51s
# 56:	total: 29.7s	remaining: 3m 51s
# 57:	total: 30.3s	remaining: 3m 50s
# 58:	total: 30.8s	remaining: 3m 50s
# 59:	total: 31.3s	remaining: 3m 49s
# 60:	learn: 0.0183301	test: 0.0247459	best: 0.0247459 (60)	total: 31.8s	remaining: 3m 48s
# 61:	total: 32.3s	remaining: 3m 48s
# 62:	total: 32.8s	remaining: 3m 47s
# 63:	total: 33.3s	remaining: 3m 47s
# 64:	total: 33.9s	remaining: 3m 46s
# 65:	learn: 0.0181656	test: 0.0246978	best: 0.0246978 (65)	total: 34.4s	remaining: 3m 46s
# 66:	total: 34.9s	remaining: 3m 45s
# 67:	total: 35.4s	remaining: 3m 44s
# 68:	total: 35.9s	remaining: 3m 44s
# 69:	total: 36.4s	remaining: 3m 43s
# 70:	learn: 0.0179864	test: 0.0246444	best: 0.0246444 (70)	total: 36.9s	remaining: 3m 43s
# 71:	total: 37.4s	remaining: 3m 42s
# 72:	total: 37.9s	remaining: 3m 41s
# 73:	total: 38.5s	remaining: 3m 41s
# 74:	total: 39s	remaining: 3m 41s
# 75:	learn: 0.0172051	test: 0.0242157	best: 0.0242157 (75)	total: 39.5s	remaining: 3m 40s
# 76:	total: 40s	remaining: 3m 39s
# 77:	total: 40.5s	remaining: 3m 39s
# 78:	total: 41.1s	remaining: 3m 38s
# 79:	total: 41.6s	remaining: 3m 38s
# 80:	learn: 0.0167358	test: 0.0239368	best: 0.0239368 (80)	total: 42.1s	remaining: 3m 37s
# 81:	total: 42.6s	remaining: 3m 37s
# 82:	total: 43.1s	remaining: 3m 36s
# 83:	total: 43.6s	remaining: 3m 36s
# 84:	total: 44.1s	remaining: 3m 35s
# 85:	learn: 0.0163359	test: 0.0236946	best: 0.0236946 (85)	total: 44.7s	remaining: 3m 35s
# 86:	total: 45.2s	remaining: 3m 34s
# 87:	total: 45.7s	remaining: 3m 33s
# 88:	total: 46.2s	remaining: 3m 33s
# 89:	total: 46.7s	remaining: 3m 32s
# 90:	learn: 0.0161587	test: 0.0236364	best: 0.0236364 (90)	total: 47.2s	remaining: 3m 32s
# 91:	total: 47.8s	remaining: 3m 31s
# 92:	total: 48.3s	remaining: 3m 31s
# 93:	total: 48.8s	remaining: 3m 30s
# 94:	total: 49.3s	remaining: 3m 30s
# 95:	learn: 0.0160956	test: 0.0236273	best: 0.0236273 (95)	total: 49.8s	remaining: 3m 29s
# 96:	total: 50.3s	remaining: 3m 29s
# 97:	total: 50.8s	remaining: 3m 28s
# 98:	total: 51.4s	remaining: 3m 28s
# 99:	total: 51.9s	remaining: 3m 27s
# 100:	learn: 0.0160262	test: 0.0235946	best: 0.0235946 (100)	total: 52.4s	remaining: 3m 26s
# 101:	total: 52.9s	remaining: 3m 26s
# 102:	total: 53.4s	remaining: 3m 25s
# 103:	total: 53.9s	remaining: 3m 25s
# 104:	total: 54.4s	remaining: 3m 24s
# 105:	learn: 0.0158095	test: 0.0235269	best: 0.0235269 (105)	total: 54.9s	remaining: 3m 24s
# 106:	total: 55.5s	remaining: 3m 23s
# 107:	total: 56s	remaining: 3m 23s
# 108:	total: 56.5s	remaining: 3m 22s
# 109:	total: 57s	remaining: 3m 22s
# 110:	learn: 0.0154659	test: 0.0233102	best: 0.0233102 (110)	total: 57.5s	remaining: 3m 21s
# 111:	total: 58s	remaining: 3m 21s
# 112:	total: 58.5s	remaining: 3m 20s
# 113:	total: 59.1s	remaining: 3m 19s
# 114:	total: 59.6s	remaining: 3m 19s
# 115:	learn: 0.0149006	test: 0.0230310	best: 0.0230310 (115)	total: 1m	remaining: 3m 19s
# 116:	total: 1m	remaining: 3m 18s
# 117:	total: 1m 1s	remaining: 3m 17s
# 118:	total: 1m 1s	remaining: 3m 17s
# 119:	total: 1m 2s	remaining: 3m 16s
# 120:	learn: 0.0147515	test: 0.0229958	best: 0.0229958 (120)	total: 1m 2s	remaining: 3m 16s
# 121:	total: 1m 3s	remaining: 3m 15s
# 122:	total: 1m 3s	remaining: 3m 15s
# 123:	total: 1m 4s	remaining: 3m 14s
# 124:	total: 1m 4s	remaining: 3m 14s
# 125:	learn: 0.0145059	test: 0.0228805	best: 0.0228805 (125)	total: 1m 5s	remaining: 3m 13s
# 126:	total: 1m 5s	remaining: 3m 13s
# 127:	total: 1m 6s	remaining: 3m 12s
# 128:	total: 1m 6s	remaining: 3m 12s
# 129:	total: 1m 7s	remaining: 3m 11s
# 130:	learn: 0.0143823	test: 0.0228273	best: 0.0228273 (130)	total: 1m 7s	remaining: 3m 11s
# 131:	total: 1m 8s	remaining: 3m 10s
# 132:	total: 1m 8s	remaining: 3m 10s
# 133:	total: 1m 9s	remaining: 3m 9s
# 134:	total: 1m 9s	remaining: 3m 9s
# 135:	learn: 0.0140794	test: 0.0226264	best: 0.0226264 (135)	total: 1m 10s	remaining: 3m 8s
# 136:	total: 1m 10s	remaining: 3m 7s
# 137:	total: 1m 11s	remaining: 3m 7s
# 138:	total: 1m 11s	remaining: 3m 6s
# 139:	total: 1m 12s	remaining: 3m 6s
# 140:	learn: 0.0140556	test: 0.0226298	best: 0.0226264 (135)	total: 1m 12s	remaining: 3m 5s
# 141:	total: 1m 13s	remaining: 3m 5s
# 142:	total: 1m 14s	remaining: 3m 4s
# 143:	total: 1m 14s	remaining: 3m 4s
# 144:	total: 1m 15s	remaining: 3m 3s
# 145:	learn: 0.0137088	test: 0.0224512	best: 0.0224512 (145)	total: 1m 15s	remaining: 3m 3s
# 146:	total: 1m 16s	remaining: 3m 2s
# 147:	total: 1m 16s	remaining: 3m 2s
# 148:	total: 1m 17s	remaining: 3m 1s
# 149:	total: 1m 17s	remaining: 3m 1s
# 150:	learn: 0.0134800	test: 0.0223299	best: 0.0223299 (150)	total: 1m 18s	remaining: 3m
# 151:	total: 1m 18s	remaining: 3m
# 152:	total: 1m 19s	remaining: 2m 59s
# 153:	total: 1m 19s	remaining: 2m 59s
# 154:	total: 1m 20s	remaining: 2m 58s
# 155:	learn: 0.0134674	test: 0.0223277	best: 0.0223277 (155)	total: 1m 20s	remaining: 2m 57s
# 156:	total: 1m 21s	remaining: 2m 57s
# 157:	total: 1m 21s	remaining: 2m 56s
# 158:	total: 1m 22s	remaining: 2m 56s
# 159:	total: 1m 22s	remaining: 2m 55s
# 160:	learn: 0.0134116	test: 0.0223371	best: 0.0223277 (155)	total: 1m 23s	remaining: 2m 55s
# 161:	total: 1m 23s	remaining: 2m 54s
# 162:	total: 1m 24s	remaining: 2m 54s
# 163:	total: 1m 24s	remaining: 2m 53s
# 164:	total: 1m 25s	remaining: 2m 53s
# 165:	learn: 0.0133953	test: 0.0223319	best: 0.0223277 (155)	total: 1m 25s	remaining: 2m 52s
# 166:	total: 1m 26s	remaining: 2m 52s
# 167:	total: 1m 26s	remaining: 2m 51s
# 168:	total: 1m 27s	remaining: 2m 51s
# 169:	total: 1m 27s	remaining: 2m 50s
# 170:	learn: 0.0132048	test: 0.0222934	best: 0.0222934 (170)	total: 1m 28s	remaining: 2m 50s
# 171:	total: 1m 28s	remaining: 2m 49s
# 172:	total: 1m 29s	remaining: 2m 48s
# 173:	total: 1m 29s	remaining: 2m 48s
# 174:	total: 1m 30s	remaining: 2m 47s
# 175:	learn: 0.0131049	test: 0.0222471	best: 0.0222471 (175)	total: 1m 30s	remaining: 2m 47s
# 176:	total: 1m 31s	remaining: 2m 46s
# 177:	total: 1m 31s	remaining: 2m 46s
# 178:	total: 1m 32s	remaining: 2m 45s
# 179:	total: 1m 33s	remaining: 2m 45s
# 180:	learn: 0.0129503	test: 0.0221857	best: 0.0221857 (180)	total: 1m 33s	remaining: 2m 44s
# 181:	total: 1m 34s	remaining: 2m 44s
# 182:	total: 1m 34s	remaining: 2m 43s
# 183:	total: 1m 35s	remaining: 2m 43s
# 184:	total: 1m 35s	remaining: 2m 42s
# 185:	learn: 0.0125375	test: 0.0219505	best: 0.0219505 (185)	total: 1m 36s	remaining: 2m 42s
# 186:	total: 1m 36s	remaining: 2m 41s
# 187:	total: 1m 37s	remaining: 2m 41s
# 188:	total: 1m 37s	remaining: 2m 40s
# 189:	total: 1m 38s	remaining: 2m 40s
# 190:	learn: 0.0122659	test: 0.0217289	best: 0.0217289 (190)	total: 1m 38s	remaining: 2m 39s
# 191:	total: 1m 39s	remaining: 2m 39s
# 192:	total: 1m 39s	remaining: 2m 38s
# 193:	total: 1m 40s	remaining: 2m 38s
# 194:	total: 1m 40s	remaining: 2m 37s
# 195:	learn: 0.0122562	test: 0.0217234	best: 0.0217234 (195)	total: 1m 41s	remaining: 2m 37s
# 196:	total: 1m 41s	remaining: 2m 36s
# 197:	total: 1m 42s	remaining: 2m 35s
# 198:	total: 1m 42s	remaining: 2m 35s
# 199:	total: 1m 43s	remaining: 2m 34s
# 200:	learn: 0.0122112	test: 0.0216940	best: 0.0216940 (200)	total: 1m 43s	remaining: 2m 34s
# 201:	total: 1m 44s	remaining: 2m 33s
# 202:	total: 1m 44s	remaining: 2m 33s
# 203:	total: 1m 45s	remaining: 2m 32s
# 204:	total: 1m 45s	remaining: 2m 32s
# 205:	learn: 0.0121967	test: 0.0216884	best: 0.0216884 (205)	total: 1m 46s	remaining: 2m 31s
# 206:	total: 1m 46s	remaining: 2m 31s
# 207:	total: 1m 47s	remaining: 2m 30s
# 208:	total: 1m 47s	remaining: 2m 30s
# 209:	total: 1m 48s	remaining: 2m 29s
# 210:	learn: 0.0121041	test: 0.0216306	best: 0.0216306 (210)	total: 1m 48s	remaining: 2m 29s
# 211:	total: 1m 49s	remaining: 2m 28s
# 212:	total: 1m 49s	remaining: 2m 28s
# 213:	total: 1m 50s	remaining: 2m 27s
# 214:	total: 1m 51s	remaining: 2m 27s
# 215:	learn: 0.0120998	test: 0.0216314	best: 0.0216306 (210)	total: 1m 51s	remaining: 2m 26s
# 216:	total: 1m 52s	remaining: 2m 26s
# 217:	total: 1m 52s	remaining: 2m 25s
# 218:	total: 1m 53s	remaining: 2m 25s
# 219:	total: 1m 53s	remaining: 2m 24s
# 220:	learn: 0.0119723	test: 0.0215539	best: 0.0215539 (220)	total: 1m 54s	remaining: 2m 24s
# 221:	total: 1m 54s	remaining: 2m 23s
# 222:	total: 1m 55s	remaining: 2m 23s
# 223:	total: 1m 55s	remaining: 2m 22s
# 224:	total: 1m 56s	remaining: 2m 21s
# 225:	learn: 0.0119431	test: 0.0215421	best: 0.0215421 (225)	total: 1m 56s	remaining: 2m 21s
# 226:	total: 1m 57s	remaining: 2m 20s
# 227:	total: 1m 57s	remaining: 2m 20s
# 228:	total: 1m 58s	remaining: 2m 19s
# 229:	total: 1m 58s	remaining: 2m 19s
# 230:	learn: 0.0119126	test: 0.0215377	best: 0.0215377 (230)	total: 1m 59s	remaining: 2m 18s
# 231:	total: 1m 59s	remaining: 2m 18s
# 232:	total: 2m	remaining: 2m 17s
# 233:	total: 2m	remaining: 2m 17s
# 234:	total: 2m 1s	remaining: 2m 16s
# 235:	learn: 0.0118365	test: 0.0215078	best: 0.0215078 (235)	total: 2m 1s	remaining: 2m 16s
# 236:	total: 2m 2s	remaining: 2m 15s
# 237:	total: 2m 2s	remaining: 2m 15s
# 238:	total: 2m 3s	remaining: 2m 14s
# 239:	total: 2m 3s	remaining: 2m 14s
# 240:	learn: 0.0118331	test: 0.0215121	best: 0.0215078 (235)	total: 2m 4s	remaining: 2m 13s
# 241:	total: 2m 4s	remaining: 2m 13s
# 242:	total: 2m 5s	remaining: 2m 12s
# 243:	total: 2m 5s	remaining: 2m 12s
# 244:	total: 2m 6s	remaining: 2m 11s
# 245:	learn: 0.0118264	test: 0.0215099	best: 0.0215078 (235)	total: 2m 7s	remaining: 2m 11s
# 246:	total: 2m 7s	remaining: 2m 10s
# 247:	total: 2m 8s	remaining: 2m 10s
# 248:	total: 2m 8s	remaining: 2m 9s
# 249:	total: 2m 9s	remaining: 2m 9s
# 250:	learn: 0.0116373	test: 0.0213930	best: 0.0213930 (250)	total: 2m 9s	remaining: 2m 8s
# 251:	total: 2m 10s	remaining: 2m 8s
# 252:	total: 2m 10s	remaining: 2m 7s
# 253:	total: 2m 11s	remaining: 2m 7s
# 254:	total: 2m 11s	remaining: 2m 6s
# 255:	learn: 0.0115107	test: 0.0212857	best: 0.0212857 (255)	total: 2m 12s	remaining: 2m 5s
# 256:	total: 2m 12s	remaining: 2m 5s
# 257:	total: 2m 13s	remaining: 2m 4s
# 258:	total: 2m 13s	remaining: 2m 4s
# 259:	total: 2m 14s	remaining: 2m 3s
# 260:	learn: 0.0115044	test: 0.0212930	best: 0.0212857 (255)	total: 2m 14s	remaining: 2m 3s
# 261:	total: 2m 15s	remaining: 2m 2s
# 262:	total: 2m 15s	remaining: 2m 2s
# 263:	total: 2m 16s	remaining: 2m 1s
# 264:	total: 2m 16s	remaining: 2m 1s
# 265:	learn: 0.0112471	test: 0.0211063	best: 0.0211063 (265)	total: 2m 17s	remaining: 2m
# 266:	total: 2m 17s	remaining: 2m
# 267:	total: 2m 18s	remaining: 1m 59s
# 268:	total: 2m 18s	remaining: 1m 59s
# 269:	total: 2m 19s	remaining: 1m 58s
# 270:	learn: 0.0110985	test: 0.0210705	best: 0.0210705 (270)	total: 2m 19s	remaining: 1m 58s
# 271:	total: 2m 20s	remaining: 1m 57s
# 272:	total: 2m 20s	remaining: 1m 57s
# 273:	total: 2m 21s	remaining: 1m 56s
# 274:	total: 2m 21s	remaining: 1m 56s
# 275:	learn: 0.0107899	test: 0.0208718	best: 0.0208718 (275)	total: 2m 22s	remaining: 1m 55s
# 276:	total: 2m 23s	remaining: 1m 55s
# 277:	total: 2m 23s	remaining: 1m 54s
# 278:	total: 2m 24s	remaining: 1m 54s
# 279:	total: 2m 24s	remaining: 1m 53s
# 280:	learn: 0.0105753	test: 0.0207498	best: 0.0207498 (280)	total: 2m 25s	remaining: 1m 53s
# 281:	total: 2m 25s	remaining: 1m 52s
# 282:	total: 2m 26s	remaining: 1m 52s
# 283:	total: 2m 26s	remaining: 1m 51s
# 284:	total: 2m 27s	remaining: 1m 51s
# 285:	learn: 0.0104072	test: 0.0206770	best: 0.0206770 (285)	total: 2m 27s	remaining: 1m 50s
# 286:	total: 2m 28s	remaining: 1m 49s
# 287:	total: 2m 28s	remaining: 1m 49s
# 288:	total: 2m 29s	remaining: 1m 48s
# 289:	total: 2m 29s	remaining: 1m 48s
# 290:	learn: 0.0103338	test: 0.0206529	best: 0.0206529 (290)	total: 2m 30s	remaining: 1m 47s
# 291:	total: 2m 30s	remaining: 1m 47s
# 292:	total: 2m 31s	remaining: 1m 46s
# 293:	total: 2m 31s	remaining: 1m 46s
# 294:	total: 2m 32s	remaining: 1m 45s
# 295:	learn: 0.0102884	test: 0.0206195	best: 0.0206195 (295)	total: 2m 32s	remaining: 1m 45s
# 296:	total: 2m 33s	remaining: 1m 44s
# 297:	total: 2m 33s	remaining: 1m 44s
# 298:	total: 2m 34s	remaining: 1m 43s
# 299:	total: 2m 34s	remaining: 1m 43s
# 300:	learn: 0.0102825	test: 0.0206174	best: 0.0206174 (300)	total: 2m 35s	remaining: 1m 42s
# 301:	total: 2m 35s	remaining: 1m 42s
# 302:	total: 2m 36s	remaining: 1m 41s
# 303:	total: 2m 36s	remaining: 1m 41s
# 304:	total: 2m 37s	remaining: 1m 40s
# 305:	learn: 0.0102711	test: 0.0206133	best: 0.0206133 (305)	total: 2m 38s	remaining: 1m 40s
# 306:	total: 2m 38s	remaining: 1m 39s
# 307:	total: 2m 39s	remaining: 1m 39s
# 308:	total: 2m 39s	remaining: 1m 38s
# 309:	total: 2m 40s	remaining: 1m 38s
# 310:	learn: 0.0102675	test: 0.0206159	best: 0.0206133 (305)	total: 2m 40s	remaining: 1m 37s
# 311:	total: 2m 41s	remaining: 1m 37s
# 312:	total: 2m 41s	remaining: 1m 36s
# 313:	total: 2m 42s	remaining: 1m 36s
# 314:	total: 2m 42s	remaining: 1m 35s
# 315:	learn: 0.0102500	test: 0.0206024	best: 0.0206024 (315)	total: 2m 43s	remaining: 1m 35s
# 316:	total: 2m 43s	remaining: 1m 34s
# 317:	total: 2m 44s	remaining: 1m 33s
# 318:	total: 2m 44s	remaining: 1m 33s
# 319:	total: 2m 45s	remaining: 1m 32s
# 320:	learn: 0.0101172	test: 0.0204777	best: 0.0204777 (320)	total: 2m 45s	remaining: 1m 32s
# 321:	total: 2m 46s	remaining: 1m 31s
# 322:	total: 2m 46s	remaining: 1m 31s
# 323:	total: 2m 47s	remaining: 1m 30s
# 324:	total: 2m 47s	remaining: 1m 30s
# 325:	learn: 0.0099906	test: 0.0204166	best: 0.0204166 (325)	total: 2m 48s	remaining: 1m 29s
# 326:	total: 2m 48s	remaining: 1m 29s
# 327:	total: 2m 49s	remaining: 1m 28s
# 328:	total: 2m 49s	remaining: 1m 28s
# 329:	total: 2m 50s	remaining: 1m 27s
# 330:	learn: 0.0099260	test: 0.0203720	best: 0.0203720 (330)	total: 2m 50s	remaining: 1m 27s
# 331:	total: 2m 51s	remaining: 1m 26s
# 332:	total: 2m 51s	remaining: 1m 26s
# 333:	total: 2m 52s	remaining: 1m 25s
# 334:	total: 2m 52s	remaining: 1m 25s
# 335:	learn: 0.0099243	test: 0.0203677	best: 0.0203677 (335)	total: 2m 53s	remaining: 1m 24s
# 336:	total: 2m 54s	remaining: 1m 24s
# 337:	total: 2m 54s	remaining: 1m 23s
# 338:	total: 2m 55s	remaining: 1m 23s
# 339:	total: 2m 55s	remaining: 1m 22s
# 340:	learn: 0.0099230	test: 0.0203668	best: 0.0203668 (340)	total: 2m 56s	remaining: 1m 22s
# 341:	total: 2m 56s	remaining: 1m 21s
# 342:	total: 2m 57s	remaining: 1m 21s
# 343:	total: 2m 57s	remaining: 1m 20s
# 344:	total: 2m 58s	remaining: 1m 20s
# 345:	learn: 0.0098577	test: 0.0203295	best: 0.0203295 (345)	total: 2m 58s	remaining: 1m 19s
# 346:	total: 2m 59s	remaining: 1m 19s
# 347:	total: 2m 59s	remaining: 1m 18s
# 348:	total: 3m	remaining: 1m 17s
# 349:	total: 3m	remaining: 1m 17s
# 350:	learn: 0.0096130	test: 0.0201858	best: 0.0201858 (350)	total: 3m 1s	remaining: 1m 16s
# 351:	total: 3m 1s	remaining: 1m 16s
# 352:	total: 3m 2s	remaining: 1m 15s
# 353:	total: 3m 2s	remaining: 1m 15s
# 354:	total: 3m 3s	remaining: 1m 14s
# 355:	learn: 0.0095665	test: 0.0201992	best: 0.0201858 (350)	total: 3m 3s	remaining: 1m 14s
# 356:	total: 3m 4s	remaining: 1m 13s
# 357:	total: 3m 4s	remaining: 1m 13s
# 358:	total: 3m 5s	remaining: 1m 12s
# 359:	total: 3m 5s	remaining: 1m 12s
# 360:	learn: 0.0095599	test: 0.0201916	best: 0.0201858 (350)	total: 3m 6s	remaining: 1m 11s
# 361:	total: 3m 6s	remaining: 1m 11s
# 362:	total: 3m 7s	remaining: 1m 10s
# 363:	total: 3m 7s	remaining: 1m 10s
# 364:	total: 3m 8s	remaining: 1m 9s
# 365:	learn: 0.0094858	test: 0.0201425	best: 0.0201425 (365)	total: 3m 9s	remaining: 1m 9s
# 366:	total: 3m 9s	remaining: 1m 8s
# 367:	total: 3m 10s	remaining: 1m 8s
# 368:	total: 3m 10s	remaining: 1m 7s
# 369:	total: 3m 11s	remaining: 1m 7s
# 370:	learn: 0.0094844	test: 0.0201429	best: 0.0201425 (365)	total: 3m 11s	remaining: 1m 6s
# 371:	total: 3m 12s	remaining: 1m 6s
# 372:	total: 3m 12s	remaining: 1m 5s
# 373:	total: 3m 13s	remaining: 1m 5s
# 374:	total: 3m 13s	remaining: 1m 4s
# 375:	learn: 0.0094449	test: 0.0201360	best: 0.0201360 (375)	total: 3m 14s	remaining: 1m 4s
# 376:	total: 3m 14s	remaining: 1m 3s
# 377:	total: 3m 15s	remaining: 1m 2s
# 378:	total: 3m 15s	remaining: 1m 2s
# 379:	total: 3m 16s	remaining: 1m 1s
# 380:	learn: 0.0094291	test: 0.0201105	best: 0.0201105 (380)	total: 3m 16s	remaining: 1m 1s
# 381:	total: 3m 17s	remaining: 1m
# 382:	total: 3m 17s	remaining: 1m
# 383:	total: 3m 18s	remaining: 59.9s
# 384:	total: 3m 18s	remaining: 59.4s
# 385:	learn: 0.0094279	test: 0.0201151	best: 0.0201105 (380)	total: 3m 19s	remaining: 58.9s
# 386:	total: 3m 19s	remaining: 58.3s
# 387:	total: 3m 20s	remaining: 57.8s
# 388:	total: 3m 20s	remaining: 57.3s
# 389:	total: 3m 21s	remaining: 56.8s
# 390:	learn: 0.0093066	test: 0.0200598	best: 0.0200598 (390)	total: 3m 21s	remaining: 56.3s
# 391:	total: 3m 22s	remaining: 55.8s
# 392:	total: 3m 22s	remaining: 55.2s
# 393:	total: 3m 23s	remaining: 54.7s
# 394:	total: 3m 23s	remaining: 54.2s
# 395:	learn: 0.0093059	test: 0.0200621	best: 0.0200598 (390)	total: 3m 24s	remaining: 53.7s
# 396:	total: 3m 24s	remaining: 53.2s
# 397:	total: 3m 25s	remaining: 52.7s
# 398:	total: 3m 25s	remaining: 52.1s
# 399:	total: 3m 26s	remaining: 51.6s
# 400:	learn: 0.0092985	test: 0.0200724	best: 0.0200598 (390)	total: 3m 27s	remaining: 51.1s
# 401:	total: 3m 27s	remaining: 50.6s
# 402:	total: 3m 28s	remaining: 50.1s
# 403:	total: 3m 28s	remaining: 49.6s
# 404:	total: 3m 29s	remaining: 49s
# 405:	learn: 0.0092261	test: 0.0200213	best: 0.0200213 (405)	total: 3m 29s	remaining: 48.5s
# 406:	total: 3m 30s	remaining: 48s
# 407:	total: 3m 30s	remaining: 47.5s
# 408:	total: 3m 31s	remaining: 47s
# 409:	total: 3m 31s	remaining: 46.5s
# 410:	learn: 0.0092251	test: 0.0200253	best: 0.0200213 (405)	total: 3m 32s	remaining: 45.9s
# 411:	total: 3m 32s	remaining: 45.4s
# 412:	total: 3m 33s	remaining: 44.9s
# 413:	total: 3m 33s	remaining: 44.4s
# 414:	total: 3m 34s	remaining: 43.9s
# 415:	learn: 0.0092225	test: 0.0200206	best: 0.0200206 (415)	total: 3m 34s	remaining: 43.4s
# 416:	total: 3m 35s	remaining: 42.8s
# 417:	total: 3m 35s	remaining: 42.3s
# 418:	total: 3m 36s	remaining: 41.8s
# 419:	total: 3m 36s	remaining: 41.3s
# 420:	learn: 0.0092212	test: 0.0200245	best: 0.0200206 (415)	total: 3m 37s	remaining: 40.8s
# 421:	total: 3m 37s	remaining: 40.3s
# 422:	total: 3m 38s	remaining: 39.7s
# 423:	total: 3m 38s	remaining: 39.2s
# 424:	total: 3m 39s	remaining: 38.7s
# 425:	learn: 0.0092187	test: 0.0200289	best: 0.0200206 (415)	total: 3m 39s	remaining: 38.2s
# 426:	total: 3m 40s	remaining: 37.7s
# 427:	total: 3m 40s	remaining: 37.2s
# 428:	total: 3m 41s	remaining: 36.6s
# 429:	total: 3m 41s	remaining: 36.1s
# 430:	learn: 0.0092117	test: 0.0200265	best: 0.0200206 (415)	total: 3m 42s	remaining: 35.6s
# 431:	total: 3m 42s	remaining: 35.1s
# 432:	total: 3m 43s	remaining: 34.6s
# 433:	total: 3m 44s	remaining: 34.1s
# 434:	total: 3m 44s	remaining: 33.6s
# 435:	learn: 0.0092111	test: 0.0200253	best: 0.0200206 (415)	total: 3m 45s	remaining: 33s
# 436:	total: 3m 45s	remaining: 32.5s
# 437:	total: 3m 46s	remaining: 32s
# 438:	total: 3m 46s	remaining: 31.5s
# 439:	total: 3m 47s	remaining: 31s
# 440:	learn: 0.0092091	test: 0.0200259	best: 0.0200206 (415)	total: 3m 47s	remaining: 30.5s
# 441:	total: 3m 48s	remaining: 29.9s
# 442:	total: 3m 48s	remaining: 29.4s
# 443:	total: 3m 49s	remaining: 28.9s
# 444:	total: 3m 49s	remaining: 28.4s
# 445:	learn: 0.0091901	test: 0.0200358	best: 0.0200206 (415)	total: 3m 50s	remaining: 27.9s
# 446:	total: 3m 50s	remaining: 27.4s
# 447:	total: 3m 51s	remaining: 26.8s
# 448:	total: 3m 51s	remaining: 26.3s
# 449:	total: 3m 52s	remaining: 25.8s
# 450:	learn: 0.0091821	test: 0.0200353	best: 0.0200206 (415)	total: 3m 52s	remaining: 25.3s
# 451:	total: 3m 53s	remaining: 24.8s
# 452:	total: 3m 53s	remaining: 24.3s
# 453:	total: 3m 54s	remaining: 23.7s
# 454:	total: 3m 54s	remaining: 23.2s
# 455:	learn: 0.0091811	test: 0.0200375	best: 0.0200206 (415)	total: 3m 55s	remaining: 22.7s
# 456:	total: 3m 55s	remaining: 22.2s
# 457:	total: 3m 56s	remaining: 21.7s
# 458:	total: 3m 56s	remaining: 21.2s
# 459:	total: 3m 57s	remaining: 20.6s
# 460:	learn: 0.0091797	test: 0.0200407	best: 0.0200206 (415)	total: 3m 57s	remaining: 20.1s
# 461:	total: 3m 58s	remaining: 19.6s
# 462:	total: 3m 58s	remaining: 19.1s
# 463:	total: 3m 59s	remaining: 18.6s
# 464:	total: 4m	remaining: 18.1s
# 465:	learn: 0.0091728	test: 0.0200454	best: 0.0200206 (415)	total: 4m	remaining: 17.5s
# 466:	total: 4m 1s	remaining: 17s
# 467:	total: 4m 1s	remaining: 16.5s
# 468:	total: 4m 2s	remaining: 16s
# 469:	total: 4m 2s	remaining: 15.5s
# 470:	learn: 0.0091520	test: 0.0200544	best: 0.0200206 (415)	total: 4m 3s	remaining: 15s
# 471:	total: 4m 3s	remaining: 14.5s
# 472:	total: 4m 4s	remaining: 13.9s
# 473:	total: 4m 4s	remaining: 13.4s
# 474:	total: 4m 5s	remaining: 12.9s
# 475:	learn: 0.0090955	test: 0.0200647	best: 0.0200206 (415)	total: 4m 5s	remaining: 12.4s
# 476:	total: 4m 6s	remaining: 11.9s
# 477:	total: 4m 6s	remaining: 11.4s
# 478:	total: 4m 7s	remaining: 10.8s
# 479:	total: 4m 7s	remaining: 10.3s
# 480:	learn: 0.0090806	test: 0.0200669	best: 0.0200206 (415)	total: 4m 8s	remaining: 9.8s
# 481:	total: 4m 8s	remaining: 9.29s
# 482:	total: 4m 9s	remaining: 8.77s
# 483:	total: 4m 9s	remaining: 8.26s
# 484:	total: 4m 10s	remaining: 7.74s
# 485:	learn: 0.0090054	test: 0.0200436	best: 0.0200206 (415)	total: 4m 10s	remaining: 7.22s
# 486:	total: 4m 11s	remaining: 6.71s
# 487:	total: 4m 11s	remaining: 6.19s
# 488:	total: 4m 12s	remaining: 5.68s
# 489:	total: 4m 12s	remaining: 5.16s
# 490:	learn: 0.0090031	test: 0.0200494	best: 0.0200206 (415)	total: 4m 13s	remaining: 4.64s
# 491:	total: 4m 13s	remaining: 4.13s
# 492:	total: 4m 14s	remaining: 3.61s
# 493:	total: 4m 14s	remaining: 3.1s
# 494:	total: 4m 15s	remaining: 2.58s
# 495:	learn: 0.0089958	test: 0.0200547	best: 0.0200206 (415)	total: 4m 15s	remaining: 2.06s
# 496:	total: 4m 16s	remaining: 1.55s
# 497:	total: 4m 16s	remaining: 1.03s
# 498:	total: 4m 17s	remaining: 516ms
# 499:	learn: 0.0089236	test: 0.0200437	best: 0.0200206 (415)	total: 4m 18s	remaining: 0us
# bestTest = 0.02002062167
# bestIteration = 415
# Shrink model to first 416 iterations.

# %% [markdown]
# ### 2.2.2. Checking Performance
#
# Using the split for validation for a bit of internal checking of performance (i.e., not official)

# %%
y_pred = tb_catb.predict(X_tb_validate)
print("CATB_TB")
print(classification_report(y_tb_validate, y_pred, digits=4))
print("AUC-ROC:", roc_auc_score(y_tb_validate, y_pred))
print(classification_report(y_tb_validate, y_pred, digits=4), file=open("Outputs/CATB/"+MODEL_FILENAME+"_CATB_TB_ClassReport.txt", mode='w'))
print("AUC-ROC:", roc_auc_score(y_tb_validate, y_pred), file=open("Outputs/CATB/"+MODEL_FILENAME+"_CATB_TB_ClassReport.txt", mode='a'))
disp = ConfusionMatrixDisplay(confusion_matrix(y_tb_validate, y_pred))
disp.plot()
plt.savefig("Outputs/CATB/"+MODEL_FILENAME+"_CATB_TB_"+"_ConfMatrix.png")
# Out:
# CATB_TB
#               precision    recall  f1-score   support
#
#            0     0.9984    0.9910    0.9947     10842
#            1     0.9910    0.9984    0.9947     10848
#
#     accuracy                         0.9947     21690
#    macro avg     0.9947    0.9947    0.9947     21690
# weighted avg     0.9947    0.9947    0.9947     21690
#
# AUC-ROC: 0.9946969840737349

# %% [markdown]
# ### 2.2.3. Preview of the Tree
#
# *How can it be a tree if there is no proof of a tree?*

# %%
tree = tb_catb.plot_tree(0, catboost.Pool(X_tb_training, y_tb_training, cat_features=get_indexes(), feature_names=list(X_tb_training.columns)))
tree.save("Outputs/CATB/"+MODEL_FILENAME+"_CATB_TREE/TB_Tree"+".svg")
display(tree)

# %% [markdown]
# ## 2.3. Training on Instance-Based Behaviors

# %% [markdown]
# ### 2.3.1 Training Model

# %%
#Training Model
start_time()
ib_catb = setup_model(IB_HYPERPARAMS, "IB")
ib_catb.fit(X_ib_training, y_ib_training, plot=True, eval_set=catboost.Pool(X_ib_validate, label=y_ib_validate, cat_features=get_indexes()), save_snapshot=True, snapshot_interval=60)
end_time("CATB_IB")

#Saving Model as file
ib_catb.save_model("Outputs/CATB/"+MODEL_FILENAME+"_CATB_IB.model", format="json")
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Default metric period is 5 because AUC is/are not implemented for GPU
# 0:	learn: 0.2684435	test: 0.2705661	best: 0.2705661 (0)	total: 454ms	remaining: 45s
# 1:	total: 889ms	remaining: 43.6s
# 2:	total: 1.32s	remaining: 42.8s
# 3:	total: 1.76s	remaining: 42.2s
# 4:	total: 2.19s	remaining: 41.6s
# 5:	learn: 0.0351123	test: 0.0380095	best: 0.0380095 (5)	total: 2.62s	remaining: 41.1s
# 6:	total: 3.05s	remaining: 40.5s
# 7:	total: 3.48s	remaining: 40s
# 8:	total: 3.91s	remaining: 39.5s
# 9:	total: 4.33s	remaining: 39s
# 10:	learn: 0.0261036	test: 0.0302473	best: 0.0302473 (10)	total: 4.77s	remaining: 38.6s
# 11:	total: 5.2s	remaining: 38.1s
# 12:	total: 5.62s	remaining: 37.6s
# 13:	total: 6.05s	remaining: 37.2s
# 14:	total: 6.48s	remaining: 36.7s
# 15:	learn: 0.0233119	test: 0.0284015	best: 0.0284015 (15)	total: 6.91s	remaining: 36.3s
# 16:	total: 7.34s	remaining: 35.8s
# 17:	total: 7.76s	remaining: 35.4s
# 18:	total: 8.19s	remaining: 34.9s
# 19:	total: 8.62s	remaining: 34.5s
# 20:	learn: 0.0214788	test: 0.0271603	best: 0.0271603 (20)	total: 9.05s	remaining: 34.1s
# 21:	total: 9.48s	remaining: 33.6s
# 22:	total: 9.91s	remaining: 33.2s
# 23:	total: 10.3s	remaining: 32.7s
# 24:	total: 10.8s	remaining: 32.3s
# 25:	learn: 0.0201667	test: 0.0267523	best: 0.0267523 (25)	total: 11.2s	remaining: 31.9s
# 26:	total: 11.6s	remaining: 31.4s
# 27:	total: 12s	remaining: 31s
# 28:	total: 12.5s	remaining: 30.5s
# 29:	total: 12.9s	remaining: 30.1s
# 30:	learn: 0.0191668	test: 0.0260782	best: 0.0260782 (30)	total: 13.3s	remaining: 29.7s
# 31:	total: 13.8s	remaining: 29.2s
# 32:	total: 14.2s	remaining: 28.8s
# 33:	total: 14.6s	remaining: 28.4s
# 34:	total: 15s	remaining: 27.9s
# 35:	learn: 0.0183183	test: 0.0258186	best: 0.0258186 (35)	total: 15.5s	remaining: 27.5s
# 36:	total: 15.9s	remaining: 27.1s
# 37:	total: 16.3s	remaining: 26.6s
# 38:	total: 16.7s	remaining: 26.2s
# 39:	total: 17.2s	remaining: 25.8s
# 40:	learn: 0.0181034	test: 0.0256753	best: 0.0256753 (40)	total: 17.6s	remaining: 25.3s
# 41:	total: 18s	remaining: 24.9s
# 42:	total: 18.5s	remaining: 24.5s
# 43:	total: 18.9s	remaining: 24.1s
# 44:	total: 19.3s	remaining: 23.6s
# 45:	learn: 0.0178574	test: 0.0256080	best: 0.0256080 (45)	total: 19.8s	remaining: 23.2s
# 46:	total: 20.2s	remaining: 22.7s
# 47:	total: 20.6s	remaining: 22.3s
# 48:	total: 21s	remaining: 21.9s
# 49:	total: 21.5s	remaining: 21.5s
# 50:	learn: 0.0175703	test: 0.0254846	best: 0.0254846 (50)	total: 21.9s	remaining: 21s
# 51:	total: 22.3s	remaining: 20.6s
# 52:	total: 22.8s	remaining: 20.2s
# 53:	total: 23.2s	remaining: 19.7s
# 54:	total: 23.6s	remaining: 19.3s
# 55:	learn: 0.0175233	test: 0.0255118	best: 0.0254846 (50)	total: 24s	remaining: 18.9s
# 56:	total: 24.5s	remaining: 18.5s
# 57:	total: 24.9s	remaining: 18s
# 58:	total: 25.3s	remaining: 17.6s
# 59:	total: 25.7s	remaining: 17.2s
# 60:	learn: 0.0172538	test: 0.0253196	best: 0.0253196 (60)	total: 26.2s	remaining: 16.7s
# 61:	total: 26.6s	remaining: 16.3s
# 62:	total: 27s	remaining: 15.9s
# 63:	total: 27.5s	remaining: 15.4s
# 64:	total: 27.9s	remaining: 15s
# 65:	learn: 0.0167592	test: 0.0249739	best: 0.0249739 (65)	total: 28.3s	remaining: 14.6s
# 66:	total: 28.7s	remaining: 14.2s
# 67:	total: 29.2s	remaining: 13.7s
# 68:	total: 29.6s	remaining: 13.3s
# 69:	total: 30s	remaining: 12.9s
# 70:	learn: 0.0166538	test: 0.0249585	best: 0.0249585 (70)	total: 30.5s	remaining: 12.4s
# 71:	total: 30.9s	remaining: 12s
# 72:	total: 31.3s	remaining: 11.6s
# 73:	total: 31.7s	remaining: 11.1s
# 74:	total: 32.2s	remaining: 10.7s
# 75:	learn: 0.0166261	test: 0.0249638	best: 0.0249585 (70)	total: 32.6s	remaining: 10.3s
# 76:	total: 33s	remaining: 9.86s
# 77:	total: 33.4s	remaining: 9.43s
# 78:	total: 33.9s	remaining: 9s
# 79:	total: 34.3s	remaining: 8.57s
# 80:	learn: 0.0165857	test: 0.0249795	best: 0.0249585 (70)	total: 34.7s	remaining: 8.14s
# 81:	total: 35.1s	remaining: 7.71s
# 82:	total: 35.6s	remaining: 7.29s
# 83:	total: 36s	remaining: 6.86s
# 84:	total: 36.4s	remaining: 6.43s
# 85:	learn: 0.0163094	test: 0.0248088	best: 0.0248088 (85)	total: 36.9s	remaining: 6s
# 86:	total: 37.3s	remaining: 5.57s
# 87:	total: 37.7s	remaining: 5.14s
# 88:	total: 38.2s	remaining: 4.72s
# 89:	total: 38.6s	remaining: 4.29s
# 90:	learn: 0.0156978	test: 0.0244208	best: 0.0244208 (90)	total: 39s	remaining: 3.86s
# 91:	total: 39.4s	remaining: 3.43s
# 92:	total: 39.9s	remaining: 3s
# 93:	total: 40.3s	remaining: 2.57s
# 94:	total: 40.7s	remaining: 2.14s
# 95:	learn: 0.0156529	test: 0.0244421	best: 0.0244208 (90)	total: 41.1s	remaining: 1.71s
# 96:	total: 41.6s	remaining: 1.28s
# 97:	total: 42s	remaining: 857ms
# 98:	total: 42.4s	remaining: 429ms
# 99:	learn: 0.0156140	test: 0.0244558	best: 0.0244208 (90)	total: 42.9s	remaining: 0us
# bestTest = 0.02442080197
# bestIteration = 90
# Shrink model to first 91 iterations.

# %% [markdown]
# ### 2.3.2. Checking Performance
#
# Using the split for validation for a bit of internal checking of performance (i.e., not official)

# %%
y_pred = ib_catb.predict(X_ib_validate)
print("CATB_IB")
print(classification_report(y_ib_validate, y_pred, digits=4))
print("AUC-ROC:", roc_auc_score(y_ib_validate, y_pred))
print(classification_report(y_ib_validate, y_pred, digits=4), file=open("Outputs/CATB/"+MODEL_FILENAME+"_CATB_IB_ClassReport.txt", mode='w'))
print("AUC-ROC:", roc_auc_score(y_ib_validate, y_pred), file=open("Outputs/CATB/"+MODEL_FILENAME+"_CATB_IB_ClassReport.txt", mode='a'))
disp = ConfusionMatrixDisplay(confusion_matrix(y_ib_validate, y_pred))
disp.plot()
plt.savefig("Outputs/CATB/"+MODEL_FILENAME+"_CATB_IB_"+"_ConfMatrix.png")
# Out:
# CATB_IB
#               precision    recall  f1-score   support
#
#            0     0.9983    0.9905    0.9944     10842
#            1     0.9906    0.9983    0.9944     10848
#
#     accuracy                         0.9944     21690
#    macro avg     0.9945    0.9944    0.9944     21690
# weighted avg     0.9945    0.9944    0.9944     21690
#
# AUC-ROC: 0.9944203078653483

# %% [markdown]
# ### 2.3.3. Preview of the Tree
#
# *How can it be a tree if there is no proof of a tree?*

# %%
tree = ib_catb.plot_tree(0, catboost.Pool(X_ib_training, y_ib_training, cat_features=get_indexes(), feature_names=list(X_ib_training.columns)))
tree.save("Outputs/CATB/"+MODEL_FILENAME+"_CATB_TREE/IB_Tree"+".svg")
tree

# %%
logging("\n")
