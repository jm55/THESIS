# %% [markdown]
# # Evaluation and Comparison of Boosted ML Models in Behavior-Based Malware Detection
#
#
# ## Notebook: CatBoost Training
#
# ***
#
# **What is the objective of this file?**
#
# To train the model using the Train Split (Statically Split).

# %% [markdown]
# ## Checklist
#
# - Ensure that you have the proper dataset files that you intend to use (i.e., whether the lite dataset or full version).
#     - The datasets it will use points to `/Official Development/Dataset/IB` & `/Official Development/Dataset/TB`.
#     - You can run the `/Official Development/Dataset [OFFICIAL] Oliveira Dataset Notebook.ipynb file` or unzip one of the zipped folders in the `/Official Development/Dataset/Processed` towards the two aforementioned folders.
# - Ensure that you have installed the necessary libraries needed to execute the training process.
#     - You can view the list of the specific versions in the thesis document or through the `.sh` or `.bat` files in the repository's home directory.

# %% [markdown]
# # 1. CatB Training Setup
#
# Setting training environment parameters.

# %% [markdown]
# ## 1.0. Tuning Settings
#
# 1. What will the output filename be?
# 2. Will you train a tuned model?
# 3. What hyperparameter values will you use?
#
# For no. 3, the value looks like
# `{'task_type': 'CPU', 'objective': 'Logloss', 'n_estimators': 50, 'max_depth': 11, 'learning_rate': 0.1, 'l2_leaf_reg': 2, 'grow_policy': 'SymmetricTree', 'bootstrap_type': 'Bayesian', 'boosting_type': 'Ordered', 'auto_class_weights': 'Balanced'}`
# which is obtained as part of the results of the associated tuning file to this file.
#
# Alternatively, you can just point a file directly to it (overrides the manual setup if not empty).
#
# **Do not include the custom hyperparameter values for `random_state`, `thread_count`, `verbose`, `cat_features`, and `nan_mode` as the values for these are hardcoded to the notebook.**

# %%
MODEL_FILENAME = "RYZEN2c" # <== Set the prefix for the filename of the output file (don't include file extension)
TUNED_TRAINING = True # <== Set as True if you'll be training a tuned model.

# These parameters are mostly default valued parameters for CatBoost except some that are mentioned in the paper (e.g., Ordered Boosting, Symmeteric Tree); Set as None for truly defaults.
TB_HYPERPARAMS = None # None or like "{'task_type': 'CPU', 'objective':'Logloss', 'grow_policy': 'SymmetricTree', 'bootstrap_type': 'Bayesian', 'boosting_type': 'Ordered'}"
IB_HYPERPARAMS = None # None or like "{'task_type': 'CPU', 'objective':'Logloss', 'grow_policy': 'SymmetricTree', 'bootstrap_type': 'Bayesian', 'boosting_type': 'Ordered'}"

TB_HYPERPARAMS_FILE = "./Outputs/Results/Ryzen2_NoFalse/CatB Tuning/RYZEN2_CATB_TB.tune" # <== Empty string or Pointing a .tune file overrides the value set above.
IB_HYPERPARAMS_FILE = "./Outputs/Results/Ryzen2_NoFalse/CatB Tuning/RYZEN2_CATB_IB.tune" # <== Empty string or Pointing a .tune file overrides the value set above.

STATIC_SPLIT = 0.3 # <== To achieve the 70:30 Static Split
RANDOM_SEED = 1 # <== Must be the same throughout the entire study (acts as a controlled variable), hence let's just settle with 1.

# %% [markdown]
# # ⚠️Warning
#
# **Be careful of modifying the code beyond this point as it was designed to run autonomously based on the parameters set above.**

# %% [markdown]
# ## 1.1. Loading Libraries

# %%
#Python Libraries
import time
from datetime import datetime
import json

#Data/Dataset Libraries
import pandas as pd
import numpy as np

#Model Selection
from sklearn.model_selection import train_test_split

#Metrics (for in-training testing only)
from sklearn.metrics import classification_report, accuracy_score, balanced_accuracy_score, f1_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import precision_score, recall_score, roc_auc_score

#Visualization
from matplotlib import pyplot as plt

#GBDT Models
# import lightgbm
import catboost

#File Writing Library (exclusive for use on LightGBM)
from joblib import dump, load

# %% [markdown]
# ## 1.2. Logging and Diagnostics

# %%
if TUNED_TRAINING:
    MODEL_FILENAME = "TUNED_" + MODEL_FILENAME
    if len(TB_HYPERPARAMS_FILE) != 0:
        f = open(TB_HYPERPARAMS_FILE, "r")
        TB_HYPERPARAMS = f.readline()
        f.close()
    if len(IB_HYPERPARAMS_FILE) != 0:
        f = open(IB_HYPERPARAMS_FILE, "r")
        IB_HYPERPARAMS = f.readline()
        f.close()
    TB_HYPERPARAMS = TB_HYPERPARAMS.replace('\'', '\"')#.replace("False", "\"False\"").replace("True", "\"True\"")
    TB_HYPERPARAMS = json.loads(str(TB_HYPERPARAMS))
    print("Parsed TB Hyperparams:", TB_HYPERPARAMS)
    print("")
    IB_HYPERPARAMS = IB_HYPERPARAMS.replace('\'', '\"')#.replace("False", "\"False\"").replace("True", "\"True\"")
    IB_HYPERPARAMS = json.loads(str(IB_HYPERPARAMS))
    print("Parsed IB Hyperparams:", IB_HYPERPARAMS)
else:
    if TB_HYPERPARAMS != None:
        TB_HYPERPARAMS = TB_HYPERPARAMS.replace('\'', '\"').replace("False", "\"False\"").replace("True", "\"True\"")
        TB_HYPERPARAMS = json.loads(str(TB_HYPERPARAMS))
    else:
        TB_HYPERPARAMS = None
    if IB_HYPERPARAMS != None:
        IB_HYPERPARAMS = IB_HYPERPARAMS.replace('\'', '\"').replace("False", "\"False\"").replace("True", "\"True\"")
        IB_HYPERPARAMS = json.loads(str(IB_HYPERPARAMS))
    else:
        IB_HYPERPARAMS = None

start = end = 0
LOG_FILENAME = "CATB_Training_Log.txt"
def logging(message):
    log = open(LOG_FILENAME, "a")
    log.write(message)
    log.close()
def start_time():
    global start
    start = time.time()
def end_time(process):
    global start
    elapse = time.time()-start
    start = 0
    printout = f"{str(datetime.now())}@{MODEL_FILENAME}: {process} - {round(elapse, 6)}s\n"
    logging(printout)
    return round(elapse, 6)
# Out:
# Parsed TB Hyperparams: {'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'gpu_cat_features_storage': 'CpuPinnedMemory', 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2, 'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 250, 'objective': 'Logloss', 'task_type': 'GPU'}
#
# Parsed IB Hyperparams: {'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'gpu_cat_features_storage': 'CpuPinnedMemory', 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2, 'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 250, 'objective': 'Logloss', 'task_type': 'GPU'}

# %% [markdown]
# ## 1.3. Loading Datasets
#
# Note that it will use the files in `/Official Development/Dataset/IB` & `/Official Development/Dataset/TB`.

# %% [markdown]
# ### 1.3.1. Setting filenames

# %%
#Setting filenames of files
TB_Train = "../Dataset/TB/CATB_TB.csv" # <== Location for Time-based Train Split for CatBoost
#TB_Test = "../Dataset/TB/TB_Test_CATB.csv" # <== Location for Time-based Test Split for CatBoost
IB_Train = "../Dataset/IB/CATB_IB.csv" # <== Location for Instance-based Train Split for CatBoost
#IB_Test = "../Dataset/IB/IB_Test_CATB.csv" # <== Location for Instance-based Test Split for CatBoost

# %% [markdown]
# ### 1.3.2. Loading datasets to DataFrames

# %%
#Loading datasets to DataFrames
tb_train = pd.read_csv(TB_Train, low_memory=False).fillna("NaN")
ib_train = pd.read_csv(IB_Train, low_memory=False).fillna("NaN")

print("Dataset Sizes")
print("TB Train Size:", tb_train.shape)
print("IB Train Size:", ib_train.shape)
# Out:
# Dataset Sizes
# TB Train Size: (77026, 101)
# IB Train Size: (77026, 101)

# %% [markdown]
# ### 1.3.3. Previewing datasets

# %%
#Previewing Time-based Dataset
tb_train.head()
# Out:
#    malware         t_0                     t_1              t_2  \
# 0        1  LdrLoadDll  LdrGetProcedureAddress       LdrLoadDll
# 1        1     NtClose               NtOpenKey  NtQueryValueKey
# 2        1     NtClose               NtOpenKey  NtQueryValueKey
# 3        0  LdrLoadDll  LdrGetProcedureAddress       LdrLoadDll
# 4        1  LdrLoadDll  LdrGetProcedureAddress       LdrLoadDll
#
#                       t_3         t_4                     t_5         t_6  \
# 0  LdrGetProcedureAddress  LdrLoadDll  LdrGetProcedureAddress  LdrLoadDll
# 1                 NtClose   NtOpenKey         NtQueryValueKey     NtClose
# 2                 NtClose   NtOpenKey         NtQueryValueKey     NtClose
# 3  LdrGetProcedureAddress  LdrLoadDll  LdrGetProcedureAddress  LdrLoadDll
# 4  LdrGetProcedureAddress  LdrLoadDll  LdrGetProcedureAddress  LdrLoadDll
#
#                       t_7                     t_8  ...  \
# 0  LdrGetProcedureAddress              LdrLoadDll  ...
# 1         LdrGetDllHandle  LdrGetProcedureAddress  ...
# 2         LdrGetDllHandle  LdrGetProcedureAddress  ...
# 3  LdrGetProcedureAddress              LdrLoadDll  ...
# 4  LdrGetProcedureAddress              LdrLoadDll  ...
#
#                      t_90               t_91                    t_92  \
# 0  LdrGetProcedureAddress  LookupAccountSidW  LdrGetProcedureAddress
# 1         FindResourceExW       LoadResource         FindResourceExW
# 2         FindResourceExW       LoadResource         FindResourceExW
# 3          SetFilePointer         NtReadFile          SetFilePointer
# 4            LoadResource    FindResourceExW            LoadResource
#
#                 t_93             t_94                    t_95  \
# 0  LookupAccountSidW       LdrLoadDll  LdrGetProcedureAddress
# 1       LoadResource  LdrGetDllHandle  LdrGetProcedureAddress
# 2       LoadResource  LdrGetDllHandle  LdrGetProcedureAddress
# 3         NtReadFile   SetFilePointer              NtReadFile
# 4    FindResourceExW     LoadResource           OleInitialize
#
#               t_96                    t_97                    t_98  \
# 0       LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 1      LoadStringW         LdrGetDllHandle  LdrGetProcedureAddress
# 2      LoadStringW         LdrGetDllHandle  LdrGetProcedureAddress
# 3   SetFilePointer              NtReadFile          SetFilePointer
# 4  FindResourceExW            LoadResource         FindResourceExW
#
#                      t_99
# 0  LdrGetProcedureAddress
# 1         LdrGetDllHandle
# 2         LdrGetDllHandle
# 3              NtReadFile
# 4            LoadResource
#
# [5 rows x 101 columns]

# %%
#Previewing Instance-based Dataset
ib_train.head()
# Out:
#    malware         t_0                     t_1                     t_2  \
# 0        1  LdrLoadDll  LdrGetProcedureAddress  NtProtectVirtualMemory
# 1        1     NtClose               NtOpenKey         NtQueryValueKey
# 2        1     NtClose               NtOpenKey         NtQueryValueKey
# 3        0  LdrLoadDll  LdrGetProcedureAddress  NtProtectVirtualMemory
# 4        1  LdrLoadDll  LdrGetProcedureAddress  NtProtectVirtualMemory
#
#                        t_3                          t_4              t_5  \
# 0                  NtClose                    NtOpenKey  NtQueryValueKey
# 1          LdrGetDllHandle       LdrGetProcedureAddress    GetSystemInfo
# 2          LdrGetDllHandle       LdrGetProcedureAddress    GetSystemInfo
# 3  GetSystemTimeAsFileTime  SetUnhandledExceptionFilter    GetSystemInfo
# 4                  NtClose                    NtOpenKey  NtQueryValueKey
#
#                        t_6            t_7                      t_8  ... t_90  \
# 0          LdrGetDllHandle  GetSystemInfo  NtAllocateVirtualMemory  ...  NaN
# 1  NtAllocateVirtualMemory  RegOpenKeyExW         FindFirstFileExW  ...  NaN
# 2  NtAllocateVirtualMemory  RegOpenKeyExW         FindFirstFileExW  ...  NaN
# 3  NtAllocateVirtualMemory  RegOpenKeyExW         RegQueryValueExW  ...  NaN
# 4          LdrGetDllHandle  GetSystemInfo  NtAllocateVirtualMemory  ...  NaN
#
#   t_91 t_92 t_93 t_94 t_95 t_96 t_97 t_98 t_99
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 101 columns]

# %% [markdown]
# ### 1.3.4. Statically Splitting the Train Split
#
# Train Split --> Training and Validation Split
#
# However only Training Split will be used.

# %%
#Static splitting of Train Split of Time-based
X_tb = tb_train.iloc[:,1:101] #All rows, 2nd to last column
y_tb = tb_train.iloc[:,0] #All rows, first column only
X_tb_training, X_tb_validate, y_tb_training, y_tb_validate = train_test_split(X_tb, y_tb, test_size=STATIC_SPLIT, shuffle=True, random_state=1)

#Static splitting of Train Split of Instance-based
X_ib = ib_train.iloc[:,1:101] #All rows, 2nd to last column
y_ib = ib_train.iloc[:,0] #All rows, first column only
X_ib_training, X_ib_validate, y_ib_training, y_ib_validate = train_test_split(X_ib, y_ib, test_size=STATIC_SPLIT, shuffle=True, random_state=1)

# %% [markdown]
# # 2. Model Training

# %% [markdown]
# ## 2.1. Setting up the Model

# %%
def get_indexes():
    indexes = []
    for i in range(100):
        indexes.append(f"t_{i}")
    return indexes

def setup_model(HYPERPARAMS, TYPE):
    global TUNED_TRAINING
    indexes = get_indexes()
    metric=['Logloss', 'AUC', 'Precision']
    train_dir = f"Outputs/CATB/{MODEL_FILENAME}_CATB_{TYPE}_TRAINDIR"
    if HYPERPARAMS == None:
        return catboost.CatBoostClassifier(random_state=RANDOM_SEED, thread_count=-1, verbose=1, cat_features=indexes, 
                                           nan_mode='Min', custom_metric=metric, train_dir=train_dir, one_hot_max_size=256)
    return catboost.CatBoostClassifier(**HYPERPARAMS, random_state=RANDOM_SEED, thread_count=-1, verbose=1, cat_features=indexes, 
                                       nan_mode='Min', custom_metric=metric, train_dir=train_dir, one_hot_max_size=256)

# %% [markdown]
# ## 2.2. Training on Time-Based Behaviors

# %% [markdown]
# ### 2.2.1 Training Model

# %%
#Training Model
start_time()
tb_catb = setup_model(TB_HYPERPARAMS, "TB")
tb_catb.fit(X_tb_training, y_tb_training, plot=True, eval_set=catboost.Pool(X_tb_validate, label=y_tb_validate, cat_features=get_indexes()), save_snapshot=True, snapshot_interval=60)
end_time("CATB_TB")

#Saving Model as file
tb_catb.save_model("Outputs/CATB/"+MODEL_FILENAME+"_CATB_TB.model", format="json")
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Default metric period is 5 because AUC is/are not implemented for GPU
# 0:	learn: 0.4693829	test: 0.4693175	best: 0.4693175 (0)	total: 299ms	remaining: 1m 14s
# 1:	total: 402ms	remaining: 49.8s
# 2:	total: 518ms	remaining: 42.6s
# 3:	total: 623ms	remaining: 38.3s
# 4:	total: 727ms	remaining: 35.6s
# 5:	learn: 0.0908400	test: 0.0913664	best: 0.0913664 (5)	total: 842ms	remaining: 34.2s
# 6:	total: 943ms	remaining: 32.7s
# 7:	total: 1.03s	remaining: 31.3s
# 8:	total: 1.13s	remaining: 30.2s
# 9:	total: 1.23s	remaining: 29.4s
# 10:	learn: 0.0456732	test: 0.0468462	best: 0.0468462 (10)	total: 1.32s	remaining: 28.7s
# 11:	total: 1.42s	remaining: 28.1s
# 12:	total: 1.51s	remaining: 27.5s
# 13:	total: 1.6s	remaining: 26.9s
# 14:	total: 1.68s	remaining: 26.4s
# 15:	learn: 0.0361296	test: 0.0377885	best: 0.0377885 (15)	total: 1.78s	remaining: 26.1s
# 16:	total: 1.86s	remaining: 25.6s
# 17:	total: 1.95s	remaining: 25.1s
# 18:	total: 2.03s	remaining: 24.7s
# 19:	total: 2.12s	remaining: 24.4s
# 20:	learn: 0.0329270	test: 0.0347282	best: 0.0347282 (20)	total: 2.22s	remaining: 24.2s
# 21:	total: 2.31s	remaining: 23.9s
# 22:	total: 2.4s	remaining: 23.6s
# 23:	total: 2.48s	remaining: 23.4s
# 24:	total: 2.57s	remaining: 23.1s
# 25:	learn: 0.0304956	test: 0.0326738	best: 0.0326738 (25)	total: 2.66s	remaining: 22.9s
# 26:	total: 2.73s	remaining: 22.6s
# 27:	total: 2.82s	remaining: 22.4s
# 28:	total: 2.9s	remaining: 22.1s
# 29:	total: 2.99s	remaining: 21.9s
# 30:	learn: 0.0288040	test: 0.0312792	best: 0.0312792 (30)	total: 3.08s	remaining: 21.7s
# 31:	total: 3.16s	remaining: 21.5s
# 32:	total: 3.23s	remaining: 21.3s
# 33:	total: 3.31s	remaining: 21.1s
# 34:	total: 3.4s	remaining: 20.9s
# 35:	learn: 0.0281693	test: 0.0308768	best: 0.0308768 (35)	total: 3.48s	remaining: 20.7s
# 36:	total: 3.57s	remaining: 20.5s
# 37:	total: 3.65s	remaining: 20.4s
# 38:	total: 3.73s	remaining: 20.2s
# 39:	total: 3.83s	remaining: 20.1s
# 40:	learn: 0.0267936	test: 0.0300170	best: 0.0300170 (40)	total: 3.92s	remaining: 20s
# 41:	total: 4s	remaining: 19.8s
# 42:	total: 4.08s	remaining: 19.6s
# 43:	total: 4.16s	remaining: 19.5s
# 44:	total: 4.24s	remaining: 19.3s
# 45:	learn: 0.0263730	test: 0.0298175	best: 0.0298175 (45)	total: 4.32s	remaining: 19.2s
# 46:	total: 4.4s	remaining: 19s
# 47:	total: 4.48s	remaining: 18.8s
# 48:	total: 4.56s	remaining: 18.7s
# 49:	total: 4.64s	remaining: 18.6s
# 50:	learn: 0.0259460	test: 0.0297349	best: 0.0297349 (50)	total: 4.72s	remaining: 18.4s
# 51:	total: 4.81s	remaining: 18.3s
# 52:	total: 4.89s	remaining: 18.2s
# 53:	total: 4.96s	remaining: 18s
# 54:	total: 5.05s	remaining: 17.9s
# 55:	learn: 0.0254033	test: 0.0294119	best: 0.0294119 (55)	total: 5.14s	remaining: 17.8s
# 56:	total: 5.22s	remaining: 17.7s
# 57:	total: 5.3s	remaining: 17.6s
# 58:	total: 5.39s	remaining: 17.4s
# 59:	total: 5.48s	remaining: 17.3s
# 60:	learn: 0.0250736	test: 0.0293686	best: 0.0293686 (60)	total: 5.57s	remaining: 17.3s
# 61:	total: 5.65s	remaining: 17.1s
# 62:	total: 5.72s	remaining: 17s
# 63:	total: 5.84s	remaining: 17s
# 64:	total: 5.92s	remaining: 16.8s
# 65:	learn: 0.0243593	test: 0.0289689	best: 0.0289689 (65)	total: 6s	remaining: 16.7s
# 66:	total: 6.08s	remaining: 16.6s
# 67:	total: 6.16s	remaining: 16.5s
# 68:	total: 6.24s	remaining: 16.4s
# 69:	total: 6.33s	remaining: 16.3s
# 70:	learn: 0.0239646	test: 0.0288613	best: 0.0288613 (70)	total: 6.43s	remaining: 16.2s
# 71:	total: 6.5s	remaining: 16.1s
# 72:	total: 6.58s	remaining: 16s
# 73:	total: 6.66s	remaining: 15.8s
# 74:	total: 6.74s	remaining: 15.7s
# 75:	learn: 0.0236511	test: 0.0288080	best: 0.0288080 (75)	total: 6.83s	remaining: 15.6s
# 76:	total: 6.91s	remaining: 15.5s
# 77:	total: 6.99s	remaining: 15.4s
# 78:	total: 7.07s	remaining: 15.3s
# 79:	total: 7.16s	remaining: 15.2s
# 80:	learn: 0.0234217	test: 0.0287570	best: 0.0287570 (80)	total: 7.24s	remaining: 15.1s
# 81:	total: 7.33s	remaining: 15s
# 82:	total: 7.42s	remaining: 14.9s
# 83:	total: 7.5s	remaining: 14.8s
# 84:	total: 7.59s	remaining: 14.7s
# 85:	learn: 0.0231895	test: 0.0286900	best: 0.0286900 (85)	total: 7.68s	remaining: 14.6s
# 86:	total: 7.77s	remaining: 14.6s
# 87:	total: 7.85s	remaining: 14.5s
# 88:	total: 7.93s	remaining: 14.3s
# 89:	total: 8.01s	remaining: 14.2s
# 90:	learn: 0.0229725	test: 0.0286738	best: 0.0286738 (90)	total: 8.11s	remaining: 14.2s
# 91:	total: 8.18s	remaining: 14.1s
# 92:	total: 8.26s	remaining: 13.9s
# 93:	total: 8.35s	remaining: 13.9s
# 94:	total: 8.43s	remaining: 13.8s
# 95:	learn: 0.0225671	test: 0.0284667	best: 0.0284667 (95)	total: 8.52s	remaining: 13.7s
# 96:	total: 8.6s	remaining: 13.6s
# 97:	total: 8.69s	remaining: 13.5s
# 98:	total: 8.78s	remaining: 13.4s
# 99:	total: 8.86s	remaining: 13.3s
# 100:	learn: 0.0223744	test: 0.0284705	best: 0.0284667 (95)	total: 8.96s	remaining: 13.2s
# 101:	total: 9.04s	remaining: 13.1s
# 102:	total: 9.12s	remaining: 13s
# 103:	total: 9.2s	remaining: 12.9s
# 104:	total: 9.28s	remaining: 12.8s
# 105:	learn: 0.0221889	test: 0.0284495	best: 0.0284495 (105)	total: 9.37s	remaining: 12.7s
# 106:	total: 9.45s	remaining: 12.6s
# 107:	total: 9.54s	remaining: 12.5s
# 108:	total: 9.63s	remaining: 12.5s
# 109:	total: 9.71s	remaining: 12.4s
# 110:	learn: 0.0220727	test: 0.0284421	best: 0.0284421 (110)	total: 9.8s	remaining: 12.3s
# 111:	total: 9.89s	remaining: 12.2s
# 112:	total: 9.97s	remaining: 12.1s
# 113:	total: 10.1s	remaining: 12s
# 114:	total: 10.2s	remaining: 11.9s
# 115:	learn: 0.0219549	test: 0.0284814	best: 0.0284421 (110)	total: 10.2s	remaining: 11.8s
# 116:	total: 10.3s	remaining: 11.7s
# 117:	total: 10.4s	remaining: 11.7s
# 118:	total: 10.5s	remaining: 11.6s
# 119:	total: 10.6s	remaining: 11.5s
# 120:	learn: 0.0215161	test: 0.0282576	best: 0.0282576 (120)	total: 10.7s	remaining: 11.4s
# 121:	total: 10.8s	remaining: 11.3s
# 122:	total: 10.9s	remaining: 11.3s
# 123:	total: 11s	remaining: 11.2s
# 124:	total: 11.1s	remaining: 11.1s
# 125:	learn: 0.0212601	test: 0.0282524	best: 0.0282524 (125)	total: 11.2s	remaining: 11s
# 126:	total: 11.3s	remaining: 10.9s
# 127:	total: 11.4s	remaining: 10.8s
# 128:	total: 11.4s	remaining: 10.7s
# 129:	total: 11.5s	remaining: 10.6s
# 130:	learn: 0.0210892	test: 0.0282354	best: 0.0282354 (130)	total: 11.6s	remaining: 10.5s
# 131:	total: 11.7s	remaining: 10.5s
# 132:	total: 11.8s	remaining: 10.4s
# 133:	total: 11.9s	remaining: 10.3s
# 134:	total: 12s	remaining: 10.2s
# 135:	learn: 0.0208861	test: 0.0281896	best: 0.0281896 (135)	total: 12s	remaining: 10.1s
# 136:	total: 12.1s	remaining: 10s
# 137:	total: 12.2s	remaining: 9.91s
# 138:	total: 12.3s	remaining: 9.83s
# 139:	total: 12.4s	remaining: 9.73s
# 140:	learn: 0.0206357	test: 0.0281321	best: 0.0281321 (140)	total: 12.5s	remaining: 9.65s
# 141:	total: 12.6s	remaining: 9.55s
# 142:	total: 12.6s	remaining: 9.46s
# 143:	total: 12.7s	remaining: 9.38s
# 144:	total: 12.8s	remaining: 9.29s
# 145:	learn: 0.0204862	test: 0.0281387	best: 0.0281321 (140)	total: 12.9s	remaining: 9.21s
# 146:	total: 13s	remaining: 9.13s
# 147:	total: 13.1s	remaining: 9.04s
# 148:	total: 13.2s	remaining: 8.95s
# 149:	total: 13.3s	remaining: 8.87s
# 150:	learn: 0.0200920	test: 0.0279733	best: 0.0279733 (150)	total: 13.4s	remaining: 8.77s
# 151:	total: 13.5s	remaining: 8.68s
# 152:	total: 13.5s	remaining: 8.59s
# 153:	total: 13.6s	remaining: 8.5s
# 154:	total: 13.7s	remaining: 8.41s
# 155:	learn: 0.0199243	test: 0.0279094	best: 0.0279094 (155)	total: 13.8s	remaining: 8.32s
# 156:	total: 13.9s	remaining: 8.23s
# 157:	total: 14s	remaining: 8.14s
# 158:	total: 14.1s	remaining: 8.05s
# 159:	total: 14.2s	remaining: 7.96s
# 160:	learn: 0.0196549	test: 0.0277928	best: 0.0277928 (160)	total: 14.2s	remaining: 7.87s
# 161:	total: 14.3s	remaining: 7.78s
# 162:	total: 14.4s	remaining: 7.69s
# 163:	total: 14.5s	remaining: 7.6s
# 164:	total: 14.6s	remaining: 7.51s
# 165:	learn: 0.0195898	test: 0.0277890	best: 0.0277890 (165)	total: 14.7s	remaining: 7.42s
# 166:	total: 14.7s	remaining: 7.33s
# 167:	total: 14.8s	remaining: 7.24s
# 168:	total: 14.9s	remaining: 7.15s
# 169:	total: 15s	remaining: 7.06s
# 170:	learn: 0.0194752	test: 0.0277883	best: 0.0277883 (170)	total: 15.1s	remaining: 6.99s
# 171:	total: 15.2s	remaining: 6.9s
# 172:	total: 15.3s	remaining: 6.8s
# 173:	total: 15.4s	remaining: 6.71s
# 174:	total: 15.5s	remaining: 6.63s
# 175:	learn: 0.0193046	test: 0.0277567	best: 0.0277567 (175)	total: 15.5s	remaining: 6.54s
# 176:	total: 15.6s	remaining: 6.45s
# 177:	total: 15.7s	remaining: 6.36s
# 178:	total: 15.8s	remaining: 6.27s
# 179:	total: 15.9s	remaining: 6.17s
# 180:	learn: 0.0192314	test: 0.0277600	best: 0.0277567 (175)	total: 16s	remaining: 6.09s
# 181:	total: 16s	remaining: 5.99s
# 182:	total: 16.1s	remaining: 5.9s
# 183:	total: 16.2s	remaining: 5.81s
# 184:	total: 16.3s	remaining: 5.72s
# 185:	learn: 0.0189610	test: 0.0275950	best: 0.0275950 (185)	total: 16.4s	remaining: 5.63s
# 186:	total: 16.4s	remaining: 5.54s
# 187:	total: 16.5s	remaining: 5.45s
# 188:	total: 16.6s	remaining: 5.36s
# 189:	total: 16.7s	remaining: 5.27s
# 190:	learn: 0.0188350	test: 0.0275405	best: 0.0275405 (190)	total: 16.8s	remaining: 5.18s
# 191:	total: 16.9s	remaining: 5.09s
# 192:	total: 16.9s	remaining: 5s
# 193:	total: 17s	remaining: 4.91s
# 194:	total: 17.1s	remaining: 4.82s
# 195:	learn: 0.0187005	test: 0.0275266	best: 0.0275266 (195)	total: 17.2s	remaining: 4.74s
# 196:	total: 17.3s	remaining: 4.65s
# 197:	total: 17.4s	remaining: 4.56s
# 198:	total: 17.4s	remaining: 4.47s
# 199:	total: 17.5s	remaining: 4.38s
# 200:	learn: 0.0185853	test: 0.0274171	best: 0.0274171 (200)	total: 17.6s	remaining: 4.3s
# 201:	total: 17.7s	remaining: 4.21s
# 202:	total: 17.8s	remaining: 4.12s
# 203:	total: 17.9s	remaining: 4.03s
# 204:	total: 18s	remaining: 3.95s
# 205:	learn: 0.0185220	test: 0.0274217	best: 0.0274171 (200)	total: 18.1s	remaining: 3.86s
# 206:	total: 18.2s	remaining: 3.77s
# 207:	total: 18.2s	remaining: 3.68s
# 208:	total: 18.3s	remaining: 3.6s
# 209:	total: 18.4s	remaining: 3.51s
# 210:	learn: 0.0184790	test: 0.0274299	best: 0.0274171 (200)	total: 18.5s	remaining: 3.42s
# 211:	total: 18.6s	remaining: 3.34s
# 212:	total: 18.7s	remaining: 3.25s
# 213:	total: 18.8s	remaining: 3.16s
# 214:	total: 18.9s	remaining: 3.07s
# 215:	learn: 0.0183486	test: 0.0273812	best: 0.0273812 (215)	total: 19s	remaining: 2.99s
# 216:	total: 19.1s	remaining: 2.9s
# 217:	total: 19.1s	remaining: 2.81s
# 218:	total: 19.2s	remaining: 2.72s
# 219:	total: 19.3s	remaining: 2.63s
# 220:	learn: 0.0182091	test: 0.0273392	best: 0.0273392 (220)	total: 19.4s	remaining: 2.55s
# 221:	total: 19.5s	remaining: 2.46s
# 222:	total: 19.6s	remaining: 2.37s
# 223:	total: 19.7s	remaining: 2.28s
# 224:	total: 19.8s	remaining: 2.19s
# 225:	learn: 0.0181743	test: 0.0273317	best: 0.0273317 (225)	total: 19.9s	remaining: 2.11s
# 226:	total: 19.9s	remaining: 2.02s
# 227:	total: 20s	remaining: 1.93s
# 228:	total: 20.1s	remaining: 1.84s
# 229:	total: 20.2s	remaining: 1.75s
# 230:	learn: 0.0179727	test: 0.0273039	best: 0.0273039 (230)	total: 20.3s	remaining: 1.67s
# 231:	total: 20.4s	remaining: 1.58s
# 232:	total: 20.5s	remaining: 1.49s
# 233:	total: 20.5s	remaining: 1.4s
# 234:	total: 20.6s	remaining: 1.32s
# 235:	learn: 0.0178653	test: 0.0273329	best: 0.0273039 (230)	total: 20.7s	remaining: 1.23s
# 236:	total: 20.8s	remaining: 1.14s
# 237:	total: 20.9s	remaining: 1.05s
# 238:	total: 21s	remaining: 965ms
# 239:	total: 21.1s	remaining: 877ms
# 240:	learn: 0.0178097	test: 0.0273326	best: 0.0273039 (230)	total: 21.2s	remaining: 790ms
# 241:	total: 21.2s	remaining: 702ms
# 242:	total: 21.3s	remaining: 614ms
# 243:	total: 21.4s	remaining: 526ms
# 244:	total: 21.5s	remaining: 438ms
# 245:	learn: 0.0176384	test: 0.0272329	best: 0.0272329 (245)	total: 21.6s	remaining: 351ms
# 246:	total: 21.7s	remaining: 263ms
# 247:	total: 21.8s	remaining: 175ms
# 248:	total: 21.8s	remaining: 87.7ms
# 249:	learn: 0.0176182	test: 0.0272456	best: 0.0272329 (245)	total: 21.9s	remaining: 0us
# bestTest = 0.02723288936
# bestIteration = 245
# Shrink model to first 246 iterations.

# %% [markdown]
# ### 2.2.2. Checking Performance
#
# Using the split for validation for a bit of internal checking of performance (i.e., not official)

# %%
y_pred = tb_catb.predict(X_tb_validate)
print("CATB_TB")
print(classification_report(y_tb_validate, y_pred, digits=4))
print(classification_report(y_tb_validate, y_pred, digits=4), file=open("Outputs/CATB/"+MODEL_FILENAME+"_CATB_TB_ClassReport.txt", mode='w'))
disp = ConfusionMatrixDisplay(confusion_matrix(y_tb_validate, y_pred))
disp.plot()
plt.savefig("Outputs/CATB/"+MODEL_FILENAME+"_CATB_TB_"+"_ConfMatrix.png")
# Out:
# CATB_TB
#               precision    recall  f1-score   support
#
#            0     0.9976    0.9906    0.9941     11530
#            1     0.9907    0.9976    0.9941     11578
#
#     accuracy                         0.9941     23108
#    macro avg     0.9941    0.9941    0.9941     23108
# weighted avg     0.9941    0.9941    0.9941     23108

# %% [markdown]
# ### 2.2.3. Preview of the Tree
#
# *How can it be a tree if there is no proof of a tree?*

# %%
tree = tb_catb.plot_tree(0, catboost.Pool(X_tb_training, y_tb_training, cat_features=get_indexes(), feature_names=list(X_tb_training.columns)))
tree.save("Outputs/CATB/"+MODEL_FILENAME+"_CATB_TREE/TB_Tree"+".svg")
display(tree)

# %% [markdown]
# ## 2.3. Training on Instance-Based Behaviors

# %% [markdown]
# ### 2.3.1 Training Model

# %%
#Training Model
start_time()
ib_catb = setup_model(IB_HYPERPARAMS, "IB")
ib_catb.fit(X_ib_training, y_ib_training, plot=True, eval_set=catboost.Pool(X_ib_validate, label=y_ib_validate, cat_features=get_indexes()), save_snapshot=True, snapshot_interval=60)
end_time("CATB_IB")

#Saving Model as file
ib_catb.save_model("Outputs/CATB/"+MODEL_FILENAME+"_CATB_IB.model", format="json")
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Default metric period is 5 because AUC is/are not implemented for GPU
# 0:	learn: 0.4713265	test: 0.4719034	best: 0.4719034 (0)	total: 140ms	remaining: 34.9s
# 1:	total: 235ms	remaining: 29.1s
# 2:	total: 327ms	remaining: 26.9s
# 3:	total: 411ms	remaining: 25.3s
# 4:	total: 491ms	remaining: 24s
# 5:	learn: 0.0962942	test: 0.0963796	best: 0.0963796 (5)	total: 573ms	remaining: 23.3s
# 6:	total: 662ms	remaining: 23s
# 7:	total: 742ms	remaining: 22.4s
# 8:	total: 823ms	remaining: 22s
# 9:	total: 907ms	remaining: 21.8s
# 10:	learn: 0.0524025	test: 0.0525385	best: 0.0525385 (10)	total: 998ms	remaining: 21.7s
# 11:	total: 1.07s	remaining: 21.3s
# 12:	total: 1.16s	remaining: 21.1s
# 13:	total: 1.23s	remaining: 20.7s
# 14:	total: 1.32s	remaining: 20.7s
# 15:	learn: 0.0390248	test: 0.0398110	best: 0.0398110 (15)	total: 1.41s	remaining: 20.6s
# 16:	total: 1.48s	remaining: 20.3s
# 17:	total: 1.56s	remaining: 20.1s
# 18:	total: 1.65s	remaining: 20s
# 19:	total: 1.73s	remaining: 19.9s
# 20:	learn: 0.0342251	test: 0.0354307	best: 0.0354307 (20)	total: 1.81s	remaining: 19.7s
# 21:	total: 1.88s	remaining: 19.5s
# 22:	total: 1.96s	remaining: 19.3s
# 23:	total: 2.03s	remaining: 19.2s
# 24:	total: 2.11s	remaining: 19s
# 25:	learn: 0.0316807	test: 0.0333561	best: 0.0333561 (25)	total: 2.2s	remaining: 19s
# 26:	total: 2.28s	remaining: 18.8s
# 27:	total: 2.37s	remaining: 18.8s
# 28:	total: 2.45s	remaining: 18.7s
# 29:	total: 2.52s	remaining: 18.5s
# 30:	learn: 0.0305323	test: 0.0325575	best: 0.0325575 (30)	total: 2.61s	remaining: 18.4s
# 31:	total: 2.68s	remaining: 18.3s
# 32:	total: 2.75s	remaining: 18.1s
# 33:	total: 2.83s	remaining: 18s
# 34:	total: 2.91s	remaining: 17.9s
# 35:	learn: 0.0294418	test: 0.0318463	best: 0.0318463 (35)	total: 2.99s	remaining: 17.8s
# 36:	total: 3.11s	remaining: 17.9s
# 37:	total: 3.18s	remaining: 17.8s
# 38:	total: 3.27s	remaining: 17.7s
# 39:	total: 3.36s	remaining: 17.6s
# 40:	learn: 0.0289703	test: 0.0316986	best: 0.0316986 (40)	total: 3.45s	remaining: 17.6s
# 41:	total: 3.53s	remaining: 17.5s
# 42:	total: 3.61s	remaining: 17.4s
# 43:	total: 3.69s	remaining: 17.3s
# 44:	total: 3.77s	remaining: 17.2s
# 45:	learn: 0.0282879	test: 0.0312995	best: 0.0312995 (45)	total: 3.86s	remaining: 17.1s
# 46:	total: 3.94s	remaining: 17s
# 47:	total: 4.01s	remaining: 16.9s
# 48:	total: 4.1s	remaining: 16.8s
# 49:	total: 4.17s	remaining: 16.7s
# 50:	learn: 0.0278403	test: 0.0311355	best: 0.0311355 (50)	total: 4.25s	remaining: 16.6s
# 51:	total: 4.34s	remaining: 16.5s
# 52:	total: 4.41s	remaining: 16.4s
# 53:	total: 4.49s	remaining: 16.3s
# 54:	total: 4.56s	remaining: 16.2s
# 55:	learn: 0.0270039	test: 0.0305635	best: 0.0305635 (55)	total: 4.64s	remaining: 16.1s
# 56:	total: 4.72s	remaining: 16s
# 57:	total: 4.8s	remaining: 15.9s
# 58:	total: 4.88s	remaining: 15.8s
# 59:	total: 4.96s	remaining: 15.7s
# 60:	learn: 0.0260294	test: 0.0298600	best: 0.0298600 (60)	total: 5.04s	remaining: 15.6s
# 61:	total: 5.11s	remaining: 15.5s
# 62:	total: 5.19s	remaining: 15.4s
# 63:	total: 5.26s	remaining: 15.3s
# 64:	total: 5.33s	remaining: 15.2s
# 65:	learn: 0.0255881	test: 0.0295407	best: 0.0295407 (65)	total: 5.42s	remaining: 15.1s
# 66:	total: 5.49s	remaining: 15s
# 67:	total: 5.57s	remaining: 14.9s
# 68:	total: 5.64s	remaining: 14.8s
# 69:	total: 5.71s	remaining: 14.7s
# 70:	learn: 0.0252979	test: 0.0294656	best: 0.0294656 (70)	total: 5.79s	remaining: 14.6s
# 71:	total: 5.87s	remaining: 14.5s
# 72:	total: 5.94s	remaining: 14.4s
# 73:	total: 6.03s	remaining: 14.3s
# 74:	total: 6.11s	remaining: 14.3s
# 75:	learn: 0.0250802	test: 0.0294743	best: 0.0294656 (70)	total: 6.2s	remaining: 14.2s
# 76:	total: 6.27s	remaining: 14.1s
# 77:	total: 6.34s	remaining: 14s
# 78:	total: 6.41s	remaining: 13.9s
# 79:	total: 6.49s	remaining: 13.8s
# 80:	learn: 0.0249446	test: 0.0294361	best: 0.0294361 (80)	total: 6.57s	remaining: 13.7s
# 81:	total: 6.65s	remaining: 13.6s
# 82:	total: 6.73s	remaining: 13.5s
# 83:	total: 6.81s	remaining: 13.5s
# 84:	total: 6.88s	remaining: 13.4s
# 85:	learn: 0.0244129	test: 0.0291318	best: 0.0291318 (85)	total: 6.97s	remaining: 13.3s
# 86:	total: 7.06s	remaining: 13.2s
# 87:	total: 7.14s	remaining: 13.1s
# 88:	total: 7.22s	remaining: 13.1s
# 89:	total: 7.29s	remaining: 13s
# 90:	learn: 0.0236765	test: 0.0287137	best: 0.0287137 (90)	total: 7.37s	remaining: 12.9s
# 91:	total: 7.44s	remaining: 12.8s
# 92:	total: 7.51s	remaining: 12.7s
# 93:	total: 7.58s	remaining: 12.6s
# 94:	total: 7.66s	remaining: 12.5s
# 95:	learn: 0.0230739	test: 0.0282515	best: 0.0282515 (95)	total: 7.74s	remaining: 12.4s
# 96:	total: 7.83s	remaining: 12.3s
# 97:	total: 7.91s	remaining: 12.3s
# 98:	total: 7.98s	remaining: 12.2s
# 99:	total: 8.05s	remaining: 12.1s
# 100:	learn: 0.0226429	test: 0.0279881	best: 0.0279881 (100)	total: 8.13s	remaining: 12s
# 101:	total: 8.21s	remaining: 11.9s
# 102:	total: 8.28s	remaining: 11.8s
# 103:	total: 8.39s	remaining: 11.8s
# 104:	total: 8.46s	remaining: 11.7s
# 105:	learn: 0.0224848	test: 0.0279666	best: 0.0279666 (105)	total: 8.54s	remaining: 11.6s
# 106:	total: 8.62s	remaining: 11.5s
# 107:	total: 8.69s	remaining: 11.4s
# 108:	total: 8.77s	remaining: 11.3s
# 109:	total: 8.84s	remaining: 11.3s
# 110:	learn: 0.0222227	test: 0.0278813	best: 0.0278813 (110)	total: 8.92s	remaining: 11.2s
# 111:	total: 8.99s	remaining: 11.1s
# 112:	total: 9.06s	remaining: 11s
# 113:	total: 9.13s	remaining: 10.9s
# 114:	total: 9.21s	remaining: 10.8s
# 115:	learn: 0.0220549	test: 0.0278048	best: 0.0278048 (115)	total: 9.29s	remaining: 10.7s
# 116:	total: 9.36s	remaining: 10.6s
# 117:	total: 9.43s	remaining: 10.6s
# 118:	total: 9.51s	remaining: 10.5s
# 119:	total: 9.59s	remaining: 10.4s
# 120:	learn: 0.0218065	test: 0.0276783	best: 0.0276783 (120)	total: 9.67s	remaining: 10.3s
# 121:	total: 9.74s	remaining: 10.2s
# 122:	total: 9.81s	remaining: 10.1s
# 123:	total: 9.88s	remaining: 10s
# 124:	total: 9.96s	remaining: 9.96s
# 125:	learn: 0.0217393	test: 0.0277049	best: 0.0276783 (120)	total: 10s	remaining: 9.87s
# 126:	total: 10.1s	remaining: 9.78s
# 127:	total: 10.2s	remaining: 9.7s
# 128:	total: 10.2s	remaining: 9.61s
# 129:	total: 10.3s	remaining: 9.52s
# 130:	learn: 0.0216067	test: 0.0276605	best: 0.0276605 (130)	total: 10.4s	remaining: 9.45s
# 131:	total: 10.5s	remaining: 9.37s
# 132:	total: 10.6s	remaining: 9.28s
# 133:	total: 10.6s	remaining: 9.2s
# 134:	total: 10.7s	remaining: 9.12s
# 135:	learn: 0.0214564	test: 0.0276174	best: 0.0276174 (135)	total: 10.8s	remaining: 9.04s
# 136:	total: 10.9s	remaining: 8.96s
# 137:	total: 10.9s	remaining: 8.88s
# 138:	total: 11s	remaining: 8.79s
# 139:	total: 11.1s	remaining: 8.7s
# 140:	learn: 0.0213054	test: 0.0275823	best: 0.0275823 (140)	total: 11.2s	remaining: 8.63s
# 141:	total: 11.2s	remaining: 8.54s
# 142:	total: 11.3s	remaining: 8.46s
# 143:	total: 11.4s	remaining: 8.38s
# 144:	total: 11.4s	remaining: 8.29s
# 145:	learn: 0.0212168	test: 0.0275797	best: 0.0275797 (145)	total: 11.5s	remaining: 8.21s
# 146:	total: 11.6s	remaining: 8.12s
# 147:	total: 11.7s	remaining: 8.04s
# 148:	total: 11.7s	remaining: 7.96s
# 149:	total: 11.8s	remaining: 7.88s
# 150:	learn: 0.0211588	test: 0.0275790	best: 0.0275790 (150)	total: 11.9s	remaining: 7.8s
# 151:	total: 12s	remaining: 7.71s
# 152:	total: 12s	remaining: 7.63s
# 153:	total: 12.1s	remaining: 7.55s
# 154:	total: 12.2s	remaining: 7.46s
# 155:	learn: 0.0211134	test: 0.0275699	best: 0.0275699 (155)	total: 12.3s	remaining: 7.39s
# 156:	total: 12.3s	remaining: 7.31s
# 157:	total: 12.4s	remaining: 7.22s
# 158:	total: 12.5s	remaining: 7.14s
# 159:	total: 12.5s	remaining: 7.06s
# 160:	learn: 0.0209364	test: 0.0274559	best: 0.0274559 (160)	total: 12.6s	remaining: 6.98s
# 161:	total: 12.7s	remaining: 6.9s
# 162:	total: 12.8s	remaining: 6.82s
# 163:	total: 12.8s	remaining: 6.74s
# 164:	total: 12.9s	remaining: 6.66s
# 165:	learn: 0.0208206	test: 0.0274498	best: 0.0274498 (165)	total: 13s	remaining: 6.58s
# 166:	total: 13.1s	remaining: 6.5s
# 167:	total: 13.2s	remaining: 6.43s
# 168:	total: 13.3s	remaining: 6.36s
# 169:	total: 13.3s	remaining: 6.28s
# 170:	learn: 0.0206171	test: 0.0273120	best: 0.0273120 (170)	total: 13.4s	remaining: 6.2s
# 171:	total: 13.5s	remaining: 6.12s
# 172:	total: 13.6s	remaining: 6.04s
# 173:	total: 13.6s	remaining: 5.96s
# 174:	total: 13.7s	remaining: 5.88s
# 175:	learn: 0.0205850	test: 0.0273498	best: 0.0273120 (170)	total: 13.8s	remaining: 5.8s
# 176:	total: 13.9s	remaining: 5.72s
# 177:	total: 14s	remaining: 5.64s
# 178:	total: 14s	remaining: 5.56s
# 179:	total: 14.1s	remaining: 5.48s
# 180:	learn: 0.0204232	test: 0.0272034	best: 0.0272034 (180)	total: 14.2s	remaining: 5.4s
# 181:	total: 14.2s	remaining: 5.32s
# 182:	total: 14.3s	remaining: 5.24s
# 183:	total: 14.4s	remaining: 5.16s
# 184:	total: 14.5s	remaining: 5.08s
# 185:	learn: 0.0203119	test: 0.0270885	best: 0.0270885 (185)	total: 14.5s	remaining: 5.01s
# 186:	total: 14.6s	remaining: 4.92s
# 187:	total: 14.7s	remaining: 4.85s
# 188:	total: 14.8s	remaining: 4.77s
# 189:	total: 14.8s	remaining: 4.69s
# 190:	learn: 0.0201808	test: 0.0271028	best: 0.0270885 (185)	total: 14.9s	remaining: 4.61s
# 191:	total: 15s	remaining: 4.53s
# 192:	total: 15.1s	remaining: 4.45s
# 193:	total: 15.1s	remaining: 4.37s
# 194:	total: 15.2s	remaining: 4.29s
# 195:	learn: 0.0200673	test: 0.0270725	best: 0.0270725 (195)	total: 15.3s	remaining: 4.21s
# 196:	total: 15.4s	remaining: 4.13s
# 197:	total: 15.4s	remaining: 4.05s
# 198:	total: 15.5s	remaining: 3.98s
# 199:	total: 15.6s	remaining: 3.9s
# 200:	learn: 0.0199557	test: 0.0270517	best: 0.0270517 (200)	total: 15.7s	remaining: 3.82s
# 201:	total: 15.7s	remaining: 3.74s
# 202:	total: 15.8s	remaining: 3.66s
# 203:	total: 15.9s	remaining: 3.58s
# 204:	total: 16s	remaining: 3.5s
# 205:	learn: 0.0197010	test: 0.0269083	best: 0.0269083 (205)	total: 16s	remaining: 3.43s
# 206:	total: 16.1s	remaining: 3.35s
# 207:	total: 16.2s	remaining: 3.27s
# 208:	total: 16.3s	remaining: 3.19s
# 209:	total: 16.3s	remaining: 3.11s
# 210:	learn: 0.0193993	test: 0.0267219	best: 0.0267219 (210)	total: 16.4s	remaining: 3.04s
# 211:	total: 16.5s	remaining: 2.96s
# 212:	total: 16.6s	remaining: 2.88s
# 213:	total: 16.6s	remaining: 2.8s
# 214:	total: 16.7s	remaining: 2.72s
# 215:	learn: 0.0192805	test: 0.0266657	best: 0.0266657 (215)	total: 16.8s	remaining: 2.64s
# 216:	total: 16.9s	remaining: 2.56s
# 217:	total: 16.9s	remaining: 2.49s
# 218:	total: 17s	remaining: 2.41s
# 219:	total: 17.1s	remaining: 2.33s
# 220:	learn: 0.0192610	test: 0.0266693	best: 0.0266657 (215)	total: 17.2s	remaining: 2.25s
# 221:	total: 17.2s	remaining: 2.17s
# 222:	total: 17.3s	remaining: 2.1s
# 223:	total: 17.4s	remaining: 2.02s
# 224:	total: 17.5s	remaining: 1.94s
# 225:	learn: 0.0191250	test: 0.0265711	best: 0.0265711 (225)	total: 17.5s	remaining: 1.86s
# 226:	total: 17.6s	remaining: 1.79s
# 227:	total: 17.7s	remaining: 1.71s
# 228:	total: 17.8s	remaining: 1.63s
# 229:	total: 17.8s	remaining: 1.55s
# 230:	learn: 0.0183387	test: 0.0259135	best: 0.0259135 (230)	total: 17.9s	remaining: 1.47s
# 231:	total: 18s	remaining: 1.4s
# 232:	total: 18.1s	remaining: 1.32s
# 233:	total: 18.2s	remaining: 1.24s
# 234:	total: 18.2s	remaining: 1.16s
# 235:	learn: 0.0176985	test: 0.0253953	best: 0.0253953 (235)	total: 18.3s	remaining: 1.09s
# 236:	total: 18.4s	remaining: 1.01s
# 237:	total: 18.5s	remaining: 931ms
# 238:	total: 18.5s	remaining: 853ms
# 239:	total: 18.6s	remaining: 775ms
# 240:	learn: 0.0175840	test: 0.0253763	best: 0.0253763 (240)	total: 18.7s	remaining: 698ms
# 241:	total: 18.8s	remaining: 620ms
# 242:	total: 18.8s	remaining: 543ms
# 243:	total: 18.9s	remaining: 465ms
# 244:	total: 19s	remaining: 387ms
# 245:	learn: 0.0174099	test: 0.0252944	best: 0.0252944 (245)	total: 19.1s	remaining: 310ms
# 246:	total: 19.1s	remaining: 232ms
# 247:	total: 19.2s	remaining: 155ms
# 248:	total: 19.3s	remaining: 77.4ms
# 249:	learn: 0.0173394	test: 0.0252803	best: 0.0252803 (249)	total: 19.4s	remaining: 0us
# bestTest = 0.02528033488
# bestIteration = 249

# %% [markdown]
# ### 2.3.2. Checking Performance
#
# Using the split for validation for a bit of internal checking of performance (i.e., not official)

# %%
y_pred = ib_catb.predict(X_ib_validate)
print("CATB_IB")
print(classification_report(y_ib_validate, y_pred, digits=4))
print(classification_report(y_ib_validate, y_pred, digits=4), file=open("Outputs/CATB/"+MODEL_FILENAME+"_CATB_IB_ClassReport.txt", mode='w'))
disp = ConfusionMatrixDisplay(confusion_matrix(y_ib_validate, y_pred))
disp.plot()
plt.savefig("Outputs/CATB/"+MODEL_FILENAME+"_CATB_IB_"+"_ConfMatrix.png")
# Out:
# CATB_IB
#               precision    recall  f1-score   support
#
#            0     0.9971    0.9912    0.9941     11530
#            1     0.9912    0.9971    0.9942     11578
#
#     accuracy                         0.9942     23108
#    macro avg     0.9942    0.9942    0.9942     23108
# weighted avg     0.9942    0.9942    0.9942     23108

# %% [markdown]
# ### 2.3.3. Preview of the Tree
#
# *How can it be a tree if there is no proof of a tree?*

# %%
tree = ib_catb.plot_tree(0, catboost.Pool(X_ib_training, y_ib_training, cat_features=get_indexes(), feature_names=list(X_ib_training.columns)))
tree.save("Outputs/CATB/"+MODEL_FILENAME+"_CATB_TREE/IB_Tree"+".svg")
tree

# %%
logging("\n")
