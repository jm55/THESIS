# %% [markdown]
# # Evaluation and Comparison of Boosted ML Models in Behavior-Based Malware Detection
#
#
# ## Notebook: CatBoost Training
#
# ***
#
# **What is the objective of this file?**
#
# To train the model using the Train Split (Statically Split).

# %% [markdown]
# ## Checklist
#
# - Ensure that you have the proper dataset files that you intend to use (i.e., whether the lite dataset or full version).
#     - The datasets it will use points to `/Official Development/Dataset/IB` & `/Official Development/Dataset/TB`.
#     - You can run the `/Official Development/Dataset [OFFICIAL] Oliveira Dataset Notebook.ipynb file` or unzip one of the zipped folders in the `/Official Development/Dataset/Processed` towards the two aforementioned folders.
# - Ensure that you have installed the necessary libraries needed to execute the training process.
#     - You can view the list of the specific versions in the thesis document or through the `.sh` or `.bat` files in the repository's home directory.

# %% [markdown]
# # 1. CatB Training Setup
#
# Setting training environment parameters.

# %% [markdown]
# ## 1.0. Tuning Settings
#
# 1. What will the output filename be?
# 2. Will you train a tuned model?
# 3. What hyperparameter values will you use?
#
# For no. 3, the value looks like
# `{'task_type': 'CPU', 'objective': 'Logloss', 'n_estimators': 50, 'max_depth': 11, 'learning_rate': 0.1, 'l2_leaf_reg': 2, 'grow_policy': 'SymmetricTree', 'bootstrap_type': 'Bayesian', 'boosting_type': 'Ordered', 'auto_class_weights': 'Balanced'}`
# which is obtained as part of the results of the associated tuning file to this file.
#
# Alternatively, you can just point a file directly to it (overrides the manual setup if not empty).
#
# **Do not include the custom hyperparameter values for `random_state`, `thread_count`, `verbose`, `cat_features`, and `nan_mode` as the values for these are hardcoded to the notebook.**

# %%
MODEL_FILENAME = "RYZEN2b" # <== Set the prefix for the filename of the output file (don't include file extension)
TUNED_TRAINING = True # <== Set as True if you'll be training a tuned model.

# These parameters are mostly default valued parameters for CatBoost except some that are mentioned in the paper (e.g., Ordered Boosting, Symmeteric Tree); Set as None for truly defaults.
TB_HYPERPARAMS = None # None or like "{'task_type': 'CPU', 'objective':'Logloss', 'grow_policy': 'SymmetricTree', 'bootstrap_type': 'Bayesian', 'boosting_type': 'Ordered'}"
IB_HYPERPARAMS = None # None or like "{'task_type': 'CPU', 'objective':'Logloss', 'grow_policy': 'SymmetricTree', 'bootstrap_type': 'Bayesian', 'boosting_type': 'Ordered'}"

TB_HYPERPARAMS_FILE = "./Outputs/CATB/Tuning/RYZEN2b_CATB_TB.tune" # <== Empty string or Pointing a .tune file overrides the value set above.
IB_HYPERPARAMS_FILE = "./Outputs/CATB/Tuning/RYZEN2b_CATB_IB.tune" # <== Empty string or Pointing a .tune file overrides the value set above.

STATIC_SPLIT = 0.3 # <== To achieve the 70:30 Static Split
RANDOM_SEED = 1 # <== Must be the same throughout the entire study (acts as a controlled variable), hence let's just settle with 1.

# %% [markdown]
# # ⚠️Warning
#
# **Be careful of modifying the code beyond this point as it was designed to run autonomously based on the parameters set above.**

# %% [markdown]
# ## 1.1. Loading Libraries

# %%
#Python Libraries
import time
from datetime import datetime
import json

#Data/Dataset Libraries
import pandas as pd
import numpy as np

#Model Selection
from sklearn.model_selection import train_test_split

#Metrics (for in-training testing only)
from sklearn.metrics import classification_report, accuracy_score, balanced_accuracy_score, f1_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import precision_score, recall_score, roc_auc_score

#Visualization
from matplotlib import pyplot as plt

#GBDT Models
# import lightgbm
import catboost

#File Writing Library (exclusive for use on LightGBM)
from joblib import dump, load

# %% [markdown]
# ## 1.2. Logging and Diagnostics

# %%
if TUNED_TRAINING:
    MODEL_FILENAME = "TUNED_" + MODEL_FILENAME
    if len(TB_HYPERPARAMS_FILE) != 0:
        f = open(TB_HYPERPARAMS_FILE, "r")
        TB_HYPERPARAMS = f.readline()
        f.close()
    if len(IB_HYPERPARAMS_FILE) != 0:
        f = open(IB_HYPERPARAMS_FILE, "r")
        IB_HYPERPARAMS = f.readline()
        f.close()
    TB_HYPERPARAMS = TB_HYPERPARAMS.replace('\'', '\"')#.replace("False", "\"False\"").replace("True", "\"True\"")
    TB_HYPERPARAMS = json.loads(str(TB_HYPERPARAMS))
    print("Parsed TB Hyperparams:", TB_HYPERPARAMS)
    print("")
    IB_HYPERPARAMS = IB_HYPERPARAMS.replace('\'', '\"')#.replace("False", "\"False\"").replace("True", "\"True\"")
    IB_HYPERPARAMS = json.loads(str(IB_HYPERPARAMS))
    print("Parsed IB Hyperparams:", IB_HYPERPARAMS)
else:
    if TB_HYPERPARAMS != None:
        TB_HYPERPARAMS = TB_HYPERPARAMS.replace('\'', '\"').replace("False", "\"False\"").replace("True", "\"True\"")
        TB_HYPERPARAMS = json.loads(str(TB_HYPERPARAMS))
    else:
        TB_HYPERPARAMS = None
    if IB_HYPERPARAMS != None:
        IB_HYPERPARAMS = IB_HYPERPARAMS.replace('\'', '\"').replace("False", "\"False\"").replace("True", "\"True\"")
        IB_HYPERPARAMS = json.loads(str(IB_HYPERPARAMS))
    else:
        IB_HYPERPARAMS = None

start = end = 0
LOG_FILENAME = "CATB_Training_Log.txt"
def logging(message):
    log = open(LOG_FILENAME, "a")
    log.write(message)
    log.close()
def start_time():
    global start
    start = time.time()
def end_time(process):
    global start
    elapse = time.time()-start
    start = 0
    printout = f"{str(datetime.now())}@{MODEL_FILENAME}: {process} - {round(elapse, 6)}s\n"
    logging(printout)
    return round(elapse, 6)
# Out:
# Parsed TB Hyperparams: {'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'gpu_cat_features_storage': 'CpuPinnedMemory', 'grow_policy': 'SymmetricTree', 'learning_rate': 0.1, 'n_estimators': 50, 'objective': 'Logloss', 'task_type': 'GPU'}
#
# Parsed IB Hyperparams: {'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'gpu_cat_features_storage': 'CpuPinnedMemory', 'grow_policy': 'SymmetricTree', 'learning_rate': 0.1, 'n_estimators': 100, 'objective': 'Logloss', 'task_type': 'GPU'}

# %% [markdown]
# ## 1.3. Loading Datasets
#
# Note that it will use the files in `/Official Development/Dataset/IB` & `/Official Development/Dataset/TB`.

# %% [markdown]
# ### 1.3.1. Setting filenames

# %%
#Setting filenames of files
TB_Train = "../Dataset/TB/CATB_TB.csv" # <== Location for Time-based Train Split for CatBoost
#TB_Test = "../Dataset/TB/TB_Test_CATB.csv" # <== Location for Time-based Test Split for CatBoost
IB_Train = "../Dataset/IB/CATB_IB.csv" # <== Location for Instance-based Train Split for CatBoost
#IB_Test = "../Dataset/IB/IB_Test_CATB.csv" # <== Location for Instance-based Test Split for CatBoost

# %% [markdown]
# ### 1.3.2. Loading datasets to DataFrames

# %%
#Loading datasets to DataFrames
tb_train = pd.read_csv(TB_Train, low_memory=False).fillna("NaN")
ib_train = pd.read_csv(IB_Train, low_memory=False).fillna("NaN")

print("Dataset Sizes")
print("TB Train Size:", tb_train.shape)
print("IB Train Size:", ib_train.shape)
# Out:
# Dataset Sizes
# TB Train Size: (8258, 101)
# IB Train Size: (8258, 101)

# %% [markdown]
# ### 1.3.3. Previewing datasets

# %%
#Previewing Time-based Dataset
tb_train.head()
# Out:
#    malware                      t_0            t_1                     t_2  \
# 0        1             SetErrorMode  OleInitialize         LdrGetDllHandle
# 1        1  GetSystemTimeAsFileTime     LdrLoadDll  LdrGetProcedureAddress
# 2        1  GetSystemTimeAsFileTime     LdrLoadDll  LdrGetProcedureAddress
# 3        1  GetSystemTimeAsFileTime     LdrLoadDll  LdrGetProcedureAddress
# 4        1                  NtClose      NtOpenKey         NtQueryValueKey
#
#           t_3                     t_4              t_5  \
# 0  LdrLoadDll  LdrGetProcedureAddress       LdrLoadDll
# 1  LdrLoadDll  LdrGetProcedureAddress       LdrLoadDll
# 2  LdrLoadDll  LdrGetProcedureAddress       LdrLoadDll
# 3  LdrLoadDll  LdrGetProcedureAddress       LdrLoadDll
# 4     NtClose               NtOpenKey  NtQueryValueKey
#
#                       t_6              t_7                     t_8  ...  \
# 0  LdrGetProcedureAddress       LdrLoadDll  LdrGetProcedureAddress  ...
# 1  LdrGetProcedureAddress       LdrLoadDll  LdrGetProcedureAddress  ...
# 2  LdrGetProcedureAddress       LdrLoadDll  LdrGetProcedureAddress  ...
# 3  LdrGetProcedureAddress       LdrLoadDll  LdrGetProcedureAddress  ...
# 4                 NtClose  LdrGetDllHandle  LdrGetProcedureAddress  ...
#
#                       t_90               t_91                    t_92  \
# 0            RegOpenKeyExW   RegQueryValueExW             RegCloseKey
# 1  NtAllocateVirtualMemory   NtCreateThreadEx       NtDuplicateObject
# 2  NtAllocateVirtualMemory         LdrLoadDll  LdrGetProcedureAddress
# 3         NtCreateThreadEx  NtDuplicateObject          NtResumeThread
# 4   LdrGetProcedureAddress  LookupAccountSidW  LdrGetProcedureAddress
#
#                       t_93                 t_94                        t_95  \
# 0           NtCreateMutant  GetNativeSystemInfo  GetSystemWindowsDirectoryW
# 1           NtResumeThread    NtDuplicateObject     NtAllocateVirtualMemory
# 2         NtDelayExecution          EnumWindows     GetSystemTimeAsFileTime
# 3  NtAllocateVirtualMemory    NtDuplicateObject               RegOpenKeyExW
# 4        LookupAccountSidW           LdrLoadDll      LdrGetProcedureAddress
#
#                t_96                     t_97                     t_98  \
# 0           NtClose               LdrLoadDll   LdrGetProcedureAddress
# 1     RegOpenKeyExW         RegQueryValueExW  GetFileVersionInfoSizeW
# 2     RegOpenKeyExW         RegQueryInfoKeyW            RegEnumKeyExW
# 3  RegQueryValueExW  GetFileVersionInfoSizeW      GetFileVersionInfoW
# 4        LdrLoadDll   LdrGetProcedureAddress               LdrLoadDll
#
#                       t_99
# 0              RegEnumKeyW
# 1  NtAllocateVirtualMemory
# 2            RegOpenKeyExW
# 3              RegCloseKey
# 4   LdrGetProcedureAddress
#
# [5 rows x 101 columns]

# %%
#Previewing Instance-based Dataset
ib_train.head()
# Out:
#    malware                      t_0            t_1                     t_2  \
# 0        1             SetErrorMode  OleInitialize         LdrGetDllHandle
# 1        1  GetSystemTimeAsFileTime     LdrLoadDll  LdrGetProcedureAddress
# 2        1  GetSystemTimeAsFileTime     LdrLoadDll  LdrGetProcedureAddress
# 3        1  GetSystemTimeAsFileTime     LdrLoadDll  LdrGetProcedureAddress
# 4        1                  NtClose      NtOpenKey         NtQueryValueKey
#
#                            t_3                          t_4  \
# 0                   LdrLoadDll       LdrGetProcedureAddress
# 1  SetUnhandledExceptionFilter       NtProtectVirtualMemory
# 2              LdrGetDllHandle  SetUnhandledExceptionFilter
# 3  SetUnhandledExceptionFilter       NtProtectVirtualMemory
# 4              LdrGetDllHandle       LdrGetProcedureAddress
#
#                        t_5                         t_6              t_7  \
# 0            NtOpenSection          NtMapViewOfSection    RegOpenKeyExW
# 1  NtAllocateVirtualMemory  GetSystemWindowsDirectoryW    CreateActCtxW
# 2     CryptAcquireContextW                   NtOpenKey  NtQueryValueKey
# 3  NtAllocateVirtualMemory  GetSystemWindowsDirectoryW    CreateActCtxW
# 4            GetSystemInfo     NtAllocateVirtualMemory    RegOpenKeyExW
#
#                 t_8  ... t_90 t_91 t_92 t_93 t_94 t_95 t_96 t_97 t_98 t_99
# 0  RegQueryValueExW  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1   LdrGetDllHandle  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2           NtClose  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3   LdrGetDllHandle  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  FindFirstFileExW  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 101 columns]

# %% [markdown]
# ### 1.3.4. Statically Splitting the Train Split
#
# Train Split --> Training and Validation Split
#
# However only Training Split will be used.

# %%
#Static splitting of Train Split of Time-based
X_tb = tb_train.iloc[:,1:101] #All rows, 2nd to last column
y_tb = tb_train.iloc[:,0] #All rows, first column only
X_tb_training, X_tb_validate, y_tb_training, y_tb_validate = train_test_split(X_tb, y_tb, test_size=STATIC_SPLIT, shuffle=True, random_state=1)

#Static splitting of Train Split of Instance-based
X_ib = ib_train.iloc[:,1:101] #All rows, 2nd to last column
y_ib = ib_train.iloc[:,0] #All rows, first column only
X_ib_training, X_ib_validate, y_ib_training, y_ib_validate = train_test_split(X_ib, y_ib, test_size=STATIC_SPLIT, shuffle=True, random_state=1)

# %% [markdown]
# # 2. Model Training

# %% [markdown]
# ## 2.1. Setting up the Model

# %%
def get_indexes():
    indexes = []
    for i in range(100):
        indexes.append(f"t_{i}")
    return indexes

def setup_model(HYPERPARAMS, TYPE):
    global TUNED_TRAINING
    indexes = get_indexes()
    metric=['Logloss', 'AUC', 'Precision']
    train_dir = f"Outputs/CATB/{MODEL_FILENAME}_CATB_{TYPE}_TRAINDIR"
    if HYPERPARAMS == None:
        return catboost.CatBoostClassifier(random_state=RANDOM_SEED, thread_count=-1, verbose=1, cat_features=indexes, 
                                           nan_mode='Min', custom_metric=metric, train_dir=train_dir, one_hot_max_size=256)
    return catboost.CatBoostClassifier(**HYPERPARAMS, random_state=RANDOM_SEED, thread_count=-1, verbose=1, cat_features=indexes, 
                                       nan_mode='Min', custom_metric=metric, train_dir=train_dir, one_hot_max_size=256)

# %% [markdown]
# ## 2.2. Training on Time-Based Behaviors

# %% [markdown]
# ### 2.2.1 Training Model

# %%
#Training Model
start_time()
tb_catb = setup_model(TB_HYPERPARAMS, "TB")
tb_catb.fit(X_tb_training, y_tb_training, plot=True, eval_set=catboost.Pool(X_tb_validate, label=y_tb_validate, cat_features=get_indexes()), save_snapshot=True, snapshot_interval=60)
end_time("CATB_TB")

#Saving Model as file
tb_catb.save_model("Outputs/CATB/"+MODEL_FILENAME+"_CATB_TB.model", format="json")
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Default metric period is 5 because AUC is/are not implemented for GPU
# 0:	learn: 0.4358672	test: 0.4366475	best: 0.4366475 (0)	total: 156ms	remaining: 7.63s
# 1:	total: 209ms	remaining: 5.03s
# 2:	total: 265ms	remaining: 4.14s
# 3:	total: 315ms	remaining: 3.63s
# 4:	total: 372ms	remaining: 3.35s
# 5:	learn: 0.0770563	test: 0.0891467	best: 0.0891467 (5)	total: 430ms	remaining: 3.15s
# 6:	total: 492ms	remaining: 3.02s
# 7:	total: 549ms	remaining: 2.88s
# 8:	total: 603ms	remaining: 2.75s
# 9:	total: 654ms	remaining: 2.62s
# 10:	learn: 0.0343478	test: 0.0532541	best: 0.0532541 (10)	total: 707ms	remaining: 2.5s
# 11:	total: 755ms	remaining: 2.39s
# 12:	total: 804ms	remaining: 2.29s
# 13:	total: 854ms	remaining: 2.19s
# 14:	total: 903ms	remaining: 2.11s
# 15:	learn: 0.0250699	test: 0.0467640	best: 0.0467640 (15)	total: 957ms	remaining: 2.03s
# 16:	total: 1s	remaining: 1.95s
# 17:	total: 1.05s	remaining: 1.87s
# 18:	total: 1.1s	remaining: 1.79s
# 19:	total: 1.14s	remaining: 1.72s
# 20:	learn: 0.0229904	test: 0.0470409	best: 0.0467640 (15)	total: 1.19s	remaining: 1.65s
# 21:	total: 1.24s	remaining: 1.58s
# 22:	total: 1.29s	remaining: 1.51s
# 23:	total: 1.34s	remaining: 1.45s
# 24:	total: 1.39s	remaining: 1.39s
# 25:	learn: 0.0214965	test: 0.0469009	best: 0.0467640 (15)	total: 1.43s	remaining: 1.32s
# 26:	total: 1.48s	remaining: 1.26s
# 27:	total: 1.53s	remaining: 1.2s
# 28:	total: 1.57s	remaining: 1.14s
# 29:	total: 1.62s	remaining: 1.08s
# 30:	learn: 0.0206048	test: 0.0468643	best: 0.0467640 (15)	total: 1.67s	remaining: 1.02s
# 31:	total: 1.72s	remaining: 969ms
# 32:	total: 1.77s	remaining: 912ms
# 33:	total: 1.82s	remaining: 857ms
# 34:	total: 1.88s	remaining: 805ms
# 35:	learn: 0.0189145	test: 0.0463189	best: 0.0463189 (35)	total: 1.93s	remaining: 751ms
# 36:	total: 1.98s	remaining: 694ms
# 37:	total: 2.02s	remaining: 638ms
# 38:	total: 2.07s	remaining: 584ms
# 39:	total: 2.12s	remaining: 530ms
# 40:	learn: 0.0184765	test: 0.0459868	best: 0.0459868 (40)	total: 2.17s	remaining: 476ms
# 41:	total: 2.22s	remaining: 424ms
# 42:	total: 2.28s	remaining: 372ms
# 43:	total: 2.34s	remaining: 319ms
# 44:	total: 2.39s	remaining: 266ms
# 45:	learn: 0.0181094	test: 0.0456931	best: 0.0456931 (45)	total: 2.46s	remaining: 214ms
# 46:	total: 2.52s	remaining: 161ms
# 47:	total: 2.58s	remaining: 107ms
# 48:	total: 2.62s	remaining: 53.5ms
# 49:	learn: 0.0179132	test: 0.0455217	best: 0.0455217 (49)	total: 2.67s	remaining: 0us
# bestTest = 0.04552168457
# bestIteration = 49

# %% [markdown]
# ### 2.2.2. Checking Performance
#
# Using the split for validation for a bit of internal checking of performance (i.e., not official)

# %%
y_pred = tb_catb.predict(X_tb_validate)
print("CATB_TB")
print(classification_report(y_tb_validate, y_pred, digits=4))
print("AUC-ROC:", roc_auc_score(y_tb_validate, y_pred))
print(classification_report(y_tb_validate, y_pred, digits=4), file=open("Outputs/CATB/"+MODEL_FILENAME+"_CATB_TB_ClassReport.txt", mode='w'))
print("AUC-ROC:", roc_auc_score(y_tb_validate, y_pred), file=open("Outputs/CATB/"+MODEL_FILENAME+"_CATB_TB_ClassReport.txt", mode='a'))
disp = ConfusionMatrixDisplay(confusion_matrix(y_tb_validate, y_pred))
disp.plot()
plt.savefig("Outputs/CATB/"+MODEL_FILENAME+"_CATB_TB_"+"_ConfMatrix.png")
# Out:
# CATB_TB
#               precision    recall  f1-score   support
#
#            0     0.9944    0.9850    0.9897      1267
#            1     0.9845    0.9942    0.9893      1211
#
#     accuracy                         0.9895      2478
#    macro avg     0.9894    0.9896    0.9895      2478
# weighted avg     0.9896    0.9895    0.9895      2478
#
# AUC-ROC: 0.9896117997545519

# %% [markdown]
# ### 2.2.3. Preview of the Tree
#
# *How can it be a tree if there is no proof of a tree?*

# %%
tree = tb_catb.plot_tree(0, catboost.Pool(X_tb_training, y_tb_training, cat_features=get_indexes(), feature_names=list(X_tb_training.columns)))
tree.save("Outputs/CATB/"+MODEL_FILENAME+"_CATB_TREE/TB_Tree"+".svg")
display(tree)

# %% [markdown]
# ## 2.3. Training on Instance-Based Behaviors

# %% [markdown]
# ### 2.3.1 Training Model

# %%
#Training Model
start_time()
ib_catb = setup_model(IB_HYPERPARAMS, "IB")
ib_catb.fit(X_ib_training, y_ib_training, plot=True, eval_set=catboost.Pool(X_ib_validate, label=y_ib_validate, cat_features=get_indexes()), save_snapshot=True, snapshot_interval=60)
end_time("CATB_IB")

#Saving Model as file
ib_catb.save_model("Outputs/CATB/"+MODEL_FILENAME+"_CATB_IB.model", format="json")
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Default metric period is 5 because AUC is/are not implemented for GPU
# 0:	learn: 0.4482485	test: 0.4495294	best: 0.4495294 (0)	total: 54.9ms	remaining: 5.43s
# 1:	total: 100ms	remaining: 4.91s
# 2:	total: 144ms	remaining: 4.66s
# 3:	total: 187ms	remaining: 4.49s
# 4:	total: 235ms	remaining: 4.46s
# 5:	learn: 0.0855044	test: 0.0970130	best: 0.0970130 (5)	total: 286ms	remaining: 4.47s
# 6:	total: 337ms	remaining: 4.47s
# 7:	total: 393ms	remaining: 4.52s
# 8:	total: 449ms	remaining: 4.54s
# 9:	total: 501ms	remaining: 4.5s
# 10:	learn: 0.0374021	test: 0.0533749	best: 0.0533749 (10)	total: 556ms	remaining: 4.49s
# 11:	total: 602ms	remaining: 4.41s
# 12:	total: 646ms	remaining: 4.32s
# 13:	total: 692ms	remaining: 4.25s
# 14:	total: 741ms	remaining: 4.2s
# 15:	learn: 0.0277020	test: 0.0466057	best: 0.0466057 (15)	total: 794ms	remaining: 4.17s
# 16:	total: 842ms	remaining: 4.11s
# 17:	total: 889ms	remaining: 4.05s
# 18:	total: 935ms	remaining: 3.99s
# 19:	total: 980ms	remaining: 3.92s
# 20:	learn: 0.0239878	test: 0.0455859	best: 0.0455859 (20)	total: 1.03s	remaining: 3.86s
# 21:	total: 1.07s	remaining: 3.8s
# 22:	total: 1.12s	remaining: 3.74s
# 23:	total: 1.16s	remaining: 3.69s
# 24:	total: 1.21s	remaining: 3.64s
# 25:	learn: 0.0223908	test: 0.0458331	best: 0.0455859 (20)	total: 1.27s	remaining: 3.61s
# 26:	total: 1.31s	remaining: 3.55s
# 27:	total: 1.36s	remaining: 3.5s
# 28:	total: 1.41s	remaining: 3.45s
# 29:	total: 1.46s	remaining: 3.4s
# 30:	learn: 0.0214472	test: 0.0459911	best: 0.0455859 (20)	total: 1.5s	remaining: 3.35s
# 31:	total: 1.55s	remaining: 3.29s
# 32:	total: 1.6s	remaining: 3.24s
# 33:	total: 1.64s	remaining: 3.19s
# 34:	total: 1.69s	remaining: 3.13s
# 35:	learn: 0.0205907	test: 0.0456870	best: 0.0455859 (20)	total: 1.74s	remaining: 3.09s
# 36:	total: 1.78s	remaining: 3.04s
# 37:	total: 1.83s	remaining: 2.99s
# 38:	total: 1.88s	remaining: 2.94s
# 39:	total: 1.93s	remaining: 2.9s
# 40:	learn: 0.0198797	test: 0.0457532	best: 0.0455859 (20)	total: 1.98s	remaining: 2.85s
# 41:	total: 2.03s	remaining: 2.81s
# 42:	total: 2.08s	remaining: 2.76s
# 43:	total: 2.12s	remaining: 2.7s
# 44:	total: 2.17s	remaining: 2.65s
# 45:	learn: 0.0196910	test: 0.0458340	best: 0.0455859 (20)	total: 2.21s	remaining: 2.6s
# 46:	total: 2.26s	remaining: 2.54s
# 47:	total: 2.3s	remaining: 2.49s
# 48:	total: 2.35s	remaining: 2.44s
# 49:	total: 2.4s	remaining: 2.4s
# 50:	learn: 0.0188494	test: 0.0454079	best: 0.0454079 (50)	total: 2.45s	remaining: 2.35s
# 51:	total: 2.5s	remaining: 2.3s
# 52:	total: 2.54s	remaining: 2.25s
# 53:	total: 2.59s	remaining: 2.21s
# 54:	total: 2.64s	remaining: 2.16s
# 55:	learn: 0.0184954	test: 0.0455829	best: 0.0454079 (50)	total: 2.69s	remaining: 2.11s
# 56:	total: 2.74s	remaining: 2.06s
# 57:	total: 2.79s	remaining: 2.02s
# 58:	total: 2.83s	remaining: 1.97s
# 59:	total: 2.89s	remaining: 1.93s
# 60:	learn: 0.0182911	test: 0.0454964	best: 0.0454079 (50)	total: 2.94s	remaining: 1.88s
# 61:	total: 2.99s	remaining: 1.83s
# 62:	total: 3.04s	remaining: 1.78s
# 63:	total: 3.09s	remaining: 1.74s
# 64:	total: 3.13s	remaining: 1.69s
# 65:	learn: 0.0178710	test: 0.0456208	best: 0.0454079 (50)	total: 3.18s	remaining: 1.64s
# 66:	total: 3.23s	remaining: 1.59s
# 67:	total: 3.28s	remaining: 1.54s
# 68:	total: 3.33s	remaining: 1.5s
# 69:	total: 3.38s	remaining: 1.45s
# 70:	learn: 0.0172688	test: 0.0455024	best: 0.0454079 (50)	total: 3.44s	remaining: 1.41s
# 71:	total: 3.49s	remaining: 1.36s
# 72:	total: 3.54s	remaining: 1.31s
# 73:	total: 3.59s	remaining: 1.26s
# 74:	total: 3.64s	remaining: 1.21s
# 75:	learn: 0.0163761	test: 0.0449745	best: 0.0449745 (75)	total: 3.69s	remaining: 1.17s
# 76:	total: 3.74s	remaining: 1.12s
# 77:	total: 3.8s	remaining: 1.07s
# 78:	total: 3.85s	remaining: 1.02s
# 79:	total: 3.91s	remaining: 977ms
# 80:	learn: 0.0162540	test: 0.0450312	best: 0.0449745 (75)	total: 3.96s	remaining: 930ms
# 81:	total: 4.01s	remaining: 881ms
# 82:	total: 4.07s	remaining: 833ms
# 83:	total: 4.12s	remaining: 785ms
# 84:	total: 4.17s	remaining: 736ms
# 85:	learn: 0.0161310	test: 0.0450194	best: 0.0449745 (75)	total: 4.22s	remaining: 687ms
# 86:	total: 4.27s	remaining: 638ms
# 87:	total: 4.31s	remaining: 588ms
# 88:	total: 4.36s	remaining: 539ms
# 89:	total: 4.41s	remaining: 490ms
# 90:	learn: 0.0157305	test: 0.0447635	best: 0.0447635 (90)	total: 4.48s	remaining: 443ms
# 91:	total: 4.52s	remaining: 393ms
# 92:	total: 4.57s	remaining: 344ms
# 93:	total: 4.62s	remaining: 295ms
# 94:	total: 4.66s	remaining: 245ms
# 95:	learn: 0.0155527	test: 0.0447475	best: 0.0447475 (95)	total: 4.71s	remaining: 196ms
# 96:	total: 4.75s	remaining: 147ms
# 97:	total: 4.8s	remaining: 97.9ms
# 98:	total: 4.85s	remaining: 49ms
# 99:	learn: 0.0154481	test: 0.0447837	best: 0.0447475 (95)	total: 4.9s	remaining: 0us
# bestTest = 0.04474754118
# bestIteration = 95
# Shrink model to first 96 iterations.

# %% [markdown]
# ### 2.3.2. Checking Performance
#
# Using the split for validation for a bit of internal checking of performance (i.e., not official)

# %%
y_pred = ib_catb.predict(X_ib_validate)
print("CATB_IB")
print(classification_report(y_ib_validate, y_pred, digits=4))
print("AUC-ROC:", roc_auc_score(y_ib_validate, y_pred))
print(classification_report(y_ib_validate, y_pred, digits=4), file=open("Outputs/CATB/"+MODEL_FILENAME+"_CATB_IB_ClassReport.txt", mode='w'))
print("AUC-ROC:", roc_auc_score(y_ib_validate, y_pred), file=open("Outputs/CATB/"+MODEL_FILENAME+"_CATB_IB_ClassReport.txt", mode='a'))
disp = ConfusionMatrixDisplay(confusion_matrix(y_ib_validate, y_pred))
disp.plot()
plt.savefig("Outputs/CATB/"+MODEL_FILENAME+"_CATB_IB_"+"_ConfMatrix.png")
# Out:
# CATB_IB
#               precision    recall  f1-score   support
#
#            0     0.9960    0.9826    0.9893      1267
#            1     0.9821    0.9959    0.9889      1211
#
#     accuracy                         0.9891      2478
#    macro avg     0.9890    0.9893    0.9891      2478
# weighted avg     0.9892    0.9891    0.9891      2478
#
# AUC-ROC: 0.9892536646121419

# %% [markdown]
# ### 2.3.3. Preview of the Tree
#
# *How can it be a tree if there is no proof of a tree?*

# %%
tree = ib_catb.plot_tree(0, catboost.Pool(X_ib_training, y_ib_training, cat_features=get_indexes(), feature_names=list(X_ib_training.columns)))
tree.save("Outputs/CATB/"+MODEL_FILENAME+"_CATB_TREE/IB_Tree"+".svg")
tree

# %%
logging("\n")
