# %% [markdown]
# # Evaluation and Comparison of Boosted ML Models in Behavior-Based Malware Detection
#
#
# ## Notebook: CatBoost Training
#
# ***
#
# **What is the objective of this file?**
#
# To train the model using the Train Split (Statically Split).

# %% [markdown]
# ## Checklist
#
# - Ensure that you have the proper dataset files that you intend to use (i.e., whether the lite dataset or full version).
#     - The datasets it will use points to `/Official Development/Dataset/IB` & `/Official Development/Dataset/TB`.
#     - You can run the `/Official Development/Dataset [OFFICIAL] Oliveira Dataset Notebook.ipynb file` or unzip one of the zipped folders in the `/Official Development/Dataset/Processed` towards the two aforementioned folders.
# - Ensure that you have installed the necessary libraries needed to execute the training process.
#     - You can view the list of the specific versions in the thesis document or through the `.sh` or `.bat` files in the repository's home directory.

# %% [markdown]
# # 1. CatB Training Setup
#
# Setting training environment parameters.

# %% [markdown]
# ## 1.0. Tuning Settings
#
# 1. What will the output filename be?
# 2. Will you train a tuned model?
# 3. What hyperparameter values will you use?
#
# For no. 3, the value looks like
# `{'task_type': 'CPU', 'objective': 'Logloss', 'n_estimators': 50, 'max_depth': 11, 'learning_rate': 0.1, 'l2_leaf_reg': 2, 'grow_policy': 'SymmetricTree', 'bootstrap_type': 'Bayesian', 'boosting_type': 'Ordered', 'auto_class_weights': 'Balanced'}`
# which is obtained as part of the results of the associated tuning file to this file.
#
# Alternatively, you can just point a file directly to it (overrides the manual setup if not empty).
#
# **Do not include the custom hyperparameter values for `random_state`, `thread_count`, `verbose`, `cat_features`, and `nan_mode` as the values for these are hardcoded to the notebook.**

# %%
MODEL_FILENAME = "Test" # <== Set the prefix for the filename of the output file (don't include file extension)
TUNED_TRAINING = True # <== Set as True if you'll be training a tuned model.

TB_HYPERPARAMS = "{'task_type': 'CPU', 'objective': 'Logloss', 'n_estimators': 50, 'max_depth': 11, 'learning_rate': 0.1, 'l2_leaf_reg': 2, 'grow_policy': 'SymmetricTree', 'bootstrap_type': 'Bayesian', 'boosting_type': 'Ordered', 'auto_class_weights': 'Balanced'}"
IB_HYPERPARAMS = "{'task_type': 'CPU', 'objective': 'Logloss', 'n_estimators': 50, 'max_depth': 11, 'learning_rate': 0.1, 'l2_leaf_reg': 2, 'grow_policy': 'SymmetricTree', 'bootstrap_type': 'Bayesian', 'boosting_type': 'Ordered', 'auto_class_weights': 'Balanced'}"

TB_HYPERPARAMS_FILE = "Outputs/TEST_TUNE_TB_CATB.tune" # <== Pointing a file overrides the value set above.
IB_HYPERPARAMS_FILE = "Outputs/TEST_TUNE_IB_CATB.tune" # <== Pointing a file overrides the value set above.

STATIC_SPLIT = 0.3 # <== To achieve the 70:30 Static Split
RANDOM_SEED = 1 # <== Must be the same throughout the entire study (acts as a controlled variable), hence let's just settle with 1.

# %% [markdown]
# # ⚠️Warning
#
# **Be careful of modifying the code beyond this point as it was designed to run autonomously based on the parameters set above.**

# %% [markdown]
# ## 1.1. Loading Libraries

# %%
#Python Libraries
import time
from datetime import datetime
import json

#Data/Dataset Libraries
import pandas as pd
import numpy as np

#Model Selection
from sklearn.model_selection import train_test_split

#Metrics (for in-training testing only)
from sklearn.metrics import classification_report, accuracy_score, balanced_accuracy_score, f1_score
from sklearn.metrics import precision_score, recall_score, roc_auc_score

#Visualization
from matplotlib import pyplot as plt

#GBDT Models
import lightgbm
import catboost

#File Writing Library (exclusive for use on LightGBM)
from joblib import dump, load

# %% [markdown]
# ## 1.2. Logging and Diagnostics

# %%
if TUNED_TRAINING:
    MODEL_FILENAME = "TUNED_" + MODEL_FILENAME
    if len(TB_HYPERPARAMS_FILE) != 0:
        f = open(TB_HYPERPARAMS_FILE, "r")
        TB_HYPERPARAMS = f.readline()
        f.close()
    if len(IB_HYPERPARAMS_FILE) != 0:
        f = open(IB_HYPERPARAMS_FILE, "r")
        IB_HYPERPARAMS = f.readline()
        f.close()
    TB_HYPERPARAMS = TB_HYPERPARAMS.replace('\'', '\"').replace("False", "\"False\"").replace("True", "\"True\"")
    TB_HYPERPARAMS = json.loads(str(TB_HYPERPARAMS))
    print("Parsed TB Hyperparams:", TB_HYPERPARAMS)
    IB_HYPERPARAMS = IB_HYPERPARAMS.replace('\'', '\"').replace("False", "\"False\"").replace("True", "\"True\"")
    IB_HYPERPARAMS = json.loads(str(IB_HYPERPARAMS))
    print("Parsed IB Hyperparams:", IB_HYPERPARAMS)
    
start = end = 0
LOG_FILENAME = "CATB_Training_Log.txt"
def logging(message):
    log = open(LOG_FILENAME, "a")
    log.write(message)
    log.close()
def start_time():
    global start
    start = time.time()
def end_time(process):
    global start
    elapse = time.time()-start
    start = 0
    printout = f"{str(datetime.now())}@{MODEL_FILENAME}: {process} - {round(elapse, 6)}s\n"
    logging(printout)
    return round(elapse, 6)
# Out:
# Parsed TB Hyperparams: {'task_type': 'CPU', 'objective': 'Logloss', 'n_estimators': 50, 'max_depth': 6, 'learning_rate': 0.1, 'l2_leaf_reg': 1, 'grow_policy': 'SymmetricTree', 'bootstrap_type': 'Bayesian', 'boosting_type': 'Ordered', 'auto_class_weights': 'Balanced'}
# Parsed IB Hyperparams: {'task_type': 'CPU', 'objective': 'Logloss', 'n_estimators': 50, 'max_depth': 11, 'learning_rate': 0.1, 'l2_leaf_reg': 2, 'grow_policy': 'SymmetricTree', 'bootstrap_type': 'Bayesian', 'boosting_type': 'Ordered', 'auto_class_weights': 'Balanced'}

# %% [markdown]
# ## 1.3. Loading Datasets
#
# Note that it will use the files in `/Official Development/Dataset/IB` & `/Official Development/Dataset/TB`.

# %% [markdown]
# ### 1.3.1. Setting filenames

# %%
#Setting filenames of files
TB_Train = "../Dataset/TB/TB_CATB.csv" # <== Location for Time-based Train Split for LightGBM
#TB_Test = "../Dataset/TB/TB_Test_CATB.csv" # <== Location for Time-based Test Split for LightGBM
IB_Train = "../Dataset/IB/IB_CATB.csv" # <== Location for Instance-based Train Split for LightGBM
#IB_Test = "../Dataset/IB/IB_Test_CATB.csv" # <== Location for Instance-based Test Split for LightGBM

# %% [markdown]
# ### 1.3.2. Loading datasets to DataFrames

# %%
#Loading datasets to DataFrames
tb_train = pd.read_csv(TB_Train, low_memory=False).fillna("NaN")
ib_train = pd.read_csv(IB_Train, low_memory=False).fillna("NaN")

print("Dataset Sizes")
print("TB Train Size:", tb_train.shape)
print("IB Train Size:", ib_train.shape)
# Out:
# Dataset Sizes
# TB Train Size: (4574, 101)
# IB Train Size: (4574, 101)

# %% [markdown]
# ### 1.3.3. Previewing datasets

# %%
#Previewing Time-based Dataset
tb_train.head()
# Out:
#    malware                      t_0                      t_1  \
# 0        1          LdrGetDllHandle            GetSystemInfo
# 1        1  GetSystemTimeAsFileTime  NtAllocateVirtualMemory
# 2        1               LdrLoadDll   LdrGetProcedureAddress
# 3        1  GetSystemTimeAsFileTime               LdrLoadDll
# 4        1  GetSystemTimeAsFileTime               LdrLoadDll
#
#                       t_2                      t_3                      t_4  \
# 0        NtDelayExecution  GetSystemTimeAsFileTime  NtAllocateVirtualMemory
# 1     NtFreeVirtualMemory  NtAllocateVirtualMemory          LdrGetDllHandle
# 2              LdrLoadDll   LdrGetProcedureAddress               LdrLoadDll
# 3  LdrGetProcedureAddress               LdrLoadDll   LdrGetProcedureAddress
# 4  LdrGetProcedureAddress               LdrLoadDll   LdrGetProcedureAddress
#
#                       t_5                      t_6                     t_7  \
# 0     NtFreeVirtualMemory  NtAllocateVirtualMemory         LdrGetDllHandle
# 1  LdrGetProcedureAddress          LdrGetDllHandle  LdrGetProcedureAddress
# 2  LdrGetProcedureAddress               LdrLoadDll  LdrGetProcedureAddress
# 3              LdrLoadDll   LdrGetProcedureAddress              LdrLoadDll
# 4              LdrLoadDll   LdrGetProcedureAddress              LdrLoadDll
#
#                       t_8  ...                     t_90  \
# 0  LdrGetProcedureAddress  ...                  NtClose
# 1         LdrGetDllHandle  ...             GetCursorPos
# 2              LdrLoadDll  ...  NtAllocateVirtualMemory
# 3  LdrGetProcedureAddress  ...         RegQueryValueExW
# 4  LdrGetProcedureAddress  ...   LdrGetProcedureAddress
#
#                       t_91                    t_92                    t_93  \
# 0  NtAllocateVirtualMemory           RegOpenKeyExW             RegCloseKey
# 1  NtAllocateVirtualMemory     NtFreeVirtualMemory            GetCursorPos
# 2               LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 3            RegOpenKeyExW        RegQueryValueExW           RegOpenKeyExW
# 4         GetSystemMetrics         LdrGetDllHandle  LdrGetProcedureAddress
#
#                       t_94                 t_95                    t_96  \
# 0         RegQueryValueExW          RegCloseKey           RegOpenKeyExW
# 1  NtAllocateVirtualMemory  NtFreeVirtualMemory            GetCursorPos
# 2   LdrGetProcedureAddress           LdrLoadDll  LdrGetProcedureAddress
# 3         RegQueryValueExW        RegOpenKeyExW        RegQueryValueExW
# 4      GetSystemDirectoryW           LdrLoadDll            CreateThread
#
#                       t_97                    t_98              t_99
# 0              RegCloseKey        RegQueryValueExW       RegCloseKey
# 1  NtAllocateVirtualMemory     NtFreeVirtualMemory      GetCursorPos
# 2               LdrLoadDll  LdrGetProcedureAddress        LdrLoadDll
# 3            RegOpenKeyExW        RegQueryValueExW     RegOpenKeyExW
# 4          FindResourceExW                 NtClose  GetSystemMetrics
#
# [5 rows x 101 columns]

# %%
#Previewing Instance-based Dataset
ib_train.head()
# Out:
#    malware                      t_0                      t_1  \
# 0        1          LdrGetDllHandle            GetSystemInfo
# 1        1  GetSystemTimeAsFileTime  NtAllocateVirtualMemory
# 2        1               LdrLoadDll   LdrGetProcedureAddress
# 3        1  GetSystemTimeAsFileTime               LdrLoadDll
# 4        1  GetSystemTimeAsFileTime               LdrLoadDll
#
#                       t_2                      t_3  \
# 0        NtDelayExecution  GetSystemTimeAsFileTime
# 1     NtFreeVirtualMemory          LdrGetDllHandle
# 2  NtProtectVirtualMemory                  NtClose
# 3  LdrGetProcedureAddress          LdrGetDllHandle
# 4  LdrGetProcedureAddress          LdrGetDllHandle
#
#                            t_4                          t_5  \
# 0      NtAllocateVirtualMemory          NtFreeVirtualMemory
# 1       LdrGetProcedureAddress  SetUnhandledExceptionFilter
# 2                    NtOpenKey              NtQueryValueKey
# 3  SetUnhandledExceptionFilter         CryptAcquireContextW
# 4  SetUnhandledExceptionFilter             SHGetFolderPathW
#
#                       t_6                       t_7                      t_8  \
# 0  LdrGetProcedureAddress  CreateToolhelp32Snapshot            Thread32First
# 1     GetSystemDirectoryW          NtDelayExecution               LdrLoadDll
# 2         LdrGetDllHandle             GetSystemInfo  NtAllocateVirtualMemory
# 3               NtOpenKey           NtQueryValueKey                  NtClose
# 4            SetErrorMode        GetFileAttributesW         CreateDirectoryW
#
#    ... t_90 t_91 t_92 t_93 t_94 t_95 t_96 t_97 t_98 t_99
# 0  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 101 columns]

# %% [markdown]
# ### 1.3.4. Statically Splitting the Train Split
#
# Train Split --> Training and Validation Split
#
# However only Training Split will be used.

# %%
#Static splitting of Train Split of Time-based
X_tb = tb_train.iloc[:,1:] #All rows, 2nd to last column
y_tb = tb_train.iloc[:,0] #All rows, first column only
X_tb_training, X_tb_validate, y_tb_training, y_tb_validate = train_test_split(X_tb, y_tb, test_size=STATIC_SPLIT, shuffle=True)

#Static splitting of Train Split of Instance-based
X_ib = ib_train.iloc[:,1:] #All rows, 2nd to last column
y_ib = ib_train.iloc[:,0] #All rows, first column only
X_ib_training, X_ib_validate, y_ib_training, y_ib_validate = train_test_split(X_ib, y_ib, test_size=STATIC_SPLIT, shuffle=True)

# %% [markdown]
# # 2. Model Training

# %% [markdown]
# ## 2.1. Setting up the Model

# %%
def get_indexes():
    indexes = []
    for i in range(100):
        indexes.append(f"t_{i}")
    return indexes

def setup_model(HYPERPARAMS):
    global TUNED_TRAINING
    indexes = get_indexes()
    if TUNED_TRAINING:
        return catboost.CatBoostClassifier(**HYPERPARAMS, random_state=RANDOM_SEED, thread_count=-1, verbose=1, cat_features=indexes, nan_mode='Min')
    return catboost.CatBoostClassifier(random_state=RANDOM_SEED, thread_count=-1, verbose=1, cat_features=indexes, nan_mode='Min')

# %% [markdown]
# ## 2.2. Training on Time-Based Behaviors

# %% [markdown]
# ### 2.2.1 Training Model

# %%
#Training Model
start_time()
tb_catb = setup_model(TB_HYPERPARAMS)
tb_catb.fit(X_tb_training, y_tb_training)
end_time("TB_CATB")

#Saving Model as file
tb_catb.save_model("Outputs/"+MODEL_FILENAME+"_TB_CATB.model", format="json")
# Out:
# 0:	learn: 0.5505661	total: 199ms	remaining: 9.76s
# 1:	learn: 0.4443661	total: 315ms	remaining: 7.57s
# 2:	learn: 0.3304839	total: 422ms	remaining: 6.61s
# 3:	learn: 0.2172555	total: 554ms	remaining: 6.37s
# 4:	learn: 0.1676314	total: 696ms	remaining: 6.26s
# 5:	learn: 0.1277432	total: 781ms	remaining: 5.73s
# 6:	learn: 0.1015474	total: 895ms	remaining: 5.5s
# 7:	learn: 0.0856368	total: 1.03s	remaining: 5.42s
# 8:	learn: 0.0764367	total: 1.09s	remaining: 4.99s
# 9:	learn: 0.0685441	total: 1.22s	remaining: 4.87s
# 10:	learn: 0.0593176	total: 1.36s	remaining: 4.81s
# 11:	learn: 0.0536970	total: 1.49s	remaining: 4.71s
# 12:	learn: 0.0494665	total: 1.62s	remaining: 4.62s
# 13:	learn: 0.0468629	total: 1.71s	remaining: 4.39s
# 14:	learn: 0.0442722	total: 1.83s	remaining: 4.26s
# 15:	learn: 0.0426857	total: 1.96s	remaining: 4.17s
# 16:	learn: 0.0403688	total: 2.11s	remaining: 4.09s
# 17:	learn: 0.0392917	total: 2.23s	remaining: 3.97s
# 18:	learn: 0.0384558	total: 2.36s	remaining: 3.85s
# 19:	learn: 0.0372139	total: 2.49s	remaining: 3.73s
# 20:	learn: 0.0353263	total: 2.62s	remaining: 3.62s
# 21:	learn: 0.0337887	total: 2.77s	remaining: 3.52s
# 22:	learn: 0.0334333	total: 2.89s	remaining: 3.4s
# 23:	learn: 0.0330160	total: 3.03s	remaining: 3.28s
# 24:	learn: 0.0324815	total: 3.16s	remaining: 3.16s
# 25:	learn: 0.0321989	total: 3.27s	remaining: 3.02s
# 26:	learn: 0.0311515	total: 3.4s	remaining: 2.9s
# 27:	learn: 0.0299890	total: 3.55s	remaining: 2.79s
# 28:	learn: 0.0290279	total: 3.69s	remaining: 2.67s
# 29:	learn: 0.0288188	total: 3.83s	remaining: 2.55s
# 30:	learn: 0.0277068	total: 3.96s	remaining: 2.43s
# 31:	learn: 0.0268243	total: 4.1s	remaining: 2.3s
# 32:	learn: 0.0261744	total: 4.23s	remaining: 2.18s
# 33:	learn: 0.0260907	total: 4.32s	remaining: 2.03s
# 34:	learn: 0.0256873	total: 4.4s	remaining: 1.88s
# 35:	learn: 0.0251241	total: 4.49s	remaining: 1.75s
# 36:	learn: 0.0247153	total: 4.62s	remaining: 1.62s
# 37:	learn: 0.0241618	total: 4.77s	remaining: 1.5s
# 38:	learn: 0.0240363	total: 4.87s	remaining: 1.37s
# 39:	learn: 0.0238557	total: 4.99s	remaining: 1.25s
# 40:	learn: 0.0237472	total: 5.08s	remaining: 1.11s
# 41:	learn: 0.0235919	total: 5.17s	remaining: 984ms
# 42:	learn: 0.0233719	total: 5.29s	remaining: 860ms
# 43:	learn: 0.0228895	total: 5.42s	remaining: 740ms
# 44:	learn: 0.0225418	total: 5.56s	remaining: 618ms
# 45:	learn: 0.0219437	total: 5.7s	remaining: 496ms
# 46:	learn: 0.0219179	total: 5.77s	remaining: 368ms
# 47:	learn: 0.0218844	total: 5.84s	remaining: 243ms
# 48:	learn: 0.0217402	total: 5.93s	remaining: 121ms
# 49:	learn: 0.0216948	total: 6s	remaining: 0us

# %% [markdown]
# ### 2.2.2. Checking Performance
#
# Using the split for validation for a bit of internal checking of performance (i.e., not official)

# %%
print(classification_report(y_tb_validate, tb_catb.predict(X_tb_validate),digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9985    0.9820    0.9901       665
#            1     0.9833    0.9986    0.9909       708
#
#     accuracy                         0.9905      1373
#    macro avg     0.9909    0.9903    0.9905      1373
# weighted avg     0.9907    0.9905    0.9905      1373

# %% [markdown]
# ### 2.2.3. Preview of the Tree
#
# *How can it be a tree if there is no proof of a tree?*

# %%
tb_catb.plot_tree(0)

# %% [markdown]
# ## 2.3. Training on Instance-Based Behaviors

# %% [markdown]
# ### 2.3.1 Training Model

# %%
#Training Model
start_time()
ib_catb = setup_model(IB_HYPERPARAMS)
ib_catb.fit(X_ib_training, y_ib_training)
end_time("IB_CATB")

#Saving Model as file
ib_catb.save_model("Outputs/"+MODEL_FILENAME+"_IB_CATB.model", format="json")
# Out:
# 0:	learn: 0.5566410	total: 27.8ms	remaining: 1.36s
# 1:	learn: 0.4510431	total: 68.8ms	remaining: 1.65s
# 2:	learn: 0.3005677	total: 95.5ms	remaining: 1.5s
# 3:	learn: 0.2182015	total: 174ms	remaining: 2s
# 4:	learn: 0.1677452	total: 208ms	remaining: 1.87s
# 5:	learn: 0.1469490	total: 236ms	remaining: 1.73s
# 6:	learn: 0.1173550	total: 288ms	remaining: 1.77s
# 7:	learn: 0.1074583	total: 326ms	remaining: 1.71s
# 8:	learn: 0.0973680	total: 390ms	remaining: 1.78s
# 9:	learn: 0.0825056	total: 417ms	remaining: 1.67s
# 10:	learn: 0.0719084	total: 468ms	remaining: 1.66s
# 11:	learn: 0.0632744	total: 574ms	remaining: 1.82s
# 12:	learn: 0.0593302	total: 602ms	remaining: 1.71s
# 13:	learn: 0.0554650	total: 647ms	remaining: 1.66s
# 14:	learn: 0.0517395	total: 729ms	remaining: 1.7s
# 15:	learn: 0.0474569	total: 794ms	remaining: 1.69s
# 16:	learn: 0.0449737	total: 873ms	remaining: 1.69s
# 17:	learn: 0.0428123	total: 927ms	remaining: 1.65s
# 18:	learn: 0.0415838	total: 1.01s	remaining: 1.64s
# 19:	learn: 0.0398548	total: 1.19s	remaining: 1.78s
# 20:	learn: 0.0378033	total: 1.5s	remaining: 2.08s
# 21:	learn: 0.0370546	total: 1.56s	remaining: 1.99s
# 22:	learn: 0.0367785	total: 1.6s	remaining: 1.88s
# 23:	learn: 0.0366079	total: 1.62s	remaining: 1.76s
# 24:	learn: 0.0366077	total: 1.64s	remaining: 1.64s
# 25:	learn: 0.0351587	total: 1.75s	remaining: 1.62s
# 26:	learn: 0.0350128	total: 1.8s	remaining: 1.54s
# 27:	learn: 0.0349310	total: 1.84s	remaining: 1.45s
# 28:	learn: 0.0334067	total: 1.9s	remaining: 1.38s
# 29:	learn: 0.0329861	total: 1.94s	remaining: 1.29s
# 30:	learn: 0.0322600	total: 2.02s	remaining: 1.24s
# 31:	learn: 0.0317362	total: 2.1s	remaining: 1.18s
# 32:	learn: 0.0314960	total: 2.15s	remaining: 1.1s
# 33:	learn: 0.0311198	total: 2.23s	remaining: 1.05s
# 34:	learn: 0.0310141	total: 2.25s	remaining: 966ms
# 35:	learn: 0.0301554	total: 2.36s	remaining: 917ms
# 36:	learn: 0.0288124	total: 2.68s	remaining: 941ms
# 37:	learn: 0.0287362	total: 2.71s	remaining: 856ms
# 38:	learn: 0.0286155	total: 2.74s	remaining: 773ms
# 39:	learn: 0.0284117	total: 2.79s	remaining: 698ms
# 40:	learn: 0.0269108	total: 3.09s	remaining: 679ms
# 41:	learn: 0.0262581	total: 3.2s	remaining: 610ms
# 42:	learn: 0.0259568	total: 3.26s	remaining: 530ms
# 43:	learn: 0.0252239	total: 3.31s	remaining: 451ms
# 44:	learn: 0.0248454	total: 3.64s	remaining: 404ms
# 45:	learn: 0.0248307	total: 3.66s	remaining: 319ms
# 46:	learn: 0.0247681	total: 3.69s	remaining: 236ms
# 47:	learn: 0.0244148	total: 3.74s	remaining: 156ms
# 48:	learn: 0.0243936	total: 3.78s	remaining: 77.1ms
# 49:	learn: 0.0242829	total: 3.81s	remaining: 0us

# %% [markdown]
# ### 2.3.2. Checking Performance
#
# Using the split for validation for a bit of internal checking of performance (i.e., not official)

# %%
print(classification_report(y_tb_validate, tb_catb.predict(X_tb_validate),digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9985    0.9820    0.9901       665
#            1     0.9833    0.9986    0.9909       708
#
#     accuracy                         0.9905      1373
#    macro avg     0.9909    0.9903    0.9905      1373
# weighted avg     0.9907    0.9905    0.9905      1373

# %% [markdown]
# ### 2.3.3. Preview of the Tree
#
# *How can it be a tree if there is no proof of a tree?*

# %%
tb_catb.plot_tree(0)

# %%
logging("\n")
