# %% [markdown]
# # Evaluation and Comparison of Boosted ML Models in Behavior-Based Malware Detection
#
#
# ## Notebook: LightGBM Training
#
# ***
#
# **What is the objective of this file?**
#
# To train the model using the Train Split (Statically Split).

# %% [markdown]
# ## Checklist
#
# - Ensure that you have the proper dataset files that you intend to use (i.e., whether the lite dataset or full version).
#     - The datasets it will use points to `/Official Development/Dataset/IB` & `/Official Development/Dataset/TB`.
#     - You can run the `/Official Development/Dataset [OFFICIAL] Oliveira Dataset Notebook.ipynb file` or unzip one of the zipped folders in the `/Official Development/Dataset/Processed` towards the two aforementioned folders.
# - Ensure that you have installed the necessary libraries needed to execute the training process.
#     - You can view the list of the specific versions in the thesis document or through the `.sh` or `.bat` files in the repository's home directory.

# %% [markdown]
# # 1. LightGBM Training Setup
#
# Setting training environment parameters.

# %% [markdown]
# ## 1.0. Tuning Settings
#
# 1. What will the output filename be?
# 2. Will you train a tuned model?
# 3. What hyperparameter values will you use?
#
# For no. 3, the value looks like
# `{'tree_learner': 'data', 'objective': 'binary', 'num_leaves': 8, 'n_estimators': 50, 'max_depth': -1, 'learning_rate': 0.1, 'l2_leaf_reg': 5, 'device': 'cpu', 'data_sample_strategy': 'goss', 'class_weight': 'balanced', 'boosting_type': 'gbdt', 'boost_from_average': False}`
# which is obtained as part of the results of the associated tuning file to this file.
#
# Alternatively, you can just point a file directly to it (overrides the manual setup if not empty).
#
# **Do not include the custom hyperparameter values for `random_state`, `n_jobs`, and `verbose` as the values for these are hardcoded to the notebook.**

# %%
MODEL_FILENAME = "TEST" # <== Set the prefix for the filename of the output file (don't include file extension)
TUNED_TRAINING = True # <== Set as True if you'll be training a tuned model.

HYPERPARAMS = "{'tree_learner': 'data', 'objective': 'binary', 'num_leaves': 8, 'n_estimators': 50, 'max_depth': -1, 'learning_rate': 0.1, 'l2_leaf_reg': 5, 'device': 'cpu', 'data_sample_strategy': 'goss', 'class_weight': 'balanced', 'boosting_type': 'gbdt', 'boost_from_average': False}"
HYPERPARAMS_FILE = "Outputs/TEST_TUNE_TB_LGBM.tune" # <== Pointing a file; Overrides the value set above. 

STATIC_SPLIT = 0.3 # <== To achieve the 70:30 Static Split
RANDOM_SEED = 1 # <== Think of this as a seed generator which allows for a more consistent "randomization" which also applies on other areas of the study (i.e., dataset, tuning, and eval)

# %% [markdown]
# # ⚠️Warning
#
# **Be careful of modifying the code beyond this point as it was designed to run autonomously based on the parameters set above.**

# %% [markdown]
# ## 1.1. Loading Libraries

# %%
#Python Libraries
import time
from datetime import datetime
import json

#Data/Dataset Libraries
import pandas as pd
import numpy as np

#Model Selection
from sklearn.model_selection import train_test_split

#Metrics (for in-training testing only)
from sklearn.metrics import classification_report, accuracy_score, balanced_accuracy_score, f1_score
from sklearn.metrics import precision_score, recall_score, roc_auc_score

#Visualization
from matplotlib import pyplot as plt

#GBDT Models
import lightgbm
import catboost

#File Writing Library (exclusive for use on LightGBM)
from joblib import dump, load

# %% [markdown]
# ## 1.2. Logging and Diagnostics

# %%
if TUNED_TRAINING:
    MODEL_FILENAME = "TUNED_" + MODEL_FILENAME
    if len(HYPERPARAMS_FILE) != 0:
        f = open(HYPERPARAMS_FILE, "r")
        HYPERPARAMS = f.readline()
        f.close()
    HYPERPARAMS = HYPERPARAMS.replace('\'', '\"')
    HYPERPARAMS = HYPERPARAMS.replace("False", "\"False\"")
    HYPERPARAMS = HYPERPARAMS.replace("True", "\"True\"")
    HYPERPARAMS = json.loads(str(HYPERPARAMS))
    print("Parsed Hyperparams:", HYPERPARAMS)
    
start = end = 0
LOG_FILENAME = "LGBM_Training_Log.txt"
def logging(message):
    log = open(LOG_FILENAME, "a")
    log.write(message)
    log.close()
def startTime():
    global start
    start = time.time()
def endTime(process):
    global start
    elapse = time.time()-start
    start = 0
    printout = f"{str(datetime.now())}@{MODEL_FILENAME}: {process} - {round(elapse, 6)}s\n"
    logging(printout)
    return round(elapse, 6)
# Out:
# Parsed Hyperparams: {'tree_learner': 'data', 'objective': 'binary', 'num_leaves': 31, 'n_estimators': 100, 'max_depth': -1, 'learning_rate': 0.3, 'l2_leaf_reg': 2, 'device': 'gpu', 'data_sample_strategy': 'goss', 'class_weight': 'balanced', 'boosting_type': 'gbdt', 'boost_from_average': 'True'}

# %% [markdown]
# ## 1.3. Loading Datasets
#
# Note that it will use the files in `/Official Development/Dataset/IB` & `/Official Development/Dataset/TB`.

# %% [markdown]
# ### 1.3.1. Setting filenames

# %%
#Setting filenames of files
TB_Train = "../Dataset/TB/TB_LGBM.csv" # <== Location for Time-based Train Split for LightGBM
#TB_Test = "../Dataset/TB/TB_Test_LGBM.csv" # <== Location for Time-based Test Split for LightGBM
IB_Train = "../Dataset/IB/IB_LGBM.csv" # <== Location for Instance-based Train Split for LightGBM
#IB_Test = "../Dataset/IB/IB_Test_LGBM.csv" # <== Location for Instance-based Test Split for LightGBM

# %% [markdown]
# ### 1.3.2. Loading datasets to DataFrames

# %%
#Loading datasets to DataFrames
tb_train = pd.read_csv(TB_Train, low_memory=False).fillna("NaN")
ib_train = pd.read_csv(IB_Train, low_memory=False).fillna("NaN")

print("Dataset Sizes")
print("TB Train Size:", tb_train.shape)
print("IB Train Size:", ib_train.shape)
# Out:
# Dataset Sizes
# TB Train Size: (4574, 101)
# IB Train Size: (4574, 101)

# %% [markdown]
# ### 1.3.3. Previewing datasets

# %%
#Previewing Time-based Dataset
tb_train.head()
# Out:
#    malware  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  t_8  ...  t_90  t_91  \
# 0        1  134   93  162   95  153  170  153  134  135  ...   154   153
# 1        1   95  153  170  153  134  135  134  135  134  ...    72   153
# 2        1  136  135  136  135  136  135  136  135  136  ...   153   136
# 3        1   95  136  135  136  135  136  135  136  135  ...   236   232
# 4        1   95  136  135  136  135  136  135  136  135  ...   135    94
#
#    t_92  t_93  t_94  t_95  t_96  t_97  t_98  t_99
# 0   232   219   236   219   232   219   236   219
# 1   170    72   153   170    72   153   170    72
# 2   135   136   135   136   135   136   135   136
# 3   236   232   236   232   236   232   236   232
# 4   134   135    92   136    25    59   154    94
#
# [5 rows x 101 columns]

# %%
#Previewing Instance-based Dataset
ib_train.head()
# Out:
#    malware  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  t_8  ...  t_90  t_91  \
# 0        1  134   93  162   95  153  170  135   26  270  ...   148   148
# 1        1   95  153  170  134  135  262   92  162  136  ...   148   148
# 2        1  136  135  183  154  177  191  134   93  153  ...   148   148
# 3        1   95  136  135  134  262   28  177  191  154  ...   148   148
# 4        1   95  136  135  134  262  248  254   76   18  ...   148   148
#
#    t_92  t_93  t_94  t_95  t_96  t_97  t_98  t_99
# 0   148   148   148   148   148   148   148   148
# 1   148   148   148   148   148   148   148   148
# 2   148   148   148   148   148   148   148   148
# 3   148   148   148   148   148   148   148   148
# 4   148   148   148   148   148   148   148   148
#
# [5 rows x 101 columns]

# %% [markdown]
# ### 1.3.4. Statically Splitting the Train Split
#
# Train Split --> Training and Validation Split
#
# However only Training Split will be used.

# %%
#Static splitting of Train Split of Time-based
X_tb = tb_train.iloc[:,1:] #All rows, 2nd to last column
y_tb = tb_train.iloc[:,0] #All rows, first column only
X_tb_training, X_tb_validate, y_tb_training, y_tb_validate = train_test_split(X_tb, y_tb, test_size=STATIC_SPLIT, shuffle=True)

#Static splitting of Train Split of Instance-based
X_ib = ib_train.iloc[:,1:] #All rows, 2nd to last column
y_ib = ib_train.iloc[:,0] #All rows, first column only
X_ib_training, X_ib_validate, y_ib_training, y_ib_validate = train_test_split(X_ib, y_ib, test_size=STATIC_SPLIT, shuffle=True)

# %% [markdown]
# # 2. Model Training

# %% [markdown]
# ## 2.1. Setting up the Model

# %%
def setupModel():
    global HYPERPARAMS
    global TUNED_TRAINING
    if TUNED_TRAINING:
        return lightgbm.LGBMClassifier(**HYPERPARAMS, random_state=RANDOM_SEED, n_jobs=-1, verbose=1)
    return lightgbm.LGBMClassifier(random_state=RANDOM_SEED, n_jobs=-1, verbose=1)

# %% [markdown]
# ## 2.2. Training on Time-Based Behaviors

# %% [markdown]
# ### 2.2.1. Training the Model

# %%
#Training Model
startTime()
tb_lgbm = setupModel()
tb_lgbm.fit(X_tb_training, y_tb_training)
endTime("TB_LGBM")

#Saving Model as file
dump(tb_lgbm, "Outputs/"+MODEL_FILENAME+"_TB_LGBM.model")
# Out:
# [LightGBM] [Warning] Unknown parameter: l2_leaf_reg
# [LightGBM] [Warning] Unknown parameter: l2_leaf_reg
# [LightGBM] [Info] Number of positive: 1604, number of negative: 1597
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 4863
# [LightGBM] [Info] Number of data points in the train set: 3201, number of used features: 100
# [LightGBM] [Info] Using GPU Device: gfx902, Vendor: Advanced Micro Devices, Inc.
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.31 MB) transferred to GPU in 0.016291 secs. 1 sparse feature groups
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=-0.000000
# [LightGBM] [Info] Start training from score -0.000000
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.15 MB) transferred to GPU in 0.008790 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.12 MB) transferred to GPU in 0.007789 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.008826 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007600 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007784 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007809 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007726 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007517 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.008440 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007878 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007872 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007732 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.008432 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007974 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.008448 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007472 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007585 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007568 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007547 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007747 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.008473 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007698 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007628 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.009011 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007744 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.008987 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.008474 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007261 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007568 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.008059 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.008523 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007607 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.008263 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007784 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007524 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007751 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007516 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007254 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007713 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007922 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007739 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007829 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007792 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007736 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007306 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.008907 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007756 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007460 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007591 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007437 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007628 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007525 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.008440 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.008597 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007732 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.008693 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007769 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007634 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007600 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007968 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.008007 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.008012 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.008578 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007832 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007987 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.008432 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.008029 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.009122 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.008075 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007708 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007832 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007698 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007598 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007351 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007641 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007674 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007324 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007800 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007507 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007445 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.008770 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.008051 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007528 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.008354 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007730 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007786 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007701 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007976 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007918 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.008370 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.008311 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007744 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007843 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007750 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.008243 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.007884 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 98 dense feature groups (0.09 MB) transferred to GPU in 0.008253 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ['Outputs/TUNED_TEST_TUNED_TB_LGBM.model']

# %% [markdown]
# ### 2.2.2. Checking Performance
#
# Using the split for validation for a bit of internal checking of performance (i.e., not official)

# %%
print(classification_report(y_tb_validate, tb_lgbm.predict(X_tb_validate),digits=4))
# Out:
# [LightGBM] [Warning] Unknown parameter: l2_leaf_reg
#               precision    recall  f1-score   support
#
#            0     0.9970    0.9783    0.9876       690
#            1     0.9784    0.9971    0.9877       683
#
#     accuracy                         0.9876      1373
#    macro avg     0.9877    0.9877    0.9876      1373
# weighted avg     0.9878    0.9876    0.9876      1373

# %% [markdown]
# ### 2.2.3. Preview of the Tree
#
# *How can it be a tree if there is no proof of a tree?*

# %%
#One of the many layers of LGBM (1st layer)
lightgbm.plot_tree(tb_lgbm, figsize=(10,10), dpi=300, show_info='data_percentage', precision=2, orientation='vertical')
# Out:
# <Axes: >

# %% [markdown]
# ## 2.3. Training on Instance-Based Behaviors

# %% [markdown]
# ### 2.3.1. Training the Model

# %%
#Training Model
startTime()
ib_lgbm = setupModel()
ib_lgbm.fit(X_ib_training, y_ib_training)
endTime("IB_LGBM")

#Saving Model as file
dump(ib_lgbm, "Outputs/"+MODEL_FILENAME+"_IB_LGBM.model")
# Out:
# [LightGBM] [Warning] Unknown parameter: l2_leaf_reg
# [LightGBM] [Warning] Unknown parameter: l2_leaf_reg
# [LightGBM] [Info] Number of positive: 1575, number of negative: 1626
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1529
# [LightGBM] [Info] Number of data points in the train set: 3201, number of used features: 34
# [LightGBM] [Info] Using GPU Device: gfx902, Vendor: Advanced Micro Devices, Inc.
# [LightGBM] [Info] Compiling OpenCL Kernel with 64 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.07 MB) transferred to GPU in 0.005585 secs. 1 sparse feature groups
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Start training from score 0.000000
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.03 MB) transferred to GPU in 0.003785 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003484 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003565 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003513 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003406 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.007784 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.004659 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003282 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003458 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003620 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003616 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003450 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003642 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003423 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003370 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003569 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003541 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003286 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003517 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003410 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003985 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003514 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003347 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003712 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003683 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003526 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.004676 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003449 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003481 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003677 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003513 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003514 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003329 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003488 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003399 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003433 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003587 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003478 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003622 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003431 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003616 secs. 1 sparse feature groups
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003355 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003615 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003615 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003800 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003621 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003375 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003690 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003411 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.006688 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003473 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003643 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003652 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003578 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003333 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003450 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003634 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003572 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003578 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003763 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003412 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003554 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003767 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003493 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003370 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003610 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003328 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.004189 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003466 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003553 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003999 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003693 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003641 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003373 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003692 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003666 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003576 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003708 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003800 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003345 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003654 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003505 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003432 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003625 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003356 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003936 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003531 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003402 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.004099 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003575 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003314 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003500 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003639 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003729 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003451 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003491 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 22 dense feature groups (0.02 MB) transferred to GPU in 0.003249 secs. 1 sparse feature groups
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ['Outputs/TUNED_TEST_TUNED_IB_LGBM.model']

# %% [markdown]
# ### 2.3.2. Checking Performance
#
# Using the split for validation for a bit of internal checking of performance (i.e., not official)

# %%
print(classification_report(y_ib_validate, ib_lgbm.predict(X_ib_validate),digits=4))
# Out:
# [LightGBM] [Warning] Unknown parameter: l2_leaf_reg
#               precision    recall  f1-score   support
#
#            0     0.9984    0.9697    0.9839       661
#            1     0.9726    0.9986    0.9854       712
#
#     accuracy                         0.9847      1373
#    macro avg     0.9855    0.9842    0.9847      1373
# weighted avg     0.9851    0.9847    0.9847      1373

# %% [markdown]
# ### 2.3.3. Preview of the Tree
#
# *How can it be a tree if there is no proof of a tree?*

# %%
#One of the many layers of LGBM (1st layer)
lightgbm.plot_tree(ib_lgbm, figsize=(10,10), dpi=300, show_info='data_percentage', precision=2, orientation='vertical')
# Out:
# <Axes: >

# %%
logging("\n")
