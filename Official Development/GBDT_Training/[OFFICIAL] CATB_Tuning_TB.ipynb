# %% [markdown]
# # Evaluation and Comparison of Boosted ML Models in Behavior-Based Malware Detection
#
#
# ## Notebook: CatBoost Tuning
#
# ***
#
# **What is the objective of this file?**
#
# To tune the model using the Train Split (Dynamically Split).

# %% [markdown]
# # Checklist
#
# - Ensure that you have the proper dataset files that you intend to use (i.e., whether the lite dataset or full version).
#     - The datasets it will use points to `/Official Development/Dataset/IB` & `/Official Development/Dataset/TB`.
#     - You can run the `/Official Development/Dataset [OFFICIAL] Oliveira Dataset Notebook.ipynb file` or unzip one of the zipped folders in the `/Official Development/Dataset/Processed` towards the two aforementioned folders.
# - Ensure that you have installed the necessary libraries needed to execute the training process.
#     - You can view the list of the specific versions in the thesis document or through the `.sh` or `.bat` files in the repository's home directory.

# %% [markdown]
# # 1. CatBoost Tuning Setup
#
# Setting tuning environment parameters.

# %% [markdown]
# ## 1.0. Tuning Settings
#
# 1. What will the output filename be?
# 2. What is the dictionary of hyperparameter values?

# %%
OUTPUT_FILENAME = "RYZEN3b" # <== Specify the filename of the output hyperparameters text file (can be used during tuned model training).

K = 5
DYNAMIC_SPLIT = 1/K # <== Expected validation ratio. Training ratio will be 1-(1/K). Just for when needed to view.
RANDOM_SEED = 1 # <==  <== Must be the same throughout the entire study (acts as a controlled variable), hence let's just settle with 1.

# %% [markdown]
# **Recommended Parameters as per the paper/documentation:**
# 1. grow_policy = SymmetricTree
# 2. objective = Logloss
# 3. bootstrap_type* = Bayesian
# 4. boosting_type = Ordered/Plain*
#
# *As per documentation relative to study's objectives and needs.

# %%
#Sample (tested) parameter set
catb_params = {
    #Based-on Study/Documentation (Do not change)
    'grow_policy':['SymmetricTree'], # CatBoost is intended to grow symmetrically.
    'objective':['Logloss'], # Same objective as LightGBMClassifier
    'bootstrap_type':['Bayesian'], # Recommended for classifier models
    'boosting_type':['Ordered'], # "Ordered Boosting" as per paper.
    
    #Others; Not common but can improve accuracy/performance:
    'task_type':['GPU'], #CPU/GPU (CUDA)
    #'devices':['0:1'], #incase there are multiple-GPUs
    'gpu_cat_features_storage':['CpuPinnedMemory'],
    'pinned_memory_size':['4gb'],
    
    #Common (Add and experiment with valid values)
    'learning_rate':[0.1,0.2,0.3], #Default: Varies on 'objective'
    'l2_leaf_reg':[1,2,3], #Default: 3.0
    'max_depth':[2,4,6,8,10], #Default: 6 (GPU); Limited by GPU memory (up to 16)
    'n_estimators':[5,10,50,100,500,1000,5000,10000], #Default: 1000
    #'max_leaves':[2,4,8,16,32,64], #Only applicable if 'grow_policy' is Lossguide
    #Source: https://catboost.ai/en/docs/references/training-parameters/common
}

# %% [markdown]
# # ⚠️Warning
#
# **Be careful of modifying the code beyond this point as it was designed to run autonomously based on the parameters set above.**

# %% [markdown]
# ## 1.1. Loading Libraries & Diagnostics

# %%
#Python Libraries
import time
from datetime import datetime
import os

#Data/Dataset Libraries
import pandas as pd
import numpy as np

#Model Selection
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

#Metrics (for in-tuning testing only)
from sklearn.metrics import classification_report, accuracy_score, balanced_accuracy_score, f1_score
from sklearn.metrics import precision_score, recall_score, roc_auc_score

#Visualization
from matplotlib import pyplot as plt

#GBDT Models
# import lightgbm
import catboost

#File Writing Library (exclusive for use on LightGBM)
from joblib import dump, load

start = end = 0
LOG_FILENAME = "CATB_Tuning_Log.txt"

# %%
def logging(message):
    log = open(LOG_FILENAME, "a")
    log.write(message)
    log.close()
def start_time():
    global start
    start = time.time()
def end_time(process):
    global start
    elapse = time.time()-start
    start = 0
    printout = f"{str(datetime.now())}@{OUTPUT_FILENAME}: {process} - {round(elapse, 6)}s\n"
    logging(printout)
    return round(elapse, 6)
def print_to_file(label, output):
    global OUTPUT_FILENAME
    filename = f"{OUTPUT_FILENAME}_{label}.tune"
    with open("Outputs/CATB/" + filename, 'w') as f:
        f.write(str(output))
        f.close()
def get_indexes(dataset):
    indexes = []
    for i in range(dataset.shape[1]-1):
        indexes.append("t_"+str(i))
    return indexes

# %% [markdown]
# ## 1.2. Loading Datasets

# %% [markdown]
# ### 1.2.1. Setting Filenames

# %%
#Setting filenames of files
TB_Train = "../Dataset/TB/CATB_TB.csv" # <== Location for Time-based Train Split for LightGBM
#TB_Test = "../Dataset/TB/CATB_TB_Test.csv" # <== Location for Time-based Test Split for LightGBM
IB_Train = "../Dataset/IB/CATB_IB.csv" # <== Location for Instance-based Train Split for LightGBM
#IB_Test = "../Dataset/IB/CATB_IB_Test.csv" # <== Location for Instance-based Test Split for LightGBM

# %% [markdown]
# ### 1.2.2. Loading datasets to DataFrames

# %%
#Loading datasets to DataFrames
tb_train = pd.read_csv(TB_Train, low_memory=False).fillna("NaN")
ib_train = pd.read_csv(IB_Train, low_memory=False).fillna("NaN")

print("Dataset Sizes")
print("TB Train Size:", tb_train.shape)
print("IB Train Size:", ib_train.shape)
# Out:
# Dataset Sizes
# TB Train Size: (8258, 101)
# IB Train Size: (8258, 101)

# %% [markdown]
# ### 1.2.3. Previewing datasets

# %%
#Previewing Time-based Dataset
tb_train.head()
# Out:
#    malware                      t_0            t_1                     t_2  \
# 0        1             SetErrorMode  OleInitialize         LdrGetDllHandle
# 1        1  GetSystemTimeAsFileTime     LdrLoadDll  LdrGetProcedureAddress
# 2        1  GetSystemTimeAsFileTime     LdrLoadDll  LdrGetProcedureAddress
# 3        1  GetSystemTimeAsFileTime     LdrLoadDll  LdrGetProcedureAddress
# 4        1                  NtClose      NtOpenKey         NtQueryValueKey
#
#           t_3                     t_4              t_5  \
# 0  LdrLoadDll  LdrGetProcedureAddress       LdrLoadDll
# 1  LdrLoadDll  LdrGetProcedureAddress       LdrLoadDll
# 2  LdrLoadDll  LdrGetProcedureAddress       LdrLoadDll
# 3  LdrLoadDll  LdrGetProcedureAddress       LdrLoadDll
# 4     NtClose               NtOpenKey  NtQueryValueKey
#
#                       t_6              t_7                     t_8  ...  \
# 0  LdrGetProcedureAddress       LdrLoadDll  LdrGetProcedureAddress  ...
# 1  LdrGetProcedureAddress       LdrLoadDll  LdrGetProcedureAddress  ...
# 2  LdrGetProcedureAddress       LdrLoadDll  LdrGetProcedureAddress  ...
# 3  LdrGetProcedureAddress       LdrLoadDll  LdrGetProcedureAddress  ...
# 4                 NtClose  LdrGetDllHandle  LdrGetProcedureAddress  ...
#
#                       t_90               t_91                    t_92  \
# 0            RegOpenKeyExW   RegQueryValueExW             RegCloseKey
# 1  NtAllocateVirtualMemory   NtCreateThreadEx       NtDuplicateObject
# 2  NtAllocateVirtualMemory         LdrLoadDll  LdrGetProcedureAddress
# 3         NtCreateThreadEx  NtDuplicateObject          NtResumeThread
# 4   LdrGetProcedureAddress  LookupAccountSidW  LdrGetProcedureAddress
#
#                       t_93                 t_94                        t_95  \
# 0           NtCreateMutant  GetNativeSystemInfo  GetSystemWindowsDirectoryW
# 1           NtResumeThread    NtDuplicateObject     NtAllocateVirtualMemory
# 2         NtDelayExecution          EnumWindows     GetSystemTimeAsFileTime
# 3  NtAllocateVirtualMemory    NtDuplicateObject               RegOpenKeyExW
# 4        LookupAccountSidW           LdrLoadDll      LdrGetProcedureAddress
#
#                t_96                     t_97                     t_98  \
# 0           NtClose               LdrLoadDll   LdrGetProcedureAddress
# 1     RegOpenKeyExW         RegQueryValueExW  GetFileVersionInfoSizeW
# 2     RegOpenKeyExW         RegQueryInfoKeyW            RegEnumKeyExW
# 3  RegQueryValueExW  GetFileVersionInfoSizeW      GetFileVersionInfoW
# 4        LdrLoadDll   LdrGetProcedureAddress               LdrLoadDll
#
#                       t_99
# 0              RegEnumKeyW
# 1  NtAllocateVirtualMemory
# 2            RegOpenKeyExW
# 3              RegCloseKey
# 4   LdrGetProcedureAddress
#
# [5 rows x 101 columns]

# %%
#Previewing Instance-based Dataset
ib_train.head()
# Out:
#    malware                      t_0            t_1                     t_2  \
# 0        1             SetErrorMode  OleInitialize         LdrGetDllHandle
# 1        1  GetSystemTimeAsFileTime     LdrLoadDll  LdrGetProcedureAddress
# 2        1  GetSystemTimeAsFileTime     LdrLoadDll  LdrGetProcedureAddress
# 3        1  GetSystemTimeAsFileTime     LdrLoadDll  LdrGetProcedureAddress
# 4        1                  NtClose      NtOpenKey         NtQueryValueKey
#
#                            t_3                          t_4  \
# 0                   LdrLoadDll       LdrGetProcedureAddress
# 1  SetUnhandledExceptionFilter       NtProtectVirtualMemory
# 2              LdrGetDllHandle  SetUnhandledExceptionFilter
# 3  SetUnhandledExceptionFilter       NtProtectVirtualMemory
# 4              LdrGetDllHandle       LdrGetProcedureAddress
#
#                        t_5                         t_6              t_7  \
# 0            NtOpenSection          NtMapViewOfSection    RegOpenKeyExW
# 1  NtAllocateVirtualMemory  GetSystemWindowsDirectoryW    CreateActCtxW
# 2     CryptAcquireContextW                   NtOpenKey  NtQueryValueKey
# 3  NtAllocateVirtualMemory  GetSystemWindowsDirectoryW    CreateActCtxW
# 4            GetSystemInfo     NtAllocateVirtualMemory    RegOpenKeyExW
#
#                 t_8  ... t_90 t_91 t_92 t_93 t_94 t_95 t_96 t_97 t_98 t_99
# 0  RegQueryValueExW  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1   LdrGetDllHandle  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2           NtClose  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3   LdrGetDllHandle  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  FindFirstFileExW  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 101 columns]

# %% [markdown]
# ## 1.3. Preparing Stratified K-Folds for RandomizedSearchCV
#
# By default, RandomizedSearchCV uses a normal K-Folds with k value of 5.

# %% [markdown]
# ### 1.3.1. Underlying Code for Stratified K-Folds
#
# Most of the code is for visualizing actually. Only `get_strat_kfold()` matters.

# %%
def get_strat_kfold():
    global K
    return StratifiedKFold(n_splits=K, shuffle=True, random_state=1)

#K-folds sample visualization
def kfolds_vis(dataset):
    global K
    X = dataset.iloc[:,1:] #All rows, 2nd to last column
    y = dataset.iloc[:,0] #All rows, first column only
    fig, ax = plt.subplots(figsize=(10,K+1), dpi=300)
    train = plot_cv_indices(get_strat_kfold(), X, y, ax, K)
    plt.show()

#K-folds sample visualization (inner workings)
def plot_cv_indices(cv, X, y, ax, n_splits, lw=25):
    #From: https://scikit-learn.org/stable/auto_examples/model_selection/plot_cv_indices.html
    for ii, (tr, tt) in enumerate(cv.split(X=X, y=y)):
        indices = np.array([np.nan] * len(X))
        indices[tt], indices[tr] = 1,0
        ax.scatter(range(len(indices)), [ii] * len(indices), c=indices, marker="_", 
                   lw=lw, cmap=plt.cm.Paired, vmin=0, vmax=1)
    #ax.scatter(range(len(X)), [ii] * len(X), c=y, marker="_", lw=lw, cmap=plt.cm.Paired)
    yticklabels = list(range(n_splits))
    ax.set(yticks=np.arange(n_splits), yticklabels=yticklabels, xlabel="Dataset Subsample", ylabel="CV iteration", ylim=[n_splits,-1], xlim=[0, X.shape[0]])
    ax.set_title("{}".format(type(cv).__name__))
    return ax

# %% [markdown]
# ### 1.3.2. Visualizing the K-Folds
#
# The objective of the visualization is to show that no CV iteration will have the same set of samples (i.e., no overfitting).

# %%
print("Stratified K-Folds Split at",K,"splits.")
print("TB/TB_Encoded Dataset")
kfolds_vis(tb_train)
print("IB/IB_Encoded Dataset")
kfolds_vis(ib_train)
# Out:
# Stratified K-Folds Split at 5 splits.
# TB/TB_Encoded Dataset
# IB/IB_Encoded Dataset

# %% [markdown]
# ### 1.3.3. Plotting Search CV Results
#
# As suggested from https://stackoverflow.com/a/57013458

# %%
def plot_search_results(grid, cv_results, TYPE, scoring=['Accuracy','Precision','Recall','ROC-AUC']):
    ## Results from grid search
    results = grid.cv_results_
    means_test_acc = results['mean_test_accuracy']
    stds_test_acc = results['std_test_accuracy']
    means_test_prec = results['mean_test_precision']
    stds_test_prec = results['std_test_precision']
    means_test_rec = results['mean_test_recall']
    stds_test_rec = results['std_test_recall']
    means_test_auc = results['mean_test_roc_auc']
    stds_test_auc = results['std_test_roc_auc']
    ## Getting indexes of values per hyper-parameter
    masks=[]
    masks_names= list(grid.best_params_.keys())
    for p_k, p_v in grid.best_params_.items():
        masks.append(list(results['param_'+p_k].data==p_v))
    params = grid.get_params()['param_grid']

    ## Plotting results (per Hyperparam)
    plot_row = 0
    if len(params)%3 == 0:
        plot_row = int(len(params)/3)
    else:
        plot_row = int(len(params)/3) + 1
    fig, ax = plt.subplots(plot_row,3, sharex='none', sharey='none',figsize=(16,4*plot_row), dpi=300, layout='constrained')
    fig.suptitle('Performance on Different Hyperparameter Values (uses Validation Split)')
    pram_preformace_in_best = {}
    row = col = 0
    for i, p in enumerate(masks_names):
        m = np.stack(masks[:i] + masks[i+1:])
        pram_preformace_in_best
        best_parms_mask = m.all(axis=0)
        best_index = np.where(best_parms_mask)[0]
        x = np.array(params[p])
        ax[row,col].set_ylabel("Mean Score")
        ax[row,col].errorbar(x, np.array(means_test_acc[best_index]), np.array(stds_test_acc[best_index]), linestyle='-', marker='o', label='Accuracy')
        ax[row,col].errorbar(x, np.array(means_test_prec[best_index]), np.array(stds_test_prec[best_index]), linestyle='-', marker='o', label='Precision')
        ax[row,col].errorbar(x, np.array(means_test_rec[best_index]), np.array(stds_test_rec[best_index]), linestyle='-', marker='o', label='Recall')
        ax[row,col].errorbar(x, np.array(means_test_auc[best_index]), np.array(stds_test_auc[best_index]), linestyle='-', marker='o', label='AUC-ROC')
        ax[row,col].legend()
        ax[row,col].set_xlabel(p.upper())
        col += 1
        if col == 3:
            col = 0
            row += 1
    plt.savefig('Outputs/CATB/'+ OUTPUT_FILENAME + "_" + TYPE + "_CATB_HYPERPARAMS.png")
    plt.show()
    
    ## Plotting results (per Iteration)
    plt.figure(figsize=(8,5), dpi=300)
    plt.ylabel('Score')
    plt.xlabel('Tuning Iterations')
    plt.plot(cv_results.index, cv_results['mean_test_accuracy'], linestyle='-', marker='o', label='Accuracy')
    # plt.savefig('Outputs/CATB/'+OUTPUT_FILENAME+'_'+TYPE+'_CATB_ACCURACY'+".png")
    plt.plot(cv_results.index, cv_results['mean_test_precision'], linestyle='-', marker='o', label='Precision')
    # plt.savefig('Outputs/CATB/'+OUTPUT_FILENAME+'_'+TYPE+'_CATB_PRECISION'+".png")
    plt.plot(cv_results.index, cv_results['mean_test_recall'], linestyle='-', marker='o', label='Recall')
    # plt.savefig('Outputs/CATB/'+OUTPUT_FILENAME+'_'+TYPE+'_CATB_RECALL'+".png")
    plt.plot(cv_results.index, cv_results['mean_test_roc_auc'], linestyle='-', marker='o', label='AUC-ROC')
    plt.title("Performance on Different Hyperparameter Values (uses Validation Split)")
    plt.savefig('Outputs/CATB/'+OUTPUT_FILENAME+'_'+TYPE+'_CATB_ITERATIONS'+".png")
    plt.legend(loc='upper left')
    plt.show()

# %% [markdown]
# ## 2. Tuning Proper
#
# *Actual Model Tuning Process*
#
# **Notes:**
# 1. Not all hyperparameters are compatible with each other.
# 2. Select, test, and prioritize ones that are relevant to the project.
# 3. The example shown below are already tested for compatibility.
# 4. Watch your terminal for outputs.
#
# CATB Hyperparameters: https://lightgbm.readthedocs.io/en/latest/Parameters.html
#
# CatBoost Hyperparameters: https://catboost.ai/en/docs/references/training-parameters/

# %% [markdown]
# ## 2.1. Tuning Preparation
#
# The `refit_strategy()` contains the code for model tuning strategy where multiple metrics are considered as part of the model selection process. The order of metrics (by importance) are as follows: Accuracy, Precision, Recall, & Training Time.

# %%
#Create the Stratified K-Folds
stratKFold = get_strat_kfold()

#Specify features (X) and labels (y) for Time-based data
X_tb = tb_train.iloc[:,1:101] #All rows, 2nd to last column
y_tb = tb_train.iloc[:,0] #All rows, first column only

#Specify features (X) and labels (y) for Instance-based data
X_ib = ib_train.iloc[:,1:101] #All rows, 2nd to last column
y_ib = ib_train.iloc[:,0] #All rows, first column only

def get_threshold(cv_results, target:str):
    return cv_results[target].max() - (2*cv_results[target].std())

def refit_strategy(cv_results):
    cv_results_ = pd.DataFrame(cv_results)
    # Filter-out all results below 80% score on acc, prec, & recall
    cv_results_ = cv_results_[cv_results_["mean_test_accuracy"] >= .80]
    cv_results_ = cv_results_[cv_results_["mean_test_precision"] >= .80]
    cv_results_ = cv_results_[cv_results_["mean_test_recall"] >= .80]
    cv_results_ = cv_results_[cv_results_["mean_test_f1"] >= .80]
    cv_results_ = cv_results_[cv_results_["mean_test_roc_auc"] >= .80]
    # Filter-out all results below max-std threshold score on acc, prec, & recall
    cv_results_ = cv_results_[cv_results_["mean_test_accuracy"] >= get_threshold(cv_results_, 'mean_test_accuracy')]
    cv_results_ = cv_results_[cv_results_["mean_test_precision"] >= get_threshold(cv_results_, 'mean_test_precision')]
    cv_results_ = cv_results_[cv_results_["mean_test_recall"] >= get_threshold(cv_results_, 'mean_test_recall')]
    cv_results_ = cv_results_[cv_results_["mean_test_f1"] >= get_threshold(cv_results_, 'mean_test_f1')]
    cv_results_ = cv_results_[cv_results_["mean_test_roc_auc"] >= get_threshold(cv_results_, 'mean_test_roc_auc')]
    cv_results_.to_csv(f"./Outputs/CATB/CVRes_{time.time()}.csv", index=False)
    display(cv_results_)
    return cv_results_['mean_fit_time'].idxmax()

def get_tuner(model, params, scoring=['accuracy','precision','recall', 'roc_auc', 'f1']):
    return GridSearchCV(model, params, scoring=scoring, n_jobs=1, refit=refit_strategy, 
                        cv=get_strat_kfold(), verbose=2, pre_dispatch=8, error_score=0, return_train_score=True)

# %% [markdown]
# ## 2.2. Time-based Model Tuning

# %%
start_time()
catb_classifier = catboost.CatBoostClassifier(random_state=1, thread_count=-1, verbose=0, 
                                              cat_features=get_indexes(tb_train), nan_mode='Min', one_hot_max_size=256,)
tb_tuner = get_tuner(catb_classifier, catb_params)
tb_tuner.fit(X_tb, y_tb)
end_time("CATB_TB")
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.1, n_estimators=10, objective=Logloss, task_type=GPU; total time=   1.8s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.1, n_estimators=10, objective=Logloss, task_type=GPU; total time=   1.1s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.1, n_estimators=10, objective=Logloss, task_type=GPU; total time=   1.2s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.1, n_estimators=10, objective=Logloss, task_type=GPU; total time=   1.2s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.1, n_estimators=10, objective=Logloss, task_type=GPU; total time=   1.2s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.1, n_estimators=50, objective=Logloss, task_type=GPU; total time=   3.5s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.1, n_estimators=50, objective=Logloss, task_type=GPU; total time=   3.7s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.1, n_estimators=50, objective=Logloss, task_type=GPU; total time=   3.3s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.1, n_estimators=50, objective=Logloss, task_type=GPU; total time=   3.5s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.1, n_estimators=50, objective=Logloss, task_type=GPU; total time=   3.4s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.1, n_estimators=100, objective=Logloss, task_type=GPU; total time=   6.3s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.1, n_estimators=100, objective=Logloss, task_type=GPU; total time=   6.0s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.1, n_estimators=100, objective=Logloss, task_type=GPU; total time=   5.8s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.1, n_estimators=100, objective=Logloss, task_type=GPU; total time=   5.8s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.1, n_estimators=100, objective=Logloss, task_type=GPU; total time=   5.8s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.2, n_estimators=10, objective=Logloss, task_type=GPU; total time=   1.1s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.2, n_estimators=10, objective=Logloss, task_type=GPU; total time=   1.1s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.2, n_estimators=10, objective=Logloss, task_type=GPU; total time=   1.1s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.2, n_estimators=10, objective=Logloss, task_type=GPU; total time=   1.1s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.2, n_estimators=10, objective=Logloss, task_type=GPU; total time=   1.2s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.2, n_estimators=50, objective=Logloss, task_type=GPU; total time=   3.3s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.2, n_estimators=50, objective=Logloss, task_type=GPU; total time=   3.2s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.2, n_estimators=50, objective=Logloss, task_type=GPU; total time=   3.4s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.2, n_estimators=50, objective=Logloss, task_type=GPU; total time=   3.5s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.2, n_estimators=50, objective=Logloss, task_type=GPU; total time=   3.4s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.2, n_estimators=100, objective=Logloss, task_type=GPU; total time=   6.2s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.2, n_estimators=100, objective=Logloss, task_type=GPU; total time=   6.3s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.2, n_estimators=100, objective=Logloss, task_type=GPU; total time=   6.5s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.2, n_estimators=100, objective=Logloss, task_type=GPU; total time=   6.3s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.2, n_estimators=100, objective=Logloss, task_type=GPU; total time=   7.0s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.3, n_estimators=10, objective=Logloss, task_type=GPU; total time=   1.2s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.3, n_estimators=10, objective=Logloss, task_type=GPU; total time=   1.2s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.3, n_estimators=10, objective=Logloss, task_type=GPU; total time=   1.2s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.3, n_estimators=10, objective=Logloss, task_type=GPU; total time=   1.3s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.3, n_estimators=10, objective=Logloss, task_type=GPU; total time=   1.2s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.3, n_estimators=50, objective=Logloss, task_type=GPU; total time=   3.6s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.3, n_estimators=50, objective=Logloss, task_type=GPU; total time=   3.5s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.3, n_estimators=50, objective=Logloss, task_type=GPU; total time=   3.6s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.3, n_estimators=50, objective=Logloss, task_type=GPU; total time=   3.6s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.3, n_estimators=50, objective=Logloss, task_type=GPU; total time=   3.4s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.3, n_estimators=100, objective=Logloss, task_type=GPU; total time=   6.1s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.3, n_estimators=100, objective=Logloss, task_type=GPU; total time=   6.4s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.3, n_estimators=100, objective=Logloss, task_type=GPU; total time=   5.9s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.3, n_estimators=100, objective=Logloss, task_type=GPU; total time=   5.8s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.3, n_estimators=100, objective=Logloss, task_type=GPU; total time=   5.8s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.4, n_estimators=10, objective=Logloss, task_type=GPU; total time=   1.1s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.4, n_estimators=10, objective=Logloss, task_type=GPU; total time=   1.1s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.4, n_estimators=10, objective=Logloss, task_type=GPU; total time=   1.1s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.4, n_estimators=10, objective=Logloss, task_type=GPU; total time=   1.2s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.4, n_estimators=10, objective=Logloss, task_type=GPU; total time=   1.3s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.4, n_estimators=50, objective=Logloss, task_type=GPU; total time=   3.4s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.4, n_estimators=50, objective=Logloss, task_type=GPU; total time=   3.3s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.4, n_estimators=50, objective=Logloss, task_type=GPU; total time=   3.3s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.4, n_estimators=50, objective=Logloss, task_type=GPU; total time=   3.3s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.4, n_estimators=50, objective=Logloss, task_type=GPU; total time=   3.2s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.4, n_estimators=100, objective=Logloss, task_type=GPU; total time=   6.1s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.4, n_estimators=100, objective=Logloss, task_type=GPU; total time=   6.0s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.4, n_estimators=100, objective=Logloss, task_type=GPU; total time=   6.3s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.4, n_estimators=100, objective=Logloss, task_type=GPU; total time=   6.3s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.4, n_estimators=100, objective=Logloss, task_type=GPU; total time=   6.3s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.5, n_estimators=10, objective=Logloss, task_type=GPU; total time=   1.4s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.5, n_estimators=10, objective=Logloss, task_type=GPU; total time=   1.2s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.5, n_estimators=10, objective=Logloss, task_type=GPU; total time=   1.3s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.5, n_estimators=10, objective=Logloss, task_type=GPU; total time=   1.2s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.5, n_estimators=10, objective=Logloss, task_type=GPU; total time=   1.2s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.5, n_estimators=50, objective=Logloss, task_type=GPU; total time=   3.3s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.5, n_estimators=50, objective=Logloss, task_type=GPU; total time=   3.3s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.5, n_estimators=50, objective=Logloss, task_type=GPU; total time=   3.4s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.5, n_estimators=50, objective=Logloss, task_type=GPU; total time=   3.5s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.5, n_estimators=50, objective=Logloss, task_type=GPU; total time=   3.9s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.5, n_estimators=100, objective=Logloss, task_type=GPU; total time=   6.2s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.5, n_estimators=100, objective=Logloss, task_type=GPU; total time=   6.2s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.5, n_estimators=100, objective=Logloss, task_type=GPU; total time=   6.2s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.5, n_estimators=100, objective=Logloss, task_type=GPU; total time=   6.1s
# [CV] END boosting_type=Ordered, bootstrap_type=Bayesian, gpu_cat_features_storage=CpuPinnedMemory, grow_policy=SymmetricTree, learning_rate=0.5, n_estimators=100, objective=Logloss, task_type=GPU; total time=   6.0s
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 1       3.404973      0.116341         0.180998        0.018840
# 4       3.304794      0.101144         0.165001        0.009146
# 6       1.142595      0.032131         0.165807        0.004995
#
#   param_boosting_type param_bootstrap_type param_gpu_cat_features_storage  \
# 1             Ordered             Bayesian                CpuPinnedMemory
# 4             Ordered             Bayesian                CpuPinnedMemory
# 6             Ordered             Bayesian                CpuPinnedMemory
#
#   param_grow_policy param_learning_rate param_n_estimators  ...  \
# 1     SymmetricTree                 0.1                 50  ...
# 4     SymmetricTree                 0.2                 50  ...
# 6     SymmetricTree                 0.3                 10  ...
#
#   mean_test_roc_auc std_test_roc_auc rank_test_roc_auc  split0_train_roc_auc  \
# 1          0.997908         0.001001                 3              0.999384
# 4          0.998144         0.001337                 1              0.999805
# 6          0.997339         0.000651                10              0.998894
#
#    split1_train_roc_auc  split2_train_roc_auc  split3_train_roc_auc  \
# 1              0.999803              0.999518              0.999672
# 4              0.999895              0.999713              0.999771
# 6              0.999121              0.998821              0.999189
#
#    split4_train_roc_auc  mean_train_roc_auc  std_train_roc_auc
# 1              0.999866            0.999648           0.000178
# 4              0.999648            0.999767           0.000084
# 6              0.999310            0.999067           0.000183
#
# [3 rows x 73 columns]
# 327.170403

# %%
print_to_file("CATB_TB", tb_tuner.best_params_)
cv_results = pd.DataFrame.from_dict(tb_tuner.cv_results_)
cv_results.to_csv(f"./Outputs/CATB/{OUTPUT_FILENAME}_CATB_TB_Tune_CVRes.csv")
display(cv_results)
plot_search_results(tb_tuner, cv_results, 'TB')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        1.225399      0.232799         0.165600        0.010072
# 1        3.404973      0.116341         0.180998        0.018840
# 2        5.878589      0.188110         0.157006        0.001670
# 3        1.063402      0.024563         0.159806        0.000743
# 4        3.304794      0.101144         0.165001        0.009146
# 5        6.396979      0.249602         0.166670        0.013692
# 6        1.142595      0.032131         0.165807        0.004995
# 7        3.431189      0.077498         0.202401        0.028309
# 8        5.947200      0.198921         0.165200        0.007224
# 9        1.101789      0.046572         0.166609        0.010816
# 10       3.223384      0.040593         0.163222        0.003641
# 11       6.118133      0.132126         0.175242        0.012558
# 12       1.181196      0.069405         0.168203        0.007306
# 13       3.410773      0.217684         0.169608        0.005639
# 14       6.077937      0.064499         0.170024        0.009882
#
#    param_boosting_type param_bootstrap_type param_gpu_cat_features_storage  \
# 0              Ordered             Bayesian                CpuPinnedMemory
# 1              Ordered             Bayesian                CpuPinnedMemory
# 2              Ordered             Bayesian                CpuPinnedMemory
# 3              Ordered             Bayesian                CpuPinnedMemory
# 4              Ordered             Bayesian                CpuPinnedMemory
# 5              Ordered             Bayesian                CpuPinnedMemory
# 6              Ordered             Bayesian                CpuPinnedMemory
# 7              Ordered             Bayesian                CpuPinnedMemory
# 8              Ordered             Bayesian                CpuPinnedMemory
# 9              Ordered             Bayesian                CpuPinnedMemory
# 10             Ordered             Bayesian                CpuPinnedMemory
# 11             Ordered             Bayesian                CpuPinnedMemory
# 12             Ordered             Bayesian                CpuPinnedMemory
# 13             Ordered             Bayesian                CpuPinnedMemory
# 14             Ordered             Bayesian                CpuPinnedMemory
#
#    param_grow_policy param_learning_rate param_n_estimators  ...  \
# 0      SymmetricTree                 0.1                 10  ...
# 1      SymmetricTree                 0.1                 50  ...
# 2      SymmetricTree                 0.1                100  ...
# 3      SymmetricTree                 0.2                 10  ...
# 4      SymmetricTree                 0.2                 50  ...
# 5      SymmetricTree                 0.2                100  ...
# 6      SymmetricTree                 0.3                 10  ...
# 7      SymmetricTree                 0.3                 50  ...
# 8      SymmetricTree                 0.3                100  ...
# 9      SymmetricTree                 0.4                 10  ...
# 10     SymmetricTree                 0.4                 50  ...
# 11     SymmetricTree                 0.4                100  ...
# 12     SymmetricTree                 0.5                 10  ...
# 13     SymmetricTree                 0.5                 50  ...
# 14     SymmetricTree                 0.5                100  ...
#
#    mean_test_roc_auc std_test_roc_auc rank_test_roc_auc  split0_train_roc_auc  \
# 0           0.997449         0.001455                 8              0.999023
# 1           0.997908         0.001001                 3              0.999384
# 2           0.997863         0.001196                 4              0.999718
# 3           0.997495         0.001274                 7              0.999027
# 4           0.998144         0.001337                 1              0.999805
# 5           0.997986         0.001470                 2              0.999950
# 6           0.997339         0.000651                10              0.998894
# 7           0.997655         0.001186                 5              0.999757
# 8           0.997607         0.001250                 6              0.999976
# 9           0.996616         0.001172                14              0.999064
# 10          0.997207         0.001948                12              0.999902
# 11          0.997280         0.002211                11              0.999886
# 12          0.996544         0.001208                15              0.998280
# 13          0.997204         0.001568                13              0.999622
# 14          0.997439         0.001647                 9              0.999645
#
#     split1_train_roc_auc  split2_train_roc_auc  split3_train_roc_auc  \
# 0               0.998749              0.998929              0.998827
# 1               0.999803              0.999518              0.999672
# 2               0.999957              0.999484              0.999942
# 3               0.998703              0.999101              0.999499
# 4               0.999895              0.999713              0.999771
# 5               0.999969              0.999606              0.999978
# 6               0.999121              0.998821              0.999189
# 7               0.999753              0.999424              0.999825
# 8               0.999989              0.999464              0.999970
# 9               0.998855              0.998869              0.999312
# 10              0.999870              0.999301              0.999921
# 11              0.999988              0.999580              0.999998
# 12              0.998549              0.998672              0.999626
# 13              0.999983              0.999474              0.999827
# 14              0.999990              0.999480              0.999992
#
#     split4_train_roc_auc  mean_train_roc_auc  std_train_roc_auc
# 0               0.999276            0.998961           0.000183
# 1               0.999866            0.999648           0.000178
# 2               0.999947            0.999810           0.000186
# 3               0.999208            0.999107           0.000258
# 4               0.999648            0.999767           0.000084
# 5               0.999948            0.999890           0.000142
# 6               0.999310            0.999067           0.000183
# 7               0.999790            0.999710           0.000145
# 8               0.999953            0.999870           0.000204
# 9               0.999331            0.999086           0.000206
# 10              0.999544            0.999708           0.000246
# 11              0.999671            0.999825           0.000170
# 12              0.999184            0.998862           0.000482
# 13              0.999954            0.999772           0.000196
# 14              0.999991            0.999820           0.000216
#
# [15 rows x 73 columns]

# %%
logging("\n")
