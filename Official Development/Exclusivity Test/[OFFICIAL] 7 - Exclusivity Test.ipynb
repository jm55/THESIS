# %% [markdown]
# # Dataset Exclusion Generator
#
# This notebook generates the datasets of the following variation(s):
# - Dataset whose malware and benign samples contain at least 1 API Call that is exclusive to each (for training and testing)

# %% [markdown]
# ## 1. Import Dataset

# %%
from joblib import load
import numpy as np
import warnings
warnings.filterwarnings('ignore')

#Load list of API calls
API_LIST = "../Dataset/api_calls.txt"
DELIMITER = "NaN"
API_FILE = open(API_LIST,"r")
APIS = API_FILE.readline().split(',')
APIS.append(DELIMITER) #serves as a label for NaN values for Instance-based datasets
API_FILE.close()

# %%
benign_exclusive = ['CryptProtectMemory','FindFirstFileExA','GetFileVersionInfoExW','GetFileVersionInfoSizeExW','GetUserNameExW','IWbemServices_ExecMethod','listen','NtDeleteFile','NtLoadKey','recvfrom','RegDeleteKeyA','WriteConsoleW']
malicious_exclusive = ['connect','ControlService','CopyFileA','CopyFileExW','CreateJobObjectW','CreateRemoteThread','CreateServiceA','CreateServiceW','CryptDecodeObjectEx','CryptDecrypt','CryptEncrypt','CryptProtectData','DeleteUrlCacheEntryA','DeleteUrlCacheEntryW','DnsQuery_A','EnumServicesStatusA','getaddrinfo','GetAddrInfoW','GetBestInterfaceEx','GetDiskFreeSpaceW','gethostbyname','GetUserNameExA','HttpOpenRequestA','HttpOpenRequestW','HttpQueryInfoA','HttpSendRequestA','InternetCloseHandle','InternetConnectA','InternetConnectW','InternetCrackUrlA','InternetGetConnectedState','InternetOpenA','InternetOpenUrlA','InternetOpenUrlW','InternetOpenW','InternetQueryOptionA','InternetReadFile','InternetSetStatusCallback','MoveFileWithProgressW','NtGetContextThread','NtReadVirtualMemory','NtSetContextThread','NtSuspendThread','NtTerminateThread','NtWriteVirtualMemory','ObtainUserAgentString','OpenSCManagerA','OpenServiceA','recv','RegDeleteKeyW','RtlDecompressBuffer','RtlRemoveVectoredExceptionHandler','send','SetFileInformationByHandle','SetFileTime','SetInformationJobObject','shutdown','StartServiceA','WSARecv','WSASocketA']

print("# Benign Exclusive APIs:", len(benign_exclusive))
print("# Malicious Exclusive APIs:", len(malicious_exclusive))
# Out:
# # Benign Exclusive APIs: 12
# # Malicious Exclusive APIs: 60

# %%
def complete_validation(df):
    collector = []
    for i in df.columns[1:101]:
        collector += df[i].to_list()
    return len(pd.Series(collector).unique())

# %%
import pandas as pd
df = pd.read_csv('../Dataset/oliveira_labelled_str.csv')
df
print(f"Raw Dataset (wo False Labelled Malicious Samples) Unique APIs: {complete_validation(df)}/307")
# Out:
# Raw Dataset (wo False Labelled Malicious Samples) Unique APIs: 260/307

# %% [markdown]
# It turns out that the real number of API Calls in use by the samples is only **260 out of 307** which indicates that the end product dataset of the dataset's author had changes when they initially made it and when it was released for public use.

# %%
#Loading existing test data (mixed)
lgbm_test = pd.read_csv("../Dataset/TB/LGBM_TB_Test.csv")
catb_test = pd.read_csv("../Dataset/TB/CATB_TB_Test.csv")

print(f"Original Training Dataset Unique APIs: {complete_validation(pd.read_csv('../Dataset/TB/CATB_TB.csv'))}/260")
print(f"Original Test Dataset Unique APIs: {complete_validation(pd.read_csv('../Dataset/TB/CATB_TB_Test.csv'))}/260")
# Out:
# Original Training Dataset Unique APIs: 259/260
# Original Test Dataset Unique APIs: 222/260

# %% [markdown]
# ## 2. How many are samples that contain at least 1 of its exclusive API Call?

# %%
def count_sample_exclusive(exclusive:list, malware:int):
    size = df[df['malware']==malware].shape[0]
    total = 0
    for x in exclusive:
        matches = df[df['malware']==malware]['pattern'].str.contains(x)
        raw_types = df[df['malware']==malware][df['pattern'].str.contains(x)]['type'].value_counts()
        types = ""
        for r in range(len(raw_types)):
            types += f"{raw_types.index.to_list()[r]} ({raw_types.to_list()[r]}) "
        print(f"{x:36s} {len(matches[matches==True]):4d} | {types}")
        total += len(matches[matches==True])
    print("")
    label = "Malicious"
    if malware == 0:
        label = "Benign"
    #print(f"{label} Samples with at least 1 Exclusive {label} API Call: {total} ({total/size*100:.4f}% of {label} samples)")

# %%
count_sample_exclusive(malicious_exclusive, 1)
# Out:
# connect                               190 | adware (103) trojan (62) pua (24) downloader (1)
# ControlService                          1 | trojan (1)
# CopyFileA                             108 | trojan (97) miner (8) virus (2) worm (1)
# CopyFileExW                            30 | trojan (28) pua (2)
# CreateJobObjectW                       32 | trojan (27) pua (3) adware (2)
# CreateRemoteThread                      2 | trojan (2)
# CreateServiceA                         35 | trojan (34) virus (1)
# CreateServiceW                          9 | trojan (9)
# CryptDecodeObjectEx                     2 | trojan (1) downloader (1)
# CryptDecrypt                         3001 | trojan (2551) pua (233) adware (120) downloader (97)
# CryptEncrypt                           39 | trojan (39)
# CryptProtectData                       27 | trojan (27)
# DeleteUrlCacheEntryA                    8 | trojan (6) miner (1) pua (1)
# DeleteUrlCacheEntryW                   22 | pua (20) trojan (2)
# DnsQuery_A                              9 | trojan (9)
# EnumServicesStatusA                     2 | trojan (2)
# getaddrinfo                           210 | adware (136) trojan (61) pua (10) downloader (1) miner (1) ransomware (1)
# GetAddrInfoW                            2 | trojan (2)
# GetBestInterfaceEx                     24 | trojan (24)
# GetDiskFreeSpaceW                      86 | trojan (77) adware (4) pua (3) ransomware (1) miner (1)
# gethostbyname                          63 | trojan (44) pua (18) adware (1)
# GetUserNameExA                          3 | trojan (3)
# HttpOpenRequestA                      189 | trojan (187) adware (2)
# HttpOpenRequestW                       30 | pua (19) trojan (8) adware (2) virus (1)
# HttpQueryInfoA                          2 | trojan (2)
# HttpSendRequestA                       15 | trojan (15)
# InternetCloseHandle                    24 | trojan (24)
# InternetConnectA                      205 | trojan (194) adware (7) downloader (2) pua (2)
# InternetConnectW                       30 | pua (19) trojan (8) adware (2) virus (1)
# InternetCrackUrlA                      65 | trojan (54) adware (7) downloader (2) pua (2)
# InternetGetConnectedState               3 | trojan (3)
# InternetOpenA                         264 | trojan (249) adware (7) downloader (3) pua (3) miner (1) virus (1)
# InternetOpenUrlA                        9 | trojan (9)
# InternetOpenUrlW                        1 | trojan (1)
# InternetOpenW                          46 | trojan (22) pua (21) adware (2) virus (1)
# InternetQueryOptionA                    3 | trojan (3)
# InternetReadFile                        2 | trojan (2)
# InternetSetStatusCallback               1 | trojan (1)
# MoveFileWithProgressW                 176 | trojan (125) pua (41) adware (7) miner (2) ransomware (1)
# NtGetContextThread                     49 | trojan (47) miner (2)
# NtReadVirtualMemory                     5 | trojan (3) miner (2)
# NtSetContextThread                     34 | trojan (33) miner (1)
# NtSuspendThread                        21 | trojan (21)
# NtTerminateThread                      21 | ransomware (19) trojan (2)
# NtWriteVirtualMemory                    6 | trojan (4) miner (2)
# ObtainUserAgentString                   1 | trojan (1)
# OpenSCManagerA                        179 | trojan (168) adware (4) pua (3) downloader (2) virus (2)
# OpenServiceA                          143 | trojan (135) pua (3) downloader (2) adware (2) virus (1)
# recv                                   13 | trojan (12) pua (1)
# RegDeleteKeyW                           4 | trojan (1) downloader (1) pua (1) adware (1)
# RtlDecompressBuffer                    16 | trojan (16)
# RtlRemoveVectoredExceptionHandler       2 | trojan (2)
# send                                   37 | trojan (22) pua (15)
# SetFileInformationByHandle              1 | trojan (1)
# SetFileTime                           115 | trojan (94) pua (15) adware (5) miner (1)
# SetInformationJobObject                 1 | trojan (1)
# shutdown                               12 | pua (10) trojan (2)
# StartServiceA                          42 | trojan (41) virus (1)
# WSARecv                                15 | pua (11) trojan (4)
# WSASocketA                              1 | trojan (1)

# %%
count_sample_exclusive(benign_exclusive,0)
# Out:
# CryptProtectMemory                      1 | benign (1)
# FindFirstFileExA                        3 | benign (3)
# GetFileVersionInfoExW                   2 | benign (2)
# GetFileVersionInfoSizeExW               2 | benign (2)
# GetUserNameExW                          2 | benign (2)
# IWbemServices_ExecMethod                1 | benign (1)
# listen                                  2 | benign (2)
# NtDeleteFile                            1 | benign (1)
# NtLoadKey                               1 | benign (1)
# recvfrom                                1 | benign (1)
# RegDeleteKeyA                           2 | benign (2)
# WriteConsoleW                          16 | benign (16)

# %% [markdown]
# ## 3. Dataset Exclusivity Filtering

# %%
def filter_sample_exclusive():
    global benign_exclusive
    global malicious_excusive
    exclusive_df = None
    for x in benign_exclusive:
        exclusive_df = pd.concat([exclusive_df, df[df['pattern'].str.contains(x)]], axis=0)
    for x in malicious_exclusive:
        exclusive_df = pd.concat([exclusive_df, df[df['pattern'].str.contains(x)]], axis=0)
    exclusive_df.drop_duplicates(subset=['hash'], inplace=True, keep='first')
    remaining_df = pd.concat([exclusive_df, df], axis=0)
    remaining_df.drop_duplicates(subset=['hash'], inplace=True, keep=False)
    return exclusive_df, remaining_df

# %% [markdown]
# ## 4. Dataset whose Malware and Benign samples contain at least 1 API Call exclusive to Malicious and Benign samples (for training & testing)

# %%
exclusive_str, remaining_str = filter_sample_exclusive()

# %%
print(f"# of samples that qualifies as \"Exclusive\": {exclusive_str.shape[0]} ({exclusive_str.shape[0]/df.shape[0]*100:.4f}%)")
print(f"# of samples that do not qualify as \"Exclusive\": {remaining_str.shape[0]} ({remaining_str.shape[0]/df.shape[0]*100:.4f}%)")
# Out:
# # of samples that qualifies as "Exclusive": 4289 (10.4006%)
# # of samples that do not qualify as "Exclusive": 36936 (89.5679%)

# %%
print("Composition of samples that contain at least 1 API Call exclusive to it: ", exclusive_str['type'].value_counts())
print("\n")
display(exclusive_str)
display(remaining_str)
# Out:
# Composition of samples that contain at least 1 API Call exclusive to it:  type
# trojan        3498
# pua            333
# adware         282
# downloader     103
# benign          31
# ransomware      22
# miner           14
# virus            5
# worm             1
# Name: count, dtype: int64
#                                    hash                      t_0  \
# 10799  c662cc346f4c041ee954b9a4333ed28d  GetSystemTimeAsFileTime
# 4489   3e122e753cd94f004797b3b4dddba96a  GetSystemTimeAsFileTime
# 22078  204113cdf14320ee9db1f88a62a48019  GetSystemTimeAsFileTime
# 37148  00a1b66bd25adb59460871ee40e6ebc0  GetSystemTimeAsFileTime
# 16397  59147b8b8abf9768ca96badfd91d7bb9  GetSystemTimeAsFileTime
# ...                                 ...                      ...
# 39222  a9009a2935ed87db57d544e28a99510b  GetSystemTimeAsFileTime
# 39382  a3b81a0902ddbaccd03413c90b255387  GetSystemTimeAsFileTime
# 40301  e501a7d4d95d9a87027be637376a329e  NtAllocateVirtualMemory
# 40645  5d9c5d82d8070ef29ed745c15b1c0989  NtAllocateVirtualMemory
# 33305  438640515058a2d5e92bdae3c382ac52  GetSystemTimeAsFileTime
#
#                                t_1                         t_2  \
# 10799                   LdrLoadDll      LdrGetProcedureAddress
# 4489   SetUnhandledExceptionFilter     NtAllocateVirtualMemory
# 22078  SetUnhandledExceptionFilter     NtAllocateVirtualMemory
# 37148  SetUnhandledExceptionFilter  GetSystemWindowsDirectoryW
# 16397  SetUnhandledExceptionFilter     NtAllocateVirtualMemory
# ...                            ...                         ...
# 39222              LdrGetDllHandle      LdrGetProcedureAddress
# 39382                   LdrLoadDll      LdrGetProcedureAddress
# 40301                 SetErrorMode                 LoadStringA
# 40645                 SetErrorMode                 LoadStringA
# 33305      NtAllocateVirtualMemory         NtFreeVirtualMemory
#
#                                t_3                      t_4  \
# 10799                   LdrLoadDll   LdrGetProcedureAddress
# 4489                   timeGetTime  NtAllocateVirtualMemory
# 22078                  timeGetTime  NtAllocateVirtualMemory
# 37148      NtAllocateVirtualMemory      GetSystemDirectoryW
# 16397                   LdrLoadDll   LdrGetProcedureAddress
# ...                            ...                      ...
# 39222  SetUnhandledExceptionFilter          FindResourceExW
# 39382                   LdrLoadDll   LdrGetProcedureAddress
# 40301                OleInitialize               LdrLoadDll
# 40645                OleInitialize               LdrLoadDll
# 33305      NtAllocateVirtualMemory          LdrGetDllHandle
#
#                           t_5                         t_6  \
# 10799              LdrLoadDll      LdrGetProcedureAddress
# 4489               LdrLoadDll                LdrUnloadDll
# 22078             timeGetTime     GetSystemTimeAsFileTime
# 37148           RegOpenKeyExA  GetSystemWindowsDirectoryW
# 16397                 NtClose                   NtOpenKey
# ...                       ...                         ...
# 39222             SetFileTime             FindResourceExW
# 39382              LdrLoadDll      LdrGetProcedureAddress
# 40301  LdrGetProcedureAddress     NtAllocateVirtualMemory
# 40645  LdrGetProcedureAddress     NtAllocateVirtualMemory
# 33305  LdrGetProcedureAddress             LdrGetDllHandle
#
#                            t_7                         t_8  ...  \
# 10799               LdrLoadDll      LdrGetProcedureAddress  ...
# 4489              NtCreateFile                 GetFileType  ...
# 22078  NtAllocateVirtualMemory                NtCreateFile  ...
# 37148              LoadStringW  GetSystemWindowsDirectoryW  ...
# 16397          NtQueryValueKey                     NtClose  ...
# ...                        ...                         ...  ...
# 39222    NtOpenDirectoryObject             FindResourceExW  ...
# 39382               LdrLoadDll      LdrGetProcedureAddress  ...
# 40301      NtFreeVirtualMemory     NtAllocateVirtualMemory  ...
# 40645      NtFreeVirtualMemory     NtAllocateVirtualMemory  ...
# 33305   LdrGetProcedureAddress             LdrGetDllHandle  ...
#
#                           t_93                  t_94                    t_95  \
# 10799  NtAllocateVirtualMemory  GetFileAttributesExW            NtCreateFile
# 4489                   NtClose      FindFirstFileExA                 NtClose
# 22078                  NtClose      FindFirstFileExA                 NtClose
# 37148                  NtClose      FindFirstFileExA                 NtClose
# 16397   LdrGetProcedureAddress       LdrGetDllHandle  LdrGetProcedureAddress
# ...                        ...                   ...                     ...
# 39222      NtFreeVirtualMemory               NtClose              NtOpenFile
# 39382             GetTempPathW           SearchPathW            GetTempPathW
# 40301  NtAllocateVirtualMemory         RegOpenKeyExW         LdrGetDllHandle
# 40645            FindResourceA           LoadStringA              LdrLoadDll
# 33305          NtQueryValueKey               NtClose               NtOpenKey
#
#                          t_96                     t_97  \
# 10799     NtFreeVirtualMemory              GetFileType
# 4489         FindFirstFileExA                  NtClose
# 22078            NtCreateFile              GetFileType
# 37148        FindFirstFileExA                  NtClose
# 16397         LdrGetDllHandle   LdrGetProcedureAddress
# ...                       ...                      ...
# 39222  NtQueryInformationFile  NtAllocateVirtualMemory
# 39382             SearchPathW             GetTempPathW
# 40301         FindResourceExW             LoadResource
# 40645  LdrGetProcedureAddress            __exception__
# 33305         NtQueryValueKey                  NtClose
#
#                           t_98                    t_99 malware    type  \
# 10799                  NtClose             DeleteFileW       0  benign
# 4489          FindFirstFileExA                 NtClose       0  benign
# 22078  NtAllocateVirtualMemory              NtReadFile       0  benign
# 37148         FindFirstFileExA                 NtClose       0  benign
# 16397          LdrGetDllHandle  LdrGetProcedureAddress       0  benign
# ...                        ...                     ...     ...     ...
# 39222               NtReadFile     NtFreeVirtualMemory       1  trojan
# 39382              SearchPathW            GetTempPathW       1  trojan
# 40301          FindResourceExW            LoadResource       1  trojan
# 40645          FindResourceExA           FindResourceA       1  trojan
# 33305                NtOpenKey         NtQueryValueKey       1  trojan
#
#                                                  pattern
# 10799  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 4489   GetSystemTimeAsFileTime,SetUnhandledExceptionF...
# 22078  GetSystemTimeAsFileTime,SetUnhandledExceptionF...
# 37148  GetSystemTimeAsFileTime,SetUnhandledExceptionF...
# 16397  GetSystemTimeAsFileTime,SetUnhandledExceptionF...
# ...                                                  ...
# 39222  GetSystemTimeAsFileTime,LdrGetDllHandle,LdrGet...
# 39382  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 40301  NtAllocateVirtualMemory,SetErrorMode,LoadStrin...
# 40645  NtAllocateVirtualMemory,SetErrorMode,LoadStrin...
# 33305  GetSystemTimeAsFileTime,NtAllocateVirtualMemor...
#
# [4289 rows x 104 columns]
#                                    hash                          t_0  \
# 0      071e8c3f8922e186e57548cd4c703a5d                RegOpenKeyExA
# 1      33f8e6d08a6aae939f25a8e0d63dd523      GetSystemTimeAsFileTime
# 2      b68abd064e975e1c6d5f25e748663076  SetUnhandledExceptionFilter
# 4      c9b3700a77facf29172f32df6bc77f48      GetSystemTimeAsFileTime
# 5      cc6217be863e606e49da90fee2252f52       LdrGetProcedureAddress
# ...                                 ...                          ...
# 41233  e3d6d58faa040f0f9742c9d0eaf58be4      GetSystemTimeAsFileTime
# 41234  9b917bab7f32188ae40c744f2be9aaf8      GetSystemTimeAsFileTime
# 41235  35a18ee05f75f04912018d9f462cb990      GetSystemTimeAsFileTime
# 41236  654139d715abcf7ecdddbef5a84f224b      GetSystemTimeAsFileTime
# 41237  078c9d4e7be4819a06974c6f292a4857                RegOpenKeyExA
#
#                            t_1                     t_2  \
# 0                    NtOpenKey         NtQueryValueKey
# 1      NtAllocateVirtualMemory     NtFreeVirtualMemory
# 2                OleInitialize              LdrLoadDll
# 4                   LdrLoadDll  LdrGetProcedureAddress
# 5      NtAllocateVirtualMemory  LdrGetProcedureAddress
# ...                        ...                     ...
# 41233               LdrLoadDll  LdrGetProcedureAddress
# 41234               LdrLoadDll  LdrGetProcedureAddress
# 41235               LdrLoadDll  LdrGetProcedureAddress
# 41236               LdrLoadDll  LdrGetProcedureAddress
# 41237                NtOpenKey         NtQueryValueKey
#
#                            t_3                     t_4  \
# 0                      NtClose               NtOpenKey
# 1      NtAllocateVirtualMemory         LdrGetDllHandle
# 2       LdrGetProcedureAddress              LdrLoadDll
# 4                   LdrLoadDll  LdrGetProcedureAddress
# 5      NtAllocateVirtualMemory  LdrGetProcedureAddress
# ...                        ...                     ...
# 41233               LdrLoadDll  LdrGetProcedureAddress
# 41234               LdrLoadDll  LdrGetProcedureAddress
# 41235               LdrLoadDll  LdrGetProcedureAddress
# 41236               LdrLoadDll  LdrGetProcedureAddress
# 41237                  NtClose               NtOpenKey
#
#                           t_5                     t_6                     t_7  \
# 0             NtQueryValueKey                 NtClose   NtQueryAttributesFile
# 1      LdrGetProcedureAddress         LdrGetDllHandle  LdrGetProcedureAddress
# 2      LdrGetProcedureAddress              LdrLoadDll  LdrGetProcedureAddress
# 4                  LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 5                  LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# ...                       ...                     ...                     ...
# 41233              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 41234              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 41235              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 41236              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 41237         NtQueryValueKey                 NtClose   NtQueryAttributesFile
#
#                           t_8  ...                     t_93  \
# 0                 LoadStringA  ...          NtCreateSection
# 1             LdrGetDllHandle  ...   LdrGetProcedureAddress
# 2                  LdrLoadDll  ...         RegQueryValueExA
# 4      LdrGetProcedureAddress  ...         RegQueryInfoKeyW
# 5      LdrGetProcedureAddress  ...            RegOpenKeyExW
# ...                       ...  ...                      ...
# 41233  LdrGetProcedureAddress  ...         RegQueryValueExW
# 41234  LdrGetProcedureAddress  ...  GetSystemTimeAsFileTime
# 41235  LdrGetProcedureAddress  ...            RegOpenKeyExW
# 41236  LdrGetProcedureAddress  ...         RegQueryValueExW
# 41237             LoadStringA  ...          NtCreateSection
#
#                              t_94              t_95  \
# 0              NtMapViewOfSection           NtClose
# 1      GetSystemWindowsDirectoryW      NtCreateFile
# 2                     RegCloseKey     RegOpenKeyExA
# 4                   RegEnumKeyExW     RegOpenKeyExW
# 5                RegQueryValueExW       RegCloseKey
# ...                           ...               ...
# 41233               RegOpenKeyExW  RegQueryValueExW
# 41234            NtDelayExecution       EnumWindows
# 41235            RegQueryValueExW     RegOpenKeyExW
# 41236               RegOpenKeyExW  RegQueryValueExW
# 41237          NtMapViewOfSection           NtClose
#
#                                     t_96                     t_97  \
# 0                       GetSystemMetrics  NtAllocateVirtualMemory
# 1                        NtCreateSection       NtMapViewOfSection
# 2                       RegQueryValueExA              RegCloseKey
# 4                       RegQueryValueExW            RegOpenKeyExW
# 5      GetVolumeNameForVolumeMountPointW   LdrGetProcedureAddress
# ...                                  ...                      ...
# 41233                      RegOpenKeyExW         RegQueryValueExW
# 41234            GetSystemTimeAsFileTime         NtDelayExecution
# 41235                   RegQueryValueExW            RegOpenKeyExW
# 41236                      RegOpenKeyExW         RegQueryValueExW
# 41237                   GetSystemMetrics  NtAllocateVirtualMemory
#
#                    t_98                        t_99 malware    type  \
# 0         CreateActCtxW  GetSystemWindowsDirectoryW       1  trojan
# 1               NtClose            GetSystemMetrics       1     pua
# 2         RegEnumKeyExA               RegOpenKeyExA       1  trojan
# 4      RegQueryValueExW               RegOpenKeyExW       1  trojan
# 5         RegOpenKeyExW                 RegCloseKey       1  trojan
# ...                 ...                         ...     ...     ...
# 41233     RegOpenKeyExW            RegQueryValueExW       1  trojan
# 41234       EnumWindows     GetSystemTimeAsFileTime       1  trojan
# 41235  RegQueryValueExW               RegOpenKeyExW       1  trojan
# 41236     RegOpenKeyExW            RegQueryValueExW       1  trojan
# 41237     CreateActCtxW  GetSystemWindowsDirectoryW       1  trojan
#
#                                                  pattern
# 0      RegOpenKeyExA,NtOpenKey,NtQueryValueKey,NtClos...
# 1      GetSystemTimeAsFileTime,NtAllocateVirtualMemor...
# 2      SetUnhandledExceptionFilter,OleInitialize,LdrL...
# 4      GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 5      LdrGetProcedureAddress,NtAllocateVirtualMemory...
# ...                                                  ...
# 41233  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 41234  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 41235  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 41236  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 41237  RegOpenKeyExA,NtOpenKey,NtQueryValueKey,NtClos...
#
# [36936 rows x 104 columns]

# %%
def convert(api:str):
    return APIS.index(api)
def ordinal_encode(df):
    global APIS
    for j in range(1,101):
        df.iloc[:,j] = pd.Series(list(map(convert, df.iloc[:,j].to_list())))
    return df

exclusive_enc = ordinal_encode(exclusive_str.copy(deep=True))
remaining_enc = ordinal_encode(remaining_str.copy(deep=True))

# %%
display(exclusive_enc)
display(remaining_enc)
# Out:
#                                    hash  t_0  t_1  t_2  t_3  t_4  t_5  t_6  \
# 10799  c662cc346f4c041ee954b9a4333ed28d   82  240  117  240  117  240  117
# 4489   3e122e753cd94f004797b3b4dddba96a   82   16  208   57  208  240   50
# 22078  204113cdf14320ee9db1f88a62a48019   82   16  208   57  208   57   82
# 37148  00a1b66bd25adb59460871ee40e6ebc0   82   16   71  208  275  112   71
# 16397  59147b8b8abf9768ca96badfd91d7bb9   82   16  208  240  117  215  274
# ...                                 ...  ...  ...  ...  ...  ...  ...  ...
# 39222  a9009a2935ed87db57d544e28a99510b   82  172  117   16   60  234   60
# 39382  a3b81a0902ddbaccd03413c90b255387   82  240  117  240  117  240  117
# 40301  e501a7d4d95d9a87027be637376a329e  208  286   76  110  240  117  208
# 40645  5d9c5d82d8070ef29ed745c15b1c0989  208  286   76  110  240  117  208
# 33305  438640515058a2d5e92bdae3c382ac52   82  208  187  208  172  117  172
#
#        t_7  t_8  ... t_93 t_94 t_95 t_96 t_97 t_98 t_99 malware    type  \
# 10799  240  117  ...  208   73  297  187   93  215  127       0  benign
# 4489   297   93  ...  215  281  215  281  215  281  215       0  benign
# 22078  208  297  ...  215  281  215  297   93  208  264       0  benign
# 37148   25   71  ...  215  281  215  281  215  281  215       0  benign
# 16397  158  215  ...  117  172  117  172  117  172  117       0  benign
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...     ...     ...
# 39222  294   60  ...  187  215   20   34  208  264  187       1  trojan
# 39382  240  117  ...  271   47  271   47  271   47  271       1  trojan
# 40301  187  208  ...  208  260  172   60   81   60   81       1  trojan
# 40645  187  208  ...  111   76  240  117  306  291  111       1  trojan
# 33305  117  172  ...  158  215  274  158  215  274  158       1  trojan
#
#                                                  pattern
# 10799  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 4489   GetSystemTimeAsFileTime,SetUnhandledExceptionF...
# 22078  GetSystemTimeAsFileTime,SetUnhandledExceptionF...
# 37148  GetSystemTimeAsFileTime,SetUnhandledExceptionF...
# 16397  GetSystemTimeAsFileTime,SetUnhandledExceptionF...
# ...                                                  ...
# 39222  GetSystemTimeAsFileTime,LdrGetDllHandle,LdrGet...
# 39382  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 40301  NtAllocateVirtualMemory,SetErrorMode,LoadStrin...
# 40645  NtAllocateVirtualMemory,SetErrorMode,LoadStrin...
# 33305  GetSystemTimeAsFileTime,NtAllocateVirtualMemor...
#
# [4289 rows x 104 columns]
#                                    hash  t_0  t_1  t_2  t_3  t_4  t_5  t_6  \
# 0      071e8c3f8922e186e57548cd4c703a5d  112  274  158  215  274  158  215
# 1      33f8e6d08a6aae939f25a8e0d63dd523   82  208  187  208  172  117  172
# 2      b68abd064e975e1c6d5f25e748663076   16  110  240  117  240  117  240
# 4      c9b3700a77facf29172f32df6bc77f48   82  240  117  240  117  240  117
# 5      cc6217be863e606e49da90fee2252f52  117  208  117  208  117  240  117
# ...                                 ...  ...  ...  ...  ...  ...  ...  ...
# 41233  e3d6d58faa040f0f9742c9d0eaf58be4   82  240  117  240  117  240  117
# 41234  9b917bab7f32188ae40c744f2be9aaf8   82  240  117  240  117  240  117
# 41235  35a18ee05f75f04912018d9f462cb990   82  240  117  240  117  240  117
# 41236  654139d715abcf7ecdddbef5a84f224b   82  240  117  240  117  240  117
# 41237  078c9d4e7be4819a06974c6f292a4857  112  274  158  215  274  158  215
#
#        t_7  t_8  ... t_93 t_94 t_95 t_96 t_97 t_98 t_99 malware    type  \
# 0      298   76  ...  135  171  215   35  208   56   71       1  trojan
# 1      117  172  ...  117   71  297  135  171  215   35       1     pua
# 2      117  240  ...  123   65  112  123   65  113  112       1  trojan
# 4      240  117  ...   40  209  260  141  260  141  260       1  trojan
# 5      240  117  ...  260  141   65    9  117  260   65       1  trojan
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...     ...     ...
# 41233  240  117  ...  141  260  141  260  141  260  141       1  trojan
# 41234  240  117  ...   82  159  224   82  159  224   82       1  trojan
# 41235  240  117  ...  260  141  260  141  260  141  260       1  trojan
# 41236  240  117  ...  141  260  141  260  141  260  141       1  trojan
# 41237  298   76  ...  135  171  215   35  208   56   71       1  trojan
#
#                                                  pattern
# 0      RegOpenKeyExA,NtOpenKey,NtQueryValueKey,NtClos...
# 1      GetSystemTimeAsFileTime,NtAllocateVirtualMemor...
# 2      SetUnhandledExceptionFilter,OleInitialize,LdrL...
# 4      GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 5      LdrGetProcedureAddress,NtAllocateVirtualMemory...
# ...                                                  ...
# 41233  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 41234  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 41235  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 41236  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 41237  RegOpenKeyExA,NtOpenKey,NtQueryValueKey,NtClos...
#
# [36936 rows x 104 columns]

# %%
# Validate if the contents of the dataset contain all 307 unique API Calls originally from the raw dataset (exclude 'NaN').
print(f"Exclusive Dataset: {complete_validation(exclusive_enc)}/260")
print(f"Common Dataset: {complete_validation(remaining_enc)}/260")
# Out:
# Exclusive Dataset: 248/260
# Common Dataset: 184/260

# %% [markdown]
# ## 5. Training on these datasets

# %%
import lightgbm as lgbm
import catboost as catb
import sklearn.metrics as metrics
from sklearn.model_selection import train_test_split

def get_indexes(numeric=False):
    indexes = []
    if numeric:
        for i in range(100):
            indexes.append(i)
    else:
        for i in range(100):
            indexes.append(f"t_{i}")
    return indexes

lgbm_model = lgbm.LGBMClassifier(random_state=1, n_jobs=0, verbose=-1, categorical_feature=get_indexes(True),
                                 boost_from_average=True, boosting_type='gbdt', class_weight='balanced', 
                                 data_sample_strategy='goss', enable_bundle=True, 
                                 objective='binary', tree_learner='feature', device='gpu')
catb_model = catb.CatBoostClassifier(random_state=1, thread_count=-1, verbose=0, cat_features=get_indexes(), 
                                     nan_mode='Min', one_hot_max_size=256,
                                     boosting_type='Ordered', bootstrap_type='Bayesian', 
                                     grow_policy='SymmetricTree', objective='Logloss', task_type='GPU')

# %%
def exclusivity_train_test(model, train:pd.DataFrame, test:pd.DataFrame, encoded:bool, model_name, test_ratio):
    print(f"{model_name}\n")
    X_train, X_test, y_train, y_test = train_test_split(train.iloc[:,1:101], train['malware'], test_size=test_ratio, random_state=1)
    test_feat = test.iloc[:, 1:101]
    if encoded:
        X_train, X_test, y_train, y_test = train_test_split(train.iloc[:,1:101].astype('int64'), train['malware'], test_size=test_ratio, random_state=1)
        test_feat = test.iloc[:, 1:101].astype('int64')
        X_test = X_test.astype('int64')
        y_test = y_test.astype('int64')
        X_train = X_train.astype('int64')
        y_train = y_train.astype('int64')
    model.fit(X_train, y_train)
    y_pred_a = model.predict(X_test)
    y_pred_b = model.predict(test_feat)
    print(f"Testing on Test Split ({test_ratio*100:.0f}%) of Training Data:\n", 
          metrics.classification_report(y_test, y_pred_a, digits=4),
          f"\nROC_AUC: {metrics.roc_auc_score(y_test, y_pred_a):.4f}\n")
    print("Testing on \"External\" Test Dataset:\n", 
          metrics.classification_report(test['malware'], y_pred_b, digits=4),
          f"\nROC_AUC: {metrics.roc_auc_score(test['malware'], y_pred_b):.4f}\n")

# %%
exclusivity_train_test(lgbm_model, exclusive_enc, remaining_enc, True, "LightGBM", 0.10)
# Out:
# LightGBM
#
# Testing on Test Split (10%) of Training Data:
#                precision    recall  f1-score   support
#
#            0     0.7500    0.7500    0.7500         4
#            1     0.9976    0.9976    0.9976       425
#
#     accuracy                         0.9953       429
#    macro avg     0.8738    0.8738    0.8738       429
# weighted avg     0.9953    0.9953    0.9953       429
#
# ROC_AUC: 0.8738
#
# Testing on "External" Test Dataset:
#                precision    recall  f1-score   support
#
#            0     0.8667    0.1005    0.1801      1035
#            1     0.9747    0.9996    0.9870     35901
#
#     accuracy                         0.9744     36936
#    macro avg     0.9207    0.5500    0.5835     36936
# weighted avg     0.9717    0.9744    0.9644     36936
#
# ROC_AUC: 0.5500

# %%
exclusivity_train_test(lgbm_model, exclusive_enc, lgbm_test, True, "LightGBM", 0.10)
# Out:
# LightGBM
#
# Testing on Test Split (10%) of Training Data:
#                precision    recall  f1-score   support
#
#            0     0.7500    0.7500    0.7500         4
#            1     0.9976    0.9976    0.9976       425
#
#     accuracy                         0.9953       429
#    macro avg     0.8738    0.8738    0.8738       429
# weighted avg     0.9953    0.9953    0.9953       429
#
# ROC_AUC: 0.8738
#
# Testing on "External" Test Dataset:
#                precision    recall  f1-score   support
#
#            0     0.9231    0.1062    0.1905       113
#            1     0.9754    0.9998    0.9874      4011
#
#     accuracy                         0.9753      4124
#    macro avg     0.9493    0.5530    0.5890      4124
# weighted avg     0.9740    0.9753    0.9656      4124
#
# ROC_AUC: 0.5530

# %%
exclusivity_train_test(catb_model, exclusive_str, remaining_str, False, "CatBoost", 0.10)
# Out:
# CatBoost
#
# Testing on Test Split (10%) of Training Data:
#                precision    recall  f1-score   support
#
#            0     0.6667    1.0000    0.8000         4
#            1     1.0000    0.9953    0.9976       425
#
#     accuracy                         0.9953       429
#    macro avg     0.8333    0.9976    0.8988       429
# weighted avg     0.9969    0.9953    0.9958       429
#
# ROC_AUC: 0.9976
#
# Testing on "External" Test Dataset:
#                precision    recall  f1-score   support
#
#            0     0.7580    0.1604    0.2648      1035
#            1     0.9763    0.9985    0.9873     35901
#
#     accuracy                         0.9750     36936
#    macro avg     0.8672    0.5795    0.6260     36936
# weighted avg     0.9702    0.9750    0.9671     36936
#
# ROC_AUC: 0.5795

# %%
exclusivity_train_test(catb_model, exclusive_str, catb_test, False, "CatBoost", 0.10)
# Out:
# CatBoost
#
# Testing on Test Split (10%) of Training Data:
#                precision    recall  f1-score   support
#
#            0     0.6667    1.0000    0.8000         4
#            1     1.0000    0.9953    0.9976       425
#
#     accuracy                         0.9953       429
#    macro avg     0.8333    0.9976    0.8988       429
# weighted avg     0.9969    0.9953    0.9958       429
#
# ROC_AUC: 0.9976
#
# Testing on "External" Test Dataset:
#                precision    recall  f1-score   support
#
#            0     0.8333    0.1770    0.2920       113
#            1     0.9773    0.9990    0.9880      4011
#
#     accuracy                         0.9765      4124
#    macro avg     0.9053    0.5880    0.6400      4124
# weighted avg     0.9734    0.9765    0.9690      4124
#
# ROC_AUC: 0.5880

# %% [markdown]
# ## 6. Predicting on previously trained models
#
# This is to determine if the performance is reliant on the existence of those exclusive API Calls.
#
# As there are no significant differences in terms of performance of the model between time-based and instance-based behaviors, only models trained on time-based behaviors will be tested.

# %%
#Opening existing trained models
lgbm_model = load('../GBDT_Training/Outputs/LGBM/Default/RYZEN3b_LGBM_TB.model') # <== Point these to the respective .model files
catb_model = catb.CatBoostClassifier()
catb_model = catb_model.load_model("../GBDT_Training/Outputs/CATB/Default/RYZEN3b_CATB_TB.model", format='json') # <== Point these to the respective .model files

def existing_models(input_df, model,encoded:bool):
    if encoded:
        y_pred = model.predict(input_df.iloc[:,1:101].astype('int64'))
    else:
        y_pred = model.predict(input_df.iloc[:,1:101])
    print(metrics.classification_report(input_df['malware'], y_pred, digits=4),
          f"\nROC_AUC: {metrics.roc_auc_score(input_df['malware'], y_pred):.4f}\n")

# %% [markdown]
# ### 6.1. Checking performance on mixed input data (i.e., original test data).

# %%
existing_models(lgbm_test, lgbm_model, True)
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9315    0.6018    0.7312       113
#            1     0.9889    0.9988    0.9938      4011
#
#     accuracy                         0.9879      4124
#    macro avg     0.9602    0.8003    0.8625      4124
# weighted avg     0.9873    0.9879    0.9866      4124
#
# ROC_AUC: 0.8003

# %%
existing_models(catb_test, catb_model, False)
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9383    0.6726    0.7835       113
#            1     0.9908    0.9988    0.9948      4011
#
#     accuracy                         0.9898      4124
#    macro avg     0.9646    0.8357    0.8891      4124
# weighted avg     0.9894    0.9898    0.9890      4124
#
# ROC_AUC: 0.8357

# %% [markdown]
# ### 6.2. Checking performance on exclusive and non-exclusive data (i.e., exclusivity data).

# %%
existing_models(exclusive_enc, lgbm_model, True)
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9286    0.8387    0.8814        31
#            1     0.9988    0.9995    0.9992      4258
#
#     accuracy                         0.9984      4289
#    macro avg     0.9637    0.9191    0.9403      4289
# weighted avg     0.9983    0.9984    0.9983      4289
#
# ROC_AUC: 0.9191

# %%
existing_models(remaining_enc, lgbm_model, True)
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9840    0.8329    0.9021      1035
#            1     0.9952    0.9996    0.9974     35901
#
#     accuracy                         0.9949     36936
#    macro avg     0.9896    0.9162    0.9498     36936
# weighted avg     0.9949    0.9949    0.9947     36936
#
# ROC_AUC: 0.9162

# %%
existing_models(exclusive_str, catb_model, False)
# Out:
#               precision    recall  f1-score   support
#
#            0     0.7632    0.9355    0.8406        31
#            1     0.9995    0.9979    0.9987      4258
#
#     accuracy                         0.9974      4289
#    macro avg     0.8813    0.9667    0.9196      4289
# weighted avg     0.9978    0.9974    0.9976      4289
#
# ROC_AUC: 0.9667

# %%
existing_models(remaining_str, catb_model, False)
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9836    0.8135    0.8905      1035
#            1     0.9947    0.9996    0.9971     35901
#
#     accuracy                         0.9944     36936
#    macro avg     0.9891    0.9066    0.9438     36936
# weighted avg     0.9943    0.9944    0.9941     36936
#
# ROC_AUC: 0.9066
