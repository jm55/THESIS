# %% [markdown]
# # Model Comparison
#
# **Objectives**
# - Take note of the results of previous performance tests that used the Holdout Method (i.e., during Model Robustness Test)
# - Using `McNemar Test`, determine any differences between GBDT Models (e.g., LGBM Default vs CatBoost Default), between configurations (e.g., LGBM Default vs LGBM Tuned), and between behavior-types (i.e., Time-based LGBM Tuned vs Time-based CatBoost Tuned)
# - Use whichever dataset is appropriate (probably the Test/Holdout Split).
# - Take note of the results
#
# Assume a `significance level` of **0.05 (5%)** as it was mentioned in RRL relating to Model Comparison (let's just use it the reference no. for significane level).
#
# <hr>
#
# *Kindly double check the statement(s) that will follow:*
#
# Assume null hypothesis as *"there is a significant difference between the two models"*. `<== Modify this accordingly depending on which will be compared (whether if GBDT vs GBDT or Default vs Tuned)`
#
# If the resulting `p-value` is larger than the `significance level`, the null hypothesis is not rejected. Else if otherwise (`p-value` < `significance level`).
#
# Interpretting the resulting array:
# [[a,b]
#  [c,d]]
#
# - a = Both models are correct
# - b = Model 1 wrong, Model 2 correct
# - c = Model 1 correct, Model 2 wrong
# - d = Both models are wrong
#
# References:
# - [https://rasbt.github.io/mlxtend/user_guide/evaluate/mcnemar/](https://rasbt.github.io/mlxtend/user_guide/evaluate/mcnemar/)

# %%
import statsmodels.stats.contingency_tables as statsmodels #mcnemar
import mlxtend.evaluate as mlxtend #mcnemar_table, mcnemar
import pandas as pd
import numpy as np
import lightgbm as lgbm
import catboost as catb
from joblib import load

import warnings
warnings.filterwarnings("ignore")

# %%
DF_LGBM_TB = pd.read_csv('../Dataset/TB/LGBM_TB_Test.csv', low_memory=False) #<== Point these to the proper Test/Holdout datasets.
DF_LGBM_IB = pd.read_csv('../Dataset/IB/LGBM_IB_Test.csv', low_memory=False)
DF_CATB_TB = pd.read_csv('../Dataset/TB/CATB_TB_Test.csv', low_memory=False) #<== Point these to the proper Test/Holdout datasets.
DF_CATB_IB = pd.read_csv('../Dataset/IB/CATB_IB_Test.csv', low_memory=False)
DF_CATB_IB.iloc[:,1:101] = DF_CATB_IB.iloc[:,1:101].astype('str')
DF_CATB_IB.replace("nan", "NaN", inplace=True)

y_target = DF_LGBM_TB['malware'] # <---- labels are equal across all datasets

# %%
display(DF_LGBM_TB)
display(DF_LGBM_IB)
display(DF_CATB_TB)
display(DF_CATB_IB)
# Out:
#       malware  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  t_8  ...  t_92  t_93  \
# 0           1  240  117  240  117  240  117  240  117  240  ...   240   117
# 1           1   82  198   86   82  274   37  240  117  260  ...   274   215
# 2           1  215  208  228  117  228  240  117  228  159  ...   230    35
# 3           1  159  208  260  141   65  208   20   34  215  ...   187   135
# 4           1   82  240  117  240  117  240  117  240  117  ...   260   141
# ...       ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 4119        1  208  228  240  117  240  117   82  240  117  ...   208   172
# 4120        1   82  208  172  117  172  208   16  110  172  ...   279   208
# 4121        1   82  240  117  240  117   93  117   16  147  ...   230   240
# 4122        1  112  274  158  215  274  158  215  298   76  ...   297   135
# 4123        1  198  172  117  275  208  286  208  187  208  ...   228   297
#
#       t_94  t_95  t_96  t_97  t_98  t_99                              hash  \
# 0      240   117   172    60   225    35  0fe987c56cfb02db5d810534d6098d93
# 1      274   158   215    37   158   215  f58d31adac5b879b50ce07a9da086736
# 2      240   117   208    89   225    35  f07d9fa9d2852bd4b7b36f39dd531b4a
# 3      171   262   208   262   187   262  7a493fa07f0f7d0c9e372eedae03036b
# 4      260   141   260   141   260   141  ba60236d9f9fe6cd0a10ffbbf2296669
# ...    ...   ...   ...   ...   ...   ...                               ...
# 4119   117   187   208   187   172   117  b2e6e058b25a25175f4f2d264f0bb83c
# 4120    82   112   123    65   208   112  e768ea96da507ed239ce925c24b8fd1a
# 4121   117   225    35   208    89   225  5a99618b63178d7a221552fe962992e3
# 4122   171   215    35   208    56    71  10a935e723a4b1cc416adb7af2bc4965
# 4123     2   140    81     8   199   264  e1a5553452ca55133b678460246d4838
#
#             type
# 0         trojan
# 1         trojan
# 2            pua
# 3     ransomware
# 4         trojan
# ...          ...
# 4119      trojan
# 4120      trojan
# 4121      trojan
# 4122      trojan
# 4123      trojan
#
# [4124 rows x 103 columns]
#       malware  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  t_8  ...  t_92  t_93  \
# 0           1  240  117  228  215  274  158  172  198  208  ...   307   307
# 1           1   82  198   86  274   37  240  117  260   40  ...   307   307
# 2           1  215  208  228  117  240  159  187  260  141  ...   307   307
# 3           1  159  208  260  141   65   20   34  215  172  ...   307   307
# 4           1   82  240  117  172   16   11  274  158  215  ...   307   307
# ...       ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 4119        1  208  228  240  117   82  245  210   65  172  ...   307   307
# 4120        1   82  208  172  117   16  110  286  257  215  ...   307   307
# 4121        1   82  240  117   93   16  147  228  208   71  ...   307   307
# 4122        1  112  274  158  215  298   76  208  172  117  ...   307   307
# 4123        1  198  172  117  275  208  286  187  240   71  ...   307   307
#
#       t_94  t_95  t_96  t_97  t_98  t_99                              hash  \
# 0      307   307   307   307   307   307  0fe987c56cfb02db5d810534d6098d93
# 1      307   307   307   307   307   307  f58d31adac5b879b50ce07a9da086736
# 2      307   307   307   307   307   307  f07d9fa9d2852bd4b7b36f39dd531b4a
# 3      307   307   307   307   307   307  7a493fa07f0f7d0c9e372eedae03036b
# 4      307   307   307   307   307   307  ba60236d9f9fe6cd0a10ffbbf2296669
# ...    ...   ...   ...   ...   ...   ...                               ...
# 4119   307   307   307   307   307   307  b2e6e058b25a25175f4f2d264f0bb83c
# 4120   307   307   307   307   307   307  e768ea96da507ed239ce925c24b8fd1a
# 4121   307   307   307   307   307   307  5a99618b63178d7a221552fe962992e3
# 4122   307   307   307   307   307   307  10a935e723a4b1cc416adb7af2bc4965
# 4123   307   307   307   307   307   307  e1a5553452ca55133b678460246d4838
#
#             type
# 0         trojan
# 1         trojan
# 2            pua
# 3     ransomware
# 4         trojan
# ...          ...
# 4119      trojan
# 4120      trojan
# 4121      trojan
# 4122      trojan
# 4123      trojan
#
# [4124 rows x 103 columns]
#       malware                      t_0                      t_1  \
# 0           1               LdrLoadDll   LdrGetProcedureAddress
# 1           1  GetSystemTimeAsFileTime            GetSystemInfo
# 2           1                  NtClose  NtAllocateVirtualMemory
# 3           1         NtDelayExecution  NtAllocateVirtualMemory
# 4           1  GetSystemTimeAsFileTime               LdrLoadDll
# ...       ...                      ...                      ...
# 4119        1  NtAllocateVirtualMemory   NtProtectVirtualMemory
# 4120        1  GetSystemTimeAsFileTime  NtAllocateVirtualMemory
# 4121        1  GetSystemTimeAsFileTime               LdrLoadDll
# 4122        1            RegOpenKeyExA                NtOpenKey
# 4123        1            GetSystemInfo          LdrGetDllHandle
#
#                          t_2                      t_3  \
# 0                 LdrLoadDll   LdrGetProcedureAddress
# 1             NtCreateMutant  GetSystemTimeAsFileTime
# 2     NtProtectVirtualMemory   LdrGetProcedureAddress
# 3              RegOpenKeyExW         RegQueryValueExW
# 4     LdrGetProcedureAddress               LdrLoadDll
# ...                      ...                      ...
# 4119              LdrLoadDll   LdrGetProcedureAddress
# 4120         LdrGetDllHandle   LdrGetProcedureAddress
# 4121  LdrGetProcedureAddress               LdrLoadDll
# 4122         NtQueryValueKey                  NtClose
# 4123  LdrGetProcedureAddress      GetSystemDirectoryW
#
#                           t_4                      t_5  \
# 0                  LdrLoadDll   LdrGetProcedureAddress
# 1                   NtOpenKey              NtOpenKeyEx
# 2      NtProtectVirtualMemory               LdrLoadDll
# 3                 RegCloseKey  NtAllocateVirtualMemory
# 4      LdrGetProcedureAddress               LdrLoadDll
# ...                       ...                      ...
# 4119               LdrLoadDll   LdrGetProcedureAddress
# 4120          LdrGetDllHandle  NtAllocateVirtualMemory
# 4121   LdrGetProcedureAddress              GetFileType
# 4122                NtOpenKey          NtQueryValueKey
# 4123  NtAllocateVirtualMemory             SetErrorMode
#
#                               t_6                          t_7  \
# 0                      LdrLoadDll       LdrGetProcedureAddress
# 1                      LdrLoadDll       LdrGetProcedureAddress
# 2          LdrGetProcedureAddress       NtProtectVirtualMemory
# 3                      NtOpenFile       NtQueryInformationFile
# 4          LdrGetProcedureAddress                   LdrLoadDll
# ...                           ...                          ...
# 4119      GetSystemTimeAsFileTime                   LdrLoadDll
# 4120  SetUnhandledExceptionFilter                OleInitialize
# 4121       LdrGetProcedureAddress  SetUnhandledExceptionFilter
# 4122                      NtClose        NtQueryAttributesFile
# 4123      NtAllocateVirtualMemory          NtFreeVirtualMemory
#
#                           t_8  ...                     t_92  \
# 0                  LdrLoadDll  ...               LdrLoadDll
# 1               RegOpenKeyExW  ...                NtOpenKey
# 2            NtDelayExecution  ...             GetUserNameW
# 3                     NtClose  ...      NtFreeVirtualMemory
# 4      LdrGetProcedureAddress  ...            RegOpenKeyExW
# ...                       ...  ...                      ...
# 4119   LdrGetProcedureAddress  ...  NtAllocateVirtualMemory
# 4120          LdrGetDllHandle  ...           RegisterHotKey
# 4121              FindWindowA  ...             GetUserNameW
# 4122              LoadStringA  ...             NtCreateFile
# 4123  NtAllocateVirtualMemory  ...   NtProtectVirtualMemory
#
#                          t_93                     t_94  \
# 0      LdrGetProcedureAddress               LdrLoadDll
# 1                     NtClose                NtOpenKey
# 2            GetSystemMetrics               LdrLoadDll
# 3             NtCreateSection       NtMapViewOfSection
# 4            RegQueryValueExW            RegOpenKeyExW
# ...                       ...                      ...
# 4119          LdrGetDllHandle   LdrGetProcedureAddress
# 4120  NtAllocateVirtualMemory  GetSystemTimeAsFileTime
# 4121               LdrLoadDll   LdrGetProcedureAddress
# 4122          NtCreateSection       NtMapViewOfSection
# 4123             NtCreateFile            FindResourceW
#
#                           t_95                     t_96  \
# 0       LdrGetProcedureAddress          LdrGetDllHandle
# 1              NtQueryValueKey                  NtClose
# 2       LdrGetProcedureAddress  NtAllocateVirtualMemory
# 3     NtQuerySystemInformation  NtAllocateVirtualMemory
# 4             RegQueryValueExW            RegOpenKeyExW
# ...                        ...                      ...
# 4119       NtFreeVirtualMemory  NtAllocateVirtualMemory
# 4120             RegOpenKeyExA         RegQueryValueExA
# 4121               DrawTextExW         GetSystemMetrics
# 4122                   NtClose         GetSystemMetrics
# 4123            SizeofResource             LoadResource
#
#                           t_97                     t_98  \
# 0              FindResourceExW              DrawTextExW
# 1                  NtOpenKeyEx          NtQueryValueKey
# 2            NtDuplicateObject              DrawTextExW
# 3     NtQuerySystemInformation      NtFreeVirtualMemory
# 4             RegQueryValueExW            RegOpenKeyExW
# ...                        ...                      ...
# 4119       NtFreeVirtualMemory          LdrGetDllHandle
# 4120               RegCloseKey  NtAllocateVirtualMemory
# 4121   NtAllocateVirtualMemory        NtDuplicateObject
# 4122   NtAllocateVirtualMemory            CreateActCtxW
# 4123               GetFileSize           SetFilePointer
#
#                             t_99                              hash        type
# 0               GetSystemMetrics  0fe987c56cfb02db5d810534d6098d93      trojan
# 1                        NtClose  f58d31adac5b879b50ce07a9da086736      trojan
# 2               GetSystemMetrics  f07d9fa9d2852bd4b7b36f39dd531b4a         pua
# 3       NtQuerySystemInformation  7a493fa07f0f7d0c9e372eedae03036b  ransomware
# 4               RegQueryValueExW  ba60236d9f9fe6cd0a10ffbbf2296669      trojan
# ...                          ...                               ...         ...
# 4119      LdrGetProcedureAddress  b2e6e058b25a25175f4f2d264f0bb83c      trojan
# 4120               RegOpenKeyExA  e768ea96da507ed239ce925c24b8fd1a      trojan
# 4121                 DrawTextExW  5a99618b63178d7a221552fe962992e3      trojan
# 4122  GetSystemWindowsDirectoryW  10a935e723a4b1cc416adb7af2bc4965      trojan
# 4123                  NtReadFile  e1a5553452ca55133b678460246d4838      trojan
#
# [4124 rows x 103 columns]
#       malware                      t_0                      t_1  \
# 0           1               LdrLoadDll   LdrGetProcedureAddress
# 1           1  GetSystemTimeAsFileTime            GetSystemInfo
# 2           1                  NtClose  NtAllocateVirtualMemory
# 3           1         NtDelayExecution  NtAllocateVirtualMemory
# 4           1  GetSystemTimeAsFileTime               LdrLoadDll
# ...       ...                      ...                      ...
# 4119        1  NtAllocateVirtualMemory   NtProtectVirtualMemory
# 4120        1  GetSystemTimeAsFileTime  NtAllocateVirtualMemory
# 4121        1  GetSystemTimeAsFileTime               LdrLoadDll
# 4122        1            RegOpenKeyExA                NtOpenKey
# 4123        1            GetSystemInfo          LdrGetDllHandle
#
#                          t_2                     t_3  \
# 0     NtProtectVirtualMemory                 NtClose
# 1             NtCreateMutant               NtOpenKey
# 2     NtProtectVirtualMemory  LdrGetProcedureAddress
# 3              RegOpenKeyExW        RegQueryValueExW
# 4     LdrGetProcedureAddress         LdrGetDllHandle
# ...                      ...                     ...
# 4119              LdrLoadDll  LdrGetProcedureAddress
# 4120         LdrGetDllHandle  LdrGetProcedureAddress
# 4121  LdrGetProcedureAddress             GetFileType
# 4122         NtQueryValueKey                 NtClose
# 4123  LdrGetProcedureAddress     GetSystemDirectoryW
#
#                               t_4                   t_5  \
# 0                       NtOpenKey       NtQueryValueKey
# 1                     NtOpenKeyEx            LdrLoadDll
# 2                      LdrLoadDll      NtDelayExecution
# 3                     RegCloseKey            NtOpenFile
# 4     SetUnhandledExceptionFilter  CryptAcquireContextW
# ...                           ...                   ...
# 4119      GetSystemTimeAsFileTime       RegCreateKeyExA
# 4120  SetUnhandledExceptionFilter         OleInitialize
# 4121  SetUnhandledExceptionFilter           FindWindowA
# 4122        NtQueryAttributesFile           LoadStringA
# 4123      NtAllocateVirtualMemory          SetErrorMode
#
#                           t_6                      t_7  \
# 0             LdrGetDllHandle            GetSystemInfo
# 1      LdrGetProcedureAddress            RegOpenKeyExW
# 2         NtFreeVirtualMemory            RegOpenKeyExW
# 3      NtQueryInformationFile                  NtClose
# 4                   NtOpenKey          NtQueryValueKey
# ...                       ...                      ...
# 4119           RegSetValueExA              RegCloseKey
# 4120             SetErrorMode         FindFirstFileExW
# 4121   NtProtectVirtualMemory  NtAllocateVirtualMemory
# 4122  NtAllocateVirtualMemory          LdrGetDllHandle
# 4123      NtFreeVirtualMemory               LdrLoadDll
#
#                              t_8  ... t_92 t_93 t_94 t_95 t_96 t_97 t_98 t_99  \
# 0        NtAllocateVirtualMemory  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1               RegQueryInfoKeyW  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2               RegQueryValueExW  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3                LdrGetDllHandle  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4                        NtClose  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                          ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 4119             LdrGetDllHandle  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4120                     NtClose  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4121  GetSystemWindowsDirectoryW  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4122      LdrGetProcedureAddress  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4123  GetSystemWindowsDirectoryW  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                   hash        type
# 0     0fe987c56cfb02db5d810534d6098d93      trojan
# 1     f58d31adac5b879b50ce07a9da086736      trojan
# 2     f07d9fa9d2852bd4b7b36f39dd531b4a         pua
# 3     7a493fa07f0f7d0c9e372eedae03036b  ransomware
# 4     ba60236d9f9fe6cd0a10ffbbf2296669      trojan
# ...                                ...         ...
# 4119  b2e6e058b25a25175f4f2d264f0bb83c      trojan
# 4120  e768ea96da507ed239ce925c24b8fd1a      trojan
# 4121  5a99618b63178d7a221552fe962992e3      trojan
# 4122  10a935e723a4b1cc416adb7af2bc4965      trojan
# 4123  e1a5553452ca55133b678460246d4838      trojan
#
# [4124 rows x 103 columns]

# %% [markdown]
# **Battle Chart:**
#
# **GBDT vs GBDT**
# - LGBM TB vs CatBoost TB
# - LGBM IB vs CatBoost IB
# - Tuned LGBM TB vs Tuned CatBoost TB
# - Tuned LGBM IB vs Tuned CatBoost IB
#
# **Default vs Tuned**
# - LGBM TB vs Tuned LGBM TB
# - LGBM IB vs Tuned LGBM IB
# - CatBoost TB vs Tuned CatBoost TB
# - CatBoost IB vs Tuned CatBoost IB

# %%
def mcnemar_test(model1, model2, dataset1, dataset2):
    y_pred1 = model1.predict(dataset1.iloc[:,1:101])
    y_pred2 = model2.predict(dataset2.iloc[:,1:101])
    table = mlxtend.mcnemar_table(y_target,y_pred1,y_pred2)
    display(table)
    print("statsmodels.mcnemar:")
    print(statsmodels.mcnemar(table, exact=False, correction=False))
    chi2, p = mlxtend.mcnemar(table, exact=False, corrected=False)
    print("\nmlxtend.mcnemar (sanity check):")
    print(f"pvalue:\t{p}\nchi2:\t{chi2}\n")
    print("")

# %%
print('COMPARISON 1: DEFAULT LGBM TB vs DEFAULT CATBOOST TB\n')
lgbm_tb = load('../GBDT_Training/Outputs/LGBM/Default/RYZEN3b_LGBM_TB.model')
catb_tb = catb.CatBoostClassifier().load_model("../GBDT_Training/Outputs/CATB/Default/RYZEN3b_CATB_TB.model", format='json')

mcnemar_test(lgbm_tb, catb_tb, DF_LGBM_TB, DF_CATB_TB)
# Out:
# COMPARISON 1: DEFAULT LGBM TB vs DEFAULT CATBOOST TB
# array([[4068,    6],
#        [  14,   36]])
# statsmodels.mcnemar:
# pvalue      0.07363827012030257
# statistic   3.2
#
# mlxtend.mcnemar (sanity check):
# pvalue:	0.07363827012030257
# chi2:	3.2

# %%
print('COMPARISON 2: DEFAULT LGBM IB vs DEFAULT CATBOOST IB\n')
lgbm_ib = load('../GBDT_Training/Outputs/LGBM/Default/RYZEN3b_LGBM_IB.model')
catb_ib = catb.CatBoostClassifier().load_model("../GBDT_Training/Outputs/CATB/Default/RYZEN3b_CATB_IB.model", format='json')

mcnemar_test(lgbm_ib, catb_ib, DF_LGBM_IB, DF_CATB_IB)
# Out:
# COMPARISON 2: DEFAULT LGBM IB vs DEFAULT CATBOOST IB
# array([[4075,    6],
#        [   9,   34]])
# statsmodels.mcnemar:
# pvalue      0.4385780260809997
# statistic   0.6
#
# mlxtend.mcnemar (sanity check):
# pvalue:	0.4385780260809997
# chi2:	0.6

# %%
print('COMPARISON 3: TUNED LGBM TB vs TUNED CATBOOST TB\n')
lgbm_tb = load('../GBDT_Training/Outputs/LGBM/Tuned/TUNED_RYZEN3b_LGBM_TB.model')
catb_tb = catb.CatBoostClassifier().load_model("../GBDT_Training/Outputs/CATB/Tuned/TUNED_RYZEN3b_CATB_TB.model", format='json')

mcnemar_test(lgbm_tb, catb_tb, DF_LGBM_TB, DF_CATB_TB)
# Out:
# COMPARISON 3: TUNED LGBM TB vs TUNED CATBOOST TB
# array([[4069,    8],
#        [  11,   36]])
# statsmodels.mcnemar:
# pvalue      0.4912971242158931
# statistic   0.47368421052631576
#
# mlxtend.mcnemar (sanity check):
# pvalue:	0.4912971242158931
# chi2:	0.47368421052631576

# %%
print('COMPARISON 4: TUNED LGBM IB vs TUNED CATBOOST IB\n')
lgbm_ib = load('../GBDT_Training/Outputs/LGBM/Tuned/TUNED_RYZEN3b_LGBM_IB.model')
catb_ib = catb.CatBoostClassifier().load_model("../GBDT_Training/Outputs/CATB/Tuned/TUNED_RYZEN3b_CATB_IB.model", format='json')

mcnemar_test(lgbm_ib, catb_ib, DF_LGBM_IB, DF_CATB_IB)
# Out:
# COMPARISON 4: TUNED LGBM IB vs TUNED CATBOOST IB
# array([[4077,   10],
#        [   7,   30]])
# statsmodels.mcnemar:
# pvalue      0.46685427082272524
# statistic   0.5294117647058824
#
# mlxtend.mcnemar (sanity check):
# pvalue:	0.46685427082272524
# chi2:	0.5294117647058824

# %%
print('COMPARISON 5: DEFAULT LGBM TB vs TUNED LGBM TB\n')
default_tb = load('../GBDT_Training/Outputs/LGBM/Default/RYZEN3b_LGBM_TB.model')
tuned_tb = load('../GBDT_Training/Outputs/LGBM/Tuned/TUNED_RYZEN3b_LGBM_TB.model')

mcnemar_test(default_tb, tuned_tb, DF_LGBM_TB, DF_LGBM_TB)
# Out:
# COMPARISON 5: DEFAULT LGBM TB vs TUNED LGBM TB
# array([[4072,    2],
#        [   5,   45]])
# statsmodels.mcnemar:
# pvalue      0.25683925795785334
# statistic   1.2857142857142858
#
# mlxtend.mcnemar (sanity check):
# pvalue:	0.25683925795785334
# chi2:	1.2857142857142858

# %%
print('COMPARISON 6: DEFAULT LGBM IB vs TUNED LGBM IB\n')
default_ib = load('../GBDT_Training/Outputs/LGBM/Default/RYZEN3b_LGBM_IB.model')
tuned_ib = load('../GBDT_Training/Outputs/LGBM/Tuned/TUNED_RYZEN3b_LGBM_IB.model')

mcnemar_test(default_ib, tuned_ib, DF_LGBM_IB, DF_LGBM_IB)
# Out:
# COMPARISON 6: DEFAULT LGBM IB vs TUNED LGBM IB
# array([[4079,    2],
#        [   8,   35]])
# statsmodels.mcnemar:
# pvalue      0.05777957112359715
# statistic   3.6
#
# mlxtend.mcnemar (sanity check):
# pvalue:	0.05777957112359715
# chi2:	3.6

# %%
print('COMPARISON 7: DEFAULT CATBOOST TB vs TUNED CATBOOST TB\n')
default_tb = catb.CatBoostClassifier().load_model("../GBDT_Training/Outputs/CATB/Default/RYZEN3b_CATB_TB.model", format='json')
tuned_tb = catb.CatBoostClassifier().load_model("../GBDT_Training/Outputs/CATB/Tuned/TUNED_RYZEN3b_CATB_TB.model", format='json')

mcnemar_test(default_tb, tuned_tb, DF_CATB_TB, DF_CATB_TB)
# Out:
# COMPARISON 7: DEFAULT CATBOOST TB vs TUNED CATBOOST TB
# array([[4074,    8],
#        [   6,   36]])
# statsmodels.mcnemar:
# pvalue      0.5929800980174266
# statistic   0.2857142857142857
#
# mlxtend.mcnemar (sanity check):
# pvalue:	0.5929800980174266
# chi2:	0.2857142857142857

# %%
print('COMPARISON 8: DEFAULT CATBOOST IB vs TUNED CATBOOST IB\n')
default_ib = catb.CatBoostClassifier().load_model("../GBDT_Training/Outputs/CATB/Default/RYZEN3b_CATB_IB.model", format='json')
tuned_ib = catb.CatBoostClassifier().load_model("../GBDT_Training/Outputs/CATB/Tuned/TUNED_RYZEN3b_CATB_IB.model", format='json')

mcnemar_test(default_ib, tuned_ib, DF_CATB_IB, DF_CATB_IB)
# Out:
# COMPARISON 8: DEFAULT CATBOOST IB vs TUNED CATBOOST IB
# array([[4080,    4],
#        [   4,   36]])
# statsmodels.mcnemar:
# pvalue      1.0
# statistic   0.0
#
# mlxtend.mcnemar (sanity check):
# pvalue:	1.0
# chi2:	0.0

# %%
print('COMPARISON 9: DEFAULT LIGHTGBM TB vs DEFAULT LIGHTGBM IB\n')
default_tb = load('../GBDT_Training/Outputs/LGBM/Default/RYZEN3b_LGBM_TB.model')
default_ib = load('../GBDT_Training/Outputs/LGBM/Default/RYZEN3b_LGBM_IB.model')

mcnemar_test(default_tb, default_ib, DF_LGBM_TB, DF_LGBM_IB)
# Out:
# COMPARISON 9: DEFAULT LIGHTGBM TB vs DEFAULT LIGHTGBM IB
# array([[4069,    5],
#        [  12,   38]])
# statsmodels.mcnemar:
# pvalue      0.08955507441364248
# statistic   2.8823529411764706
#
# mlxtend.mcnemar (sanity check):
# pvalue:	0.08955507441364248
# chi2:	2.8823529411764706

# %%
print('COMPARISON 10: TUNED LIGHTGBM TB vs TUNED LIGHTGBM IB\n')
tuned_tb = load('../GBDT_Training/Outputs/LGBM/Tuned/TUNED_RYZEN3b_LGBM_TB.model')
tuned_ib = load('../GBDT_Training/Outputs/LGBM/Tuned/TUNED_RYZEN3b_LGBM_IB.model')

mcnemar_test(tuned_tb, tuned_ib, DF_LGBM_TB, DF_LGBM_IB)
# Out:
# COMPARISON 10: TUNED LIGHTGBM TB vs TUNED LIGHTGBM IB
# array([[4073,    4],
#        [  14,   33]])
# statsmodels.mcnemar:
# pvalue      0.01842212545409897
# statistic   5.555555555555555
#
# mlxtend.mcnemar (sanity check):
# pvalue:	0.01842212545409897
# chi2:	5.555555555555555

# %%
print('COMPARISON 11: DEFAULT CATBOOST TB vs DEFAULT CATBOOST IB\n')
default_tb = catb.CatBoostClassifier().load_model("../GBDT_Training/Outputs/CATB/Default/RYZEN3b_CATB_TB.model", format='json')
default_ib = catb.CatBoostClassifier().load_model("../GBDT_Training/Outputs/CATB/Default/RYZEN3b_CATB_IB.model", format='json')

mcnemar_test(default_tb, default_ib, DF_CATB_TB, DF_CATB_IB)
# Out:
# COMPARISON 11: DEFAULT CATBOOST TB vs DEFAULT CATBOOST IB
# array([[4072,   10],
#        [  12,   30]])
# statsmodels.mcnemar:
# pvalue      0.6698153575994165
# statistic   0.18181818181818182
#
# mlxtend.mcnemar (sanity check):
# pvalue:	0.6698153575994165
# chi2:	0.18181818181818182

# %%
print('COMPARISON 12: TUNED CATBOOST TB vs TUNED CATBOOST IB\n')
tuned_tb = catb.CatBoostClassifier().load_model("../GBDT_Training/Outputs/CATB/Tuned/TUNED_RYZEN3b_CATB_TB.model", format='json')
tuned_ib = catb.CatBoostClassifier().load_model("../GBDT_Training/Outputs/CATB/Tuned/TUNED_RYZEN3b_CATB_IB.model", format='json')

mcnemar_test(tuned_tb, tuned_ib, DF_CATB_TB, DF_CATB_IB)
# Out:
# COMPARISON 12: TUNED CATBOOST TB vs TUNED CATBOOST IB
# array([[4067,   13],
#        [  17,   27]])
# statsmodels.mcnemar:
# pvalue      0.4652088184521417
# statistic   0.5333333333333333
#
# mlxtend.mcnemar (sanity check):
# pvalue:	0.4652088184521417
# chi2:	0.5333333333333333
