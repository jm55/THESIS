# %% [markdown]
# # Model Robustness
#
# **Objectives**
# - Load the Model(s)
# - Run predictions on the model using the Holdout/Test Datasplit (better if the malicious samples are verified for malware types)
# - Record instances where the model failed to predict correctly
# - Record the performance of the models (e.g., Accuracy, Precision, Recall, ROC-AUC, etc.)

# %%
import pandas as pd
import numpy as np

import lightgbm as lgbm
import catboost as catb

from sklearn.metrics import classification_report, roc_auc_score, accuracy_score, average_precision_score, roc_auc_score, recall_score, precision_score, f1_score
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix, RocCurveDisplay

from joblib import load
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 1. Determine the Model Performance in each of the GBDT Models and each of its two behavior-types.
#
# `How does the model perform using 'real-world' data (i.e., Test/Holdout Split)?`
#
# Run other metrics as well as you see fit that are not found in the classification_report and Confusion Matrix.
#
# - Label column is `0/'malicious'`
# - Feature column is `[:, 1:101]`

# %% [markdown]
# ### 1.1 Defining a helper function for evaluation

# %%
def evaluate(model, test_set, y_actual):
    y_pred = model.predict(test_set)
    cm = confusion_matrix(y_actual, y_pred)
    print(classification_report(y_actual, y_pred, digits=4))
    print("AUC-ROC Score: " + str(roc_auc_score(y_actual, y_pred)))
    print("ROC Curve & Confusion matrix:")
    RocCurveDisplay.from_predictions(y_actual, y_pred)
    ConfusionMatrixDisplay(cm).plot()
    #print(classification_report(y_actual, y_pred, digits=4))

# %% [markdown]
# ### 1.2 LightGBM

# %%
DF_LGBM_TB = pd.read_csv('Dataset/LGBM_TB_Test.csv', low_memory=False) #<== Point these to the proper Test/Holdout datasets.
DF_LGBM_IB = pd.read_csv('Dataset/LGBM_IB_Test.csv', low_memory=False)

display(DF_LGBM_TB.head())
display(DF_LGBM_IB.head())
# Out:
#    malware  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  t_8  ...  t_92  t_93  \
# 0        1  215  274  158  215  274  158  215  172  117  ...    15   240
# 1        1  286  110  172  240  117  240  117  240  117  ...   275   260
# 2        1   82  208  187  208  172  117  172  208   16  ...   117   172
# 3        1  112  274  158  215  274  158  215  298   76  ...   297   135
# 4        1   82  240  117  240  117  240  117  240  117  ...   260   141
#
#    t_94  t_95  t_96  t_97  t_98  t_99                              hash  \
# 0   117   240   117   240   117   172  f0f8ba4c3d750a4ce2deea48152a33d4
# 1   240   117   141    65   260   141  39b2d87c1adb582fbcacc3a56e274d48
# 2   117   208   172   117   100   215  429236cdeb63d68bf48a3b48b0a34612
# 3   171   215    35   208    56    71  46079cbf0bcfe8fab9894b4ec88bece3
# 4   260   141   260   141   260   141  303ceda3f52afa9b69ed4f97fec2c895
#
#          type
# 0      trojan
# 1      trojan
# 2  downloader
# 3      trojan
# 4      trojan
#
# [5 rows x 103 columns]
#    malware  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  t_8  ...  t_92  t_93  \
# 0        1  215  274  158  172  117  198  208  260  257  ...   307   307
# 1        1  286  110  172  240  117  106  171  260  141  ...   307   307
# 2        1   82  208  187  172  117   16  240  112  123  ...   307   307
# 3        1  112  274  158  215  298   76  208  172  117  ...   307   307
# 4        1   82  240  117  172   16   11  274  158  215  ...   307   307
#
#    t_94  t_95  t_96  t_97  t_98  t_99                              hash  \
# 0   307   307   307   307   307   307  f0f8ba4c3d750a4ce2deea48152a33d4
# 1   307   307   307   307   307   307  39b2d87c1adb582fbcacc3a56e274d48
# 2   307   307   307   307   307   307  429236cdeb63d68bf48a3b48b0a34612
# 3   307   307   307   307   307   307  46079cbf0bcfe8fab9894b4ec88bece3
# 4   307   307   307   307   307   307  303ceda3f52afa9b69ed4f97fec2c895
#
#          type
# 0      trojan
# 1      trojan
# 2  downloader
# 3      trojan
# 4      trojan
#
# [5 rows x 103 columns]

# %%
# Load trained LightGBM model files
default_tb = load('Models/LGBM/Train_Default/RYZEN2c_LGBM_TB.model') # <== Point these to the respective .model files
default_ib = load('Models/LGBM/Train_Default/RYZEN2c_LGBM_IB.model')
tuned_tb = load('Models/LGBM/Train_Tuned/TUNED_RYZEN2c_LGBM_TB.model')
tuned_ib = load('Models/LGBM/Train_Tuned/TUNED_RYZEN2c_LGBM_IB.model')

# %%
print("1. Default LGBM TB\n")
evaluate(default_tb, DF_LGBM_TB.iloc[:,1:101], DF_LGBM_TB.iloc[:,0])
# Out:
# 1. Default LGBM TB
#
#               precision    recall  f1-score   support
#
#            0     0.9492    0.5385    0.6871       104
#            1     0.9889    0.9993    0.9941      4284
#
#     accuracy                         0.9884      4388
#    macro avg     0.9690    0.7689    0.8406      4388
# weighted avg     0.9880    0.9884    0.9868      4388
#
# AUC-ROC Score: 0.7688806291747468
# ROC Curve & Confusion matrix:

# %%
print("2. Default LGBM IB\n")
evaluate(default_ib, DF_LGBM_IB.iloc[:,1:101], DF_LGBM_IB.iloc[:,0])
# Out:
# 2. Default LGBM IB
#
#               precision    recall  f1-score   support
#
#            0     0.8824    0.5769    0.6977       104
#            1     0.9898    0.9981    0.9940      4284
#
#     accuracy                         0.9881      4388
#    macro avg     0.9361    0.7875    0.8458      4388
# weighted avg     0.9873    0.9881    0.9869      4388
#
# AUC-ROC Score: 0.7875278316454787
# ROC Curve & Confusion matrix:

# %%
print("3. Tuned LGBM TB\n")
evaluate(tuned_tb, DF_LGBM_TB.iloc[:,1:101], DF_LGBM_TB.iloc[:,0])
# Out:
# 3. Tuned LGBM TB
#
#               precision    recall  f1-score   support
#
#            0     0.9672    0.5673    0.7152       104
#            1     0.9896    0.9995    0.9945      4284
#
#     accuracy                         0.9893      4388
#    macro avg     0.9784    0.7834    0.8548      4388
# weighted avg     0.9891    0.9893    0.9879      4388
#
# AUC-ROC Score: 0.7834204194498312
# ROC Curve & Confusion matrix:

# %%
print("4. Tuned LGBM IB\n")
evaluate(tuned_ib, DF_LGBM_IB.iloc[:,1:101], DF_LGBM_IB.iloc[:,0])
# Out:
# 4. Tuned LGBM IB
#
#               precision    recall  f1-score   support
#
#            0     0.8933    0.6442    0.7486       104
#            1     0.9914    0.9981    0.9948      4284
#
#     accuracy                         0.9897      4388
#    macro avg     0.9424    0.8212    0.8717      4388
# weighted avg     0.9891    0.9897    0.9889      4388
#
# AUC-ROC Score: 0.8211816777993248
# ROC Curve & Confusion matrix:

# %% [markdown]
# ### 1.3 CatBoost

# %%
DF_CATB_TB = pd.read_csv('Dataset/CATB_TB_Test.csv', low_memory=False) #<== Point these to the proper Test/Holdout datasets.
DF_CATB_IB = pd.read_csv('Dataset/CATB_IB_Test.csv', low_memory=False)

DF_CATB_IB.iloc[:,1:101] = DF_CATB_IB.iloc[:,1:101].astype('str')
DF_CATB_IB.replace("nan", "NaN", inplace=True)

#DF_CATB_TB = DF_CATB_TB[DF_CATB_TB['Type 1'] != '_']
#DF_CATB_IB = DF_CATB_IB[DF_CATB_IB['Type 1'] != '_']

display(DF_CATB_TB.head())
display(DF_CATB_IB.head())
# Out:
#    malware                      t_0                      t_1  \
# 0        1                  NtClose                NtOpenKey
# 1        1             SetErrorMode            OleInitialize
# 2        1  GetSystemTimeAsFileTime  NtAllocateVirtualMemory
# 3        1            RegOpenKeyExA                NtOpenKey
# 4        1  GetSystemTimeAsFileTime               LdrLoadDll
#
#                       t_2                      t_3                     t_4  \
# 0         NtQueryValueKey                  NtClose               NtOpenKey
# 1         LdrGetDllHandle               LdrLoadDll  LdrGetProcedureAddress
# 2     NtFreeVirtualMemory  NtAllocateVirtualMemory         LdrGetDllHandle
# 3         NtQueryValueKey                  NtClose               NtOpenKey
# 4  LdrGetProcedureAddress               LdrLoadDll  LdrGetProcedureAddress
#
#                       t_5                     t_6                      t_7  \
# 0         NtQueryValueKey                 NtClose          LdrGetDllHandle
# 1              LdrLoadDll  LdrGetProcedureAddress               LdrLoadDll
# 2  LdrGetProcedureAddress         LdrGetDllHandle  NtAllocateVirtualMemory
# 3         NtQueryValueKey                 NtClose    NtQueryAttributesFile
# 4              LdrLoadDll  LdrGetProcedureAddress               LdrLoadDll
#
#                            t_8  ...                    t_92              t_93  \
# 0       LdrGetProcedureAddress  ...       LookupAccountSidW        LdrLoadDll
# 1       LdrGetProcedureAddress  ...     GetSystemDirectoryW     RegOpenKeyExW
# 2  SetUnhandledExceptionFilter  ...  LdrGetProcedureAddress   LdrGetDllHandle
# 3                  LoadStringA  ...            NtCreateFile   NtCreateSection
# 4       LdrGetProcedureAddress  ...           RegOpenKeyExW  RegQueryValueExW
#
#                      t_94                     t_95                    t_96  \
# 0  LdrGetProcedureAddress               LdrLoadDll  LdrGetProcedureAddress
# 1              LdrLoadDll   LdrGetProcedureAddress        RegQueryValueExW
# 2  LdrGetProcedureAddress  NtAllocateVirtualMemory         LdrGetDllHandle
# 3      NtMapViewOfSection                  NtClose        GetSystemMetrics
# 4           RegOpenKeyExW         RegQueryValueExW           RegOpenKeyExW
#
#                       t_97                    t_98  \
# 0               LdrLoadDll  LdrGetProcedureAddress
# 1              RegCloseKey           RegOpenKeyExW
# 2   LdrGetProcedureAddress           NtOpenProcess
# 3  NtAllocateVirtualMemory           CreateActCtxW
# 4         RegQueryValueExW           RegOpenKeyExW
#
#                          t_99                              hash        type
# 0             LdrGetDllHandle  f0f8ba4c3d750a4ce2deea48152a33d4      trojan
# 1            RegQueryValueExW  39b2d87c1adb582fbcacc3a56e274d48      trojan
# 2                     NtClose  429236cdeb63d68bf48a3b48b0a34612  downloader
# 3  GetSystemWindowsDirectoryW  46079cbf0bcfe8fab9894b4ec88bece3      trojan
# 4            RegQueryValueExW  303ceda3f52afa9b69ed4f97fec2c895      trojan
#
# [5 rows x 103 columns]
#    malware                      t_0                      t_1  \
# 0        1                  NtClose                NtOpenKey
# 1        1             SetErrorMode            OleInitialize
# 2        1  GetSystemTimeAsFileTime  NtAllocateVirtualMemory
# 3        1            RegOpenKeyExA                NtOpenKey
# 4        1  GetSystemTimeAsFileTime               LdrLoadDll
#
#                       t_2              t_3                          t_4  \
# 0         NtQueryValueKey  LdrGetDllHandle       LdrGetProcedureAddress
# 1         LdrGetDllHandle       LdrLoadDll       LdrGetProcedureAddress
# 2     NtFreeVirtualMemory  LdrGetDllHandle       LdrGetProcedureAddress
# 3         NtQueryValueKey          NtClose        NtQueryAttributesFile
# 4  LdrGetProcedureAddress  LdrGetDllHandle  SetUnhandledExceptionFilter
#
#                            t_5                      t_6              t_7  \
# 0                GetSystemInfo  NtAllocateVirtualMemory    RegOpenKeyExW
# 1                NtOpenSection       NtMapViewOfSection    RegOpenKeyExW
# 2  SetUnhandledExceptionFilter               LdrLoadDll    RegOpenKeyExA
# 3                  LoadStringA  NtAllocateVirtualMemory  LdrGetDllHandle
# 4         CryptAcquireContextW                NtOpenKey  NtQueryValueKey
#
#                       t_8  ... t_92 t_93 t_94 t_95 t_96 t_97 t_98 t_99  \
# 0        FindFirstFileExW  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1        RegQueryValueExW  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2        RegQueryValueExA  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3  LdrGetProcedureAddress  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4                 NtClose  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                hash        type
# 0  f0f8ba4c3d750a4ce2deea48152a33d4      trojan
# 1  39b2d87c1adb582fbcacc3a56e274d48      trojan
# 2  429236cdeb63d68bf48a3b48b0a34612  downloader
# 3  46079cbf0bcfe8fab9894b4ec88bece3      trojan
# 4  303ceda3f52afa9b69ed4f97fec2c895      trojan
#
# [5 rows x 103 columns]

# %%
# Load trained CatBoost model files (CatBoost requires instantiation before being able to load a trianed model file).
default_tb = catb.CatBoostClassifier()
default_ib = catb.CatBoostClassifier()
tuned_tb = catb.CatBoostClassifier()
tuned_ib = catb.CatBoostClassifier()
default_tb = default_tb.load_model("Models/CATB/Train_Default/RYZEN2c_CATB_TB.model", format='json') # <== Point these to the respective .model files
default_ib = default_ib.load_model("Models/CATB/Train_Default/RYZEN2c_CATB_IB.model", format='json')
tuned_tb = tuned_tb.load_model("Models/CATB/Train_Tuned/TUNED_RYZEN2c_CATB_TB.model", format='json')
tuned_ib = tuned_ib.load_model("Models/CATB/Train_Tuned/TUNED_RYZEN2c_CATB_IB.model", format='json')

# %%
print("1. Default CatBoost TB\n")
evaluate(default_tb, DF_CATB_TB.iloc[:,1:101], DF_CATB_TB.iloc[:,0])
# Out:
# 1. Default CatBoost TB
#
#               precision    recall  f1-score   support
#
#            0     0.8714    0.5865    0.7011       104
#            1     0.9900    0.9979    0.9940      4284
#
#     accuracy                         0.9881      4388
#    macro avg     0.9307    0.7922    0.8476      4388
# weighted avg     0.9872    0.9881    0.9870      4388
#
# AUC-ROC Score: 0.7922188106011635
# ROC Curve & Confusion matrix:

# %%
print("2. Default CatBoost IB\n")
evaluate(default_ib, DF_CATB_IB.iloc[:,1:101], DF_CATB_IB.iloc[:,0])
# Out:
# 2. Default CatBoost IB
#
#               precision    recall  f1-score   support
#
#            0     0.8642    0.6731    0.7568       104
#            1     0.9921    0.9974    0.9948      4284
#
#     accuracy                         0.9897      4388
#    macro avg     0.9282    0.8353    0.8758      4388
# weighted avg     0.9891    0.9897    0.9891      4388
#
# AUC-ROC Score: 0.8352546146663794
# ROC Curve & Confusion matrix:

# %%
print("3. Tuned CatBoost TB\n")
evaluate(tuned_tb, DF_CATB_TB.iloc[:,1:101], DF_CATB_TB.iloc[:,0])
# Out:
# 3. Tuned CatBoost TB
#
#               precision    recall  f1-score   support
#
#            0     0.8462    0.5288    0.6509       104
#            1     0.9887    0.9977    0.9931      4284
#
#     accuracy                         0.9866      4388
#    macro avg     0.9174    0.7633    0.8220      4388
# weighted avg     0.9853    0.9866    0.9850      4388
#
# AUC-ROC Score: 0.7632559434030022
# ROC Curve & Confusion matrix:

# %%
print("4. Tuned CatBoost IB\n")
evaluate(tuned_ib, DF_CATB_IB.iloc[:,1:101], DF_CATB_IB.iloc[:,0])
# Out:
# 4. Tuned CatBoost IB
#
#               precision    recall  f1-score   support
#
#            0     0.8625    0.6635    0.7500       104
#            1     0.9919    0.9974    0.9946      4284
#
#     accuracy                         0.9895      4388
#    macro avg     0.9272    0.8304    0.8723      4388
# weighted avg     0.9888    0.9895    0.9888      4388
#
# AUC-ROC Score: 0.8304469223586871
# ROC Curve & Confusion matrix:

# %% [markdown]
# ## 2. Check for model capabilities at a malware type level in each GBDT Models and each of its two behavior-types.
#
# Using the `xx` dataset, determine the prediction capability of the model in each malware type.
#
# **Answer this question:**
#
# `How good are the model (as per classification report and confusion matrix) on a per-malware type basis?`
#
# The theory is that malware-types that are prominent in terms of quantity might be detected accurately as malware than those that are not.

# %% [markdown]
# ### 2.1 Defining a helper function

# %%
def evaluate_per_type(model, test_set, mal_type):
    filtered_set = test_set.loc[(test_set['type'] == 'benign') | (test_set['type'] == mal_type)]
    y_pred = model.predict(filtered_set.iloc[:,1:101])
    acc = accuracy_score(filtered_set.iloc[:,0], y_pred)
    prec = precision_score(filtered_set.iloc[:,0], y_pred)
    rec = recall_score(filtered_set.iloc[:,0], y_pred)
    auc_roc = roc_auc_score(filtered_set.iloc[:,0], y_pred)
    f1 = f1_score(filtered_set.iloc[:,0], y_pred)
    cm = confusion_matrix(filtered_set.iloc[:,0], y_pred)
    print("Malware Type: " + mal_type)
    print("==========================")
    print(f"Accuracy:  {acc:.4f}")
    print(f"Precision: {prec:.4f}")
    print(f"Recall:    {rec:.4f}")
    print(f"F1 Score:  {f1:.4f}")
    print(f"AUC-ROC:   {auc_roc:.4f}")
    print(f"TN: {cm[0,0]:4d} FN: {cm[1,0]:4d}")
    print(f"TP: {cm[1,1]:4d} FP: {cm[0,1]:4d}")
    print("")

# %% [markdown]
# ### 2.1 LightGBM

# %%
#Load Verified Test/Holodut Dataset
DF_LGBM_TB = pd.read_csv('./Dataset/LGBM_TB_Test.csv', low_memory=False)
DF_LGBM_IB = pd.read_csv('./Dataset/LGBM_IB_Test.csv', low_memory=False)

# No need to drop these "_" muna, assume na walang false-labelled malicious samples (pa-comment out nalang muna).
# DF_LGBM_TB = DF_LGBM_TB[DF_LGBM_TB['type'] != '_']
# DF_LGBM_IB = DF_LGBM_IB[DF_LGBM_IB['type'] != '_']
DF_LGBM_TB = DF_LGBM_TB.dropna()
DF_LGBM_IB = DF_LGBM_IB.dropna()

#Models
default_tb = load('./Models/LGBM/Train_Default/RYZEN2c_LGBM_TB.model')
default_ib = load('./Models/LGBM/Train_Default/RYZEN2c_LGBM_IB.model')
tuned_tb = load('./Models/LGBM/Train_Tuned/TUNED_RYZEN2c_LGBM_TB.model')
tuned_ib = load('./Models/LGBM/Train_Tuned/TUNED_RYZEN2c_LGBM_IB.model')

display(DF_LGBM_TB)
print("DF_LGBM_TB:", DF_LGBM_TB['type'].unique().tolist())
display(DF_LGBM_IB)
print("DF_LGBM_IB:", DF_LGBM_IB['type'].unique().tolist())

'''
COLUMNS:
Features = [:, 1:101]
Label = [:, 0]
Hash = [:, 101]
Type 1 (malware type) = [:, 102]
'''
# Out:
#       malware  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  t_8  ...  t_92  t_93  \
# 0           1  215  274  158  215  274  158  215  172  117  ...    15   240
# 1           1  286  110  172  240  117  240  117  240  117  ...   275   260
# 2           1   82  208  187  208  172  117  172  208   16  ...   117   172
# 3           1  112  274  158  215  274  158  215  298   76  ...   297   135
# 4           1   82  240  117  240  117  240  117  240  117  ...   260   141
# ...       ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 4383        1   82  240  117  240  117   93  117  172  117  ...    37   240
# 4384        1  240  117  240  117  240  117  240  117  240  ...    81    60
# 4385        1   82  240  117  240  117  240  117  240  117  ...   260   141
# 4386        1  240  228  240  228   31   86  172  117  172  ...    65    70
# 4387        1  286  110  172  240  117  240  117  240  117  ...   172   117
#
#       t_94  t_95  t_96  t_97  t_98  t_99                              hash  \
# 0      117   240   117   240   117   172  f0f8ba4c3d750a4ce2deea48152a33d4
# 1      240   117   141    65   260   141  39b2d87c1adb582fbcacc3a56e274d48
# 2      117   208   172   117   100   215  429236cdeb63d68bf48a3b48b0a34612
# 3      171   215    35   208    56    71  46079cbf0bcfe8fab9894b4ec88bece3
# 4      260   141   260   141   260   141  303ceda3f52afa9b69ed4f97fec2c895
# ...    ...   ...   ...   ...   ...   ...                               ...
# 4383   117   240   117   198   240   117  ace1fb315abc4e4a10624c8b03f917aa
# 4384    81    60    81    60    81    60  f8948ed47902c6400b086a867685c107
# 4385   260   141   260   141   260   141  131e9e0e7ce851fd4be463c32e025c7b
# 4386   215    37   117    70   215    37  c85d6c224b59b3ce76698e9d5aacd3ae
# 4387   240   117   240   262   261   106  673c18473d60716147397eab14427a59
#
#             type
# 0         trojan
# 1         trojan
# 2     downloader
# 3         trojan
# 4         trojan
# ...          ...
# 4383      trojan
# 4384      trojan
# 4385      trojan
# 4386      trojan
# 4387           _
#
# [4388 rows x 103 columns]
# DF_LGBM_TB: ['trojan', 'downloader', 'adware', 'pua', '_', 'ransomware', 'benign', 'spyware', 'virus', 'hacktool', 'miner']
#       malware  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  t_8  ...  t_92  t_93  \
# 0           1  215  274  158  172  117  198  208  260  257  ...   307   307
# 1           1  286  110  172  240  117  106  171  260  141  ...   307   307
# 2           1   82  208  187  172  117   16  240  112  123  ...   307   307
# 3           1  112  274  158  215  298   76  208  172  117  ...   307   307
# 4           1   82  240  117  172   16   11  274  158  215  ...   307   307
# ...       ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 4383        1   82  240  117   93  172   16  215  274  158  ...   307   307
# 4384        1  240  117  228  215  274  158  172  198  208  ...   307   307
# 4385        1   82  240  117  172   16   11  274  158  215  ...   307   307
# 4386        1  240  228   31   86  172  117  274  215  106  ...   307   307
# 4387        1  286  110  172  240  117  106  171  260  141  ...   307   307
#
#       t_94  t_95  t_96  t_97  t_98  t_99                              hash  \
# 0      307   307   307   307   307   307  f0f8ba4c3d750a4ce2deea48152a33d4
# 1      307   307   307   307   307   307  39b2d87c1adb582fbcacc3a56e274d48
# 2      307   307   307   307   307   307  429236cdeb63d68bf48a3b48b0a34612
# 3      307   307   307   307   307   307  46079cbf0bcfe8fab9894b4ec88bece3
# 4      307   307   307   307   307   307  303ceda3f52afa9b69ed4f97fec2c895
# ...    ...   ...   ...   ...   ...   ...                               ...
# 4383   307   307   307   307   307   307  ace1fb315abc4e4a10624c8b03f917aa
# 4384   307   307   307   307   307   307  f8948ed47902c6400b086a867685c107
# 4385   307   307   307   307   307   307  131e9e0e7ce851fd4be463c32e025c7b
# 4386   307   307   307   307   307   307  c85d6c224b59b3ce76698e9d5aacd3ae
# 4387   307   307   307   307   307   307  673c18473d60716147397eab14427a59
#
#             type
# 0         trojan
# 1         trojan
# 2     downloader
# 3         trojan
# 4         trojan
# ...          ...
# 4383      trojan
# 4384      trojan
# 4385      trojan
# 4386      trojan
# 4387           _
#
# [4388 rows x 103 columns]
# DF_LGBM_IB: ['trojan', 'downloader', 'adware', 'pua', '_', 'ransomware', 'benign', 'spyware', 'virus', 'hacktool', 'miner']
# '\nCOLUMNS:\nFeatures = [:, 1:101]\nLabel = [:, 0]\nHash = [:, 101]\nType 1 (malware type) = [:, 102]\n'

# %%
print("1. Default LGBM TB\n")
for mal_type in DF_LGBM_TB['type'].unique().tolist():
    if(mal_type != 'benign'):
        evaluate_per_type(default_tb, DF_LGBM_TB, mal_type)
# Out:
# 1. Default LGBM TB
#
# Malware Type: trojan
# ==========================
# Accuracy:  0.9864
# Precision: 0.9862
# Recall:    1.0000
# F1 Score:  0.9930
# AUC-ROC:   0.7718
# TN:   56 FN:    0
# TP: 3351 FP:   47
#
# Malware Type: downloader
# ==========================
# Accuracy:  0.8630
# Precision: 0.8362
# Recall:    1.0000
# F1 Score:  0.9108
# AUC-ROC:   0.7718
# TN:   56 FN:    0
# TP:  240 FP:   47
#
# Malware Type: adware
# ==========================
# Accuracy:  0.8449
# Precision: 0.8097
# Recall:    1.0000
# F1 Score:  0.8949
# AUC-ROC:   0.7718
# TN:   56 FN:    0
# TP:  200 FP:   47
#
# Malware Type: pua
# ==========================
# Accuracy:  0.8303
# Precision: 0.7873
# Recall:    1.0000
# F1 Score:  0.8810
# AUC-ROC:   0.7718
# TN:   56 FN:    0
# TP:  174 FP:   47
#
# Malware Type: _
# ==========================
# Accuracy:  0.8634
# Precision: 0.8442
# Recall:    0.9924
# F1 Score:  0.9123
# AUC-ROC:   0.7654
# TN:   56 FN:    2
# TP:  260 FP:   48
#
# Malware Type: ransomware
# ==========================
# Accuracy:  0.6544
# Precision: 0.4125
# Recall:    1.0000
# F1 Score:  0.5841
# AUC-ROC:   0.7718
# TN:   56 FN:    0
# TP:   33 FP:   47
#
# Malware Type: spyware
# ==========================
# Accuracy:  0.5648
# Precision: 0.0962
# Recall:    1.0000
# F1 Score:  0.1754
# AUC-ROC:   0.7718
# TN:   56 FN:    0
# TP:    5 FP:   47
#
# Malware Type: virus
# ==========================
# Accuracy:  0.5766
# Precision: 0.1455
# Recall:    1.0000
# F1 Score:  0.2540
# AUC-ROC:   0.7718
# TN:   56 FN:    0
# TP:    8 FP:   47
#
# Malware Type: hacktool
# ==========================
# Accuracy:  0.5566
# Precision: 0.0600
# Recall:    1.0000
# F1 Score:  0.1132
# AUC-ROC:   0.7718
# TN:   56 FN:    0
# TP:    3 FP:   47
#
# Malware Type: miner
# ==========================
# Accuracy:  0.5676
# Precision: 0.1296
# Recall:    0.8750
# F1 Score:  0.2258
# AUC-ROC:   0.7093
# TN:   56 FN:    1
# TP:    7 FP:   47

# %%
print("2. Default LGBM IB\n")
for mal_type in DF_LGBM_IB['type'].unique().tolist():
    if(mal_type != 'benign'):
        evaluate_per_type(default_ib, DF_LGBM_IB, mal_type)
# Out:
# 2. Default LGBM IB
#
# Malware Type: trojan
# ==========================
# Accuracy:  0.9873
# Precision: 0.9873
# Recall:    0.9997
# F1 Score:  0.9935
# AUC-ROC:   0.7911
# TN:   60 FN:    1
# TP: 3350 FP:   43
#
# Malware Type: downloader
# ==========================
# Accuracy:  0.8746
# Precision: 0.8481
# Recall:    1.0000
# F1 Score:  0.9178
# AUC-ROC:   0.7913
# TN:   60 FN:    0
# TP:  240 FP:   43
#
# Malware Type: adware
# ==========================
# Accuracy:  0.8581
# Precision: 0.8230
# Recall:    1.0000
# F1 Score:  0.9029
# AUC-ROC:   0.7913
# TN:   60 FN:    0
# TP:  200 FP:   43
#
# Malware Type: pua
# ==========================
# Accuracy:  0.8448
# Precision: 0.8018
# Recall:    1.0000
# F1 Score:  0.8900
# AUC-ROC:   0.7913
# TN:   60 FN:    0
# TP:  174 FP:   43
#
# Malware Type: _
# ==========================
# Accuracy:  0.8607
# Precision: 0.8528
# Recall:    0.9733
# F1 Score:  0.9091
# AUC-ROC:   0.7751
# TN:   60 FN:    7
# TP:  255 FP:   44
#
# Malware Type: ransomware
# ==========================
# Accuracy:  0.6838
# Precision: 0.4342
# Recall:    1.0000
# F1 Score:  0.6055
# AUC-ROC:   0.7913
# TN:   60 FN:    0
# TP:   33 FP:   43
#
# Malware Type: spyware
# ==========================
# Accuracy:  0.6019
# Precision: 0.1042
# Recall:    1.0000
# F1 Score:  0.1887
# AUC-ROC:   0.7913
# TN:   60 FN:    0
# TP:    5 FP:   43
#
# Malware Type: virus
# ==========================
# Accuracy:  0.6126
# Precision: 0.1569
# Recall:    1.0000
# F1 Score:  0.2712
# AUC-ROC:   0.7913
# TN:   60 FN:    0
# TP:    8 FP:   43
#
# Malware Type: hacktool
# ==========================
# Accuracy:  0.5943
# Precision: 0.0652
# Recall:    1.0000
# F1 Score:  0.1224
# AUC-ROC:   0.7913
# TN:   60 FN:    0
# TP:    3 FP:   43
#
# Malware Type: miner
# ==========================
# Accuracy:  0.6126
# Precision: 0.1569
# Recall:    1.0000
# F1 Score:  0.2712
# AUC-ROC:   0.7913
# TN:   60 FN:    0
# TP:    8 FP:   43

# %%
print("3. Tuned LGBM TB\n")
for mal_type in DF_LGBM_TB['type'].unique().tolist():
    if(mal_type != 'benign'):
        evaluate_per_type(tuned_tb, DF_LGBM_TB, mal_type)
# Out:
# 3. Tuned LGBM TB
#
# Malware Type: trojan
# ==========================
# Accuracy:  0.9873
# Precision: 0.9870
# Recall:    1.0000
# F1 Score:  0.9935
# AUC-ROC:   0.7864
# TN:   59 FN:    0
# TP: 3351 FP:   44
#
# Malware Type: downloader
# ==========================
# Accuracy:  0.8717
# Precision: 0.8451
# Recall:    1.0000
# F1 Score:  0.9160
# AUC-ROC:   0.7864
# TN:   59 FN:    0
# TP:  240 FP:   44
#
# Malware Type: adware
# ==========================
# Accuracy:  0.8548
# Precision: 0.8197
# Recall:    1.0000
# F1 Score:  0.9009
# AUC-ROC:   0.7864
# TN:   59 FN:    0
# TP:  200 FP:   44
#
# Malware Type: pua
# ==========================
# Accuracy:  0.8412
# Precision: 0.7982
# Recall:    1.0000
# F1 Score:  0.8878
# AUC-ROC:   0.7864
# TN:   59 FN:    0
# TP:  174 FP:   44
#
# Malware Type: _
# ==========================
# Accuracy:  0.8716
# Precision: 0.8525
# Recall:    0.9924
# F1 Score:  0.9171
# AUC-ROC:   0.7798
# TN:   59 FN:    2
# TP:  260 FP:   45
#
# Malware Type: ransomware
# ==========================
# Accuracy:  0.6765
# Precision: 0.4286
# Recall:    1.0000
# F1 Score:  0.6000
# AUC-ROC:   0.7864
# TN:   59 FN:    0
# TP:   33 FP:   44
#
# Malware Type: spyware
# ==========================
# Accuracy:  0.5926
# Precision: 0.1020
# Recall:    1.0000
# F1 Score:  0.1852
# AUC-ROC:   0.7864
# TN:   59 FN:    0
# TP:    5 FP:   44
#
# Malware Type: virus
# ==========================
# Accuracy:  0.6036
# Precision: 0.1538
# Recall:    1.0000
# F1 Score:  0.2667
# AUC-ROC:   0.7864
# TN:   59 FN:    0
# TP:    8 FP:   44
#
# Malware Type: hacktool
# ==========================
# Accuracy:  0.5849
# Precision: 0.0638
# Recall:    1.0000
# F1 Score:  0.1200
# AUC-ROC:   0.7864
# TN:   59 FN:    0
# TP:    3 FP:   44
#
# Malware Type: miner
# ==========================
# Accuracy:  0.6036
# Precision: 0.1538
# Recall:    1.0000
# F1 Score:  0.2667
# AUC-ROC:   0.7864
# TN:   59 FN:    0
# TP:    8 FP:   44

# %%
print("4. Tuned LGBM IB\n")
for mal_type in DF_LGBM_IB['type'].unique().tolist():
    if(mal_type != 'benign'):
        evaluate_per_type(tuned_ib, DF_LGBM_IB, mal_type)
# Out:
# 4. Tuned LGBM IB
#
# Malware Type: trojan
# ==========================
# Accuracy:  0.9896
# Precision: 0.9894
# Recall:    1.0000
# F1 Score:  0.9947
# AUC-ROC:   0.8252
# TN:   67 FN:    0
# TP: 3351 FP:   36
#
# Malware Type: downloader
# ==========================
# Accuracy:  0.8950
# Precision: 0.8696
# Recall:    1.0000
# F1 Score:  0.9302
# AUC-ROC:   0.8252
# TN:   67 FN:    0
# TP:  240 FP:   36
#
# Malware Type: adware
# ==========================
# Accuracy:  0.8812
# Precision: 0.8475
# Recall:    1.0000
# F1 Score:  0.9174
# AUC-ROC:   0.8252
# TN:   67 FN:    0
# TP:  200 FP:   36
#
# Malware Type: pua
# ==========================
# Accuracy:  0.8700
# Precision: 0.8286
# Recall:    1.0000
# F1 Score:  0.9062
# AUC-ROC:   0.8252
# TN:   67 FN:    0
# TP:  174 FP:   36
#
# Malware Type: _
# ==========================
# Accuracy:  0.8770
# Precision: 0.8729
# Recall:    0.9695
# F1 Score:  0.9186
# AUC-ROC:   0.8068
# TN:   67 FN:    8
# TP:  254 FP:   37
#
# Malware Type: ransomware
# ==========================
# Accuracy:  0.7353
# Precision: 0.4783
# Recall:    1.0000
# F1 Score:  0.6471
# AUC-ROC:   0.8252
# TN:   67 FN:    0
# TP:   33 FP:   36
#
# Malware Type: spyware
# ==========================
# Accuracy:  0.6667
# Precision: 0.1220
# Recall:    1.0000
# F1 Score:  0.2174
# AUC-ROC:   0.8252
# TN:   67 FN:    0
# TP:    5 FP:   36
#
# Malware Type: virus
# ==========================
# Accuracy:  0.6757
# Precision: 0.1818
# Recall:    1.0000
# F1 Score:  0.3077
# AUC-ROC:   0.8252
# TN:   67 FN:    0
# TP:    8 FP:   36
#
# Malware Type: hacktool
# ==========================
# Accuracy:  0.6604
# Precision: 0.0769
# Recall:    1.0000
# F1 Score:  0.1429
# AUC-ROC:   0.8252
# TN:   67 FN:    0
# TP:    3 FP:   36
#
# Malware Type: miner
# ==========================
# Accuracy:  0.6757
# Precision: 0.1818
# Recall:    1.0000
# F1 Score:  0.3077
# AUC-ROC:   0.8252
# TN:   67 FN:    0
# TP:    8 FP:   36

# %% [markdown]
# ### 2.2 CatBoost

# %%
#Load Verified Test/Holdout Dataset
DF_CATB_TB = pd.read_csv('./Dataset/CATB_TB_Test.csv', low_memory=False)
DF_CATB_IB = pd.read_csv('./Dataset/CATB_IB_Test.csv', low_memory=False)

# DF_CATB_TB = DF_CATB_TB[DF_CATB_TB['type'] != '_']
# DF_CATB_IB = DF_CATB_IB[DF_CATB_IB['type'] != '_']
DF_CATB_TB = DF_CATB_TB.dropna()
DF_CATB_IB = DF_CATB_IB.dropna(subset=['type']) # Drops na only on type column
DF_CATB_IB.iloc[:,1:101] = DF_CATB_IB.iloc[:,1:101].astype('str')
DF_CATB_IB.replace("nan", "NaN", inplace=True)

default_tb = catb.CatBoostClassifier()
default_ib = catb.CatBoostClassifier()
tuned_tb = catb.CatBoostClassifier()
tuned_ib = catb.CatBoostClassifier()
default_tb = default_tb.load_model("./Models/CATB/Train_Default/RYZEN2c_CATB_TB.model", format='json')
default_ib = default_ib.load_model("./Models/CATB/Train_Default/RYZEN2c_CATB_IB.model", format='json')
tuned_tb = tuned_tb.load_model("./Models/CATB/Train_Tuned/TUNED_RYZEN2c_CATB_TB.model", format='json')
tuned_ib = tuned_ib.load_model("./Models/CATB/Train_Tuned/TUNED_RYZEN2c_CATB_IB.model", format='json')

display(DF_CATB_TB)
print("DF_CATB_TB:", DF_CATB_TB['type'].unique().tolist())
display(DF_CATB_IB)
print("DF_CATB_IB:", DF_CATB_IB['type'].unique().tolist())

'''
COLUMNS:
Features = [:, 1:101]
Label = [:, 0]
Hash = [:, 101]
Type 1 (malware type) = [:, 102]
'''
# Out:
#       malware                      t_0                      t_1  \
# 0           1                  NtClose                NtOpenKey
# 1           1             SetErrorMode            OleInitialize
# 2           1  GetSystemTimeAsFileTime  NtAllocateVirtualMemory
# 3           1            RegOpenKeyExA                NtOpenKey
# 4           1  GetSystemTimeAsFileTime               LdrLoadDll
# ...       ...                      ...                      ...
# 4383        1  GetSystemTimeAsFileTime               LdrLoadDll
# 4384        1               LdrLoadDll   LdrGetProcedureAddress
# 4385        1  GetSystemTimeAsFileTime               LdrLoadDll
# 4386        1               LdrLoadDll   NtProtectVirtualMemory
# 4387        1             SetErrorMode            OleInitialize
#
#                          t_2                      t_3                     t_4  \
# 0            NtQueryValueKey                  NtClose               NtOpenKey
# 1            LdrGetDllHandle               LdrLoadDll  LdrGetProcedureAddress
# 2        NtFreeVirtualMemory  NtAllocateVirtualMemory         LdrGetDllHandle
# 3            NtQueryValueKey                  NtClose               NtOpenKey
# 4     LdrGetProcedureAddress               LdrLoadDll  LdrGetProcedureAddress
# ...                      ...                      ...                     ...
# 4383  LdrGetProcedureAddress               LdrLoadDll  LdrGetProcedureAddress
# 4384              LdrLoadDll   LdrGetProcedureAddress              LdrLoadDll
# 4385  LdrGetProcedureAddress               LdrLoadDll  LdrGetProcedureAddress
# 4386              LdrLoadDll   NtProtectVirtualMemory          CoInitializeEx
# 4387         LdrGetDllHandle               LdrLoadDll  LdrGetProcedureAddress
#
#                          t_5                     t_6                      t_7  \
# 0            NtQueryValueKey                 NtClose          LdrGetDllHandle
# 1                 LdrLoadDll  LdrGetProcedureAddress               LdrLoadDll
# 2     LdrGetProcedureAddress         LdrGetDllHandle  NtAllocateVirtualMemory
# 3            NtQueryValueKey                 NtClose    NtQueryAttributesFile
# 4                 LdrLoadDll  LdrGetProcedureAddress               LdrLoadDll
# ...                      ...                     ...                      ...
# 4383             GetFileType  LdrGetProcedureAddress          LdrGetDllHandle
# 4384  LdrGetProcedureAddress              LdrLoadDll   LdrGetProcedureAddress
# 4385              LdrLoadDll  LdrGetProcedureAddress               LdrLoadDll
# 4386          NtCreateMutant         LdrGetDllHandle   LdrGetProcedureAddress
# 4387              LdrLoadDll  LdrGetProcedureAddress               LdrLoadDll
#
#                               t_8  ...                    t_92  \
# 0          LdrGetProcedureAddress  ...       LookupAccountSidW
# 1          LdrGetProcedureAddress  ...     GetSystemDirectoryW
# 2     SetUnhandledExceptionFilter  ...  LdrGetProcedureAddress
# 3                     LoadStringA  ...            NtCreateFile
# 4          LdrGetProcedureAddress  ...           RegOpenKeyExW
# ...                           ...  ...                     ...
# 4383       LdrGetProcedureAddress  ...             NtOpenKeyEx
# 4384                   LdrLoadDll  ...            LoadResource
# 4385       LdrGetProcedureAddress  ...           RegOpenKeyExW
# 4386              LdrGetDllHandle  ...             RegCloseKey
# 4387       LdrGetProcedureAddress  ...         LdrGetDllHandle
#
#                         t_93                    t_94                     t_95  \
# 0                 LdrLoadDll  LdrGetProcedureAddress               LdrLoadDll
# 1              RegOpenKeyExW              LdrLoadDll   LdrGetProcedureAddress
# 2            LdrGetDllHandle  LdrGetProcedureAddress  NtAllocateVirtualMemory
# 3            NtCreateSection      NtMapViewOfSection                  NtClose
# 4           RegQueryValueExW           RegOpenKeyExW         RegQueryValueExW
# ...                      ...                     ...                      ...
# 4383              LdrLoadDll  LdrGetProcedureAddress               LdrLoadDll
# 4384         FindResourceExW            LoadResource          FindResourceExW
# 4385        RegQueryValueExW           RegOpenKeyExW         RegQueryValueExW
# 4386              NtQueryKey                 NtClose              NtOpenKeyEx
# 4387  LdrGetProcedureAddress              LdrLoadDll   LdrGetProcedureAddress
#
#                         t_96                      t_97  \
# 0     LdrGetProcedureAddress                LdrLoadDll
# 1           RegQueryValueExW               RegCloseKey
# 2            LdrGetDllHandle    LdrGetProcedureAddress
# 3           GetSystemMetrics   NtAllocateVirtualMemory
# 4              RegOpenKeyExW          RegQueryValueExW
# ...                      ...                       ...
# 4383  LdrGetProcedureAddress             GetSystemInfo
# 4384            LoadResource           FindResourceExW
# 4385           RegOpenKeyExW          RegQueryValueExW
# 4386  LdrGetProcedureAddress                NtQueryKey
# 4387              LdrLoadDll  NtQuerySystemInformation
#
#                         t_98                        t_99  \
# 0     LdrGetProcedureAddress             LdrGetDllHandle
# 1              RegOpenKeyExW            RegQueryValueExW
# 2              NtOpenProcess                     NtClose
# 3              CreateActCtxW  GetSystemWindowsDirectoryW
# 4              RegOpenKeyExW            RegQueryValueExW
# ...                      ...                         ...
# 4383              LdrLoadDll      LdrGetProcedureAddress
# 4384            LoadResource             FindResourceExW
# 4385           RegOpenKeyExW            RegQueryValueExW
# 4386                 NtClose                 NtOpenKeyEx
# 4387        CoCreateInstance               NtOpenSection
#
#                                   hash        type
# 0     f0f8ba4c3d750a4ce2deea48152a33d4      trojan
# 1     39b2d87c1adb582fbcacc3a56e274d48      trojan
# 2     429236cdeb63d68bf48a3b48b0a34612  downloader
# 3     46079cbf0bcfe8fab9894b4ec88bece3      trojan
# 4     303ceda3f52afa9b69ed4f97fec2c895      trojan
# ...                                ...         ...
# 4383  ace1fb315abc4e4a10624c8b03f917aa      trojan
# 4384  f8948ed47902c6400b086a867685c107      trojan
# 4385  131e9e0e7ce851fd4be463c32e025c7b      trojan
# 4386  c85d6c224b59b3ce76698e9d5aacd3ae      trojan
# 4387  673c18473d60716147397eab14427a59           _
#
# [4388 rows x 103 columns]
# DF_CATB_TB: ['trojan', 'downloader', 'adware', 'pua', '_', 'ransomware', 'benign', 'spyware', 'virus', 'hacktool', 'miner']
#       malware                      t_0                      t_1  \
# 0           1                  NtClose                NtOpenKey
# 1           1             SetErrorMode            OleInitialize
# 2           1  GetSystemTimeAsFileTime  NtAllocateVirtualMemory
# 3           1            RegOpenKeyExA                NtOpenKey
# 4           1  GetSystemTimeAsFileTime               LdrLoadDll
# ...       ...                      ...                      ...
# 4383        1  GetSystemTimeAsFileTime               LdrLoadDll
# 4384        1               LdrLoadDll   LdrGetProcedureAddress
# 4385        1  GetSystemTimeAsFileTime               LdrLoadDll
# 4386        1               LdrLoadDll   NtProtectVirtualMemory
# 4387        1             SetErrorMode            OleInitialize
#
#                          t_2              t_3                          t_4  \
# 0            NtQueryValueKey  LdrGetDllHandle       LdrGetProcedureAddress
# 1            LdrGetDllHandle       LdrLoadDll       LdrGetProcedureAddress
# 2        NtFreeVirtualMemory  LdrGetDllHandle       LdrGetProcedureAddress
# 3            NtQueryValueKey          NtClose        NtQueryAttributesFile
# 4     LdrGetProcedureAddress  LdrGetDllHandle  SetUnhandledExceptionFilter
# ...                      ...              ...                          ...
# 4383  LdrGetProcedureAddress      GetFileType              LdrGetDllHandle
# 4384  NtProtectVirtualMemory          NtClose                    NtOpenKey
# 4385  LdrGetProcedureAddress  LdrGetDllHandle  SetUnhandledExceptionFilter
# 4386          CoInitializeEx   NtCreateMutant              LdrGetDllHandle
# 4387         LdrGetDllHandle       LdrLoadDll       LdrGetProcedureAddress
#
#                               t_5                      t_6              t_7  \
# 0                   GetSystemInfo  NtAllocateVirtualMemory    RegOpenKeyExW
# 1                   NtOpenSection       NtMapViewOfSection    RegOpenKeyExW
# 2     SetUnhandledExceptionFilter               LdrLoadDll    RegOpenKeyExA
# 3                     LoadStringA  NtAllocateVirtualMemory  LdrGetDllHandle
# 4            CryptAcquireContextW                NtOpenKey  NtQueryValueKey
# ...                           ...                      ...              ...
# 4383  SetUnhandledExceptionFilter                  NtClose        NtOpenKey
# 4384              NtQueryValueKey          LdrGetDllHandle    GetSystemInfo
# 4385         CryptAcquireContextW                NtOpenKey  NtQueryValueKey
# 4386       LdrGetProcedureAddress                NtOpenKey          NtClose
# 4387                NtOpenSection       NtMapViewOfSection    RegOpenKeyExW
#
#                           t_8  ... t_92 t_93 t_94 t_95 t_96 t_97 t_98 t_99  \
# 0            FindFirstFileExW  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1            RegQueryValueExW  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2            RegQueryValueExA  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3      LdrGetProcedureAddress  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4                     NtClose  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                       ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 4383          NtQueryValueKey  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4384  NtAllocateVirtualMemory  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4385                  NtClose  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4386            NtOpenSection  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4387         RegQueryValueExW  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                   hash        type
# 0     f0f8ba4c3d750a4ce2deea48152a33d4      trojan
# 1     39b2d87c1adb582fbcacc3a56e274d48      trojan
# 2     429236cdeb63d68bf48a3b48b0a34612  downloader
# 3     46079cbf0bcfe8fab9894b4ec88bece3      trojan
# 4     303ceda3f52afa9b69ed4f97fec2c895      trojan
# ...                                ...         ...
# 4383  ace1fb315abc4e4a10624c8b03f917aa      trojan
# 4384  f8948ed47902c6400b086a867685c107      trojan
# 4385  131e9e0e7ce851fd4be463c32e025c7b      trojan
# 4386  c85d6c224b59b3ce76698e9d5aacd3ae      trojan
# 4387  673c18473d60716147397eab14427a59           _
#
# [4388 rows x 103 columns]
# DF_CATB_IB: ['trojan', 'downloader', 'adware', 'pua', '_', 'ransomware', 'benign', 'spyware', 'virus', 'hacktool', 'miner']
# '\nCOLUMNS:\nFeatures = [:, 1:101]\nLabel = [:, 0]\nHash = [:, 101]\nType 1 (malware type) = [:, 102]\n'

# %%
print("1. Default CatBoost TB\n")
for mal_type in DF_CATB_TB['type'].unique().tolist():
    if(mal_type != 'benign'):
        evaluate_per_type(default_tb, DF_CATB_TB, mal_type)
# Out:
# 1. Default CatBoost TB
#
# Malware Type: trojan
# ==========================
# Accuracy:  0.9873
# Precision: 0.9876
# Recall:    0.9994
# F1 Score:  0.9935
# AUC-ROC:   0.7958
# TN:   61 FN:    2
# TP: 3349 FP:   42
#
# Malware Type: downloader
# ==========================
# Accuracy:  0.8776
# Precision: 0.8511
# Recall:    1.0000
# F1 Score:  0.9195
# AUC-ROC:   0.7961
# TN:   61 FN:    0
# TP:  240 FP:   42
#
# Malware Type: adware
# ==========================
# Accuracy:  0.8614
# Precision: 0.8264
# Recall:    1.0000
# F1 Score:  0.9050
# AUC-ROC:   0.7961
# TN:   61 FN:    0
# TP:  200 FP:   42
#
# Malware Type: pua
# ==========================
# Accuracy:  0.8412
# Precision: 0.8037
# Recall:    0.9885
# F1 Score:  0.8866
# AUC-ROC:   0.7904
# TN:   61 FN:    2
# TP:  172 FP:   42
#
# Malware Type: _
# ==========================
# Accuracy:  0.8689
# Precision: 0.8567
# Recall:    0.9809
# F1 Score:  0.9146
# AUC-ROC:   0.7837
# TN:   61 FN:    5
# TP:  257 FP:   43
#
# Malware Type: ransomware
# ==========================
# Accuracy:  0.6912
# Precision: 0.4400
# Recall:    1.0000
# F1 Score:  0.6111
# AUC-ROC:   0.7961
# TN:   61 FN:    0
# TP:   33 FP:   42
#
# Malware Type: spyware
# ==========================
# Accuracy:  0.6111
# Precision: 0.1064
# Recall:    1.0000
# F1 Score:  0.1923
# AUC-ROC:   0.7961
# TN:   61 FN:    0
# TP:    5 FP:   42
#
# Malware Type: virus
# ==========================
# Accuracy:  0.6216
# Precision: 0.1600
# Recall:    1.0000
# F1 Score:  0.2759
# AUC-ROC:   0.7961
# TN:   61 FN:    0
# TP:    8 FP:   42
#
# Malware Type: hacktool
# ==========================
# Accuracy:  0.6038
# Precision: 0.0667
# Recall:    1.0000
# F1 Score:  0.1250
# AUC-ROC:   0.7961
# TN:   61 FN:    0
# TP:    3 FP:   42
#
# Malware Type: miner
# ==========================
# Accuracy:  0.6216
# Precision: 0.1600
# Recall:    1.0000
# F1 Score:  0.2759
# AUC-ROC:   0.7961
# TN:   61 FN:    0
# TP:    8 FP:   42

# %%
print("2. Default CatBoost IB\n")
for mal_type in DF_CATB_TB['type'].unique().tolist():
    if(mal_type != 'benign'):
        evaluate_per_type(default_ib, DF_CATB_IB, mal_type)
# Out:
# 2. Default CatBoost IB
#
# Malware Type: trojan
# ==========================
# Accuracy:  0.9896
# Precision: 0.9902
# Recall:    0.9991
# F1 Score:  0.9947
# AUC-ROC:   0.8394
# TN:   70 FN:    3
# TP: 3348 FP:   33
#
# Malware Type: downloader
# ==========================
# Accuracy:  0.9038
# Precision: 0.8791
# Recall:    1.0000
# F1 Score:  0.9357
# AUC-ROC:   0.8398
# TN:   70 FN:    0
# TP:  240 FP:   33
#
# Malware Type: adware
# ==========================
# Accuracy:  0.8911
# Precision: 0.8584
# Recall:    1.0000
# F1 Score:  0.9238
# AUC-ROC:   0.8398
# TN:   70 FN:    0
# TP:  200 FP:   33
#
# Malware Type: pua
# ==========================
# Accuracy:  0.8809
# Precision: 0.8406
# Recall:    1.0000
# F1 Score:  0.9134
# AUC-ROC:   0.8398
# TN:   70 FN:    0
# TP:  174 FP:   33
#
# Malware Type: _
# ==========================
# Accuracy:  0.8852
# Precision: 0.8819
# Recall:    0.9695
# F1 Score:  0.9236
# AUC-ROC:   0.8213
# TN:   70 FN:    8
# TP:  254 FP:   34
#
# Malware Type: ransomware
# ==========================
# Accuracy:  0.7574
# Precision: 0.5000
# Recall:    1.0000
# F1 Score:  0.6667
# AUC-ROC:   0.8398
# TN:   70 FN:    0
# TP:   33 FP:   33
#
# Malware Type: spyware
# ==========================
# Accuracy:  0.6944
# Precision: 0.1316
# Recall:    1.0000
# F1 Score:  0.2326
# AUC-ROC:   0.8398
# TN:   70 FN:    0
# TP:    5 FP:   33
#
# Malware Type: virus
# ==========================
# Accuracy:  0.7027
# Precision: 0.1951
# Recall:    1.0000
# F1 Score:  0.3265
# AUC-ROC:   0.8398
# TN:   70 FN:    0
# TP:    8 FP:   33
#
# Malware Type: hacktool
# ==========================
# Accuracy:  0.6887
# Precision: 0.0833
# Recall:    1.0000
# F1 Score:  0.1538
# AUC-ROC:   0.8398
# TN:   70 FN:    0
# TP:    3 FP:   33
#
# Malware Type: miner
# ==========================
# Accuracy:  0.7027
# Precision: 0.1951
# Recall:    1.0000
# F1 Score:  0.3265
# AUC-ROC:   0.8398
# TN:   70 FN:    0
# TP:    8 FP:   33

# %%
print("3. Tuned CatBoost TB\n")
for mal_type in DF_CATB_TB['type'].unique().tolist():
    if(mal_type != 'benign'):
        evaluate_per_type(tuned_tb, DF_CATB_TB, mal_type)
# Out:
# 3. Tuned CatBoost TB
#
# Malware Type: trojan
# ==========================
# Accuracy:  0.9852
# Precision: 0.9859
# Recall:    0.9991
# F1 Score:  0.9924
# AUC-ROC:   0.7665
# TN:   55 FN:    3
# TP: 3348 FP:   48
#
# Malware Type: downloader
# ==========================
# Accuracy:  0.8601
# Precision: 0.8333
# Recall:    1.0000
# F1 Score:  0.9091
# AUC-ROC:   0.7670
# TN:   55 FN:    0
# TP:  240 FP:   48
#
# Malware Type: adware
# ==========================
# Accuracy:  0.8416
# Precision: 0.8065
# Recall:    1.0000
# F1 Score:  0.8929
# AUC-ROC:   0.7670
# TN:   55 FN:    0
# TP:  200 FP:   48
#
# Malware Type: pua
# ==========================
# Accuracy:  0.8231
# Precision: 0.7828
# Recall:    0.9943
# F1 Score:  0.8759
# AUC-ROC:   0.7641
# TN:   55 FN:    1
# TP:  173 FP:   48
#
# Malware Type: _
# ==========================
# Accuracy:  0.8525
# Precision: 0.8399
# Recall:    0.9809
# F1 Score:  0.9049
# AUC-ROC:   0.7549
# TN:   55 FN:    5
# TP:  257 FP:   49
#
# Malware Type: ransomware
# ==========================
# Accuracy:  0.6471
# Precision: 0.4074
# Recall:    1.0000
# F1 Score:  0.5789
# AUC-ROC:   0.7670
# TN:   55 FN:    0
# TP:   33 FP:   48
#
# Malware Type: spyware
# ==========================
# Accuracy:  0.5556
# Precision: 0.0943
# Recall:    1.0000
# F1 Score:  0.1724
# AUC-ROC:   0.7670
# TN:   55 FN:    0
# TP:    5 FP:   48
#
# Malware Type: virus
# ==========================
# Accuracy:  0.5676
# Precision: 0.1429
# Recall:    1.0000
# F1 Score:  0.2500
# AUC-ROC:   0.7670
# TN:   55 FN:    0
# TP:    8 FP:   48
#
# Malware Type: hacktool
# ==========================
# Accuracy:  0.5472
# Precision: 0.0588
# Recall:    1.0000
# F1 Score:  0.1111
# AUC-ROC:   0.7670
# TN:   55 FN:    0
# TP:    3 FP:   48
#
# Malware Type: miner
# ==========================
# Accuracy:  0.5586
# Precision: 0.1273
# Recall:    0.8750
# F1 Score:  0.2222
# AUC-ROC:   0.7045
# TN:   55 FN:    1
# TP:    7 FP:   48

# %%
print("4. Tuned CatBoost IB\n")
for mal_type in DF_CATB_TB['type'].unique().tolist():
    if(mal_type != 'benign'):
        evaluate_per_type(tuned_ib, DF_CATB_IB, mal_type)
# Out:
# 4. Tuned CatBoost IB
#
# Malware Type: trojan
# ==========================
# Accuracy:  0.9896
# Precision: 0.9899
# Recall:    0.9994
# F1 Score:  0.9947
# AUC-ROC:   0.8347
# TN:   69 FN:    2
# TP: 3349 FP:   34
#
# Malware Type: downloader
# ==========================
# Accuracy:  0.9009
# Precision: 0.8759
# Recall:    1.0000
# F1 Score:  0.9339
# AUC-ROC:   0.8350
# TN:   69 FN:    0
# TP:  240 FP:   34
#
# Malware Type: adware
# ==========================
# Accuracy:  0.8878
# Precision: 0.8547
# Recall:    1.0000
# F1 Score:  0.9217
# AUC-ROC:   0.8350
# TN:   69 FN:    0
# TP:  200 FP:   34
#
# Malware Type: pua
# ==========================
# Accuracy:  0.8773
# Precision: 0.8365
# Recall:    1.0000
# F1 Score:  0.9110
# AUC-ROC:   0.8350
# TN:   69 FN:    0
# TP:  174 FP:   34
#
# Malware Type: _
# ==========================
# Accuracy:  0.8798
# Precision: 0.8785
# Recall:    0.9656
# F1 Score:  0.9200
# AUC-ROC:   0.8146
# TN:   69 FN:    9
# TP:  253 FP:   35
#
# Malware Type: ransomware
# ==========================
# Accuracy:  0.7500
# Precision: 0.4925
# Recall:    1.0000
# F1 Score:  0.6600
# AUC-ROC:   0.8350
# TN:   69 FN:    0
# TP:   33 FP:   34
#
# Malware Type: spyware
# ==========================
# Accuracy:  0.6852
# Precision: 0.1282
# Recall:    1.0000
# F1 Score:  0.2273
# AUC-ROC:   0.8350
# TN:   69 FN:    0
# TP:    5 FP:   34
#
# Malware Type: virus
# ==========================
# Accuracy:  0.6937
# Precision: 0.1905
# Recall:    1.0000
# F1 Score:  0.3200
# AUC-ROC:   0.8350
# TN:   69 FN:    0
# TP:    8 FP:   34
#
# Malware Type: hacktool
# ==========================
# Accuracy:  0.6792
# Precision: 0.0811
# Recall:    1.0000
# F1 Score:  0.1500
# AUC-ROC:   0.8350
# TN:   69 FN:    0
# TP:    3 FP:   34
#
# Malware Type: miner
# ==========================
# Accuracy:  0.6937
# Precision: 0.1905
# Recall:    1.0000
# F1 Score:  0.3200
# AUC-ROC:   0.8350
# TN:   69 FN:    0
# TP:    8 FP:   34
