# %% [markdown]
# # Repeated Holdout Test
#
# **Objectives**
# - Load the Model(s)
# - Run predictions on the model using the Training/Validation & Holdout/Test* data split using Stratified K-Folds CV (params: k=5 & random_seed=1)
# - Record the performance of the models (e.g., accuracy, precision, recall, ROC-AUC, etc.) on every CV instance for use in analysis to determine possible occurence of overfitting.
#
# *The addition of the use of Holdout/Test split here acts as an addition to the original plan of only using Training/Validation data splits.*
#
# **Essentially, this answers the question:** `Is the model overfitted from the training data?`

# %%
import pandas as pd

import lightgbm as lgbm
import catboost as catb
 
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report

from joblib import load

import warnings
warnings.filterwarnings("ignore")

# %%
DF_LGBM_TB_TRAIN = pd.read_csv('./Dataset/LGBM_TB.csv', low_memory=False) #<== Point these to the appropriate Training+Validation datasets.
DF_LGBM_IB_TRAIN = pd.read_csv('./Dataset/LGBM_IB.csv', low_memory=False)
DF_LGBM_TB_TEST = pd.read_csv('./Dataset/LGBM_TB_Test.csv', low_memory=False)
DF_LGBM_IB_TEST = pd.read_csv('./Dataset/LGBM_IB_Test.csv', low_memory=False)
display(DF_LGBM_TB_TRAIN.head())
display(DF_LGBM_IB_TRAIN.head())
display(DF_LGBM_TB_TEST.head())
display(DF_LGBM_IB_TEST.head())

DF_CATB_TB_TRAIN = pd.read_csv('./Dataset/CATB_TB.csv', low_memory=False)
DF_CATB_IB_TRAIN = pd.read_csv('./Dataset/CATB_IB.csv', low_memory=False)
DF_CATB_TB_TEST = pd.read_csv('./Dataset/CATB_TB_Test.csv', low_memory=False)
DF_CATB_IB_TEST = pd.read_csv('./Dataset/CATB_IB_Test.csv', low_memory=False)

DF_CATB_IB_TRAIN.iloc[:,1:101] = DF_CATB_IB_TRAIN.iloc[:,1:101].astype('str')
DF_CATB_IB_TRAIN.replace("nan", "NaN", inplace=True)
DF_CATB_IB_TEST.iloc[:,1:101] = DF_CATB_IB_TEST.iloc[:,1:101].astype('str')
DF_CATB_IB_TEST.replace("nan", "NaN", inplace=True)

display(DF_CATB_TB_TRAIN.head())
display(DF_CATB_IB_TRAIN.head())
display(DF_CATB_TB_TEST.head())
display(DF_CATB_IB_TEST.head())
# Out:
#    malware  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  t_8  ...  t_90  t_91  \
# 0        1  112  274  158  215  274  158  215  298   76  ...   117    71
# 1        1   82  240  117  240  117  240  117  240  117  ...    40   209
# 2        1   82   86   82   37   70   37  240  117  260  ...   198   215
# 3        1   82  240  117  240  117  240  117  240  117  ...   141   260
# 4        1  286  110  172  240  117  240  117  240  117  ...   260   141
#
#    t_92  t_93  t_94  t_95  t_96  t_97  t_98  t_99
# 0   297   135   171   215    35   208    56    71
# 1   260   141   260   141   260   141   260   141
# 2   178   215   260    65   260   141    65    20
# 3   141   260   141   260   141   260   141   260
# 4    65    86    99    71   215   240   117   240
#
# [5 rows x 101 columns]
#    malware  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  t_8  ...  t_90  t_91  \
# 0        1  112  274  158  215  298   76  208  172  117  ...   307   307
# 1        1   82  240  117  172   16   11  274  158  215  ...   307   307
# 2        1   82   86   37   70  240  117  260   40  209  ...   307   307
# 3        1   82  240  117  172   16   11  274  158  215  ...   307   307
# 4        1  286  110  172  240  117  106  171  260  141  ...   307   307
#
#    t_92  t_93  t_94  t_95  t_96  t_97  t_98  t_99
# 0   307   307   307   307   307   307   307   307
# 1   307   307   307   307   307   307   307   307
# 2   307   307   307   307   307   307   307   307
# 3   307   307   307   307   307   307   307   307
# 4   307   307   307   307   307   307   307   307
#
# [5 rows x 101 columns]
#    malware  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  t_8  ...  t_92  t_93  \
# 0        1  208  172  240  117  240  262  112  123   65  ...   274   215
# 1        1  112  274  158  215  274  158  215  298   76  ...   297   135
# 2        1  215  274  158  215  274  158  215  172  117  ...    15   240
# 3        1   82  240  117  240  117  240  117  240  117  ...   208    93
# 4        1  112  274  158  215  274  158  215  298   76  ...   297   135
#
#    t_94  t_95  t_96  t_97  t_98  t_99                              hash  \
# 0   274   215   274   215   274   215  4e270486b92ccff8afa59935ba4f5adc
# 1   171   215    35   208    56    71  d92d0f24e15384541a0c3c72424fe3a8
# 2   117   240   117   240   117   172  1dcb9bd8dcdd50f6d07035ea895ecfd1
# 3   208    16    31   215   108   208  24dd4677c14eb5828bda78749fded6b8
# 4   171   215    35   208    56    71  cc5d38cb80faaf60d8efabecdc04f832
#
#      type
# 0  trojan
# 1  trojan
# 2  trojan
# 3     pua
# 4  trojan
#
# [5 rows x 103 columns]
#    malware  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  t_8  ...  t_92  t_93  \
# 0        1  208  172  240  117  262  112  123   65  274  ...   307   307
# 1        1  112  274  158  215  298   76  208  172  117  ...   307   307
# 2        1  215  274  158  172  117  198  208  260  257  ...   307   307
# 3        1   82  240  117   93   16  228  208  198   86  ...   307   307
# 4        1  112  274  158  215  298   76  208  172  117  ...   307   307
#
#    t_94  t_95  t_96  t_97  t_98  t_99                              hash  \
# 0   307   307   307   307   307   307  4e270486b92ccff8afa59935ba4f5adc
# 1   307   307   307   307   307   307  d92d0f24e15384541a0c3c72424fe3a8
# 2   307   307   307   307   307   307  1dcb9bd8dcdd50f6d07035ea895ecfd1
# 3   307   307   307   307   307   307  24dd4677c14eb5828bda78749fded6b8
# 4   307   307   307   307   307   307  cc5d38cb80faaf60d8efabecdc04f832
#
#      type
# 0  trojan
# 1  trojan
# 2  trojan
# 3     pua
# 4  trojan
#
# [5 rows x 103 columns]
#    malware                      t_0             t_1                      t_2  \
# 0        1            RegOpenKeyExA       NtOpenKey          NtQueryValueKey
# 1        1  GetSystemTimeAsFileTime      LdrLoadDll   LdrGetProcedureAddress
# 2        1  GetSystemTimeAsFileTime  NtCreateMutant  GetSystemTimeAsFileTime
# 3        1  GetSystemTimeAsFileTime      LdrLoadDll   LdrGetProcedureAddress
# 4        1             SetErrorMode   OleInitialize          LdrGetDllHandle
#
#            t_3                     t_4              t_5  \
# 0      NtClose               NtOpenKey  NtQueryValueKey
# 1   LdrLoadDll  LdrGetProcedureAddress       LdrLoadDll
# 2  NtOpenKeyEx              NtQueryKey      NtOpenKeyEx
# 3   LdrLoadDll  LdrGetProcedureAddress       LdrLoadDll
# 4   LdrLoadDll  LdrGetProcedureAddress       LdrLoadDll
#
#                       t_6                     t_7                     t_8  \
# 0                 NtClose   NtQueryAttributesFile             LoadStringA
# 1  LdrGetProcedureAddress              LdrLoadDll  LdrGetProcedureAddress
# 2              LdrLoadDll  LdrGetProcedureAddress           RegOpenKeyExW
# 3  LdrGetProcedureAddress              LdrLoadDll  LdrGetProcedureAddress
# 4  LdrGetProcedureAddress              LdrLoadDll  LdrGetProcedureAddress
#
#    ...                    t_90                        t_91  \
# 0  ...  LdrGetProcedureAddress  GetSystemWindowsDirectoryW
# 1  ...        RegQueryInfoKeyW               RegEnumKeyExW
# 2  ...           GetSystemInfo                     NtClose
# 3  ...        RegQueryValueExW               RegOpenKeyExW
# 4  ...           RegOpenKeyExW            RegQueryValueExW
#
#                    t_92              t_93                 t_94  \
# 0          NtCreateFile   NtCreateSection   NtMapViewOfSection
# 1         RegOpenKeyExW  RegQueryValueExW        RegOpenKeyExW
# 2  NtUnmapViewOfSection           NtClose        RegOpenKeyExW
# 3      RegQueryValueExW     RegOpenKeyExW     RegQueryValueExW
# 4           RegCloseKey    NtCreateMutant  GetNativeSystemInfo
#
#                          t_95              t_96                     t_97  \
# 0                     NtClose  GetSystemMetrics  NtAllocateVirtualMemory
# 1            RegQueryValueExW     RegOpenKeyExW         RegQueryValueExW
# 2                 RegCloseKey     RegOpenKeyExW         RegQueryValueExW
# 3               RegOpenKeyExW  RegQueryValueExW            RegOpenKeyExW
# 4  GetSystemWindowsDirectoryW           NtClose               LdrLoadDll
#
#                      t_98                        t_99
# 0           CreateActCtxW  GetSystemWindowsDirectoryW
# 1           RegOpenKeyExW            RegQueryValueExW
# 2             RegCloseKey                  NtOpenFile
# 3        RegQueryValueExW               RegOpenKeyExW
# 4  LdrGetProcedureAddress                  LdrLoadDll
#
# [5 rows x 101 columns]
#    malware                      t_0             t_1                     t_2  \
# 0        1            RegOpenKeyExA       NtOpenKey         NtQueryValueKey
# 1        1  GetSystemTimeAsFileTime      LdrLoadDll  LdrGetProcedureAddress
# 2        1  GetSystemTimeAsFileTime  NtCreateMutant             NtOpenKeyEx
# 3        1  GetSystemTimeAsFileTime      LdrLoadDll  LdrGetProcedureAddress
# 4        1             SetErrorMode   OleInitialize         LdrGetDllHandle
#
#                t_3                          t_4                     t_5  \
# 0          NtClose        NtQueryAttributesFile             LoadStringA
# 1  LdrGetDllHandle  SetUnhandledExceptionFilter    CryptAcquireContextW
# 2       NtQueryKey                   LdrLoadDll  LdrGetProcedureAddress
# 3  LdrGetDllHandle  SetUnhandledExceptionFilter    CryptAcquireContextW
# 4       LdrLoadDll       LdrGetProcedureAddress           NtOpenSection
#
#                        t_6               t_7                     t_8  ...  \
# 0  NtAllocateVirtualMemory   LdrGetDllHandle  LdrGetProcedureAddress  ...
# 1                NtOpenKey   NtQueryValueKey                 NtClose  ...
# 2            RegOpenKeyExW  RegQueryInfoKeyW           RegEnumKeyExW  ...
# 3                NtOpenKey   NtQueryValueKey                 NtClose  ...
# 4       NtMapViewOfSection     RegOpenKeyExW        RegQueryValueExW  ...
#
#   t_90 t_91 t_92 t_93 t_94 t_95 t_96 t_97 t_98 t_99
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 101 columns]
#    malware                      t_0              t_1                     t_2  \
# 0        1  NtAllocateVirtualMemory  LdrGetDllHandle              LdrLoadDll
# 1        1            RegOpenKeyExA        NtOpenKey         NtQueryValueKey
# 2        1                  NtClose        NtOpenKey         NtQueryValueKey
# 3        1  GetSystemTimeAsFileTime       LdrLoadDll  LdrGetProcedureAddress
# 4        1            RegOpenKeyExA        NtOpenKey         NtQueryValueKey
#
#                       t_3                     t_4                       t_5  \
# 0  LdrGetProcedureAddress              LdrLoadDll  NtQuerySystemInformation
# 1                 NtClose               NtOpenKey           NtQueryValueKey
# 2                 NtClose               NtOpenKey           NtQueryValueKey
# 3              LdrLoadDll  LdrGetProcedureAddress                LdrLoadDll
# 4                 NtClose               NtOpenKey           NtQueryValueKey
#
#                       t_6                    t_7                     t_8  ...  \
# 0           RegOpenKeyExA       RegQueryValueExA             RegCloseKey  ...
# 1                 NtClose  NtQueryAttributesFile             LoadStringA  ...
# 2                 NtClose        LdrGetDllHandle  LdrGetProcedureAddress  ...
# 3  LdrGetProcedureAddress             LdrLoadDll  LdrGetProcedureAddress  ...
# 4                 NtClose  NtQueryAttributesFile             LoadStringA  ...
#
#                       t_92             t_93                     t_94  \
# 0                NtOpenKey          NtClose                NtOpenKey
# 1             NtCreateFile  NtCreateSection       NtMapViewOfSection
# 2        LookupAccountSidW       LdrLoadDll   LdrGetProcedureAddress
# 3  NtAllocateVirtualMemory      GetFileType  NtAllocateVirtualMemory
# 4             NtCreateFile  NtCreateSection       NtMapViewOfSection
#
#                           t_95                    t_96  \
# 0                      NtClose               NtOpenKey
# 1                      NtClose        GetSystemMetrics
# 2                   LdrLoadDll  LdrGetProcedureAddress
# 3  SetUnhandledExceptionFilter          CoInitializeEx
# 4                      NtClose        GetSystemMetrics
#
#                       t_97                    t_98  \
# 0                  NtClose               NtOpenKey
# 1  NtAllocateVirtualMemory           CreateActCtxW
# 2               LdrLoadDll  LdrGetProcedureAddress
# 3                  NtClose              WSAStartup
# 4  NtAllocateVirtualMemory           CreateActCtxW
#
#                          t_99                              hash    type
# 0                     NtClose  4e270486b92ccff8afa59935ba4f5adc  trojan
# 1  GetSystemWindowsDirectoryW  d92d0f24e15384541a0c3c72424fe3a8  trojan
# 2             LdrGetDllHandle  1dcb9bd8dcdd50f6d07035ea895ecfd1  trojan
# 3     NtAllocateVirtualMemory  24dd4677c14eb5828bda78749fded6b8     pua
# 4  GetSystemWindowsDirectoryW  cc5d38cb80faaf60d8efabecdc04f832  trojan
#
# [5 rows x 103 columns]
#    malware                      t_0              t_1                     t_2  \
# 0        1  NtAllocateVirtualMemory  LdrGetDllHandle              LdrLoadDll
# 1        1            RegOpenKeyExA        NtOpenKey         NtQueryValueKey
# 2        1                  NtClose        NtOpenKey         NtQueryValueKey
# 3        1  GetSystemTimeAsFileTime       LdrLoadDll  LdrGetProcedureAddress
# 4        1            RegOpenKeyExA        NtOpenKey         NtQueryValueKey
#
#                       t_3                          t_4  \
# 0  LdrGetProcedureAddress     NtQuerySystemInformation
# 1                 NtClose        NtQueryAttributesFile
# 2         LdrGetDllHandle       LdrGetProcedureAddress
# 3             GetFileType  SetUnhandledExceptionFilter
# 4                 NtClose        NtQueryAttributesFile
#
#                       t_5                      t_6              t_7  \
# 0           RegOpenKeyExA         RegQueryValueExA      RegCloseKey
# 1             LoadStringA  NtAllocateVirtualMemory  LdrGetDllHandle
# 2           GetSystemInfo  NtAllocateVirtualMemory    RegOpenKeyExW
# 3  NtProtectVirtualMemory  NtAllocateVirtualMemory    GetSystemInfo
# 4             LoadStringA  NtAllocateVirtualMemory  LdrGetDllHandle
#
#                       t_8  ... t_92 t_93 t_94 t_95 t_96 t_97 t_98 t_99  \
# 0               NtOpenKey  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1  LdrGetProcedureAddress  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2        FindFirstFileExW  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3          NtCreateMutant  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  LdrGetProcedureAddress  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                hash    type
# 0  4e270486b92ccff8afa59935ba4f5adc  trojan
# 1  d92d0f24e15384541a0c3c72424fe3a8  trojan
# 2  1dcb9bd8dcdd50f6d07035ea895ecfd1  trojan
# 3  24dd4677c14eb5828bda78749fded6b8     pua
# 4  cc5d38cb80faaf60d8efabecdc04f832  trojan
#
# [5 rows x 103 columns]

# %% [markdown]
# ### 0. Defining a helper function for evaluation

# %%
def stratified_kfolds_eval(train_set, test_set, model):
    features = train_set.drop('malware', axis=1)
    labels = train_set['malware']
    kfolds = StratifiedKFold(n_splits=5, shuffle=True, random_state=1)
    print('HOLDOUT FOLD PREDICTIONS')
    print('-------------------------------------------------------')
    ctr = 1
    for train, holdout in kfolds.split(features, labels):
        X_holdout = features.iloc[holdout]
        Y_holdout = labels.iloc[holdout]
        Y_pred = model.predict(X_holdout)
        print(f"Fold: {ctr}")
        print(classification_report(Y_holdout, Y_pred, digits=4))
        print('-------------------------------------------------------')
        ctr += 1
    
    #comparing each holdout fold result with test split result
    print('\nTEST SPLIT PREDICTIONS')
    print('-------------------------------------------------------')
    Y_pred = model.predict(test_set.iloc[:,1:101])
    print(classification_report(test_set.iloc[:,0], Y_pred, digits=4))
    print('-------------------------------------------------------')

# %% [markdown]
# ### 1. LightGBM

# %%
default_tb = load('Models/LGBM/Default/RYZEN3b_LGBM_TB.model') # <== Point these to the respective .model files
default_ib = load('Models/LGBM/Default/RYZEN3b_LGBM_IB.model')
tuned_tb = load('Models/LGBM/Tuned/TUNED_Manual_RYZEN3b_LGBM_TB.model')
tuned_ib = load('Models/LGBM/Tuned/TUNED_Manual_RYZEN3b_LGBM_IB.model')

print("1. Default LGBM TB, 'holdout' from train/validation split vs test split\n")
stratified_kfolds_eval(DF_LGBM_TB_TRAIN, DF_LGBM_TB_TEST, default_tb)
# Out:
# 1. Default LGBM TB, 'holdout' from train/validation split vs test split
#
# HOLDOUT FOLD PREDICTIONS
# -------------------------------------------------------
# Fold: 1
#               precision    recall  f1-score   support
#
#            0     0.9994    0.9963    0.9979      7230
#            1     0.9963    0.9994    0.9979      7230
#
#     accuracy                         0.9979     14460
#    macro avg     0.9979    0.9979    0.9979     14460
# weighted avg     0.9979    0.9979    0.9979     14460
#
# -------------------------------------------------------
# Fold: 2
#               precision    recall  f1-score   support
#
#            0     0.9997    0.9959    0.9978      7230
#            1     0.9959    0.9997    0.9978      7230
#
#     accuracy                         0.9978     14460
#    macro avg     0.9978    0.9978    0.9978     14460
# weighted avg     0.9978    0.9978    0.9978     14460
#
# -------------------------------------------------------
# Fold: 3
#               precision    recall  f1-score   support
#
#            0     0.9989    0.9950    0.9970      7230
#            1     0.9950    0.9989    0.9970      7230
#
#     accuracy                         0.9970     14460
#    macro avg     0.9970    0.9970    0.9970     14460
# weighted avg     0.9970    0.9970    0.9970     14460
#
# -------------------------------------------------------
# Fold: 4
#               precision    recall  f1-score   support
#
#            0     0.9997    0.9967    0.9982      7229
#            1     0.9967    0.9997    0.9982      7230
#
#     accuracy                         0.9982     14459
#    macro avg     0.9982    0.9982    0.9982     14459
# weighted avg     0.9982    0.9982    0.9982     14459
#
# -------------------------------------------------------
# Fold: 5
#               precision    recall  f1-score   support
#
#            0     0.9999    0.9949    0.9974      7230
#            1     0.9949    0.9999    0.9974      7229
#
#     accuracy                         0.9974     14459
#    macro avg     0.9974    0.9974    0.9974     14459
# weighted avg     0.9974    0.9974    0.9974     14459
#
# -------------------------------------------------------
#
# TEST SPLIT PREDICTIONS
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.9851    0.5789    0.7293       114
#            1     0.9882    0.9998    0.9939      4010
#
#     accuracy                         0.9881      4124
#    macro avg     0.9866    0.7893    0.8616      4124
# weighted avg     0.9881    0.9881    0.9866      4124
#
# -------------------------------------------------------

# %%
print("2. Default LGBM IB, 'holdout' from train/validation split vs test split\n")
stratified_kfolds_eval(DF_LGBM_IB_TRAIN, DF_LGBM_IB_TEST, default_ib)
# Out:
# 2. Default LGBM IB, 'holdout' from train/validation split vs test split
#
# HOLDOUT FOLD PREDICTIONS
# -------------------------------------------------------
# Fold: 1
#               precision    recall  f1-score   support
#
#            0     0.9996    0.9954    0.9975      7230
#            1     0.9955    0.9996    0.9975      7230
#
#     accuracy                         0.9975     14460
#    macro avg     0.9975    0.9975    0.9975     14460
# weighted avg     0.9975    0.9975    0.9975     14460
#
# -------------------------------------------------------
# Fold: 2
#               precision    recall  f1-score   support
#
#            0     0.9997    0.9959    0.9978      7230
#            1     0.9959    0.9997    0.9978      7230
#
#     accuracy                         0.9978     14460
#    macro avg     0.9978    0.9978    0.9978     14460
# weighted avg     0.9978    0.9978    0.9978     14460
#
# -------------------------------------------------------
# Fold: 3
#               precision    recall  f1-score   support
#
#            0     0.9994    0.9959    0.9976      7230
#            1     0.9959    0.9994    0.9977      7230
#
#     accuracy                         0.9976     14460
#    macro avg     0.9977    0.9976    0.9976     14460
# weighted avg     0.9977    0.9976    0.9976     14460
#
# -------------------------------------------------------
# Fold: 4
#               precision    recall  f1-score   support
#
#            0     1.0000    0.9954    0.9977      7229
#            1     0.9955    1.0000    0.9977      7230
#
#     accuracy                         0.9977     14459
#    macro avg     0.9977    0.9977    0.9977     14459
# weighted avg     0.9977    0.9977    0.9977     14459
#
# -------------------------------------------------------
# Fold: 5
#               precision    recall  f1-score   support
#
#            0     0.9997    0.9952    0.9974      7230
#            1     0.9952    0.9997    0.9974      7229
#
#     accuracy                         0.9974     14459
#    macro avg     0.9975    0.9974    0.9974     14459
# weighted avg     0.9975    0.9974    0.9974     14459
#
# -------------------------------------------------------
#
# TEST SPLIT PREDICTIONS
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.9067    0.5965    0.7196       114
#            1     0.9886    0.9983    0.9934      4010
#
#     accuracy                         0.9871      4124
#    macro avg     0.9477    0.7974    0.8565      4124
# weighted avg     0.9864    0.9871    0.9859      4124
#
# -------------------------------------------------------

# %%
print("3. Tuned LGBM TB, 'holdout' from train/validation split vs test split\n")
stratified_kfolds_eval(DF_LGBM_TB_TRAIN, DF_LGBM_TB_TEST, tuned_tb)
# Out:
# 3. Tuned LGBM TB, 'holdout' from train/validation split vs test split
#
# HOLDOUT FOLD PREDICTIONS
# -------------------------------------------------------
# Fold: 1
#               precision    recall  f1-score   support
#
#            0     0.9992    0.9971    0.9981      7230
#            1     0.9971    0.9992    0.9981      7230
#
#     accuracy                         0.9981     14460
#    macro avg     0.9981    0.9981    0.9981     14460
# weighted avg     0.9981    0.9981    0.9981     14460
#
# -------------------------------------------------------
# Fold: 2
#               precision    recall  f1-score   support
#
#            0     0.9997    0.9964    0.9981      7230
#            1     0.9964    0.9997    0.9981      7230
#
#     accuracy                         0.9981     14460
#    macro avg     0.9981    0.9981    0.9981     14460
# weighted avg     0.9981    0.9981    0.9981     14460
#
# -------------------------------------------------------
# Fold: 3
#               precision    recall  f1-score   support
#
#            0     0.9990    0.9959    0.9974      7230
#            1     0.9959    0.9990    0.9974      7230
#
#     accuracy                         0.9974     14460
#    macro avg     0.9974    0.9974    0.9974     14460
# weighted avg     0.9974    0.9974    0.9974     14460
#
# -------------------------------------------------------
# Fold: 4
#               precision    recall  f1-score   support
#
#            0     0.9997    0.9970    0.9983      7229
#            1     0.9970    0.9997    0.9983      7230
#
#     accuracy                         0.9983     14459
#    macro avg     0.9983    0.9983    0.9983     14459
# weighted avg     0.9983    0.9983    0.9983     14459
#
# -------------------------------------------------------
# Fold: 5
#               precision    recall  f1-score   support
#
#            0     1.0000    0.9963    0.9981      7230
#            1     0.9963    1.0000    0.9981      7229
#
#     accuracy                         0.9981     14459
#    macro avg     0.9981    0.9981    0.9981     14459
# weighted avg     0.9981    0.9981    0.9981     14459
#
# -------------------------------------------------------
#
# TEST SPLIT PREDICTIONS
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.9855    0.5965    0.7432       114
#            1     0.9887    0.9998    0.9942      4010
#
#     accuracy                         0.9886      4124
#    macro avg     0.9871    0.7981    0.8687      4124
# weighted avg     0.9886    0.9886    0.9872      4124
#
# -------------------------------------------------------

# %%
print("4. Tuned LGBM IB, 'holdout' from train/validation split vs test split\n")
stratified_kfolds_eval(DF_LGBM_IB_TRAIN, DF_LGBM_IB_TEST, tuned_ib)
# Out:
# 4. Tuned LGBM IB, 'holdout' from train/validation split vs test split
#
# HOLDOUT FOLD PREDICTIONS
# -------------------------------------------------------
# Fold: 1
#               precision    recall  f1-score   support
#
#            0     0.9996    0.9963    0.9979      7230
#            1     0.9963    0.9996    0.9979      7230
#
#     accuracy                         0.9979     14460
#    macro avg     0.9979    0.9979    0.9979     14460
# weighted avg     0.9979    0.9979    0.9979     14460
#
# -------------------------------------------------------
# Fold: 2
#               precision    recall  f1-score   support
#
#            0     0.9997    0.9971    0.9984      7230
#            1     0.9971    0.9997    0.9984      7230
#
#     accuracy                         0.9984     14460
#    macro avg     0.9984    0.9984    0.9984     14460
# weighted avg     0.9984    0.9984    0.9984     14460
#
# -------------------------------------------------------
# Fold: 3
#               precision    recall  f1-score   support
#
#            0     0.9993    0.9964    0.9979      7230
#            1     0.9964    0.9993    0.9979      7230
#
#     accuracy                         0.9979     14460
#    macro avg     0.9979    0.9979    0.9979     14460
# weighted avg     0.9979    0.9979    0.9979     14460
#
# -------------------------------------------------------
# Fold: 4
#               precision    recall  f1-score   support
#
#            0     1.0000    0.9963    0.9981      7229
#            1     0.9963    1.0000    0.9981      7230
#
#     accuracy                         0.9981     14459
#    macro avg     0.9981    0.9981    0.9981     14459
# weighted avg     0.9981    0.9981    0.9981     14459
#
# -------------------------------------------------------
# Fold: 5
#               precision    recall  f1-score   support
#
#            0     0.9994    0.9960    0.9977      7230
#            1     0.9960    0.9994    0.9977      7229
#
#     accuracy                         0.9977     14459
#    macro avg     0.9977    0.9977    0.9977     14459
# weighted avg     0.9977    0.9977    0.9977     14459
#
# -------------------------------------------------------
#
# TEST SPLIT PREDICTIONS
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.9506    0.6754    0.7897       114
#            1     0.9908    0.9990    0.9949      4010
#
#     accuracy                         0.9901      4124
#    macro avg     0.9707    0.8372    0.8923      4124
# weighted avg     0.9897    0.9901    0.9892      4124
#
# -------------------------------------------------------

# %% [markdown]
# ### 2. CatBoost

# %%
default_tb = catb.CatBoostClassifier()
default_ib = catb.CatBoostClassifier()
tuned_tb = catb.CatBoostClassifier()
tuned_ib = catb.CatBoostClassifier()
default_tb = default_tb.load_model("./Models/CATB/Default/RYZEN2b_CATB_TB.model", format='json')
default_ib = default_ib.load_model("./Models/CATB/Default/RYZEN2b_CATB_IB.model", format='json')
tuned_tb = tuned_tb.load_model("./Models/CATB/Tuned/TUNED_Manual_RYZEN3b_CATB_TB.model", format='json')
tuned_ib = tuned_ib.load_model("./Models/CATB/Tuned/TUNED_Manual_RYZEN3b_CATB_IB.model", format='json')

print("1. Default CatBoost TB, 'holdout' from train/validation split vs test split\n")
stratified_kfolds_eval(DF_CATB_TB_TRAIN, DF_CATB_TB_TEST, default_tb)
# Out:
# 1. Default CatBoost TB, 'holdout' from train/validation split vs test split
#
# HOLDOUT FOLD PREDICTIONS
# -------------------------------------------------------
# Fold: 1
#               precision    recall  f1-score   support
#
#            0     0.9996    0.9945    0.9970      7230
#            1     0.9945    0.9996    0.9970      7230
#
#     accuracy                         0.9970     14460
#    macro avg     0.9970    0.9970    0.9970     14460
# weighted avg     0.9970    0.9970    0.9970     14460
#
# -------------------------------------------------------
# Fold: 2
#               precision    recall  f1-score   support
#
#            0     0.9999    0.9959    0.9979      7230
#            1     0.9959    0.9999    0.9979      7230
#
#     accuracy                         0.9979     14460
#    macro avg     0.9979    0.9979    0.9979     14460
# weighted avg     0.9979    0.9979    0.9979     14460
#
# -------------------------------------------------------
# Fold: 3
#               precision    recall  f1-score   support
#
#            0     0.9996    0.9938    0.9967      7230
#            1     0.9938    0.9996    0.9967      7230
#
#     accuracy                         0.9967     14460
#    macro avg     0.9967    0.9967    0.9967     14460
# weighted avg     0.9967    0.9967    0.9967     14460
#
# -------------------------------------------------------
# Fold: 4
#               precision    recall  f1-score   support
#
#            0     1.0000    0.9956    0.9978      7229
#            1     0.9956    1.0000    0.9978      7230
#
#     accuracy                         0.9978     14459
#    macro avg     0.9978    0.9978    0.9978     14459
# weighted avg     0.9978    0.9978    0.9978     14459
#
# -------------------------------------------------------
# Fold: 5
#               precision    recall  f1-score   support
#
#            0     0.9994    0.9939    0.9967      7230
#            1     0.9939    0.9994    0.9967      7229
#
#     accuracy                         0.9967     14459
#    macro avg     0.9967    0.9967    0.9967     14459
# weighted avg     0.9967    0.9967    0.9967     14459
#
# -------------------------------------------------------
#
# TEST SPLIT PREDICTIONS
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.9571    0.5877    0.7283       114
#            1     0.9884    0.9993    0.9938      4010
#
#     accuracy                         0.9879      4124
#    macro avg     0.9728    0.7935    0.8610      4124
# weighted avg     0.9875    0.9879    0.9865      4124
#
# -------------------------------------------------------

# %%
print("2. Default CatBoost IB, 'holdout' from train/validation split vs test split\n")
stratified_kfolds_eval(DF_CATB_IB_TRAIN, DF_CATB_IB_TEST, default_ib)
# Out:
# 2. Default CatBoost IB, 'holdout' from train/validation split vs test split
#
# HOLDOUT FOLD PREDICTIONS
# -------------------------------------------------------
# Fold: 1
#               precision    recall  f1-score   support
#
#            0     0.9996    0.9961    0.9979      7230
#            1     0.9961    0.9996    0.9979      7230
#
#     accuracy                         0.9979     14460
#    macro avg     0.9979    0.9979    0.9979     14460
# weighted avg     0.9979    0.9979    0.9979     14460
#
# -------------------------------------------------------
# Fold: 2
#               precision    recall  f1-score   support
#
#            0     0.9996    0.9968    0.9982      7230
#            1     0.9968    0.9996    0.9982      7230
#
#     accuracy                         0.9982     14460
#    macro avg     0.9982    0.9982    0.9982     14460
# weighted avg     0.9982    0.9982    0.9982     14460
#
# -------------------------------------------------------
# Fold: 3
#               precision    recall  f1-score   support
#
#            0     0.9989    0.9946    0.9967      7230
#            1     0.9946    0.9989    0.9968      7230
#
#     accuracy                         0.9967     14460
#    macro avg     0.9968    0.9967    0.9967     14460
# weighted avg     0.9968    0.9967    0.9967     14460
#
# -------------------------------------------------------
# Fold: 4
#               precision    recall  f1-score   support
#
#            0     0.9999    0.9960    0.9979      7229
#            1     0.9960    0.9999    0.9979      7230
#
#     accuracy                         0.9979     14459
#    macro avg     0.9979    0.9979    0.9979     14459
# weighted avg     0.9979    0.9979    0.9979     14459
#
# -------------------------------------------------------
# Fold: 5
#               precision    recall  f1-score   support
#
#            0     0.9993    0.9952    0.9972      7230
#            1     0.9952    0.9993    0.9972      7229
#
#     accuracy                         0.9972     14459
#    macro avg     0.9972    0.9972    0.9972     14459
# weighted avg     0.9972    0.9972    0.9972     14459
#
# -------------------------------------------------------
#
# TEST SPLIT PREDICTIONS
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.9351    0.6316    0.7539       114
#            1     0.9896    0.9988    0.9942      4010
#
#     accuracy                         0.9886      4124
#    macro avg     0.9623    0.8152    0.8740      4124
# weighted avg     0.9881    0.9886    0.9875      4124
#
# -------------------------------------------------------

# %%
print("3. Tuned CatBoost TB, 'holdout' from train/validation split vs test split\n")
stratified_kfolds_eval(DF_CATB_TB_TRAIN, DF_CATB_TB_TEST, tuned_tb)
# Out:
# 3. Tuned CatBoost TB, 'holdout' from train/validation split vs test split
#
# HOLDOUT FOLD PREDICTIONS
# -------------------------------------------------------
# Fold: 1
#               precision    recall  f1-score   support
#
#            0     0.9992    0.9954    0.9973      7230
#            1     0.9955    0.9992    0.9973      7230
#
#     accuracy                         0.9973     14460
#    macro avg     0.9973    0.9973    0.9973     14460
# weighted avg     0.9973    0.9973    0.9973     14460
#
# -------------------------------------------------------
# Fold: 2
#               precision    recall  f1-score   support
#
#            0     0.9996    0.9964    0.9980      7230
#            1     0.9964    0.9996    0.9980      7230
#
#     accuracy                         0.9980     14460
#    macro avg     0.9980    0.9980    0.9980     14460
# weighted avg     0.9980    0.9980    0.9980     14460
#
# -------------------------------------------------------
# Fold: 3
#               precision    recall  f1-score   support
#
#            0     0.9990    0.9956    0.9973      7230
#            1     0.9956    0.9990    0.9973      7230
#
#     accuracy                         0.9973     14460
#    macro avg     0.9973    0.9973    0.9973     14460
# weighted avg     0.9973    0.9973    0.9973     14460
#
# -------------------------------------------------------
# Fold: 4
#               precision    recall  f1-score   support
#
#            0     0.9997    0.9963    0.9980      7229
#            1     0.9963    0.9997    0.9980      7230
#
#     accuracy                         0.9980     14459
#    macro avg     0.9980    0.9980    0.9980     14459
# weighted avg     0.9980    0.9980    0.9980     14459
#
# -------------------------------------------------------
# Fold: 5
#               precision    recall  f1-score   support
#
#            0     0.9996    0.9952    0.9974      7230
#            1     0.9952    0.9996    0.9974      7229
#
#     accuracy                         0.9974     14459
#    macro avg     0.9974    0.9974    0.9974     14459
# weighted avg     0.9974    0.9974    0.9974     14459
#
# -------------------------------------------------------
#
# TEST SPLIT PREDICTIONS
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.9125    0.6404    0.7526       114
#            1     0.9899    0.9983    0.9940      4010
#
#     accuracy                         0.9884      4124
#    macro avg     0.9512    0.8193    0.8733      4124
# weighted avg     0.9877    0.9884    0.9874      4124
#
# -------------------------------------------------------

# %%
print("4. Default CatBoost IB, 'holdout' from train/validation split vs test split\n")
stratified_kfolds_eval(DF_CATB_IB_TRAIN, DF_CATB_IB_TEST, tuned_ib)
# Out:
# 4. Default CatBoost IB, 'holdout' from train/validation split vs test split
#
# HOLDOUT FOLD PREDICTIONS
# -------------------------------------------------------
# Fold: 1
#               precision    recall  f1-score   support
#
#            0     0.9990    0.9959    0.9974      7230
#            1     0.9959    0.9990    0.9974      7230
#
#     accuracy                         0.9974     14460
#    macro avg     0.9974    0.9974    0.9974     14460
# weighted avg     0.9974    0.9974    0.9974     14460
#
# -------------------------------------------------------
# Fold: 2
#               precision    recall  f1-score   support
#
#            0     0.9996    0.9968    0.9982      7230
#            1     0.9968    0.9996    0.9982      7230
#
#     accuracy                         0.9982     14460
#    macro avg     0.9982    0.9982    0.9982     14460
# weighted avg     0.9982    0.9982    0.9982     14460
#
# -------------------------------------------------------
# Fold: 3
#               precision    recall  f1-score   support
#
#            0     0.9985    0.9950    0.9967      7230
#            1     0.9950    0.9985    0.9968      7230
#
#     accuracy                         0.9967     14460
#    macro avg     0.9968    0.9967    0.9967     14460
# weighted avg     0.9968    0.9967    0.9967     14460
#
# -------------------------------------------------------
# Fold: 4
#               precision    recall  f1-score   support
#
#            0     0.9997    0.9954    0.9976      7229
#            1     0.9955    0.9997    0.9976      7230
#
#     accuracy                         0.9976     14459
#    macro avg     0.9976    0.9976    0.9976     14459
# weighted avg     0.9976    0.9976    0.9976     14459
#
# -------------------------------------------------------
# Fold: 5
#               precision    recall  f1-score   support
#
#            0     0.9990    0.9953    0.9972      7230
#            1     0.9953    0.9990    0.9972      7229
#
#     accuracy                         0.9972     14459
#    macro avg     0.9972    0.9972    0.9972     14459
# weighted avg     0.9972    0.9972    0.9972     14459
#
# -------------------------------------------------------
#
# TEST SPLIT PREDICTIONS
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.8791    0.7018    0.7805       114
#            1     0.9916    0.9973    0.9944      4010
#
#     accuracy                         0.9891      4124
#    macro avg     0.9353    0.8495    0.8874      4124
# weighted avg     0.9885    0.9891    0.9885      4124
#
# -------------------------------------------------------
