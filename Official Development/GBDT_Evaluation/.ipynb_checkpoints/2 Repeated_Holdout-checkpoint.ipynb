# %% [markdown]
# # Repeated Holdout Test
#
# **Objectives**
# - Load the Model(s)
# - Run predictions on the model using the Training/Validation & Holdout/Test* data split using Stratified K-Folds CV (params: k=5 & random_seed=1)
# - Record the performance of the models (e.g., accuracy, precision, recall, ROC-AUC, etc.) on every CV instance for use in analysis to determine possible occurence of overfitting.
#
# *The addition of the use of Holdout/Test split here acts as an addition to the original plan of only using Training/Validation data splits.*
#
# **Essentially, this answers the question:** `Is the model overfitted from the training data?`

# %%
import pandas as pd

import lightgbm as lgbm
import catboost as catb
 
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report

from joblib import load

import warnings
warnings.filterwarnings("ignore")

# %%
DF_LGBM_TB_TRAIN = pd.read_csv('./Dataset/LGBM_TB.csv', low_memory=False) #<== Point these to the appropriate Training+Validation datasets.
DF_LGBM_IB_TRAIN = pd.read_csv('./Dataset/LGBM_IB.csv', low_memory=False)
DF_LGBM_TB_TEST = pd.read_csv('./Dataset/LGBM_TB_Test.csv', low_memory=False)
DF_LGBM_IB_TEST = pd.read_csv('./Dataset/LGBM_IB_Test.csv', low_memory=False)
display(DF_LGBM_TB_TRAIN.head())
display(DF_LGBM_IB_TRAIN.head())
display(DF_LGBM_TB_TEST.head())
display(DF_LGBM_IB_TEST.head())

DF_CATB_TB_TRAIN = pd.read_csv('./Dataset/CATB_TB.csv', low_memory=False)
DF_CATB_IB_TRAIN = pd.read_csv('./Dataset/CATB_IB.csv', low_memory=False)
DF_CATB_TB_TEST = pd.read_csv('./Dataset/CATB_TB_Test.csv', low_memory=False)
DF_CATB_IB_TEST = pd.read_csv('./Dataset/CATB_IB_Test.csv', low_memory=False)

DF_CATB_IB_TRAIN.iloc[:,1:101] = DF_CATB_IB_TRAIN.iloc[:,1:101].astype('str')
DF_CATB_IB_TRAIN.replace("nan", "NaN", inplace=True)
DF_CATB_IB_TEST.iloc[:,1:101] = DF_CATB_IB_TEST.iloc[:,1:101].astype('str')
DF_CATB_IB_TEST.replace("nan", "NaN", inplace=True)

display(DF_CATB_TB_TRAIN.head())
display(DF_CATB_IB_TRAIN.head())
display(DF_CATB_TB_TEST.head())
display(DF_CATB_IB_TEST.head())
# Out:
#    malware  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  t_8  ...  t_90  t_91  \
# 0        1   82  240  117  240  117   93  117  172  117  ...   117    37
# 1        1   82  240  117  240  117  240  117  240  117  ...   260    40
# 2        1  286  110  172  240  117  240  117  240  117  ...    25    71
# 3        1  112  274  158  215  274  158  215  298   76  ...   117    71
# 4        1   82  240  117  240  117  240  117  240  117  ...   225    35
#
#    t_92  t_93  t_94  t_95  t_96  t_97  t_98  t_99
# 0   294   240   117   198   208   187   208   240
# 1   159   224    82   209   260    40   209   260
# 2   275   260   240   117   141    65   260   141
# 3   297   135   171   215    35   208    56    71
# 4   225    35   240   117   225    35   225   215
#
# [5 rows x 101 columns]
#    malware  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  t_8  ...  t_90  t_91  \
# 0        1   82  240  117   93  172   16  215  228  208  ...   307   307
# 1        1   82  240  117  172   16   11  274  158  215  ...   307   307
# 2        1  286  110  172  240  117  106  171  260  141  ...   307   307
# 3        1  112  274  158  215  298   76  208  172  117  ...   307   307
# 4        1   82  240  117   16  228  208   71   56  172  ...   307   307
#
#    t_92  t_93  t_94  t_95  t_96  t_97  t_98  t_99
# 0   307   307   307   307   307   307   307   307
# 1   307   307   307   307   307   307   307   307
# 2   307   307   307   307   307   307   307   307
# 3   307   307   307   307   307   307   307   307
# 4   307   307   307   307   307   307   307   307
#
# [5 rows x 101 columns]
#    malware  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  t_8  ...  t_92  t_93  \
# 0        1  112  274  158  215  274  158  215  298   76  ...   297   135
# 1        1   82  240  117  240  117  240  117  240  117  ...   260   141
# 2        1   82  240  117  240  117  240  117  240  117  ...   260   141
# 3        1  112  274  158  215  274  158  215  298   76  ...   297   135
# 4        1  286  110  172  240  117  240  117  240  117  ...   275   260
#
#    t_94  t_95  t_96  t_97  t_98  t_99                              hash  \
# 0   171   215    35   208    56    71  c0299a7bdcde86ded3c3afd350028c01
# 1   260   141   260   141   260   141  57cd6a362b9b3808663ebbc84ec17b2c
# 2   260   141   260   141   260   141  732d1b5f0c4c0d113cbebd5d3c519c44
# 3   171   215    35   208    56    71  aea1feacee06204634e843b49aeca4ee
# 4   240   117   141    65   260   141  0f7d52267f2d793bc374520a52a96ce0
#
#      type
# 0  trojan
# 1  trojan
# 2  trojan
# 3  trojan
# 4  trojan
#
# [5 rows x 103 columns]
#    malware  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  t_8  ...  t_92  t_93  \
# 0        1  112  274  158  215  298   76  208  172  117  ...   307   307
# 1        1   82  240  117  172   16   11  274  158  215  ...   307   307
# 2        1   82  240  117  172   16   11  274  158  215  ...   307   307
# 3        1  112  274  158  215  298   76  208  172  117  ...   307   307
# 4        1  286  110  172  240  117  106  171  260  141  ...   307   307
#
#    t_94  t_95  t_96  t_97  t_98  t_99                              hash  \
# 0   307   307   307   307   307   307  c0299a7bdcde86ded3c3afd350028c01
# 1   307   307   307   307   307   307  57cd6a362b9b3808663ebbc84ec17b2c
# 2   307   307   307   307   307   307  732d1b5f0c4c0d113cbebd5d3c519c44
# 3   307   307   307   307   307   307  aea1feacee06204634e843b49aeca4ee
# 4   307   307   307   307   307   307  0f7d52267f2d793bc374520a52a96ce0
#
#      type
# 0  trojan
# 1  trojan
# 2  trojan
# 3  trojan
# 4  trojan
#
# [5 rows x 103 columns]
#    malware                      t_0            t_1                     t_2  \
# 0        1  GetSystemTimeAsFileTime     LdrLoadDll  LdrGetProcedureAddress
# 1        1  GetSystemTimeAsFileTime     LdrLoadDll  LdrGetProcedureAddress
# 2        1             SetErrorMode  OleInitialize         LdrGetDllHandle
# 3        1            RegOpenKeyExA      NtOpenKey         NtQueryValueKey
# 4        1  GetSystemTimeAsFileTime     LdrLoadDll  LdrGetProcedureAddress
#
#           t_3                     t_4              t_5  \
# 0  LdrLoadDll  LdrGetProcedureAddress      GetFileType
# 1  LdrLoadDll  LdrGetProcedureAddress       LdrLoadDll
# 2  LdrLoadDll  LdrGetProcedureAddress       LdrLoadDll
# 3     NtClose               NtOpenKey  NtQueryValueKey
# 4  LdrLoadDll  LdrGetProcedureAddress       LdrLoadDll
#
#                       t_6                    t_7                     t_8  ...  \
# 0  LdrGetProcedureAddress        LdrGetDllHandle  LdrGetProcedureAddress  ...
# 1  LdrGetProcedureAddress             LdrLoadDll  LdrGetProcedureAddress  ...
# 2  LdrGetProcedureAddress             LdrLoadDll  LdrGetProcedureAddress  ...
# 3                 NtClose  NtQueryAttributesFile             LoadStringA  ...
# 4  LdrGetProcedureAddress             LdrLoadDll  LdrGetProcedureAddress  ...
#
#                      t_90                        t_91                   t_92  \
# 0  LdrGetProcedureAddress                 NtOpenKeyEx  NtOpenDirectoryObject
# 1           RegOpenKeyExW            RegQueryInfoKeyW       NtDelayExecution
# 2             LoadStringW  GetSystemWindowsDirectoryW    GetSystemDirectoryW
# 3  LdrGetProcedureAddress  GetSystemWindowsDirectoryW           NtCreateFile
# 4             DrawTextExW            GetSystemMetrics            DrawTextExW
#
#                t_93                     t_94                    t_95  \
# 0        LdrLoadDll   LdrGetProcedureAddress           GetSystemInfo
# 1       EnumWindows  GetSystemTimeAsFileTime           RegEnumKeyExW
# 2     RegOpenKeyExW               LdrLoadDll  LdrGetProcedureAddress
# 3   NtCreateSection       NtMapViewOfSection                 NtClose
# 4  GetSystemMetrics               LdrLoadDll  LdrGetProcedureAddress
#
#                       t_96                     t_97                     t_98  \
# 0  NtAllocateVirtualMemory      NtFreeVirtualMemory  NtAllocateVirtualMemory
# 1            RegOpenKeyExW         RegQueryInfoKeyW            RegEnumKeyExW
# 2         RegQueryValueExW              RegCloseKey            RegOpenKeyExW
# 3         GetSystemMetrics  NtAllocateVirtualMemory            CreateActCtxW
# 4              DrawTextExW         GetSystemMetrics              DrawTextExW
#
#                          t_99
# 0                  LdrLoadDll
# 1               RegOpenKeyExW
# 2            RegQueryValueExW
# 3  GetSystemWindowsDirectoryW
# 4                     NtClose
#
# [5 rows x 101 columns]
#    malware                      t_0            t_1                     t_2  \
# 0        1  GetSystemTimeAsFileTime     LdrLoadDll  LdrGetProcedureAddress
# 1        1  GetSystemTimeAsFileTime     LdrLoadDll  LdrGetProcedureAddress
# 2        1             SetErrorMode  OleInitialize         LdrGetDllHandle
# 3        1            RegOpenKeyExA      NtOpenKey         NtQueryValueKey
# 4        1  GetSystemTimeAsFileTime     LdrLoadDll  LdrGetProcedureAddress
#
#                            t_3                          t_4  \
# 0                  GetFileType              LdrGetDllHandle
# 1              LdrGetDllHandle  SetUnhandledExceptionFilter
# 2                   LdrLoadDll       LdrGetProcedureAddress
# 3                      NtClose        NtQueryAttributesFile
# 4  SetUnhandledExceptionFilter       NtProtectVirtualMemory
#
#                            t_5                         t_6  \
# 0  SetUnhandledExceptionFilter                     NtClose
# 1         CryptAcquireContextW                   NtOpenKey
# 2                NtOpenSection          NtMapViewOfSection
# 3                  LoadStringA     NtAllocateVirtualMemory
# 4      NtAllocateVirtualMemory  GetSystemWindowsDirectoryW
#
#                       t_7                      t_8  ... t_90 t_91 t_92 t_93  \
# 0  NtProtectVirtualMemory  NtAllocateVirtualMemory  ...  NaN  NaN  NaN  NaN
# 1         NtQueryValueKey                  NtClose  ...  NaN  NaN  NaN  NaN
# 2           RegOpenKeyExW         RegQueryValueExW  ...  NaN  NaN  NaN  NaN
# 3         LdrGetDllHandle   LdrGetProcedureAddress  ...  NaN  NaN  NaN  NaN
# 4           CreateActCtxW          LdrGetDllHandle  ...  NaN  NaN  NaN  NaN
#
#   t_94 t_95 t_96 t_97 t_98 t_99
# 0  NaN  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 101 columns]
#    malware                      t_0            t_1                     t_2  \
# 0        1            RegOpenKeyExA      NtOpenKey         NtQueryValueKey
# 1        1  GetSystemTimeAsFileTime     LdrLoadDll  LdrGetProcedureAddress
# 2        1  GetSystemTimeAsFileTime     LdrLoadDll  LdrGetProcedureAddress
# 3        1            RegOpenKeyExA      NtOpenKey         NtQueryValueKey
# 4        1             SetErrorMode  OleInitialize         LdrGetDllHandle
#
#           t_3                     t_4              t_5  \
# 0     NtClose               NtOpenKey  NtQueryValueKey
# 1  LdrLoadDll  LdrGetProcedureAddress       LdrLoadDll
# 2  LdrLoadDll  LdrGetProcedureAddress       LdrLoadDll
# 3     NtClose               NtOpenKey  NtQueryValueKey
# 4  LdrLoadDll  LdrGetProcedureAddress       LdrLoadDll
#
#                       t_6                    t_7                     t_8  ...  \
# 0                 NtClose  NtQueryAttributesFile             LoadStringA  ...
# 1  LdrGetProcedureAddress             LdrLoadDll  LdrGetProcedureAddress  ...
# 2  LdrGetProcedureAddress             LdrLoadDll  LdrGetProcedureAddress  ...
# 3                 NtClose  NtQueryAttributesFile             LoadStringA  ...
# 4  LdrGetProcedureAddress             LdrLoadDll  LdrGetProcedureAddress  ...
#
#                   t_92              t_93                t_94  \
# 0         NtCreateFile   NtCreateSection  NtMapViewOfSection
# 1        RegOpenKeyExW  RegQueryValueExW       RegOpenKeyExW
# 2        RegOpenKeyExW  RegQueryValueExW       RegOpenKeyExW
# 3         NtCreateFile   NtCreateSection  NtMapViewOfSection
# 4  GetSystemDirectoryW     RegOpenKeyExW          LdrLoadDll
#
#                      t_95              t_96                     t_97  \
# 0                 NtClose  GetSystemMetrics  NtAllocateVirtualMemory
# 1        RegQueryValueExW     RegOpenKeyExW         RegQueryValueExW
# 2        RegQueryValueExW     RegOpenKeyExW         RegQueryValueExW
# 3                 NtClose  GetSystemMetrics  NtAllocateVirtualMemory
# 4  LdrGetProcedureAddress  RegQueryValueExW              RegCloseKey
#
#             t_98                        t_99  \
# 0  CreateActCtxW  GetSystemWindowsDirectoryW
# 1  RegOpenKeyExW            RegQueryValueExW
# 2  RegOpenKeyExW            RegQueryValueExW
# 3  CreateActCtxW  GetSystemWindowsDirectoryW
# 4  RegOpenKeyExW            RegQueryValueExW
#
#                                hash    type
# 0  c0299a7bdcde86ded3c3afd350028c01  trojan
# 1  57cd6a362b9b3808663ebbc84ec17b2c  trojan
# 2  732d1b5f0c4c0d113cbebd5d3c519c44  trojan
# 3  aea1feacee06204634e843b49aeca4ee  trojan
# 4  0f7d52267f2d793bc374520a52a96ce0  trojan
#
# [5 rows x 103 columns]
#    malware                      t_0            t_1                     t_2  \
# 0        1            RegOpenKeyExA      NtOpenKey         NtQueryValueKey
# 1        1  GetSystemTimeAsFileTime     LdrLoadDll  LdrGetProcedureAddress
# 2        1  GetSystemTimeAsFileTime     LdrLoadDll  LdrGetProcedureAddress
# 3        1            RegOpenKeyExA      NtOpenKey         NtQueryValueKey
# 4        1             SetErrorMode  OleInitialize         LdrGetDllHandle
#
#                t_3                          t_4                   t_5  \
# 0          NtClose        NtQueryAttributesFile           LoadStringA
# 1  LdrGetDllHandle  SetUnhandledExceptionFilter  CryptAcquireContextW
# 2  LdrGetDllHandle  SetUnhandledExceptionFilter  CryptAcquireContextW
# 3          NtClose        NtQueryAttributesFile           LoadStringA
# 4       LdrLoadDll       LdrGetProcedureAddress         NtOpenSection
#
#                        t_6              t_7                     t_8  ... t_92  \
# 0  NtAllocateVirtualMemory  LdrGetDllHandle  LdrGetProcedureAddress  ...  NaN
# 1                NtOpenKey  NtQueryValueKey                 NtClose  ...  NaN
# 2                NtOpenKey  NtQueryValueKey                 NtClose  ...  NaN
# 3  NtAllocateVirtualMemory  LdrGetDllHandle  LdrGetProcedureAddress  ...  NaN
# 4       NtMapViewOfSection    RegOpenKeyExW        RegQueryValueExW  ...  NaN
#
#   t_93 t_94 t_95 t_96 t_97 t_98 t_99                              hash    type
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  c0299a7bdcde86ded3c3afd350028c01  trojan
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  57cd6a362b9b3808663ebbc84ec17b2c  trojan
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  732d1b5f0c4c0d113cbebd5d3c519c44  trojan
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  aea1feacee06204634e843b49aeca4ee  trojan
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  0f7d52267f2d793bc374520a52a96ce0  trojan
#
# [5 rows x 103 columns]

# %% [markdown]
# ### 0. Defining a helper function for evaluation

# %%
def stratified_kfolds_eval(train_set, test_set, model):
    features = train_set.drop('malware', axis=1)
    labels = train_set['malware']
    kfolds = StratifiedKFold(n_splits=5, shuffle=True, random_state=1)
    print('HOLDOUT FOLD PREDICTIONS')
    print('-------------------------------------------------------')
    ctr = 1
    for train, holdout in kfolds.split(features, labels):
        X_holdout = features.iloc[holdout]
        Y_holdout = labels.iloc[holdout]
        Y_pred = model.predict(X_holdout)
        print(f"Fold: {ctr}")
        print(classification_report(Y_holdout, Y_pred, digits=4))
        print('-------------------------------------------------------')
        ctr += 1
    
    #comparing each holdout fold result with test split result
    print('\nTEST SPLIT PREDICTIONS')
    print('-------------------------------------------------------')
    Y_pred = model.predict(test_set.iloc[:,1:101])
    print(classification_report(test_set.iloc[:,0], Y_pred, digits=4))
    print('-------------------------------------------------------')

# %% [markdown]
# ### 1. LightGBM

# %%
default_tb = load('./Models/LGBM/Train_Default/DEMO_LGBM_TB.model')
default_ib = load('./Models/LGBM/Train_Default/DEMO_LGBM_IB.model')
tuned_tb = load('./Models/LGBM/Train_Tuned/TUNED_DEMO_LGBM_TB.model')
tuned_ib = load('./Models/LGBM/Train_Tuned/TUNED_DEMO_LGBM_IB.model')

print("1. Default LGBM TB, 'holdout' from train/validation split vs test split\n")
stratified_kfolds_eval(DF_LGBM_TB_TRAIN, DF_LGBM_TB_TEST, default_tb)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 default_tb = load('./Models/LGBM/Train_Default/DEMO_LGBM_TB.model')
#       2 default_ib = load('./Models/LGBM/Train_Default/DEMO_LGBM_IB.model')
#       3 tuned_tb = load('./Models/LGBM/Train_Tuned/TUNED_DEMO_LGBM_TB.model')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\joblib\numpy_pickle.py:650, in load(filename, mmap_mode)
#     648         obj = _unpickle(fobj)
#     649 else:
# --> 650     with open(filename, 'rb') as f:
#     651         with _read_fileobject(f, filename, mmap_mode) as fobj:
#     652             if isinstance(fobj, str):
#     653                 # if the returned file object is a string, this means we
#     654                 # try to load a pickle file generated with an version of
#     655                 # Joblib so we load it with joblib compatibility function.
#
# FileNotFoundError: [Errno 2] No such file or directory: './Models/LGBM/Train_Default/DEMO_LGBM_TB.model'

# %%
print("2. Default LGBM IB, 'holdout' from train/validation split vs test split\n")
stratified_kfolds_eval(DF_LGBM_IB_TRAIN, DF_LGBM_IB_TEST, default_ib)

# %%
print("3. Tuned LGBM TB, 'holdout' from train/validation split vs test split\n")
stratified_kfolds_eval(DF_LGBM_TB_TRAIN, DF_LGBM_TB_TEST, tuned_tb)

# %%
print("4. Tuned LGBM IB, 'holdout' from train/validation split vs test split\n")
stratified_kfolds_eval(DF_LGBM_IB_TRAIN, DF_LGBM_IB_TEST, tuned_ib)

# %% [markdown]
# ### 2. CatBoost

# %%
default_tb = catb.CatBoostClassifier()
default_ib = catb.CatBoostClassifier()
tuned_tb = catb.CatBoostClassifier()
tuned_ib = catb.CatBoostClassifier()
default_tb = default_tb.load_model("./Models/CATB/Train_Default/DEMO_CATB_TB.model", format='json')
default_ib = default_ib.load_model("./Models/CATB/Train_Default/DEMO_CATB_IB.model", format='json')
tuned_tb = tuned_tb.load_model("./Models/CATB/Train_Tuned/TUNED_DEMO_CATB_TB.model", format='json')
tuned_ib = tuned_ib.load_model("./Models/CATB/Train_Tuned/TUNED_DEMO_CATB_IB.model", format='json')

print("1. Default CatBoost TB, 'holdout' from train/validation split vs test split\n")
stratified_kfolds_eval(DF_CATB_TB_TRAIN, DF_CATB_TB_TEST, default_tb)

# %%
print("2. Default CatBoost IB, 'holdout' from train/validation split vs test split\n")
stratified_kfolds_eval(DF_CATB_IB_TRAIN, DF_CATB_IB_TEST, default_ib)

# %%
print("3. Tuned CatBoost TB, 'holdout' from train/validation split vs test split\n")
stratified_kfolds_eval(DF_CATB_TB_TRAIN, DF_CATB_TB_TEST, tuned_tb)

# %%
print("4. Default CatBoost IB, 'holdout' from train/validation split vs test split\n")
stratified_kfolds_eval(DF_CATB_IB_TRAIN, DF_CATB_IB_TEST, tuned_ib)
