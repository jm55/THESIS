# %% [markdown]
# # Clustering Demo (Benign)
#
# **Note:** Make sure that you have `oliveira.csv` in the same directory as this notebook.
#
# **Note:** No Clustering occurs here as it is Benign, though it is still needed to be executed as it has a specific step that will be used as part of Dataset Analysis.

# %% [markdown]
# ## Code Preparation
#
# Prepare the functions that might be used as the notebook runs.

# %%
import pandas as pd

#Load list of API calls
API_LIST = "../api_calls.txt"
DELIMITER = "NaN"
API_FILE = open(API_LIST,"r")
APIS = API_FILE.readline().split(',')
APIS.append(DELIMITER) #serves as a label for NaN values for Instance-based datasets
API_FILE.close()

#Random Seed
seed = 1

def list_to_str(ls:list):
    '''Convert list to a stringified version (comma delimited).'''
    output = ""
    for l in ls:
        output += str(l) + ","
    return output[0:len(output)-1]

def load_df():
    '''Load the dataset file (CSV) as DataFrame'''
    print("Loading DF...")
    df = pd.read_csv("../oliveira.csv", low_memory=False, memory_map=True)
    df = df[df['malware'] == 0].copy()
    df = df.drop('malware', axis=1)
    print("")
    return df.reset_index().iloc[:,1:]

def get_x(df:pd.DataFrame):
    '''Get the feature columns of the DataFrame'''
    return df.iloc[:, 1:102-1]

#Inverse Label Encoding
def inverse_labeller(item):
    global APIS
    return item.map(lambda x: APIS[int(x)])
def inverse_label(df:pd.DataFrame):
    print("Inverse Labelling...")
    df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
    print("")
    return df

# %% [markdown]
# ## Load Dataset

# %%
df = load_df()
inverse_labelled_df = inverse_label(df)
# Out:
# Loading DF...
#
# Inverse Labelling...
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                      SetErrorMode
# 1                     GetSystemInfo
# 2           GetSystemTimeAsFileTime
# 3           GetSystemTimeAsFileTime
# 4                      SetErrorMode
#                    ...
# 1074                   SetErrorMode
# 1075        GetSystemTimeAsFileTime
# 1076    SetUnhandledExceptionFilter
# 1077                        NtClose
# 1078                   SetErrorMode
# Name: t_0, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                     OleInitialize
# 1           NtAllocateVirtualMemory
# 2            NtProtectVirtualMemory
# 3                        LdrLoadDll
# 4                     OleInitialize
#                    ...
# 1074                  OleInitialize
# 1075    SetUnhandledExceptionFilter
# 1076                 NtCreateMutant
# 1077                      NtOpenKey
# 1078                LdrGetDllHandle
# Name: t_1, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                   LdrGetDllHandle
# 1                     NtOpenSection
# 2       SetUnhandledExceptionFilter
# 3            LdrGetProcedureAddress
# 4                   LdrGetDllHandle
#                    ...
# 1074                LdrGetDllHandle
# 1075                   GetCursorPos
# 1076        NtAllocateVirtualMemory
# 1077                NtQueryValueKey
# 1078         LdrGetProcedureAddress
# Name: t_2, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                   LdrLoadDll
# 1                 GetTempPathW
# 2       GetTimeZoneInformation
# 3                   LdrLoadDll
# 4                   LdrLoadDll
#                  ...
# 1074                LdrLoadDll
# 1075              SetErrorMode
# 1076                   NtClose
# 1077                   NtClose
# 1078       GetSystemDirectoryW
# Name: t_3, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        LdrGetProcedureAddress
# 1              CreateDirectoryW
# 2       GetSystemTimeAsFileTime
# 3        LdrGetProcedureAddress
# 4        LdrGetProcedureAddress
#                  ...
# 1074     LdrGetProcedureAddress
# 1075              FindResourceW
# 1076             NtCreateMutant
# 1077                  NtOpenKey
# 1078    NtAllocateVirtualMemory
# Name: t_4, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                   LdrLoadDll
# 1           GetFileAttributesW
# 2       GetTimeZoneInformation
# 3                   LdrLoadDll
# 4                   LdrLoadDll
#                  ...
# 1074                LdrLoadDll
# 1075         SetWindowsHookExW
# 1076                   NtClose
# 1077           NtQueryValueKey
# 1078       NtFreeVirtualMemory
# Name: t_5, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        LdrGetProcedureAddress
# 1              FindFirstFileExW
# 2       GetSystemTimeAsFileTime
# 3        LdrGetProcedureAddress
# 4        LdrGetProcedureAddress
#                  ...
# 1074     LdrGetProcedureAddress
# 1075             CoInitializeEx
# 1076             NtCreateMutant
# 1077                    NtClose
# 1078    NtAllocateVirtualMemory
# Name: t_6, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                   LdrLoadDll
# 1                  DeleteFileW
# 2       GetTimeZoneInformation
# 3                   LdrLoadDll
# 4                   LdrLoadDll
#                  ...
# 1074                LdrLoadDll
# 1075         NtDuplicateObject
# 1076                   NtClose
# 1077           LdrGetDllHandle
# 1078                LdrLoadDll
# Name: t_7, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        LdrGetProcedureAddress
# 1          NtQueryDirectoryFile
# 2       GetSystemTimeAsFileTime
# 3        LdrGetProcedureAddress
# 4        LdrGetProcedureAddress
#                  ...
# 1074     LdrGetProcedureAddress
# 1075    NtAllocateVirtualMemory
# 1076    NtAllocateVirtualMemory
# 1077     LdrGetProcedureAddress
# 1078        GetSystemDirectoryW
# Name: t_8, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                 NtOpenSection
# 1                   DeleteFileW
# 2            GetFileAttributesW
# 3                    LdrLoadDll
# 4                 NtOpenSection
#                  ...
# 1074              NtOpenSection
# 1075             CoInitializeEx
# 1076    GetSystemTimeAsFileTime
# 1077            LdrGetDllHandle
# 1078                 LdrLoadDll
# Name: t_9, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0            NtMapViewOfSection
# 1          NtQueryDirectoryFile
# 2              CreateDirectoryW
# 3        LdrGetProcedureAddress
# 4            NtMapViewOfSection
#                  ...
# 1074         NtMapViewOfSection
# 1075            DeviceIoControl
# 1076    NtAllocateVirtualMemory
# 1077     LdrGetProcedureAddress
# 1078        GetSystemDirectoryW
# Name: t_10, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                    RegOpenKeyExW
# 1                          NtClose
# 2               GetFileAttributesW
# 3                       LdrLoadDll
# 4                    RegOpenKeyExW
#                    ...
# 1074                 RegOpenKeyExW
# 1075             NtDuplicateObject
# 1076       GetSystemTimeAsFileTime
# 1077               LdrGetDllHandle
# 1078    GetSystemWindowsDirectoryW
# Name: t_11, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0              RegQueryValueExW
# 1              RemoveDirectoryW
# 2                  NtCreateFile
# 3        LdrGetProcedureAddress
# 4              RegQueryValueExW
#                  ...
# 1074           RegQueryValueExW
# 1075    NtAllocateVirtualMemory
# 1076    NtAllocateVirtualMemory
# 1077     LdrGetProcedureAddress
# 1078        GetSystemDirectoryW
# Name: t_12, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                       RegCloseKey
# 1            LdrGetProcedureAddress
# 2                       GetFileType
# 3       SetUnhandledExceptionFilter
# 4                       RegCloseKey
#                    ...
# 1074                    RegCloseKey
# 1075                     UuidCreate
# 1076                LdrGetDllHandle
# 1077                  GetSystemInfo
# 1078                  RegOpenKeyExA
# Name: t_13, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                    RegOpenKeyExW
# 1                  LdrGetDllHandle
# 2                     NtCreateFile
# 3          NtAllocateVirtualMemory
# 4                    RegOpenKeyExW
#                    ...
# 1074                 RegOpenKeyExW
# 1075        LdrGetProcedureAddress
# 1076        LdrGetProcedureAddress
# 1077       NtAllocateVirtualMemory
# 1078    GetSystemWindowsDirectoryW
# Name: t_14, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0               RegQueryValueExW
# 1                  FindResourceA
# 2                    GetFileType
# 3       NtQuerySystemInformation
# 4               RegQueryValueExW
#                   ...
# 1074            RegQueryValueExW
# 1075            CoCreateInstance
# 1076                  LdrLoadDll
# 1077               RegOpenKeyExW
# 1078                 LoadStringW
# Name: t_15, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                      RegCloseKey
# 1                     LoadResource
# 2                      DeleteFileW
# 3                       LdrLoadDll
# 4                      RegCloseKey
#                    ...
# 1074                   RegCloseKey
# 1075       NtAllocateVirtualMemory
# 1076        LdrGetProcedureAddress
# 1077              FindFirstFileExW
# 1078    GetSystemWindowsDirectoryW
# Name: t_16, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0             RegOpenKeyExW
# 1            SizeofResource
# 2              NtCreateFile
# 3           LdrGetDllHandle
# 4             RegOpenKeyExW
#                ...
# 1074          RegOpenKeyExW
# 1075              NtOpenKey
# 1076           LdrUnloadDll
# 1077            LoadStringW
# 1078    GetSystemDirectoryW
# Name: t_17, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0             RegQueryValueExW
# 1                FindResourceA
# 2                  GetFileType
# 3       LdrGetProcedureAddress
# 4             RegQueryValueExW
#                  ...
# 1074          RegQueryValueExW
# 1075                   NtClose
# 1076                   NtClose
# 1077                LdrLoadDll
# 1078             RegOpenKeyExW
# Name: t_18, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                  RegCloseKey
# 1                 LoadResource
# 2                      NtClose
# 3               CoInitializeEx
# 4                  RegCloseKey
#                  ...
# 1074               RegCloseKey
# 1075             RegOpenKeyExW
# 1076                 NtOpenKey
# 1077    LdrGetProcedureAddress
# 1078                LdrLoadDll
# Name: t_19, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                     RegOpenKeyExW
# 1                    SizeofResource
# 2       SetUnhandledExceptionFilter
# 3                  CoCreateInstance
# 4                     RegOpenKeyExW
#                    ...
# 1074                  RegOpenKeyExW
# 1075                    RegCloseKey
# 1076                NtQueryValueKey
# 1077            GetNativeSystemInfo
# 1078         LdrGetProcedureAddress
# Name: t_20, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       RegQueryValueExW
# 1          FindResourceA
# 2            NtWriteFile
# 3             LdrLoadDll
# 4       RegQueryValueExW
#               ...
# 1074    RegQueryValueExW
# 1075       RegOpenKeyExW
# 1076             NtClose
# 1077         LoadStringW
# 1078    RegQueryValueExW
# Name: t_21, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                  RegCloseKey
# 1                 LoadResource
# 2              LdrGetDllHandle
# 3       LdrGetProcedureAddress
# 4                  RegCloseKey
#                  ...
# 1074               RegCloseKey
# 1075               RegCloseKey
# 1076                 NtOpenKey
# 1077           LdrGetDllHandle
# 1078               RegCloseKey
# Name: t_22, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                RegOpenKeyExW
# 1               SizeofResource
# 2       LdrGetProcedureAddress
# 3                   LdrLoadDll
# 4                RegOpenKeyExW
#                  ...
# 1074             RegOpenKeyExW
# 1075          NtDelayExecution
# 1076           NtQueryValueKey
# 1077    LdrGetProcedureAddress
# 1078             RegOpenKeyExW
# Name: t_23, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0             RegQueryValueExW
# 1                FindResourceA
# 2              LdrGetDllHandle
# 3       LdrGetProcedureAddress
# 4             RegQueryValueExW
#                  ...
# 1074          RegQueryValueExW
# 1075             CreateActCtxW
# 1076                   NtClose
# 1077             RegOpenKeyExW
# 1078          RegQueryValueExW
# Name: t_24, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                  RegCloseKey
# 1                 LoadResource
# 2       LdrGetProcedureAddress
# 3                CreateActCtxW
# 4                  RegCloseKey
#                  ...
# 1074               RegCloseKey
# 1075                LdrLoadDll
# 1076                 NtOpenKey
# 1077                 NtOpenKey
# 1078                 NtOpenKey
# Name: t_25, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                RegOpenKeyExW
# 1               SizeofResource
# 2                  NtWriteFile
# 3              FindResourceExW
# 4                RegOpenKeyExW
#                  ...
# 1074             RegOpenKeyExW
# 1075    LdrGetProcedureAddress
# 1076           NtQueryValueKey
# 1077           NtQueryValueKey
# 1078           NtQueryValueKey
# Name: t_26, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                       NtClose
# 1                 FindResourceA
# 2        GetTimeZoneInformation
# 3                  LoadResource
# 4                       NtClose
#                  ...
# 1074                    NtClose
# 1075    NtAllocateVirtualMemory
# 1076    NtAllocateVirtualMemory
# 1077            LdrGetDllHandle
# 1078                    NtClose
# Name: t_27, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                     NtOpenKey
# 1                    LdrLoadDll
# 2       GetSystemTimeAsFileTime
# 3                SizeofResource
# 4                     NtOpenKey
#                  ...
# 1074                  NtOpenKey
# 1075            LdrGetDllHandle
# 1076               SetErrorMode
# 1077     LdrGetProcedureAddress
# 1078                  NtOpenKey
# Name: t_28, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0              NtQueryValueKey
# 1       LdrGetProcedureAddress
# 2       GetTimeZoneInformation
# 3       LdrGetProcedureAddress
# 4              NtQueryValueKey
#                  ...
# 1074           NtQueryValueKey
# 1075    LdrGetProcedureAddress
# 1076             OleInitialize
# 1077           LdrGetDllHandle
# 1078           NtQueryValueKey
# Name: t_29, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                      NtClose
# 1              LdrGetDllHandle
# 2                  NtWriteFile
# 3                OleInitialize
# 4                      NtClose
#                  ...
# 1074                   NtClose
# 1075                 NtOpenKey
# 1076         SetWindowsHookExW
# 1077    LdrGetProcedureAddress
# 1078                   NtClose
# Name: t_30, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                     NtOpenKey
# 1        LdrGetProcedureAddress
# 2        GetTimeZoneInformation
# 3                     NtOpenKey
# 4                     NtOpenKey
#                  ...
# 1074                  NtOpenKey
# 1075                    NtClose
# 1076    GetSystemTimeAsFileTime
# 1077              RegOpenKeyExW
# 1078                RegCloseKey
# Name: t_31, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0               NtQueryValueKey
# 1               LdrGetDllHandle
# 2       GetSystemTimeAsFileTime
# 3               NtQueryValueKey
# 4               NtQueryValueKey
#                  ...
# 1074            NtQueryValueKey
# 1075              RegOpenKeyExW
# 1076    NtAllocateVirtualMemory
# 1077           RegQueryValueExW
# 1078             NtCreateMutant
# Name: t_32, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                      NtClose
# 1       LdrGetProcedureAddress
# 2                  NtWriteFile
# 3                      NtClose
# 4                      NtClose
#                  ...
# 1074                   NtClose
# 1075               RegCloseKey
# 1076                LdrLoadDll
# 1077               RegCloseKey
# 1078       GetNativeSystemInfo
# Name: t_33, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                       LdrLoadDll
# 1                    FindResourceA
# 2                     NtCreateFile
# 3                        NtOpenKey
# 4                       LdrLoadDll
#                    ...
# 1074                    LdrLoadDll
# 1075                 RegOpenKeyExW
# 1076        LdrGetProcedureAddress
# 1077               LdrGetDllHandle
# 1078    GetSystemWindowsDirectoryW
# Name: t_34, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           LdrGetProcedureAddress
# 1                  LdrGetDllHandle
# 2           GetTimeZoneInformation
# 3                  NtQueryValueKey
# 4           LdrGetProcedureAddress
#                    ...
# 1074        LdrGetProcedureAddress
# 1075              RegQueryValueExW
# 1076    GetSystemWindowsDirectoryW
# 1077        LdrGetProcedureAddress
# 1078                       NtClose
# Name: t_35, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       GetSystemWindowsDirectoryW
# 1           LdrGetProcedureAddress
# 2          GetSystemTimeAsFileTime
# 3                          NtClose
# 4       GetSystemWindowsDirectoryW
#                    ...
# 1074    GetSystemWindowsDirectoryW
# 1075                   RegCloseKey
# 1076                  NtCreateFile
# 1077                    LdrLoadDll
# 1078                    LdrLoadDll
# Name: t_36, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                 NtCreateFile
# 1                      NtClose
# 2                  NtWriteFile
# 3             GetSystemMetrics
# 4                 NtCreateFile
#                  ...
# 1074              NtCreateFile
# 1075             RegOpenKeyExW
# 1076           NtCreateSection
# 1077    LdrGetProcedureAddress
# 1078       GetSystemDirectoryW
# Name: t_37, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0               NtCreateSection
# 1                 RegOpenKeyExW
# 2        GetTimeZoneInformation
# 3       NtAllocateVirtualMemory
# 4               NtCreateSection
#                  ...
# 1074            NtCreateSection
# 1075                 NtQueryKey
# 1076         NtMapViewOfSection
# 1077            LdrGetDllHandle
# 1078                 LdrLoadDll
# Name: t_38, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0            NtMapViewOfSection
# 1              RegQueryValueExW
# 2       GetSystemTimeAsFileTime
# 3              GetSystemMetrics
# 4            NtMapViewOfSection
#                  ...
# 1074         NtMapViewOfSection
# 1075              RegOpenKeyExW
# 1076                    NtClose
# 1077     LdrGetProcedureAddress
# 1078        GetSystemDirectoryW
# Name: t_39, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                       NtClose
# 1       GetSystemTimeAsFileTime
# 2                   NtWriteFile
# 3                    LdrLoadDll
# 4                       NtClose
#                  ...
# 1074                    NtClose
# 1075                RegCloseKey
# 1076    GetSystemTimeAsFileTime
# 1077               SetErrorMode
# 1078                 LdrLoadDll
# Name: t_40, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                RegOpenKeyExA
# 1                RegOpenKeyExW
# 2       GetTimeZoneInformation
# 3       LdrGetProcedureAddress
# 4                RegOpenKeyExA
#                  ...
# 1074             RegOpenKeyExA
# 1075          RegQueryValueExW
# 1076         SetWindowsHookExW
# 1077                LdrLoadDll
# 1078    LdrGetProcedureAddress
# Name: t_41, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        LdrGetProcedureAddress
# 1              RegQueryValueExW
# 2       GetSystemTimeAsFileTime
# 3                 CreateActCtxW
# 4        LdrGetProcedureAddress
#                  ...
# 1074     LdrGetProcedureAddress
# 1075              RegOpenKeyExW
# 1076    GetSystemTimeAsFileTime
# 1077               SetErrorMode
# 1078            LdrGetDllHandle
# Name: t_42, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                 CreateActCtxW
# 1                   RegCloseKey
# 2                   NtWriteFile
# 3                    LdrLoadDll
# 4                 CreateActCtxW
#                  ...
# 1074              CreateActCtxW
# 1075           RegQueryValueExW
# 1076    NtAllocateVirtualMemory
# 1077           GetSystemMetrics
# 1078     LdrGetProcedureAddress
# Name: t_43, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                    LdrLoadDll
# 1                 RegOpenKeyExW
# 2                    WSAStartup
# 3        LdrGetProcedureAddress
# 4                    LdrLoadDll
#                  ...
# 1074                 LdrLoadDll
# 1075                RegCloseKey
# 1076    GetSystemTimeAsFileTime
# 1077            FindResourceExW
# 1078                 LdrLoadDll
# Name: t_44, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       LdrGetProcedureAddress
# 1             RegQueryValueExW
# 2                  NtWriteFile
# 3                   LdrLoadDll
# 4       LdrGetProcedureAddress
#                  ...
# 1074    LdrGetProcedureAddress
# 1075             RegOpenKeyExW
# 1076                   NtClose
# 1077              LoadResource
# 1078       GetSystemDirectoryW
# Name: t_45, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           GetSystemDirectoryW
# 1                   RegCloseKey
# 2       NtAllocateVirtualMemory
# 3        LdrGetProcedureAddress
# 4           GetSystemDirectoryW
#                  ...
# 1074                 LdrLoadDll
# 1075                RegCloseKey
# 1076           GetSystemMetrics
# 1077            FindResourceExW
# 1078                 LdrLoadDll
# Name: t_46, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                 RegOpenKeyExA
# 1                 RegOpenKeyExW
# 2        GetTimeZoneInformation
# 3                 RegOpenKeyExW
# 4                 RegOpenKeyExA
#                  ...
# 1074     LdrGetProcedureAddress
# 1075                  NtOpenKey
# 1076    NtAllocateVirtualMemory
# 1077               LoadResource
# 1078        GetSystemDirectoryW
# Name: t_47, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                    LdrLoadDll
# 1              RegQueryValueExW
# 2       GetSystemTimeAsFileTime
# 3        LdrGetProcedureAddress
# 4                    LdrLoadDll
#                  ...
# 1074              RegOpenKeyExW
# 1075                    NtClose
# 1076           GetSystemMetrics
# 1077            FindResourceExW
# 1078                 LdrLoadDll
# Name: t_48, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       LdrGetProcedureAddress
# 1                  RegCloseKey
# 2                  NtWriteFile
# 3              NtCreateSection
# 4       LdrGetProcedureAddress
#                  ...
# 1074          RegQueryValueExW
# 1075             RegOpenKeyExW
# 1076                LdrLoadDll
# 1077              LoadResource
# 1078       GetSystemDirectoryW
# Name: t_49, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                 RegOpenKeyExW
# 1                    LdrLoadDll
# 2                  SetErrorMode
# 3            NtMapViewOfSection
# 4                 RegOpenKeyExW
#                  ...
# 1074                RegCloseKey
# 1075                RegCloseKey
# 1076     LdrGetProcedureAddress
# 1077            FindResourceExW
# 1078    NtAllocateVirtualMemory
# Name: t_50, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0              RegQueryValueExW
# 1        LdrGetProcedureAddress
# 2          GetFileAttributesExW
# 3                 NtOpenProcess
# 4              RegQueryValueExW
#                  ...
# 1074              RegOpenKeyExW
# 1075              RegOpenKeyExW
# 1076    NtAllocateVirtualMemory
# 1077               LoadResource
# 1078            LdrGetDllHandle
# Name: t_51, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                  RegCloseKey
# 1                  RegCloseKey
# 2                 SetErrorMode
# 3                      NtClose
# 4                  RegCloseKey
#                  ...
# 1074    LdrGetProcedureAddress
# 1075               RegCloseKey
# 1076                LdrLoadDll
# 1077           FindResourceExW
# 1078    LdrGetProcedureAddress
# Name: t_52, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                RegOpenKeyExW
# 1               NtCreateMutant
# 2                 NtCreateFile
# 3                NtOpenProcess
# 4                RegOpenKeyExW
#                  ...
# 1074             RegOpenKeyExW
# 1075                LdrLoadDll
# 1076    LdrGetProcedureAddress
# 1077              LoadResource
# 1078     NtQueryAttributesFile
# Name: t_53, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       LdrGetProcedureAddress
# 1              LdrGetDllHandle
# 2              NtCreateSection
# 3            NtDuplicateObject
# 4       LdrGetProcedureAddress
#                  ...
# 1074          RegQueryValueExW
# 1075    LdrGetProcedureAddress
# 1076                WSAStartup
# 1077           FindResourceExW
# 1078              NtCreateFile
# Name: t_54, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                 RegOpenKeyExW
# 1        LdrGetProcedureAddress
# 2            NtMapViewOfSection
# 3                       NtClose
# 4                 RegOpenKeyExW
#                  ...
# 1074                RegCloseKey
# 1075           CoCreateInstance
# 1076    NtAllocateVirtualMemory
# 1077               LoadResource
# 1078            NtCreateSection
# Name: t_55, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0              RegQueryValueExW
# 1                       NtClose
# 2                       NtClose
# 3          NtUnmapViewOfSection
# 4              RegQueryValueExW
#                  ...
# 1074     LdrGetProcedureAddress
# 1075    NtAllocateVirtualMemory
# 1076            LdrGetDllHandle
# 1077            FindResourceExW
# 1078         NtMapViewOfSection
# Name: t_56, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                  RegCloseKey
# 1                NtOpenSection
# 2             SHGetFolderPathW
# 3                      NtClose
# 4                  RegCloseKey
#                  ...
# 1074             RegOpenKeyExW
# 1075            NtCreateMutant
# 1076    LdrGetProcedureAddress
# 1077              LoadResource
# 1078                   NtClose
# Name: t_57, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        LdrGetProcedureAddress
# 1               NtCreateSection
# 2       NtAllocateVirtualMemory
# 3                 NtOpenProcess
# 4        LdrGetProcedureAddress
#                  ...
# 1074           RegQueryValueExW
# 1075            LdrGetDllHandle
# 1076                 LdrLoadDll
# 1077            FindResourceExW
# 1078                 LdrLoadDll
# Name: t_58, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                RegOpenKeyExW
# 1           NtMapViewOfSection
# 2                 SetErrorMode
# 3            NtDuplicateObject
# 4                RegOpenKeyExW
#                  ...
# 1074               RegCloseKey
# 1075    LdrGetProcedureAddress
# 1076    LdrGetProcedureAddress
# 1077              LoadResource
# 1078       GetSystemDirectoryW
# Name: t_59, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0              RegQueryValueExW
# 1       NtAllocateVirtualMemory
# 2          GetFileAttributesExW
# 3                       NtClose
# 4              RegQueryValueExW
#                  ...
# 1074     LdrGetProcedureAddress
# 1075    NtAllocateVirtualMemory
# 1076    NtAllocateVirtualMemory
# 1077            FindResourceExW
# 1078                 LdrLoadDll
# Name: t_60, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                             RegCloseKey
# 1                                 NtClose
# 2                            SetErrorMode
# 3                 NtAllocateVirtualMemory
# 4                             RegCloseKey
#                       ...
# 1074    GetVolumeNameForVolumeMountPointW
# 1075           GetSystemWindowsDirectoryW
# 1076                           LdrLoadDll
# 1077                         LoadResource
# 1078                      LdrGetDllHandle
# Name: t_61, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# ...
# 1                FindResourceA
# 2                 SetErrorMode
# 3                      NtClose
# 4                RegOpenKeyExW
#                  ...
# 1074    LdrGetProcedureAddress
# 1075    LdrGetProcedureAddress
# 1076              LoadResource
# 1077    LdrGetProcedureAddress
# 1078          RegQueryValueExW
# Name: t_79, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                 LdrLoadDll
# 1            LdrGetDllHandle
# 2       GetFileAttributesExW
# 3                 LdrLoadDll
# 4                 LdrLoadDll
#                 ...
# 1074             RegEnumKeyW
# 1075         LdrGetDllHandle
# 1076        GetSystemMetrics
# 1077              LdrLoadDll
# 1078             RegCloseKey
# Name: t_80, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        LdrGetProcedureAddress
# 1        LdrGetProcedureAddress
# 2                  SetErrorMode
# 3        LdrGetProcedureAddress
# 4        LdrGetProcedureAddress
#                  ...
# 1074              RegOpenKeyExW
# 1075     LdrGetProcedureAddress
# 1076    NtAllocateVirtualMemory
# 1077     LdrGetProcedureAddress
# 1078              RegOpenKeyExW
# Name: t_81, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                RegEnumKeyW
# 1                    NtClose
# 2       GetFileAttributesExW
# 3                 LdrLoadDll
# 4                RegEnumKeyW
#                 ...
# 1074        RegQueryValueExW
# 1075              LdrLoadDll
# 1076              LdrLoadDll
# 1077              LdrLoadDll
# 1078        RegQueryValueExW
# Name: t_82, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                RegOpenKeyExW
# 1               NtCreateMutant
# 2                 SetErrorMode
# 3       LdrGetProcedureAddress
# 4                RegOpenKeyExW
#                  ...
# 1074               RegCloseKey
# 1075    LdrGetProcedureAddress
# 1076    LdrGetProcedureAddress
# 1077    LdrGetProcedureAddress
# 1078               RegCloseKey
# Name: t_83, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0              RegQueryValueExW
# 1                       NtClose
# 2          GetFileAttributesExW
# 3                 CreateActCtxW
# 4              RegQueryValueExW
#                  ...
# 1074                RegEnumKeyW
# 1075    NtAllocateVirtualMemory
# 1076               LdrUnloadDll
# 1077                 LdrLoadDll
# 1078              RegOpenKeyExW
# Name: t_84, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                  RegCloseKey
# 1                RegOpenKeyExW
# 2                 SetErrorMode
# 3                   LdrLoadDll
# 4                  RegCloseKey
#                  ...
# 1074               RegCloseKey
# 1075                LdrLoadDll
# 1076               DrawTextExW
# 1077    LdrGetProcedureAddress
# 1078          RegQueryValueExW
# Name: t_85, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                  RegEnumKeyW
# 1        NtQueryAttributesFile
# 2         GetFileAttributesExW
# 3         NtUnmapViewOfSection
# 4                  RegEnumKeyW
#                  ...
# 1074    LdrGetProcedureAddress
# 1075    LdrGetProcedureAddress
# 1076          GetSystemMetrics
# 1077                LdrLoadDll
# 1078               RegCloseKey
# Name: t_86, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                  RegCloseKey
# 1                FindResourceA
# 2                 SetErrorMode
# 3                      NtClose
# 4                  RegCloseKey
#                  ...
# 1074             RegOpenKeyExW
# 1075                LdrLoadDll
# 1076               DrawTextExW
# 1077    LdrGetProcedureAddress
# 1078             RegOpenKeyExW
# Name: t_87, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       LdrGetProcedureAddress
# 1                 LoadResource
# 2         GetFileAttributesExW
# 3       LdrGetProcedureAddress
# 4       LdrGetProcedureAddress
#                  ...
# 1074              NtCreateFile
# 1075              CreateThread
# 1076          GetSystemMetrics
# 1077         LookupAccountSidW
# 1078          RegQueryValueExW
# Name: t_88, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                 RegOpenKeyExW
# 1               LdrGetDllHandle
# 2                  SetErrorMode
# 3              GetSystemMetrics
# 4                 RegOpenKeyExW
#                  ...
# 1074                    NtClose
# 1075    NtAllocateVirtualMemory
# 1076               CreateThread
# 1077     LdrGetProcedureAddress
# 1078                RegCloseKey
# Name: t_89, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                 NtCreateFile
# 1       LdrGetProcedureAddress
# 2         GetFileAttributesExW
# 3                   LdrLoadDll
# 4                 NtCreateFile
#                  ...
# 1074      NtQueryDirectoryFile
# 1075          GetSystemMetrics
# 1076            NtResumeThread
# 1077         LookupAccountSidW
# 1078             RegOpenKeyExW
# Name: t_90, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                       NtClose
# 1                       NtClose
# 2                  SetErrorMode
# 3        LdrGetProcedureAddress
# 4                       NtClose
#                  ...
# 1074                    NtClose
# 1075    NtAllocateVirtualMemory
# 1076              RegOpenKeyExW
# 1077                 LdrLoadDll
# 1078           RegQueryValueExW
# Name: t_91, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0          NtQueryDirectoryFile
# 1                NtCreateMutant
# 2          GetFileAttributesExW
# 3       NtAllocateVirtualMemory
# 4          NtQueryDirectoryFile
#                  ...
# 1074     LdrGetProcedureAddress
# 1075                 LdrLoadDll
# 1076           RegQueryValueExW
# 1077     LdrGetProcedureAddress
# 1078                RegCloseKey
# Name: t_92, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                       NtClose
# 1                       NtClose
# 2                  SetErrorMode
# 3        LdrGetProcedureAddress
# 4                       NtClose
#                  ...
# 1074    NtAllocateVirtualMemory
# 1075     LdrGetProcedureAddress
# 1076                RegCloseKey
# 1077                 LdrLoadDll
# 1078              RegOpenKeyExW
# Name: t_93, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        LdrGetProcedureAddress
# 1               LdrGetDllHandle
# 2       NtAllocateVirtualMemory
# 3              GetSystemMetrics
# 4        LdrGetProcedureAddress
#                  ...
# 1074            LdrGetDllHandle
# 1075    NtAllocateVirtualMemory
# 1076              RegOpenKeyExW
# 1077     LdrGetProcedureAddress
# 1078                    NtClose
# Name: t_94, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                 CoCreateInstance
# 1           LdrGetProcedureAddress
# 2                     SetErrorMode
# 3                       LdrLoadDll
# 4       GetSystemWindowsDirectoryW
#                    ...
# 1074        LdrGetProcedureAddress
# 1075              GetSystemMetrics
# 1076              RegQueryValueExW
# 1077                    LdrLoadDll
# 1078                    LdrLoadDll
# Name: t_95, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                NtOpenSection
# 1                      NtClose
# 2         GetFileAttributesExW
# 3       LdrGetProcedureAddress
# 4                  LoadStringW
#                  ...
# 1074           LdrGetDllHandle
# 1075             RegOpenKeyExW
# 1076               RegCloseKey
# 1077    LdrGetProcedureAddress
# 1078    LdrGetProcedureAddress
# Name: t_96, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                 CreateDirectoryW
# 1                   NtCreateMutant
# 2                     SetErrorMode
# 3                 GetSystemMetrics
# 4       GetSystemWindowsDirectoryW
#                    ...
# 1074        LdrGetProcedureAddress
# 1075       NtAllocateVirtualMemory
# 1076                 RegOpenKeyExW
# 1077               LdrGetDllHandle
# 1078    GetSystemWindowsDirectoryW
# Name: t_97, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0                  NtCreateFile
# 1                       NtClose
# 2              FindFirstFileExW
# 3       NtAllocateVirtualMemory
# 4           GetSystemDirectoryW
#                  ...
# 1074            LdrGetDllHandle
# 1075           GetSystemMetrics
# 1076           RegQueryValueExW
# 1077            FindResourceExW
# 1078               NtCreateFile
# Name: t_98, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2421665981.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        LdrGetProcedureAddress
# 1                  NtCreateFile
# 2          NtQueryDirectoryFile
# 3                    LdrLoadDll
# 4                 RegOpenKeyExW
#                  ...
# 1074     LdrGetProcedureAddress
# 1075    NtAllocateVirtualMemory
# 1076                RegCloseKey
# 1077               LoadResource
# 1078            NtCreateSection
# Name: t_99, Length: 1079, dtype: object' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')

# %% [markdown]
# ## Create `Benign/API_Patterns_Benign.csv`

# %%
patterns = []
print("Injecting API patterns...")
for row in range(df.shape[0]):
    patterns.append(list_to_str(inverse_labelled_df.iloc[row,1:101].transpose().to_list()))
inverse_labelled_df['pattern'] = patterns
inverse_labelled_df.to_csv(f"Benign/API_Patterns_Benign.csv", index=False)
inverse_labelled_df
# Out:
# Injecting API patterns...
# C:\Users\ESCALONA-PC03\AppData\Local\Temp\ipykernel_10008\2237446881.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   inverse_labelled_df['pattern'] = patterns
#                                   hash                          t_0  \
# 0     5b51d65972a349f90a86984c26b12b30                 SetErrorMode
# 1     ceb8cc125478fad641daa4e04e9b2f19                GetSystemInfo
# 2     f108600edf46d7c20f6acc522aeba6df      GetSystemTimeAsFileTime
# 3     711be6337cb78a948f04759a0bd210ce      GetSystemTimeAsFileTime
# 4     6de26f67ceb1e3303b889489010f4c3f                 SetErrorMode
# ...                                ...                          ...
# 1074  d282ef96a93986f89825508812958354                 SetErrorMode
# 1075  c0389d256f976044adf570f0df908953      GetSystemTimeAsFileTime
# 1076  20316e717de5db169aecbb67377504ce  SetUnhandledExceptionFilter
# 1077  ce945d424b93ea73fbbedf0254f6bc07                      NtClose
# 1078  70b78f7bdf9c484913d10365348ed2ba                 SetErrorMode
#
#                               t_1                          t_2  \
# 0                   OleInitialize              LdrGetDllHandle
# 1         NtAllocateVirtualMemory                NtOpenSection
# 2          NtProtectVirtualMemory  SetUnhandledExceptionFilter
# 3                      LdrLoadDll       LdrGetProcedureAddress
# 4                   OleInitialize              LdrGetDllHandle
# ...                           ...                          ...
# 1074                OleInitialize              LdrGetDllHandle
# 1075  SetUnhandledExceptionFilter                 GetCursorPos
# 1076               NtCreateMutant      NtAllocateVirtualMemory
# 1077                    NtOpenKey              NtQueryValueKey
# 1078              LdrGetDllHandle       LdrGetProcedureAddress
#
#                          t_3                      t_4                     t_5  \
# 0                 LdrLoadDll   LdrGetProcedureAddress              LdrLoadDll
# 1               GetTempPathW         CreateDirectoryW      GetFileAttributesW
# 2     GetTimeZoneInformation  GetSystemTimeAsFileTime  GetTimeZoneInformation
# 3                 LdrLoadDll   LdrGetProcedureAddress              LdrLoadDll
# 4                 LdrLoadDll   LdrGetProcedureAddress              LdrLoadDll
# ...                      ...                      ...                     ...
# 1074              LdrLoadDll   LdrGetProcedureAddress              LdrLoadDll
# 1075            SetErrorMode            FindResourceW       SetWindowsHookExW
# 1076                 NtClose           NtCreateMutant                 NtClose
# 1077                 NtClose                NtOpenKey         NtQueryValueKey
# 1078     GetSystemDirectoryW  NtAllocateVirtualMemory     NtFreeVirtualMemory
#
#                           t_6                     t_7  \
# 0      LdrGetProcedureAddress              LdrLoadDll
# 1            FindFirstFileExW             DeleteFileW
# 2     GetSystemTimeAsFileTime  GetTimeZoneInformation
# 3      LdrGetProcedureAddress              LdrLoadDll
# 4      LdrGetProcedureAddress              LdrLoadDll
# ...                       ...                     ...
# 1074   LdrGetProcedureAddress              LdrLoadDll
# 1075           CoInitializeEx       NtDuplicateObject
# 1076           NtCreateMutant                 NtClose
# 1077                  NtClose         LdrGetDllHandle
# 1078  NtAllocateVirtualMemory              LdrLoadDll
#
#                           t_8  ...                     t_91  \
# 0      LdrGetProcedureAddress  ...                  NtClose
# 1        NtQueryDirectoryFile  ...                  NtClose
# 2     GetSystemTimeAsFileTime  ...             SetErrorMode
# 3      LdrGetProcedureAddress  ...   LdrGetProcedureAddress
# 4      LdrGetProcedureAddress  ...                  NtClose
# ...                       ...  ...                      ...
# 1074   LdrGetProcedureAddress  ...                  NtClose
# 1075  NtAllocateVirtualMemory  ...  NtAllocateVirtualMemory
# 1076  NtAllocateVirtualMemory  ...            RegOpenKeyExW
# 1077   LdrGetProcedureAddress  ...               LdrLoadDll
# 1078      GetSystemDirectoryW  ...         RegQueryValueExW
#
#                          t_92                     t_93  \
# 0        NtQueryDirectoryFile                  NtClose
# 1              NtCreateMutant                  NtClose
# 2        GetFileAttributesExW             SetErrorMode
# 3     NtAllocateVirtualMemory   LdrGetProcedureAddress
# 4        NtQueryDirectoryFile                  NtClose
# ...                       ...                      ...
# 1074   LdrGetProcedureAddress  NtAllocateVirtualMemory
# 1075               LdrLoadDll   LdrGetProcedureAddress
# 1076         RegQueryValueExW              RegCloseKey
# 1077   LdrGetProcedureAddress               LdrLoadDll
# 1078              RegCloseKey            RegOpenKeyExW
#
#                          t_94                        t_95  \
# 0      LdrGetProcedureAddress            CoCreateInstance
# 1             LdrGetDllHandle      LdrGetProcedureAddress
# 2     NtAllocateVirtualMemory                SetErrorMode
# 3            GetSystemMetrics                  LdrLoadDll
# 4      LdrGetProcedureAddress  GetSystemWindowsDirectoryW
# ...                       ...                         ...
# 1074          LdrGetDllHandle      LdrGetProcedureAddress
# 1075  NtAllocateVirtualMemory            GetSystemMetrics
# 1076            RegOpenKeyExW            RegQueryValueExW
# 1077   LdrGetProcedureAddress                  LdrLoadDll
# 1078                  NtClose                  LdrLoadDll
#
#                         t_96                        t_97  \
# 0              NtOpenSection            CreateDirectoryW
# 1                    NtClose              NtCreateMutant
# 2       GetFileAttributesExW                SetErrorMode
# 3     LdrGetProcedureAddress            GetSystemMetrics
# 4                LoadStringW  GetSystemWindowsDirectoryW
# ...                      ...                         ...
# 1074         LdrGetDllHandle      LdrGetProcedureAddress
# 1075           RegOpenKeyExW     NtAllocateVirtualMemory
# 1076             RegCloseKey               RegOpenKeyExW
# 1077  LdrGetProcedureAddress             LdrGetDllHandle
# 1078  LdrGetProcedureAddress  GetSystemWindowsDirectoryW
#
#                          t_98                     t_99  \
# 0                NtCreateFile   LdrGetProcedureAddress
# 1                     NtClose             NtCreateFile
# 2            FindFirstFileExW     NtQueryDirectoryFile
# 3     NtAllocateVirtualMemory               LdrLoadDll
# 4         GetSystemDirectoryW            RegOpenKeyExW
# ...                       ...                      ...
# 1074          LdrGetDllHandle   LdrGetProcedureAddress
# 1075         GetSystemMetrics  NtAllocateVirtualMemory
# 1076         RegQueryValueExW              RegCloseKey
# 1077          FindResourceExW             LoadResource
# 1078             NtCreateFile          NtCreateSection
#
#                                                 pattern
# 0     SetErrorMode,OleInitialize,LdrGetDllHandle,Ldr...
# 1     GetSystemInfo,NtAllocateVirtualMemory,NtOpenSe...
# 2     GetSystemTimeAsFileTime,NtProtectVirtualMemory...
# 3     GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 4     SetErrorMode,OleInitialize,LdrGetDllHandle,Ldr...
# ...                                                 ...
# 1074  SetErrorMode,OleInitialize,LdrGetDllHandle,Ldr...
# 1075  GetSystemTimeAsFileTime,SetUnhandledExceptionF...
# 1076  SetUnhandledExceptionFilter,NtCreateMutant,NtA...
# 1077  NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOp...
# 1078  SetErrorMode,LdrGetDllHandle,LdrGetProcedureAd...
#
# [1079 rows x 102 columns]
