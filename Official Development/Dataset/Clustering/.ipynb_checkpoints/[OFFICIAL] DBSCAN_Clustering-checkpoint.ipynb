# %%
import pandas as pd
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.metrics import davies_bouldin_score
# from sklearn.cluster import SpectralClustering, AgglomerativeClustering, OPTICS, MeanShift # Not working

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

#Load list of API calls
API_LIST = "../api_calls.txt"
DELIMITER = "NaN"
API_FILE = open(API_LIST,"r")
APIS = API_FILE.readline().split(',')
APIS.append(DELIMITER) #Add the label for NaN values.
API_FILE.close()

#Random Seed
seed = 1

def list_to_str(ls:list):
    '''Convert list to a stringified version (comma delimited).'''
    output = ""
    for l in ls:
        output += str(l) + ","
    return output[0:len(output)-1]

def load_df():
    '''Load the dataset file (CSV) as DataFrame'''
    print("Loading DF...")
    # df = pd.read_csv("../oliveira.csv") # MAKE SURE THIS IS SET AS `oliveira.csv`
    df = pd.read_csv("../oliveira_labelled.csv") # MAKE SURE THIS IS SET AS `oliveira.csv`
    df = df[df['malware'] == 1].copy()
    # df = df.drop('malware', axis=1)
    # df = df.drop('type', axis=1)
    print("")
    return df.reset_index().iloc[:,1:]

def get_x(df:pd.DataFrame):
    '''Get the feature columns of the DataFrame'''
    return df.iloc[:,1:101]#df.iloc[:, 1:101]

def clean_format_dataset(input_df:pd.DataFrame):
    #Remove falsely labelled malicious samples
    input_df = input_df[input_df['type'] != '_']
    
    #Remove specific malware types
    # <CODE HERE>
    
    #Remove type column
    #type_col = input_df.pop('type')
    
    #Removing hash column
    #hash_col = input_df.pop('hash')
    
    #Re-arranging column positions
    #label_col = input_df.pop('malware')
    #input_df = pd.concat([label_col, input_df], axis=1)
    #input_df = pd.concat([input_df, hash_col], axis=1) # <=== This will be retained for the benefit of model evaluation.
    #input_df = pd.concat([input_df, type_col], axis=1) # <=== This will be retained for the benefit of model evaluation.
    return input_df

#Inverse Label Encoding
def inverse_labeller(item):
    '''Low Level. Converts encoded API calls to string API calls'''
    global APIS
    return item.map(lambda x: APIS[int(x)])
def inverse_label(df:pd.DataFrame):
    '''High Level. Converts encoded API calls to string API calls'''
    df2 = df.copy(deep=True)
    df2.iloc[:, 1:101] = df2.iloc[:, 1:101].apply(inverse_labeller, axis=1, result_type='reduce')
    print("")
    return df2

def inject_patterns(inner_df:pd.DataFrame, inverse_labelled_df:pd.DataFrame):
    '''Injects the API call patterns of each sample as its last column'''
    patterns = []
    print("Injecting API patterns...")
    for row in range(inner_df.shape[0]):
        patterns.append(list_to_str(inverse_labelled_df.iloc[row,1:101].transpose().to_list()))
    inner_df['pattern'] = patterns
    inverse_labelled_df = inverse_label(inner_df)
    inverse_labelled_df.to_csv(f"Clustering/Malicious/API_Patterns.csv", index=False) #For readability
    return inner_df, inverse_labelled_df # DBSCAN requires only the numeric label encoded version of the API Calls

# def common_api_cluster(inner_df:pd.DataFrame, name:str):
#     '''Determine the most common API call patterns for each cluster'''
#     global df
#     inner_df = df
#     clusters = inner_df['cluster'].unique()
#     clusters.sort()
#     commonAPI = []
#     print("Searching for Common API Patterns per Cluster...")
#     print(clusters)
#     for cluster in clusters:
#         raw_commonC = inner_df[inner_df['cluster']==cluster]['pattern']#.value_counts()
#         commonC = raw_commonC.value_counts().to_frame(name='counts').reset_index()
#         commonAPI.append([cluster, commonC['counts'].iloc[0], round(commonC['counts'].iloc[0]/raw_commonC.shape[0],4), commonC['pattern'].iloc[0]])
#     commonAPI = pd.DataFrame(commonAPI, columns=['cluster', 'count', 'match_ratio', 'pattern'])
#     commonAPI.to_csv(f"Clustering/Malicious/Manual_{name}_Common_API_Cluster.csv", index=False)
#     print("")
#     print("Average Match Ratio:", commonAPI['match_ratio'].mean())
#     return commonAPI

def get_samplehash_common(inner_df:pd.DataFrame, common_counts:pd.DataFrame, name:str, samplesize:int):
    '''Get sample hashes from each cluster that matches the common API call pattern of the cluster.'''
    hashes = []
    for i in range(inner_df.shape[0]):
        hashes.append([inner_df.iloc[i,:]['cluster'], inner_df.iloc[i,:]['hash'], '_', inner_df.iloc[i,:]['pattern']])
    hashes = pd.DataFrame(hashes, columns=['cluster', 'hash', 'type', 'pattern'])
    hashes['type'] = inner_df['type']
    hashes.to_csv(f"Clustering/Malicious/Manual_{name}_SampleHash_Common.csv", index=False)
    print("")
    return hashes
# Out:
# C:\Users\ejose\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = load_df() # Load raw oliveira_labelled.csv
df = clean_format_dataset(df)
inv_df = inverse_label(df.copy())
df, inv_label_df = inject_patterns(df.copy(), inv_df) #Just to make it more readable.
# reserve_df = df.copy()
# Out:
# Loading DF...
#
#
# Injecting API patterns...

# %%
display("DF for DBSCAN to Use",df)
display("Human readable version of the one above",inv_label_df)
# Out:
# 'DF for DBSCAN to Use'
#                                    hash  t_0  t_1  t_2  t_3  t_4  t_5  t_6  \
# 0      071e8c3f8922e186e57548cd4c703a5d  112  274  158  215  274  158  215
# 1      33f8e6d08a6aae939f25a8e0d63dd523   82  208  187  208  172  117  172
# 2      b68abd064e975e1c6d5f25e748663076   16  110  240  117  240  117  240
# 3      72049be7bd30ea61297ea624ae198067   82  208  187  208  172  117  172
# 4      c9b3700a77facf29172f32df6bc77f48   82  240  117  240  117  240  117
# ...                                 ...  ...  ...  ...  ...  ...  ...  ...
# 42792  e3d6d58faa040f0f9742c9d0eaf58be4   82  240  117  240  117  240  117
# 42793  9b917bab7f32188ae40c744f2be9aaf8   82  240  117  240  117  240  117
# 42794  35a18ee05f75f04912018d9f462cb990   82  240  117  240  117  240  117
# 42795  654139d715abcf7ecdddbef5a84f224b   82  240  117  240  117  240  117
# 42796  078c9d4e7be4819a06974c6f292a4857  112  274  158  215  274  158  215
#
#        t_7  t_8  ...  t_93  t_94  t_95  t_96  t_97  t_98  t_99  malware  \
# 0      298   76  ...   135   171   215    35   208    56    71        1
# 1      117  172  ...   117    71   297   135   171   215    35        1
# 2      117  240  ...   123    65   112   123    65   113   112        1
# 3      117  172  ...   208   302   187   208   302   228   302        1
# 4      240  117  ...    40   209   260   141   260   141   260        1
# ...    ...  ...  ...   ...   ...   ...   ...   ...   ...   ...      ...
# 42792  240  117  ...   141   260   141   260   141   260   141        1
# 42793  240  117  ...    82   159   224    82   159   224    82        1
# 42794  240  117  ...   260   141   260   141   260   141   260        1
# 42795  240  117  ...   141   260   141   260   141   260   141        1
# 42796  298   76  ...   135   171   215    35   208    56    71        1
#
#          type                                            pattern
# 0      trojan  RegOpenKeyExA,NtOpenKey,NtQueryValueKey,NtClos...
# 1         pua  GetSystemTimeAsFileTime,NtAllocateVirtualMemor...
# 2      trojan  SetUnhandledExceptionFilter,OleInitialize,LdrL...
# 3      trojan  GetSystemTimeAsFileTime,NtAllocateVirtualMemor...
# 4      trojan  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# ...       ...                                                ...
# 42792  trojan  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 42793  trojan  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 42794  trojan  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 42795  trojan  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 42796  trojan  RegOpenKeyExA,NtOpenKey,NtQueryValueKey,NtClos...
#
# [40159 rows x 104 columns]
# 'Human readable version of the one above'
#                                    hash                          t_0  \
# 0      071e8c3f8922e186e57548cd4c703a5d                RegOpenKeyExA
# 1      33f8e6d08a6aae939f25a8e0d63dd523      GetSystemTimeAsFileTime
# 2      b68abd064e975e1c6d5f25e748663076  SetUnhandledExceptionFilter
# 3      72049be7bd30ea61297ea624ae198067      GetSystemTimeAsFileTime
# 4      c9b3700a77facf29172f32df6bc77f48      GetSystemTimeAsFileTime
# ...                                 ...                          ...
# 42792  e3d6d58faa040f0f9742c9d0eaf58be4      GetSystemTimeAsFileTime
# 42793  9b917bab7f32188ae40c744f2be9aaf8      GetSystemTimeAsFileTime
# 42794  35a18ee05f75f04912018d9f462cb990      GetSystemTimeAsFileTime
# 42795  654139d715abcf7ecdddbef5a84f224b      GetSystemTimeAsFileTime
# 42796  078c9d4e7be4819a06974c6f292a4857                RegOpenKeyExA
#
#                            t_1                     t_2  \
# 0                    NtOpenKey         NtQueryValueKey
# 1      NtAllocateVirtualMemory     NtFreeVirtualMemory
# 2                OleInitialize              LdrLoadDll
# 3      NtAllocateVirtualMemory     NtFreeVirtualMemory
# 4                   LdrLoadDll  LdrGetProcedureAddress
# ...                        ...                     ...
# 42792               LdrLoadDll  LdrGetProcedureAddress
# 42793               LdrLoadDll  LdrGetProcedureAddress
# 42794               LdrLoadDll  LdrGetProcedureAddress
# 42795               LdrLoadDll  LdrGetProcedureAddress
# 42796                NtOpenKey         NtQueryValueKey
#
#                            t_3                     t_4  \
# 0                      NtClose               NtOpenKey
# 1      NtAllocateVirtualMemory         LdrGetDllHandle
# 2       LdrGetProcedureAddress              LdrLoadDll
# 3      NtAllocateVirtualMemory         LdrGetDllHandle
# 4                   LdrLoadDll  LdrGetProcedureAddress
# ...                        ...                     ...
# 42792               LdrLoadDll  LdrGetProcedureAddress
# 42793               LdrLoadDll  LdrGetProcedureAddress
# 42794               LdrLoadDll  LdrGetProcedureAddress
# 42795               LdrLoadDll  LdrGetProcedureAddress
# 42796                  NtClose               NtOpenKey
#
#                           t_5                     t_6                     t_7  \
# 0             NtQueryValueKey                 NtClose   NtQueryAttributesFile
# 1      LdrGetProcedureAddress         LdrGetDllHandle  LdrGetProcedureAddress
# 2      LdrGetProcedureAddress              LdrLoadDll  LdrGetProcedureAddress
# 3      LdrGetProcedureAddress         LdrGetDllHandle  LdrGetProcedureAddress
# 4                  LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# ...                       ...                     ...                     ...
# 42792              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 42793              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 42794              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 42795              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 42796         NtQueryValueKey                 NtClose   NtQueryAttributesFile
#
#                           t_8  ...                     t_93  \
# 0                 LoadStringA  ...          NtCreateSection
# 1             LdrGetDllHandle  ...   LdrGetProcedureAddress
# 2                  LdrLoadDll  ...         RegQueryValueExA
# 3             LdrGetDllHandle  ...  NtAllocateVirtualMemory
# 4      LdrGetProcedureAddress  ...         RegQueryInfoKeyW
# ...                       ...  ...                      ...
# 42792  LdrGetProcedureAddress  ...         RegQueryValueExW
# 42793  LdrGetProcedureAddress  ...  GetSystemTimeAsFileTime
# 42794  LdrGetProcedureAddress  ...            RegOpenKeyExW
# 42795  LdrGetProcedureAddress  ...         RegQueryValueExW
# 42796             LoadStringA  ...          NtCreateSection
#
#                              t_94                 t_95  \
# 0              NtMapViewOfSection              NtClose
# 1      GetSystemWindowsDirectoryW         NtCreateFile
# 2                     RegCloseKey        RegOpenKeyExA
# 3            NtWriteVirtualMemory  NtFreeVirtualMemory
# 4                   RegEnumKeyExW        RegOpenKeyExW
# ...                           ...                  ...
# 42792               RegOpenKeyExW     RegQueryValueExW
# 42793            NtDelayExecution          EnumWindows
# 42794            RegQueryValueExW        RegOpenKeyExW
# 42795               RegOpenKeyExW     RegQueryValueExW
# 42796          NtMapViewOfSection              NtClose
#
#                           t_96                     t_97  \
# 0             GetSystemMetrics  NtAllocateVirtualMemory
# 1              NtCreateSection       NtMapViewOfSection
# 2             RegQueryValueExA              RegCloseKey
# 3      NtAllocateVirtualMemory     NtWriteVirtualMemory
# 4             RegQueryValueExW            RegOpenKeyExW
# ...                        ...                      ...
# 42792            RegOpenKeyExW         RegQueryValueExW
# 42793  GetSystemTimeAsFileTime         NtDelayExecution
# 42794         RegQueryValueExW            RegOpenKeyExW
# 42795            RegOpenKeyExW         RegQueryValueExW
# 42796         GetSystemMetrics  NtAllocateVirtualMemory
#
#                          t_98                        t_99 malware    type  \
# 0               CreateActCtxW  GetSystemWindowsDirectoryW       1  trojan
# 1                     NtClose            GetSystemMetrics       1     pua
# 2               RegEnumKeyExA               RegOpenKeyExA       1  trojan
# 3      NtProtectVirtualMemory        NtWriteVirtualMemory       1  trojan
# 4            RegQueryValueExW               RegOpenKeyExW       1  trojan
# ...                       ...                         ...     ...     ...
# 42792           RegOpenKeyExW            RegQueryValueExW       1  trojan
# 42793             EnumWindows     GetSystemTimeAsFileTime       1  trojan
# 42794        RegQueryValueExW               RegOpenKeyExW       1  trojan
# 42795           RegOpenKeyExW            RegQueryValueExW       1  trojan
# 42796           CreateActCtxW  GetSystemWindowsDirectoryW       1  trojan
#
#                                                  pattern
# 0      RegOpenKeyExA,NtOpenKey,NtQueryValueKey,NtClos...
# 1      GetSystemTimeAsFileTime,NtAllocateVirtualMemor...
# 2      SetUnhandledExceptionFilter,OleInitialize,LdrL...
# 3      GetSystemTimeAsFileTime,NtAllocateVirtualMemor...
# 4      GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# ...                                                  ...
# 42792  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 42793  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 42794  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 42795  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 42796  RegOpenKeyExA,NtOpenKey,NtQueryValueKey,NtClos...
#
# [40159 rows x 104 columns]

# %%
dbscan = DBSCAN(algorithm='auto', n_jobs=-1, min_samples=1, metric='euclidean')
X = get_x(df) # <== Uses the numerical API calls (i.e., label encoded) instead of string API calls (i.e., inverse label encoded)
display("X (features) for DBSCAN to use(requires in numberic form)", X)
dbscan.fit(X)
print("Silhouette Score:", silhouette_score(X, dbscan.labels_, random_state=1))
print("Davis Bouldin Score:", davies_bouldin_score(X, dbscan.labels_))
# Out:
# 'X (features) for DBSCAN to use(requires in numberic form)'
#        t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  t_8  t_9  ...  t_90  t_91  \
# 0      112  274  158  215  274  158  215  298   76  208  ...   117    71
# 1       82  208  187  208  172  117  172  117  172  117  ...    60    81
# 2       16  110  240  117  240  117  240  117  240  117  ...   123    65
# 3       82  208  187  208  172  117  172  117  172  117  ...   215   208
# 4       82  240  117  240  117  240  117  240  117  172  ...    40   209
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 42792   82  240  117  240  117  240  117  240  117  172  ...   260   141
# 42793   82  240  117  240  117  240  117  240  117  172  ...    82   159
# 42794   82  240  117  240  117  240  117  240  117  172  ...   141   260
# 42795   82  240  117  240  117  240  117  240  117  172  ...   260   141
# 42796  112  274  158  215  274  158  215  298   76  208  ...   117    71
#
#        t_92  t_93  t_94  t_95  t_96  t_97  t_98  t_99
# 0       297   135   171   215    35   208    56    71
# 1       240   117    71   297   135   171   215    35
# 2       112   123    65   112   123    65   113   112
# 3       302   208   302   187   208   302   228   302
# 4       260    40   209   260   141   260   141   260
# ...     ...   ...   ...   ...   ...   ...   ...   ...
# 42792   260   141   260   141   260   141   260   141
# 42793   224    82   159   224    82   159   224    82
# 42794   141   260   141   260   141   260   141   260
# 42795   260   141   260   141   260   141   260   141
# 42796   297   135   171   215    35   208    56    71
#
# [40159 rows x 100 columns]
# Silhouette Score: 0.7629174033217958
# Davis Bouldin Score: 0.0

# %%
# TOP 10 CLUSTERS BY SAMPLE QUANTITY
df['cluster'] = dbscan.labels_
display(df['cluster'].value_counts()[0:10]) # Top 10 clusters by quantity
display(df['cluster'].value_counts(ascending=True)[0:10]) # Top 10 clusters by quantity

df.to_csv(f"./Clustering/Malicious/Manual_DBSCAN_Clustering.csv", index=False)
df = inverse_label(df) # To make a string API Call version of the clustering results 
df.to_csv(f"./Clustering/Malicious/Manual_DBSCAN_Encoded_Clustering.csv", index=False)

# commonAPI = common_api_cluster(df, "DBSCAN")
# display(commonAPI)
# Out:
# cluster
# 0      3305
# 9      1114
# 99     1093
# 21     1040
# 146     861
# 36      801
# 17      738
# 37      698
# 47      685
# 19      575
# Name: count, dtype: int64
# cluster
# 5745    1
# 7630    1
# 7631    1
# 7632    1
# 7633    1
# 7634    1
# 7636    1
# 7637    1
# 7638    1
# 7639    1
# Name: count, dtype: int64

# %%
df
# Out:
#                                    hash                          t_0  \
# 0      071e8c3f8922e186e57548cd4c703a5d                RegOpenKeyExA
# 1      33f8e6d08a6aae939f25a8e0d63dd523      GetSystemTimeAsFileTime
# 2      b68abd064e975e1c6d5f25e748663076  SetUnhandledExceptionFilter
# 3      72049be7bd30ea61297ea624ae198067      GetSystemTimeAsFileTime
# 4      c9b3700a77facf29172f32df6bc77f48      GetSystemTimeAsFileTime
# ...                                 ...                          ...
# 42792  e3d6d58faa040f0f9742c9d0eaf58be4      GetSystemTimeAsFileTime
# 42793  9b917bab7f32188ae40c744f2be9aaf8      GetSystemTimeAsFileTime
# 42794  35a18ee05f75f04912018d9f462cb990      GetSystemTimeAsFileTime
# 42795  654139d715abcf7ecdddbef5a84f224b      GetSystemTimeAsFileTime
# 42796  078c9d4e7be4819a06974c6f292a4857                RegOpenKeyExA
#
#                            t_1                     t_2  \
# 0                    NtOpenKey         NtQueryValueKey
# 1      NtAllocateVirtualMemory     NtFreeVirtualMemory
# 2                OleInitialize              LdrLoadDll
# 3      NtAllocateVirtualMemory     NtFreeVirtualMemory
# 4                   LdrLoadDll  LdrGetProcedureAddress
# ...                        ...                     ...
# 42792               LdrLoadDll  LdrGetProcedureAddress
# 42793               LdrLoadDll  LdrGetProcedureAddress
# 42794               LdrLoadDll  LdrGetProcedureAddress
# 42795               LdrLoadDll  LdrGetProcedureAddress
# 42796                NtOpenKey         NtQueryValueKey
#
#                            t_3                     t_4  \
# 0                      NtClose               NtOpenKey
# 1      NtAllocateVirtualMemory         LdrGetDllHandle
# 2       LdrGetProcedureAddress              LdrLoadDll
# 3      NtAllocateVirtualMemory         LdrGetDllHandle
# 4                   LdrLoadDll  LdrGetProcedureAddress
# ...                        ...                     ...
# 42792               LdrLoadDll  LdrGetProcedureAddress
# 42793               LdrLoadDll  LdrGetProcedureAddress
# 42794               LdrLoadDll  LdrGetProcedureAddress
# 42795               LdrLoadDll  LdrGetProcedureAddress
# 42796                  NtClose               NtOpenKey
#
#                           t_5                     t_6                     t_7  \
# 0             NtQueryValueKey                 NtClose   NtQueryAttributesFile
# 1      LdrGetProcedureAddress         LdrGetDllHandle  LdrGetProcedureAddress
# 2      LdrGetProcedureAddress              LdrLoadDll  LdrGetProcedureAddress
# 3      LdrGetProcedureAddress         LdrGetDllHandle  LdrGetProcedureAddress
# 4                  LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# ...                       ...                     ...                     ...
# 42792              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 42793              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 42794              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 42795              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 42796         NtQueryValueKey                 NtClose   NtQueryAttributesFile
#
#                           t_8  ...                        t_94  \
# 0                 LoadStringA  ...          NtMapViewOfSection
# 1             LdrGetDllHandle  ...  GetSystemWindowsDirectoryW
# 2                  LdrLoadDll  ...                 RegCloseKey
# 3             LdrGetDllHandle  ...        NtWriteVirtualMemory
# 4      LdrGetProcedureAddress  ...               RegEnumKeyExW
# ...                       ...  ...                         ...
# 42792  LdrGetProcedureAddress  ...               RegOpenKeyExW
# 42793  LdrGetProcedureAddress  ...            NtDelayExecution
# 42794  LdrGetProcedureAddress  ...            RegQueryValueExW
# 42795  LdrGetProcedureAddress  ...               RegOpenKeyExW
# 42796             LoadStringA  ...          NtMapViewOfSection
#
#                       t_95                     t_96                     t_97  \
# 0                  NtClose         GetSystemMetrics  NtAllocateVirtualMemory
# 1             NtCreateFile          NtCreateSection       NtMapViewOfSection
# 2            RegOpenKeyExA         RegQueryValueExA              RegCloseKey
# 3      NtFreeVirtualMemory  NtAllocateVirtualMemory     NtWriteVirtualMemory
# 4            RegOpenKeyExW         RegQueryValueExW            RegOpenKeyExW
# ...                    ...                      ...                      ...
# 42792     RegQueryValueExW            RegOpenKeyExW         RegQueryValueExW
# 42793          EnumWindows  GetSystemTimeAsFileTime         NtDelayExecution
# 42794        RegOpenKeyExW         RegQueryValueExW            RegOpenKeyExW
# 42795     RegQueryValueExW            RegOpenKeyExW         RegQueryValueExW
# 42796              NtClose         GetSystemMetrics  NtAllocateVirtualMemory
#
#                          t_98                        t_99 malware    type  \
# 0               CreateActCtxW  GetSystemWindowsDirectoryW       1  trojan
# 1                     NtClose            GetSystemMetrics       1     pua
# 2               RegEnumKeyExA               RegOpenKeyExA       1  trojan
# 3      NtProtectVirtualMemory        NtWriteVirtualMemory       1  trojan
# 4            RegQueryValueExW               RegOpenKeyExW       1  trojan
# ...                       ...                         ...     ...     ...
# 42792           RegOpenKeyExW            RegQueryValueExW       1  trojan
# 42793             EnumWindows     GetSystemTimeAsFileTime       1  trojan
# 42794        RegQueryValueExW               RegOpenKeyExW       1  trojan
# 42795           RegOpenKeyExW            RegQueryValueExW       1  trojan
# 42796           CreateActCtxW  GetSystemWindowsDirectoryW       1  trojan
#
#                                                  pattern cluster
# 0      RegOpenKeyExA,NtOpenKey,NtQueryValueKey,NtClos...       0
# 1      GetSystemTimeAsFileTime,NtAllocateVirtualMemor...       1
# 2      SetUnhandledExceptionFilter,OleInitialize,LdrL...       2
# 3      GetSystemTimeAsFileTime,NtAllocateVirtualMemor...       3
# 4      GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...       4
# ...                                                  ...     ...
# 42792  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...      17
# 42793  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...   11490
# 42794  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...   11491
# 42795  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...      17
# 42796  RegOpenKeyExA,NtOpenKey,NtQueryValueKey,NtClos...       0
#
# [40159 rows x 105 columns]

# %%
# commonHashes = get_samplehash_common(df, None, "DBSCAN", 99999) #Won't be picking a number of samples per cluster anymore 
# display(commonHashes)
# display(commonHashes['Type 1'].unique())
