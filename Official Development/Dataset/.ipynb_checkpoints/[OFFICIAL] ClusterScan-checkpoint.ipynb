# %% [markdown]
# # Malicious ClusterScan
#
# Describes/summarizes the or set of clusters. Useful for when you aim to enlist

# %% [markdown]
# ## 1. Import Libraries/Datasets

# %%
import pandas as pd

malicious_df = pd.read_csv('./Clustering/[EDITED]KMeans_SampleHash_Common.csv', low_memory=False, index_col=False) #This should point to a VirusTotal verified <Data Clustering>_SampleHash_Common.csv file

#Load list of API calls
API_LIST = "api_calls.txt"
DELIMITER = "NaN"
API_FILE = open(API_LIST,"r")
APIS = API_FILE.readline().split(',')
APIS.append(DELIMITER) #serves as a label for NaN values for Instance-based datasets
API_FILE.close()

def get_unique_clusters(df:pd.DataFrame):
    return list(df['cluster'].unique())

# %% [markdown]
# ## 2. DataFrame Preview

# %%
#Replace '-' empty malware type delimiter with '_' for consistency
malicious_df.replace(to_replace='-',value='_', inplace=True)
malicious_df
# Out:
#      cluster                              hash   Type 1     Type 2     Type 3  \
# 0          0  490d584c7d303ed35c673460b63f3ca8  trojan   dropper       pua
# 1          0  9ab8ea1d2d68a0d4110df413e677976c  trojan  hacktool         _
# 2          0  adbc74815ef2bd1ea4967abad812233d  trojan         _         _
# 3          0  f6eb4841bba3a4cee747700dc0ee1609       _         _         _
# 4          0  f5a0ad49337ebc87897698e70d03364e  trojan   dropper         _
# ..       ...                               ...     ...       ...       ...
# 490       99  38beaa14fdd861489b7c1e88161266f9  trojan         _         _
# 491       99  125e4dfc79fbfdadfeba0fea49533621  trojan   dropper  hacktool
# 492       99  ce4823889c3c5f42ffd5654be87d8ff3  trojan         _         _
# 493       99  d7f05bb88c5547e567e0a4ee484feba4  trojan     miner  hacktool
# 494       99  eee58f6bd3fb1bd13b88870f0e50e12b  trojan         _         _
#
#                                                pattern
# 0    GetSystemTimeAsFileTime,NtCreateMutant,GetSyst...
# 1    GetSystemTimeAsFileTime,NtCreateMutant,GetSyst...
# 2    GetSystemTimeAsFileTime,NtCreateMutant,GetSyst...
# 3    GetSystemTimeAsFileTime,NtCreateMutant,GetSyst...
# 4    GetSystemTimeAsFileTime,NtCreateMutant,GetSyst...
# ..                                                 ...
# 490  GetSystemTimeAsFileTime,LdrGetDllHandle,LdrGet...
# 491  GetSystemTimeAsFileTime,LdrGetDllHandle,LdrGet...
# 492  GetSystemTimeAsFileTime,LdrGetDllHandle,LdrGet...
# 493  GetSystemTimeAsFileTime,LdrGetDllHandle,LdrGet...
# 494  GetSystemTimeAsFileTime,LdrGetDllHandle,LdrGet...
#
# [495 rows x 6 columns]

# %%
#Drop row that is falsely labelled. (i.e. '_' on all popularity levels of VirusTotal)
malicious_df.drop(malicious_df[(malicious_df['Type 1']=='_')&(malicious_df['Type 2']=='_')&(malicious_df['Type 3']=='_')].index, inplace=True)
malicious_df
# Out:
#      cluster                              hash   Type 1     Type 2     Type 3  \
# 0          0  490d584c7d303ed35c673460b63f3ca8  trojan   dropper       pua
# 1          0  9ab8ea1d2d68a0d4110df413e677976c  trojan  hacktool         _
# 2          0  adbc74815ef2bd1ea4967abad812233d  trojan         _         _
# 4          0  f5a0ad49337ebc87897698e70d03364e  trojan   dropper         _
# 5          1  1ff43aa97f19dc8543aeaa1cd53e3885  trojan    adware         _
# ..       ...                               ...     ...       ...       ...
# 490       99  38beaa14fdd861489b7c1e88161266f9  trojan         _         _
# 491       99  125e4dfc79fbfdadfeba0fea49533621  trojan   dropper  hacktool
# 492       99  ce4823889c3c5f42ffd5654be87d8ff3  trojan         _         _
# 493       99  d7f05bb88c5547e567e0a4ee484feba4  trojan     miner  hacktool
# 494       99  eee58f6bd3fb1bd13b88870f0e50e12b  trojan         _         _
#
#                                                pattern
# 0    GetSystemTimeAsFileTime,NtCreateMutant,GetSyst...
# 1    GetSystemTimeAsFileTime,NtCreateMutant,GetSyst...
# 2    GetSystemTimeAsFileTime,NtCreateMutant,GetSyst...
# 4    GetSystemTimeAsFileTime,NtCreateMutant,GetSyst...
# 5    GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# ..                                                 ...
# 490  GetSystemTimeAsFileTime,LdrGetDllHandle,LdrGet...
# 491  GetSystemTimeAsFileTime,LdrGetDllHandle,LdrGet...
# 492  GetSystemTimeAsFileTime,LdrGetDllHandle,LdrGet...
# 493  GetSystemTimeAsFileTime,LdrGetDllHandle,LdrGet...
# 494  GetSystemTimeAsFileTime,LdrGetDllHandle,LdrGet...
#
# [462 rows x 6 columns]

# %% [markdown]
# ## 3. Identify "What Malware Types are there in each cluster?"
#
# This indicates what are the individual malware types mostly associated to cluster in terms of quantity regardless of order by popularity by VT.

# %%
#Identify the overall list of types each cluster is as designated by VirusTotal.
unique_clusters = get_unique_clusters(malicious_df)

summary = []
for u in unique_clusters:
    df_copy = malicious_df[malicious_df['cluster'] == u].copy(deep=True)
    types = list(df_copy['Type 1']) + list(df_copy['Type 2']) + list(df_copy['Type 3'])
    c_types = types.copy()
    types.sort(key=lambda x:c_types.count(x), reverse=True) #Sort the list by quantity (i.e., type with most quantity comes first)
    types = pd.Series(types).unique() #Combine the 3 levels of classifications of VirusTotal
    types = list(types)
    if '_' in types:
        types.remove('_')
    types = ' '.join(types)
    summary.append([int(u), types])
summary = pd.DataFrame(summary, columns=['cluster', 'types'])
for s in range(summary.shape[0]):
    print(f"{summary['cluster'].iloc[s]:2d} | {summary['types'].iloc[s]}")
# Note that the order of malware types starts from Type 1, Type 2, and Type 3.
# Out:
#  0 | trojan dropper hacktool pua
#  1 | trojan adware
#  2 | trojan adware pua
#  3 | trojan adware
#  4 | downloader adware trojan
#  5 | trojan dropper miner worm
#  6 | trojan downloader ransomware adware pua
#  7 | trojan adware
#  8 | trojan adware
#  9 | trojan adware downloader pua
# 10 | trojan adware
# 11 | trojan adware dropper
# 12 | trojan adware
# 13 | downloader adware trojan
# 14 | trojan adware virus
# 15 | trojan ransomware dropper pua
# 16 | trojan adware pua
# 17 | trojan spyware
# 18 | trojan adware
# 19 | adware trojan pua
# 20 | adware trojan virus dropper
# 21 | adware trojan downloader virus
# 22 | trojan downloader adware pua
# 23 | trojan adware pua spyware downloader
# 24 | trojan adware
# 25 | pua adware trojan ransomware
# 26 | trojan adware
# 27 | trojan spyware
# 28 | softomate trojan virus adware
# 29 | trojan adware
# 30 | trojan downloader
# 31 | trojan adware
# 32 | trojan adware pua
# 33 | trojan adware
# 34 | trojan adware
# 35 | trojan adware
# 36 | trojan adware pua downloader
# 37 | trojan adware
# 38 | trojan dropper
# 39 | trojan adware virus
# 40 | ransomware trojan
# 41 | trojan adware virus
# 42 | trojan adware
# 43 | trojan adware virus
# 44 | trojan downloader adware
# 45 | adware trojan downloader virus miner
# 46 | trojan adware
# 47 | trojan adware
# 48 | trojan
# 49 | trojan dropper
# 50 | trojan downloader adware
# 51 | adware downloader trojan
# 52 | trojan adware pua
# 53 | trojan pua
# 54 | trojan adware pua
# 55 | trojan miner pua
# 56 | trojan adware pua
# 57 | trojan adware
# 58 | trojan
# 59 | trojan adware spyware
# 60 | trojan downloader pua adware
# 62 | trojan adware virus
# 63 | trojan adware
# 64 | trojan adware virus
# 65 | trojan
# 66 | trojan adware
# 67 | trojan adware pua downloader
# 68 | trojan adware
# 69 | trojan
# 70 | trojan adware pua dropper
# 71 | trojan adware downloader pua
# 72 | trojan adware pua
# 73 | downloader adware trojan
# 74 | trojan adware
# 75 | trojan banker
# 76 | trojan adware virus
# 77 | trojan
# 78 | trojan ransomware
# 79 | trojan adware virus
# 80 | trojan adware
# 81 | trojan adware pua downloader
# 82 | trojan adware virus
# 83 | trojan adware pua downloader
# 84 | trojan adware
# 85 | adware trojan virus pua
# 86 | trojan adware pua
# 87 | trojan
# 88 | trojan adware downloader
# 89 | trojan pua adware
# 90 | trojan adware virus
# 91 | adware downloader trojan pua
# 92 | trojan adware
# 93 | trojan adware virus
# 94 | trojan adware
# 95 | trojan
# 96 | trojan downloader
# 97 | trojan miner spyware
# 98 | trojan downloader ransomware miner
# 99 | trojan hacktool dropper miner

# %%
# Summarize Clusters that have the same malware types as per VirusTotal.
unique_type_summary = list(summary['types'].unique())
print("# of Unique Type Summaries:", len(unique_type_summary),"\n")

count_summary = []
for i, u in enumerate(list(summary['types'].unique())):
    print("Malware Type Summary:", u)
    print("Matching Clusters:", list(summary[summary['types'] == u]['cluster']))
    count_summary.append([i, u, len(list(summary[summary['types'] == u]['cluster']))])
    print("")
count_summary.sort(key=lambda x: x[2])
    
pd.DataFrame(count_summary, columns=['cluster','malware_type_summary', 'count'])
# Out:
# # of Unique Type Summaries: 40
#
# Malware Type Summary: trojan dropper hacktool pua
# Matching Clusters: [0]
#
# Malware Type Summary: trojan adware
# Matching Clusters: [1, 3, 7, 8, 10, 12, 18, 24, 26, 29, 31, 33, 34, 35, 37, 42, 46, 47, 57, 63, 66, 68, 74, 80, 84, 92, 94]
#
# Malware Type Summary: trojan adware pua
# Matching Clusters: [2, 16, 32, 52, 54, 56, 72, 86]
#
# Malware Type Summary: downloader adware trojan
# Matching Clusters: [4, 13, 73]
#
# Malware Type Summary: trojan dropper miner worm
# Matching Clusters: [5]
#
# Malware Type Summary: trojan downloader ransomware adware pua
# Matching Clusters: [6]
#
# Malware Type Summary: trojan adware downloader pua
# Matching Clusters: [9, 71]
#
# Malware Type Summary: trojan adware dropper
# Matching Clusters: [11]
#
# Malware Type Summary: trojan adware virus
# Matching Clusters: [14, 39, 41, 43, 62, 64, 76, 79, 82, 90, 93]
#
# Malware Type Summary: trojan ransomware dropper pua
# Matching Clusters: [15]
#
# Malware Type Summary: trojan spyware
# Matching Clusters: [17, 27]
#
# Malware Type Summary: adware trojan pua
# Matching Clusters: [19]
#
# Malware Type Summary: adware trojan virus dropper
# Matching Clusters: [20]
#
# Malware Type Summary: adware trojan downloader virus
# Matching Clusters: [21]
#
# Malware Type Summary: trojan downloader adware pua
# Matching Clusters: [22]
#
# Malware Type Summary: trojan adware pua spyware downloader
# Matching Clusters: [23]
#
# Malware Type Summary: pua adware trojan ransomware
# Matching Clusters: [25]
#
# Malware Type Summary: softomate trojan virus adware
# Matching Clusters: [28]
#
# Malware Type Summary: trojan downloader
# Matching Clusters: [30, 96]
#
# Malware Type Summary: trojan adware pua downloader
# Matching Clusters: [36, 67, 81, 83]
#
# Malware Type Summary: trojan dropper
# Matching Clusters: [38, 49]
#
# Malware Type Summary: ransomware trojan
# Matching Clusters: [40]
#
# Malware Type Summary: trojan downloader adware
# Matching Clusters: [44, 50]
#
# Malware Type Summary: adware trojan downloader virus miner
# Matching Clusters: [45]
#
# Malware Type Summary: trojan
# Matching Clusters: [48, 58, 65, 69, 77, 87, 95]
#
# Malware Type Summary: adware downloader trojan
# Matching Clusters: [51]
#
# Malware Type Summary: trojan pua
# Matching Clusters: [53]
#
# Malware Type Summary: trojan miner pua
# Matching Clusters: [55]
#
# Malware Type Summary: trojan adware spyware
# Matching Clusters: [59]
#
# Malware Type Summary: trojan downloader pua adware
# Matching Clusters: [60]
#
# Malware Type Summary: trojan adware pua dropper
# Matching Clusters: [70]
#
# Malware Type Summary: trojan banker
# Matching Clusters: [75]
#
# Malware Type Summary: trojan ransomware
# Matching Clusters: [78]
#
# Malware Type Summary: adware trojan virus pua
# Matching Clusters: [85]
#
# Malware Type Summary: trojan adware downloader
# Matching Clusters: [88]
#
# Malware Type Summary: trojan pua adware
# Matching Clusters: [89]
#
# Malware Type Summary: adware downloader trojan pua
# Matching Clusters: [91]
#
# Malware Type Summary: trojan miner spyware
# Matching Clusters: [97]
#
# Malware Type Summary: trojan downloader ransomware miner
# Matching Clusters: [98]
#
# Malware Type Summary: trojan hacktool dropper miner
# Matching Clusters: [99]
#     cluster                     malware_type_summary  count
# 0         0              trojan dropper hacktool pua      1
# 1         4                trojan dropper miner worm      1
# 2         5  trojan downloader ransomware adware pua      1
# 3         7                    trojan adware dropper      1
# 4         9            trojan ransomware dropper pua      1
# 5        11                        adware trojan pua      1
# 6        12              adware trojan virus dropper      1
# 7        13           adware trojan downloader virus      1
# 8        14             trojan downloader adware pua      1
# 9        15     trojan adware pua spyware downloader      1
# 10       16             pua adware trojan ransomware      1
# 11       17            softomate trojan virus adware      1
# 12       21                        ransomware trojan      1
# 13       23     adware trojan downloader virus miner      1
# 14       25                 adware downloader trojan      1
# 15       26                               trojan pua      1
# 16       27                         trojan miner pua      1
# 17       28                    trojan adware spyware      1
# 18       29             trojan downloader pua adware      1
# 19       30                trojan adware pua dropper      1
# 20       31                            trojan banker      1
# 21       32                        trojan ransomware      1
# 22       33                  adware trojan virus pua      1
# 23       34                 trojan adware downloader      1
# 24       35                        trojan pua adware      1
# 25       36             adware downloader trojan pua      1
# 26       37                     trojan miner spyware      1
# 27       38       trojan downloader ransomware miner      1
# 28       39            trojan hacktool dropper miner      1
# 29        6             trojan adware downloader pua      2
# 30       10                           trojan spyware      2
# 31       18                        trojan downloader      2
# 32       20                           trojan dropper      2
# 33       22                 trojan downloader adware      2
# 34        3                 downloader adware trojan      3
# 35       19             trojan adware pua downloader      4
# 36       24                                   trojan      7
# 37        2                        trojan adware pua      8
# 38        8                      trojan adware virus     11
# 39        1                            trojan adware     27
