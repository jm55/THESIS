# %% [markdown]
# # Oliveira Dataset Notebook
#
#
# This is the official notebook for the thesis study
#
# **"Evaluation and Comparison of Boosted ML Models in Behavior-Based Malware Detection"**

# %% [markdown]
# # 0. Preparations

# %%
#Python Libraries
import time, datetime
import threading

#Data/Dataset libraries
import pandas as pd
import numpy as np

#Split Sampler/Data Splitting
from sklearn.model_selection import train_test_split

#Oversampler
from imblearn.over_sampling import SMOTEN

#Label Encoding
from sklearn.preprocessing import LabelEncoder

#Timer
start = end = 0
def startTime():
    global start
    start = time.time()
def endTime(process):
    global start
    elapse = time.time()-start
    start = 0
    printout = f"{str(datetime.datetime.now())}: {process} - {round(elapse, 6)}s\n"
    print(printout)
    print("")
    log = open("dataset_time.txt", "a")
    log.write(printout)
    log.close()
    return round(elapse, 6)

# %% [markdown]
# # 1. Import Datasets

# %%
#Filenames
filename = ["oliveira_lite.csv", "oliveira.csv"]
DATASET_FILENAME = filename[1] #Change accordingly;
API_LIST = "api_calls.txt"

#Load list of API calls
API_FILE = open(API_LIST,"r")
APIS = API_FILE.readline().split(',')
APIS.append("NaN") #serves as a label for NaN values for Instance-based datasets
API_FILE.close()

#Importing Datasets
oli = pd.read_csv(DATASET_FILENAME)
print("Oliveira Info:")
oli.info()
# Out:
# Oliveira Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43876 entries, 0 to 43875
# Columns: 102 entries, hash to malware
# dtypes: int64(101), object(1)
# memory usage: 34.1+ MB

# %%
#Previewing Dataset
oli.head()
# Out:
#                                hash  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  \
# 0  071e8c3f8922e186e57548cd4c703a5d  112  274  158  215  274  158  215  298
# 1  33f8e6d08a6aae939f25a8e0d63dd523   82  208  187  208  172  117  172  117
# 2  b68abd064e975e1c6d5f25e748663076   16  110  240  117  240  117  240  117
# 3  72049be7bd30ea61297ea624ae198067   82  208  187  208  172  117  172  117
# 4  c9b3700a77facf29172f32df6bc77f48   82  240  117  240  117  240  117  240
#
#    t_8  ...  t_91  t_92  t_93  t_94  t_95  t_96  t_97  t_98  t_99  malware
# 0   76  ...    71   297   135   171   215    35   208    56    71        1
# 1  172  ...    81   240   117    71   297   135   171   215    35        1
# 2  240  ...    65   112   123    65   112   123    65   113   112        1
# 3  172  ...   208   302   208   302   187   208   302   228   302        1
# 4  117  ...   209   260    40   209   260   141   260   141   260        1
#
# [5 rows x 102 columns]

# %%
print("Oliveira Label Counts")
print("0 as Benign, 1 as Malicious")
oli.malware.value_counts()
# Out:
# Oliveira Label Counts
# 0 as Benign, 1 as Malicious
# malware
# 1    42797
# 0     1079
# Name: count, dtype: int64

# %%
print("Oliveira Unique API calls list")
oli_unique = pd.Series(oli[list(oli.columns.values)[2:]].values.ravel())
oli_unique.sort_values(inplace=True, ascending=False)
oli_unique.value_counts()[0:19].plot(kind='barh', figsize=(7,3.5), title='Top 20 API calls in \'Oliveira\'') #Top 20 only
# Out:
# Oliveira Unique API calls list
# <Axes: title={'center': "Top 20 API calls in 'Oliveira'"}>

# %% [markdown]
# # 2. Dataset Preparation

# %% [markdown]
# ## 2.1. Dataset Cleaning and Dataset Formatting

# %%
#Removing hash column
hash_col = oli.pop('hash')
#Re-arranging column positions
label_col = oli.pop('malware')
oli = pd.concat([label_col, oli], axis=1)

oli
# Out:
#        malware  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  t_8  ...  t_90  t_91  \
# 0            1  112  274  158  215  274  158  215  298   76  ...   117    71
# 1            1   82  208  187  208  172  117  172  117  172  ...    60    81
# 2            1   16  110  240  117  240  117  240  117  240  ...   123    65
# 3            1   82  208  187  208  172  117  172  117  172  ...   215   208
# 4            1   82  240  117  240  117  240  117  240  117  ...    40   209
# ...        ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 43871        1   82  240  117  240  117  240  117  240  117  ...   260   141
# 43872        1   82  240  117  240  117  240  117  240  117  ...    82   159
# 43873        1   82  240  117  240  117  240  117  240  117  ...   141   260
# 43874        1   82  240  117  240  117  240  117  240  117  ...   260   141
# 43875        1  112  274  158  215  274  158  215  298   76  ...   117    71
#
#        t_92  t_93  t_94  t_95  t_96  t_97  t_98  t_99
# 0       297   135   171   215    35   208    56    71
# 1       240   117    71   297   135   171   215    35
# 2       112   123    65   112   123    65   113   112
# 3       302   208   302   187   208   302   228   302
# 4       260    40   209   260   141   260   141   260
# ...     ...   ...   ...   ...   ...   ...   ...   ...
# 43871   260   141   260   141   260   141   260   141
# 43872   224    82   159   224    82   159   224    82
# 43873   141   260   141   260   141   260   141   260
# 43874   260   141   260   141   260   141   260   141
# 43875   297   135   171   215    35   208    56    71
#
# [43876 rows x 101 columns]

# %% [markdown]
# ## 2.2. Inverse Data Encoding
#
# *Encoded API calls to String API Calls*

# %%
#Inverse Label Encoding
def inverse_label(item):
    global APIS
    return item.map(lambda x: APIS[int(x)])
startTime()
oli.iloc[:, 1:] = oli.iloc[:, 1:].apply(inverse_label, axis=1, result_type='reduce')
endTime("inverse_data_encode")

oli.head()
# Out:
# 2023-10-18 16:42:19.182265: inverse_data_encode - 8.486974s
#    malware                          t_0                      t_1  \
# 0        1                RegOpenKeyExA                NtOpenKey
# 1        1      GetSystemTimeAsFileTime  NtAllocateVirtualMemory
# 2        1  SetUnhandledExceptionFilter            OleInitialize
# 3        1      GetSystemTimeAsFileTime  NtAllocateVirtualMemory
# 4        1      GetSystemTimeAsFileTime               LdrLoadDll
#
#                       t_2                      t_3                     t_4  \
# 0         NtQueryValueKey                  NtClose               NtOpenKey
# 1     NtFreeVirtualMemory  NtAllocateVirtualMemory         LdrGetDllHandle
# 2              LdrLoadDll   LdrGetProcedureAddress              LdrLoadDll
# 3     NtFreeVirtualMemory  NtAllocateVirtualMemory         LdrGetDllHandle
# 4  LdrGetProcedureAddress               LdrLoadDll  LdrGetProcedureAddress
#
#                       t_5                     t_6                     t_7  \
# 0         NtQueryValueKey                 NtClose   NtQueryAttributesFile
# 1  LdrGetProcedureAddress         LdrGetDllHandle  LdrGetProcedureAddress
# 2  LdrGetProcedureAddress              LdrLoadDll  LdrGetProcedureAddress
# 3  LdrGetProcedureAddress         LdrGetDllHandle  LdrGetProcedureAddress
# 4              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
#
#                       t_8  ...                    t_90  \
# 0             LoadStringA  ...  LdrGetProcedureAddress
# 1         LdrGetDllHandle  ...         FindResourceExW
# 2              LdrLoadDll  ...        RegQueryValueExA
# 3         LdrGetDllHandle  ...                 NtClose
# 4  LdrGetProcedureAddress  ...        RegQueryInfoKeyW
#
#                          t_91                  t_92                     t_93  \
# 0  GetSystemWindowsDirectoryW          NtCreateFile          NtCreateSection
# 1                LoadResource            LdrLoadDll   LdrGetProcedureAddress
# 2                 RegCloseKey         RegOpenKeyExA         RegQueryValueExA
# 3     NtAllocateVirtualMemory  NtWriteVirtualMemory  NtAllocateVirtualMemory
# 4               RegEnumKeyExW         RegOpenKeyExW         RegQueryInfoKeyW
#
#                          t_94                 t_95                     t_96  \
# 0          NtMapViewOfSection              NtClose         GetSystemMetrics
# 1  GetSystemWindowsDirectoryW         NtCreateFile          NtCreateSection
# 2                 RegCloseKey        RegOpenKeyExA         RegQueryValueExA
# 3        NtWriteVirtualMemory  NtFreeVirtualMemory  NtAllocateVirtualMemory
# 4               RegEnumKeyExW        RegOpenKeyExW         RegQueryValueExW
#
#                       t_97                    t_98                        t_99
# 0  NtAllocateVirtualMemory           CreateActCtxW  GetSystemWindowsDirectoryW
# 1       NtMapViewOfSection                 NtClose            GetSystemMetrics
# 2              RegCloseKey           RegEnumKeyExA               RegOpenKeyExA
# 3     NtWriteVirtualMemory  NtProtectVirtualMemory        NtWriteVirtualMemory
# 4            RegOpenKeyExW        RegQueryValueExW               RegOpenKeyExW
#
# [5 rows x 101 columns]

# %%
print("Oliveira Unique API calls list")
oli_unique = pd.Series(oli[list(oli.columns.values)[1:]].values.ravel())
oli_unique.sort_values(inplace=True, ascending=False)
oli_unique.value_counts()[0:19].plot(kind='barh', figsize=(7,3.5), title='Top 20 API calls in \'Oliveira\'') #Top 20 only
# Out:
# Oliveira Unique API calls list
# <Axes: title={'center': "Top 20 API calls in 'Oliveira'"}>

# %% [markdown]
# ## 2.3. Feature Duplicate Processing
#
# *Building Time-based and Instance-Based Datasets*

# %%
TB = oli.copy(deep=True) #Time-based behavior (same as original)
IB = oli.copy(deep=True) #Instance-based behavior (to be created)

startTime()
print("Transposing IB...")
IB.transpose()
print("IB Transposed!")
print("Removing duplicates...")
print("Row:", end=" ")
for r in range(oli.shape[0]):
    #Per row (sample) removal of duplicates, thus cannot scale into the whole dataframe (which is way faster)
    row = IB.iloc[r, 1:].drop_duplicates(keep='first', inplace=False).to_list() 
    for i in range(100-len(row)):
        row.append("NaN")
    IB.iloc[r, 1:] = row
    if r % 100 == 0:
        print(r, end=" ")
print("\nDuplicates removed!")
print("Retransposing IB (revert)...")
IB.transpose()
print("IB Retransposed!")
endTime("feature_duplicate_process")
# Out:
# Transposing IB...
# IB Transposed!
# Removing duplicates...
# Row: 0 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800 2900 3000 3100 3200 3300 3400 3500 3600 3700 3800 3900 4000 4100 4200 4300 4400 4500 4600 4700 4800 4900 5000 5100 5200 5300 5400 5500 5600 5700 5800 5900 6000 6100 6200 6300 6400 6500 6600 6700 6800 6900 7000 7100 7200 7300 7400 7500 7600 7700 7800 7900 8000 8100 8200 8300 8400 8500 8600 8700 8800 8900 9000 9100 9200 9300 9400 9500 9600 9700 9800 9900 10000 10100 10200 10300 10400 10500 10600 10700 10800 10900 11000 11100 11200 11300 11400 11500 11600 11700 11800 11900 12000 12100 12200 12300 12400 12500 12600 12700 12800 12900 13000 13100 13200 13300 13400 13500 13600 13700 13800 13900 14000 14100 14200 14300 14400 14500 14600 14700 14800 14900 15000 15100 15200 15300 15400 15500 15600 15700 15800 15900 16000 16100 16200 16300 16400 16500 16600 16700 16800 16900 17000 17100 17200 17300 17400 17500 17600 17700 17800 17900 18000 18100 18200 18300 18400 18500 18600 18700 18800 18900 19000 19100 19200 19300 19400 19500 19600 19700 19800 19900 20000 20100 20200 20300 20400 20500 20600 20700 20800 20900 21000 21100 21200 21300 21400 21500 21600 21700 21800 21900 22000 22100 22200 22300 22400 22500 22600 22700 22800 22900 23000 23100 23200 23300 23400 23500 23600 23700 23800 23900 24000 24100 24200 24300 24400 24500 24600 24700 24800 24900 25000 25100 25200 25300 25400 25500 25600 25700 25800 25900 26000 26100 26200 26300 26400 26500 26600 26700 26800 26900 27000 27100 27200 27300 27400 27500 27600 27700 27800 27900 28000 28100 28200 28300 28400 28500 28600 28700 28800 28900 29000 29100 29200 29300 29400 29500 29600 29700 29800 29900 30000 30100 30200 30300 30400 30500 30600 30700 30800 30900 31000 31100 31200 31300 31400 31500 31600 31700 31800 31900 32000 32100 32200 32300 32400 32500 32600 32700 32800 32900 33000 33100 33200 33300 33400 33500 33600 33700 33800 33900 34000 34100 34200 34300 34400 34500 34600 34700 34800 34900 35000 35100 35200 35300 35400 35500 35600 35700 35800 35900 36000 36100 36200 36300 36400 36500 36600 36700 36800 36900 37000 37100 37200 37300 37400 37500 37600 37700 37800 37900 38000 38100 38200 38300 38400 38500 38600 38700 38800 38900 39000 39100 39200 39300 39400 39500 39600 39700 39800 39900 40000 40100 40200 40300 40400 40500 40600 40700 40800 40900 41000 41100 41200 41300 41400 41500 41600 41700 41800 41900 42000 42100 42200 42300 42400 42500 42600 42700 42800 42900 43000 43100 43200 43300 43400 43500 43600 43700 43800
# Duplicates removed!
# Retransposing IB (revert)...
# IB Retransposed!
# 2023-10-18 16:55:43.884183: feature_duplicate_process - 798.966341s
# 798.966341

# %% [markdown]
# # 3. Data Splitting (1st Tranche)

# %%
TEST_RATIO = 0.1

def firstSplit(dataset):
    global TEST_RATIO
    X = dataset.iloc[:,1:] #Features
    y = dataset.iloc[:,0] #Labels
    return train_test_split(X, y, test_size=TEST_RATIO, random_state=1, shuffle=True)

startTime()
#Time-based
TB_Features, TB_Reserve_Features, TB_Labels, TB_Reserve_Labels = firstSplit(TB)
TB = pd.concat([TB_Labels,TB_Features], axis=1)
TB_Reserve = pd.concat([TB_Reserve_Labels, TB_Reserve_Features], axis=1)
#Instance-based
IB_Features, IB_Reserve_Features, IB_Labels, IB_Reserve_Labels = firstSplit(IB)
IB = pd.concat([IB_Labels,IB_Features], axis=1)
IB_Reserve = pd.concat([IB_Reserve_Labels, IB_Reserve_Features], axis=1)
endTime("1st_data_split")

print(f"TB Train Split: {str(TB.shape)}")
print(f"TB Test/Holdout Split: {str(TB_Reserve.shape)}")

print(f"IB Train Split: {str(IB.shape)}")
print(f"IB Test/Holdout Split: {str(IB_Reserve.shape)}")
# Out:
# 2023-10-18 16:55:44.263056: 1st_data_split - 0.357246s
#
#
# TB Train Split: (39488, 101)
# TB Test/Holdout Split: (4388, 101)
# IB Train Split: (39488, 101)
# IB Test/Holdout Split: (4388, 101)

# %% [markdown]
# # 4. Data Rebalancing (SMOTE)

# %% [markdown]
# ## 4.1. Rebalancing Function

# %%
def TB_rebalance(balancer):
    global TB
    #Time-based
    X = TB.iloc[:,1:]
    y = TB.iloc[:,0]
    print("TB Rebalance...")
    X, y = balancer.fit_resample(X, y)
    print("TB Rebalancing Finished!")
    TB = pd.concat([y, X], axis=1)
def IB_rebalance(balancer):
    global IB
    #Instance-based
    X = IB.iloc[:,1:]
    y = IB.iloc[:,0]
    print("IB Rebalance...")
    X, y = balancer.fit_resample(X, y)
    print("IB Rebalancing Finished!")
    IB = pd.concat([y, X], axis=1)
def sample_distribution(dataset):
    distribution = []
    total_size = dataset.shape[0]
    dataset = str(dataset[['hash']].value_counts()[0:10]).split('\n')
    dataset.pop(0)
    dataset.pop(len(dataset)-1)
    for d in dataset:
        hs = d.split(' ')[0]
        qt = int(d.split(' ')[len(d.split(' '))-1])
        ratio = str(round(qt/total_size*100,2))+"%"
        distribution.append([hs,qt,ratio])
        print([hs,qt,ratio])

# %% [markdown]
# ## 4.2. Rebalancing

# %%
tb_thread = threading.Thread(target=TB_rebalance, args=(SMOTEN(sampling_strategy='minority', random_state=1, k_neighbors=2),))
ib_thread = threading.Thread(target=IB_rebalance, args=(SMOTEN(sampling_strategy='minority', random_state=1, k_neighbors=2),))

startTime()
tb_thread.start()
ib_thread.start()
tb_thread.join()
ib_thread.join()
endTime("tb/ib_rebalance_smote")
# Out:
# TB Rebalance...IB Rebalance...
#
# IB Rebalancing Finished!
# TB Rebalancing Finished!
# 2023-10-18 17:12:17.583278: tb/ib_rebalance_smote - 993.287147s
# 993.287147

# %%
print(f"TB Train Split (Rebalanced):\n{TB['malware'].value_counts()}")
print(f"TB Train Split (Rebalanced):\n{IB['malware'].value_counts()}")
# Out:
# TB Train Split (Rebalanced):
# malware
# 1    38513
# 0    38513
# Name: count, dtype: int64
# TB Train Split (Rebalanced):
# malware
# 1    38513
# 0    38513
# Name: count, dtype: int64

# %% [markdown]
# # 5. Label Encoding

# %%
def label_encode(offset):
    global APIS
    global ENCODED
    le = LabelEncoder()
    le.fit(APIS)
    ENCODED[offset].iloc[:,1:] = ENCODED[offset].iloc[:,1:].apply(le.transform)

ENCODED = [TB.copy(deep=True), IB.copy(deep=True), TB_Reserve.copy(deep=True), IB_Reserve.copy(deep=True)]

tb_thread = threading.Thread(target=label_encode, args=(0,))
ib_thread = threading.Thread(target=label_encode, args=(1,))
tb_test_thread = threading.Thread(target=label_encode, args=(2,))
ib_test_thread = threading.Thread(target=label_encode, args=(3,))

startTime()
tb_thread.start()
ib_thread.start()
tb_test_thread.start()
ib_test_thread.start()
tb_thread.join()
ib_thread.join()
tb_test_thread.join()
ib_test_thread.join()
endTime("label_encode")
# Out:
# 2023-10-18 17:12:41.448191: label_encode - 23.477728s
# 23.477728

# %% [markdown]
# # 6. Saving to File

# %%
def savetocsv(dfs, filenames):
    for d in range(len(dfs)):
        dfs[d].to_csv(index=False, chunksize=100, mode='w', path_or_buf=filenames[d])

STR_FILENAMES = ['TB/TB_CATB.csv', 'IB/IB_CATB.csv', 'TB/TB_Test_CATB.csv', 'IB/IB_Test_CATB.csv']
STR_API = [TB.copy(deep=True), IB.copy(deep=True), TB_Reserve.copy(deep=True), IB_Reserve.copy(deep=True)]

ENC_FILENAMES = ['TB/TB_LGBM.csv', 'IB/IB_LGBM.csv', 'TB/TB_Test_LGBM.csv', 'IB/IB_Test_LGBM.csv']
ENC_API = ENCODED

startTime()
savetocsv(STR_API, STR_FILENAMES)
savetocsv(ENC_API, ENC_FILENAMES)
endTime('save_to_file')
# Out:
# 2023-10-18 17:12:54.555582: save_to_file - 12.753853s
# 12.753853
