# %% [markdown]
# # Malicious ClusterScan
#
# Describes/summarizes the or set of clusters. Useful for when you aim to enlist

# %% [markdown]
# ## 1. Import Libraries/Datasets

# %%
import pandas as pd

malicious_df = pd.read_csv('./Clustering/[EDITED]KMeans_SampleHash_Common.csv', low_memory=False) #This should point to a verified <DataClustering>_SampleHash_Common.csv file
benign_df = pd.read_csv('./Clustering/Benign/API_Patterns.csv', low_memory=False) #This should point to the API_Patterns.csv file

#Load list of API calls
API_LIST = "api_calls.txt"
DELIMITER = "NaN"
API_FILE = open(API_LIST,"r")
APIS = API_FILE.readline().split(',')
APIS.append(DELIMITER) #serves as a label for NaN values for Instance-based datasets
API_FILE.close()

def get_unique_clusters(df:pd.DataFrame):
    return list(df['cluster'].unique())

# %% [markdown]
# ## 2. DataFrame Preview

# %%
#Replace '-' empty malware type delimiter with '_' for consistency
malicious_df.replace(to_replace='-',value='_', inplace=True)
malicious_df
# Out:
#      cluster                              hash   type1     type2     type3  \
# 0          0  490d584c7d303ed35c673460b63f3ca8  trojan   dropper       pua
# 1          0  9ab8ea1d2d68a0d4110df413e677976c  trojan  hacktool         _
# 2          0  adbc74815ef2bd1ea4967abad812233d  trojan         _         _
# 3          0  f6eb4841bba3a4cee747700dc0ee1609       _         _         _
# 4          0  f5a0ad49337ebc87897698e70d03364e  trojan   dropper         _
# ..       ...                               ...     ...       ...       ...
# 490       99  38beaa14fdd861489b7c1e88161266f9  trojan         _         _
# 491       99  125e4dfc79fbfdadfeba0fea49533621  trojan   dropper  hacktool
# 492       99  ce4823889c3c5f42ffd5654be87d8ff3  trojan         _         _
# 493       99  d7f05bb88c5547e567e0a4ee484feba4  trojan     miner  hacktool
# 494       99  eee58f6bd3fb1bd13b88870f0e50e12b  trojan         _         _
#
#                                                pattern
# 0    GetSystemTimeAsFileTime,NtCreateMutant,GetSyst...
# 1    GetSystemTimeAsFileTime,NtCreateMutant,GetSyst...
# 2    GetSystemTimeAsFileTime,NtCreateMutant,GetSyst...
# 3    GetSystemTimeAsFileTime,NtCreateMutant,GetSyst...
# 4    GetSystemTimeAsFileTime,NtCreateMutant,GetSyst...
# ..                                                 ...
# 490  GetSystemTimeAsFileTime,LdrGetDllHandle,LdrGet...
# 491  GetSystemTimeAsFileTime,LdrGetDllHandle,LdrGet...
# 492  GetSystemTimeAsFileTime,LdrGetDllHandle,LdrGet...
# 493  GetSystemTimeAsFileTime,LdrGetDllHandle,LdrGet...
# 494  GetSystemTimeAsFileTime,LdrGetDllHandle,LdrGet...
#
# [495 rows x 6 columns]

# %% [markdown]
# ## 3. How many are falsely labelled samples from the verified samples?

# %%
false_labelled = malicious_df[(malicious_df['type1']=='_')&(malicious_df['type2']=='_')&(malicious_df['type3']=='_')].copy(deep=True)
false_labelled.drop(columns=['type1', 'type2', 'type3'], inplace=True)

print(f"No. of falsely labelled samples from verified samples: {false_labelled.shape[0]}")
print("")

print("Counts of Falsely Labelled Samples in each Cluster")
print(false_labelled['cluster'].value_counts())
print("")

display(false_labelled)
# Out:
# No. of falsely labelled samples from verified samples: 33
#
# Counts of Falsely Labelled Samples in each Cluster
# cluster
# 61    5
# 55    4
# 25    3
# 28    3
# 58    3
# 77    3
# 22    2
# 23    2
# 44    2
# 85    2
# 0     1
# 19    1
# 45    1
# 98    1
# Name: count, dtype: int64
#      cluster                              hash  \
# 3          0  f6eb4841bba3a4cee747700dc0ee1609
# 95        19  9fbb71598d55fb6ac2d788a4edbe7ae6
# 111       22  0f7d7c34ed0cfd0c481df870d67ac98f
# 112       22  fce6af9ba629f6195f625217de2f2bc2
# 116       23  3555236a4ee1bd9ea8b9c33ffcf89dca
# 117       23  bf042f37cde592df4d7cd54a40b0e2bc
# 125       25  bbefd38b6cbb856a60a7e717bbece419
# 127       25  72d69a114513bf55f8efb6089423e09a
# 129       25  a8da6503536530a1da8592810550de86
# 140       28  4633b8a44132e2aa1dbb7a7fbced3090
# 141       28  da3ecb4063206a0fcd0c0bd48422fe22
# 144       28  823e7d57cf5594a320eff12984eceaf3
# 218       44  b601fe47d027c9e4849127bb99b0e3ae
# 219       44  8e7f4f9027d0ee1ae285885c4bc3fcd9
# 226       45  7b71017fc6e54ec740af6bf397f8e738
# 273       55  3404789eefc0159e40786b9ac4b5384d
# 274       55  02fad6820cd2ae7810c16a922c160f53
# 276       55  6697e908b087473502c293c6a89f01a2
# 277       55  23b8020775d5812a8d1309525a7196a9
# 289       58  0b4f18e98842b43fb816fe4a5d427967
# 290       58  dd5354a2b084b6c91140f4da44e3c3ba
# 292       58  9d8280a072e596bb2bba5adfc0b5b885
# 303       61  8bca081e5b6ec0862e461057fb46e863
# 304       61  e163ccbaf8a7aac44a47ec9d531269c7
# 305       61  bd776cc9f72cccb85aba417ce389c894
# 306       61  951205c514ed3139e7eb9340e69bbd2d
# 307       61  1d867ad6e784b470e02229527043de90
# 383       77  9537e46eb89f04d84b686818ebf6c6dc
# 384       77  a3501225280bfeaff6940a3269dcb9b3
# 385       77  f6d80e073ee5dd78f8e249dcbacf9d13
# 420       85  e7ebf3ccb20570140f013746280c87da
# 422       85  0fdf201c4f3eca0bc5d6d040f300b22f
# 487       98  02b6d264d8b1a9b28699ad9de9948db8
#
#                                                pattern
# 3    GetSystemTimeAsFileTime,NtCreateMutant,GetSyst...
# 95   GetSystemInfo,LdrGetDllHandle,LdrGetProcedureA...
# 111  SetErrorMode,OleInitialize,LdrGetDllHandle,Ldr...
# 112  SetErrorMode,OleInitialize,LdrGetDllHandle,Ldr...
# 116  SetErrorMode,OleInitialize,LdrGetDllHandle,Ldr...
# 117  SetErrorMode,OleInitialize,LdrGetDllHandle,Ldr...
# 125  GetSystemInfo,LdrGetDllHandle,LdrGetProcedureA...
# 127  GetSystemInfo,LdrGetDllHandle,LdrGetProcedureA...
# 129  GetSystemInfo,LdrGetDllHandle,LdrGetProcedureA...
# 140  SetErrorMode,OleInitialize,LdrGetDllHandle,Ldr...
# 141  SetErrorMode,OleInitialize,LdrGetDllHandle,Ldr...
# 144  SetErrorMode,OleInitialize,LdrGetDllHandle,Ldr...
# 218  LdrGetDllHandle,LdrGetProcedureAddress,NtAlloc...
# 219  LdrGetDllHandle,LdrGetProcedureAddress,NtAlloc...
# 226  SetErrorMode,LdrGetDllHandle,LdrGetProcedureAd...
# 273  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 274  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 276  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 277  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 289  GetSystemTimeAsFileTime,NtAllocateVirtualMemor...
# 290  GetSystemTimeAsFileTime,NtAllocateVirtualMemor...
# 292  GetSystemTimeAsFileTime,NtAllocateVirtualMemor...
# 303  NtAllocateVirtualMemory,NtFreeVirtualMemory,Nt...
# 304  NtAllocateVirtualMemory,NtFreeVirtualMemory,Nt...
# 305  NtAllocateVirtualMemory,NtFreeVirtualMemory,Nt...
# 306  NtAllocateVirtualMemory,NtFreeVirtualMemory,Nt...
# 307  NtAllocateVirtualMemory,NtFreeVirtualMemory,Nt...
# 383  GetSystemInfo,LdrGetDllHandle,LdrGetProcedureA...
# 384  GetSystemInfo,LdrGetDllHandle,LdrGetProcedureA...
# 385  GetSystemInfo,LdrGetDllHandle,LdrGetProcedureA...
# 420  LdrGetDllHandle,LdrGetProcedureAddress,GetSyst...
# 422  LdrGetDllHandle,LdrGetProcedureAddress,GetSyst...
# 487  SetErrorMode,LdrGetDllHandle,LdrGetProcedureAd...

# %% [markdown]
# ## 4. Does the presented API Call Patterns match those from the API Call Patterns of those Benign samples?
#
# **Remember that the samples labelled as benign in Oliveira came from Win7 executables which means that there is a guarantee that those are truly benign which makes it safe for use in comparison.**

# %%
unique_false_patterns = list(false_labelled['pattern'])

same = []
print("Falsely Labelled Malicious Samples that Match API Call Patterns of Benign Samples","\n")
for f in unique_false_patterns:
    if benign_df[benign_df['pattern']==f].shape[0]>0:
        print("API Call Pattern:")
        print("\t" + f)
        print("Clusters & Hashes of Matching Falsely Labelled Samples:")
        for p in range(false_labelled[false_labelled['pattern']==f].shape[0]):
            print(f"\t{false_labelled['cluster'].iloc[p]} - {false_labelled['hash'].iloc[p]}")
        print("Hashes of Benign Samples with Matching API Call Patterns:")
        for p in range(benign_df[benign_df['pattern']==f].shape[0]):
            print(f"\t{benign_df['hash'].iloc[p]}")
        same.append(f)
        print("\n")
print("")
print(f"No. of API Call Patterns of Falsely-Labelled Malicious Samples that match the API Call Patterns of Benign Samples: {len(same)} ({len(same)/benign_df.shape[0]*100:.4f}%)")
# Out:
# Falsely Labelled Malicious Samples that Match API Call Patterns of Benign Samples
#
# API Call Pattern:
# 	GetSystemTimeAsFileTime,NtCreateMutant,GetSystemTimeAsFileTime,NtOpenKeyEx,NtQueryKey,NtOpenKeyEx,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumKeyExW,RegOpenKeyExW,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumValueW,LdrGetProcedureAddress,RegCloseKey,GetFileAttributesW,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryValueExW,RegCloseKey,NtOpenFile,NtQueryDirectoryFile,NtClose,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,RegOpenKeyExW,RegQueryInfoKeyW,RegEnumValueW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,NtOpenFile,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,NtOpenFile,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,GetSystemTimeAsFileTime,NtQuerySystemInformation,NtProtectVirtualMemory,GetSystemDirectoryW,LdrGetDllHandle,LdrLoadDll,GetSystemDirectoryW,LdrGetDllHandle,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,NtClose,NtQueryKey,NtOpenKeyEx,NtQueryValueKey,NtClose,GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProcedureAddress,GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProcedureAddress,NtCreateFile,GetFileSize,NtCreateSection,NtMapViewOfSection,GetSystemInfo,NtClose,NtUnmapViewOfSection,NtClose,NtCreateFile,GetFileSize,NtCreateSection,NtMapViewOfSection,GetSystemInfo,NtClose,NtUnmapViewOfSection,NtClose,RegOpenKeyExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,NtOpenFile
# Clusters & Hashes of Matching Falsely Labelled Samples:
# 	0 - f6eb4841bba3a4cee747700dc0ee1609
# Hashes of Benign Samples with Matching API Call Patterns:
# 	5b51d65972a349f90a86984c26b12b30
# 	ceb8cc125478fad641daa4e04e9b2f19
#
#
#
# No. of API Call Patterns of Falsely-Labelled Malicious Samples that match the API Call Patterns of Benign Samples: 1 (0.0927%)

# %%
print("In terms of unique API Calls:")
for i, s in enumerate(same):
    print(i, list(pd.Series(s.split(',')).unique()))
    print("")
# Out:
# In terms of unique API Calls:
# 0 ['GetSystemTimeAsFileTime', 'NtCreateMutant', 'NtOpenKeyEx', 'NtQueryKey', 'LdrLoadDll', 'LdrGetProcedureAddress', 'RegOpenKeyExW', 'RegQueryInfoKeyW', 'RegEnumKeyExW', 'RegEnumValueW', 'RegCloseKey', 'GetFileAttributesW', 'RegQueryValueExW', 'NtOpenFile', 'NtQueryDirectoryFile', 'NtClose', 'NtQuerySystemInformation', 'NtProtectVirtualMemory', 'GetSystemDirectoryW', 'LdrGetDllHandle', 'NtOpenKey', 'NtQueryValueKey', 'NtCreateFile', 'GetFileSize', 'NtCreateSection', 'NtMapViewOfSection', 'GetSystemInfo', 'NtUnmapViewOfSection']
