# %% [markdown]
# # Malicious ClusterScan
#
# Describes/summarizes the or set of clusters. Useful for when you aim to enlist the summarized malware types found in each cluster in order by Malware Type.
#
# Assume that the dataset is already pre-processed:
# 1. Removal of nan values
# 2. Data Cleaning (Removal of False Labels and *Removal/Aggregation of malware types of poor quantity*)
# 3. Inverse Ordinal Encoding (for representation purposes only)

# %% [markdown]
# ## Import Libraries/Datasets

# %%
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

plt.rcParams["figure.autolayout"] = True

malicious_df = pd.read_csv('./Manual_DBSCAN_Clustering_w_FalseLabels.csv', low_memory=False, index_col=False) #This should point to a VirusTotal verified <Data Clustering>_SampleHash_Common.csv file

#Load list of API calls
API_LIST = "../api_calls.txt"
DELIMITER = "NaN"
API_FILE = open(API_LIST,"r")
APIS = API_FILE.readline().split(',')
APIS.append(DELIMITER) #serves as a label for NaN values for Instance-based datasets
API_FILE.close()

def list_to_str(ls:list):
    output = ""
    for l in ls:
        output += str(l) + " "
    return output[0:len(output)-1]

def inject_patterns(inner_df:pd.DataFrame):
    patterns = []
    for row in range(inner_df.shape[0]):
        patterns.append(list_to_str(inner_df.iloc[row,2:5].transpose().to_list()))
    inner_df['type_pattern'] = patterns
    return inner_df

def get_unique_clusters(df:pd.DataFrame):
    return list(df['cluster'].unique())

def get_summary(df:pd.DataFrame):
    #Identify the overall list of types each cluster is as designated by VirusTotal.
    unique_clusters = get_unique_clusters(df)
    summary = []
    for u in unique_clusters:
        cluster_sublist = [u]
        df_copy = malicious_df[malicious_df['cluster'] == u].copy(deep=True)
        idx = list(df_copy['type'].value_counts().index)
        counts = list(df_copy['type'].value_counts())
        type_sublist = []
        for i in range(len(idx)):
            type_sublist.append([idx[i], counts[i]])
        cluster_sublist.append(type_sublist)
        # str_summary = []
        # cluster_sublist.append(list(df_copy['type_pattern'].value_counts().index))
        # cluster_sublist.append(list(df_copy['type_pattern'].value_counts()))
        summary.append(cluster_sublist)
    return summary

DELIMITER = "NaN"
API_FILE = open(API_LIST,"r")
APIS = API_FILE.readline().split(',')
APIS.append(DELIMITER) #serves as a label for NaN values for Instance-based datasets
API_FILE.close()

from sklearn.preprocessing import LabelEncoder
#Inverse Label Encoding
def inverse_label(item):
    global APIS
    return item.map(lambda x: APIS[int(x)])
oliveira = pd.read_csv('../oliveira.csv', low_memory=False)
oliveira.iloc[:, 1:101] = oliveira.iloc[:, 1:101].apply(inverse_label, axis=1, result_type='reduce')

def how_many_clusters():
    c = malicious_df['cluster'].unique()
    c.sort()
    print("Number of Clusters:", c.size)
    c = malicious_df['cluster'].value_counts(ascending=True)
    print("Number of single-item Clusters:", c[c==1].count())
    print("Number of Samples Remaining:", malicious_df.shape[0])
# Out:
# C:\Users\ejose\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# ## DataFrame Preview

# %%
#Replace '-' empty malware type delimiter with '_' for consistency
malicious_df.replace(to_replace='-',value='_', inplace=True)
display(malicious_df.head(10))
display(malicious_df.shape)
malicious_df['type'].value_counts(ascending=True).plot(kind='barh')
# Out:
#                                hash  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  \
# 0  071e8c3f8922e186e57548cd4c703a5d  112  274  158  215  274  158  215  298
# 1  33f8e6d08a6aae939f25a8e0d63dd523   82  208  187  208  172  117  172  117
# 2  b68abd064e975e1c6d5f25e748663076   16  110  240  117  240  117  240  117
# 3  72049be7bd30ea61297ea624ae198067   82  208  187  208  172  117  172  117
# 4  c9b3700a77facf29172f32df6bc77f48   82  240  117  240  117  240  117  240
# 5  cc6217be863e606e49da90fee2252f52  117  208  117  208  117  240  117  240
# 6  f7a1a3c38809d807b3f5f4cc00b1e9b7  215  274  158  215  274  158  215  172
# 7  164b56522eb24164184460f8523ed7e2   82  240  117  240  117  240  117  240
# 8  56ae1459ba61a14eb119982d6ec793d7   82  240  117  240  117  240  117  240
# 9  c4148ca91c5246a8707a1ac1fd1e2e36   82  208  187  208  172  117  172  208
#
#    t_8  ...  t_94  t_95  t_96  t_97  t_98  t_99  malware        type  \
# 0   76  ...   171   215    35   208    56    71        1      trojan
# 1  172  ...    71   297   135   171   215    35        1         pua
# 2  240  ...    65   112   123    65   113   112        1      trojan
# 3  172  ...   302   187   208   302   228   302        1      trojan
# 4  117  ...   209   260   141   260   141   260        1      trojan
# 5  117  ...   141    65     9   117   260    65        1      trojan
# 6  117  ...   172    60    81    60    81   225        1  downloader
# 7  117  ...   275   240    80    60   215    35        1      adware
# 8  117  ...   215   108   208    80   240   117        1      adware
# 9   16  ...   208   172   117   100   215    35        1  downloader
#
#                                              pattern  cluster
# 0  RegOpenKeyExA,NtOpenKey,NtQueryValueKey,NtClos...        0
# 1  GetSystemTimeAsFileTime,NtAllocateVirtualMemor...        1
# 2  SetUnhandledExceptionFilter,OleInitialize,LdrL...        2
# 3  GetSystemTimeAsFileTime,NtAllocateVirtualMemor...        3
# 4  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...        4
# 5  LdrGetProcedureAddress,NtAllocateVirtualMemory...        5
# 6  NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOp...        6
# 7  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...        7
# 8  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...        8
# 9  GetSystemTimeAsFileTime,NtAllocateVirtualMemor...        9
#
# [10 rows x 105 columns]
# (42797, 105)
# <Axes: ylabel='type'>

# %% [markdown]
# # Dataset Cleaning and Inverse Ordinal Encoding (for representation)

# %%
#INJECT PATTERN (i.e., summarized malware type pattern) to the DataFrame
malicious_df = inject_patterns(malicious_df)

print("Raw Clustered malicious samples")
how_many_clusters()
# Out:
# Raw Clustered malicious samples
# Number of Clusters: 12597
# Number of single-item Clusters: 10413
# Number of Samples Remaining: 42797

# %% [markdown]
# ## "What Malware Types can be found in the overall dataset?"
#
# ### This is regardless of cluster.

# %%
output = malicious_df['type'].value_counts()
str_output = str(output) + "\n\n"
with open("./Output/1 MalwareTypes_in_Dataset.txt", 'w') as f:
    f.write(str_output)
    f.flush
    f.close()
display(output)
fig, axs = plt.subplots(nrows=1, layout='constrained')
fig.set_figwidth(4)
fig.set_figheight(3)
fig.set_dpi(300)
axs.set_title('Malware Type Counts')
axs.barh(malicious_df['type'].value_counts().index, malicious_df['type'].value_counts())
axs.invert_yaxis()
# axs[1].set_title('Type 2 Malware Type Counts')
# axs[1].invert_yaxis()
# axs[1].barh(malicious_df['Type 2'].value_counts().index, malicious_df['Type 2'].value_counts())
# axs[2].invert_yaxis()
# axs[2].set_title('Type 3 (Least \'Popular\') Malware Type Counts')
# axs[2].barh(malicious_df['Type 3'].value_counts().index, malicious_df['Type 3'].value_counts())
plt.savefig("./Output/1 Popular Malware Types in Dataset.png")
# Out:
# type
# trojan        33352
# _              2638
# downloader     2249
# pua            2135
# adware         1815
# ransomware      341
# miner           125
# virus            79
# spyware          48
# hacktool          7
# dropper           5
# worm              3
# Name: count, dtype: int64

# %% [markdown]
# ## How many clusters are there?

# %%
#Prior to noise removal
print("Prior to noise removal")
how_many_clusters()
# Out:
# Prior to noise removal
# Number of Clusters: 12597
# Number of single-item Clusters: 10413
# Number of Samples Remaining: 42797

# %%
# DROP CLUSTERS WITH MORE THAN 1 MALWARE TYPE UNDER IT (i.e. NOISE)
unique_clusters = get_unique_clusters(malicious_df)
for u in unique_clusters:
    if len(malicious_df[malicious_df['cluster'] == u]['type'].unique()) > 1:
        malicious_df = malicious_df.drop(malicious_df[malicious_df['cluster'] == u].index)
# malicious_df.head()

print("After removing yet unlabelled malicious samples\n and clusters with more than 1 malware type")
how_many_clusters()
# Out:
# After removing yet unlabelled malicious samples
#  and clusters with more than 1 malware type
# Number of Clusters: 12011
# Number of single-item Clusters: 10413
# Number of Samples Remaining: 17335

# %%
# REMOVE SINGLE ITEM CLUSTERS
unique_clusters = get_unique_clusters(malicious_df)
for u in unique_clusters:
    if malicious_df[malicious_df['cluster'] == u].shape[0] == 1:
        malicious_df = malicious_df.drop(malicious_df[malicious_df['cluster'] == u].index)

print("After removing single-item clusters")
how_many_clusters()
# Out:
# After removing single-item clusters
# Number of Clusters: 1598
# Number of single-item Clusters: 0
# Number of Samples Remaining: 6922

# %% [markdown]
# ## "What Malware Types are there in each cluster?"

# %% [markdown]
# ### Identify the counts of Malware Types per Cluster
#
# This indicates the malware types (including the # of instances) found in each cluster.

# %%
str_output = ""
summary = get_summary(malicious_df)
summary.sort()
for s in summary:
    str_output += f"CLUSTER {s[0]}: "
    for t in s[1]:
        str_output += f"{t[0]} ({t[1]}); "
    # str_output += "\n\tType 2: "
    # for t in s[2]:
    #     str_output += f"{t[0]} ({t[1]}); "
    # str_output += "\n\tType 3: "
    # for t in s[3]:
    #     str_output += f"{t[0]} ({t[1]}); "
    # str_output += "\n\tMost Popular Malware Type Combination (in order Most to Least):\n"
    # for i,t in enumerate(s[4]):
    #     str_output += f"\t    {i+1} {t:12s} ({s[5][i]})\n"
    str_output += "\n"
with open("./Output/1 MalwareType_per_Cluster_woNoise.txt", 'w') as f:
    f.write(str_output)
    f.flush
    f.close()
print(str_output)
# Out:
# CLUSTER 2: trojan (8);
# CLUSTER 11: trojan (10);
# CLUSTER 14: _ (2);
# CLUSTER 16: trojan (23);
# CLUSTER 17: trojan (12);
# CLUSTER 20: trojan (2);
# CLUSTER 25: trojan (29);
# CLUSTER 26: trojan (2);
# CLUSTER 35: trojan (14);
# CLUSTER 42: trojan (99);
# CLUSTER 43: trojan (2);
# CLUSTER 44: trojan (101);
# CLUSTER 47: trojan (2);
# CLUSTER 52: trojan (3);
# CLUSTER 57: trojan (12);
# CLUSTER 59: trojan (5);
# CLUSTER 61: trojan (16);
# CLUSTER 65: _ (2);
# CLUSTER 67: trojan (3);
# CLUSTER 69: trojan (19);
# CLUSTER 71: trojan (2);
# CLUSTER 73: downloader (4);
# CLUSTER 78: trojan (3);
# CLUSTER 81: trojan (7);
# CLUSTER 85: trojan (35);
# CLUSTER 87: miner (3);
# CLUSTER 88: trojan (28);
# CLUSTER 90: trojan (4);
# CLUSTER 93: adware (6);
# CLUSTER 94: trojan (12);
# CLUSTER 95: virus (7);
# CLUSTER 96: trojan (84);
# CLUSTER 100: trojan (2);
# CLUSTER 104: trojan (2);
# CLUSTER 107: trojan (11);
# CLUSTER 110: trojan (5);
# CLUSTER 121: _ (4);
# CLUSTER 124: trojan (11);
# CLUSTER 131: trojan (4);
# CLUSTER 132: trojan (2);
# CLUSTER 134: trojan (19);
# CLUSTER 139: trojan (32);
# CLUSTER 145: _ (2);
# CLUSTER 146: trojan (5);
# CLUSTER 148: trojan (4);
# CLUSTER 151: trojan (10);
# CLUSTER 156: trojan (4);
# CLUSTER 161: trojan (3);
# CLUSTER 167: trojan (15);
# CLUSTER 169: trojan (11);
# CLUSTER 172: trojan (3);
# CLUSTER 182: trojan (3);
# CLUSTER 183: trojan (6);
# CLUSTER 190: trojan (2);
# CLUSTER 199: trojan (3);
# CLUSTER 202: trojan (14);
# CLUSTER 203: trojan (2);
# CLUSTER 214: trojan (2);
# CLUSTER 216: trojan (11);
# CLUSTER 222: trojan (127);
# CLUSTER 223: trojan (6);
# CLUSTER 239: trojan (18);
# CLUSTER 248: trojan (14);
# CLUSTER 253: trojan (3);
# CLUSTER 258: trojan (15);
# CLUSTER 261: trojan (16);
# CLUSTER 266: trojan (5);
# CLUSTER 270: trojan (4);
# CLUSTER 272: trojan (14);
# CLUSTER 274: trojan (8);
# CLUSTER 277: trojan (40);
# CLUSTER 278: pua (2);
# CLUSTER 280: trojan (2);
# CLUSTER 281: trojan (2);
# CLUSTER 283: trojan (10);
# CLUSTER 293: adware (28);
# CLUSTER 294: trojan (2);
# CLUSTER 301: trojan (3);
# CLUSTER 304: trojan (17);
# CLUSTER 306: trojan (6);
# CLUSTER 307: trojan (5);
# CLUSTER 309: trojan (2);
# CLUSTER 312: trojan (5);
# CLUSTER 314: trojan (4);
# CLUSTER 322: trojan (29);
# CLUSTER 326: trojan (13);
# CLUSTER 329: trojan (3);
# CLUSTER 333: trojan (26);
# CLUSTER 334: trojan (6);
# CLUSTER 337: trojan (18);
# CLUSTER 340: trojan (42);
# CLUSTER 343: trojan (5);
# CLUSTER 344: trojan (3);
# CLUSTER 345: trojan (6);
# CLUSTER 351: trojan (3);
# CLUSTER 355: trojan (2);
# CLUSTER 359: trojan (9);
# CLUSTER 361: _ (47);
# CLUSTER 366: trojan (6);
# CLUSTER 367: trojan (7);
# CLUSTER 368: trojan (6);
# CLUSTER 369: trojan (2);
# CLUSTER 370: trojan (2);
# CLUSTER 373: trojan (3);
# CLUSTER 374: trojan (6);
# CLUSTER 375: trojan (2);
# CLUSTER 376: trojan (8);
# CLUSTER 377: trojan (62);
# CLUSTER 384: ransomware (4);
# CLUSTER 386: trojan (5);
# CLUSTER 389: trojan (15);
# CLUSTER 390: trojan (3);
# CLUSTER 392: _ (3);
# CLUSTER 393: trojan (6);
# CLUSTER 397: trojan (2);
# CLUSTER 400: trojan (5);
# CLUSTER 402: _ (2);
# CLUSTER 406: trojan (2);
# CLUSTER 410: trojan (2);
# CLUSTER 416: trojan (3);
# CLUSTER 422: trojan (2);
# CLUSTER 427: trojan (2);
# CLUSTER 428: trojan (2);
# CLUSTER 431: trojan (2);
# CLUSTER 435: trojan (2);
# CLUSTER 438: trojan (12);
# CLUSTER 439: trojan (6);
# CLUSTER 442: trojan (17);
# CLUSTER 443: trojan (25);
# CLUSTER 446: trojan (15);
# CLUSTER 448: trojan (5);
# CLUSTER 451: trojan (44);
# CLUSTER 452: trojan (2);
# CLUSTER 455: trojan (2);
# CLUSTER 456: trojan (37);
# CLUSTER 457: trojan (28);
# CLUSTER 458: trojan (2);
# CLUSTER 460: trojan (2);
# CLUSTER 461: trojan (4);
# CLUSTER 462: _ (4);
# CLUSTER 463: trojan (6);
# CLUSTER 472: trojan (7);
# CLUSTER 478: trojan (2);
# CLUSTER 484: trojan (2);
# CLUSTER 486: trojan (2);
# CLUSTER 488: trojan (16);
# CLUSTER 489: trojan (3);
# CLUSTER 490: trojan (2);
# CLUSTER 492: trojan (2);
# CLUSTER 493: trojan (37);
# CLUSTER 496: trojan (4);
# CLUSTER 497: trojan (6);
# CLUSTER 500: _ (2);
# CLUSTER 501: pua (2);
# CLUSTER 503: trojan (2);
# CLUSTER 504: trojan (10);
# CLUSTER 506: pua (3);
# CLUSTER 508: trojan (5);
# CLUSTER 509: trojan (24);
# CLUSTER 520: trojan (41);
# CLUSTER 522: trojan (14);
# CLUSTER 524: trojan (2);
# CLUSTER 529: trojan (3);
# CLUSTER 531: trojan (75);
# CLUSTER 535: trojan (10);
# CLUSTER 537: trojan (5);
# CLUSTER 544: trojan (2);
# CLUSTER 548: trojan (4);
# CLUSTER 551: trojan (3);
# CLUSTER 552: trojan (5);
# CLUSTER 554: trojan (2);
# CLUSTER 571: trojan (54);
# CLUSTER 576: trojan (12);
# CLUSTER 577: trojan (8);
# CLUSTER 580: trojan (15);
# CLUSTER 585: trojan (10);
# CLUSTER 588: trojan (3);
# CLUSTER 600: trojan (2);
# CLUSTER 602: trojan (2);
# CLUSTER 607: trojan (2);
# CLUSTER 609: adware (2);
# CLUSTER 612: trojan (2);
# CLUSTER 615: pua (4);
# CLUSTER 619: trojan (2);
# CLUSTER 622: trojan (3);
# CLUSTER 623: trojan (10);
# CLUSTER 624: trojan (2);
# CLUSTER 626: trojan (6);
# CLUSTER 631: trojan (5);
# CLUSTER 632: trojan (7);
# CLUSTER 635: trojan (45);
# CLUSTER 640: trojan (3);
# CLUSTER 643: trojan (3);
# CLUSTER 644: trojan (2);
# CLUSTER 645: adware (2);
# CLUSTER 646: _ (4);
# CLUSTER 647: trojan (2);
# CLUSTER 649: trojan (4);
# CLUSTER 651: trojan (2);
# CLUSTER 652: trojan (5);
# CLUSTER 654: trojan (3);
# CLUSTER 660: _ (2);
# CLUSTER 661: trojan (2);
# CLUSTER 665: trojan (10);
# CLUSTER 677: trojan (9);
# CLUSTER 678: trojan (2);
# CLUSTER 679: trojan (3);
# CLUSTER 681: trojan (3);
# CLUSTER 693: trojan (12);
# CLUSTER 696: _ (2);
# CLUSTER 697: trojan (3);
# CLUSTER 700: trojan (4);
# CLUSTER 704: trojan (6);
# CLUSTER 707: trojan (6);
# CLUSTER 719: trojan (2);
# CLUSTER 725: trojan (5);
# CLUSTER 726: trojan (5);
# CLUSTER 727: trojan (3);
# CLUSTER 729: trojan (2);
# CLUSTER 732: trojan (10);
# CLUSTER 741: ransomware (5);
# CLUSTER 745: trojan (5);
# CLUSTER 746: trojan (6);
# CLUSTER 750: trojan (5);
# CLUSTER 751: _ (5);
# CLUSTER 753: trojan (2);
# CLUSTER 759: trojan (24);
# CLUSTER 771: trojan (2);
# CLUSTER 772: trojan (6);
# CLUSTER 774: trojan (4);
# CLUSTER 781: trojan (36);
# CLUSTER 782: trojan (3);
# CLUSTER 787: trojan (2);
# CLUSTER 798: trojan (6);
# CLUSTER 803: downloader (4);
# CLUSTER 807: trojan (39);
# CLUSTER 810: _ (5);
# CLUSTER 813: trojan (27);
# CLUSTER 818: _ (2);
# CLUSTER 824: trojan (2);
# CLUSTER 828: trojan (2);
# CLUSTER 833: trojan (3);
# CLUSTER 835: trojan (2);
# CLUSTER 836: trojan (6);
# CLUSTER 837: trojan (4);
# CLUSTER 842: trojan (2);
# CLUSTER 845: trojan (21);
# CLUSTER 848: trojan (3);
# CLUSTER 849: trojan (2);
# CLUSTER 853: trojan (30);
# CLUSTER 855: trojan (4);
# CLUSTER 857: trojan (2);
# CLUSTER 861: trojan (2);
# CLUSTER 866: trojan (2);
# CLUSTER 870: trojan (2);
# CLUSTER 873: _ (3);
# CLUSTER 878: trojan (2);
# CLUSTER 882: trojan (3);
# CLUSTER 883: trojan (5);
# CLUSTER 885: trojan (4);
# CLUSTER 890: trojan (2);
# CLUSTER 891: trojan (4);
# CLUSTER 892: trojan (2);
# CLUSTER 894: trojan (2);
# CLUSTER 895: _ (2);
# CLUSTER 899: adware (2);
# CLUSTER 901: trojan (3);
# CLUSTER 903: trojan (2);
# CLUSTER 905: adware (2);
# CLUSTER 906: trojan (2);
# CLUSTER 909: trojan (10);
# CLUSTER 913: trojan (2);
# CLUSTER 916: trojan (30);
# CLUSTER 917: trojan (4);
# CLUSTER 926: trojan (7);
# CLUSTER 929: trojan (12);
# CLUSTER 944: trojan (2);
# CLUSTER 946: _ (3);
# CLUSTER 947: trojan (11);
# CLUSTER 949: trojan (3);
# CLUSTER 952: trojan (2);
# CLUSTER 957: trojan (13);
# CLUSTER 958: trojan (2);
# CLUSTER 962: trojan (3);
# CLUSTER 964: trojan (2);
# CLUSTER 972: trojan (2);
# CLUSTER 973: trojan (2);
# CLUSTER 987: trojan (3);
# CLUSTER 988: trojan (5);
# CLUSTER 992: trojan (2);
# CLUSTER 994: trojan (2);
# CLUSTER 995: trojan (4);
# CLUSTER 1000: trojan (3);
# CLUSTER 1002: trojan (2);
# CLUSTER 1003: trojan (6);
# CLUSTER 1004: trojan (2);
# CLUSTER 1006: trojan (4);
# CLUSTER 1007: trojan (7);
# CLUSTER 1010: trojan (5);
# CLUSTER 1015: adware (5);
# CLUSTER 1017: trojan (4);
# CLUSTER 1019: trojan (4);
# CLUSTER 1020: trojan (2);
# CLUSTER 1023: trojan (2);
# CLUSTER 1028: trojan (6);
# CLUSTER 1040: trojan (4);
# CLUSTER 1041: trojan (5);
# CLUSTER 1058: _ (2);
# CLUSTER 1065: trojan (2);
# CLUSTER 1066: adware (3);
# CLUSTER 1068: trojan (6);
# CLUSTER 1070: trojan (2);
# CLUSTER 1071: trojan (3);
# CLUSTER 1079: trojan (2);
# CLUSTER 1080: trojan (2);
# CLUSTER 1081: trojan (4);
# CLUSTER 1085: trojan (2);
# CLUSTER 1086: trojan (20);
# CLUSTER 1088: trojan (2);
# CLUSTER 1096: trojan (5);
# CLUSTER 1097: trojan (13);
# CLUSTER 1098: adware (2);
# CLUSTER 1099: adware (2);
# CLUSTER 1106: trojan (2);
# CLUSTER 1110: trojan (6);
# CLUSTER 1111: trojan (4);
# CLUSTER 1112: trojan (2);
# CLUSTER 1120: trojan (3);
# CLUSTER 1121: trojan (28);
# CLUSTER 1124: trojan (13);
# CLUSTER 1133: trojan (2);
# CLUSTER 1136: trojan (5);
# CLUSTER 1142: trojan (16);
# CLUSTER 1143: trojan (2);
# CLUSTER 1150: trojan (6);
# CLUSTER 1152: trojan (6);
# CLUSTER 1157: trojan (2);
# CLUSTER 1160: trojan (4);
# CLUSTER 1170: trojan (2);
# CLUSTER 1182: trojan (2);
# CLUSTER 1183: trojan (8);
# CLUSTER 1184: trojan (4);
# CLUSTER 1185: trojan (2);
# CLUSTER 1190: trojan (2);
# CLUSTER 1193: trojan (3);
# CLUSTER 1194: trojan (2);
# CLUSTER 1199: _ (3);
# CLUSTER 1207: trojan (12);
# CLUSTER 1209: trojan (2);
# CLUSTER 1216: trojan (25);
# CLUSTER 1224: trojan (2);
# CLUSTER 1229: trojan (4);
# CLUSTER 1233: trojan (2);
# CLUSTER 1234: trojan (2);
# CLUSTER 1241: trojan (2);
# CLUSTER 1261: trojan (8);
# CLUSTER 1266: trojan (13);
# CLUSTER 1267: trojan (3);
# CLUSTER 1268: trojan (7);
# CLUSTER 1270: trojan (2);
# CLUSTER 1277: trojan (19);
# CLUSTER 1279: trojan (2);
# CLUSTER 1287: _ (2);
# CLUSTER 1290: trojan (2);
# CLUSTER 1292: trojan (2);
# CLUSTER 1294: trojan (6);
# CLUSTER 1297: trojan (2);
# CLUSTER 1300: trojan (2);
# CLUSTER 1301: trojan (3);
# CLUSTER 1305: trojan (6);
# CLUSTER 1308: trojan (2);
# CLUSTER 1316: pua (3);
# CLUSTER 1320: trojan (2);
# CLUSTER 1321: adware (8);
# CLUSTER 1323: trojan (4);
# CLUSTER 1329: trojan (16);
# CLUSTER 1332: trojan (2);
# CLUSTER 1337: _ (3);
# CLUSTER 1340: trojan (3);
# CLUSTER 1358: trojan (5);
# CLUSTER 1359: trojan (3);
# CLUSTER 1368: _ (5);
# CLUSTER 1373: trojan (6);
# CLUSTER 1377: trojan (2);
# CLUSTER 1383: trojan (2);
# CLUSTER 1385: trojan (6);
# CLUSTER 1386: _ (2);
# CLUSTER 1390: pua (2);
# CLUSTER 1400: trojan (2);
# CLUSTER 1401: _ (2);
# CLUSTER 1402: trojan (2);
# CLUSTER 1405: trojan (7);
# CLUSTER 1406: trojan (8);
# CLUSTER 1411: trojan (2);
# CLUSTER 1412: adware (3);
# CLUSTER 1420: trojan (3);
# CLUSTER 1423: trojan (12);
# CLUSTER 1425: pua (4);
# CLUSTER 1426: trojan (4);
# CLUSTER 1427: trojan (3);
# CLUSTER 1433: trojan (7);
# CLUSTER 1448: trojan (5);
# CLUSTER 1455: trojan (3);
# CLUSTER 1458: trojan (8);
# CLUSTER 1459: trojan (3);
# CLUSTER 1462: trojan (2);
# CLUSTER 1474: trojan (2);
# CLUSTER 1475: trojan (42);
# CLUSTER 1493: trojan (3);
# CLUSTER 1495: trojan (2);
# CLUSTER 1505: trojan (4);
# CLUSTER 1512: trojan (6);
# CLUSTER 1513: trojan (2);
# CLUSTER 1516: trojan (3);
# CLUSTER 1529: adware (2);
# CLUSTER 1538: trojan (2);
# CLUSTER 1539: trojan (4);
# CLUSTER 1541: trojan (3);
# CLUSTER 1550: trojan (4);
# CLUSTER 1554: _ (6);
# CLUSTER 1562: trojan (2);
# CLUSTER 1564: _ (7);
# CLUSTER 1573: trojan (4);
# CLUSTER 1574: trojan (8);
# CLUSTER 1585: trojan (7);
# CLUSTER 1586: trojan (2);
# CLUSTER 1591: trojan (2);
# CLUSTER 1595: trojan (3);
# CLUSTER 1596: trojan (20);
# CLUSTER 1599: trojan (3);
# CLUSTER 1604: _ (2);
# CLUSTER 1606: trojan (5);
# CLUSTER 1608: trojan (2);
# CLUSTER 1612: trojan (6);
# CLUSTER 1613: trojan (5);
# CLUSTER 1627: trojan (2);
# CLUSTER 1632: trojan (2);
# CLUSTER 1635: trojan (3);
# CLUSTER 1639: trojan (3);
# CLUSTER 1642: trojan (4);
# CLUSTER 1643: trojan (2);
# CLUSTER 1648: trojan (3);
# CLUSTER 1652: trojan (4);
# CLUSTER 1661: trojan (3);
# CLUSTER 1662: trojan (7);
# CLUSTER 1673: trojan (15);
# CLUSTER 1674: trojan (2);
# CLUSTER 1676: trojan (2);
# CLUSTER 1681: trojan (3);
# CLUSTER 1689: _ (2);
# CLUSTER 1699: trojan (12);
# CLUSTER 1714: miner (2);
# CLUSTER 1718: _ (2);
# CLUSTER 1719: trojan (2);
# CLUSTER 1722: trojan (5);
# CLUSTER 1723: trojan (9);
# CLUSTER 1724: _ (2);
# CLUSTER 1725: _ (2);
# CLUSTER 1736: trojan (2);
# CLUSTER 1738: trojan (2);
# CLUSTER 1746: trojan (3);
# CLUSTER 1750: trojan (2);
# CLUSTER 1753: ransomware (2);
# CLUSTER 1754: trojan (2);
# CLUSTER 1755: trojan (4);
# CLUSTER 1757: adware (2);
# CLUSTER 1763: _ (2);
# CLUSTER 1773: trojan (3);
# CLUSTER 1776: trojan (10);
# CLUSTER 1778: trojan (6);
# CLUSTER 1781: _ (4);
# CLUSTER 1786: trojan (2);
# CLUSTER 1790: trojan (4);
# CLUSTER 1797: trojan (3);
# CLUSTER 1800: trojan (7);
# CLUSTER 1807: trojan (13);
# CLUSTER 1811: trojan (3);
# CLUSTER 1814: trojan (3);
# CLUSTER 1817: trojan (2);
# CLUSTER 1825: trojan (3);
# CLUSTER 1829: trojan (17);
# CLUSTER 1830: trojan (3);
# CLUSTER 1841: trojan (2);
# CLUSTER 1842: trojan (3);
# CLUSTER 1850: adware (4);
# CLUSTER 1851: trojan (6);
# CLUSTER 1854: trojan (2);
# CLUSTER 1862: trojan (4);
# CLUSTER 1868: trojan (11);
# CLUSTER 1877: trojan (2);
# CLUSTER 1888: adware (4);
# CLUSTER 1891: trojan (2);
# CLUSTER 1895: trojan (2);
# CLUSTER 1896: trojan (10);
# CLUSTER 1909: trojan (2);
# CLUSTER 1911: trojan (3);
# CLUSTER 1912: adware (2);
# CLUSTER 1915: trojan (4);
# CLUSTER 1925: trojan (2);
# CLUSTER 1929: trojan (2);
# CLUSTER 1931: trojan (2);
# CLUSTER 1933: trojan (2);
# CLUSTER 1940: trojan (3);
# CLUSTER 1943: trojan (2);
# CLUSTER 1947: trojan (6);
# CLUSTER 1950: trojan (5);
# CLUSTER 1954: trojan (2);
# CLUSTER 1955: trojan (2);
# CLUSTER 1956: trojan (2);
# CLUSTER 1957: trojan (2);
# CLUSTER 1958: trojan (2);
# CLUSTER 1963: trojan (2);
# CLUSTER 1967: trojan (2);
# CLUSTER 1968: trojan (7);
# CLUSTER 1976: trojan (2);
# CLUSTER 1977: _ (2);
# CLUSTER 1981: trojan (4);
# CLUSTER 1988: trojan (3);
# CLUSTER 1996: trojan (2);
# CLUSTER 1997: trojan (2);
# CLUSTER 1998: trojan (4);
# CLUSTER 1999: trojan (2);
# CLUSTER 2014: trojan (9);
# CLUSTER 2015: _ (2);
# CLUSTER 2020: trojan (2);
# CLUSTER 2023: trojan (2);
# CLUSTER 2024: trojan (3);
# CLUSTER 2025: trojan (4);
# CLUSTER 2027: trojan (2);
# CLUSTER 2028: trojan (2);
# CLUSTER 2029: trojan (4);
# CLUSTER 2048: adware (6);
# CLUSTER 2053: trojan (3);
# CLUSTER 2059: trojan (10);
# CLUSTER 2064: trojan (5);
# CLUSTER 2066: trojan (4);
# CLUSTER 2071: trojan (2);
# CLUSTER 2080: trojan (2);
# CLUSTER 2082: _ (3);
# CLUSTER 2083: trojan (6);
# CLUSTER 2087: trojan (3);
# CLUSTER 2089: adware (2);
# CLUSTER 2092: trojan (4);
# CLUSTER 2093: trojan (2);
# CLUSTER 2096: trojan (2);
# CLUSTER 2104: trojan (2);
# CLUSTER 2106: trojan (2);
# CLUSTER 2107: trojan (3);
# CLUSTER 2111: trojan (4);
# CLUSTER 2114: pua (2);
# CLUSTER 2118: trojan (2);
# CLUSTER 2121: trojan (3);
# CLUSTER 2125: trojan (7);
# CLUSTER 2130: trojan (4);
# CLUSTER 2133: _ (2);
# CLUSTER 2147: _ (2);
# CLUSTER 2160: trojan (3);
# CLUSTER 2166: trojan (4);
# CLUSTER 2169: trojan (2);
# CLUSTER 2174: trojan (2);
# CLUSTER 2191: trojan (2);
# CLUSTER 2192: trojan (2);
# CLUSTER 2200: trojan (2);
# CLUSTER 2205: trojan (2);
# CLUSTER 2206: _ (2);
# CLUSTER 2207: trojan (7);
# CLUSTER 2218: trojan (3);
# CLUSTER 2220: trojan (2);
# CLUSTER 2222: trojan (2);
# CLUSTER 2230: trojan (3);
# CLUSTER 2236: trojan (2);
# CLUSTER 2239: _ (2);
# CLUSTER 2240: trojan (2);
# CLUSTER 2242: trojan (2);
# CLUSTER 2245: trojan (2);
# CLUSTER 2246: trojan (2);
# CLUSTER 2247: trojan (14);
# CLUSTER 2250: trojan (2);
# CLUSTER 2255: trojan (4);
# CLUSTER 2259: trojan (19);
# CLUSTER 2260: _ (2);
# CLUSTER 2267: trojan (3);
# CLUSTER 2270: trojan (5);
# CLUSTER 2271: _ (2);
# CLUSTER 2279: trojan (6);
# CLUSTER 2281: trojan (3);
# CLUSTER 2285: miner (3);
# CLUSTER 2286: trojan (12);
# CLUSTER 2287: trojan (3);
# CLUSTER 2291: trojan (3);
# CLUSTER 2292: _ (2);
# CLUSTER 2297: trojan (3);
# CLUSTER 2300: trojan (2);
# CLUSTER 2302: trojan (12);
# CLUSTER 2306: trojan (4);
# CLUSTER 2307: trojan (4);
# CLUSTER 2309: trojan (3);
# CLUSTER 2312: _ (2);
# CLUSTER 2314: trojan (3);
# CLUSTER 2317: trojan (5);
# CLUSTER 2323: trojan (8);
# CLUSTER 2332: trojan (2);
# CLUSTER 2336: trojan (8);
# CLUSTER 2338: trojan (2);
# CLUSTER 2341: trojan (2);
# CLUSTER 2347: trojan (3);
# CLUSTER 2348: trojan (3);
# CLUSTER 2361: trojan (8);
# CLUSTER 2362: trojan (4);
# CLUSTER 2365: trojan (3);
# CLUSTER 2369: trojan (4);
# CLUSTER 2371: trojan (6);
# CLUSTER 2372: trojan (2);
# CLUSTER 2382: trojan (2);
# CLUSTER 2388: trojan (8);
# CLUSTER 2389: trojan (4);
# CLUSTER 2392: trojan (4);
# CLUSTER 2395: trojan (3);
# CLUSTER 2396: trojan (7);
# CLUSTER 2407: trojan (2);
# CLUSTER 2413: trojan (6);
# CLUSTER 2423: trojan (3);
# CLUSTER 2425: trojan (5);
# CLUSTER 2429: trojan (2);
# CLUSTER 2430: trojan (2);
# CLUSTER 2433: trojan (2);
# CLUSTER 2438: trojan (2);
# CLUSTER 2445: trojan (4);
# CLUSTER 2446: trojan (5);
# CLUSTER 2467: trojan (2);
# CLUSTER 2468: trojan (2);
# CLUSTER 2469: trojan (4);
# CLUSTER 2470: trojan (9);
# CLUSTER 2478: trojan (2);
# CLUSTER 2480: trojan (6);
# CLUSTER 2488: trojan (7);
# CLUSTER 2493: trojan (6);
# CLUSTER 2500: trojan (2);
# CLUSTER 2504: trojan (3);
# CLUSTER 2529: trojan (3);
# CLUSTER 2538: trojan (7);
# CLUSTER 2540: trojan (2);
# CLUSTER 2552: trojan (3);
# CLUSTER 2556: trojan (2);
# CLUSTER 2559: trojan (4);
# CLUSTER 2564: trojan (2);
# CLUSTER 2571: adware (8);
# CLUSTER 2578: trojan (3);
# CLUSTER 2579: trojan (2);
# CLUSTER 2581: trojan (2);
# CLUSTER 2583: trojan (2);
# CLUSTER 2585: adware (3);
# CLUSTER 2599: trojan (7);
# CLUSTER 2600: trojan (2);
# CLUSTER 2604: trojan (7);
# CLUSTER 2612: _ (3);
# CLUSTER 2614: trojan (2);
# CLUSTER 2618: trojan (4);
# CLUSTER 2620: trojan (16);
# CLUSTER 2621: trojan (9);
# CLUSTER 2630: trojan (3);
# CLUSTER 2644: trojan (4);
# CLUSTER 2645: trojan (2);
# CLUSTER 2646: adware (9);
# CLUSTER 2661: trojan (26);
# CLUSTER 2664: trojan (3);
# CLUSTER 2666: trojan (3);
# CLUSTER 2677: trojan (2);
# CLUSTER 2688: trojan (2);
# CLUSTER 2690: trojan (3);
# CLUSTER 2698: trojan (2);
# CLUSTER 2699: trojan (3);
# CLUSTER 2700: adware (2);
# CLUSTER 2702: trojan (2);
# CLUSTER 2706: trojan (2);
# CLUSTER 2707: trojan (4);
# CLUSTER 2709: trojan (8);
# CLUSTER 2713: trojan (2);
# CLUSTER 2716: trojan (12);
# CLUSTER 2717: trojan (4);
# CLUSTER 2718: trojan (5);
# CLUSTER 2719: trojan (3);
# CLUSTER 2721: trojan (6);
# CLUSTER 2725: trojan (6);
# CLUSTER 2728: trojan (2);
# CLUSTER 2731: trojan (3);
# CLUSTER 2742: trojan (2);
# CLUSTER 2745: trojan (2);
# CLUSTER 2771: trojan (4);
# CLUSTER 2778: trojan (2);
# CLUSTER 2779: trojan (4);
# CLUSTER 2795: trojan (3);
# CLUSTER 2801: trojan (2);
# CLUSTER 2803: trojan (3);
# CLUSTER 2808: trojan (2);
# CLUSTER 2809: trojan (2);
# CLUSTER 2812: trojan (4);
# CLUSTER 2813: trojan (2);
# CLUSTER 2814: trojan (4);
# CLUSTER 2830: trojan (5);
# CLUSTER 2832: trojan (4);
# CLUSTER 2838: _ (2);
# CLUSTER 2842: trojan (4);
# CLUSTER 2844: trojan (4);
# CLUSTER 2848: trojan (3);
# CLUSTER 2855: trojan (3);
# CLUSTER 2857: trojan (15);
# CLUSTER 2860: trojan (6);
# CLUSTER 2865: _ (2);
# CLUSTER 2866: trojan (3);
# CLUSTER 2868: _ (2);
# CLUSTER 2891: trojan (7);
# CLUSTER 2895: trojan (2);
# CLUSTER 2896: trojan (11);
# CLUSTER 2897: trojan (6);
# CLUSTER 2898: trojan (3);
# CLUSTER 2909: trojan (4);
# CLUSTER 2917: _ (2);
# CLUSTER 2923: _ (2);
# CLUSTER 2925: trojan (6);
# CLUSTER 2926: trojan (3);
# CLUSTER 2928: trojan (2);
# CLUSTER 2933: trojan (4);
# CLUSTER 2956: trojan (2);
# CLUSTER 2958: trojan (2);
# CLUSTER 2968: trojan (3);
# CLUSTER 2971: trojan (6);
# CLUSTER 2972: trojan (2);
# CLUSTER 2980: trojan (4);
# CLUSTER 2983: trojan (2);
# CLUSTER 2987: trojan (2);
# CLUSTER 2992: trojan (3);
# CLUSTER 2994: trojan (3);
# CLUSTER 2996: trojan (2);
# CLUSTER 2997: trojan (3);
# CLUSTER 2998: trojan (2);
# CLUSTER 3003: trojan (4);
# CLUSTER 3012: trojan (5);
# CLUSTER 3028: trojan (3);
# CLUSTER 3029: trojan (3);
# CLUSTER 3032: trojan (2);
# CLUSTER 3038: trojan (3);
# CLUSTER 3040: trojan (9);
# CLUSTER 3046: trojan (3);
# CLUSTER 3054: trojan (4);
# CLUSTER 3059: trojan (4);
# CLUSTER 3064: _ (5);
# CLUSTER 3066: trojan (11);
# CLUSTER 3070: trojan (6);
# CLUSTER 3076: miner (4);
# CLUSTER 3080: trojan (2);
# CLUSTER 3084: trojan (2);
# CLUSTER 3087: trojan (2);
# CLUSTER 3090: trojan (4);
# CLUSTER 3092: trojan (5);
# CLUSTER 3102: trojan (4);
# CLUSTER 3105: trojan (3);
# CLUSTER 3111: trojan (2);
# CLUSTER 3115: _ (2);
# CLUSTER 3116: trojan (3);
# CLUSTER 3123: trojan (3);
# CLUSTER 3125: trojan (5);
# CLUSTER 3128: trojan (2);
# CLUSTER 3132: trojan (2);
# CLUSTER 3134: trojan (6);
# CLUSTER 3141: trojan (2);
# CLUSTER 3142: trojan (6);
# CLUSTER 3144: trojan (3);
# CLUSTER 3146: trojan (2);
# CLUSTER 3163: trojan (2);
# CLUSTER 3165: trojan (2);
# CLUSTER 3166: trojan (2);
# CLUSTER 3170: trojan (2);
# CLUSTER 3188: trojan (3);
# CLUSTER 3193: trojan (2);
# CLUSTER 3196: trojan (2);
# CLUSTER 3197: pua (2);
# CLUSTER 3199: trojan (3);
# CLUSTER 3207: trojan (2);
# CLUSTER 3222: _ (3);
# CLUSTER 3224: trojan (2);
# CLUSTER 3231: trojan (2);
# CLUSTER 3234: trojan (2);
# CLUSTER 3241: trojan (2);
# CLUSTER 3248: trojan (3);
# CLUSTER 3255: trojan (3);
# CLUSTER 3265: adware (2);
# CLUSTER 3275: adware (3);
# CLUSTER 3278: trojan (4);
# CLUSTER 3280: _ (7);
# CLUSTER 3299: _ (2);
# CLUSTER 3303: trojan (2);
# CLUSTER 3312: trojan (2);
# CLUSTER 3323: _ (2);
# CLUSTER 3327: trojan (3);
# CLUSTER 3329: trojan (5);
# CLUSTER 3331: trojan (2);
# CLUSTER 3334: trojan (4);
# CLUSTER 3337: trojan (4);
# CLUSTER 3342: pua (2);
# CLUSTER 3350: trojan (4);
# CLUSTER 3352: trojan (2);
# CLUSTER 3353: trojan (6);
# CLUSTER 3354: trojan (4);
# CLUSTER 3364: trojan (2);
# CLUSTER 3366: trojan (2);
# CLUSTER 3369: trojan (3);
# CLUSTER 3371: trojan (3);
# CLUSTER 3378: _ (3);
# CLUSTER 3379: trojan (2);
# CLUSTER 3385: trojan (2);
# CLUSTER 3386: trojan (2);
# CLUSTER 3387: trojan (2);
# CLUSTER 3392: _ (2);
# CLUSTER 3398: adware (2);
# CLUSTER 3399: trojan (4);
# CLUSTER 3423: trojan (2);
# CLUSTER 3436: trojan (2);
# CLUSTER 3473: trojan (2);
# CLUSTER 3475: trojan (7);
# CLUSTER 3478: trojan (9);
# CLUSTER 3480: trojan (3);
# CLUSTER 3481: trojan (2);
# CLUSTER 3488: trojan (3);
# CLUSTER 3498: _ (2);
# CLUSTER 3501: trojan (2);
# CLUSTER 3508: trojan (2);
# CLUSTER 3509: trojan (4);
# CLUSTER 3511: trojan (2);
# CLUSTER 3516: trojan (2);
# CLUSTER 3523: trojan (5);
# CLUSTER 3524: adware (2);
# CLUSTER 3529: trojan (3);
# CLUSTER 3539: trojan (3);
# CLUSTER 3541: _ (2);
# CLUSTER 3542: _ (2);
# CLUSTER 3549: _ (3);
# CLUSTER 3560: trojan (3);
# CLUSTER 3563: trojan (3);
# CLUSTER 3564: trojan (4);
# CLUSTER 3565: _ (6);
# CLUSTER 3567: trojan (4);
# CLUSTER 3568: trojan (7);
# CLUSTER 3581: trojan (2);
# CLUSTER 3593: _ (2);
# CLUSTER 3595: adware (2);
# CLUSTER 3607: _ (2);
# CLUSTER 3610: trojan (4);
# CLUSTER 3616: adware (2);
# CLUSTER 3622: trojan (4);
# CLUSTER 3630: trojan (3);
# CLUSTER 3636: _ (3);
# CLUSTER 3647: pua (3);
# CLUSTER 3658: trojan (2);
# CLUSTER 3677: trojan (5);
# CLUSTER 3681: trojan (3);
# CLUSTER 3687: trojan (3);
# CLUSTER 3690: trojan (2);
# CLUSTER 3697: trojan (3);
# CLUSTER 3703: pua (2);
# CLUSTER 3705: trojan (2);
# CLUSTER 3715: trojan (4);
# CLUSTER 3716: trojan (10);
# CLUSTER 3720: trojan (4);
# CLUSTER 3738: trojan (4);
# CLUSTER 3743: trojan (6);
# CLUSTER 3753: trojan (2);
# CLUSTER 3757: trojan (4);
# CLUSTER 3759: trojan (2);
# CLUSTER 3768: trojan (2);
# CLUSTER 3771: trojan (2);
# CLUSTER 3779: trojan (7);
# CLUSTER 3782: adware (2);
# CLUSTER 3787: trojan (2);
# CLUSTER 3794: trojan (3);
# CLUSTER 3797: trojan (8);
# CLUSTER 3803: trojan (2);
# CLUSTER 3809: _ (2);
# CLUSTER 3820: trojan (4);
# CLUSTER 3821: trojan (4);
# CLUSTER 3828: trojan (2);
# CLUSTER 3846: miner (4);
# CLUSTER 3847: trojan (2);
# CLUSTER 3851: trojan (2);
# CLUSTER 3860: trojan (2);
# CLUSTER 3863: trojan (2);
# CLUSTER 3864: adware (4);
# CLUSTER 3879: adware (6);
# CLUSTER 3884: trojan (5);
# CLUSTER 3891: trojan (2);
# CLUSTER 3896: trojan (2);
# CLUSTER 3900: trojan (2);
# CLUSTER 3904: trojan (2);
# CLUSTER 3905: trojan (2);
# CLUSTER 3932: trojan (2);
# CLUSTER 3951: trojan (2);
# CLUSTER 3952: miner (2);
# CLUSTER 3962: trojan (2);
# CLUSTER 3966: trojan (2);
# CLUSTER 3985: trojan (2);
# CLUSTER 3990: trojan (5);
# CLUSTER 3991: trojan (2);
# CLUSTER 3992: trojan (2);
# CLUSTER 4012: trojan (2);
# CLUSTER 4014: trojan (3);
# CLUSTER 4016: trojan (4);
# CLUSTER 4030: trojan (2);
# CLUSTER 4033: trojan (2);
# CLUSTER 4035: trojan (4);
# CLUSTER 4036: trojan (2);
# CLUSTER 4044: trojan (2);
# CLUSTER 4045: trojan (3);
# CLUSTER 4052: _ (2);
# CLUSTER 4061: trojan (2);
# CLUSTER 4067: _ (2);
# CLUSTER 4091: trojan (3);
# CLUSTER 4097: trojan (2);
# CLUSTER 4102: adware (2);
# CLUSTER 4109: trojan (9);
# CLUSTER 4115: ransomware (2);
# CLUSTER 4116: _ (2);
# CLUSTER 4121: trojan (2);
# CLUSTER 4124: trojan (2);
# CLUSTER 4127: trojan (2);
# CLUSTER 4137: _ (2);
# CLUSTER 4142: trojan (2);
# CLUSTER 4156: trojan (2);
# CLUSTER 4159: trojan (3);
# CLUSTER 4162: _ (2);
# CLUSTER 4167: trojan (2);
# CLUSTER 4174: trojan (2);
# CLUSTER 4177: _ (6);
# CLUSTER 4184: trojan (3);
# CLUSTER 4185: _ (3);
# CLUSTER 4189: trojan (2);
# CLUSTER 4193: trojan (2);
# CLUSTER 4199: trojan (2);
# CLUSTER 4205: _ (2);
# CLUSTER 4212: trojan (2);
# CLUSTER 4219: trojan (4);
# CLUSTER 4226: trojan (3);
# CLUSTER 4228: trojan (4);
# CLUSTER 4230: trojan (2);
# CLUSTER 4231: trojan (3);
# CLUSTER 4241: trojan (3);
# CLUSTER 4242: trojan (3);
# CLUSTER 4243: trojan (2);
# CLUSTER 4256: trojan (3);
# CLUSTER 4271: trojan (4);
# CLUSTER 4280: trojan (2);
# CLUSTER 4281: adware (2);
# CLUSTER 4282: trojan (2);
# CLUSTER 4292: trojan (2);
# CLUSTER 4304: _ (2);
# CLUSTER 4306: trojan (4);
# CLUSTER 4308: trojan (2);
# CLUSTER 4312: trojan (3);
# CLUSTER 4313: trojan (4);
# CLUSTER 4318: trojan (3);
# CLUSTER 4319: _ (2);
# CLUSTER 4329: trojan (2);
# CLUSTER 4332: _ (2);
# CLUSTER 4333: _ (4);
# CLUSTER 4340: trojan (4);
# CLUSTER 4341: trojan (2);
# CLUSTER 4345: trojan (3);
# CLUSTER 4353: virus (2);
# CLUSTER 4361: trojan (2);
# CLUSTER 4363: trojan (8);
# CLUSTER 4364: trojan (2);
# CLUSTER 4366: trojan (2);
# CLUSTER 4371: trojan (2);
# CLUSTER 4375: trojan (2);
# CLUSTER 4376: pua (2);
# CLUSTER 4381: trojan (2);
# CLUSTER 4398: trojan (2);
# CLUSTER 4407: adware (5);
# CLUSTER 4411: trojan (2);
# CLUSTER 4414: trojan (2);
# CLUSTER 4419: trojan (4);
# CLUSTER 4423: trojan (5);
# CLUSTER 4450: trojan (9);
# CLUSTER 4466: trojan (3);
# CLUSTER 4469: trojan (3);
# CLUSTER 4473: trojan (2);
# CLUSTER 4476: trojan (3);
# CLUSTER 4477: trojan (2);
# CLUSTER 4478: trojan (6);
# CLUSTER 4479: trojan (2);
# CLUSTER 4495: trojan (3);
# CLUSTER 4497: trojan (4);
# CLUSTER 4500: _ (2);
# CLUSTER 4504: _ (2);
# CLUSTER 4506: _ (2);
# CLUSTER 4507: trojan (3);
# CLUSTER 4510: trojan (2);
# CLUSTER 4519: trojan (2);
# CLUSTER 4530: trojan (2);
# CLUSTER 4531: trojan (2);
# CLUSTER 4537: trojan (2);
# CLUSTER 4539: trojan (4);
# CLUSTER 4541: trojan (2);
# CLUSTER 4547: adware (2);
# CLUSTER 4549: trojan (3);
# CLUSTER 4550: trojan (5);
# CLUSTER 4552: trojan (3);
# CLUSTER 4562: trojan (4);
# CLUSTER 4566: trojan (2);
# CLUSTER 4573: trojan (4);
# CLUSTER 4586: trojan (3);
# CLUSTER 4592: trojan (3);
# CLUSTER 4599: trojan (2);
# CLUSTER 4625: trojan (3);
# CLUSTER 4637: trojan (2);
# CLUSTER 4645: trojan (4);
# CLUSTER 4663: trojan (7);
# CLUSTER 4665: trojan (2);
# CLUSTER 4666: trojan (2);
# CLUSTER 4668: _ (5);
# CLUSTER 4676: trojan (2);
# CLUSTER 4684: trojan (13);
# CLUSTER 4686: trojan (2);
# CLUSTER 4688: trojan (2);
# CLUSTER 4691: trojan (4);
# CLUSTER 4695: trojan (6);
# CLUSTER 4699: trojan (2);
# CLUSTER 4702: trojan (2);
# CLUSTER 4703: _ (3);
# CLUSTER 4710: trojan (2);
# CLUSTER 4713: trojan (4);
# CLUSTER 4720: trojan (3);
# CLUSTER 4735: pua (2);
# CLUSTER 4736: _ (3);
# CLUSTER 4740: trojan (3);
# CLUSTER 4752: _ (3);
# CLUSTER 4754: trojan (3);
# CLUSTER 4755: trojan (4);
# CLUSTER 4758: trojan (3);
# CLUSTER 4762: trojan (2);
# CLUSTER 4772: trojan (3);
# CLUSTER 4776: trojan (2);
# CLUSTER 4777: trojan (3);
# CLUSTER 4785: _ (3);
# CLUSTER 4789: trojan (4);
# CLUSTER 4793: trojan (3);
# CLUSTER 4799: trojan (2);
# CLUSTER 4801: trojan (2);
# CLUSTER 4809: trojan (3);
# CLUSTER 4815: trojan (5);
# CLUSTER 4820: trojan (2);
# CLUSTER 4827: trojan (2);
# CLUSTER 4842: trojan (4);
# CLUSTER 4847: trojan (3);
# CLUSTER 4869: trojan (2);
# CLUSTER 4888: trojan (2);
# CLUSTER 4889: trojan (5);
# CLUSTER 4903: trojan (2);
# CLUSTER 4906: _ (2);
# CLUSTER 4912: trojan (2);
# CLUSTER 4913: trojan (2);
# CLUSTER 4922: trojan (2);
# CLUSTER 4925: trojan (6);
# CLUSTER 4929: trojan (4);
# CLUSTER 4943: pua (2);
# CLUSTER 4944: trojan (2);
# CLUSTER 4946: trojan (2);
# CLUSTER 4947: trojan (4);
# CLUSTER 4953: _ (2);
# CLUSTER 4966: trojan (2);
# CLUSTER 4969: trojan (2);
# CLUSTER 4979: _ (2);
# CLUSTER 4990: trojan (2);
# CLUSTER 4996: trojan (2);
# CLUSTER 5003: trojan (2);
# CLUSTER 5008: _ (2);
# CLUSTER 5010: trojan (2);
# CLUSTER 5012: trojan (2);
# CLUSTER 5014: trojan (2);
# CLUSTER 5019: trojan (2);
# CLUSTER 5024: trojan (2);
# CLUSTER 5042: trojan (2);
# CLUSTER 5051: trojan (2);
# CLUSTER 5058: trojan (2);
# CLUSTER 5062: trojan (3);
# CLUSTER 5064: trojan (2);
# CLUSTER 5066: trojan (2);
# CLUSTER 5068: adware (2);
# CLUSTER 5071: trojan (4);
# CLUSTER 5085: trojan (2);
# CLUSTER 5094: trojan (2);
# CLUSTER 5096: trojan (2);
# CLUSTER 5103: trojan (2);
# CLUSTER 5105: _ (2);
# CLUSTER 5106: trojan (5);
# CLUSTER 5108: _ (2);
# CLUSTER 5117: trojan (2);
# CLUSTER 5124: trojan (4);
# CLUSTER 5136: trojan (2);
# CLUSTER 5140: _ (3);
# CLUSTER 5143: trojan (3);
# CLUSTER 5144: trojan (3);
# CLUSTER 5149: trojan (7);
# CLUSTER 5160: _ (2);
# CLUSTER 5170: trojan (5);
# CLUSTER 5183: trojan (3);
# CLUSTER 5184: trojan (4);
# CLUSTER 5192: trojan (3);
# CLUSTER 5198: trojan (2);
# CLUSTER 5201: trojan (2);
# CLUSTER 5204: trojan (4);
# CLUSTER 5206: trojan (3);
# CLUSTER 5211: trojan (4);
# CLUSTER 5217: adware (5);
# CLUSTER 5219: trojan (2);
# CLUSTER 5220: adware (2);
# CLUSTER 5224: trojan (2);
# CLUSTER 5229: _ (2);
# CLUSTER 5230: pua (2);
# CLUSTER 5233: _ (2);
# CLUSTER 5235: trojan (2);
# CLUSTER 5240: trojan (2);
# CLUSTER 5252: trojan (2);
# CLUSTER 5253: trojan (2);
# CLUSTER 5256: trojan (3);
# CLUSTER 5262: trojan (2);
# CLUSTER 5263: _ (3);
# CLUSTER 5269: trojan (5);
# CLUSTER 5272: trojan (2);
# CLUSTER 5274: trojan (4);
# CLUSTER 5308: trojan (2);
# CLUSTER 5313: _ (2);
# CLUSTER 5317: trojan (2);
# CLUSTER 5328: trojan (3);
# CLUSTER 5329: trojan (6);
# CLUSTER 5332: _ (2);
# CLUSTER 5338: trojan (2);
# CLUSTER 5355: trojan (3);
# CLUSTER 5359: _ (2);
# CLUSTER 5361: trojan (3);
# CLUSTER 5395: trojan (2);
# CLUSTER 5400: trojan (3);
# CLUSTER 5419: trojan (3);
# CLUSTER 5420: trojan (2);
# CLUSTER 5424: _ (2);
# CLUSTER 5447: trojan (2);
# CLUSTER 5450: trojan (4);
# CLUSTER 5461: trojan (2);
# CLUSTER 5468: trojan (3);
# CLUSTER 5471: trojan (3);
# CLUSTER 5474: trojan (2);
# CLUSTER 5479: trojan (2);
# CLUSTER 5481: trojan (6);
# CLUSTER 5482: trojan (7);
# CLUSTER 5489: trojan (2);
# CLUSTER 5490: trojan (2);
# CLUSTER 5493: trojan (2);
# CLUSTER 5494: trojan (2);
# CLUSTER 5503: trojan (4);
# CLUSTER 5504: trojan (2);
# CLUSTER 5514: trojan (2);
# CLUSTER 5518: _ (2);
# CLUSTER 5519: trojan (2);
# CLUSTER 5521: trojan (2);
# CLUSTER 5522: trojan (2);
# CLUSTER 5523: trojan (2);
# CLUSTER 5524: trojan (2);
# CLUSTER 5530: trojan (2);
# CLUSTER 5552: trojan (2);
# CLUSTER 5561: trojan (3);
# CLUSTER 5565: _ (3);
# CLUSTER 5597: trojan (3);
# CLUSTER 5600: trojan (3);
# CLUSTER 5613: trojan (2);
# CLUSTER 5622: trojan (2);
# CLUSTER 5635: trojan (2);
# CLUSTER 5656: trojan (2);
# CLUSTER 5667: _ (2);
# CLUSTER 5672: adware (2);
# CLUSTER 5674: trojan (3);
# CLUSTER 5681: trojan (2);
# CLUSTER 5718: trojan (2);
# CLUSTER 5730: trojan (3);
# CLUSTER 5743: trojan (3);
# CLUSTER 5747: trojan (2);
# CLUSTER 5759: trojan (2);
# CLUSTER 5767: trojan (5);
# CLUSTER 5768: trojan (2);
# CLUSTER 5776: trojan (2);
# CLUSTER 5777: trojan (2);
# CLUSTER 5782: trojan (2);
# CLUSTER 5802: trojan (2);
# CLUSTER 5803: trojan (3);
# CLUSTER 5814: trojan (2);
# CLUSTER 5818: trojan (5);
# CLUSTER 5827: virus (2);
# CLUSTER 5845: trojan (2);
# CLUSTER 5848: miner (4);
# CLUSTER 5865: adware (3);
# CLUSTER 5870: trojan (3);
# CLUSTER 5871: trojan (2);
# CLUSTER 5881: trojan (3);
# CLUSTER 5886: trojan (2);
# CLUSTER 5888: trojan (3);
# CLUSTER 5890: trojan (2);
# CLUSTER 5896: trojan (2);
# CLUSTER 5900: adware (2);
# CLUSTER 5909: trojan (3);
# CLUSTER 5919: trojan (2);
# CLUSTER 5928: trojan (10);
# CLUSTER 5930: trojan (2);
# CLUSTER 5940: trojan (2);
# CLUSTER 5944: trojan (2);
# CLUSTER 5947: trojan (2);
# CLUSTER 5948: trojan (4);
# CLUSTER 5960: trojan (2);
# CLUSTER 5964: trojan (2);
# CLUSTER 5992: pua (3);
# CLUSTER 5995: trojan (2);
# CLUSTER 5998: trojan (3);
# CLUSTER 6015: trojan (3);
# CLUSTER 6036: trojan (2);
# CLUSTER 6047: trojan (2);
# CLUSTER 6056: trojan (2);
# CLUSTER 6064: trojan (4);
# CLUSTER 6065: trojan (2);
# CLUSTER 6080: adware (2);
# CLUSTER 6081: trojan (2);
# CLUSTER 6097: trojan (3);
# CLUSTER 6110: downloader (2);
# CLUSTER 6116: trojan (8);
# CLUSTER 6119: trojan (3);
# CLUSTER 6135: trojan (2);
# CLUSTER 6142: trojan (3);
# CLUSTER 6144: pua (2);
# CLUSTER 6146: trojan (9);
# CLUSTER 6154: trojan (3);
# CLUSTER 6158: trojan (2);
# CLUSTER 6162: trojan (2);
# CLUSTER 6169: trojan (2);
# CLUSTER 6177: pua (2);
# CLUSTER 6186: trojan (2);
# CLUSTER 6194: trojan (2);
# CLUSTER 6203: trojan (2);
# CLUSTER 6210: trojan (3);
# CLUSTER 6226: trojan (2);
# CLUSTER 6249: _ (2);
# CLUSTER 6251: trojan (2);
# CLUSTER 6252: trojan (2);
# CLUSTER 6262: trojan (2);
# CLUSTER 6268: trojan (2);
# CLUSTER 6272: trojan (2);
# CLUSTER 6275: trojan (4);
# CLUSTER 6281: trojan (2);
# CLUSTER 6292: trojan (2);
# CLUSTER 6293: trojan (2);
# CLUSTER 6308: trojan (5);
# CLUSTER 6328: trojan (2);
# CLUSTER 6359: trojan (2);
# CLUSTER 6389: trojan (6);
# CLUSTER 6390: trojan (2);
# CLUSTER 6394: trojan (2);
# CLUSTER 6420: pua (2);
# CLUSTER 6425: trojan (2);
# CLUSTER 6430: adware (2);
# CLUSTER 6433: trojan (3);
# CLUSTER 6440: spyware (3);
# CLUSTER 6451: pua (2);
# CLUSTER 6463: trojan (2);
# CLUSTER 6474: trojan (2);
# CLUSTER 6481: trojan (2);
# CLUSTER 6501: trojan (2);
# CLUSTER 6502: trojan (2);
# CLUSTER 6529: _ (2);
# CLUSTER 6530: trojan (2);
# CLUSTER 6531: adware (2);
# CLUSTER 6533: adware (3);
# CLUSTER 6536: trojan (2);
# CLUSTER 6539: trojan (2);
# CLUSTER 6548: trojan (4);
# CLUSTER 6562: trojan (2);
# CLUSTER 6568: trojan (5);
# CLUSTER 6572: trojan (2);
# CLUSTER 6574: trojan (2);
# CLUSTER 6577: trojan (2);
# CLUSTER 6588: trojan (3);
# CLUSTER 6592: trojan (5);
# CLUSTER 6602: trojan (2);
# CLUSTER 6609: trojan (2);
# CLUSTER 6615: trojan (2);
# CLUSTER 6639: trojan (2);
# CLUSTER 6641: trojan (2);
# CLUSTER 6645: trojan (3);
# CLUSTER 6679: trojan (4);
# CLUSTER 6682: trojan (2);
# CLUSTER 6684: trojan (2);
# CLUSTER 6685: trojan (2);
# CLUSTER 6690: trojan (2);
# CLUSTER 6693: trojan (2);
# CLUSTER 6696: trojan (2);
# CLUSTER 6697: trojan (2);
# CLUSTER 6711: trojan (2);
# CLUSTER 6714: trojan (4);
# CLUSTER 6777: trojan (3);
# CLUSTER 6792: trojan (2);
# CLUSTER 6798: trojan (2);
# CLUSTER 6800: trojan (4);
# CLUSTER 6801: trojan (2);
# CLUSTER 6802: trojan (2);
# CLUSTER 6843: trojan (2);
# CLUSTER 6864: trojan (2);
# CLUSTER 6886: trojan (2);
# CLUSTER 6900: adware (2);
# CLUSTER 6919: trojan (2);
# CLUSTER 6921: trojan (2);
# CLUSTER 6928: trojan (2);
# CLUSTER 6933: trojan (3);
# CLUSTER 6965: trojan (3);
# CLUSTER 6975: trojan (2);
# CLUSTER 6982: trojan (4);
# CLUSTER 7005: trojan (2);
# CLUSTER 7032: trojan (2);
# CLUSTER 7052: trojan (2);
# CLUSTER 7053: adware (3);
# CLUSTER 7054: pua (2);
# CLUSTER 7060: trojan (3);
# CLUSTER 7064: trojan (2);
# CLUSTER 7068: trojan (3);
# CLUSTER 7077: trojan (3);
# CLUSTER 7087: trojan (2);
# CLUSTER 7091: trojan (3);
# CLUSTER 7102: trojan (3);
# CLUSTER 7105: adware (2);
# CLUSTER 7124: _ (2);
# CLUSTER 7130: trojan (2);
# CLUSTER 7132: trojan (2);
# CLUSTER 7133: trojan (2);
# CLUSTER 7141: adware (2);
# CLUSTER 7144: trojan (6);
# CLUSTER 7150: trojan (2);
# CLUSTER 7153: trojan (2);
# CLUSTER 7161: trojan (3);
# CLUSTER 7164: trojan (2);
# CLUSTER 7165: trojan (2);
# CLUSTER 7167: trojan (2);
# CLUSTER 7169: trojan (2);
# CLUSTER 7181: _ (2);
# CLUSTER 7200: ransomware (2);
# CLUSTER 7242: trojan (3);
# CLUSTER 7264: trojan (2);
# CLUSTER 7273: trojan (3);
# CLUSTER 7284: _ (2);
# CLUSTER 7292: trojan (2);
# CLUSTER 7301: trojan (2);
# CLUSTER 7306: trojan (2);
# CLUSTER 7307: trojan (2);
# CLUSTER 7309: trojan (2);
# CLUSTER 7319: trojan (3);
# CLUSTER 7323: trojan (2);
# CLUSTER 7324: trojan (2);
# CLUSTER 7347: trojan (2);
# CLUSTER 7366: _ (3);
# CLUSTER 7385: trojan (2);
# CLUSTER 7411: trojan (3);
# CLUSTER 7421: trojan (2);
# CLUSTER 7439: trojan (2);
# CLUSTER 7443: trojan (2);
# CLUSTER 7458: trojan (3);
# CLUSTER 7460: trojan (2);
# CLUSTER 7471: trojan (2);
# CLUSTER 7495: trojan (2);
# CLUSTER 7509: _ (2);
# CLUSTER 7519: trojan (2);
# CLUSTER 7523: pua (2);
# CLUSTER 7535: trojan (3);
# CLUSTER 7545: trojan (3);
# CLUSTER 7548: trojan (3);
# CLUSTER 7553: trojan (2);
# CLUSTER 7557: pua (2);
# CLUSTER 7563: trojan (2);
# CLUSTER 7574: trojan (2);
# CLUSTER 7578: trojan (3);
# CLUSTER 7581: trojan (2);
# CLUSTER 7597: trojan (3);
# CLUSTER 7600: adware (2);
# CLUSTER 7618: trojan (2);
# CLUSTER 7627: _ (2);
# CLUSTER 7648: trojan (3);
# CLUSTER 7661: trojan (3);
# CLUSTER 7668: trojan (2);
# CLUSTER 7683: trojan (2);
# CLUSTER 7690: trojan (2);
# CLUSTER 7698: trojan (2);
# CLUSTER 7721: trojan (2);
# CLUSTER 7725: trojan (2);
# CLUSTER 7728: trojan (2);
# CLUSTER 7742: trojan (2);
# CLUSTER 7748: adware (8);
# CLUSTER 7782: _ (2);
# CLUSTER 7800: trojan (2);
# CLUSTER 7803: trojan (2);
# CLUSTER 7805: _ (2);
# CLUSTER 7813: trojan (2);
# CLUSTER 7825: adware (2);
# CLUSTER 7836: trojan (3);
# CLUSTER 7853: trojan (2);
# CLUSTER 7871: trojan (2);
# CLUSTER 7890: trojan (2);
# CLUSTER 7901: trojan (2);
# CLUSTER 7909: trojan (2);
# CLUSTER 7915: trojan (2);
# CLUSTER 7933: trojan (2);
# CLUSTER 7934: trojan (4);
# CLUSTER 7942: trojan (2);
# CLUSTER 7948: _ (2);
# CLUSTER 7975: trojan (3);
# CLUSTER 8006: trojan (4);
# CLUSTER 8009: trojan (4);
# CLUSTER 8022: trojan (2);
# CLUSTER 8026: trojan (4);
# CLUSTER 8035: trojan (2);
# CLUSTER 8037: trojan (2);
# CLUSTER 8073: trojan (2);
# CLUSTER 8108: trojan (3);
# CLUSTER 8124: trojan (2);
# CLUSTER 8129: trojan (3);
# CLUSTER 8133: _ (2);
# CLUSTER 8135: trojan (3);
# CLUSTER 8140: trojan (2);
# CLUSTER 8153: trojan (2);
# CLUSTER 8164: trojan (2);
# CLUSTER 8173: trojan (2);
# CLUSTER 8175: _ (2);
# CLUSTER 8183: trojan (2);
# CLUSTER 8185: trojan (2);
# CLUSTER 8207: adware (2);
# CLUSTER 8229: trojan (2);
# CLUSTER 8240: pua (2);
# CLUSTER 8249: trojan (2);
# CLUSTER 8251: trojan (2);
# CLUSTER 8253: trojan (2);
# CLUSTER 8255: trojan (2);
# CLUSTER 8258: trojan (3);
# CLUSTER 8261: trojan (2);
# CLUSTER 8272: trojan (2);
# CLUSTER 8300: trojan (4);
# CLUSTER 8303: trojan (3);
# CLUSTER 8306: trojan (3);
# CLUSTER 8313: pua (2);
# CLUSTER 8329: trojan (2);
# CLUSTER 8331: trojan (3);
# CLUSTER 8343: trojan (2);
# CLUSTER 8366: adware (2);
# CLUSTER 8368: trojan (2);
# CLUSTER 8382: trojan (2);
# CLUSTER 8400: trojan (2);
# CLUSTER 8404: trojan (2);
# CLUSTER 8428: trojan (2);
# CLUSTER 8429: adware (2);
# CLUSTER 8431: trojan (2);
# CLUSTER 8443: trojan (2);
# CLUSTER 8449: trojan (2);
# CLUSTER 8464: _ (3);
# CLUSTER 8478: trojan (2);
# CLUSTER 8481: _ (2);
# CLUSTER 8483: trojan (2);
# CLUSTER 8490: trojan (2);
# CLUSTER 8570: trojan (3);
# CLUSTER 8590: trojan (2);
# CLUSTER 8596: trojan (2);
# CLUSTER 8601: trojan (2);
# CLUSTER 8629: trojan (2);
# CLUSTER 8638: _ (2);
# CLUSTER 8670: trojan (4);
# CLUSTER 8688: _ (2);
# CLUSTER 8694: trojan (2);
# CLUSTER 8700: trojan (2);
# CLUSTER 8710: trojan (2);
# CLUSTER 8712: trojan (2);
# CLUSTER 8713: trojan (2);
# CLUSTER 8732: trojan (2);
# CLUSTER 8788: trojan (2);
# CLUSTER 8848: trojan (2);
# CLUSTER 8904: trojan (2);
# CLUSTER 8908: trojan (2);
# CLUSTER 8916: trojan (2);
# CLUSTER 8951: trojan (3);
# CLUSTER 8967: trojan (4);
# CLUSTER 8973: trojan (3);
# CLUSTER 9004: trojan (2);
# CLUSTER 9005: trojan (2);
# CLUSTER 9011: trojan (2);
# CLUSTER 9016: trojan (2);
# CLUSTER 9049: trojan (2);
# CLUSTER 9057: _ (2);
# CLUSTER 9066: trojan (2);
# CLUSTER 9076: _ (2);
# CLUSTER 9112: trojan (2);
# CLUSTER 9212: trojan (2);
# CLUSTER 9213: trojan (2);
# CLUSTER 9217: trojan (2);
# CLUSTER 9231: trojan (3);
# CLUSTER 9252: trojan (3);
# CLUSTER 9255: trojan (2);
# CLUSTER 9289: trojan (2);
# CLUSTER 9319: trojan (2);
# CLUSTER 9323: _ (2);
# CLUSTER 9332: trojan (3);
# CLUSTER 9352: trojan (2);
# CLUSTER 9353: trojan (2);
# CLUSTER 9389: trojan (2);
# CLUSTER 9449: trojan (2);
# CLUSTER 9475: trojan (2);
# CLUSTER 9483: trojan (2);
# CLUSTER 9486: trojan (2);
# CLUSTER 9499: trojan (2);
# CLUSTER 9501: trojan (2);
# CLUSTER 9545: trojan (3);
# CLUSTER 9591: _ (2);
# CLUSTER 9593: trojan (2);
# CLUSTER 9633: trojan (2);
# CLUSTER 9648: trojan (2);
# CLUSTER 9676: trojan (2);
# CLUSTER 9686: _ (3);
# CLUSTER 9742: trojan (2);
# CLUSTER 9745: trojan (2);
# CLUSTER 9752: trojan (2);
# CLUSTER 9787: pua (2);
# CLUSTER 9793: pua (2);
# CLUSTER 9809: trojan (2);
# CLUSTER 9850: trojan (2);
# CLUSTER 9855: trojan (4);
# CLUSTER 9875: trojan (2);
# CLUSTER 9919: trojan (2);
# CLUSTER 9970: trojan (3);
# CLUSTER 9971: trojan (3);
# CLUSTER 9996: pua (2);
# CLUSTER 10007: trojan (3);
# CLUSTER 10014: trojan (2);
# CLUSTER 10029: adware (2);
# CLUSTER 10030: trojan (2);
# CLUSTER 10042: trojan (3);
# CLUSTER 10043: trojan (2);
# CLUSTER 10052: trojan (2);
# CLUSTER 10073: trojan (2);
# CLUSTER 10117: trojan (2);
# CLUSTER 10181: trojan (2);
# CLUSTER 10186: trojan (2);
# CLUSTER 10310: trojan (2);
# CLUSTER 10315: trojan (2);
# CLUSTER 10392: trojan (2);
# CLUSTER 10401: adware (2);
# CLUSTER 10454: trojan (2);
# CLUSTER 10484: trojan (2);
# CLUSTER 10507: trojan (2);
# CLUSTER 10532: trojan (2);
# CLUSTER 10544: _ (2);
# CLUSTER 10547: trojan (2);
# CLUSTER 10603: trojan (2);
# CLUSTER 10607: pua (2);
# CLUSTER 10611: trojan (2);
# CLUSTER 10618: trojan (2);
# CLUSTER 10651: trojan (2);
# CLUSTER 10655: trojan (2);
# CLUSTER 10678: trojan (2);
# CLUSTER 10682: trojan (2);
# CLUSTER 10690: trojan (2);
# CLUSTER 10703: trojan (4);
# CLUSTER 10715: trojan (2);
# CLUSTER 10731: trojan (2);
# CLUSTER 10753: trojan (2);
# CLUSTER 10812: trojan (2);
# CLUSTER 10825: trojan (2);
# CLUSTER 10836: trojan (2);
# CLUSTER 10872: trojan (2);
# CLUSTER 10898: trojan (2);
# CLUSTER 10928: trojan (2);
# CLUSTER 10996: trojan (2);
# CLUSTER 11011: trojan (2);
# CLUSTER 11028: trojan (2);
# CLUSTER 11031: trojan (2);
# CLUSTER 11042: trojan (2);
# CLUSTER 11069: trojan (2);
# CLUSTER 11126: trojan (2);
# CLUSTER 11236: trojan (2);
# CLUSTER 11247: trojan (2);
# CLUSTER 11403: trojan (2);
# CLUSTER 11415: trojan (2);
# CLUSTER 11419: trojan (2);
# CLUSTER 11442: _ (2);
# CLUSTER 11473: trojan (2);
# CLUSTER 11530: trojan (2);
# CLUSTER 11691: trojan (2);
# CLUSTER 11756: trojan (2);
# CLUSTER 11876: trojan (2);
# CLUSTER 11881: trojan (2);
# CLUSTER 11922: trojan (2);
# CLUSTER 12314: trojan (2);
# CLUSTER 12335: trojan (2);

# %% [markdown]
# ### Identify the Clusters that have the same Unique Malware Type
#
# This indicates what clusters have verified malicious samples that match specific Malware Types.
#
# This indicates the most occuring Malware Type which extends to the most 'popular' malware type that is probably found in the dataset.
#
# Such findings may also be used as a reflection as to what malware types are most prevalent in the wild.

# %%
# Summarize Clusters that have the same malware types as per VirusTotal.
str_output = f"# of Unique Malware Type: {len(malicious_df['type'].unique())}" + "\n\n"

cluster_instance_summary = [0] * len(list(malicious_df['cluster'].unique()))
count_summary = []
for i, u in enumerate(list(malicious_df['type'].unique())):
    matching = malicious_df[malicious_df['type'] == u]['cluster']
    count_summary.append([u, len(list(matching)), len(list(matching.unique())) ,str(list(matching.unique()))])
    str_output += f"Unique Malware Type: {i+1}".upper() + "\n"
    str_output += f"Malware Type: {u}" + "\n"
    str_output += f"Matching Clusters Count: {len(list(matching.unique()))}" + "\n"
    str_output += f"Matching Clusters: {list(matching.unique())}" + "\n"
    str_output += "\n"
with open("./Output/1 Clusters_on_Unique_MalwareType_woNoise.txt", 'w') as f:
    f.write(str_output)
    f.flush
    f.close()
print(str_output)

count_summary.sort(key=lambda x: x[1])
count_summary = pd.DataFrame(count_summary, columns=['Malware Type', 'No. of Matching Verified Samples', 'No. of Matching Clusters', "Matching Clusters"])

count_summary.sort_values(by='No. of Matching Clusters',ascending=False, inplace=True)
display("Top 10 Most Common Malware Type (by Cluster Count)")
display(count_summary[['Malware Type','No. of Matching Clusters', 'Matching Clusters']].iloc[0:10])
count_summary[['Malware Type','No. of Matching Clusters', 'Matching Clusters']].iloc[0:10].to_csv("./Output/1 10_Most_Common_MalwareType_byClusterCount_woNoise.csv", index=False)
# Out:
# # of Unique Malware Type: 9
#
# UNIQUE MALWARE TYPE: 1
# Malware Type: trojan
# Matching Clusters Count: 1361
# Matching Clusters: [2, 11, 16, 17, 20, 25, 26, 35, 42, 43, 44, 47, 52, 57, 59, 61, 67, 69, 71, 78, 81, 85, 88, 90, 94, 96, 100, 104, 107, 110, 124, 131, 132, 134, 139, 146, 148, 151, 156, 161, 167, 169, 172, 182, 183, 190, 199, 202, 203, 214, 216, 222, 223, 239, 248, 253, 258, 261, 266, 270, 272, 274, 277, 280, 281, 283, 294, 301, 304, 306, 307, 309, 312, 314, 322, 326, 329, 333, 334, 337, 340, 343, 344, 345, 351, 355, 359, 366, 367, 368, 369, 370, 373, 374, 375, 376, 377, 386, 389, 390, 393, 397, 400, 406, 410, 416, 422, 427, 428, 431, 435, 438, 439, 442, 443, 446, 448, 451, 452, 455, 456, 457, 458, 460, 461, 463, 472, 478, 484, 486, 488, 489, 490, 492, 493, 496, 497, 503, 504, 508, 509, 520, 522, 524, 529, 531, 535, 537, 544, 548, 551, 552, 554, 571, 576, 577, 580, 585, 588, 600, 602, 607, 612, 619, 622, 623, 624, 626, 631, 632, 635, 640, 643, 644, 647, 649, 651, 652, 654, 661, 665, 677, 678, 679, 681, 693, 697, 700, 704, 707, 719, 725, 726, 727, 729, 732, 745, 746, 750, 753, 759, 771, 772, 774, 781, 782, 787, 798, 807, 813, 824, 828, 833, 835, 836, 837, 842, 845, 848, 849, 853, 855, 857, 861, 866, 870, 878, 882, 883, 885, 890, 891, 892, 894, 901, 903, 906, 909, 913, 916, 917, 926, 929, 944, 947, 949, 952, 957, 958, 962, 964, 972, 973, 987, 988, 992, 994, 995, 1000, 1002, 1003, 1004, 1006, 1007, 1010, 1017, 1019, 1020, 1023, 1028, 1040, 1041, 1065, 1068, 1070, 1071, 1079, 1080, 1081, 1085, 1086, 1088, 1096, 1097, 1106, 1110, 1111, 1112, 1120, 1121, 1124, 1133, 1136, 1142, 1143, 1150, 1152, 1157, 1160, 1170, 1182, 1183, 1184, 1185, 1190, 1193, 1194, 1207, 1209, 1216, 1224, 1229, 1233, 1234, 1241, 1261, 1266, 1267, 1268, 1270, 1277, 1279, 1290, 1292, 1294, 1297, 1300, 1301, 1305, 1308, 1320, 1323, 1329, 1332, 1340, 1358, 1359, 1373, 1377, 1383, 1385, 1400, 1402, 1405, 1406, 1411, 1420, 1423, 1426, 1427, 1433, 1448, 1455, 1458, 1459, 1462, 1474, 1475, 1493, 1495, 1505, 1512, 1513, 1516, 1538, 1539, 1541, 1550, 1562, 1573, 1574, 1585, 1586, 1591, 1595, 1596, 1599, 1606, 1608, 1612, 1613, 1627, 1632, 1635, 1639, 1642, 1643, 1648, 1652, 1661, 1662, 1673, 1674, 1676, 1681, 1699, 1719, 1722, 1723, 1736, 1738, 1746, 1750, 1754, 1755, 1773, 1776, 1778, 1786, 1790, 1797, 1800, 1807, 1811, 1814, 1817, 1825, 1829, 1830, 1841, 1842, 1851, 1854, 1862, 1868, 1877, 1891, 1895, 1896, 1909, 1911, 1915, 1925, 1929, 1931, 1933, 1940, 1943, 1947, 1950, 1954, 1955, 1956, 1957, 1958, 1963, 1967, 1968, 1976, 1981, 1988, 1996, 1997, 1998, 1999, 2014, 2020, 2023, 2024, 2025, 2027, 2028, 2029, 2053, 2059, 2064, 2066, 2071, 2080, 2083, 2087, 2092, 2093, 2096, 2104, 2106, 2107, 2111, 2118, 2121, 2125, 2130, 2160, 2166, 2169, 2174, 2191, 2192, 2200, 2205, 2207, 2218, 2220, 2222, 2230, 2236, 2240, 2242, 2245, 2246, 2247, 2250, 2255, 2259, 2267, 2270, 2279, 2281, 2286, 2287, 2291, 2297, 2300, 2302, 2306, 2307, 2309, 2314, 2317, 2323, 2332, 2336, 2338, 2341, 2347, 2348, 2361, 2362, 2365, 2369, 2371, 2372, 2382, 2388, 2389, 2392, 2395, 2396, 2407, 2413, 2423, 2425, 2429, 2430, 2433, 2438, 2445, 2446, 2467, 2468, 2469, 2470, 2478, 2480, 2488, 2493, 2500, 2504, 2529, 2538, 2540, 2552, 2556, 2559, 2564, 2578, 2579, 2581, 2583, 2599, 2600, 2604, 2614, 2618, 2620, 2621, 2630, 2644, 2645, 2661, 2664, 2666, 2677, 2688, 2690, 2698, 2699, 2702, 2706, 2707, 2709, 2713, 2716, 2717, 2718, 2719, 2721, 2725, 2728, 2731, 2742, 2745, 2771, 2778, 2779, 2795, 2801, 2803, 2808, 2809, 2812, 2813, 2814, 2830, 2832, 2842, 2844, 2848, 2855, 2857, 2860, 2866, 2891, 2895, 2896, 2897, 2898, 2909, 2925, 2926, 2928, 2933, 2956, 2958, 2968, 2971, 2972, 2980, 2983, 2987, 2992, 2994, 2996, 2997, 2998, 3003, 3012, 3028, 3029, 3032, 3038, 3040, 3046, 3054, 3059, 3066, 3070, 3080, 3084, 3087, 3090, 3092, 3102, 3105, 3111, 3116, 3123, 3125, 3128, 3132, 3134, 3141, 3142, 3144, 3146, 3163, 3165, 3166, 3170, 3188, 3193, 3196, 3199, 3207, 3224, 3231, 3234, 3241, 3248, 3255, 3278, 3303, 3312, 3327, 3329, 3331, 3334, 3337, 3350, 3352, 3353, 3354, 3364, 3366, 3369, 3371, 3379, 3385, 3386, 3387, 3399, ...
#
# UNIQUE MALWARE TYPE: 2
# Malware Type: _
# Matching Clusters Count: 130
# Matching Clusters: [14, 65, 121, 145, 361, 392, 402, 462, 500, 646, 660, 696, 751, 810, 818, 873, 895, 946, 1058, 1199, 1287, 1337, 1368, 1386, 1401, 1554, 1564, 1604, 1689, 1718, 1724, 1725, 1763, 1781, 1977, 2015, 2082, 2133, 2147, 2206, 2239, 2260, 2271, 2292, 2312, 2612, 2838, 2865, 2868, 2917, 2923, 3064, 3115, 3222, 3280, 3299, 3323, 3378, 3392, 3498, 3541, 3542, 3549, 3565, 3593, 3607, 3636, 3809, 4052, 4067, 4116, 4137, 4162, 4177, 4185, 4205, 4304, 4319, 4332, 4333, 4500, 4504, 4506, 4668, 4703, 4736, 4752, 4785, 4906, 4953, 4979, 5008, 5105, 5108, 5140, 5160, 5229, 5233, 5263, 5313, 5332, 5359, 5424, 5518, 5565, 5667, 6249, 6529, 7124, 7181, 7284, 7366, 7509, 7627, 7782, 7805, 7948, 8133, 8175, 8464, 8481, 8638, 8688, 9057, 9076, 9323, 9591, 9686, 10544, 11442]
#
# UNIQUE MALWARE TYPE: 3
# Malware Type: downloader
# Matching Clusters Count: 3
# Matching Clusters: [73, 803, 6110]
#
# UNIQUE MALWARE TYPE: 4
# Malware Type: miner
# Matching Clusters Count: 7
# Matching Clusters: [87, 1714, 2285, 3076, 3846, 3952, 5848]
#
# UNIQUE MALWARE TYPE: 5
# Malware Type: adware
# Matching Clusters Count: 58
# Matching Clusters: [93, 293, 609, 645, 899, 905, 1015, 1066, 1098, 1099, 1321, 1412, 1529, 1757, 1850, 1888, 1912, 2048, 2089, 2571, 2585, 2646, 2700, 3265, 3275, 3398, 3524, 3595, 3616, 3782, 3864, 3879, 4102, 4281, 4407, 4547, 5068, 5217, 5220, 5672, 5865, 5900, 6080, 6430, 6531, 6533, 6900, 7053, 7105, 7141, 7600, 7748, 7825, 8207, 8366, 8429, 10029, 10401]
#
# UNIQUE MALWARE TYPE: 6
# Malware Type: virus
# Matching Clusters Count: 3
# Matching Clusters: [95, 4353, 5827]
#
# UNIQUE MALWARE TYPE: 7
# Malware Type: pua
# Matching Clusters Count: 30
# Matching Clusters: [278, 501, 506, 615, 1316, 1390, 1425, 2114, 3197, 3342, 3647, 3703, 4376, 4735, 4943, 5230, 5992, 6144, 6177, 6420, 6451, 7054, 7523, 7557, 8240, 8313, 9787, 9793, 9996, 10607]
#
# UNIQUE MALWARE TYPE: 8
# Malware Type: ransomware
# Matching Clusters Count: 5
# Matching Clusters: [384, 741, 1753, 4115, 7200]
#
# UNIQUE MALWARE TYPE: 9
# Malware Type: spyware
# Matching Clusters Count: 1
# Matching Clusters: [6440]
# 'Top 10 Most Common Malware Type (by Cluster Count)'
#   Malware Type  No. of Matching Clusters  \
# 8       trojan                      1361
# 7            _                       130
# 6       adware                        58
# 5          pua                        30
# 4        miner                         7
# 3   ransomware                         5
# 1   downloader                         3
# 2        virus                         3
# 0      spyware                         1
#
#                                    Matching Clusters
# 8  [2, 11, 16, 17, 20, 25, 26, 35, 42, 43, 44, 47...
# 7  [14, 65, 121, 145, 361, 392, 402, 462, 500, 64...
# 6  [93, 293, 609, 645, 899, 905, 1015, 1066, 1098...
# 5  [278, 501, 506, 615, 1316, 1390, 1425, 2114, 3...
# 4           [87, 1714, 2285, 3076, 3846, 3952, 5848]
# 3                       [384, 741, 1753, 4115, 7200]
# 1                                    [73, 803, 6110]
# 2                                   [95, 4353, 5827]
# 0                                             [6440]

# %% [markdown]
# ## "What the API Calls are in each Malware Type"

# %%
malware_types = count_summary['Malware Type'].to_list()
malware_apis = []

pd.set_option("display.max_rows", None)

print("Top 10 API CALLS PER MALWARE TYPE")
for m in malware_types:
    hashes = malicious_df[malicious_df['type'] == m]['hash'].to_list()
    complete = []
    for h in hashes:
        complete += oliveira[oliveira['hash']==h].iloc[0,1:101].to_list()
    ser = pd.Series(complete, name=m)
    ser.value_counts().to_csv(f"./Output/1_APICALL_{m}_woNoise.csv")
    malware_apis.append(ser.unique().tolist())
    display(ser.value_counts())
# Out:
# Top 10 API CALLS PER MALWARE TYPE
# trojan
# LdrGetProcedureAddress               96467
# LdrLoadDll                           56743
# LdrGetDllHandle                      40368
# RegOpenKeyExW                        31588
# NtAllocateVirtualMemory              31312
# NtClose                              30650
# LoadResource                         29623
# FindResourceExW                      27677
# RegQueryValueExW                     23749
# RegCloseKey                          18752
# NtQueryValueKey                      16133
# NtOpenKey                            13587
# GetSystemMetrics                     13238
# GetSystemTimeAsFileTime              11100
# SetErrorMode                          9198
# NtProtectVirtualMemory                8270
# NtFreeVirtualMemory                   7842
# NtDelayExecution                      6494
# RegOpenKeyExA                         6148
# GetSystemInfo                         5581
# GetFileAttributesW                    5264
# NtOpenKeyEx                           5180
# LoadStringA                           4653
# SetUnhandledExceptionFilter           4373
# GetCursorPos                          4216
# CoInitializeEx                        4169
# SetFilePointer                        4014
# DrawTextExW                           3912
# NtReadFile                            3571
# NtCreateFile                          3496
# GetFileSize                           3042
# RegEnumKeyW                           3022
# NtMapViewOfSection                    2972
# GetSystemDirectoryW                   2959
# NtQuerySystemInformation              2957
# CoCreateInstance                      2854
# RegQueryInfoKeyW                      2788
# RegEnumKeyExW                         2782
# FindFirstFileExW                      2638
# EnumWindows                           2503
# CryptAcquireContextW                  2304
# RegQueryValueExA                      2251
# GetSystemWindowsDirectoryW            2133
# SizeofResource                        2036
# NtDeviceIoControlFile                 2001
# CreateThread                          1998
# NtQueryDirectoryFile                  1837
# RegSetValueExW                        1817
# NtDuplicateObject                     1804
# RegCreateKeyExW                       1801
# GetFileType                           1766
# FindResourceA                         1765
# CreateActCtxW                         1725
# NtCreateSection                       1623
# NtQueryInformationFile                1576
# __exception__                         1566
# FindResourceW                         1542
# CryptHashData                         1530
# CryptCreateHash                       1530
# UuidCreate                            1470
# FindResourceExA                       1388
# OleInitialize                         1382
# NtOpenDirectoryObject                 1300
# LdrUnloadDll                          1275
# NtQueryAttributesFile                 1201
# WSAStartup                            1161
# SearchPathW                           1134
# GetTempPathW                          1050
# NtCreateMutant                        1049
# SetWindowsHookExA                      912
# NtOpenFile                             833
# GetNativeSystemInfo                    727
# GlobalMemoryStatus                     716
# NtSetInformationFile                   702
# IsDebuggerPresent                      652
# LoadStringW                            625
# NtCreateThreadEx                       599
# NtEnumerateValueKey                    578
# NtOpenSection                          577
# NtOpenProcess                          553
# LookupPrivilegeValueW                  551
# NtResumeThread                         541
# GetForegroundWindow                    535
# NtEnumerateKey                         485
# GetFileInformationByHandle             482
# NtUnmapViewOfSection                   478
# NtQueryKey                             467
# NtWriteFile                            461
# GetUserNameW                           452
# CryptDecrypt                           444
# SetEndOfFile                           381
# RegEnumKeyExA                          373
# GetTimeZoneInformation                 372
# NtOpenMutant                           341
# SHGetFolderPathW                       267
# LookupAccountSidW                      264
# CreateDirectoryW                       255
# GetFileVersionInfoSizeW                236
# GetFileVersionInfoW                    184
# CryptEncrypt                           170
# SetFilePointerEx                       170
# CreateToolhelp32Snapshot               167
# CopyFileExW                            155
# Process32FirstW                        136
# GlobalMemoryStatusEx                   134
# WriteConsoleA                          125
# RegCreateKeyExA                        117
# FindWindowW                            116
# Process32NextW                         110
# SetFileAttributesW                     108
# GetDiskFreeSpaceExW                    102
# GetShortPathNameW                       98
# CreateJobObjectW                        98
# SetFileTime                             88
# GetFileSizeEx                           80
# OpenSCManagerW                          74
# select                                  72
# GetUserNameA                            71
# GetDiskFreeSpaceW                       69
# RegSetValueExA                          69
# ReadProcessMemory                       67
# NtOpenThread                            66
# GetSystemDirectoryA                     65
# GetComputerNameW                        62
# DeleteFileW                             53
# GetVolumeNameForVolumeMountPointW       52
# OpenServiceW                            50
# FindWindowA                             50
# socket                                  50
# connect                                 48
# CreateProcessInternalW                  43
# send                                    42
# recv                                    42
# DeviceIoControl                         41
# NtTerminateProcess                      38
# GetFileAttributesExW                    38
# WriteProcessMemory                      35
# timeGetTime                             34
# MoveFileWithProgressW                   33
# RegEnumValueW                           31
# RegEnumValueA                           31
# GetSystemWindowsDirectoryA              31
# OpenSCManagerA                          31
# SetWindowsHookExW                       30
# GetVolumePathNameW                      24
# GetVolumePathNamesForVolumeNameW        24
# StartServiceA                           19
# NtCreateKey                             18
# CopyFileW                               18
# GetComputerNameA                        16
# OpenServiceA                            16
# CoGetClassObject                        15
# DrawTextExA                             14
# CopyFileA                               13
# OutputDebugStringA                      13
# NtGetContextThread                      13
# RemoveDirectoryA                        12
# Module32NextW                           12
# Module32FirstW                          12
# SetStdHandle                            12
# InternetSetOptionA                      12
# NtSetContextThread                      11
# CreateServiceA                          11
# CoUninitialize                          10
# RegisterHotKey                          10
# CryptAcquireContextA                    10
# Thread32Next                             9
# Thread32First                            9
# CoCreateInstanceEx                       9
# InternetConnectA                         8
# HttpOpenRequestA                         8
# InternetOpenA                            8
# GetBestInterfaceEx                       7
# CoInitializeSecurity                     7
# GetAdaptersAddresses                     7
# InternetOpenW                            7
# StartServiceW                            6
# DnsQuery_A                               6
# NtSetValueKey                            6
# gethostbyname                            6
# GetAdaptersInfo                          6
# MessageBoxTimeoutA                       4
# NtSuspendThread                          4
# RtlAddVectoredExceptionHandler           4
# CryptProtectData                         4
# UnhookWindowsHookEx                      3
# InternetCrackUrlW                        2
# ioctlsocket                              2
# RtlDecompressBuffer                      2
# InternetCloseHandle                      2
# RemoveDirectoryW                         2
# ShellExecuteExW                          2
# GetKeyState                              2
# GetAsyncKeyState                         2
# InternetCrackUrlA                        2
# DeleteUrlCacheEntryA                     2
# CreateServiceW                           2
# Name: count, dtype: int64
# _
# LdrGetProcedureAddress               6340
# LdrGetDllHandle                      4281
# NtClose                              2774
# NtAllocateVirtualMemory              2524
# LdrLoadDll                           1996
# NtReadFile                           1497
# SetFilePointer                       1280
# RegOpenKeyExW                        1192
# NtOpenKey                            1027
# NtQueryValueKey                       960
# RegCloseKey                           948
# NtFreeVirtualMemory                   864
# GetSystemMetrics                      816
# RegQueryValueExW                      789
# LoadResource                          755
# NtCreateFile                          711
# FindResourceExW                       597
# NtMapViewOfSection                    504
# SetErrorMode                          454
# FindFirstFileExW                      369
# NtCreateSection                       321
# GetSystemWindowsDirectoryW            296
# NtWriteFile                           258
# GetSystemTimeAsFileTime               241
# RegOpenKeyExA                         238
# GetFileAttributesW                    218
# DrawTextExW                           189
# NtQueryAttributesFile                 189
# GetSystemDirectoryW                   184
# SetUnhandledExceptionFilter           170
# IsDebuggerPresent                     168
# RegCreateKeyExW                       161
# CreateDirectoryW                      155
# RegSetValueExW                        150
# SizeofResource                        134
# FindResourceA                         133
# NtProtectVirtualMemory                133
# GetFileSize                           125
# LoadStringA                           125
# GetTempPathW                          123
# GetSystemInfo                         122
# GetForegroundWindow                   119
# NtOpenMutant                          118
# RegQueryValueExA                      114
# NtOpenProcess                         110
# NtDuplicateObject                     109
# GetFileType                           106
# SetFilePointerEx                      106
# NtOpenFile                            103
# CoInitializeEx                         95
# CreateActCtxW                          92
# NtCreateMutant                         84
# FindResourceExA                        82
# LoadStringW                            76
# FindResourceW                          74
# OleInitialize                          73
# ReadProcessMemory                      68
# NtQueryInformationFile                 59
# NtUnmapViewOfSection                   59
# NtOpenDirectoryObject                  56
# NtQuerySystemInformation               55
# SHGetFolderPathW                       52
# __exception__                          48
# CreateProcessInternalW                 47
# GetNativeSystemInfo                    46
# LdrUnloadDll                           43
# RegEnumKeyW                            42
# NtOpenSection                          40
# CreateThread                           40
# DeleteFileW                            38
# GetFileVersionInfoSizeW                38
# GetFileVersionInfoW                    36
# NtResumeThread                         35
# SetEndOfFile                           32
# GlobalMemoryStatusEx                   30
# NtSetInformationFile                   30
# NtOpenKeyEx                            28
# GetShortPathNameW                      27
# GetVolumeNameForVolumeMountPointW      24
# NtDelayExecution                       22
# WriteProcessMemory                     20
# SearchPathW                            19
# NtQueryDirectoryFile                   19
# SetFileTime                            19
# NtSuspendThread                        19
# GetSystemDirectoryA                    18
# GetTimeZoneInformation                 18
# GetCursorPos                           17
# RegCreateKeyExA                        16
# NtEnumerateValueKey                    16
# SetWindowsHookExA                      16
# RegSetValueExA                         14
# NtEnumerateKey                         14
# NtCreateThreadEx                       12
# LookupAccountSidW                      12
# SetFileAttributesW                     12
# RemoveDirectoryA                       10
# GetDiskFreeSpaceExW                    10
# GetFileSizeEx                           8
# GetDiskFreeSpaceW                       8
# OutputDebugStringA                      8
# RegQueryInfoKeyW                        8
# SetWindowsHookExW                       8
# Process32FirstW                         7
# CreateToolhelp32Snapshot                7
# Process32NextW                          7
# DeviceIoControl                         6
# WSAStartup                              6
# GlobalMemoryStatus                      6
# CoCreateInstance                        6
# NtGetContextThread                      6
# UuidCreate                              6
# NtOpenThread                            4
# RemoveDirectoryW                        4
# timeGetTime                             4
# RegEnumKeyExA                           4
# RegEnumKeyExW                           4
# DrawTextExA                             4
# NtTerminateProcess                      4
# RegEnumValueW                           4
# CryptAcquireContextA                    3
# CoInitializeSecurity                    2
# GetAdaptersInfo                         2
# FindWindowA                             2
# InternetCrackUrlA                       2
# OpenSCManagerW                          2
# FindWindowW                             2
# MessageBoxTimeoutA                      2
# NtDeviceIoControlFile                   2
# MessageBoxTimeoutW                      2
# CoUninitialize                          2
# Name: count, dtype: int64
# adware
# LdrGetProcedureAddress               4205
# LdrGetDllHandle                      3578
# NtAllocateVirtualMemory              1427
# NtClose                              1147
# LdrLoadDll                            711
# RegCloseKey                           605
# GetSystemTimeAsFileTime               458
# RegOpenKeyExA                         392
# NtOpenKey                             390
# NtQueryValueKey                       355
# NtFreeVirtualMemory                   324
# SetUnhandledExceptionFilter           298
# SetErrorMode                          295
# GetFileAttributesW                    257
# RegOpenKeyExW                         256
# NtCreateFile                          234
# NtReadFile                            230
# NtDelayExecution                      224
# RegSetValueExA                        219
# SHGetFolderPathW                      194
# GetSystemMetrics                      190
# NtOpenFile                            189
# RegQueryValueExA                      179
# RegCreateKeyExA                       176
# LoadResource                          158
# GetSystemWindowsDirectoryW            157
# SetFilePointer                        150
# RegQueryValueExW                      143
# NtMapViewOfSection                    134
# NtCreateMutant                        129
# CoInitializeEx                        126
# CreateThread                          107
# NtProtectVirtualMemory                 99
# NtCreateSection                        99
# socket                                 97
# GetSystemDirectoryW                    96
# ioctlsocket                            95
# select                                 93
# connect                                91
# Process32NextW                         89
# FindResourceW                          88
# Process32FirstW                        87
# CreateToolhelp32Snapshot               87
# SizeofResource                         87
# RegCreateKeyExW                        83
# FindResourceExW                        75
# WSAStartup                             68
# RegSetValueExW                         64
# NtDuplicateObject                      62
# getaddrinfo                            60
# LoadStringW                            58
# GetTimeZoneInformation                 52
# closesocket                            49
# CoCreateInstance                       47
# GetNativeSystemInfo                    41
# NtQueryInformationFile                 39
# NtWriteFile                            34
# GetFileSize                            34
# GetTempPathW                           31
# IsDebuggerPresent                      31
# NtResumeThread                         29
# WriteProcessMemory                     26
# GetFileType                            26
# GetSystemInfo                          25
# FindResourceA                          24
# LdrUnloadDll                           21
# CoInitializeSecurity                   18
# CreateActCtxW                          17
# LoadStringA                            16
# NtDeviceIoControlFile                  14
# DrawTextExW                            14
# FindFirstFileExW                       13
# GetCursorPos                           13
# UuidCreate                             13
# CreateDirectoryW                       12
# NtOpenMutant                           12
# GetFileVersionInfoSizeW                11
# NtCreateThreadEx                       11
# GetFileVersionInfoW                    11
# NtQueryAttributesFile                  10
# NtOpenKeyEx                            10
# CoCreateInstanceEx                      9
# OpenServiceW                            9
# FindWindowW                             9
# DeviceIoControl                         9
# IWbemServices_ExecQuery                 9
# GetAdaptersInfo                         9
# CoGetClassObject                        9
# GetComputerNameW                        9
# OutputDebugStringA                      9
# OpenSCManagerW                          9
# NtOpenProcess                           8
# MoveFileWithProgressW                   8
# SetWindowsHookExW                       8
# OleInitialize                           8
# RegEnumKeyW                             8
# NtQuerySystemInformation                7
# NtOpenDirectoryObject                   6
# DeleteFileW                             6
# CoUninitialize                          5
# NtOpenSection                           4
# NtOpenThread                            4
# GetVolumeNameForVolumeMountPointW       4
# NtTerminateProcess                      3
# NtUnmapViewOfSection                    3
# CopyFileW                               3
# NtQueryDirectoryFile                    2
# GetUserNameA                            2
# ShellExecuteExW                         2
# Name: count, dtype: int64
# pua
# LdrGetProcedureAddress               1403
# LdrGetDllHandle                       994
# NtClose                               652
# LdrLoadDll                            419
# NtAllocateVirtualMemory               403
# NtDeviceIoControlFile                 264
# NtOpenKey                             247
# NtQueryValueKey                       220
# NtProtectVirtualMemory                177
# GetSystemMetrics                      145
# NtFreeVirtualMemory                   132
# NtReadFile                            118
# SetFilePointer                        112
# RegOpenKeyExW                          99
# RegCloseKey                            93
# NtCreateFile                           69
# GetSystemTimeAsFileTime                69
# SetErrorMode                           63
# LoadResource                           61
# NtMapViewOfSection                     56
# GetFileAttributesW                     52
# SetUnhandledExceptionFilter            52
# RegQueryValueExW                       50
# FindResourceExW                        47
# GetSystemWindowsDirectoryW             42
# GetSystemInfo                          42
# FindResourceW                          37
# NtCreateSection                        35
# FindFirstFileExW                       34
# GetFileSize                            30
# NtDelayExecution                       29
# GetSystemDirectoryW                    26
# LoadStringA                            26
# RegOpenKeyExA                          25
# NtCreateMutant                         23
# LoadStringW                            22
# IsDebuggerPresent                      21
# NtOpenKeyEx                            20
# OutputDebugStringA                     20
# GetFileType                            18
# GetNativeSystemInfo                    18
# SizeofResource                         17
# CoInitializeEx                         16
# NtOpenProcess                          16
# CreateDirectoryW                       15
# RegQueryValueExA                       15
# NtDuplicateObject                      15
# NtQueryAttributesFile                  14
# NtQuerySystemInformation               13
# MoveFileWithProgressW                  13
# NtOpenMutant                           12
# NtOpenFile                             11
# NtOpenDirectoryObject                  10
# SHGetFolderPathW                        9
# LdrUnloadDll                            9
# GlobalMemoryStatusEx                    9
# NtQueryInformationFile                  8
# NtEnumerateKey                          8
# UuidCreate                              8
# NtEnumerateValueKey                     8
# CreateThread                            7
# SetFileTime                             6
# NtWriteFile                             6
# FindResourceA                           6
# WSAStartup                              6
# GetTimeZoneInformation                  4
# RegCreateKeyExA                         4
# GetForegroundWindow                     4
# GetTempPathW                            4
# SetEndOfFile                            4
# CreateProcessInternalW                  4
# socket                                  4
# CreateActCtxW                           4
# GetCursorPos                            4
# GetVolumeNameForVolumeMountPointW       4
# GetDiskFreeSpaceExW                     3
# CoCreateInstance                        3
# NtSetInformationFile                    3
# RemoveDirectoryW                        3
# GetFileVersionInfoSizeW                 2
# RegSetValueExW                          2
# WriteProcessMemory                      2
# OleInitialize                           2
# NtOpenSection                           2
# DrawTextExW                             2
# RegCreateKeyExW                         2
# GetFileVersionInfoW                     2
# DeleteFileW                             2
# SetWindowsHookExW                       2
# SetFileAttributesW                      2
# NtResumeThread                          2
# RegSetValueExA                          2
# Name: count, dtype: int64
# miner
# LdrGetProcedureAddress            236
# NtClose                           157
# LdrGetDllHandle                   144
# NtQueryAttributesFile             142
# LdrLoadDll                        112
# RegOpenKeyExW                     108
# NtCreateFile                      102
# NtMapViewOfSection                 99
# NtCreateSection                    95
# NtUnmapViewOfSection               93
# RegCloseKey                        90
# RegQueryValueExW                   82
# NtAllocateVirtualMemory            73
# GetSystemWindowsDirectoryW         56
# LdrUnloadDll                       48
# GetSystemInfo                      42
# NtQueryValueKey                    42
# NtOpenKey                          42
# GetSystemTimeAsFileTime            38
# GetSystemDirectoryW                36
# RegOpenKeyExA                      28
# WSAStartup                         27
# NtProtectVirtualMemory             25
# NtDuplicateObject                  23
# LoadStringW                        20
# NtOpenDirectoryObject              20
# NtCreateMutant                     20
# SetUnhandledExceptionFilter        20
# GetNativeSystemInfo                18
# SetErrorMode                       18
# socket                             16
# GetFileAttributesW                 12
# LoadResource                        8
# FindResourceExW                     8
# NtFreeVirtualMemory                 6
# GetSystemMetrics                    6
# GetFileType                         5
# RtlAddVectoredExceptionHandler      4
# NtDelayExecution                    4
# NtResumeThread                      4
# NtCreateThreadEx                    4
# GlobalMemoryStatusEx                4
# RegQueryValueExA                    4
# NtQuerySystemInformation            4
# NtOpenProcess                       4
# WriteProcessMemory                  4
# Thread32Next                        4
# Thread32First                       4
# CreateToolhelp32Snapshot            4
# CopyFileA                           4
# GetFileSize                         4
# CoCreateInstance                    4
# NtOpenSection                       4
# closesocket                         3
# LoadStringA                         2
# FindFirstFileExW                    2
# NtQueryKey                          2
# SetWindowsHookExA                   2
# CreateThread                        2
# SearchPathW                         2
# OleInitialize                       2
# CreateDirectoryW                    2
# Name: count, dtype: int64
# ransomware
# NtClose                       210
# NtAllocateVirtualMemory       172
# NtOpenKey                     138
# NtQuerySystemInformation      126
# RegQueryValueExW              112
# RegOpenKeyExW                 112
# NtFreeVirtualMemory           107
# RegCloseKey                   107
# NtQueryValueKey                75
# LdrGetProcedureAddress         33
# LdrLoadDll                     21
# NtCreateFile                   21
# NtEnumerateValueKey            18
# NtEnumerateKey                 18
# NtOpenFile                     17
# NtMapViewOfSection             15
# NtCreateSection                15
# CreateToolhelp32Snapshot       15
# GetSystemWindowsDirectoryW     15
# NtQueryInformationFile         15
# NtCreateMutant                 15
# Process32NextW                 13
# Process32FirstW                13
# LdrGetDllHandle                12
# NtOpenProcess                   9
# GetComputerNameW                9
# GetUserNameW                    9
# SHGetFolderPathW                9
# CreateThread                    8
# NtDelayExecution                6
# GetTempPathW                    6
# CryptAcquireContextW            6
# GetFileSize                     6
# NtDuplicateObject               6
# NtTerminateThread               6
# NtOpenMutant                    5
# Name: count, dtype: int64
# downloader
# LdrGetProcedureAddress         264
# LdrLoadDll                     140
# LdrGetDllHandle                128
# NtClose                         54
# NtReadFile                      40
# NtAllocateVirtualMemory         40
# NtWriteFile                     30
# LdrUnloadDll                    28
# NtCreateFile                    26
# GetSystemTimeAsFileTime         22
# SetFilePointer                  20
# LoadResource                    18
# RegCloseKey                     16
# FindFirstFileExW                16
# FindResourceExW                 16
# RegOpenKeyExW                   12
# SetUnhandledExceptionFilter     10
# SizeofResource                  10
# RegQueryValueExW                 8
# SetErrorMode                     8
# GetFileType                      8
# NtQueryAttributesFile            8
# NtFreeVirtualMemory              8
# RegOpenKeyExA                    8
# RegQueryValueExA                 8
# GetFileAttributesW               8
# CoInitializeEx                   6
# IsDebuggerPresent                4
# GetSystemMetrics                 4
# NtOpenKey                        4
# NtQueryValueKey                  4
# CreateDirectoryW                 4
# NtProtectVirtualMemory           4
# GetNativeSystemInfo              4
# NtOpenProcess                    4
# SHGetFolderPathW                 2
# DeleteFileW                      2
# FindResourceW                    2
# SetFilePointerEx                 2
# Name: count, dtype: int64
# virus
# NtReadFile                           196
# NtWriteFile                          190
# LdrGetProcedureAddress               105
# LdrLoadDll                            85
# NtClose                               62
# NtAllocateVirtualMemory               37
# NtCreateFile                          35
# RegCloseKey                           33
# FindResourceExW                       28
# LdrGetDllHandle                       25
# NtOpenKey                             22
# NtQueryValueKey                       22
# LoadResource                          21
# RegOpenKeyExA                         20
# RegOpenKeyExW                         18
# LoadStringA                           18
# SetFilePointer                        17
# GetSystemWindowsDirectoryW            16
# GetTempPathW                          15
# RegQueryValueExW                      14
# GetSystemMetrics                      14
# NtFreeVirtualMemory                   13
# NtQueryAttributesFile                  9
# GetFileAttributesW                     9
# NtDuplicateObject                      8
# GetTimeZoneInformation                 7
# GetSystemInfo                          7
# RegQueryValueExA                       7
# GetFileType                            7
# GetVolumeNameForVolumeMountPointW      6
# NtCreateSection                        4
# GetFileSize                            4
# LoadStringW                            4
# GetSystemDirectoryW                    4
# FindFirstFileExW                       4
# NtMapViewOfSection                     4
# NtOpenFile                             2
# NtQueryDirectoryFile                   2
# CreateDirectoryW                       2
# NtCreateMutant                         2
# GetNativeSystemInfo                    2
# Name: count, dtype: int64
# spyware
# FindResourceExW               57
# LoadResource                  48
# LdrGetProcedureAddress        39
# LdrGetDllHandle               33
# GetSystemMetrics              18
# NtAllocateVirtualMemory       15
# NtClose                       12
# LdrLoadDll                     9
# LoadStringA                    9
# NtOpenKey                      6
# DrawTextExW                    6
# RegOpenKeyExA                  6
# NtQueryValueKey                6
# RegCloseKey                    3
# GetSystemWindowsDirectoryW     3
# NtCreateFile                   3
# NtCreateSection                3
# NtMapViewOfSection             3
# RegQueryValueExA               3
# NtQueryAttributesFile          3
# NtFreeVirtualMemory            3
# GetSystemInfo                  3
# GetSystemDirectoryW            3
# CreateThread                   3
# WSAStartup                     3
# Name: count, dtype: int64

# %% [markdown]
# ## "What the Unique API Calls are in each Malware Type"

# %%
for i,m in enumerate(malware_types):
    print(i, m)
    m_list = malware_apis[i]
    for j in range(len(malware_apis)):
        if j != i:
            for k in m_list[:]:
                if k in malware_apis[j]:
                    m_list.remove(k)
    print(m_list)
    print("\n")
# Out:
# 0 trojan
# ['LookupPrivilegeValueW', 'CryptCreateHash', 'CryptHashData', 'EnumWindows', 'OpenSCManagerA', 'OpenServiceA', 'StartServiceA', 'CryptProtectData', 'CryptEncrypt', 'CryptDecrypt', 'WriteConsoleA', 'GetAdaptersAddresses', 'GetBestInterfaceEx', 'GetVolumePathNamesForVolumeNameW', 'GetVolumePathNameW', 'StartServiceW', 'GetSystemWindowsDirectoryA', 'RegEnumValueA', 'GetComputerNameA', 'CreateServiceW', 'DeleteUrlCacheEntryA', 'CopyFileExW', 'GetFileAttributesExW', 'CreateServiceA', 'SetStdHandle', 'CreateJobObjectW', 'gethostbyname', 'NtSetContextThread', 'InternetOpenA', 'InternetSetOptionA', 'InternetConnectA', 'HttpOpenRequestA', 'NtCreateKey', 'NtSetValueKey', 'RegisterHotKey', 'Module32FirstW', 'Module32NextW', 'GetFileInformationByHandle', 'DnsQuery_A', 'send', 'recv', 'GetAsyncKeyState', 'UnhookWindowsHookEx', 'InternetOpenW', 'GetKeyState', 'RtlDecompressBuffer', 'InternetCloseHandle', 'InternetCrackUrlW']
#
#
# 1 _
# ['GetFileSizeEx', 'FindResourceExA', 'GetSystemDirectoryA', 'CryptAcquireContextA', 'FindWindowA', 'DrawTextExA', 'MessageBoxTimeoutA', '__exception__', 'GetShortPathNameW', 'ReadProcessMemory', 'NtSuspendThread', 'MessageBoxTimeoutW', 'RemoveDirectoryA', 'GetDiskFreeSpaceW', 'RegQueryInfoKeyW', 'RegEnumValueW', 'InternetCrackUrlA', 'LookupAccountSidW', 'RegEnumKeyExW', 'NtGetContextThread', 'GlobalMemoryStatus', 'timeGetTime', 'RegEnumKeyExA']
#
#
# 2 adware
# ['getaddrinfo', 'ioctlsocket', 'connect', 'select', 'RegEnumKeyW', 'FindWindowW', 'GetUserNameA', 'CoUninitialize', 'NtTerminateProcess', 'DeviceIoControl', 'GetAdaptersInfo', 'OpenSCManagerW', 'OpenServiceW', 'CoInitializeSecurity', 'CoCreateInstanceEx', 'CoGetClassObject', 'IWbemServices_ExecQuery', 'NtOpenThread', 'ShellExecuteExW', 'CopyFileW']
#
#
# 3 pua
# ['NtDeviceIoControlFile', 'MoveFileWithProgressW', 'GetDiskFreeSpaceExW', 'NtSetInformationFile', 'FindResourceA', 'NtOpenKeyEx', 'CreateActCtxW', 'GetCursorPos', 'SetWindowsHookExW', 'UuidCreate', 'RemoveDirectoryW', 'GetFileVersionInfoSizeW', 'GetFileVersionInfoW', 'SetFileTime', 'SetEndOfFile', 'CreateProcessInternalW', 'SetFileAttributesW', 'OutputDebugStringA', 'RegCreateKeyExW', 'RegSetValueExW', 'GetForegroundWindow', 'RegCreateKeyExA', 'RegSetValueExA']
#
#
# 4 miner
# ['NtOpenDirectoryObject', 'socket', 'NtUnmapViewOfSection', 'closesocket', 'RtlAddVectoredExceptionHandler', 'OleInitialize', 'SearchPathW', 'SetWindowsHookExA', 'NtOpenSection', 'NtQueryKey', 'CoCreateInstance', 'Thread32First', 'Thread32Next', 'WriteProcessMemory', 'GlobalMemoryStatusEx', 'NtCreateThreadEx', 'NtResumeThread', 'CopyFileA']
#
#
# 5 ransomware
# ['CreateToolhelp32Snapshot', 'Process32FirstW', 'Process32NextW', 'NtEnumerateKey', 'NtEnumerateValueKey', 'NtQueryInformationFile', 'GetUserNameW', 'GetComputerNameW', 'NtOpenMutant', 'NtDelayExecution', 'NtQuerySystemInformation', 'CryptAcquireContextW', 'NtTerminateThread']
#
#
# 6 downloader
# ['GetSystemTimeAsFileTime', 'SetUnhandledExceptionFilter', 'NtOpenProcess', 'NtProtectVirtualMemory', 'LdrUnloadDll', 'CoInitializeEx', 'SizeofResource', 'IsDebuggerPresent', 'SetErrorMode', 'SHGetFolderPathW', 'DeleteFileW', 'FindResourceW', 'SetFilePointerEx']
#
#
# 7 virus
# ['GetTempPathW', 'GetFileAttributesW', 'SetFilePointer', 'NtReadFile', 'NtWriteFile', 'GetFileType', 'GetTimeZoneInformation', 'FindFirstFileExW', 'CreateDirectoryW', 'NtQueryDirectoryFile', 'GetFileSize', 'NtOpenFile', 'LoadStringW', 'RegOpenKeyExW', 'RegQueryValueExW', 'NtCreateMutant', 'GetNativeSystemInfo', 'NtDuplicateObject', 'GetVolumeNameForVolumeMountPointW']
#
#
# 8 spyware
# ['RegOpenKeyExA', 'NtOpenKey', 'NtQueryValueKey', 'NtClose', 'NtQueryAttributesFile', 'LoadStringA', 'NtAllocateVirtualMemory', 'LdrGetDllHandle', 'LdrGetProcedureAddress', 'GetSystemMetrics', 'RegQueryValueExA', 'RegCloseKey', 'LdrLoadDll', 'GetSystemWindowsDirectoryW', 'NtCreateFile', 'NtCreateSection', 'NtMapViewOfSection', 'FindResourceExW', 'LoadResource', 'DrawTextExW', 'NtFreeVirtualMemory', 'GetSystemInfo', 'GetSystemDirectoryW', 'CreateThread', 'WSAStartup']

# %% [markdown]
# ## How many samples remaining?

# %%
print(f"{malicious_df.shape[0]}\n{malicious_df.shape[0]/42797*100:.4f}%")
# Out:
# 6922
# 16.1740%

# %% [markdown]
# ## What are the remaining clusters?

# %%
how_many_clusters()
# Out:
# Number of Clusters: 1598
# Number of single-item Clusters: 0
# Number of Samples Remaining: 6922
