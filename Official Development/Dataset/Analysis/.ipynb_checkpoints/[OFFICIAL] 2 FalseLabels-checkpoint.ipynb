# %% [markdown]
# # Malicious False Labels
#
# Describes/summarizes the or set of clusters. Useful for when you aim to enlist those samples (and its API calls) that were falsely labelled as malcious as per the third-party verification tool, VirusTotal.
#
# Note that this notebook only makes use of the verified xxxx_SampleHash_Common.csv file which represents a significant majority of the entire Oliveira dataset.

# %% [markdown]
# ## Import Libraries/Datasets

# %%
import pandas as pd

malicious_df = pd.read_csv('./Manual_DBSCAN_Encoded_Clustering_w_FalseLabels.csv', low_memory=False) #This should point to a verified <DataClustering>_SampleHash_Common.csv file
benign_df = pd.read_csv('./API_Patterns_Benign.csv', low_memory=False) #This should point to the API_Patterns.csv file

#DROP ROWS WITH NA
import numpy as nan
malicious_df.dropna(inplace=True, subset=['type'])
display(malicious_df['type'].unique())

#Load list of API calls
API_LIST = "../api_calls.txt"
DELIMITER = "NaN"
API_FILE = open(API_LIST,"r")
APIS = API_FILE.readline().split(',')
APIS.append(DELIMITER) #serves as a label for NaN values for Instance-based datasets
API_FILE.close()

def get_unique_clusters(df:pd.DataFrame):
    return list(df['cluster'].unique())
# Out:
# array(['trojan', 'pua', 'downloader', 'adware', 'hacktool', '_', 'miner',
#        'virus', 'spyware', 'ransomware', 'dropper', 'worm'], dtype=object)

# %% [markdown]
# ## DataFrame Preview

# %%
#Replace '-' empty malware type delimiter with '_' for consistency
malicious_df.replace(to_replace='-',value='_', inplace=True)
# display(malicious_df['cluster'].value_counts())
display(malicious_df)
# Out:
#                                    hash                          t_0  \
# 0      071e8c3f8922e186e57548cd4c703a5d                RegOpenKeyExA
# 1      33f8e6d08a6aae939f25a8e0d63dd523      GetSystemTimeAsFileTime
# 2      b68abd064e975e1c6d5f25e748663076  SetUnhandledExceptionFilter
# 3      72049be7bd30ea61297ea624ae198067      GetSystemTimeAsFileTime
# 4      c9b3700a77facf29172f32df6bc77f48      GetSystemTimeAsFileTime
# ...                                 ...                          ...
# 42792  e3d6d58faa040f0f9742c9d0eaf58be4      GetSystemTimeAsFileTime
# 42793  9b917bab7f32188ae40c744f2be9aaf8      GetSystemTimeAsFileTime
# 42794  35a18ee05f75f04912018d9f462cb990      GetSystemTimeAsFileTime
# 42795  654139d715abcf7ecdddbef5a84f224b      GetSystemTimeAsFileTime
# 42796  078c9d4e7be4819a06974c6f292a4857                RegOpenKeyExA
#
#                            t_1                     t_2  \
# 0                    NtOpenKey         NtQueryValueKey
# 1      NtAllocateVirtualMemory     NtFreeVirtualMemory
# 2                OleInitialize              LdrLoadDll
# 3      NtAllocateVirtualMemory     NtFreeVirtualMemory
# 4                   LdrLoadDll  LdrGetProcedureAddress
# ...                        ...                     ...
# 42792               LdrLoadDll  LdrGetProcedureAddress
# 42793               LdrLoadDll  LdrGetProcedureAddress
# 42794               LdrLoadDll  LdrGetProcedureAddress
# 42795               LdrLoadDll  LdrGetProcedureAddress
# 42796                NtOpenKey         NtQueryValueKey
#
#                            t_3                     t_4  \
# 0                      NtClose               NtOpenKey
# 1      NtAllocateVirtualMemory         LdrGetDllHandle
# 2       LdrGetProcedureAddress              LdrLoadDll
# 3      NtAllocateVirtualMemory         LdrGetDllHandle
# 4                   LdrLoadDll  LdrGetProcedureAddress
# ...                        ...                     ...
# 42792               LdrLoadDll  LdrGetProcedureAddress
# 42793               LdrLoadDll  LdrGetProcedureAddress
# 42794               LdrLoadDll  LdrGetProcedureAddress
# 42795               LdrLoadDll  LdrGetProcedureAddress
# 42796                  NtClose               NtOpenKey
#
#                           t_5                     t_6                     t_7  \
# 0             NtQueryValueKey                 NtClose   NtQueryAttributesFile
# 1      LdrGetProcedureAddress         LdrGetDllHandle  LdrGetProcedureAddress
# 2      LdrGetProcedureAddress              LdrLoadDll  LdrGetProcedureAddress
# 3      LdrGetProcedureAddress         LdrGetDllHandle  LdrGetProcedureAddress
# 4                  LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# ...                       ...                     ...                     ...
# 42792              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 42793              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 42794              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 42795              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 42796         NtQueryValueKey                 NtClose   NtQueryAttributesFile
#
#                           t_8  ...                        t_94  \
# 0                 LoadStringA  ...          NtMapViewOfSection
# 1             LdrGetDllHandle  ...  GetSystemWindowsDirectoryW
# 2                  LdrLoadDll  ...                 RegCloseKey
# 3             LdrGetDllHandle  ...        NtWriteVirtualMemory
# 4      LdrGetProcedureAddress  ...               RegEnumKeyExW
# ...                       ...  ...                         ...
# 42792  LdrGetProcedureAddress  ...               RegOpenKeyExW
# 42793  LdrGetProcedureAddress  ...            NtDelayExecution
# 42794  LdrGetProcedureAddress  ...            RegQueryValueExW
# 42795  LdrGetProcedureAddress  ...               RegOpenKeyExW
# 42796             LoadStringA  ...          NtMapViewOfSection
#
#                       t_95                     t_96                     t_97  \
# 0                  NtClose         GetSystemMetrics  NtAllocateVirtualMemory
# 1             NtCreateFile          NtCreateSection       NtMapViewOfSection
# 2            RegOpenKeyExA         RegQueryValueExA              RegCloseKey
# 3      NtFreeVirtualMemory  NtAllocateVirtualMemory     NtWriteVirtualMemory
# 4            RegOpenKeyExW         RegQueryValueExW            RegOpenKeyExW
# ...                    ...                      ...                      ...
# 42792     RegQueryValueExW            RegOpenKeyExW         RegQueryValueExW
# 42793          EnumWindows  GetSystemTimeAsFileTime         NtDelayExecution
# 42794        RegOpenKeyExW         RegQueryValueExW            RegOpenKeyExW
# 42795     RegQueryValueExW            RegOpenKeyExW         RegQueryValueExW
# 42796              NtClose         GetSystemMetrics  NtAllocateVirtualMemory
#
#                          t_98                        t_99 malware    type  \
# 0               CreateActCtxW  GetSystemWindowsDirectoryW       1  trojan
# 1                     NtClose            GetSystemMetrics       1     pua
# 2               RegEnumKeyExA               RegOpenKeyExA       1  trojan
# 3      NtProtectVirtualMemory        NtWriteVirtualMemory       1  trojan
# 4            RegQueryValueExW               RegOpenKeyExW       1  trojan
# ...                       ...                         ...     ...     ...
# 42792           RegOpenKeyExW            RegQueryValueExW       1  trojan
# 42793             EnumWindows     GetSystemTimeAsFileTime       1  trojan
# 42794        RegQueryValueExW               RegOpenKeyExW       1  trojan
# 42795           RegOpenKeyExW            RegQueryValueExW       1  trojan
# 42796           CreateActCtxW  GetSystemWindowsDirectoryW       1  trojan
#
#                                                  pattern cluster
# 0      RegOpenKeyExA,NtOpenKey,NtQueryValueKey,NtClos...       0
# 1      GetSystemTimeAsFileTime,NtAllocateVirtualMemor...       1
# 2      SetUnhandledExceptionFilter,OleInitialize,LdrL...       2
# 3      GetSystemTimeAsFileTime,NtAllocateVirtualMemor...       3
# 4      GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...       4
# ...                                                  ...     ...
# 42792  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...      19
# 42793  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...   12595
# 42794  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...   12596
# 42795  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...      19
# 42796  RegOpenKeyExA,NtOpenKey,NtQueryValueKey,NtClos...       0
#
# [42797 rows x 105 columns]

# %% [markdown]
# ## How many are falsely labelled samples from the verified samples?

# %%
def count_false_samples():
    false_labelled = malicious_df[(malicious_df['type']=='_')].copy(deep=True)
    combined = []
    for c in false_labelled['cluster'].unique():
        combined.append([c,false_labelled[false_labelled['cluster'] == c]['hash'].shape[0], malicious_df[malicious_df['cluster'] == c]['hash'].shape[0], f"{false_labelled[false_labelled['cluster'] == c]['hash'].shape[0]/malicious_df[malicious_df['cluster'] == c]['hash'].shape[0]:.4f}"])
    false_labelled = pd.DataFrame(data=combined, columns=['cluster', 'false_labelled', 'total_samples', 'percentage'])
    false_labelled.sort_values('percentage', inplace=True, ascending=False)
    false_labelled['percentage'] = false_labelled['percentage'].astype('float')
    print(f"No. of falsely labelled samples verified samples: {false_labelled.sum().iloc[1]} ({false_labelled.sum().iloc[1]/malicious_df.shape[0]*100:.4f}%)\n")
    print(f"No. of clusters with purely falsely labelled verified samples: {false_labelled[false_labelled['percentage'] == 1]['cluster'].count()} ({false_labelled[false_labelled['percentage'] == 1]['cluster'].count()/600*100:.4f}%)\n")
    print("")
    display(false_labelled)
    false_labelled.to_csv("./Output/2 Falsely_Labelled.csv", index=False)
    return false_labelled

false_labelled = count_false_samples()
# Out:
# No. of falsely labelled samples verified samples: 2638.0 (6.1640%)
#
# No. of clusters with purely falsely labelled verified samples: 1105 (184.1667%)
#      cluster  false_labelled  total_samples  percentage
# 0         14               2              2      1.0000
# 846     8487               1              1      1.0000
# 854     8584               1              1      1.0000
# 853     8564               1              1      1.0000
# 852     8541               1              1      1.0000
# ..       ...             ...            ...         ...
# 991        9               2           1116      0.0018
# 996       21               1            576      0.0017
# 986       39               1            802      0.0012
# 974      105               1           1094      0.0009
# 982        0               3           3308      0.0009
#
# [1317 rows x 4 columns]

# %% [markdown]
# ## Does the presented API Call Patterns match those from the API Call Patterns of those Benign samples?

# %%
def matching_api_in_benign():
    unique_false_patterns = list(malicious_df[malicious_df['type'] == '_']['pattern'])
    ctr = 1
    same = []
    str_output = "Falsely Labelled Malicious Samples that Match API Call Patterns of Benign Samples" + "\n"
    for f in unique_false_patterns:
        if benign_df[benign_df['pattern']==f].shape[0]>0 and f not in same:
            str_output += f"\nPATTERN: {ctr}\n"
            str_output += "API Call Pattern: "
            str_output += f"{f}\n"
            # str_output += "API Calls: \n"
            # str_output += f"\t {list(pd.Series(list(f.split(","))).unique())}\n"
            # str_output += "Clusters & Hashes of Matching Falsely Labelled Samples: \n"
    #         for p in range(false_labelled[false_labelled['pattern']==f].shape[0]):
    #             str_output += f"\tCluster: {false_labelled['cluster'].iloc[p]:3d} - Hash: {false_labelled['hash'].iloc[p]} ({false_labelled['type'].iloc[p]}, {false_labelled['Type 2'].iloc[p]}, {false_labelled['Type 3'].iloc[p]})\n"
            str_output += "\nHashes of Benign Samples with Matching API Call Patterns:\n"
            for p in range(benign_df[benign_df['pattern']==f].shape[0]):
                str_output += f"\t{benign_df[benign_df['pattern']==f]['hash'].iloc[p]}\n"
            same.append(f)
            ctr+=1
    str_output += "\n"
    str_output += f"No. of API Call Patterns of Falsely-Labelled Malicious Samples that match the API Call Patterns of Benign Samples: {len(same)} ({len(same)/benign_df.shape[0]*100:.4f}%)\n\n"
    str_output += "===================================================================================================================\n\n"
    str_output += "In terms of unique API Calls:\n"
    for i, s in enumerate(same):
        str_output += f"PATTERN: {i+1}\n{list(pd.Series(s.split(',')).unique())}\n\n"

    with open("./Output/2 Falsely_Labelled_Matching_Benign.txt", 'w') as f:
        f.write(str_output)
        f.flush()
        f.close()
    print(str_output)

matching_api_in_benign()
# Out:
# Falsely Labelled Malicious Samples that Match API Call Patterns of Benign Samples
#
# PATTERN: 1
# API Call Pattern: GetSystemTimeAsFileTime,NtCreateMutant,GetSystemTimeAsFileTime,NtOpenKeyEx,NtQueryKey,NtOpenKeyEx,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumKeyExW,RegOpenKeyExW,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumValueW,LdrGetProcedureAddress,RegCloseKey,GetFileAttributesW,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryValueExW,RegCloseKey,NtOpenFile,NtQueryDirectoryFile,NtClose,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,RegOpenKeyExW,RegQueryInfoKeyW,RegEnumValueW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,NtOpenFile,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,NtOpenFile,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,GetSystemTimeAsFileTime,NtQuerySystemInformation,NtProtectVirtualMemory,GetSystemDirectoryW,LdrGetDllHandle,LdrLoadDll,GetSystemDirectoryW,LdrGetDllHandle,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,NtClose,NtQueryKey,NtOpenKeyEx,NtQueryValueKey,NtClose,GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProcedureAddress,GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProcedureAddress,NtCreateFile,GetFileSize,NtCreateSection,NtMapViewOfSection,GetSystemInfo,NtClose,NtUnmapViewOfSection,NtClose,NtCreateFile,GetFileSize,NtCreateSection,NtMapViewOfSection,GetSystemInfo,NtClose,NtUnmapViewOfSection,NtClose,RegOpenKeyExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,NtOpenFile
#
# Hashes of Benign Samples with Matching API Call Patterns:
# 	1d5be1a1f06fb4af76db691286667685
# 	e17c7fc99e55278c9377e0ba686b4002
#
# PATTERN: 2
# API Call Pattern: GetSystemTimeAsFileTime,GetSystemInfo,NtCreateMutant,GetSystemTimeAsFileTime,NtOpenKey,NtOpenKeyEx,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumKeyExW,RegOpenKeyExW,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumValueW,LdrGetProcedureAddress,RegCloseKey,GetFileAttributesW,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryValueExW,LdrGetProcedureAddress,RegQueryValueExW,RegCloseKey,FindFirstFileExW,RegOpenKeyExW,RegQueryInfoKeyW,RegEnumValueW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,FindFirstFileExW,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,FindFirstFileExW,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,LdrGetDllHandle,LdrGetProcedureAddress,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,NtQuerySystemInformation,NtProtectVirtualMemory,GetSystemDirectoryW,LdrGetDllHandle,LdrLoadDll,GetSystemDirectoryW,LdrGetDllHandle,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,NtClose,NtOpenKeyEx,NtQueryValueKey,NtClose,LdrLoadDll,LdrGetProcedureAddress,GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProcedureAddress,NtCreateFile,GetFileSize,NtCreateSection,NtMapViewOfSection,GetSystemInfo,NtClose,NtUnmapViewOfSection,NtClose,NtCreateFile,GetFileSize,NtCreateSection,NtMapViewOfSection,GetSystemInfo,NtClose,NtUnmapViewOfSection,NtClose,RegOpenKeyExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,FindFirstFileExW,RegOpenKeyExW,RegQueryInfoKeyW,RegEnumValueW,RegCloseKey
#
# Hashes of Benign Samples with Matching API Call Patterns:
# 	e66c6c58a773cde28710fc4018b3f59b
#
# PATTERN: 3
# API Call Pattern: SetErrorMode,LdrGetDllHandle,LdrGetProcedureAddress,GetSystemDirectoryW,NtAllocateVirtualMemory,NtFreeVirtualMemory,NtAllocateVirtualMemory,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,GetSystemDirectoryW,GetSystemWindowsDirectoryW,GetSystemDirectoryW,RegOpenKeyExA,GetSystemWindowsDirectoryW,LoadStringW,GetSystemWindowsDirectoryW,GetSystemDirectoryW,RegOpenKeyExW,LdrLoadDll,LdrGetProcedureAddress,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,RegCloseKey,NtCreateMutant,GetNativeSystemInfo,GetSystemWindowsDirectoryW,NtClose,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,GetSystemDirectoryW,NtAllocateVirtualMemory,LdrGetDllHandle,LdrGetProcedureAddress,NtQueryAttributesFile,NtCreateFile,NtCreateSection,NtMapViewOfSection,NtClose,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,LdrGetDllHandle,GetSystemDirectoryW,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,GetSystemDirectoryW,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,OleInitialize,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtOpenSection,NtMapViewOfSection,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,NtClose,LdrLoadDll,LdrGetProcedureAddress,GetSystemWindowsDirectoryW,NtCreateFile,NtCreateSection
#
# Hashes of Benign Samples with Matching API Call Patterns:
# 	3506356c329758e4f703cd2103d7daab
# 	6d8c0c930480a524ad1e0e18e345b7ce
# 	e550d4d96d8b9d771c6e227aff2b9029
# 	5bbb49bd36321b485368490d3af09f15
# 	ff8a61c9edbcbd84e23b069496e73db3
# 	53d78ecdf3675e83b152b09f73398ccc
# 	cdbfad3dc698d8e5afa87bdc540f2fbb
# 	c124a717590ec531d658a4abcc367fee
# 	f2e6e397c0a2a605c791c63466c9d5ae
# 	4dabfc6c5aeabd35fac449258e174856
# 	70b78f7bdf9c484913d10365348ed2ba
#
# PATTERN: 4
# API Call Pattern: SetErrorMode,LdrGetDllHandle,LdrGetProcedureAddress,GetSystemDirectoryW,NtAllocateVirtualMemory,NtFreeVirtualMemory,NtAllocateVirtualMemory,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,GetSystemDirectoryW,GetSystemWindowsDirectoryW,GetSystemDirectoryW,RegOpenKeyExA,GetSystemWindowsDirectoryW,LoadStringW,GetSystemWindowsDirectoryW,GetSystemDirectoryW,RegOpenKeyExW,LdrLoadDll,LdrGetProcedureAddress,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,RegCloseKey,NtCreateMutant,GetNativeSystemInfo,GetSystemWindowsDirectoryW,NtClose,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,GetSystemDirectoryW,NtAllocateVirtualMemory,LdrGetDllHandle,LdrGetProcedureAddress,NtQueryAttributesFile,NtCreateFile,NtCreateSection,NtMapViewOfSection,NtClose,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,LdrGetDllHandle,GetSystemDirectoryW,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,GetSystemDirectoryW,LdrLoadDll,LdrGetProcedureAddress,OleInitialize,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtOpenSection,NtMapViewOfSection,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,NtClose,LdrLoadDll,LdrGetProcedureAddress,GetSystemWindowsDirectoryW,NtCreateFile,NtCreateSection,NtMapViewOfSection,NtClose
#
# Hashes of Benign Samples with Matching API Call Patterns:
# 	cff4037fdce24af9d2c6f03b749c55f6
# 	554ce484aba0f97dcf7658257b643c28
# 	6bb6a989b0a6a12af08ea951565be8d4
# 	78ba3a6c3809dbdf9ad4b02d8b08da7f
# 	f97186c239da55339bef96b1fae0d247
# 	c301fda32da5efcf6021509ffd06f940
# 	96e1c48e4c3d42943930e8474b7c0882
#
# PATTERN: 5
# API Call Pattern: GetSystemTimeAsFileTime,NtOpenKey,NtQueryValueKey,NtClose,NtCreateMutant,GetSystemTimeAsFileTime,NtOpenKeyEx,NtQueryKey,NtOpenKeyEx,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumKeyExW,RegOpenKeyExW,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumValueW,LdrGetProcedureAddress,RegCloseKey,GetFileAttributesW,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryValueExW,RegCloseKey,NtOpenFile,NtQueryDirectoryFile,NtClose,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,RegOpenKeyExW,RegQueryInfoKeyW,RegEnumValueW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,NtOpenFile,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,NtOpenFile,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,GetSystemTimeAsFileTime,NtQuerySystemInformation,NtProtectVirtualMemory,GetSystemDirectoryW,LdrGetDllHandle,LdrLoadDll,GetSystemDirectoryW,LdrGetDllHandle,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,NtClose,NtQueryKey,NtOpenKeyEx,NtQueryValueKey,NtClose,GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProcedureAddress,GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProcedureAddress,NtCreateFile,GetFileSize,NtCreateSection,NtMapViewOfSection,GetSystemInfo,NtClose,NtUnmapViewOfSection,NtClose,NtCreateFile,GetFileSize,NtCreateSection,NtMapViewOfSection,GetSystemInfo,NtClose,NtUnmapViewOfSection,NtClose,RegOpenKeyExW,RegCloseKey,RegOpenKeyExW
#
# Hashes of Benign Samples with Matching API Call Patterns:
# 	eae3616631dc3eafbbf4a174113c02a9
# 	acdbbae7823117ec9e9899dd01c66d5f
#
# PATTERN: 6
# API Call Pattern: GetSystemInfo,NtAllocateVirtualMemory,NtOpenSection,GetTempPathW,CreateDirectoryW,GetFileAttributesW,FindFirstFileExW,DeleteFileW,NtQueryDirectoryFile,DeleteFileW,NtQueryDirectoryFile,NtClose,RemoveDirectoryW,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,FindResourceA,LdrGetDllHandle,LdrGetProcedureAddress,NtClose,RegOpenKeyExW,RegQueryValueExW,GetSystemTimeAsFileTime,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,LdrLoadDll,LdrGetProcedureAddress,RegCloseKey,NtCreateMutant,LdrGetDllHandle,LdrGetProcedureAddress,NtClose,NtOpenSection,NtCreateSection,NtMapViewOfSection,NtAllocateVirtualMemory,NtClose,RegOpenKeyExW,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtQueryAttributesFile,FindResourceA,LoadResource,NtCreateFile,NtCreateSection,NtMapViewOfSection,GetFileSize,NtUnmapViewOfSection,NtClose,FindResourceW,LoadResource,SizeofResource,NtProtectVirtualMemory,LdrGetDllHandle,LdrGetProcedureAddress,NtClose,NtCreateSection,NtMapViewOfSection,NtCreateMutant,LdrGetDllHandle,LdrGetProcedureAddress,NtQuerySystemInformation,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetNativeSystemInfo,GetSystemMetrics,NtOpenThread,LdrGetProcedureAddress,LdrGetDllHandle,NtProtectVirtualMemory,NtOpenFile,CreateThread,NtOpenThread,NtCreateMutant,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress
#
# Hashes of Benign Samples with Matching API Call Patterns:
# 	576d81529c1689e49a44fee403d6f7ab
#
# PATTERN: 7
# API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,GetSystemTimeAsFileTime,NtAllocateVirtualMemory,NtFreeVirtualMemory,NtAllocateVirtualMemory,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,NtAllocateVirtualMemory,LdrGetDllHandle,LdrGetProcedureAddress,SetUnhandledExceptionFilter,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,GetNativeSystemInfo,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress
#
# Hashes of Benign Samples with Matching API Call Patterns:
# 	73ade5ef9ca1a5778751b35f0e4c5555
#
# PATTERN: 8
# API Call Pattern: GetSystemTimeAsFileTime,NtAllocateVirtualMemory,NtFreeVirtualMemory,NtAllocateVirtualMemory,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,NtAllocateVirtualMemory,LdrGetDllHandle,LdrGetProcedureAddress,SetUnhandledExceptionFilter,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,GetNativeSystemInfo,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,GetNativeSystemInfo,LdrUnloadDll,NtAllocateVirtualMemory,RegOpenKeyExW,NtAllocateVirtualMemory,NtFreeVirtualMemory,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,NtClose,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,GetNativeSystemInfo,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,IsDebuggerPresent,GetSystemMetrics,NtMapViewOfSection,LdrGetDllHandle,LdrGetProcedureAddress,NtAllocateVirtualMemory,GetSystemMetrics
#
# Hashes of Benign Samples with Matching API Call Patterns:
# 	88645494d347542fc0478654f753e328
#
# PATTERN: 9
# API Call Pattern: GetSystemTimeAsFileTime,NtAllocateVirtualMemory,NtFreeVirtualMemory,NtAllocateVirtualMemory,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,NtAllocateVirtualMemory,LdrGetDllHandle,LdrGetProcedureAddress,SetUnhandledExceptionFilter,RegOpenKeyExA,RegQueryValueExA,RegCloseKey,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,GetNativeSystemInfo,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,GetNativeSystemInfo,LdrUnloadDll,NtAllocateVirtualMemory,RegOpenKeyExA,NtAllocateVirtualMemory,NtFreeVirtualMemory,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,NtClose,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,GetNativeSystemInfo,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,IsDebuggerPresent,GetSystemMetrics,NtMapViewOfSection,LdrGetDllHandle,LdrGetProcedureAddress,NtAllocateVirtualMemory,GetSystemMetrics
#
# Hashes of Benign Samples with Matching API Call Patterns:
# 	52cac8b6d54e26edc242f3d2b9d62bd2
#
# PATTERN: 10
# API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,SetUnhandledExceptionFilter,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtOpenFile,DeviceIoControl,CoInitializeEx,LdrGetDllHandle,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,SetErrorMode,GetFileAttributesW,SetErrorMode,GetFileAttributesW,SetErrorMode,SHGetFolderPathW,LdrGetDllHandle,LdrGetProcedureAddress,SetErrorMode,CoInitializeEx,GetFileAttributesW,NtAllocateVirtualMemory,GetFileAttributesW,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetFileAttributesW,NtCreateFile,NtReadFile,SetFilePointer,NtReadFile,SetFilePointer,NtReadFile,NtClose,NtCreateFile
#
# Hashes of Benign Samples with Matching API Call Patterns:
# 	4aba626c632f90a7f35c70b137a2c5f8
#
# No. of API Call Patterns of Falsely-Labelled Malicious Samples that match the API Call Patterns of Benign Samples: 10 (0.9268%)
#
# ===================================================================================================================
#
# In terms of unique API Calls:
# PATTERN: 1
# ['GetSystemTimeAsFileTime', 'NtCreateMutant', 'NtOpenKeyEx', 'NtQueryKey', 'LdrLoadDll', 'LdrGetProcedureAddress', 'RegOpenKeyExW', 'RegQueryInfoKeyW', 'RegEnumKeyExW', 'RegEnumValueW', 'RegCloseKey', 'GetFileAttributesW', 'RegQueryValueExW', 'NtOpenFile', 'NtQueryDirectoryFile', 'NtClose', 'NtQuerySystemInformation', 'NtProtectVirtualMemory', 'GetSystemDirectoryW', 'LdrGetDllHandle', 'NtOpenKey', 'NtQueryValueKey', 'NtCreateFile', 'GetFileSize', 'NtCreateSection', 'NtMapViewOfSection', 'GetSystemInfo', 'NtUnmapViewOfSection']
#
# PATTERN: 2
# ['GetSystemTimeAsFileTime', 'GetSystemInfo', 'NtCreateMutant', 'NtOpenKey', 'NtOpenKeyEx', 'LdrLoadDll', 'LdrGetProcedureAddress', 'RegOpenKeyExW', 'RegQueryInfoKeyW', 'RegEnumKeyExW', 'RegEnumValueW', 'RegCloseKey', 'GetFileAttributesW', 'RegQueryValueExW', 'FindFirstFileExW', 'LdrGetDllHandle', 'NtQuerySystemInformation', 'NtProtectVirtualMemory', 'GetSystemDirectoryW', 'NtQueryValueKey', 'NtClose', 'NtCreateFile', 'GetFileSize', 'NtCreateSection', 'NtMapViewOfSection', 'NtUnmapViewOfSection']
#
# PATTERN: 3
# ['SetErrorMode', 'LdrGetDllHandle', 'LdrGetProcedureAddress', 'GetSystemDirectoryW', 'NtAllocateVirtualMemory', 'NtFreeVirtualMemory', 'LdrLoadDll', 'GetSystemWindowsDirectoryW', 'RegOpenKeyExA', 'LoadStringW', 'RegOpenKeyExW', 'RegQueryValueExW', 'RegCloseKey', 'NtOpenKey', 'NtQueryValueKey', 'NtClose', 'NtCreateMutant', 'GetNativeSystemInfo', 'NtQueryAttributesFile', 'NtCreateFile', 'NtCreateSection', 'NtMapViewOfSection', 'OleInitialize', 'NtOpenSection']
#
# PATTERN: 4
# ['SetErrorMode', 'LdrGetDllHandle', 'LdrGetProcedureAddress', 'GetSystemDirectoryW', 'NtAllocateVirtualMemory', 'NtFreeVirtualMemory', 'LdrLoadDll', 'GetSystemWindowsDirectoryW', 'RegOpenKeyExA', 'LoadStringW', 'RegOpenKeyExW', 'RegQueryValueExW', 'RegCloseKey', 'NtOpenKey', 'NtQueryValueKey', 'NtClose', 'NtCreateMutant', 'GetNativeSystemInfo', 'NtQueryAttributesFile', 'NtCreateFile', 'NtCreateSection', 'NtMapViewOfSection', 'OleInitialize', 'NtOpenSection']
#
# PATTERN: 5
# ['GetSystemTimeAsFileTime', 'NtOpenKey', 'NtQueryValueKey', 'NtClose', 'NtCreateMutant', 'NtOpenKeyEx', 'NtQueryKey', 'LdrLoadDll', 'LdrGetProcedureAddress', 'RegOpenKeyExW', 'RegQueryInfoKeyW', 'RegEnumKeyExW', 'RegEnumValueW', 'RegCloseKey', 'GetFileAttributesW', 'RegQueryValueExW', 'NtOpenFile', 'NtQueryDirectoryFile', 'NtQuerySystemInformation', 'NtProtectVirtualMemory', 'GetSystemDirectoryW', 'LdrGetDllHandle', 'NtCreateFile', 'GetFileSize', 'NtCreateSection', 'NtMapViewOfSection', 'GetSystemInfo', 'NtUnmapViewOfSection']
#
# PATTERN: 6
# ['GetSystemInfo', 'NtAllocateVirtualMemory', 'NtOpenSection', 'GetTempPathW', 'CreateDirectoryW', 'GetFileAttributesW', 'FindFirstFileExW', 'DeleteFileW', 'NtQueryDirectoryFile', 'NtClose', 'RemoveDirectoryW', 'LdrGetProcedureAddress', 'LdrLoadDll', 'LdrGetDllHandle', 'FindResourceA', 'RegOpenKeyExW', 'RegQueryValueExW', 'GetSystemTimeAsFileTime', 'RegCloseKey', 'NtCreateMutant', 'NtCreateSection', 'NtMapViewOfSection', 'NtOpenKey', 'NtQueryValueKey', 'NtQueryAttributesFile', 'LoadResource', 'NtCreateFile', 'GetFileSize', 'NtUnmapViewOfSection', 'FindResourceW', 'SizeofResource', 'NtProtectVirtualMemory', 'NtQuerySystemInformation', 'GetNativeSystemInfo', 'GetSystemMetrics', 'NtOpenThread', 'NtOpenFile', 'CreateThread']
#
# PATTERN: 7
# ['LdrLoadDll', 'LdrGetProcedureAddress', 'NtProtectVirtualMemory', 'GetSystemTimeAsFileTime', 'NtAllocateVirtualMemory', 'NtFreeVirtualMemory', 'LdrGetDllHandle', 'SetUnhandledExceptionFilter', 'RegOpenKeyExW', 'RegQueryValueExW', 'RegCloseKey', 'GetNativeSystemInfo', 'LdrUnloadDll']
#
# PATTERN: 8
# ['GetSystemTimeAsFileTime', 'NtAllocateVirtualMemory', 'NtFreeVirtualMemory', 'LdrGetDllHandle', 'LdrGetProcedureAddress', 'SetUnhandledExceptionFilter', 'RegOpenKeyExW', 'RegQueryValueExW', 'RegCloseKey', 'LdrLoadDll', 'GetNativeSystemInfo', 'LdrUnloadDll', 'NtClose', 'IsDebuggerPresent', 'GetSystemMetrics', 'NtMapViewOfSection']
#
# PATTERN: 9
# ['GetSystemTimeAsFileTime', 'NtAllocateVirtualMemory', 'NtFreeVirtualMemory', 'LdrGetDllHandle', 'LdrGetProcedureAddress', 'SetUnhandledExceptionFilter', 'RegOpenKeyExA', 'RegQueryValueExA', 'RegCloseKey', 'LdrLoadDll', 'GetNativeSystemInfo', 'LdrUnloadDll', 'NtClose', 'IsDebuggerPresent', 'GetSystemMetrics', 'NtMapViewOfSection']
#
# PATTERN: 10
# ['LdrLoadDll', 'LdrGetProcedureAddress', 'NtProtectVirtualMemory', 'GetSystemTimeAsFileTime', 'LdrGetDllHandle', 'SetUnhandledExceptionFilter', 'NtOpenFile', 'DeviceIoControl', 'CoInitializeEx', 'SetErrorMode', 'GetFileAttributesW', 'SHGetFolderPathW', 'NtAllocateVirtualMemory', 'NtCreateFile', 'NtReadFile', 'SetFilePointer', 'NtClose']
