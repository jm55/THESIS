# %% [markdown]
# # Malicious ClusterScan
#
# Describes/summarizes the or set of clusters. Useful for when you aim to enlist the summarized malware types found in each cluster in order by Malware Type.
#
# Assume that the dataset is already pre-processed:
# 1. Removal of nan values
# 2. Data Cleaning (Removal of False Labels and *Removal/Aggregation of malware types of poor quantity*)
# 3. Inverse Ordinal Encoding (for representation purposes only)

# %% [markdown]
# ## Import Libraries/Datasets

# %%
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

plt.rcParams["figure.autolayout"] = True

malicious_df = pd.read_csv('./Manual_DBSCAN_Encoded_Clustering.csv', low_memory=False, index_col=False) #This should point to a VirusTotal verified <Data Clustering>_SampleHash_Common.csv file

#Load list of API calls
API_LIST = "../api_calls.txt"
DELIMITER = "NaN"
API_FILE = open(API_LIST,"r")
APIS = API_FILE.readline().split(',')
APIS.append(DELIMITER) #serves as a label for NaN values for Instance-based datasets
API_FILE.close()

def list_to_str(ls:list):
    output = ""
    for l in ls:
        output += str(l) + " "
    return output[0:len(output)-1]

def inject_patterns(inner_df:pd.DataFrame):
    patterns = []
    for row in range(inner_df.shape[0]):
        patterns.append(list_to_str(inner_df.iloc[row,2:5].transpose().to_list()))
    inner_df['type_pattern'] = patterns
    return inner_df

def get_unique_clusters(df:pd.DataFrame):
    return list(df['cluster'].unique())

def get_summary(df:pd.DataFrame):
    #Identify the overall list of types each cluster is as designated by VirusTotal.
    unique_clusters = get_unique_clusters(df)
    summary = []
    for u in unique_clusters:
        cluster_sublist = [u]
        df_copy = malicious_df[malicious_df['cluster'] == u].copy(deep=True)
        idx = list(df_copy['type'].value_counts().index)
        counts = list(df_copy['type'].value_counts())
        type_sublist = []
        for i in range(len(idx)):
            type_sublist.append([idx[i], counts[i]])
        cluster_sublist.append(type_sublist)
        # str_summary = []
        # cluster_sublist.append(list(df_copy['type_pattern'].value_counts().index))
        # cluster_sublist.append(list(df_copy['type_pattern'].value_counts()))
        summary.append(cluster_sublist)
    return summary

DELIMITER = "NaN"
API_FILE = open(API_LIST,"r")
APIS = API_FILE.readline().split(',')
APIS.append(DELIMITER) #serves as a label for NaN values for Instance-based datasets
API_FILE.close()

from sklearn.preprocessing import LabelEncoder
#Inverse Label Encoding
def inverse_label(item):
    global APIS
    return item.map(lambda x: APIS[int(x)])
oliveira = pd.read_csv('../oliveira.csv', low_memory=False)
oliveira.iloc[:, 1:101] = oliveira.iloc[:, 1:101].apply(inverse_label, axis=1, result_type='reduce')

def how_many_clusters():
    c = malicious_df['cluster'].unique()
    c.sort()
    print("Number of Clusters:", c.size)
    c = malicious_df['cluster'].value_counts(ascending=True)
    print("Number of single-item Clusters:", c[c==1].count())
    print("Number of Samples Remaining:", malicious_df.shape[0])

# %% [markdown]
# ## DataFrame Preview

# %%
#Replace '-' empty malware type delimiter with '_' for consistency
malicious_df.replace(to_replace='-',value='_', inplace=True)
display(malicious_df.head(10))
display(malicious_df.shape)
malicious_df['type'].value_counts(ascending=True).plot(kind='barh')
# Out:
#                                hash                          t_0  \
# 0  071e8c3f8922e186e57548cd4c703a5d                RegOpenKeyExA
# 1  33f8e6d08a6aae939f25a8e0d63dd523      GetSystemTimeAsFileTime
# 2  b68abd064e975e1c6d5f25e748663076  SetUnhandledExceptionFilter
# 3  72049be7bd30ea61297ea624ae198067      GetSystemTimeAsFileTime
# 4  c9b3700a77facf29172f32df6bc77f48      GetSystemTimeAsFileTime
# 5  cc6217be863e606e49da90fee2252f52       LdrGetProcedureAddress
# 6  f7a1a3c38809d807b3f5f4cc00b1e9b7                      NtClose
# 7  164b56522eb24164184460f8523ed7e2      GetSystemTimeAsFileTime
# 8  56ae1459ba61a14eb119982d6ec793d7      GetSystemTimeAsFileTime
# 9  c4148ca91c5246a8707a1ac1fd1e2e36      GetSystemTimeAsFileTime
#
#                        t_1                     t_2                      t_3  \
# 0                NtOpenKey         NtQueryValueKey                  NtClose
# 1  NtAllocateVirtualMemory     NtFreeVirtualMemory  NtAllocateVirtualMemory
# 2            OleInitialize              LdrLoadDll   LdrGetProcedureAddress
# 3  NtAllocateVirtualMemory     NtFreeVirtualMemory  NtAllocateVirtualMemory
# 4               LdrLoadDll  LdrGetProcedureAddress               LdrLoadDll
# 5  NtAllocateVirtualMemory  LdrGetProcedureAddress  NtAllocateVirtualMemory
# 6                NtOpenKey         NtQueryValueKey                  NtClose
# 7               LdrLoadDll  LdrGetProcedureAddress               LdrLoadDll
# 8               LdrLoadDll  LdrGetProcedureAddress               LdrLoadDll
# 9  NtAllocateVirtualMemory     NtFreeVirtualMemory  NtAllocateVirtualMemory
#
#                       t_4                     t_5                     t_6  \
# 0               NtOpenKey         NtQueryValueKey                 NtClose
# 1         LdrGetDllHandle  LdrGetProcedureAddress         LdrGetDllHandle
# 2              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 3         LdrGetDllHandle  LdrGetProcedureAddress         LdrGetDllHandle
# 4  LdrGetProcedureAddress              LdrLoadDll  LdrGetProcedureAddress
# 5  LdrGetProcedureAddress              LdrLoadDll  LdrGetProcedureAddress
# 6               NtOpenKey         NtQueryValueKey                 NtClose
# 7  LdrGetProcedureAddress              LdrLoadDll  LdrGetProcedureAddress
# 8  LdrGetProcedureAddress              LdrLoadDll  LdrGetProcedureAddress
# 9         LdrGetDllHandle  LdrGetProcedureAddress         LdrGetDllHandle
#
#                        t_7                          t_8  ...  \
# 0    NtQueryAttributesFile                  LoadStringA  ...
# 1   LdrGetProcedureAddress              LdrGetDllHandle  ...
# 2   LdrGetProcedureAddress                   LdrLoadDll  ...
# 3   LdrGetProcedureAddress              LdrGetDllHandle  ...
# 4               LdrLoadDll       LdrGetProcedureAddress  ...
# 5               LdrLoadDll       LdrGetProcedureAddress  ...
# 6          LdrGetDllHandle       LdrGetProcedureAddress  ...
# 7               LdrLoadDll       LdrGetProcedureAddress  ...
# 8               LdrLoadDll       LdrGetProcedureAddress  ...
# 9  NtAllocateVirtualMemory  SetUnhandledExceptionFilter  ...
#
#                          t_94                 t_95  \
# 0          NtMapViewOfSection              NtClose
# 1  GetSystemWindowsDirectoryW         NtCreateFile
# 2                 RegCloseKey        RegOpenKeyExA
# 3        NtWriteVirtualMemory  NtFreeVirtualMemory
# 4               RegEnumKeyExW        RegOpenKeyExW
# 5            RegQueryValueExW          RegCloseKey
# 6             LdrGetDllHandle      FindResourceExW
# 7         GetSystemDirectoryW           LdrLoadDll
# 8                     NtClose           WSAStartup
# 9     NtAllocateVirtualMemory      LdrGetDllHandle
#
#                                 t_96                     t_97  \
# 0                   GetSystemMetrics  NtAllocateVirtualMemory
# 1                    NtCreateSection       NtMapViewOfSection
# 2                   RegQueryValueExA              RegCloseKey
# 3            NtAllocateVirtualMemory     NtWriteVirtualMemory
# 4                   RegQueryValueExW            RegOpenKeyExW
# 5  GetVolumeNameForVolumeMountPointW   LdrGetProcedureAddress
# 6                       LoadResource          FindResourceExW
# 7                       CreateThread          FindResourceExW
# 8            NtAllocateVirtualMemory             CreateThread
# 9             LdrGetProcedureAddress            NtOpenProcess
#
#                      t_98                        t_99 malware        type  \
# 0           CreateActCtxW  GetSystemWindowsDirectoryW       1      trojan
# 1                 NtClose            GetSystemMetrics       1         pua
# 2           RegEnumKeyExA               RegOpenKeyExA       1      trojan
# 3  NtProtectVirtualMemory        NtWriteVirtualMemory       1      trojan
# 4        RegQueryValueExW               RegOpenKeyExW       1      trojan
# 5           RegOpenKeyExW                 RegCloseKey       1      trojan
# 6            LoadResource                 DrawTextExW       1  downloader
# 7                 NtClose            GetSystemMetrics       1      adware
# 8              LdrLoadDll      LdrGetProcedureAddress       1      adware
# 9                 NtClose            GetSystemMetrics       1  downloader
#
#                                              pattern cluster
# 0  RegOpenKeyExA,NtOpenKey,NtQueryValueKey,NtClos...       0
# 1  GetSystemTimeAsFileTime,NtAllocateVirtualMemor...       1
# 2  SetUnhandledExceptionFilter,OleInitialize,LdrL...       2
# 3  GetSystemTimeAsFileTime,NtAllocateVirtualMemor...       3
# 4  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...       4
# 5  LdrGetProcedureAddress,NtAllocateVirtualMemory...       5
# 6  NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOp...       6
# 7  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...       7
# 8  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...       8
# 9  GetSystemTimeAsFileTime,NtAllocateVirtualMemor...       9
#
# [10 rows x 105 columns]
# (40159, 105)
# <Axes: ylabel='type'>

# %% [markdown]
# # Dataset Cleaning and Inverse Ordinal Encoding (for representation)

# %%
#INJECT PATTERN (i.e., summarized malware type pattern) to the DataFrame
malicious_df = inject_patterns(malicious_df)

print("Raw Clustered malicious samples")
how_many_clusters()
# Out:
# Raw Clustered malicious samples
# Number of Clusters: 11492
# Number of single-item Clusters: 9521
# Number of Samples Remaining: 40159

# %% [markdown]
# ## "What Malware Types can be found in the overall dataset?"
#
# ### This is regardless of cluster.

# %%
output = malicious_df['type'].value_counts()
str_output = str(output) + "\n\n"
with open("./Output/1 MalwareTypes_in_Dataset.txt", 'w') as f:
    f.write(str_output)
    f.flush
    f.close()
display(output)
fig, axs = plt.subplots(nrows=1, layout='constrained')
fig.set_figwidth(4)
fig.set_figheight(3)
fig.set_dpi(300)
axs.set_title('Malware Type Counts')
axs.barh(malicious_df['type'].value_counts().index, malicious_df['type'].value_counts())
axs.invert_yaxis()
# axs[1].set_title('Type 2 Malware Type Counts')
# axs[1].invert_yaxis()
# axs[1].barh(malicious_df['Type 2'].value_counts().index, malicious_df['Type 2'].value_counts())
# axs[2].invert_yaxis()
# axs[2].set_title('Type 3 (Least \'Popular\') Malware Type Counts')
# axs[2].barh(malicious_df['Type 3'].value_counts().index, malicious_df['Type 3'].value_counts())
plt.savefig("./Output/1 Popular Malware Types in Dataset.png")
# Out:
# type
# trojan        33352
# downloader     2249
# pua            2135
# adware         1815
# ransomware      341
# miner           125
# virus            79
# spyware          48
# hacktool          7
# dropper           5
# worm              3
# Name: count, dtype: int64

# %% [markdown]
# ## How many clusters are there?

# %%
#Prior to noise removal
print("Prior to noise removal")
how_many_clusters()
# Out:
# Prior to noise removal
# Number of Clusters: 11492
# Number of single-item Clusters: 9521
# Number of Samples Remaining: 40159

# %%
# DROP CLUSTERS WITH MORE THAN 1 MALWARE TYPE UNDER IT (i.e. NOISE)
unique_clusters = get_unique_clusters(malicious_df)
for u in unique_clusters:
    if len(malicious_df[malicious_df['cluster'] == u]['type'].unique()) > 1:
        malicious_df = malicious_df.drop(malicious_df[malicious_df['cluster'] == u].index)
# malicious_df.head()

print("After removing yet unlabelled malicious samples\n and clusters with more than 1 malware type")
how_many_clusters()
# Out:
# After removing yet unlabelled malicious samples
#  and clusters with more than 1 malware type
# Number of Clusters: 11033
# Number of single-item Clusters: 9521
# Number of Samples Remaining: 16576

# %%
# REMOVE SINGLE ITEM CLUSTERS
unique_clusters = get_unique_clusters(malicious_df)
for u in unique_clusters:
    if malicious_df[malicious_df['cluster'] == u].shape[0] == 1:
        malicious_df = malicious_df.drop(malicious_df[malicious_df['cluster'] == u].index)

print("After removing single-item clusters")
how_many_clusters()
# Out:
# After removing single-item clusters
# Number of Clusters: 1512
# Number of single-item Clusters: 0
# Number of Samples Remaining: 7055

# %% [markdown]
# ## "What Malware Types are there in each cluster?"

# %% [markdown]
# ### Identify the counts of Malware Types per Cluster
#
# This indicates the malware types (including the # of instances) found in each cluster.

# %%
str_output = ""
summary = get_summary(malicious_df)
summary.sort()
for s in summary:
    str_output += f"CLUSTER {s[0]}: "
    for t in s[1]:
        str_output += f"{t[0]} ({t[1]}); "
    # str_output += "\n\tType 2: "
    # for t in s[2]:
    #     str_output += f"{t[0]} ({t[1]}); "
    # str_output += "\n\tType 3: "
    # for t in s[3]:
    #     str_output += f"{t[0]} ({t[1]}); "
    # str_output += "\n\tMost Popular Malware Type Combination (in order Most to Least):\n"
    # for i,t in enumerate(s[4]):
    #     str_output += f"\t    {i+1} {t:12s} ({s[5][i]})\n"
    str_output += "\n"
with open("./Output/1 MalwareType_per_Cluster_woNoise.txt", 'w') as f:
    f.write(str_output)
    f.flush
    f.close()
print(str_output)
# Out:
# CLUSTER 2: trojan (8);
# CLUSTER 11: trojan (10);
# CLUSTER 14: trojan (23);
# CLUSTER 15: trojan (12);
# CLUSTER 18: trojan (2);
# CLUSTER 22: trojan (29);
# CLUSTER 23: trojan (2);
# CLUSTER 32: trojan (14);
# CLUSTER 39: trojan (99);
# CLUSTER 40: trojan (2);
# CLUSTER 41: trojan (101);
# CLUSTER 44: trojan (2);
# CLUSTER 49: trojan (3);
# CLUSTER 54: trojan (12);
# CLUSTER 56: trojan (5);
# CLUSTER 58: trojan (16);
# CLUSTER 63: trojan (3);
# CLUSTER 65: trojan (19);
# CLUSTER 67: trojan (2);
# CLUSTER 69: downloader (4);
# CLUSTER 73: trojan (3);
# CLUSTER 76: trojan (7);
# CLUSTER 78: trojan (9);
# CLUSTER 80: trojan (35);
# CLUSTER 82: miner (3);
# CLUSTER 83: trojan (28);
# CLUSTER 85: trojan (4);
# CLUSTER 86: trojan (7);
# CLUSTER 88: adware (6);
# CLUSTER 89: trojan (12);
# CLUSTER 90: virus (7);
# CLUSTER 91: trojan (84);
# CLUSTER 94: trojan (2);
# CLUSTER 98: trojan (2);
# CLUSTER 100: trojan (268);
# CLUSTER 101: trojan (11);
# CLUSTER 104: trojan (5);
# CLUSTER 117: trojan (11);
# CLUSTER 124: trojan (4);
# CLUSTER 125: trojan (2);
# CLUSTER 127: trojan (19);
# CLUSTER 132: trojan (32);
# CLUSTER 137: trojan (5);
# CLUSTER 139: trojan (4);
# CLUSTER 142: trojan (10);
# CLUSTER 147: trojan (4);
# CLUSTER 151: trojan (3);
# CLUSTER 157: trojan (15);
# CLUSTER 159: trojan (11);
# CLUSTER 162: trojan (3);
# CLUSTER 172: trojan (3);
# CLUSTER 173: trojan (6);
# CLUSTER 179: trojan (2);
# CLUSTER 183: trojan (5);
# CLUSTER 188: trojan (3);
# CLUSTER 190: trojan (14);
# CLUSTER 191: trojan (2);
# CLUSTER 199: trojan (2);
# CLUSTER 201: trojan (11);
# CLUSTER 207: trojan (127);
# CLUSTER 208: trojan (6);
# CLUSTER 223: trojan (18);
# CLUSTER 232: trojan (14);
# CLUSTER 237: trojan (3);
# CLUSTER 240: trojan (15);
# CLUSTER 242: trojan (16);
# CLUSTER 247: trojan (5);
# CLUSTER 251: trojan (4);
# CLUSTER 253: trojan (14);
# CLUSTER 255: trojan (8);
# CLUSTER 258: trojan (40);
# CLUSTER 259: pua (2);
# CLUSTER 261: trojan (2);
# CLUSTER 262: trojan (2);
# CLUSTER 264: trojan (10);
# CLUSTER 274: adware (28);
# CLUSTER 275: trojan (2);
# CLUSTER 281: trojan (3);
# CLUSTER 284: trojan (17);
# CLUSTER 286: trojan (6);
# CLUSTER 287: trojan (5);
# CLUSTER 289: trojan (2);
# CLUSTER 292: trojan (5);
# CLUSTER 294: trojan (4);
# CLUSTER 303: trojan (29);
# CLUSTER 307: trojan (13);
# CLUSTER 310: trojan (3);
# CLUSTER 315: trojan (26);
# CLUSTER 316: trojan (6);
# CLUSTER 319: trojan (18);
# CLUSTER 322: trojan (42);
# CLUSTER 324: trojan (5);
# CLUSTER 325: trojan (3);
# CLUSTER 326: trojan (6);
# CLUSTER 331: trojan (3);
# CLUSTER 335: trojan (2);
# CLUSTER 338: trojan (9);
# CLUSTER 344: trojan (6);
# CLUSTER 345: trojan (7);
# CLUSTER 346: trojan (6);
# CLUSTER 347: trojan (2);
# CLUSTER 348: trojan (2);
# CLUSTER 351: trojan (3);
# CLUSTER 352: trojan (6);
# CLUSTER 353: trojan (2);
# CLUSTER 354: trojan (8);
# CLUSTER 355: trojan (62);
# CLUSTER 361: ransomware (4);
# CLUSTER 363: trojan (5);
# CLUSTER 366: trojan (15);
# CLUSTER 367: trojan (3);
# CLUSTER 369: trojan (6);
# CLUSTER 373: trojan (2);
# CLUSTER 376: trojan (5);
# CLUSTER 380: trojan (2);
# CLUSTER 383: trojan (2);
# CLUSTER 389: trojan (3);
# CLUSTER 390: trojan (24);
# CLUSTER 395: trojan (2);
# CLUSTER 399: trojan (2);
# CLUSTER 400: trojan (2);
# CLUSTER 403: trojan (2);
# CLUSTER 406: trojan (2);
# CLUSTER 409: trojan (12);
# CLUSTER 410: trojan (6);
# CLUSTER 413: trojan (17);
# CLUSTER 414: trojan (25);
# CLUSTER 417: trojan (15);
# CLUSTER 419: trojan (5);
# CLUSTER 421: trojan (44);
# CLUSTER 422: trojan (2);
# CLUSTER 425: trojan (2);
# CLUSTER 426: trojan (37);
# CLUSTER 427: trojan (28);
# CLUSTER 428: trojan (2);
# CLUSTER 430: trojan (2);
# CLUSTER 431: trojan (4);
# CLUSTER 432: trojan (6);
# CLUSTER 440: trojan (7);
# CLUSTER 445: trojan (2);
# CLUSTER 451: trojan (2);
# CLUSTER 453: trojan (2);
# CLUSTER 455: trojan (16);
# CLUSTER 456: trojan (3);
# CLUSTER 457: trojan (2);
# CLUSTER 459: trojan (2);
# CLUSTER 460: trojan (37);
# CLUSTER 463: trojan (4);
# CLUSTER 464: trojan (6);
# CLUSTER 467: pua (2);
# CLUSTER 469: trojan (2);
# CLUSTER 470: trojan (10);
# CLUSTER 471: pua (3);
# CLUSTER 473: trojan (5);
# CLUSTER 474: trojan (24);
# CLUSTER 484: trojan (41);
# CLUSTER 486: trojan (14);
# CLUSTER 488: trojan (2);
# CLUSTER 492: pua (2);
# CLUSTER 493: trojan (3);
# CLUSTER 495: trojan (75);
# CLUSTER 499: trojan (10);
# CLUSTER 501: trojan (5);
# CLUSTER 508: trojan (2);
# CLUSTER 512: trojan (4);
# CLUSTER 515: trojan (3);
# CLUSTER 516: trojan (5);
# CLUSTER 518: trojan (2);
# CLUSTER 532: trojan (54);
# CLUSTER 537: trojan (12);
# CLUSTER 538: trojan (8);
# CLUSTER 541: trojan (15);
# CLUSTER 545: trojan (10);
# CLUSTER 548: trojan (3);
# CLUSTER 554: trojan (3);
# CLUSTER 557: trojan (2);
# CLUSTER 559: trojan (2);
# CLUSTER 564: trojan (2);
# CLUSTER 565: adware (2);
# CLUSTER 568: trojan (2);
# CLUSTER 571: pua (4);
# CLUSTER 573: trojan (2);
# CLUSTER 576: trojan (3);
# CLUSTER 577: trojan (10);
# CLUSTER 578: trojan (2);
# CLUSTER 580: trojan (6);
# CLUSTER 584: trojan (17);
# CLUSTER 585: trojan (5);
# CLUSTER 586: trojan (7);
# CLUSTER 588: trojan (45);
# CLUSTER 593: trojan (3);
# CLUSTER 594: trojan (3);
# CLUSTER 595: trojan (2);
# CLUSTER 596: adware (2);
# CLUSTER 597: trojan (2);
# CLUSTER 599: trojan (4);
# CLUSTER 601: trojan (2);
# CLUSTER 602: trojan (5);
# CLUSTER 604: trojan (3);
# CLUSTER 609: trojan (2);
# CLUSTER 612: trojan (10);
# CLUSTER 623: trojan (9);
# CLUSTER 624: trojan (2);
# CLUSTER 625: trojan (3);
# CLUSTER 626: trojan (3);
# CLUSTER 634: trojan (12);
# CLUSTER 636: trojan (3);
# CLUSTER 639: trojan (4);
# CLUSTER 641: trojan (6);
# CLUSTER 644: trojan (6);
# CLUSTER 645: trojan (2);
# CLUSTER 655: trojan (2);
# CLUSTER 660: trojan (5);
# CLUSTER 661: trojan (5);
# CLUSTER 662: trojan (3);
# CLUSTER 664: trojan (2);
# CLUSTER 667: trojan (10);
# CLUSTER 676: ransomware (5);
# CLUSTER 680: trojan (5);
# CLUSTER 681: trojan (6);
# CLUSTER 684: trojan (5);
# CLUSTER 686: trojan (2);
# CLUSTER 692: trojan (24);
# CLUSTER 704: trojan (2);
# CLUSTER 705: trojan (6);
# CLUSTER 707: trojan (4);
# CLUSTER 712: pua (7);
# CLUSTER 714: trojan (36);
# CLUSTER 715: trojan (3);
# CLUSTER 720: trojan (2);
# CLUSTER 730: trojan (6);
# CLUSTER 733: downloader (4);
# CLUSTER 737: trojan (39);
# CLUSTER 742: trojan (27);
# CLUSTER 752: trojan (2);
# CLUSTER 755: trojan (2);
# CLUSTER 760: trojan (3);
# CLUSTER 762: trojan (2);
# CLUSTER 763: trojan (6);
# CLUSTER 764: trojan (4);
# CLUSTER 767: trojan (2);
# CLUSTER 770: trojan (21);
# CLUSTER 773: trojan (3);
# CLUSTER 774: trojan (2);
# CLUSTER 777: trojan (4);
# CLUSTER 778: trojan (30);
# CLUSTER 779: trojan (4);
# CLUSTER 781: trojan (2);
# CLUSTER 784: trojan (2);
# CLUSTER 788: trojan (2);
# CLUSTER 792: trojan (2);
# CLUSTER 798: trojan (2);
# CLUSTER 802: trojan (3);
# CLUSTER 803: trojan (5);
# CLUSTER 804: trojan (4);
# CLUSTER 809: trojan (2);
# CLUSTER 810: trojan (4);
# CLUSTER 811: trojan (2);
# CLUSTER 813: trojan (2);
# CLUSTER 817: adware (2);
# CLUSTER 819: trojan (3);
# CLUSTER 820: trojan (2);
# CLUSTER 822: adware (2);
# CLUSTER 823: trojan (2);
# CLUSTER 826: trojan (10);
# CLUSTER 829: trojan (2);
# CLUSTER 832: trojan (30);
# CLUSTER 833: trojan (4);
# CLUSTER 838: trojan (4);
# CLUSTER 841: trojan (7);
# CLUSTER 843: trojan (12);
# CLUSTER 845: trojan (6);
# CLUSTER 855: trojan (2);
# CLUSTER 857: trojan (11);
# CLUSTER 859: trojan (3);
# CLUSTER 861: trojan (2);
# CLUSTER 866: trojan (13);
# CLUSTER 867: trojan (2);
# CLUSTER 871: trojan (3);
# CLUSTER 873: trojan (2);
# CLUSTER 881: trojan (2);
# CLUSTER 882: trojan (2);
# CLUSTER 894: trojan (3);
# CLUSTER 895: trojan (5);
# CLUSTER 899: trojan (2);
# CLUSTER 901: trojan (2);
# CLUSTER 902: trojan (4);
# CLUSTER 906: trojan (3);
# CLUSTER 908: trojan (2);
# CLUSTER 909: trojan (6);
# CLUSTER 910: trojan (2);
# CLUSTER 912: trojan (4);
# CLUSTER 913: trojan (7);
# CLUSTER 916: trojan (5);
# CLUSTER 921: adware (5);
# CLUSTER 923: trojan (4);
# CLUSTER 925: trojan (4);
# CLUSTER 926: trojan (2);
# CLUSTER 929: trojan (2);
# CLUSTER 932: trojan (22);
# CLUSTER 934: trojan (6);
# CLUSTER 946: trojan (4);
# CLUSTER 947: trojan (5);
# CLUSTER 970: trojan (2);
# CLUSTER 971: adware (3);
# CLUSTER 973: trojan (6);
# CLUSTER 975: trojan (2);
# CLUSTER 976: trojan (3);
# CLUSTER 983: trojan (2);
# CLUSTER 984: trojan (2);
# CLUSTER 985: trojan (4);
# CLUSTER 989: trojan (2);
# CLUSTER 990: trojan (20);
# CLUSTER 991: trojan (2);
# CLUSTER 997: trojan (5);
# CLUSTER 998: trojan (13);
# CLUSTER 999: adware (2);
# CLUSTER 1000: adware (2);
# CLUSTER 1006: trojan (2);
# CLUSTER 1010: trojan (6);
# CLUSTER 1011: trojan (4);
# CLUSTER 1012: trojan (2);
# CLUSTER 1019: trojan (3);
# CLUSTER 1020: trojan (28);
# CLUSTER 1023: trojan (13);
# CLUSTER 1032: trojan (2);
# CLUSTER 1035: trojan (5);
# CLUSTER 1040: trojan (16);
# CLUSTER 1041: trojan (2);
# CLUSTER 1047: trojan (6);
# CLUSTER 1049: trojan (6);
# CLUSTER 1054: trojan (2);
# CLUSTER 1057: trojan (4);
# CLUSTER 1066: trojan (2);
# CLUSTER 1078: trojan (2);
# CLUSTER 1079: trojan (8);
# CLUSTER 1080: trojan (4);
# CLUSTER 1081: trojan (2);
# CLUSTER 1086: trojan (2);
# CLUSTER 1088: trojan (5);
# CLUSTER 1090: trojan (3);
# CLUSTER 1091: trojan (2);
# CLUSTER 1105: trojan (12);
# CLUSTER 1107: trojan (2);
# CLUSTER 1113: trojan (25);
# CLUSTER 1119: trojan (2);
# CLUSTER 1124: trojan (4);
# CLUSTER 1129: trojan (2);
# CLUSTER 1130: trojan (2);
# CLUSTER 1135: trojan (2);
# CLUSTER 1155: trojan (8);
# CLUSTER 1158: trojan (13);
# CLUSTER 1159: trojan (3);
# CLUSTER 1160: trojan (7);
# CLUSTER 1162: trojan (2);
# CLUSTER 1169: trojan (19);
# CLUSTER 1171: trojan (2);
# CLUSTER 1181: trojan (2);
# CLUSTER 1183: trojan (2);
# CLUSTER 1185: trojan (6);
# CLUSTER 1188: trojan (2);
# CLUSTER 1189: trojan (2);
# CLUSTER 1190: trojan (3);
# CLUSTER 1193: trojan (6);
# CLUSTER 1196: trojan (2);
# CLUSTER 1203: pua (3);
# CLUSTER 1207: trojan (2);
# CLUSTER 1208: adware (8);
# CLUSTER 1210: trojan (4);
# CLUSTER 1213: trojan (16);
# CLUSTER 1216: trojan (2);
# CLUSTER 1218: trojan (7);
# CLUSTER 1221: trojan (3);
# CLUSTER 1238: trojan (5);
# CLUSTER 1239: trojan (3);
# CLUSTER 1251: trojan (6);
# CLUSTER 1255: trojan (2);
# CLUSTER 1260: trojan (2);
# CLUSTER 1262: trojan (6);
# CLUSTER 1266: pua (2);
# CLUSTER 1269: trojan (5);
# CLUSTER 1276: trojan (2);
# CLUSTER 1277: trojan (2);
# CLUSTER 1280: trojan (7);
# CLUSTER 1281: trojan (8);
# CLUSTER 1285: trojan (2);
# CLUSTER 1286: adware (3);
# CLUSTER 1294: trojan (3);
# CLUSTER 1297: trojan (12);
# CLUSTER 1300: pua (4);
# CLUSTER 1301: trojan (4);
# CLUSTER 1302: trojan (3);
# CLUSTER 1308: trojan (7);
# CLUSTER 1322: trojan (5);
# CLUSTER 1329: trojan (3);
# CLUSTER 1331: trojan (8);
# CLUSTER 1332: trojan (3);
# CLUSTER 1335: trojan (2);
# CLUSTER 1347: trojan (2);
# CLUSTER 1348: trojan (42);
# CLUSTER 1365: trojan (3);
# CLUSTER 1367: trojan (2);
# CLUSTER 1375: trojan (4);
# CLUSTER 1382: trojan (6);
# CLUSTER 1383: trojan (2);
# CLUSTER 1387: trojan (3);
# CLUSTER 1399: adware (2);
# CLUSTER 1407: trojan (2);
# CLUSTER 1408: trojan (4);
# CLUSTER 1410: trojan (3);
# CLUSTER 1419: trojan (4);
# CLUSTER 1429: trojan (2);
# CLUSTER 1438: trojan (4);
# CLUSTER 1439: trojan (8);
# CLUSTER 1450: trojan (7);
# CLUSTER 1451: trojan (2);
# CLUSTER 1455: trojan (2);
# CLUSTER 1459: trojan (3);
# CLUSTER 1460: trojan (20);
# CLUSTER 1463: trojan (3);
# CLUSTER 1468: trojan (5);
# CLUSTER 1470: trojan (2);
# CLUSTER 1474: trojan (6);
# CLUSTER 1475: trojan (5);
# CLUSTER 1485: trojan (7);
# CLUSTER 1489: trojan (2);
# CLUSTER 1494: trojan (2);
# CLUSTER 1497: trojan (3);
# CLUSTER 1498: trojan (2);
# CLUSTER 1500: trojan (3);
# CLUSTER 1503: trojan (4);
# CLUSTER 1504: trojan (2);
# CLUSTER 1506: trojan (2);
# CLUSTER 1508: trojan (3);
# CLUSTER 1512: trojan (4);
# CLUSTER 1521: trojan (3);
# CLUSTER 1522: trojan (7);
# CLUSTER 1531: trojan (15);
# CLUSTER 1532: trojan (2);
# CLUSTER 1534: trojan (2);
# CLUSTER 1539: trojan (3);
# CLUSTER 1553: trojan (12);
# CLUSTER 1566: miner (2);
# CLUSTER 1570: trojan (2);
# CLUSTER 1573: trojan (5);
# CLUSTER 1574: trojan (9);
# CLUSTER 1585: trojan (2);
# CLUSTER 1587: trojan (2);
# CLUSTER 1595: trojan (3);
# CLUSTER 1599: trojan (2);
# CLUSTER 1602: ransomware (2);
# CLUSTER 1603: trojan (2);
# CLUSTER 1604: trojan (4);
# CLUSTER 1606: adware (2);
# CLUSTER 1619: trojan (3);
# CLUSTER 1622: trojan (10);
# CLUSTER 1624: trojan (6);
# CLUSTER 1631: trojan (2);
# CLUSTER 1635: trojan (4);
# CLUSTER 1641: trojan (3);
# CLUSTER 1644: trojan (7);
# CLUSTER 1651: trojan (13);
# CLUSTER 1655: trojan (3);
# CLUSTER 1658: trojan (3);
# CLUSTER 1661: trojan (2);
# CLUSTER 1668: trojan (3);
# CLUSTER 1672: trojan (17);
# CLUSTER 1673: trojan (3);
# CLUSTER 1682: trojan (2);
# CLUSTER 1683: trojan (3);
# CLUSTER 1692: adware (4);
# CLUSTER 1693: trojan (6);
# CLUSTER 1696: trojan (2);
# CLUSTER 1702: trojan (4);
# CLUSTER 1708: trojan (11);
# CLUSTER 1717: trojan (2);
# CLUSTER 1728: adware (4);
# CLUSTER 1731: trojan (2);
# CLUSTER 1735: trojan (2);
# CLUSTER 1736: trojan (10);
# CLUSTER 1749: trojan (2);
# CLUSTER 1751: trojan (3);
# CLUSTER 1752: adware (2);
# CLUSTER 1755: trojan (4);
# CLUSTER 1760: trojan (11);
# CLUSTER 1764: trojan (2);
# CLUSTER 1768: trojan (2);
# CLUSTER 1770: trojan (2);
# CLUSTER 1772: trojan (2);
# CLUSTER 1779: trojan (3);
# CLUSTER 1781: trojan (2);
# CLUSTER 1783: trojan (6);
# CLUSTER 1786: trojan (5);
# CLUSTER 1790: trojan (2);
# CLUSTER 1791: trojan (2);
# CLUSTER 1792: trojan (2);
# CLUSTER 1793: trojan (2);
# CLUSTER 1794: trojan (2);
# CLUSTER 1799: trojan (2);
# CLUSTER 1803: trojan (2);
# CLUSTER 1804: trojan (7);
# CLUSTER 1810: trojan (2);
# CLUSTER 1814: trojan (4);
# CLUSTER 1821: trojan (3);
# CLUSTER 1829: trojan (2);
# CLUSTER 1830: trojan (2);
# CLUSTER 1831: trojan (4);
# CLUSTER 1832: trojan (2);
# CLUSTER 1846: trojan (9);
# CLUSTER 1851: trojan (2);
# CLUSTER 1854: trojan (2);
# CLUSTER 1855: trojan (3);
# CLUSTER 1856: trojan (4);
# CLUSTER 1857: trojan (2);
# CLUSTER 1858: trojan (2);
# CLUSTER 1859: trojan (4);
# CLUSTER 1878: adware (6);
# CLUSTER 1883: trojan (3);
# CLUSTER 1889: trojan (10);
# CLUSTER 1894: trojan (5);
# CLUSTER 1896: trojan (4);
# CLUSTER 1901: trojan (2);
# CLUSTER 1909: trojan (2);
# CLUSTER 1911: trojan (6);
# CLUSTER 1915: trojan (3);
# CLUSTER 1917: adware (2);
# CLUSTER 1920: trojan (4);
# CLUSTER 1921: trojan (2);
# CLUSTER 1924: trojan (2);
# CLUSTER 1932: trojan (2);
# CLUSTER 1934: trojan (2);
# CLUSTER 1935: trojan (3);
# CLUSTER 1939: trojan (4);
# CLUSTER 1942: pua (2);
# CLUSTER 1946: trojan (2);
# CLUSTER 1949: trojan (3);
# CLUSTER 1952: trojan (7);
# CLUSTER 1957: trojan (4);
# CLUSTER 1984: trojan (3);
# CLUSTER 1990: trojan (4);
# CLUSTER 1994: trojan (2);
# CLUSTER 1999: trojan (2);
# CLUSTER 2011: trojan (4);
# CLUSTER 2015: trojan (2);
# CLUSTER 2016: trojan (2);
# CLUSTER 2024: trojan (2);
# CLUSTER 2028: trojan (2);
# CLUSTER 2029: trojan (7);
# CLUSTER 2040: trojan (3);
# CLUSTER 2041: trojan (2);
# CLUSTER 2044: trojan (2);
# CLUSTER 2052: trojan (3);
# CLUSTER 2057: trojan (2);
# CLUSTER 2060: trojan (2);
# CLUSTER 2062: trojan (2);
# CLUSTER 2065: trojan (2);
# CLUSTER 2066: trojan (2);
# CLUSTER 2067: trojan (14);
# CLUSTER 2070: trojan (2);
# CLUSTER 2074: trojan (4);
# CLUSTER 2078: trojan (19);
# CLUSTER 2084: trojan (3);
# CLUSTER 2087: trojan (5);
# CLUSTER 2094: trojan (6);
# CLUSTER 2096: trojan (3);
# CLUSTER 2099: miner (3);
# CLUSTER 2100: trojan (12);
# CLUSTER 2101: trojan (3);
# CLUSTER 2104: trojan (3);
# CLUSTER 2109: trojan (3);
# CLUSTER 2112: trojan (2);
# CLUSTER 2114: trojan (12);
# CLUSTER 2118: trojan (4);
# CLUSTER 2119: trojan (4);
# CLUSTER 2121: trojan (3);
# CLUSTER 2124: trojan (3);
# CLUSTER 2127: trojan (5);
# CLUSTER 2133: trojan (8);
# CLUSTER 2142: trojan (2);
# CLUSTER 2146: trojan (8);
# CLUSTER 2148: trojan (2);
# CLUSTER 2151: trojan (2);
# CLUSTER 2157: trojan (3);
# CLUSTER 2158: trojan (3);
# CLUSTER 2165: trojan (2);
# CLUSTER 2171: trojan (8);
# CLUSTER 2172: trojan (4);
# CLUSTER 2176: trojan (3);
# CLUSTER 2180: trojan (4);
# CLUSTER 2182: trojan (6);
# CLUSTER 2183: trojan (2);
# CLUSTER 2193: trojan (2);
# CLUSTER 2199: trojan (8);
# CLUSTER 2200: trojan (4);
# CLUSTER 2203: trojan (4);
# CLUSTER 2205: trojan (9);
# CLUSTER 2206: trojan (3);
# CLUSTER 2207: trojan (7);
# CLUSTER 2218: trojan (2);
# CLUSTER 2224: trojan (6);
# CLUSTER 2234: trojan (3);
# CLUSTER 2236: trojan (5);
# CLUSTER 2240: trojan (2);
# CLUSTER 2241: trojan (2);
# CLUSTER 2244: trojan (2);
# CLUSTER 2249: trojan (2);
# CLUSTER 2257: trojan (4);
# CLUSTER 2258: trojan (5);
# CLUSTER 2279: trojan (2);
# CLUSTER 2280: trojan (2);
# CLUSTER 2281: trojan (4);
# CLUSTER 2282: trojan (9);
# CLUSTER 2291: trojan (2);
# CLUSTER 2293: trojan (6);
# CLUSTER 2301: trojan (7);
# CLUSTER 2306: trojan (6);
# CLUSTER 2313: trojan (2);
# CLUSTER 2317: trojan (3);
# CLUSTER 2342: trojan (3);
# CLUSTER 2351: trojan (7);
# CLUSTER 2353: trojan (2);
# CLUSTER 2362: trojan (3);
# CLUSTER 2366: trojan (2);
# CLUSTER 2369: trojan (4);
# CLUSTER 2375: trojan (2);
# CLUSTER 2382: adware (8);
# CLUSTER 2386: trojan (2);
# CLUSTER 2389: trojan (3);
# CLUSTER 2390: trojan (2);
# CLUSTER 2392: trojan (2);
# CLUSTER 2394: trojan (2);
# CLUSTER 2396: adware (3);
# CLUSTER 2409: trojan (7);
# CLUSTER 2410: trojan (2);
# CLUSTER 2414: trojan (7);
# CLUSTER 2422: trojan (2);
# CLUSTER 2425: trojan (4);
# CLUSTER 2426: trojan (16);
# CLUSTER 2427: trojan (9);
# CLUSTER 2436: trojan (3);
# CLUSTER 2449: trojan (4);
# CLUSTER 2450: trojan (2);
# CLUSTER 2451: adware (9);
# CLUSTER 2452: trojan (9);
# CLUSTER 2466: trojan (26);
# CLUSTER 2469: trojan (3);
# CLUSTER 2471: trojan (3);
# CLUSTER 2474: trojan (4);
# CLUSTER 2483: trojan (2);
# CLUSTER 2494: trojan (2);
# CLUSTER 2496: trojan (3);
# CLUSTER 2503: trojan (2);
# CLUSTER 2504: trojan (3);
# CLUSTER 2505: adware (2);
# CLUSTER 2507: trojan (2);
# CLUSTER 2510: trojan (2);
# CLUSTER 2511: trojan (4);
# CLUSTER 2513: trojan (8);
# CLUSTER 2517: trojan (2);
# CLUSTER 2520: trojan (12);
# CLUSTER 2521: trojan (4);
# CLUSTER 2522: trojan (5);
# CLUSTER 2523: trojan (3);
# CLUSTER 2524: trojan (6);
# CLUSTER 2528: trojan (6);
# CLUSTER 2531: trojan (2);
# CLUSTER 2534: trojan (3);
# CLUSTER 2545: trojan (2);
# CLUSTER 2547: trojan (2);
# CLUSTER 2562: adware (3);
# CLUSTER 2570: trojan (4);
# CLUSTER 2571: trojan (2);
# CLUSTER 2577: trojan (2);
# CLUSTER 2578: trojan (4);
# CLUSTER 2594: trojan (3);
# CLUSTER 2600: trojan (2);
# CLUSTER 2602: trojan (3);
# CLUSTER 2604: trojan (5);
# CLUSTER 2606: trojan (2);
# CLUSTER 2607: trojan (2);
# CLUSTER 2610: trojan (4);
# CLUSTER 2611: trojan (2);
# CLUSTER 2612: trojan (4);
# CLUSTER 2627: trojan (5);
# CLUSTER 2629: trojan (4);
# CLUSTER 2636: trojan (4);
# CLUSTER 2638: trojan (4);
# CLUSTER 2641: trojan (3);
# CLUSTER 2646: trojan (3);
# CLUSTER 2648: trojan (15);
# CLUSTER 2651: trojan (6);
# CLUSTER 2655: trojan (3);
# CLUSTER 2679: trojan (7);
# CLUSTER 2682: trojan (2);
# CLUSTER 2683: trojan (11);
# CLUSTER 2684: trojan (6);
# CLUSTER 2685: trojan (3);
# CLUSTER 2695: trojan (4);
# CLUSTER 2707: trojan (6);
# CLUSTER 2708: trojan (3);
# CLUSTER 2710: trojan (2);
# CLUSTER 2715: trojan (4);
# CLUSTER 2737: trojan (2);
# CLUSTER 2739: trojan (2);
# CLUSTER 2748: trojan (3);
# CLUSTER 2751: trojan (6);
# CLUSTER 2752: trojan (2);
# CLUSTER 2760: trojan (4);
# CLUSTER 2763: trojan (2);
# CLUSTER 2767: trojan (2);
# CLUSTER 2771: trojan (3);
# CLUSTER 2773: trojan (3);
# CLUSTER 2775: trojan (2);
# CLUSTER 2776: trojan (3);
# CLUSTER 2777: trojan (2);
# CLUSTER 2781: trojan (4);
# CLUSTER 2786: trojan (2);
# CLUSTER 2790: trojan (5);
# CLUSTER 2805: trojan (3);
# CLUSTER 2806: trojan (3);
# CLUSTER 2809: trojan (2);
# CLUSTER 2814: trojan (3);
# CLUSTER 2816: trojan (9);
# CLUSTER 2821: trojan (3);
# CLUSTER 2828: trojan (4);
# CLUSTER 2833: trojan (4);
# CLUSTER 2838: trojan (11);
# CLUSTER 2842: trojan (6);
# CLUSTER 2848: miner (4);
# CLUSTER 2852: trojan (2);
# CLUSTER 2856: trojan (2);
# CLUSTER 2859: trojan (2);
# CLUSTER 2861: trojan (4);
# CLUSTER 2863: trojan (5);
# CLUSTER 2873: trojan (4);
# CLUSTER 2876: trojan (3);
# CLUSTER 2882: trojan (2);
# CLUSTER 2886: trojan (3);
# CLUSTER 2893: trojan (3);
# CLUSTER 2895: trojan (5);
# CLUSTER 2898: trojan (2);
# CLUSTER 2902: trojan (2);
# CLUSTER 2904: trojan (6);
# CLUSTER 2910: trojan (2);
# CLUSTER 2911: trojan (6);
# CLUSTER 2912: trojan (3);
# CLUSTER 2914: trojan (2);
# CLUSTER 2929: trojan (2);
# CLUSTER 2931: trojan (2);
# CLUSTER 2932: trojan (2);
# CLUSTER 2935: trojan (2);
# CLUSTER 2950: trojan (3);
# CLUSTER 2955: trojan (2);
# CLUSTER 2958: trojan (2);
# CLUSTER 2959: pua (2);
# CLUSTER 2960: trojan (3);
# CLUSTER 2968: trojan (2);
# CLUSTER 2984: trojan (2);
# CLUSTER 2991: trojan (2);
# CLUSTER 2994: trojan (2);
# CLUSTER 3001: trojan (2);
# CLUSTER 3007: trojan (3);
# CLUSTER 3014: trojan (3);
# CLUSTER 3025: adware (2);
# CLUSTER 3034: adware (3);
# CLUSTER 3037: trojan (4);
# CLUSTER 3059: trojan (2);
# CLUSTER 3067: trojan (2);
# CLUSTER 3079: trojan (3);
# CLUSTER 3081: trojan (5);
# CLUSTER 3082: trojan (3);
# CLUSTER 3083: trojan (2);
# CLUSTER 3086: trojan (4);
# CLUSTER 3089: trojan (4);
# CLUSTER 3094: pua (2);
# CLUSTER 3101: trojan (4);
# CLUSTER 3103: trojan (2);
# CLUSTER 3104: trojan (6);
# CLUSTER 3105: trojan (4);
# CLUSTER 3114: trojan (2);
# CLUSTER 3116: trojan (2);
# CLUSTER 3119: trojan (3);
# CLUSTER 3121: trojan (3);
# CLUSTER 3127: trojan (2);
# CLUSTER 3133: trojan (2);
# CLUSTER 3134: trojan (2);
# CLUSTER 3135: trojan (2);
# CLUSTER 3145: adware (2);
# CLUSTER 3146: trojan (4);
# CLUSTER 3167: trojan (2);
# CLUSTER 3178: trojan (2);
# CLUSTER 3212: trojan (2);
# CLUSTER 3214: trojan (7);
# CLUSTER 3217: trojan (9);
# CLUSTER 3218: trojan (3);
# CLUSTER 3219: trojan (2);
# CLUSTER 3226: trojan (3);
# CLUSTER 3237: trojan (2);
# CLUSTER 3244: trojan (2);
# CLUSTER 3245: trojan (4);
# CLUSTER 3247: trojan (2);
# CLUSTER 3251: trojan (2);
# CLUSTER 3257: trojan (5);
# CLUSTER 3258: adware (2);
# CLUSTER 3262: trojan (3);
# CLUSTER 3272: trojan (3);
# CLUSTER 3288: trojan (3);
# CLUSTER 3291: trojan (3);
# CLUSTER 3292: trojan (4);
# CLUSTER 3294: trojan (4);
# CLUSTER 3295: trojan (7);
# CLUSTER 3306: trojan (2);
# CLUSTER 3317: adware (2);
# CLUSTER 3331: trojan (4);
# CLUSTER 3336: adware (2);
# CLUSTER 3341: trojan (4);
# CLUSTER 3348: trojan (3);
# CLUSTER 3363: pua (3);
# CLUSTER 3373: trojan (2);
# CLUSTER 3388: trojan (5);
# CLUSTER 3392: trojan (3);
# CLUSTER 3398: trojan (3);
# CLUSTER 3401: trojan (2);
# CLUSTER 3407: trojan (3);
# CLUSTER 3414: pua (2);
# CLUSTER 3416: trojan (2);
# CLUSTER 3424: trojan (4);
# CLUSTER 3425: trojan (10);
# CLUSTER 3429: trojan (4);
# CLUSTER 3445: trojan (4);
# CLUSTER 3450: trojan (6);
# CLUSTER 3460: trojan (2);
# CLUSTER 3464: trojan (4);
# CLUSTER 3466: trojan (2);
# CLUSTER 3475: trojan (2);
# CLUSTER 3478: trojan (2);
# CLUSTER 3485: trojan (7);
# CLUSTER 3489: adware (2);
# CLUSTER 3494: trojan (2);
# CLUSTER 3501: trojan (3);
# CLUSTER 3504: trojan (8);
# CLUSTER 3509: trojan (2);
# CLUSTER 3523: trojan (4);
# CLUSTER 3524: trojan (4);
# CLUSTER 3531: trojan (2);
# CLUSTER 3548: miner (4);
# CLUSTER 3549: trojan (2);
# CLUSTER 3552: trojan (2);
# CLUSTER 3561: trojan (2);
# CLUSTER 3564: trojan (2);
# CLUSTER 3565: adware (4);
# CLUSTER 3579: adware (6);
# CLUSTER 3582: trojan (5);
# CLUSTER 3588: trojan (2);
# CLUSTER 3593: trojan (2);
# CLUSTER 3597: trojan (2);
# CLUSTER 3601: trojan (2);
# CLUSTER 3602: trojan (2);
# CLUSTER 3628: trojan (2);
# CLUSTER 3640: trojan (3);
# CLUSTER 3646: trojan (2);
# CLUSTER 3647: miner (2);
# CLUSTER 3656: trojan (2);
# CLUSTER 3660: trojan (2);
# CLUSTER 3668: trojan (4);
# CLUSTER 3680: trojan (2);
# CLUSTER 3685: trojan (5);
# CLUSTER 3686: trojan (2);
# CLUSTER 3687: trojan (2);
# CLUSTER 3703: trojan (2);
# CLUSTER 3705: trojan (3);
# CLUSTER 3707: trojan (4);
# CLUSTER 3721: trojan (2);
# CLUSTER 3724: trojan (2);
# CLUSTER 3725: trojan (4);
# CLUSTER 3726: trojan (2);
# CLUSTER 3732: trojan (2);
# CLUSTER 3733: trojan (3);
# CLUSTER 3745: trojan (2);
# CLUSTER 3773: trojan (3);
# CLUSTER 3779: trojan (2);
# CLUSTER 3784: adware (2);
# CLUSTER 3791: trojan (9);
# CLUSTER 3797: ransomware (2);
# CLUSTER 3802: trojan (2);
# CLUSTER 3805: trojan (2);
# CLUSTER 3808: trojan (2);
# CLUSTER 3821: trojan (2);
# CLUSTER 3834: trojan (2);
# CLUSTER 3836: trojan (3);
# CLUSTER 3843: trojan (2);
# CLUSTER 3850: trojan (2);
# CLUSTER 3858: trojan (3);
# CLUSTER 3862: trojan (2);
# CLUSTER 3866: trojan (2);
# CLUSTER 3872: trojan (2);
# CLUSTER 3883: trojan (2);
# CLUSTER 3890: trojan (4);
# CLUSTER 3897: trojan (3);
# CLUSTER 3899: trojan (4);
# CLUSTER 3901: trojan (2);
# CLUSTER 3902: trojan (3);
# CLUSTER 3910: trojan (3);
# CLUSTER 3911: trojan (3);
# CLUSTER 3912: trojan (2);
# CLUSTER 3924: trojan (3);
# CLUSTER 3937: trojan (4);
# CLUSTER 3946: trojan (2);
# CLUSTER 3947: adware (2);
# CLUSTER 3948: trojan (2);
# CLUSTER 3958: trojan (2);
# CLUSTER 3969: trojan (4);
# CLUSTER 3971: trojan (2);
# CLUSTER 3975: trojan (3);
# CLUSTER 3976: trojan (4);
# CLUSTER 3980: trojan (3);
# CLUSTER 3989: trojan (2);
# CLUSTER 3997: trojan (4);
# CLUSTER 3998: trojan (2);
# CLUSTER 4002: trojan (3);
# CLUSTER 4009: virus (2);
# CLUSTER 4017: trojan (2);
# CLUSTER 4019: trojan (8);
# CLUSTER 4020: trojan (2);
# CLUSTER 4022: trojan (2);
# CLUSTER 4027: trojan (2);
# CLUSTER 4031: trojan (2);
# CLUSTER 4032: pua (2);
# CLUSTER 4037: trojan (2);
# CLUSTER 4052: trojan (2);
# CLUSTER 4060: adware (5);
# CLUSTER 4063: trojan (2);
# CLUSTER 4066: trojan (2);
# CLUSTER 4071: trojan (4);
# CLUSTER 4075: trojan (5);
# CLUSTER 4102: trojan (9);
# CLUSTER 4118: trojan (3);
# CLUSTER 4121: trojan (3);
# CLUSTER 4125: trojan (2);
# CLUSTER 4128: trojan (3);
# CLUSTER 4129: trojan (2);
# CLUSTER 4130: trojan (6);
# CLUSTER 4131: trojan (2);
# CLUSTER 4145: trojan (3);
# CLUSTER 4147: trojan (4);
# CLUSTER 4152: trojan (3);
# CLUSTER 4155: trojan (2);
# CLUSTER 4162: trojan (2);
# CLUSTER 4171: trojan (2);
# CLUSTER 4172: trojan (2);
# CLUSTER 4177: trojan (2);
# CLUSTER 4179: trojan (4);
# CLUSTER 4181: trojan (2);
# CLUSTER 4186: adware (2);
# CLUSTER 4188: trojan (3);
# CLUSTER 4189: trojan (5);
# CLUSTER 4191: trojan (3);
# CLUSTER 4199: trojan (4);
# CLUSTER 4203: trojan (2);
# CLUSTER 4208: trojan (4);
# CLUSTER 4220: trojan (3);
# CLUSTER 4226: trojan (3);
# CLUSTER 4231: trojan (2);
# CLUSTER 4254: trojan (3);
# CLUSTER 4266: trojan (2);
# CLUSTER 4269: pua (16);
# CLUSTER 4274: trojan (4);
# CLUSTER 4292: trojan (7);
# CLUSTER 4293: trojan (2);
# CLUSTER 4294: trojan (2);
# CLUSTER 4303: trojan (2);
# CLUSTER 4311: trojan (13);
# CLUSTER 4313: trojan (2);
# CLUSTER 4315: trojan (2);
# CLUSTER 4318: trojan (4);
# CLUSTER 4322: trojan (6);
# CLUSTER 4326: trojan (2);
# CLUSTER 4329: trojan (2);
# CLUSTER 4336: trojan (2);
# CLUSTER 4339: trojan (4);
# CLUSTER 4344: trojan (3);
# CLUSTER 4359: pua (2);
# CLUSTER 4361: trojan (3);
# CLUSTER 4373: trojan (3);
# CLUSTER 4374: trojan (4);
# CLUSTER 4377: trojan (3);
# CLUSTER 4381: trojan (2);
# CLUSTER 4388: trojan (3);
# CLUSTER 4391: trojan (2);
# CLUSTER 4392: trojan (3);
# CLUSTER 4402: trojan (4);
# CLUSTER 4406: trojan (3);
# CLUSTER 4412: trojan (2);
# CLUSTER 4414: trojan (2);
# CLUSTER 4420: trojan (3);
# CLUSTER 4424: trojan (5);
# CLUSTER 4429: trojan (2);
# CLUSTER 4435: trojan (2);
# CLUSTER 4447: trojan (4);
# CLUSTER 4451: trojan (3);
# CLUSTER 4472: trojan (2);
# CLUSTER 4490: trojan (2);
# CLUSTER 4491: trojan (5);
# CLUSTER 4504: trojan (2);
# CLUSTER 4512: trojan (2);
# CLUSTER 4513: trojan (2);
# CLUSTER 4522: trojan (2);
# CLUSTER 4525: trojan (6);
# CLUSTER 4528: trojan (4);
# CLUSTER 4541: pua (2);
# CLUSTER 4542: trojan (2);
# CLUSTER 4544: trojan (2);
# CLUSTER 4545: trojan (4);
# CLUSTER 4563: trojan (2);
# CLUSTER 4566: trojan (2);
# CLUSTER 4585: trojan (2);
# CLUSTER 4591: trojan (2);
# CLUSTER 4598: trojan (2);
# CLUSTER 4603: trojan (2);
# CLUSTER 4604: trojan (2);
# CLUSTER 4606: trojan (2);
# CLUSTER 4611: trojan (2);
# CLUSTER 4617: trojan (2);
# CLUSTER 4634: trojan (2);
# CLUSTER 4643: trojan (2);
# CLUSTER 4650: trojan (2);
# CLUSTER 4654: trojan (3);
# CLUSTER 4656: trojan (2);
# CLUSTER 4658: trojan (2);
# CLUSTER 4660: adware (2);
# CLUSTER 4664: trojan (4);
# CLUSTER 4678: trojan (2);
# CLUSTER 4686: trojan (2);
# CLUSTER 4688: trojan (2);
# CLUSTER 4694: trojan (2);
# CLUSTER 4696: trojan (5);
# CLUSTER 4705: trojan (2);
# CLUSTER 4711: trojan (4);
# CLUSTER 4723: trojan (2);
# CLUSTER 4729: trojan (3);
# CLUSTER 4730: trojan (3);
# CLUSTER 4734: trojan (7);
# CLUSTER 4749: trojan (5);
# CLUSTER 4761: trojan (3);
# CLUSTER 4762: trojan (4);
# CLUSTER 4770: trojan (3);
# CLUSTER 4776: trojan (2);
# CLUSTER 4779: trojan (2);
# CLUSTER 4781: trojan (4);
# CLUSTER 4783: trojan (3);
# CLUSTER 4788: trojan (4);
# CLUSTER 4794: adware (5);
# CLUSTER 4796: trojan (2);
# CLUSTER 4797: adware (2);
# CLUSTER 4801: trojan (2);
# CLUSTER 4806: pua (2);
# CLUSTER 4809: trojan (2);
# CLUSTER 4813: trojan (2);
# CLUSTER 4825: trojan (2);
# CLUSTER 4826: trojan (2);
# CLUSTER 4829: trojan (3);
# CLUSTER 4834: trojan (2);
# CLUSTER 4839: trojan (5);
# CLUSTER 4841: trojan (2);
# CLUSTER 4843: trojan (4);
# CLUSTER 4873: trojan (2);
# CLUSTER 4879: trojan (2);
# CLUSTER 4890: trojan (3);
# CLUSTER 4891: trojan (6);
# CLUSTER 4899: trojan (2);
# CLUSTER 4915: trojan (3);
# CLUSTER 4919: trojan (3);
# CLUSTER 4922: trojan (4);
# CLUSTER 4955: trojan (2);
# CLUSTER 4960: trojan (3);
# CLUSTER 4963: pua (2);
# CLUSTER 4980: trojan (3);
# CLUSTER 4981: trojan (2);
# CLUSTER 5005: trojan (2);
# CLUSTER 5008: trojan (4);
# CLUSTER 5018: trojan (2);
# CLUSTER 5025: trojan (3);
# CLUSTER 5028: trojan (3);
# CLUSTER 5031: trojan (2);
# CLUSTER 5035: trojan (2);
# CLUSTER 5037: trojan (6);
# CLUSTER 5038: trojan (7);
# CLUSTER 5044: trojan (2);
# CLUSTER 5045: trojan (2);
# CLUSTER 5048: trojan (2);
# CLUSTER 5049: trojan (2);
# CLUSTER 5058: trojan (4);
# CLUSTER 5059: trojan (2);
# CLUSTER 5069: trojan (2);
# CLUSTER 5073: trojan (2);
# CLUSTER 5075: trojan (2);
# CLUSTER 5076: trojan (2);
# CLUSTER 5077: trojan (2);
# CLUSTER 5078: trojan (2);
# CLUSTER 5083: trojan (2);
# CLUSTER 5105: trojan (2);
# CLUSTER 5112: trojan (3);
# CLUSTER 5140: trojan (3);
# CLUSTER 5143: trojan (3);
# CLUSTER 5156: trojan (2);
# CLUSTER 5164: trojan (2);
# CLUSTER 5174: trojan (2);
# CLUSTER 5190: trojan (2);
# CLUSTER 5204: adware (2);
# CLUSTER 5206: trojan (3);
# CLUSTER 5212: trojan (2);
# CLUSTER 5244: trojan (2);
# CLUSTER 5254: trojan (3);
# CLUSTER 5266: trojan (3);
# CLUSTER 5270: trojan (2);
# CLUSTER 5280: trojan (2);
# CLUSTER 5288: trojan (5);
# CLUSTER 5289: trojan (2);
# CLUSTER 5297: trojan (2);
# CLUSTER 5298: trojan (2);
# CLUSTER 5302: trojan (2);
# CLUSTER 5321: trojan (2);
# CLUSTER 5322: trojan (3);
# CLUSTER 5333: trojan (2);
# CLUSTER 5337: trojan (5);
# CLUSTER 5344: trojan (2);
# CLUSTER 5345: virus (2);
# CLUSTER 5363: trojan (2);
# CLUSTER 5366: miner (4);
# CLUSTER 5382: adware (3);
# CLUSTER 5386: trojan (3);
# CLUSTER 5387: trojan (2);
# CLUSTER 5396: trojan (3);
# CLUSTER 5400: trojan (2);
# CLUSTER 5402: trojan (3);
# CLUSTER 5403: trojan (2);
# CLUSTER 5408: trojan (2);
# CLUSTER 5412: adware (2);
# CLUSTER 5421: trojan (3);
# CLUSTER 5429: trojan (2);
# CLUSTER 5438: trojan (10);
# CLUSTER 5440: trojan (2);
# CLUSTER 5449: trojan (2);
# CLUSTER 5453: trojan (2);
# CLUSTER 5456: trojan (2);
# CLUSTER 5457: trojan (4);
# CLUSTER 5468: trojan (2);
# CLUSTER 5472: trojan (2);
# CLUSTER 5498: pua (3);
# CLUSTER 5500: trojan (2);
# CLUSTER 5503: trojan (3);
# CLUSTER 5520: trojan (3);
# CLUSTER 5539: trojan (2);
# CLUSTER 5550: trojan (2);
# CLUSTER 5559: trojan (2);
# CLUSTER 5566: trojan (4);
# CLUSTER 5567: trojan (2);
# CLUSTER 5581: adware (2);
# CLUSTER 5582: trojan (2);
# CLUSTER 5595: trojan (3);
# CLUSTER 5606: downloader (2);
# CLUSTER 5613: trojan (8);
# CLUSTER 5616: trojan (3);
# CLUSTER 5632: trojan (2);
# CLUSTER 5639: trojan (3);
# CLUSTER 5641: pua (2);
# CLUSTER 5643: trojan (9);
# CLUSTER 5651: trojan (3);
# CLUSTER 5655: trojan (2);
# CLUSTER 5659: trojan (2);
# CLUSTER 5666: trojan (2);
# CLUSTER 5674: pua (2);
# CLUSTER 5683: trojan (2);
# CLUSTER 5691: trojan (2);
# CLUSTER 5698: trojan (2);
# CLUSTER 5699: trojan (2);
# CLUSTER 5705: trojan (3);
# CLUSTER 5720: trojan (2);
# CLUSTER 5743: trojan (2);
# CLUSTER 5744: trojan (2);
# CLUSTER 5754: trojan (2);
# CLUSTER 5760: trojan (2);
# CLUSTER 5764: trojan (2);
# CLUSTER 5767: trojan (4);
# CLUSTER 5772: trojan (2);
# CLUSTER 5783: trojan (2);
# CLUSTER 5784: trojan (2);
# CLUSTER 5799: trojan (5);
# CLUSTER 5819: trojan (2);
# CLUSTER 5847: trojan (2);
# CLUSTER 5875: trojan (6);
# CLUSTER 5876: trojan (2);
# CLUSTER 5879: trojan (2);
# CLUSTER 5903: pua (2);
# CLUSTER 5907: trojan (2);
# CLUSTER 5912: adware (2);
# CLUSTER 5913: trojan (3);
# CLUSTER 5919: spyware (3);
# CLUSTER 5930: pua (2);
# CLUSTER 5939: trojan (2);
# CLUSTER 5950: trojan (2);
# CLUSTER 5957: trojan (2);
# CLUSTER 5975: trojan (2);
# CLUSTER 5976: trojan (2);
# CLUSTER 5999: trojan (2);
# CLUSTER 6000: adware (2);
# CLUSTER 6002: adware (3);
# CLUSTER 6005: trojan (2);
# CLUSTER 6007: trojan (2);
# CLUSTER 6015: trojan (4);
# CLUSTER 6027: trojan (2);
# CLUSTER 6032: trojan (5);
# CLUSTER 6036: trojan (2);
# CLUSTER 6038: trojan (2);
# CLUSTER 6041: trojan (2);
# CLUSTER 6050: trojan (3);
# CLUSTER 6054: trojan (5);
# CLUSTER 6064: trojan (2);
# CLUSTER 6070: trojan (2);
# CLUSTER 6077: trojan (2);
# CLUSTER 6099: trojan (2);
# CLUSTER 6101: trojan (2);
# CLUSTER 6105: trojan (3);
# CLUSTER 6136: trojan (4);
# CLUSTER 6139: trojan (2);
# CLUSTER 6141: trojan (2);
# CLUSTER 6142: trojan (2);
# CLUSTER 6146: trojan (2);
# CLUSTER 6149: trojan (2);
# CLUSTER 6152: trojan (2);
# CLUSTER 6153: trojan (2);
# CLUSTER 6165: trojan (2);
# CLUSTER 6168: trojan (4);
# CLUSTER 6220: trojan (3);
# CLUSTER 6233: trojan (2);
# CLUSTER 6239: trojan (2);
# CLUSTER 6241: trojan (4);
# CLUSTER 6242: trojan (2);
# CLUSTER 6243: trojan (2);
# CLUSTER 6279: trojan (2);
# CLUSTER 6288: trojan (2);
# CLUSTER 6301: trojan (2);
# CLUSTER 6319: trojan (2);
# CLUSTER 6332: adware (2);
# CLUSTER 6347: trojan (2);
# CLUSTER 6349: trojan (2);
# CLUSTER 6355: trojan (2);
# CLUSTER 6360: trojan (3);
# CLUSTER 6391: trojan (3);
# CLUSTER 6398: trojan (2);
# CLUSTER 6405: trojan (4);
# CLUSTER 6424: trojan (2);
# CLUSTER 6448: trojan (2);
# CLUSTER 6467: trojan (2);
# CLUSTER 6468: adware (3);
# CLUSTER 6469: pua (2);
# CLUSTER 6475: trojan (3);
# CLUSTER 6479: trojan (2);
# CLUSTER 6482: trojan (3);
# CLUSTER 6490: trojan (3);
# CLUSTER 6499: trojan (2);
# CLUSTER 6501: trojan (3);
# CLUSTER 6512: trojan (3);
# CLUSTER 6515: adware (2);
# CLUSTER 6537: trojan (2);
# CLUSTER 6540: trojan (2);
# CLUSTER 6541: trojan (2);
# CLUSTER 6549: adware (2);
# CLUSTER 6552: trojan (6);
# CLUSTER 6557: trojan (2);
# CLUSTER 6559: trojan (2);
# CLUSTER 6567: trojan (3);
# CLUSTER 6570: trojan (2);
# CLUSTER 6571: trojan (2);
# CLUSTER 6573: trojan (2);
# CLUSTER 6575: trojan (2);
# CLUSTER 6602: ransomware (2);
# CLUSTER 6642: trojan (3);
# CLUSTER 6663: trojan (2);
# CLUSTER 6670: trojan (3);
# CLUSTER 6687: trojan (2);
# CLUSTER 6695: trojan (2);
# CLUSTER 6700: trojan (2);
# CLUSTER 6701: trojan (2);
# CLUSTER 6703: trojan (2);
# CLUSTER 6712: trojan (3);
# CLUSTER 6716: trojan (2);
# CLUSTER 6717: trojan (2);
# CLUSTER 6737: trojan (2);
# CLUSTER 6772: trojan (2);
# CLUSTER 6797: trojan (3);
# CLUSTER 6805: trojan (2);
# CLUSTER 6821: trojan (2);
# CLUSTER 6825: trojan (2);
# CLUSTER 6838: trojan (3);
# CLUSTER 6840: trojan (2);
# CLUSTER 6850: trojan (2);
# CLUSTER 6872: trojan (2);
# CLUSTER 6891: trojan (2);
# CLUSTER 6895: pua (2);
# CLUSTER 6906: trojan (3);
# CLUSTER 6914: trojan (3);
# CLUSTER 6916: trojan (3);
# CLUSTER 6921: trojan (2);
# CLUSTER 6925: pua (2);
# CLUSTER 6931: trojan (2);
# CLUSTER 6940: trojan (2);
# CLUSTER 6943: trojan (3);
# CLUSTER 6946: trojan (2);
# CLUSTER 6961: trojan (3);
# CLUSTER 6964: adware (2);
# CLUSTER 6981: trojan (2);
# CLUSTER 7005: trojan (3);
# CLUSTER 7014: trojan (2);
# CLUSTER 7018: trojan (3);
# CLUSTER 7024: trojan (2);
# CLUSTER 7037: trojan (2);
# CLUSTER 7044: trojan (2);
# CLUSTER 7052: trojan (2);
# CLUSTER 7071: trojan (2);
# CLUSTER 7075: trojan (2);
# CLUSTER 7078: trojan (2);
# CLUSTER 7092: trojan (2);
# CLUSTER 7099: adware (8);
# CLUSTER 7146: trojan (2);
# CLUSTER 7149: trojan (2);
# CLUSTER 7156: trojan (2);
# CLUSTER 7167: adware (2);
# CLUSTER 7178: trojan (3);
# CLUSTER 7194: trojan (2);
# CLUSTER 7209: trojan (2);
# CLUSTER 7224: trojan (2);
# CLUSTER 7235: trojan (2);
# CLUSTER 7243: trojan (2);
# CLUSTER 7249: trojan (2);
# CLUSTER 7265: trojan (2);
# CLUSTER 7266: trojan (4);
# CLUSTER 7273: trojan (2);
# CLUSTER 7302: trojan (3);
# CLUSTER 7329: trojan (4);
# CLUSTER 7332: trojan (4);
# CLUSTER 7344: trojan (2);
# CLUSTER 7348: trojan (4);
# CLUSTER 7355: trojan (2);
# CLUSTER 7357: trojan (2);
# CLUSTER 7390: trojan (2);
# CLUSTER 7421: trojan (3);
# CLUSTER 7436: trojan (2);
# CLUSTER 7441: trojan (3);
# CLUSTER 7446: trojan (3);
# CLUSTER 7450: trojan (2);
# CLUSTER 7462: trojan (2);
# CLUSTER 7473: trojan (2);
# CLUSTER 7482: trojan (2);
# CLUSTER 7490: trojan (2);
# CLUSTER 7492: trojan (2);
# CLUSTER 7514: adware (2);
# CLUSTER 7532: trojan (2);
# CLUSTER 7542: pua (2);
# CLUSTER 7550: trojan (2);
# CLUSTER 7552: trojan (2);
# CLUSTER 7554: trojan (2);
# CLUSTER 7556: trojan (2);
# CLUSTER 7559: trojan (3);
# CLUSTER 7562: trojan (2);
# CLUSTER 7571: trojan (2);
# CLUSTER 7596: trojan (4);
# CLUSTER 7598: trojan (3);
# CLUSTER 7600: trojan (3);
# CLUSTER 7606: pua (2);
# CLUSTER 7621: trojan (2);
# CLUSTER 7623: trojan (3);
# CLUSTER 7635: trojan (2);
# CLUSTER 7657: adware (2);
# CLUSTER 7659: trojan (2);
# CLUSTER 7671: trojan (2);
# CLUSTER 7689: trojan (2);
# CLUSTER 7693: trojan (2);
# CLUSTER 7714: trojan (2);
# CLUSTER 7715: adware (2);
# CLUSTER 7717: trojan (2);
# CLUSTER 7729: trojan (2);
# CLUSTER 7735: trojan (2);
# CLUSTER 7761: trojan (2);
# CLUSTER 7765: trojan (2);
# CLUSTER 7772: trojan (2);
# CLUSTER 7846: trojan (3);
# CLUSTER 7865: trojan (2);
# CLUSTER 7870: trojan (2);
# CLUSTER 7874: trojan (2);
# CLUSTER 7900: trojan (2);
# CLUSTER 7933: trojan (4);
# CLUSTER 7955: trojan (2);
# CLUSTER 7961: trojan (2);
# CLUSTER 7970: trojan (2);
# CLUSTER 7972: trojan (2);
# CLUSTER 7973: trojan (2);
# CLUSTER 7992: trojan (2);
# CLUSTER 8045: trojan (2);
# CLUSTER 8101: trojan (2);
# CLUSTER 8123: trojan (2);
# CLUSTER 8150: trojan (2);
# CLUSTER 8154: trojan (2);
# CLUSTER 8161: trojan (2);
# CLUSTER 8194: trojan (3);
# CLUSTER 8209: trojan (4);
# CLUSTER 8215: trojan (3);
# CLUSTER 8242: trojan (2);
# CLUSTER 8243: trojan (2);
# CLUSTER 8247: trojan (2);
# CLUSTER 8250: trojan (2);
# CLUSTER 8278: trojan (2);
# CLUSTER 8292: trojan (2);
# CLUSTER 8333: trojan (2);
# CLUSTER 8375: trojan (2);
# CLUSTER 8422: trojan (2);
# CLUSTER 8423: trojan (2);
# CLUSTER 8427: trojan (2);
# CLUSTER 8440: trojan (3);
# CLUSTER 8459: trojan (3);
# CLUSTER 8462: trojan (2);
# CLUSTER 8492: trojan (2);
# CLUSTER 8517: trojan (2);
# CLUSTER 8527: trojan (3);
# CLUSTER 8543: trojan (2);
# CLUSTER 8544: trojan (2);
# CLUSTER 8577: trojan (2);
# CLUSTER 8624: pua (2);
# CLUSTER 8628: trojan (2);
# CLUSTER 8652: trojan (2);
# CLUSTER 8660: trojan (2);
# CLUSTER 8663: trojan (2);
# CLUSTER 8674: trojan (2);
# CLUSTER 8676: trojan (2);
# CLUSTER 8715: trojan (3);
# CLUSTER 8760: trojan (2);
# CLUSTER 8803: trojan (2);
# CLUSTER 8817: trojan (2);
# CLUSTER 8844: trojan (2);
# CLUSTER 8905: trojan (2);
# CLUSTER 8907: trojan (2);
# CLUSTER 8913: trojan (2);
# CLUSTER 8944: pua (2);
# CLUSTER 8949: pua (2);
# CLUSTER 8963: trojan (2);
# CLUSTER 8999: trojan (2);
# CLUSTER 9003: trojan (4);
# CLUSTER 9023: trojan (2);
# CLUSTER 9064: trojan (2);
# CLUSTER 9109: trojan (3);
# CLUSTER 9110: trojan (3);
# CLUSTER 9132: pua (2);
# CLUSTER 9140: trojan (3);
# CLUSTER 9146: trojan (2);
# CLUSTER 9162: adware (2);
# CLUSTER 9163: trojan (2);
# CLUSTER 9174: trojan (3);
# CLUSTER 9175: trojan (2);
# CLUSTER 9183: trojan (2);
# CLUSTER 9203: trojan (2);
# CLUSTER 9243: trojan (2);
# CLUSTER 9301: trojan (2);
# CLUSTER 9305: trojan (2);
# CLUSTER 9417: trojan (2);
# CLUSTER 9422: trojan (2);
# CLUSTER 9493: trojan (2);
# CLUSTER 9502: adware (2);
# CLUSTER 9548: trojan (2);
# CLUSTER 9573: trojan (2);
# CLUSTER 9593: trojan (2);
# CLUSTER 9616: trojan (2);
# CLUSTER 9626: trojan (2);
# CLUSTER 9677: trojan (2);
# CLUSTER 9681: pua (2);
# CLUSTER 9685: trojan (2);
# CLUSTER 9692: trojan (2);
# CLUSTER 9723: trojan (2);
# CLUSTER 9725: trojan (2);
# CLUSTER 9744: trojan (2);
# CLUSTER 9747: trojan (2);
# CLUSTER 9755: trojan (2);
# CLUSTER 9768: trojan (4);
# CLUSTER 9780: trojan (2);
# CLUSTER 9795: trojan (2);
# CLUSTER 9814: trojan (2);
# CLUSTER 9865: trojan (2);
# CLUSTER 9874: trojan (2);
# CLUSTER 9883: trojan (2);
# CLUSTER 9916: trojan (2);
# CLUSTER 9940: trojan (2);
# CLUSTER 9966: trojan (2);
# CLUSTER 10030: trojan (2);
# CLUSTER 10044: trojan (2);
# CLUSTER 10062: trojan (2);
# CLUSTER 10065: trojan (2);
# CLUSTER 10076: trojan (2);
# CLUSTER 10103: trojan (2);
# CLUSTER 10152: trojan (2);
# CLUSTER 10257: trojan (2);
# CLUSTER 10267: trojan (2);
# CLUSTER 10412: trojan (2);
# CLUSTER 10420: trojan (2);
# CLUSTER 10424: trojan (2);
# CLUSTER 10472: trojan (2);
# CLUSTER 10522: trojan (2);
# CLUSTER 10668: trojan (2);
# CLUSTER 10727: trojan (2);
# CLUSTER 10832: trojan (2);
# CLUSTER 10837: trojan (2);
# CLUSTER 10877: trojan (2);
# CLUSTER 11235: trojan (2);
# CLUSTER 11254: trojan (2);

# %% [markdown]
# ### Identify the Clusters that have the same Unique Malware Type
#
# This indicates what clusters have verified malicious samples that match specific Malware Types.
#
# This indicates the most occuring Malware Type which extends to the most 'popular' malware type that is probably found in the dataset.
#
# Such findings may also be used as a reflection as to what malware types are most prevalent in the wild.

# %%
# Summarize Clusters that have the same malware types as per VirusTotal.
str_output = f"# of Unique Malware Type: {len(malicious_df['type'].unique())}" + "\n\n"

cluster_instance_summary = [0] * len(list(malicious_df['cluster'].unique()))
count_summary = []
for i, u in enumerate(list(malicious_df['type'].unique())):
    matching = malicious_df[malicious_df['type'] == u]['cluster']
    count_summary.append([u, len(list(matching)), len(list(matching.unique())) ,str(list(matching.unique()))])
    str_output += f"Unique Malware Type: {i+1}".upper() + "\n"
    str_output += f"Malware Type: {u}" + "\n"
    str_output += f"Matching Clusters Count: {len(list(matching.unique()))}" + "\n"
    str_output += f"Matching Clusters: {list(matching.unique())}" + "\n"
    str_output += "\n"
with open("./Output/1 Clusters_on_Unique_MalwareType_woNoise.txt", 'w') as f:
    f.write(str_output)
    f.flush
    f.close()
print(str_output)

count_summary.sort(key=lambda x: x[1])
count_summary = pd.DataFrame(count_summary, columns=['Malware Type', 'No. of Matching Verified Samples', 'No. of Matching Clusters', "Matching Clusters"])

count_summary.sort_values(by='No. of Matching Clusters',ascending=False, inplace=True)
display("Top 10 Most Common Malware Type (by Cluster Count)")
display(count_summary[['Malware Type','No. of Matching Clusters', 'Matching Clusters']].iloc[0:10])
count_summary[['Malware Type','No. of Matching Clusters', 'Matching Clusters']].iloc[0:10].to_csv("./Output/1 10_Most_Common_MalwareType_byClusterCount_woNoise.csv", index=False)
# Out:
# # of Unique Malware Type: 8
#
# UNIQUE MALWARE TYPE: 1
# Malware Type: trojan
# Matching Clusters Count: 1399
# Matching Clusters: [2, 11, 14, 15, 18, 22, 23, 32, 39, 40, 41, 44, 49, 54, 56, 58, 63, 65, 67, 73, 76, 78, 80, 83, 85, 86, 89, 91, 94, 98, 100, 101, 104, 117, 124, 125, 127, 132, 137, 139, 142, 147, 151, 157, 159, 162, 172, 173, 179, 183, 188, 190, 191, 199, 201, 207, 208, 223, 232, 237, 240, 242, 247, 251, 253, 255, 258, 261, 262, 264, 275, 281, 284, 286, 287, 289, 292, 294, 303, 307, 310, 315, 316, 319, 322, 324, 325, 326, 331, 335, 338, 344, 345, 346, 347, 348, 351, 352, 353, 354, 355, 363, 366, 367, 369, 373, 376, 380, 383, 389, 390, 395, 399, 400, 403, 406, 409, 410, 413, 414, 417, 419, 421, 422, 425, 426, 427, 428, 430, 431, 432, 440, 445, 451, 453, 455, 456, 457, 459, 460, 463, 464, 469, 470, 473, 474, 484, 486, 488, 493, 495, 499, 501, 508, 512, 515, 516, 518, 532, 537, 538, 541, 545, 548, 554, 557, 559, 564, 568, 573, 576, 577, 578, 580, 584, 585, 586, 588, 593, 594, 595, 597, 599, 601, 602, 604, 609, 612, 623, 624, 625, 626, 634, 636, 639, 641, 644, 645, 655, 660, 661, 662, 664, 667, 680, 681, 684, 686, 692, 704, 705, 707, 714, 715, 720, 730, 737, 742, 752, 755, 760, 762, 763, 764, 767, 770, 773, 774, 777, 778, 779, 781, 784, 788, 792, 798, 802, 803, 804, 809, 810, 811, 813, 819, 820, 823, 826, 829, 832, 833, 838, 841, 843, 845, 855, 857, 859, 861, 866, 867, 871, 873, 881, 882, 894, 895, 899, 901, 902, 906, 908, 909, 910, 912, 913, 916, 923, 925, 926, 929, 932, 934, 946, 947, 970, 973, 975, 976, 983, 984, 985, 989, 990, 991, 997, 998, 1006, 1010, 1011, 1012, 1019, 1020, 1023, 1032, 1035, 1040, 1041, 1047, 1049, 1054, 1057, 1066, 1078, 1079, 1080, 1081, 1086, 1088, 1090, 1091, 1105, 1107, 1113, 1119, 1124, 1129, 1130, 1135, 1155, 1158, 1159, 1160, 1162, 1169, 1171, 1181, 1183, 1185, 1188, 1189, 1190, 1193, 1196, 1207, 1210, 1213, 1216, 1218, 1221, 1238, 1239, 1251, 1255, 1260, 1262, 1269, 1276, 1277, 1280, 1281, 1285, 1294, 1297, 1301, 1302, 1308, 1322, 1329, 1331, 1332, 1335, 1347, 1348, 1365, 1367, 1375, 1382, 1383, 1387, 1407, 1408, 1410, 1419, 1429, 1438, 1439, 1450, 1451, 1455, 1459, 1460, 1463, 1468, 1470, 1474, 1475, 1485, 1489, 1494, 1497, 1498, 1500, 1503, 1504, 1506, 1508, 1512, 1521, 1522, 1531, 1532, 1534, 1539, 1553, 1570, 1573, 1574, 1585, 1587, 1595, 1599, 1603, 1604, 1619, 1622, 1624, 1631, 1635, 1641, 1644, 1651, 1655, 1658, 1661, 1668, 1672, 1673, 1682, 1683, 1693, 1696, 1702, 1708, 1717, 1731, 1735, 1736, 1749, 1751, 1755, 1760, 1764, 1768, 1770, 1772, 1779, 1781, 1783, 1786, 1790, 1791, 1792, 1793, 1794, 1799, 1803, 1804, 1810, 1814, 1821, 1829, 1830, 1831, 1832, 1846, 1851, 1854, 1855, 1856, 1857, 1858, 1859, 1883, 1889, 1894, 1896, 1901, 1909, 1911, 1915, 1920, 1921, 1924, 1932, 1934, 1935, 1939, 1946, 1949, 1952, 1957, 1984, 1990, 1994, 1999, 2011, 2015, 2016, 2024, 2028, 2029, 2040, 2041, 2044, 2052, 2057, 2060, 2062, 2065, 2066, 2067, 2070, 2074, 2078, 2084, 2087, 2094, 2096, 2100, 2101, 2104, 2109, 2112, 2114, 2118, 2119, 2121, 2124, 2127, 2133, 2142, 2146, 2148, 2151, 2157, 2158, 2165, 2171, 2172, 2176, 2180, 2182, 2183, 2193, 2199, 2200, 2203, 2205, 2206, 2207, 2218, 2224, 2234, 2236, 2240, 2241, 2244, 2249, 2257, 2258, 2279, 2280, 2281, 2282, 2291, 2293, 2301, 2306, 2313, 2317, 2342, 2351, 2353, 2362, 2366, 2369, 2375, 2386, 2389, 2390, 2392, 2394, 2409, 2410, 2414, 2422, 2425, 2426, 2427, 2436, 2449, 2450, 2452, 2466, 2469, 2471, 2474, 2483, 2494, 2496, 2503, 2504, 2507, 2510, 2511, 2513, 2517, 2520, 2521, 2522, 2523, 2524, 2528, 2531, 2534, 2545, 2547, 2570, 2571, 2577, 2578, 2594, 2600, 2602, 2604, 2606, 2607, 2610, 2611, 2612, 2627, 2629, 2636, 2638, 2641, 2646, 2648, 2651, 2655, 2679, 2682, 2683, 2684, 2685, 2695, 2707, 2708, 2710, 2715, 2737, 2739, 2748, 2751, 2752, 2760, 2763, 2767, 2771, 2773, 2775, 2776, 2777, 2781, 2786, 2790, 2805, 2806, 2809, 2814, 2816, 2821, 2828, 2833, 2838, 2842, 2852, 2856, 2859, 2861, 2863, 2873, 2876, 2882, 2886, 2893, 2895, 2898, 2902, 2904, 2910, 2911, 2912, 2914, 2929, 2931, 2932, 2935, 2950, 2955, 2958, 2960, 2968, 2984, 2991, 2994, 3001, 3007, 3014, ...
#
# UNIQUE MALWARE TYPE: 2
# Malware Type: downloader
# Matching Clusters Count: 3
# Matching Clusters: [69, 733, 5606]
#
# UNIQUE MALWARE TYPE: 3
# Malware Type: miner
# Matching Clusters Count: 7
# Matching Clusters: [82, 1566, 2099, 2848, 3548, 3647, 5366]
#
# UNIQUE MALWARE TYPE: 4
# Malware Type: adware
# Matching Clusters Count: 59
# Matching Clusters: [88, 274, 565, 596, 817, 822, 921, 971, 999, 1000, 1208, 1286, 1399, 1606, 1692, 1728, 1752, 1878, 1917, 2382, 2396, 2451, 2505, 2562, 3025, 3034, 3145, 3258, 3317, 3336, 3489, 3565, 3579, 3784, 3947, 4060, 4186, 4660, 4794, 4797, 5204, 5382, 5412, 5581, 5912, 6000, 6002, 6332, 6468, 6515, 6549, 6964, 7099, 7167, 7514, 7657, 7715, 9162, 9502]
#
# UNIQUE MALWARE TYPE: 5
# Malware Type: virus
# Matching Clusters Count: 3
# Matching Clusters: [90, 4009, 5345]
#
# UNIQUE MALWARE TYPE: 6
# Malware Type: pua
# Matching Clusters Count: 35
# Matching Clusters: [259, 467, 471, 492, 571, 712, 1203, 1266, 1300, 1942, 2959, 3094, 3363, 3414, 4032, 4269, 4359, 4541, 4806, 4963, 5498, 5641, 5674, 5903, 5930, 6469, 6895, 6925, 7542, 7606, 8624, 8944, 8949, 9132, 9681]
#
# UNIQUE MALWARE TYPE: 7
# Malware Type: ransomware
# Matching Clusters Count: 5
# Matching Clusters: [361, 676, 1602, 3797, 6602]
#
# UNIQUE MALWARE TYPE: 8
# Malware Type: spyware
# Matching Clusters Count: 1
# Matching Clusters: [5919]
# 'Top 10 Most Common Malware Type (by Cluster Count)'
#   Malware Type  No. of Matching Clusters  \
# 7       trojan                      1399
# 6       adware                        59
# 5          pua                        35
# 4        miner                         7
# 3   ransomware                         5
# 1   downloader                         3
# 2        virus                         3
# 0      spyware                         1
#
#                                    Matching Clusters
# 7  [2, 11, 14, 15, 18, 22, 23, 32, 39, 40, 41, 44...
# 6  [88, 274, 565, 596, 817, 822, 921, 971, 999, 1...
# 5  [259, 467, 471, 492, 571, 712, 1203, 1266, 130...
# 4           [82, 1566, 2099, 2848, 3548, 3647, 5366]
# 3                       [361, 676, 1602, 3797, 6602]
# 1                                    [69, 733, 5606]
# 2                                   [90, 4009, 5345]
# 0                                             [5919]

# %% [markdown]
# ## "What the API Calls are in each Malware Type"

# %%
malware_types = count_summary['Malware Type'].to_list()
malware_apis = []

pd.set_option("display.max_rows", None)

print("Top 10 API CALLS PER MALWARE TYPE")
for m in malware_types:
    hashes = malicious_df[malicious_df['type'] == m]['hash'].to_list()
    complete = []
    for h in hashes:
        complete += oliveira[oliveira['hash']==h].iloc[0,1:101].to_list()
    ser = pd.Series(complete, name=m)
    ser.value_counts().to_csv(f"./Output/1_APICALL_{m}_woNoise.csv")
    malware_apis.append(ser.unique().tolist())
    display(ser.value_counts())
# Out:
# Top 10 API CALLS PER MALWARE TYPE
# trojan
# LdrGetProcedureAddress               108249
# LdrLoadDll                            65455
# LdrGetDllHandle                       44097
# NtClose                               33009
# NtAllocateVirtualMemory               32974
# RegOpenKeyExW                         32829
# LoadResource                          31330
# FindResourceExW                       29600
# RegQueryValueExW                      24298
# RegCloseKey                           19370
# NtQueryValueKey                       17638
# NtOpenKey                             14962
# GetSystemMetrics                      14251
# GetSystemTimeAsFileTime               11442
# SetErrorMode                          10113
# NtProtectVirtualMemory                 8681
# NtFreeVirtualMemory                    8099
# NtDelayExecution                       6525
# RegOpenKeyExA                          6239
# GetSystemInfo                          5981
# GetFileAttributesW                     5394
# NtOpenKeyEx                            5364
# LoadStringA                            4798
# SetUnhandledExceptionFilter            4489
# SetFilePointer                         4403
# GetCursorPos                           4249
# CoInitializeEx                         4177
# NtReadFile                             4013
# DrawTextExW                            4010
# NtCreateFile                           3712
# GetSystemDirectoryW                    3372
# NtMapViewOfSection                     3123
# FindFirstFileExW                       3081
# GetFileSize                            3058
# RegEnumKeyW                            3048
# NtQuerySystemInformation               3006
# CoCreateInstance                       2854
# RegQueryInfoKeyW                       2813
# RegEnumKeyExW                          2787
# EnumWindows                            2503
# CryptAcquireContextW                   2306
# RegQueryValueExA                       2261
# GetSystemWindowsDirectoryW             2252
# SizeofResource                         2135
# NtDeviceIoControlFile                  2001
# CreateThread                           2000
# NtQueryDirectoryFile                   1845
# NtDuplicateObject                      1828
# RegSetValueExW                         1817
# GetFileType                            1815
# FindResourceA                          1809
# RegCreateKeyExW                        1801
# CreateActCtxW                          1773
# OleInitialize                          1750
# NtCreateSection                        1738
# FindResourceW                          1615
# __exception__                          1580
# NtQueryInformationFile                 1580
# CryptCreateHash                        1530
# CryptHashData                          1530
# UuidCreate                             1472
# LoadStringW                            1451
# LdrUnloadDll                           1417
# FindResourceExA                        1396
# NtOpenDirectoryObject                  1338
# NtQueryAttributesFile                  1288
# WSAStartup                             1169
# SearchPathW                            1134
# NtCreateMutant                         1108
# GetTempPathW                           1063
# GetNativeSystemInfo                    1036
# NtOpenFile                              983
# SetWindowsHookExA                       912
# NtSetInformationFile                    828
# LookupAccountSidW                       800
# GlobalMemoryStatus                      716
# IsDebuggerPresent                       709
# GetTimeZoneInformation                  645
# NtOpenSection                           603
# NtCreateThreadEx                        601
# NtEnumerateValueKey                     578
# GetForegroundWindow                     563
# NtOpenProcess                           562
# LookupPrivilegeValueW                   551
# NtResumeThread                          550
# NtWriteFile                             537
# NtUnmapViewOfSection                    512
# NtEnumerateKey                          485
# GetFileInformationByHandle              482
# NtQueryKey                              467
# GetUserNameW                            454
# CryptDecrypt                            446
# SetEndOfFile                            383
# RegEnumKeyExA                           373
# NtOpenMutant                            359
# CreateDirectoryW                        268
# SHGetFolderPathW                        267
# GetFileVersionInfoSizeW                 238
# GetFileVersionInfoW                     186
# SetFilePointerEx                        170
# CryptEncrypt                            170
# CreateToolhelp32Snapshot                167
# CopyFileExW                             155
# Process32FirstW                         136
# GlobalMemoryStatusEx                    134
# FindWindowW                             125
# WriteConsoleA                           125
# RegCreateKeyExA                         117
# GetSystemDirectoryA                     111
# Process32NextW                          110
# SetFileAttributesW                      108
# GetShortPathNameW                       107
# GetDiskFreeSpaceExW                     102
# CreateJobObjectW                         98
# SetFileTime                              88
# GetFileSizeEx                            80
# GetDiskFreeSpaceW                        78
# ReadProcessMemory                        74
# OpenSCManagerW                           74
# select                                   72
# GetUserNameA                             71
# RegSetValueExA                           69
# NtOpenThread                             66
# GetVolumeNameForVolumeMountPointW        63
# GetComputerNameW                         62
# DeleteFileW                              62
# CreateProcessInternalW                   52
# OpenServiceW                             50
# FindWindowA                              50
# socket                                   50
# connect                                  48
# send                                     42
# WriteProcessMemory                       42
# recv                                     42
# RegEnumValueW                            41
# DeviceIoControl                          41
# SetWindowsHookExW                        39
# NtTerminateProcess                       38
# GetFileAttributesExW                     38
# timeGetTime                              34
# MoveFileWithProgressW                    33
# GetSystemWindowsDirectoryA               31
# RegEnumValueA                            31
# OpenSCManagerA                           31
# GetVolumePathNamesForVolumeNameW         24
# GetVolumePathNameW                       24
# RemoveDirectoryA                         19
# StartServiceA                            19
# CopyFileW                                18
# NtCreateKey                              18
# OpenServiceA                             16
# GetComputerNameA                         16
# CoGetClassObject                         15
# DrawTextExA                              14
# NtGetContextThread                       13
# OutputDebugStringA                       13
# CopyFileA                                13
# Module32NextW                            12
# Module32FirstW                           12
# SetStdHandle                             12
# InternetSetOptionA                       12
# NtSetContextThread                       11
# CreateServiceA                           11
# NtSuspendThread                          11
# CoUninitialize                           10
# CryptAcquireContextA                     10
# RegisterHotKey                           10
# Thread32Next                              9
# CoCreateInstanceEx                        9
# Thread32First                             9
# InternetOpenA                             8
# InternetConnectA                          8
# HttpOpenRequestA                          8
# GetAdaptersInfo                           8
# GetAdaptersAddresses                      7
# InternetOpenW                             7
# CoInitializeSecurity                      7
# GetBestInterfaceEx                        7
# StartServiceW                             6
# gethostbyname                             6
# DnsQuery_A                                6
# NtSetValueKey                             6
# MessageBoxTimeoutA                        4
# CryptProtectData                          4
# RtlAddVectoredExceptionHandler            4
# UnhookWindowsHookEx                       3
# GetAsyncKeyState                          2
# DeleteUrlCacheEntryA                      2
# InternetCrackUrlA                         2
# GetKeyState                               2
# ShellExecuteExW                           2
# RtlDecompressBuffer                       2
# InternetCloseHandle                       2
# InternetCrackUrlW                         2
# ioctlsocket                               2
# CreateServiceW                            2
# RemoveDirectoryW                          2
# Name: count, dtype: int64
# adware
# LdrGetProcedureAddress               4262
# LdrGetDllHandle                      3590
# NtAllocateVirtualMemory              1427
# NtClose                              1162
# LdrLoadDll                            738
# RegCloseKey                           653
# GetSystemTimeAsFileTime               458
# RegOpenKeyExA                         398
# NtOpenKey                             390
# NtQueryValueKey                       355
# NtFreeVirtualMemory                   327
# RegOpenKeyExW                         304
# SetErrorMode                          298
# SetUnhandledExceptionFilter           298
# GetFileAttributesW                    257
# NtCreateFile                          240
# NtReadFile                            230
# NtDelayExecution                      224
# RegSetValueExA                        219
# SHGetFolderPathW                      194
# GetSystemMetrics                      190
# NtOpenFile                            189
# RegQueryValueExA                      179
# RegQueryValueExW                      179
# RegCreateKeyExA                       176
# GetSystemWindowsDirectoryW            160
# LoadResource                          158
# SetFilePointer                        150
# NtMapViewOfSection                    140
# NtCreateMutant                        129
# CoInitializeEx                        126
# CreateThread                          107
# NtCreateSection                       102
# NtProtectVirtualMemory                 99
# socket                                 97
# GetSystemDirectoryW                    96
# ioctlsocket                            95
# select                                 93
# connect                                91
# Process32NextW                         89
# FindResourceW                          88
# Process32FirstW                        87
# CreateToolhelp32Snapshot               87
# SizeofResource                         87
# RegCreateKeyExW                        83
# FindResourceExW                        75
# WSAStartup                             68
# NtDuplicateObject                      65
# RegSetValueExW                         64
# getaddrinfo                            60
# LoadStringW                            58
# GetTimeZoneInformation                 52
# closesocket                            49
# CoCreateInstance                       47
# GetNativeSystemInfo                    41
# NtQueryInformationFile                 39
# NtWriteFile                            34
# GetFileSize                            34
# GetTempPathW                           31
# IsDebuggerPresent                      31
# NtResumeThread                         29
# WriteProcessMemory                     26
# GetFileType                            26
# GetSystemInfo                          25
# FindResourceA                          24
# LdrUnloadDll                           21
# CreateActCtxW                          20
# CoInitializeSecurity                   18
# LoadStringA                            16
# NtDeviceIoControlFile                  14
# DrawTextExW                            14
# RegEnumKeyW                            14
# FindFirstFileExW                       13
# GetCursorPos                           13
# UuidCreate                             13
# CreateDirectoryW                       12
# NtOpenMutant                           12
# GetFileVersionInfoSizeW                11
# NtCreateThreadEx                       11
# OleInitialize                          11
# GetFileVersionInfoW                    11
# NtQueryAttributesFile                  10
# NtOpenKeyEx                            10
# NtQuerySystemInformation               10
# GetComputerNameW                        9
# CoGetClassObject                        9
# FindWindowW                             9
# DeviceIoControl                         9
# GetAdaptersInfo                         9
# OutputDebugStringA                      9
# OpenSCManagerW                          9
# OpenServiceW                            9
# IWbemServices_ExecQuery                 9
# CoCreateInstanceEx                      9
# NtOpenProcess                           8
# MoveFileWithProgressW                   8
# SetWindowsHookExW                       8
# GetVolumeNameForVolumeMountPointW       7
# NtOpenSection                           7
# NtOpenDirectoryObject                   6
# DeleteFileW                             6
# NtQueryDirectoryFile                    5
# CoUninitialize                          5
# NtOpenThread                            4
# NtTerminateProcess                      3
# CopyFileW                               3
# NtUnmapViewOfSection                    3
# GetUserNameA                            2
# ShellExecuteExW                         2
# Name: count, dtype: int64
# pua
# LdrGetProcedureAddress               2074
# LdrGetDllHandle                      1196
# LdrLoadDll                            919
# NtClose                               790
# NtAllocateVirtualMemory               520
# NtOpenKey                             317
# NtQueryValueKey                       290
# NtDeviceIoControlFile                 264
# NtProtectVirtualMemory                200
# RegOpenKeyExW                         190
# GetSystemMetrics                      186
# RegCloseKey                           169
# NtFreeVirtualMemory                   168
# SetFilePointer                        161
# NtReadFile                            160
# LoadResource                          140
# SetErrorMode                          127
# FindResourceExW                       117
# NtCreateFile                          116
# NtMapViewOfSection                     92
# RegQueryValueExW                       90
# GetSystemInfo                          88
# LoadStringW                            84
# GetSystemTimeAsFileTime                73
# NtCreateSection                        62
# GetFileAttributesW                     59
# SetUnhandledExceptionFilter            56
# GetSystemWindowsDirectoryW             55
# RegOpenKeyExA                          53
# FindResourceW                          52
# GetFileSize                            51
# FindFirstFileExW                       50
# RegQueryValueExA                       41
# GetNativeSystemInfo                    34
# SizeofResource                         32
# NtCreateMutant                         31
# GetSystemDirectoryW                    30
# NtDelayExecution                       29
# IsDebuggerPresent                      28
# NtQueryAttributesFile                  28
# LoadStringA                            26
# LookupAccountSidW                      24
# CreateDirectoryW                       22
# OutputDebugStringA                     20
# NtOpenKeyEx                            20
# CoInitializeEx                         20
# GetFileType                            18
# NtDuplicateObject                      17
# NtOpenProcess                          16
# UuidCreate                             16
# NtQuerySystemInformation               15
# NtWriteFile                            13
# MoveFileWithProgressW                  13
# NtOpenMutant                           12
# SetEndOfFile                           11
# CreateProcessInternalW                 11
# NtOpenFile                             11
# CreateThread                           11
# CoCreateInstance                       11
# NtOpenDirectoryObject                  10
# LdrUnloadDll                            9
# GlobalMemoryStatusEx                    9
# SHGetFolderPathW                        9
# DeleteFileW                             9
# NtEnumerateValueKey                     8
# NtQueryInformationFile                  8
# NtEnumerateKey                          8
# CreateActCtxW                           6
# SetFileTime                             6
# GetVolumeNameForVolumeMountPointW       6
# FindResourceA                           6
# WSAStartup                              6
# RegEnumKeyW                             4
# OleInitialize                           4
# NtOpenSection                           4
# GetForegroundWindow                     4
# RegCreateKeyExA                         4
# CoUninitialize                          4
# GetTempPathW                            4
# GetTimeZoneInformation                  4
# socket                                  4
# GetCursorPos                            4
# GetDiskFreeSpaceExW                     3
# NtSetInformationFile                    3
# RemoveDirectoryW                        3
# WriteProcessMemory                      2
# NtQueryDirectoryFile                    2
# SetWindowsHookExW                       2
# GetFileVersionInfoW                     2
# GetFileVersionInfoSizeW                 2
# RegSetValueExW                          2
# RegCreateKeyExW                         2
# DrawTextExW                             2
# NtResumeThread                          2
# SetFileAttributesW                      2
# RegSetValueExA                          2
# Name: count, dtype: int64
# miner
# LdrGetProcedureAddress            236
# NtClose                           157
# LdrGetDllHandle                   144
# NtQueryAttributesFile             142
# LdrLoadDll                        112
# RegOpenKeyExW                     108
# NtCreateFile                      102
# NtMapViewOfSection                 99
# NtCreateSection                    95
# NtUnmapViewOfSection               93
# RegCloseKey                        90
# RegQueryValueExW                   82
# NtAllocateVirtualMemory            73
# GetSystemWindowsDirectoryW         56
# LdrUnloadDll                       48
# GetSystemInfo                      42
# NtQueryValueKey                    42
# NtOpenKey                          42
# GetSystemTimeAsFileTime            38
# GetSystemDirectoryW                36
# RegOpenKeyExA                      28
# WSAStartup                         27
# NtProtectVirtualMemory             25
# NtDuplicateObject                  23
# LoadStringW                        20
# NtOpenDirectoryObject              20
# NtCreateMutant                     20
# SetUnhandledExceptionFilter        20
# GetNativeSystemInfo                18
# SetErrorMode                       18
# socket                             16
# GetFileAttributesW                 12
# LoadResource                        8
# FindResourceExW                     8
# NtFreeVirtualMemory                 6
# GetSystemMetrics                    6
# GetFileType                         5
# RtlAddVectoredExceptionHandler      4
# NtDelayExecution                    4
# NtResumeThread                      4
# NtCreateThreadEx                    4
# GlobalMemoryStatusEx                4
# RegQueryValueExA                    4
# NtQuerySystemInformation            4
# NtOpenProcess                       4
# WriteProcessMemory                  4
# Thread32Next                        4
# Thread32First                       4
# CreateToolhelp32Snapshot            4
# CopyFileA                           4
# GetFileSize                         4
# CoCreateInstance                    4
# NtOpenSection                       4
# closesocket                         3
# LoadStringA                         2
# FindFirstFileExW                    2
# NtQueryKey                          2
# SetWindowsHookExA                   2
# CreateThread                        2
# SearchPathW                         2
# OleInitialize                       2
# CreateDirectoryW                    2
# Name: count, dtype: int64
# ransomware
# NtClose                       210
# NtAllocateVirtualMemory       172
# NtOpenKey                     138
# NtQuerySystemInformation      126
# RegQueryValueExW              112
# RegOpenKeyExW                 112
# NtFreeVirtualMemory           107
# RegCloseKey                   107
# NtQueryValueKey                75
# LdrGetProcedureAddress         33
# LdrLoadDll                     21
# NtCreateFile                   21
# NtEnumerateValueKey            18
# NtEnumerateKey                 18
# NtOpenFile                     17
# NtMapViewOfSection             15
# NtCreateSection                15
# CreateToolhelp32Snapshot       15
# GetSystemWindowsDirectoryW     15
# NtQueryInformationFile         15
# NtCreateMutant                 15
# Process32NextW                 13
# Process32FirstW                13
# LdrGetDllHandle                12
# NtOpenProcess                   9
# GetComputerNameW                9
# GetUserNameW                    9
# SHGetFolderPathW                9
# CreateThread                    8
# NtDelayExecution                6
# GetTempPathW                    6
# CryptAcquireContextW            6
# GetFileSize                     6
# NtDuplicateObject               6
# NtTerminateThread               6
# NtOpenMutant                    5
# Name: count, dtype: int64
# downloader
# LdrGetProcedureAddress         264
# LdrLoadDll                     140
# LdrGetDllHandle                128
# NtClose                         54
# NtReadFile                      40
# NtAllocateVirtualMemory         40
# NtWriteFile                     30
# LdrUnloadDll                    28
# NtCreateFile                    26
# GetSystemTimeAsFileTime         22
# SetFilePointer                  20
# LoadResource                    18
# RegCloseKey                     16
# FindFirstFileExW                16
# FindResourceExW                 16
# RegOpenKeyExW                   12
# SetUnhandledExceptionFilter     10
# SizeofResource                  10
# RegQueryValueExW                 8
# SetErrorMode                     8
# GetFileType                      8
# NtQueryAttributesFile            8
# NtFreeVirtualMemory              8
# RegOpenKeyExA                    8
# RegQueryValueExA                 8
# GetFileAttributesW               8
# CoInitializeEx                   6
# IsDebuggerPresent                4
# GetSystemMetrics                 4
# NtOpenKey                        4
# NtQueryValueKey                  4
# CreateDirectoryW                 4
# NtProtectVirtualMemory           4
# GetNativeSystemInfo              4
# NtOpenProcess                    4
# SHGetFolderPathW                 2
# DeleteFileW                      2
# FindResourceW                    2
# SetFilePointerEx                 2
# Name: count, dtype: int64
# virus
# NtReadFile                           196
# NtWriteFile                          190
# LdrGetProcedureAddress               105
# LdrLoadDll                            85
# NtClose                               62
# NtAllocateVirtualMemory               37
# NtCreateFile                          35
# RegCloseKey                           33
# FindResourceExW                       28
# LdrGetDllHandle                       25
# NtOpenKey                             22
# NtQueryValueKey                       22
# LoadResource                          21
# RegOpenKeyExA                         20
# RegOpenKeyExW                         18
# LoadStringA                           18
# SetFilePointer                        17
# GetSystemWindowsDirectoryW            16
# GetTempPathW                          15
# RegQueryValueExW                      14
# GetSystemMetrics                      14
# NtFreeVirtualMemory                   13
# NtQueryAttributesFile                  9
# GetFileAttributesW                     9
# NtDuplicateObject                      8
# GetTimeZoneInformation                 7
# GetSystemInfo                          7
# RegQueryValueExA                       7
# GetFileType                            7
# GetVolumeNameForVolumeMountPointW      6
# NtCreateSection                        4
# GetFileSize                            4
# LoadStringW                            4
# GetSystemDirectoryW                    4
# FindFirstFileExW                       4
# NtMapViewOfSection                     4
# NtOpenFile                             2
# NtQueryDirectoryFile                   2
# CreateDirectoryW                       2
# NtCreateMutant                         2
# GetNativeSystemInfo                    2
# Name: count, dtype: int64
# spyware
# FindResourceExW               57
# LoadResource                  48
# LdrGetProcedureAddress        39
# LdrGetDllHandle               33
# GetSystemMetrics              18
# NtAllocateVirtualMemory       15
# NtClose                       12
# LdrLoadDll                     9
# LoadStringA                    9
# NtOpenKey                      6
# DrawTextExW                    6
# RegOpenKeyExA                  6
# NtQueryValueKey                6
# RegCloseKey                    3
# GetSystemWindowsDirectoryW     3
# NtCreateFile                   3
# NtCreateSection                3
# NtMapViewOfSection             3
# RegQueryValueExA               3
# NtQueryAttributesFile          3
# NtFreeVirtualMemory            3
# GetSystemInfo                  3
# GetSystemDirectoryW            3
# CreateThread                   3
# WSAStartup                     3
# Name: count, dtype: int64

# %% [markdown]
# ## "What the Unique API Calls are in each Malware Type"

# %%
for i,m in enumerate(malware_types):
    print(i, m)
    m_list = malware_apis[i]
    for j in range(len(malware_apis)):
        if j != i:
            for k in m_list[:]:
                if k in malware_apis[j]:
                    m_list.remove(k)
    print(m_list)
    print("\n")
# Out:
# 0 trojan
# ['LookupPrivilegeValueW', 'RegEnumKeyExA', 'CryptCreateHash', 'CryptHashData', 'EnumWindows', 'RegQueryInfoKeyW', 'RegEnumKeyExW', 'FindResourceExA', 'ReadProcessMemory', 'OpenSCManagerA', 'OpenServiceA', 'StartServiceA', 'GlobalMemoryStatus', 'CryptAcquireContextA', 'CryptProtectData', 'CryptEncrypt', '__exception__', 'CryptDecrypt', 'WriteConsoleA', 'GetAdaptersAddresses', 'GetBestInterfaceEx', 'RegEnumValueW', 'GetVolumePathNamesForVolumeNameW', 'GetSystemDirectoryA', 'GetVolumePathNameW', 'StartServiceW', 'GetShortPathNameW', 'NtGetContextThread', 'GetSystemWindowsDirectoryA', 'RegEnumValueA', 'GetDiskFreeSpaceW', 'GetFileSizeEx', 'DrawTextExA', 'GetComputerNameA', 'CreateServiceW', 'DeleteUrlCacheEntryA', 'CopyFileExW', 'GetFileAttributesExW', 'RemoveDirectoryA', 'CreateServiceA', 'NtSuspendThread', 'FindWindowA', 'SetStdHandle', 'CreateJobObjectW', 'gethostbyname', 'NtSetContextThread', 'InternetOpenA', 'InternetSetOptionA', 'InternetConnectA', 'HttpOpenRequestA', 'NtCreateKey', 'NtSetValueKey', 'RegisterHotKey', 'Module32FirstW', 'Module32NextW', 'GetFileInformationByHandle', 'DnsQuery_A', 'send', 'recv', 'timeGetTime', 'InternetCrackUrlA', 'GetAsyncKeyState', 'UnhookWindowsHookEx', 'InternetOpenW', 'MessageBoxTimeoutA', 'GetKeyState', 'RtlDecompressBuffer', 'InternetCloseHandle', 'InternetCrackUrlW']
#
#
# 1 adware
# ['getaddrinfo', 'ioctlsocket', 'connect', 'select', 'FindWindowW', 'GetUserNameA', 'NtTerminateProcess', 'DeviceIoControl', 'GetAdaptersInfo', 'OpenSCManagerW', 'OpenServiceW', 'CoInitializeSecurity', 'CoCreateInstanceEx', 'CoGetClassObject', 'IWbemServices_ExecQuery', 'NtOpenThread', 'ShellExecuteExW', 'CopyFileW']
#
#
# 2 pua
# ['NtDeviceIoControlFile', 'MoveFileWithProgressW', 'LookupAccountSidW', 'UuidCreate', 'CoUninitialize', 'SetEndOfFile', 'CreateProcessInternalW', 'GetDiskFreeSpaceExW', 'NtSetInformationFile', 'FindResourceA', 'NtOpenKeyEx', 'CreateActCtxW', 'GetCursorPos', 'SetWindowsHookExW', 'RemoveDirectoryW', 'GetFileVersionInfoSizeW', 'GetFileVersionInfoW', 'SetFileTime', 'SetFileAttributesW', 'OutputDebugStringA', 'RegCreateKeyExW', 'RegSetValueExW', 'GetForegroundWindow', 'RegEnumKeyW', 'RegCreateKeyExA', 'RegSetValueExA']
#
#
# 3 miner
# ['NtOpenDirectoryObject', 'socket', 'NtUnmapViewOfSection', 'closesocket', 'RtlAddVectoredExceptionHandler', 'OleInitialize', 'SearchPathW', 'SetWindowsHookExA', 'NtOpenSection', 'NtQueryKey', 'CoCreateInstance', 'Thread32First', 'Thread32Next', 'WriteProcessMemory', 'GlobalMemoryStatusEx', 'NtCreateThreadEx', 'NtResumeThread', 'CopyFileA']
#
#
# 4 ransomware
# ['CreateToolhelp32Snapshot', 'Process32FirstW', 'Process32NextW', 'NtEnumerateKey', 'NtEnumerateValueKey', 'NtQueryInformationFile', 'GetUserNameW', 'GetComputerNameW', 'NtOpenMutant', 'NtDelayExecution', 'NtQuerySystemInformation', 'CryptAcquireContextW', 'NtTerminateThread']
#
#
# 5 downloader
# ['GetSystemTimeAsFileTime', 'SetUnhandledExceptionFilter', 'NtOpenProcess', 'NtProtectVirtualMemory', 'LdrUnloadDll', 'CoInitializeEx', 'SizeofResource', 'IsDebuggerPresent', 'SetErrorMode', 'SHGetFolderPathW', 'DeleteFileW', 'FindResourceW', 'SetFilePointerEx']
#
#
# 6 virus
# ['GetTempPathW', 'GetFileAttributesW', 'SetFilePointer', 'NtReadFile', 'NtWriteFile', 'GetFileType', 'GetTimeZoneInformation', 'FindFirstFileExW', 'CreateDirectoryW', 'NtQueryDirectoryFile', 'GetFileSize', 'NtOpenFile', 'LoadStringW', 'RegOpenKeyExW', 'RegQueryValueExW', 'NtCreateMutant', 'GetNativeSystemInfo', 'NtDuplicateObject', 'GetVolumeNameForVolumeMountPointW']
#
#
# 7 spyware
# ['RegOpenKeyExA', 'NtOpenKey', 'NtQueryValueKey', 'NtClose', 'NtQueryAttributesFile', 'LoadStringA', 'NtAllocateVirtualMemory', 'LdrGetDllHandle', 'LdrGetProcedureAddress', 'GetSystemMetrics', 'RegQueryValueExA', 'RegCloseKey', 'LdrLoadDll', 'GetSystemWindowsDirectoryW', 'NtCreateFile', 'NtCreateSection', 'NtMapViewOfSection', 'FindResourceExW', 'LoadResource', 'DrawTextExW', 'NtFreeVirtualMemory', 'GetSystemInfo', 'GetSystemDirectoryW', 'CreateThread', 'WSAStartup']

# %% [markdown]
# ## How many samples remaining?

# %%
print(f"{malicious_df.shape[0]}\n{malicious_df.shape[0]/42797*100:.4f}%")
# Out:
# 7055
# 16.4848%

# %% [markdown]
# ## What are the remaining clusters?

# %%
how_many_clusters()
# Out:
# Number of Clusters: 1512
# Number of single-item Clusters: 0
# Number of Samples Remaining: 7055
