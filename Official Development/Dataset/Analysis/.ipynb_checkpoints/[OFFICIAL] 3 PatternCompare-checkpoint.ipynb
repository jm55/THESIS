# %% [markdown]
# # Pattern Compare
#
# Aims to answer the question **Are there any key similarities or differences between malicious and benign samples in terms of API Call Patterns?** in **4.2.6. Dataset Analysis** of the study.
#
# Note that this notebook only makes use of the verified xxxx_SampleHash_Common.csv file which represents a significant majority of the entire Oliveira dataset.

# %% [markdown]
# ## Import Libraries/Datasets

# %%
import pandas as pd
# from difflib import SequenceMatcher
import Levenshtein
import matplotlib.pyplot as plt
import time

malicious_df = pd.read_csv('./Manual_DBSCAN_Encoded_Clustering.csv', low_memory=False) #This should point to a verified <DataClustering>_SampleHash_Common.csv file
benign_df = pd.read_csv('./API_Patterns_Benign.csv') #This should point to the API_Patterns.csv file

#DROP ROWS WITH NA
import numpy as nan
malicious_df.dropna(inplace=True, subset=['type'])
malicious_df['type'].unique()

#Load list of API calls
API_LIST = "../api_calls.txt"
DELIMITER = "NaN"
API_FILE = open(API_LIST,"r")
APIS = API_FILE.readline().split
# APIS.append(DELIMITER) #serves as a label for NaN values for Instance-based datasets
API_FILE.close()

# %% [markdown]
# ## DataFrame Preview

# %%
malicious_df.replace(to_replace='-',value='_', inplace=True)
malicious_df
# Out:
#                                    hash                          t_0  \
# 0      071e8c3f8922e186e57548cd4c703a5d                RegOpenKeyExA
# 1      33f8e6d08a6aae939f25a8e0d63dd523      GetSystemTimeAsFileTime
# 2      b68abd064e975e1c6d5f25e748663076  SetUnhandledExceptionFilter
# 3      72049be7bd30ea61297ea624ae198067      GetSystemTimeAsFileTime
# 4      c9b3700a77facf29172f32df6bc77f48      GetSystemTimeAsFileTime
# ...                                 ...                          ...
# 40154  e3d6d58faa040f0f9742c9d0eaf58be4      GetSystemTimeAsFileTime
# 40155  9b917bab7f32188ae40c744f2be9aaf8      GetSystemTimeAsFileTime
# 40156  35a18ee05f75f04912018d9f462cb990      GetSystemTimeAsFileTime
# 40157  654139d715abcf7ecdddbef5a84f224b      GetSystemTimeAsFileTime
# 40158  078c9d4e7be4819a06974c6f292a4857                RegOpenKeyExA
#
#                            t_1                     t_2  \
# 0                    NtOpenKey         NtQueryValueKey
# 1      NtAllocateVirtualMemory     NtFreeVirtualMemory
# 2                OleInitialize              LdrLoadDll
# 3      NtAllocateVirtualMemory     NtFreeVirtualMemory
# 4                   LdrLoadDll  LdrGetProcedureAddress
# ...                        ...                     ...
# 40154               LdrLoadDll  LdrGetProcedureAddress
# 40155               LdrLoadDll  LdrGetProcedureAddress
# 40156               LdrLoadDll  LdrGetProcedureAddress
# 40157               LdrLoadDll  LdrGetProcedureAddress
# 40158                NtOpenKey         NtQueryValueKey
#
#                            t_3                     t_4  \
# 0                      NtClose               NtOpenKey
# 1      NtAllocateVirtualMemory         LdrGetDllHandle
# 2       LdrGetProcedureAddress              LdrLoadDll
# 3      NtAllocateVirtualMemory         LdrGetDllHandle
# 4                   LdrLoadDll  LdrGetProcedureAddress
# ...                        ...                     ...
# 40154               LdrLoadDll  LdrGetProcedureAddress
# 40155               LdrLoadDll  LdrGetProcedureAddress
# 40156               LdrLoadDll  LdrGetProcedureAddress
# 40157               LdrLoadDll  LdrGetProcedureAddress
# 40158                  NtClose               NtOpenKey
#
#                           t_5                     t_6                     t_7  \
# 0             NtQueryValueKey                 NtClose   NtQueryAttributesFile
# 1      LdrGetProcedureAddress         LdrGetDllHandle  LdrGetProcedureAddress
# 2      LdrGetProcedureAddress              LdrLoadDll  LdrGetProcedureAddress
# 3      LdrGetProcedureAddress         LdrGetDllHandle  LdrGetProcedureAddress
# 4                  LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# ...                       ...                     ...                     ...
# 40154              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 40155              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 40156              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 40157              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 40158         NtQueryValueKey                 NtClose   NtQueryAttributesFile
#
#                           t_8  ...                        t_94  \
# 0                 LoadStringA  ...          NtMapViewOfSection
# 1             LdrGetDllHandle  ...  GetSystemWindowsDirectoryW
# 2                  LdrLoadDll  ...                 RegCloseKey
# 3             LdrGetDllHandle  ...        NtWriteVirtualMemory
# 4      LdrGetProcedureAddress  ...               RegEnumKeyExW
# ...                       ...  ...                         ...
# 40154  LdrGetProcedureAddress  ...               RegOpenKeyExW
# 40155  LdrGetProcedureAddress  ...            NtDelayExecution
# 40156  LdrGetProcedureAddress  ...            RegQueryValueExW
# 40157  LdrGetProcedureAddress  ...               RegOpenKeyExW
# 40158             LoadStringA  ...          NtMapViewOfSection
#
#                       t_95                     t_96                     t_97  \
# 0                  NtClose         GetSystemMetrics  NtAllocateVirtualMemory
# 1             NtCreateFile          NtCreateSection       NtMapViewOfSection
# 2            RegOpenKeyExA         RegQueryValueExA              RegCloseKey
# 3      NtFreeVirtualMemory  NtAllocateVirtualMemory     NtWriteVirtualMemory
# 4            RegOpenKeyExW         RegQueryValueExW            RegOpenKeyExW
# ...                    ...                      ...                      ...
# 40154     RegQueryValueExW            RegOpenKeyExW         RegQueryValueExW
# 40155          EnumWindows  GetSystemTimeAsFileTime         NtDelayExecution
# 40156        RegOpenKeyExW         RegQueryValueExW            RegOpenKeyExW
# 40157     RegQueryValueExW            RegOpenKeyExW         RegQueryValueExW
# 40158              NtClose         GetSystemMetrics  NtAllocateVirtualMemory
#
#                          t_98                        t_99 malware    type  \
# 0               CreateActCtxW  GetSystemWindowsDirectoryW       1  trojan
# 1                     NtClose            GetSystemMetrics       1     pua
# 2               RegEnumKeyExA               RegOpenKeyExA       1  trojan
# 3      NtProtectVirtualMemory        NtWriteVirtualMemory       1  trojan
# 4            RegQueryValueExW               RegOpenKeyExW       1  trojan
# ...                       ...                         ...     ...     ...
# 40154           RegOpenKeyExW            RegQueryValueExW       1  trojan
# 40155             EnumWindows     GetSystemTimeAsFileTime       1  trojan
# 40156        RegQueryValueExW               RegOpenKeyExW       1  trojan
# 40157           RegOpenKeyExW            RegQueryValueExW       1  trojan
# 40158           CreateActCtxW  GetSystemWindowsDirectoryW       1  trojan
#
#                                                  pattern cluster
# 0      RegOpenKeyExA,NtOpenKey,NtQueryValueKey,NtClos...       0
# 1      GetSystemTimeAsFileTime,NtAllocateVirtualMemor...       1
# 2      SetUnhandledExceptionFilter,OleInitialize,LdrL...       2
# 3      GetSystemTimeAsFileTime,NtAllocateVirtualMemor...       3
# 4      GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...       4
# ...                                                  ...     ...
# 40154  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...      17
# 40155  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...   11490
# 40156  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...   11491
# 40157  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...      17
# 40158  RegOpenKeyExA,NtOpenKey,NtQueryValueKey,NtClos...       0
#
# [40159 rows x 105 columns]

# %%
#Drop row that is falsely labelled.
malicious_df.drop(malicious_df[(malicious_df['type']=='_')].index, inplace=True)
malicious_df
# Out:
#                                    hash                          t_0  \
# 0      071e8c3f8922e186e57548cd4c703a5d                RegOpenKeyExA
# 1      33f8e6d08a6aae939f25a8e0d63dd523      GetSystemTimeAsFileTime
# 2      b68abd064e975e1c6d5f25e748663076  SetUnhandledExceptionFilter
# 3      72049be7bd30ea61297ea624ae198067      GetSystemTimeAsFileTime
# 4      c9b3700a77facf29172f32df6bc77f48      GetSystemTimeAsFileTime
# ...                                 ...                          ...
# 40154  e3d6d58faa040f0f9742c9d0eaf58be4      GetSystemTimeAsFileTime
# 40155  9b917bab7f32188ae40c744f2be9aaf8      GetSystemTimeAsFileTime
# 40156  35a18ee05f75f04912018d9f462cb990      GetSystemTimeAsFileTime
# 40157  654139d715abcf7ecdddbef5a84f224b      GetSystemTimeAsFileTime
# 40158  078c9d4e7be4819a06974c6f292a4857                RegOpenKeyExA
#
#                            t_1                     t_2  \
# 0                    NtOpenKey         NtQueryValueKey
# 1      NtAllocateVirtualMemory     NtFreeVirtualMemory
# 2                OleInitialize              LdrLoadDll
# 3      NtAllocateVirtualMemory     NtFreeVirtualMemory
# 4                   LdrLoadDll  LdrGetProcedureAddress
# ...                        ...                     ...
# 40154               LdrLoadDll  LdrGetProcedureAddress
# 40155               LdrLoadDll  LdrGetProcedureAddress
# 40156               LdrLoadDll  LdrGetProcedureAddress
# 40157               LdrLoadDll  LdrGetProcedureAddress
# 40158                NtOpenKey         NtQueryValueKey
#
#                            t_3                     t_4  \
# 0                      NtClose               NtOpenKey
# 1      NtAllocateVirtualMemory         LdrGetDllHandle
# 2       LdrGetProcedureAddress              LdrLoadDll
# 3      NtAllocateVirtualMemory         LdrGetDllHandle
# 4                   LdrLoadDll  LdrGetProcedureAddress
# ...                        ...                     ...
# 40154               LdrLoadDll  LdrGetProcedureAddress
# 40155               LdrLoadDll  LdrGetProcedureAddress
# 40156               LdrLoadDll  LdrGetProcedureAddress
# 40157               LdrLoadDll  LdrGetProcedureAddress
# 40158                  NtClose               NtOpenKey
#
#                           t_5                     t_6                     t_7  \
# 0             NtQueryValueKey                 NtClose   NtQueryAttributesFile
# 1      LdrGetProcedureAddress         LdrGetDllHandle  LdrGetProcedureAddress
# 2      LdrGetProcedureAddress              LdrLoadDll  LdrGetProcedureAddress
# 3      LdrGetProcedureAddress         LdrGetDllHandle  LdrGetProcedureAddress
# 4                  LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# ...                       ...                     ...                     ...
# 40154              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 40155              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 40156              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 40157              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 40158         NtQueryValueKey                 NtClose   NtQueryAttributesFile
#
#                           t_8  ...                        t_94  \
# 0                 LoadStringA  ...          NtMapViewOfSection
# 1             LdrGetDllHandle  ...  GetSystemWindowsDirectoryW
# 2                  LdrLoadDll  ...                 RegCloseKey
# 3             LdrGetDllHandle  ...        NtWriteVirtualMemory
# 4      LdrGetProcedureAddress  ...               RegEnumKeyExW
# ...                       ...  ...                         ...
# 40154  LdrGetProcedureAddress  ...               RegOpenKeyExW
# 40155  LdrGetProcedureAddress  ...            NtDelayExecution
# 40156  LdrGetProcedureAddress  ...            RegQueryValueExW
# 40157  LdrGetProcedureAddress  ...               RegOpenKeyExW
# 40158             LoadStringA  ...          NtMapViewOfSection
#
#                       t_95                     t_96                     t_97  \
# 0                  NtClose         GetSystemMetrics  NtAllocateVirtualMemory
# 1             NtCreateFile          NtCreateSection       NtMapViewOfSection
# 2            RegOpenKeyExA         RegQueryValueExA              RegCloseKey
# 3      NtFreeVirtualMemory  NtAllocateVirtualMemory     NtWriteVirtualMemory
# 4            RegOpenKeyExW         RegQueryValueExW            RegOpenKeyExW
# ...                    ...                      ...                      ...
# 40154     RegQueryValueExW            RegOpenKeyExW         RegQueryValueExW
# 40155          EnumWindows  GetSystemTimeAsFileTime         NtDelayExecution
# 40156        RegOpenKeyExW         RegQueryValueExW            RegOpenKeyExW
# 40157     RegQueryValueExW            RegOpenKeyExW         RegQueryValueExW
# 40158              NtClose         GetSystemMetrics  NtAllocateVirtualMemory
#
#                          t_98                        t_99 malware    type  \
# 0               CreateActCtxW  GetSystemWindowsDirectoryW       1  trojan
# 1                     NtClose            GetSystemMetrics       1     pua
# 2               RegEnumKeyExA               RegOpenKeyExA       1  trojan
# 3      NtProtectVirtualMemory        NtWriteVirtualMemory       1  trojan
# 4            RegQueryValueExW               RegOpenKeyExW       1  trojan
# ...                       ...                         ...     ...     ...
# 40154           RegOpenKeyExW            RegQueryValueExW       1  trojan
# 40155             EnumWindows     GetSystemTimeAsFileTime       1  trojan
# 40156        RegQueryValueExW               RegOpenKeyExW       1  trojan
# 40157           RegOpenKeyExW            RegQueryValueExW       1  trojan
# 40158           CreateActCtxW  GetSystemWindowsDirectoryW       1  trojan
#
#                                                  pattern cluster
# 0      RegOpenKeyExA,NtOpenKey,NtQueryValueKey,NtClos...       0
# 1      GetSystemTimeAsFileTime,NtAllocateVirtualMemor...       1
# 2      SetUnhandledExceptionFilter,OleInitialize,LdrL...       2
# 3      GetSystemTimeAsFileTime,NtAllocateVirtualMemor...       3
# 4      GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...       4
# ...                                                  ...     ...
# 40154  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...      17
# 40155  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...   11490
# 40156  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...   11491
# 40157  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...      17
# 40158  RegOpenKeyExA,NtOpenKey,NtQueryValueKey,NtClos...       0
#
# [40159 rows x 105 columns]

# %%
benign_df
# Out:
#                                   hash                          t_0  \
# 0     5b51d65972a349f90a86984c26b12b30                 SetErrorMode
# 1     ceb8cc125478fad641daa4e04e9b2f19                GetSystemInfo
# 2     f108600edf46d7c20f6acc522aeba6df      GetSystemTimeAsFileTime
# 3     711be6337cb78a948f04759a0bd210ce      GetSystemTimeAsFileTime
# 4     6de26f67ceb1e3303b889489010f4c3f                 SetErrorMode
# ...                                ...                          ...
# 1074  d282ef96a93986f89825508812958354                 SetErrorMode
# 1075  c0389d256f976044adf570f0df908953      GetSystemTimeAsFileTime
# 1076  20316e717de5db169aecbb67377504ce  SetUnhandledExceptionFilter
# 1077  ce945d424b93ea73fbbedf0254f6bc07                      NtClose
# 1078  70b78f7bdf9c484913d10365348ed2ba                 SetErrorMode
#
#                               t_1                          t_2  \
# 0                   OleInitialize              LdrGetDllHandle
# 1         NtAllocateVirtualMemory                NtOpenSection
# 2          NtProtectVirtualMemory  SetUnhandledExceptionFilter
# 3                      LdrLoadDll       LdrGetProcedureAddress
# 4                   OleInitialize              LdrGetDllHandle
# ...                           ...                          ...
# 1074                OleInitialize              LdrGetDllHandle
# 1075  SetUnhandledExceptionFilter                 GetCursorPos
# 1076               NtCreateMutant      NtAllocateVirtualMemory
# 1077                    NtOpenKey              NtQueryValueKey
# 1078              LdrGetDllHandle       LdrGetProcedureAddress
#
#                          t_3                      t_4                     t_5  \
# 0                 LdrLoadDll   LdrGetProcedureAddress              LdrLoadDll
# 1               GetTempPathW         CreateDirectoryW      GetFileAttributesW
# 2     GetTimeZoneInformation  GetSystemTimeAsFileTime  GetTimeZoneInformation
# 3                 LdrLoadDll   LdrGetProcedureAddress              LdrLoadDll
# 4                 LdrLoadDll   LdrGetProcedureAddress              LdrLoadDll
# ...                      ...                      ...                     ...
# 1074              LdrLoadDll   LdrGetProcedureAddress              LdrLoadDll
# 1075            SetErrorMode            FindResourceW       SetWindowsHookExW
# 1076                 NtClose           NtCreateMutant                 NtClose
# 1077                 NtClose                NtOpenKey         NtQueryValueKey
# 1078     GetSystemDirectoryW  NtAllocateVirtualMemory     NtFreeVirtualMemory
#
#                           t_6                     t_7  \
# 0      LdrGetProcedureAddress              LdrLoadDll
# 1            FindFirstFileExW             DeleteFileW
# 2     GetSystemTimeAsFileTime  GetTimeZoneInformation
# 3      LdrGetProcedureAddress              LdrLoadDll
# 4      LdrGetProcedureAddress              LdrLoadDll
# ...                       ...                     ...
# 1074   LdrGetProcedureAddress              LdrLoadDll
# 1075           CoInitializeEx       NtDuplicateObject
# 1076           NtCreateMutant                 NtClose
# 1077                  NtClose         LdrGetDllHandle
# 1078  NtAllocateVirtualMemory              LdrLoadDll
#
#                           t_8  ...                     t_91  \
# 0      LdrGetProcedureAddress  ...                  NtClose
# 1        NtQueryDirectoryFile  ...                  NtClose
# 2     GetSystemTimeAsFileTime  ...             SetErrorMode
# 3      LdrGetProcedureAddress  ...   LdrGetProcedureAddress
# 4      LdrGetProcedureAddress  ...                  NtClose
# ...                       ...  ...                      ...
# 1074   LdrGetProcedureAddress  ...                  NtClose
# 1075  NtAllocateVirtualMemory  ...  NtAllocateVirtualMemory
# 1076  NtAllocateVirtualMemory  ...            RegOpenKeyExW
# 1077   LdrGetProcedureAddress  ...               LdrLoadDll
# 1078      GetSystemDirectoryW  ...         RegQueryValueExW
#
#                          t_92                     t_93  \
# 0        NtQueryDirectoryFile                  NtClose
# 1              NtCreateMutant                  NtClose
# 2        GetFileAttributesExW             SetErrorMode
# 3     NtAllocateVirtualMemory   LdrGetProcedureAddress
# 4        NtQueryDirectoryFile                  NtClose
# ...                       ...                      ...
# 1074   LdrGetProcedureAddress  NtAllocateVirtualMemory
# 1075               LdrLoadDll   LdrGetProcedureAddress
# 1076         RegQueryValueExW              RegCloseKey
# 1077   LdrGetProcedureAddress               LdrLoadDll
# 1078              RegCloseKey            RegOpenKeyExW
#
#                          t_94                        t_95  \
# 0      LdrGetProcedureAddress            CoCreateInstance
# 1             LdrGetDllHandle      LdrGetProcedureAddress
# 2     NtAllocateVirtualMemory                SetErrorMode
# 3            GetSystemMetrics                  LdrLoadDll
# 4      LdrGetProcedureAddress  GetSystemWindowsDirectoryW
# ...                       ...                         ...
# 1074          LdrGetDllHandle      LdrGetProcedureAddress
# 1075  NtAllocateVirtualMemory            GetSystemMetrics
# 1076            RegOpenKeyExW            RegQueryValueExW
# 1077   LdrGetProcedureAddress                  LdrLoadDll
# 1078                  NtClose                  LdrLoadDll
#
#                         t_96                        t_97  \
# 0              NtOpenSection            CreateDirectoryW
# 1                    NtClose              NtCreateMutant
# 2       GetFileAttributesExW                SetErrorMode
# 3     LdrGetProcedureAddress            GetSystemMetrics
# 4                LoadStringW  GetSystemWindowsDirectoryW
# ...                      ...                         ...
# 1074         LdrGetDllHandle      LdrGetProcedureAddress
# 1075           RegOpenKeyExW     NtAllocateVirtualMemory
# 1076             RegCloseKey               RegOpenKeyExW
# 1077  LdrGetProcedureAddress             LdrGetDllHandle
# 1078  LdrGetProcedureAddress  GetSystemWindowsDirectoryW
#
#                          t_98                     t_99  \
# 0                NtCreateFile   LdrGetProcedureAddress
# 1                     NtClose             NtCreateFile
# 2            FindFirstFileExW     NtQueryDirectoryFile
# 3     NtAllocateVirtualMemory               LdrLoadDll
# 4         GetSystemDirectoryW            RegOpenKeyExW
# ...                       ...                      ...
# 1074          LdrGetDllHandle   LdrGetProcedureAddress
# 1075         GetSystemMetrics  NtAllocateVirtualMemory
# 1076         RegQueryValueExW              RegCloseKey
# 1077          FindResourceExW             LoadResource
# 1078             NtCreateFile          NtCreateSection
#
#                                                 pattern
# 0     SetErrorMode,OleInitialize,LdrGetDllHandle,Ldr...
# 1     GetSystemInfo,NtAllocateVirtualMemory,NtOpenSe...
# 2     GetSystemTimeAsFileTime,NtProtectVirtualMemory...
# 3     GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 4     SetErrorMode,OleInitialize,LdrGetDllHandle,Ldr...
# ...                                                 ...
# 1074  SetErrorMode,OleInitialize,LdrGetDllHandle,Ldr...
# 1075  GetSystemTimeAsFileTime,SetUnhandledExceptionF...
# 1076  SetUnhandledExceptionFilter,NtCreateMutant,NtA...
# 1077  NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOp...
# 1078  SetErrorMode,LdrGetDllHandle,LdrGetProcedureAd...
#
# [1079 rows x 102 columns]

# %% [markdown]
# ## Identify Malware Types
#
# Same as the output of `1 MalwareTypes_in_Dataset.txt`

# %%
'''Identify popular malware types in the dataset per Type as validated by VirusTotal.'''

def identify(malware_type:str):
    '''Identify and count the malware types per type'''
    print(f"{malware_type.upper()} LABEL")
    unique = list(malicious_df[malware_type].unique())
    if '_' in unique:
        unique.remove('_')
    quantities = []
    for t in unique:
        quantities.append([t, len(malicious_df[malicious_df[malware_type]==t])])
    quantities.sort(key=lambda ls: ls[1], reverse=True)
    for q in quantities:
        print(f"{q[0]:12s}: {q[1]}")
    print("")
    
'''Executes the identification for each type'''
types = ['type']
for i in types:    
    identify(i)
# Out:
# TYPE LABEL
# trojan      : 33352
# downloader  : 2249
# pua         : 2135
# adware      : 1815
# ransomware  : 341
# miner       : 125
# virus       : 79
# spyware     : 48
# hacktool    : 7
# dropper     : 5
# worm        : 3

# %% [markdown]
# ## Extract API Patterns

# %%
malicious_patterns = malicious_df['pattern'].to_list()
print("Malicious Sample API Patterns: ", len(malicious_patterns))
#display(malicious_patterns)

benign_patterns = benign_df['pattern'].to_list()
print("Benign Sample API Patterns: ", len(benign_patterns))
#display(benign_patterns)
# Out:
# Malicious Sample API Patterns:  40159
# Benign Sample API Patterns:  1079

# %% [markdown]
# ## Compare API Call Patterns
#
# **Note that this uses the full API Call Patterns (i.e., Time-based Behaviors)**
#
# Find those most similar unique malicious API call patterns that match those unique benign API call patterns.

# %%
#This code block may take a while to complete. SequenceMatcher.ratio() is deemed slow even by its documentation.
print("Comparing API Call Patterns...")
ratio = 0
ratios = []
start = time.time()

unique_malicious = list(malicious_df['pattern'].unique())
unique_benign = list(benign_df['pattern'].unique())
print(f"No. of unique malicious patterns: {len(unique_malicious)}")
print(f"No. of unique benign patterns: {len(unique_benign)}")
print("")
for m,ma in enumerate(unique_malicious): #For efficiency's sake, let's just compare it to unique malicious samples. Hashes that match the same malicious pattern will be collected in batches instead of one by one.
    mal_df = malicious_df[malicious_df['pattern']== ma]
    st = time.time()
    #if ma in unique_benign: # Only compute those that unique malicious patterns that are also in unique benign (shortens overall computation time)
    for b, be in enumerate(unique_benign): #For efficiency's sake, let's just compare it to unique benign samples. Hashes that match the same benign pattern will be collected in batches instead of one by one.
        ratios.append({'ratio': Levenshtein.seqratio(ma.split(',') , be.split(',')), #<=== SequenceMatcher.ratio() is too slow given the number of patterns to compare.
                    'benign_pattern':be, 'malicious_pattern': ma,
                    'type':mal_df['type'].to_list(), 
                    'malicious_hash':mal_df['hash'].to_list(), 
                    'benign_hash':benign_df[benign_df['pattern'] == be]['hash'].to_list()})
    print(f"Unique Mal. Pattern {m} {ma[0:30]}... @ {time.time()-st:.4f}s")
elapsed = time.time()-start
# Out:
# Comparing API Call Patterns...
# No. of unique malicious patterns: 11492
# No. of unique benign patterns: 624
#
# Unique Mal. Pattern 0 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.7870s
# Unique Mal. Pattern 1 GetSystemTimeAsFileTime,NtAllo... @ 0.6961s
# Unique Mal. Pattern 2 SetUnhandledExceptionFilter,Ol... @ 0.6656s
# Unique Mal. Pattern 3 GetSystemTimeAsFileTime,NtAllo... @ 0.6620s
# Unique Mal. Pattern 4 GetSystemTimeAsFileTime,LdrLoa... @ 0.6030s
# Unique Mal. Pattern 5 LdrGetProcedureAddress,NtAlloc... @ 0.6660s
# Unique Mal. Pattern 6 NtClose,NtOpenKey,NtQueryValue... @ 0.6250s
# Unique Mal. Pattern 7 GetSystemTimeAsFileTime,LdrLoa... @ 0.6580s
# Unique Mal. Pattern 8 GetSystemTimeAsFileTime,LdrLoa... @ 0.6820s
# Unique Mal. Pattern 9 GetSystemTimeAsFileTime,NtAllo... @ 0.6510s
# Unique Mal. Pattern 10 LdrGetDllHandle,LdrGetProcedur... @ 0.6429s
# Unique Mal. Pattern 11 GetSystemTimeAsFileTime,LdrLoa... @ 0.6960s
# Unique Mal. Pattern 12 GetSystemTimeAsFileTime,LdrGet... @ 0.6400s
# Unique Mal. Pattern 13 GetSystemTimeAsFileTime,LdrLoa... @ 0.5980s
# Unique Mal. Pattern 14 GetSystemTimeAsFileTime,LdrLoa... @ 0.6116s
# Unique Mal. Pattern 15 GetSystemTimeAsFileTime,LdrLoa... @ 0.5584s
# Unique Mal. Pattern 16 LdrGetDllHandle,LdrGetProcedur... @ 0.5679s
# Unique Mal. Pattern 17 GetSystemTimeAsFileTime,LdrLoa... @ 0.5896s
# Unique Mal. Pattern 18 GetSystemTimeAsFileTime,LdrLoa... @ 0.5552s
# Unique Mal. Pattern 19 LdrLoadDll,LdrGetProcedureAddr... @ 0.5832s
# Unique Mal. Pattern 20 GetSystemTimeAsFileTime,LdrGet... @ 0.5664s
# Unique Mal. Pattern 21 GetSystemTimeAsFileTime,GetSys... @ 0.6010s
# Unique Mal. Pattern 22 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5729s
# Unique Mal. Pattern 23 GetSystemTimeAsFileTime,NtAllo... @ 0.5501s
# Unique Mal. Pattern 24 GetSystemTimeAsFileTime,GetSys... @ 0.5687s
# Unique Mal. Pattern 25 GetSystemTimeAsFileTime,NtAllo... @ 0.5728s
# Unique Mal. Pattern 26 SetErrorMode,OleInitialize,Ldr... @ 0.5720s
# Unique Mal. Pattern 27 GetSystemTimeAsFileTime,LdrLoa... @ 0.5654s
# Unique Mal. Pattern 28 LdrLoadDll,LdrGetProcedureAddr... @ 0.5509s
# Unique Mal. Pattern 29 LdrLoadDll,LdrGetProcedureAddr... @ 0.5563s
# Unique Mal. Pattern 30 GetSystemTimeAsFileTime,LdrLoa... @ 0.5497s
# Unique Mal. Pattern 31 SetErrorMode,OleInitialize,Ldr... @ 0.7116s
# Unique Mal. Pattern 32 GetSystemTimeAsFileTime,NtAllo... @ 0.5441s
# Unique Mal. Pattern 33 GetSystemTimeAsFileTime,LdrLoa... @ 0.5531s
# Unique Mal. Pattern 34 GetSystemTimeAsFileTime,LdrLoa... @ 0.5677s
# Unique Mal. Pattern 35 GetSystemTimeAsFileTime,LdrLoa... @ 0.5675s
# Unique Mal. Pattern 36 NtClose,NtOpenKey,NtQueryValue... @ 0.6007s
# Unique Mal. Pattern 37 NtClose,NtOpenKey,NtQueryValue... @ 0.6021s
# Unique Mal. Pattern 38 GetSystemTimeAsFileTime,LdrLoa... @ 0.5721s
# Unique Mal. Pattern 39 GetSystemTimeAsFileTime,LdrLoa... @ 0.5529s
# Unique Mal. Pattern 40 NtQuerySystemInformation,GetSy... @ 0.5664s
# Unique Mal. Pattern 41 NtAllocateVirtualMemory,SetErr... @ 0.5712s
# Unique Mal. Pattern 42 GetSystemTimeAsFileTime,NtAllo... @ 0.5672s
# Unique Mal. Pattern 43 GetSystemTimeAsFileTime,LdrLoa... @ 0.5687s
# Unique Mal. Pattern 44 GetSystemTimeAsFileTime,LdrLoa... @ 0.5687s
# Unique Mal. Pattern 45 GetSystemMetrics,LdrLoadDll,Ld... @ 0.5709s
# Unique Mal. Pattern 46 GetSystemTimeAsFileTime,LdrLoa... @ 0.5542s
# Unique Mal. Pattern 47 GetSystemTimeAsFileTime,GetSys... @ 0.5834s
# Unique Mal. Pattern 48 GetSystemTimeAsFileTime,LdrLoa... @ 0.5561s
# Unique Mal. Pattern 49 GetSystemTimeAsFileTime,LdrLoa... @ 0.5665s
# Unique Mal. Pattern 50 GetSystemTimeAsFileTime,LdrGet... @ 0.5531s
# Unique Mal. Pattern 51 GetSystemTimeAsFileTime,LdrLoa... @ 0.5676s
# Unique Mal. Pattern 52 GetSystemTimeAsFileTime,LdrLoa... @ 0.5686s
# Unique Mal. Pattern 53 LdrLoadDll,LdrGetProcedureAddr... @ 0.5533s
# Unique Mal. Pattern 54 GetSystemTimeAsFileTime,LdrGet... @ 0.5684s
# Unique Mal. Pattern 55 GetSystemInfo,LdrGetDllHandle,... @ 0.5844s
# Unique Mal. Pattern 56 ReadProcessMemory,LdrLoadDll,L... @ 0.5707s
# Unique Mal. Pattern 57 GetSystemTimeAsFileTime,LdrLoa... @ 0.5710s
# Unique Mal. Pattern 58 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.6289s
# Unique Mal. Pattern 59 GetSystemTimeAsFileTime,LdrLoa... @ 0.6343s
# Unique Mal. Pattern 60 NtClose,NtOpenKey,NtQueryValue... @ 0.6389s
# Unique Mal. Pattern 61 SetErrorMode,LdrLoadDll,LdrGet... @ 0.6189s
# Unique Mal. Pattern 62 GetSystemTimeAsFileTime,LdrLoa... @ 0.6199s
# Unique Mal. Pattern 63 NtAllocateVirtualMemory,SetErr... @ 0.6437s
# Unique Mal. Pattern 64 GetSystemTimeAsFileTime,LdrLoa... @ 0.6263s
# Unique Mal. Pattern 65 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5583s
# Unique Mal. Pattern 66 GetSystemTimeAsFileTime,LdrLoa... @ 0.7273s
# Unique Mal. Pattern 67 GetSystemTimeAsFileTime,LdrGet... @ 0.5760s
# Unique Mal. Pattern 68 GetSystemTimeAsFileTime,LdrLoa... @ 0.5532s
# Unique Mal. Pattern 69 GetSystemTimeAsFileTime,NtAllo... @ 0.5663s
# Unique Mal. Pattern 70 GetSystemTimeAsFileTime,LdrLoa... @ 0.5564s
# Unique Mal. Pattern 71 GetSystemTimeAsFileTime,LdrLoa... @ 0.5519s
# Unique Mal. Pattern 72 LdrLoadDll,LdrGetProcedureAddr... @ 0.5654s
# Unique Mal. Pattern 73 GetSystemTimeAsFileTime,LdrLoa... @ 0.5709s
# Unique Mal. Pattern 74 GetSystemTimeAsFileTime,LdrLoa... @ 0.5686s
# Unique Mal. Pattern 75 GetSystemTimeAsFileTime,LdrLoa... @ 0.5689s
# Unique Mal. Pattern 76 NtAllocateVirtualMemory,SetErr... @ 0.5664s
# Unique Mal. Pattern 77 NtClose,NtOpenKey,NtQueryValue... @ 0.5720s
# Unique Mal. Pattern 78 LdrGetDllHandle,LdrGetProcedur... @ 0.5686s
# Unique Mal. Pattern 79 GetSystemTimeAsFileTime,LdrLoa... @ 0.5675s
# Unique Mal. Pattern 80 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5699s
# Unique Mal. Pattern 81 GetSystemTimeAsFileTime,LdrLoa... @ 0.5687s
# Unique Mal. Pattern 82 GetSystemTimeAsFileTime,SetUnh... @ 0.5529s
# Unique Mal. Pattern 83 GetSystemTimeAsFileTime,LdrLoa... @ 0.5535s
# Unique Mal. Pattern 84 LdrLoadDll,LdrGetProcedureAddr... @ 0.5527s
# Unique Mal. Pattern 85 GetSystemTimeAsFileTime,NtAllo... @ 0.5511s
# Unique Mal. Pattern 86 GetSystemTimeAsFileTime,NtAllo... @ 0.5550s
# Unique Mal. Pattern 87 GetSystemTimeAsFileTime,LdrLoa... @ 0.5508s
# Unique Mal. Pattern 88 GetSystemTimeAsFileTime,NtAllo... @ 0.5533s
# Unique Mal. Pattern 89 GetSystemTimeAsFileTime,LdrLoa... @ 0.5507s
# Unique Mal. Pattern 90 LdrLoadDll,LdrGetProcedureAddr... @ 0.5552s
# Unique Mal. Pattern 91 LdrLoadDll,LdrGetProcedureAddr... @ 0.5529s
# Unique Mal. Pattern 92 SetErrorMode,OleInitialize,Ldr... @ 0.5822s
# Unique Mal. Pattern 93 SetErrorMode,OleInitialize,Ldr... @ 0.5686s
# Unique Mal. Pattern 94 GetSystemTimeAsFileTime,SetUnh... @ 0.5732s
# Unique Mal. Pattern 95 LdrLoadDll,LdrGetProcedureAddr... @ 0.5495s
# Unique Mal. Pattern 96 GetSystemTimeAsFileTime,LdrLoa... @ 0.5688s
# Unique Mal. Pattern 97 SetErrorMode,OleInitialize,Ldr... @ 0.5707s
# Unique Mal. Pattern 98 LdrLoadDll,LdrGetProcedureAddr... @ 0.5678s
# Unique Mal. Pattern 99 NtClose,NtOpenKey,NtQueryValue... @ 0.5998s
# Unique Mal. Pattern 100 LdrLoadDll,LdrGetProcedureAddr... @ 0.5542s
# Unique Mal. Pattern 101 LdrLoadDll,LdrGetProcedureAddr... @ 0.7730s
# Unique Mal. Pattern 102 GetSystemTimeAsFileTime,NtAllo... @ 0.5651s
# Unique Mal. Pattern 103 GetSystemTimeAsFileTime,NtAllo... @ 0.5723s
# Unique Mal. Pattern 104 GetSystemTimeAsFileTime,LdrLoa... @ 0.5651s
# Unique Mal. Pattern 105 GetSystemTimeAsFileTime,LdrLoa... @ 0.5529s
# Unique Mal. Pattern 106 GetSystemTimeAsFileTime,LdrLoa... @ 0.5544s
# Unique Mal. Pattern 107 SetErrorMode,OleInitialize,Ldr... @ 0.5685s
# Unique Mal. Pattern 108 GetSystemTimeAsFileTime,LdrGet... @ 0.5708s
# Unique Mal. Pattern 109 GetSystemTimeAsFileTime,LdrLoa... @ 0.5698s
# Unique Mal. Pattern 110 SetErrorMode,OleInitialize,Ldr... @ 0.5821s
# Unique Mal. Pattern 111 __exception__,NtAllocateVirtua... @ 0.5710s
# Unique Mal. Pattern 112 GetSystemTimeAsFileTime,LdrLoa... @ 0.5663s
# Unique Mal. Pattern 113 NtClose,NtOpenKey,NtQueryValue... @ 0.5688s
# Unique Mal. Pattern 114 GetSystemTimeAsFileTime,LdrLoa... @ 0.5707s
# Unique Mal. Pattern 115 GetSystemTimeAsFileTime,LdrLoa... @ 0.5722s
# Unique Mal. Pattern 116 GetSystemTimeAsFileTime,LdrLoa... @ 0.5631s
# Unique Mal. Pattern 117 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5539s
# Unique Mal. Pattern 118 GetSystemTimeAsFileTime,LdrLoa... @ 0.5555s
# Unique Mal. Pattern 119 __exception__,LdrLoadDll,__exc... @ 0.5664s
# Unique Mal. Pattern 120 NtAllocateVirtualMemory,NtFree... @ 0.5687s
# Unique Mal. Pattern 121 LdrLoadDll,LdrGetProcedureAddr... @ 0.5687s
# Unique Mal. Pattern 122 GetSystemTimeAsFileTime,LdrLoa... @ 0.5544s
# Unique Mal. Pattern 123 GetSystemTimeAsFileTime,LdrLoa... @ 0.5517s
# Unique Mal. Pattern 124 GetSystemTimeAsFileTime,LdrLoa... @ 0.5562s
# Unique Mal. Pattern 125 GetSystemTimeAsFileTime,LdrLoa... @ 0.5665s
# Unique Mal. Pattern 126 GetSystemTimeAsFileTime,LdrLoa... @ 0.5519s
# Unique Mal. Pattern 127 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5528s
# Unique Mal. Pattern 128 NtAllocateVirtualMemory,SetErr... @ 0.5532s
# Unique Mal. Pattern 129 GetSystemTimeAsFileTime,LdrLoa... @ 0.5530s
# Unique Mal. Pattern 130 NtCreateFile,NtQueryInformatio... @ 0.5676s
# Unique Mal. Pattern 131 GetSystemTimeAsFileTime,NtAllo... @ 0.5397s
# Unique Mal. Pattern 132 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5663s
# Unique Mal. Pattern 133 GetSystemTimeAsFileTime,LdrLoa... @ 0.5688s
# Unique Mal. Pattern 134 LdrLoadDll,LdrGetProcedureAddr... @ 0.5687s
# Unique Mal. Pattern 135 NtDeviceIoControlFile,NtClose,... @ 0.5710s
# Unique Mal. Pattern 136 GetSystemTimeAsFileTime,LdrLoa... @ 0.5652s
# Unique Mal. Pattern 137 GetSystemTimeAsFileTime,LdrLoa... @ 0.5709s
# Unique Mal. Pattern 138 GetSystemTimeAsFileTime,LdrLoa... @ 0.5676s
# Unique Mal. Pattern 139 GetSystemTimeAsFileTime,LdrLoa... @ 0.5564s
# Unique Mal. Pattern 140 GetSystemTimeAsFileTime,LdrLoa... @ 0.5652s
# Unique Mal. Pattern 141 GetSystemTimeAsFileTime,LdrLoa... @ 0.5676s
# Unique Mal. Pattern 142 GetSystemTimeAsFileTime,LdrLoa... @ 0.5553s
# Unique Mal. Pattern 143 GetSystemTimeAsFileTime,LdrLoa... @ 0.8008s
# Unique Mal. Pattern 144 GetSystemTimeAsFileTime,LdrLoa... @ 0.5549s
# Unique Mal. Pattern 145 NtAllocateVirtualMemory,SetErr... @ 0.5530s
# Unique Mal. Pattern 146 NtClose,NtOpenKey,NtQueryValue... @ 0.5990s
# Unique Mal. Pattern 147 GetSystemTimeAsFileTime,LdrLoa... @ 0.5563s
# Unique Mal. Pattern 148 GetSystemTimeAsFileTime,NtAllo... @ 0.5564s
# Unique Mal. Pattern 149 GetSystemTimeAsFileTime,LdrGet... @ 0.5651s
# Unique Mal. Pattern 150 GetSystemTimeAsFileTime,LdrLoa... @ 0.5710s
# Unique Mal. Pattern 151 GetSystemTimeAsFileTime,NtAllo... @ 0.5518s
# Unique Mal. Pattern 152 GetSystemTimeAsFileTime,LdrGet... @ 0.5519s
# Unique Mal. Pattern 153 GetSystemTimeAsFileTime,LdrLoa... @ 0.5531s
# Unique Mal. Pattern 154 GetSystemTimeAsFileTime,LdrLoa... @ 0.5677s
# Unique Mal. Pattern 155 GetSystemTimeAsFileTime,LdrLoa... @ 0.5708s
# Unique Mal. Pattern 156 GetSystemTimeAsFileTime,NtAllo... @ 0.5496s
# Unique Mal. Pattern 157 GetSystemTimeAsFileTime,LdrLoa... @ 0.5698s
# Unique Mal. Pattern 158 GetSystemTimeAsFileTime,LdrLoa... @ 0.5686s
# Unique Mal. Pattern 159 GetSystemTimeAsFileTime,LdrLoa... @ 0.5521s
# Unique Mal. Pattern 160 GetSystemTimeAsFileTime,NtAllo... @ 0.5552s
# Unique Mal. Pattern 161 GetSystemTimeAsFileTime,LdrLoa... @ 0.5812s
# Unique Mal. Pattern 162 GetSystemTimeAsFileTime,LdrLoa... @ 0.5706s
# Unique Mal. Pattern 163 SetErrorMode,OleInitialize,Ldr... @ 0.5687s
# Unique Mal. Pattern 164 GetSystemTimeAsFileTime,LdrLoa... @ 0.5554s
# Unique Mal. Pattern 165 NtOpenKey,NtQueryValueKey,NtOp... @ 0.5809s
# Unique Mal. Pattern 166 GetSystemTimeAsFileTime,NtCrea... @ 0.5530s
# Unique Mal. Pattern 167 GetSystemTimeAsFileTime,NtAllo... @ 0.5542s
# Unique Mal. Pattern 168 GetSystemTimeAsFileTime,LdrLoa... @ 0.5675s
# Unique Mal. Pattern 169 GetSystemTimeAsFileTime,LdrLoa... @ 0.5675s
# Unique Mal. Pattern 170 NtAllocateVirtualMemory,NtFree... @ 0.5712s
# Unique Mal. Pattern 171 __exception__,NtAllocateVirtua... @ 0.5678s
# Unique Mal. Pattern 172 NtAllocateVirtualMemory,SetErr... @ 0.5684s
# Unique Mal. Pattern 173 GetSystemTimeAsFileTime,LdrGet... @ 0.5724s
# Unique Mal. Pattern 174 LdrLoadDll,LdrGetProcedureAddr... @ 0.5641s
# Unique Mal. Pattern 175 GetSystemTimeAsFileTime,LdrLoa... @ 0.5542s
# Unique Mal. Pattern 176 GetSystemTimeAsFileTime,LdrGet... @ 0.5561s
# Unique Mal. Pattern 177 GetSystemTimeAsFileTime,LdrLoa... @ 0.5643s
# Unique Mal. Pattern 178 GetSystemTimeAsFileTime,LdrGet... @ 0.5710s
# Unique Mal. Pattern 179 GetSystemTimeAsFileTime,LdrLoa... @ 0.5652s
# Unique Mal. Pattern 180 GetSystemInfo,LdrGetDllHandle,... @ 0.5699s
# Unique Mal. Pattern 181 GetSystemTimeAsFileTime,LdrLoa... @ 0.5674s
# Unique Mal. Pattern 182 GetSystemTimeAsFileTime,LdrLoa... @ 0.5711s
# Unique Mal. Pattern 183 GetSystemTimeAsFileTime,GetSys... @ 0.5715s
# Unique Mal. Pattern 184 GetSystemTimeAsFileTime,LdrGet... @ 0.5635s
# Unique Mal. Pattern 185 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5684s
# Unique Mal. Pattern 186 NtDelayExecution,NtAllocateVir... @ 0.5530s
# Unique Mal. Pattern 187 NtAllocateVirtualMemory,SetErr... @ 0.5566s
# Unique Mal. Pattern 188 RegOpenKeyExA,NtClose,NtQueryA... @ 0.5662s
# Unique Mal. Pattern 189 GetSystemTimeAsFileTime,LdrLoa... @ 0.5711s
# Unique Mal. Pattern 190 GetSystemTimeAsFileTime,LdrLoa... @ 0.5678s
# Unique Mal. Pattern 191 GetSystemTimeAsFileTime,NtAllo... @ 0.5550s
# Unique Mal. Pattern 192 CreateThread,NtClose,NtDelayEx... @ 0.5655s
# Unique Mal. Pattern 193 LdrGetProcedureAddress,NtAlloc... @ 0.5562s
# Unique Mal. Pattern 194 NtDelayExecution,NtAllocateVir... @ 0.5666s
# Unique Mal. Pattern 195 GetSystemTimeAsFileTime,LdrLoa... @ 0.8520s
# Unique Mal. Pattern 196 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5552s
# Unique Mal. Pattern 197 GetSystemTimeAsFileTime,LdrLoa... @ 0.5529s
# Unique Mal. Pattern 198 LdrLoadDll,LdrGetProcedureAddr... @ 0.5509s
# Unique Mal. Pattern 199 GetSystemTimeAsFileTime,LdrLoa... @ 0.5685s
# Unique Mal. Pattern 200 GetSystemTimeAsFileTime,LdrLoa... @ 0.5711s
# Unique Mal. Pattern 201 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5653s
# Unique Mal. Pattern 202 GetSystemTimeAsFileTime,GetSys... @ 0.5564s
# Unique Mal. Pattern 203 GetSystemTimeAsFileTime,LdrLoa... @ 0.5528s
# Unique Mal. Pattern 204 GetSystemTimeAsFileTime,LdrLoa... @ 0.5511s
# Unique Mal. Pattern 205 GetSystemTimeAsFileTime,LdrGet... @ 0.5552s
# Unique Mal. Pattern 206 GetSystemTimeAsFileTime,LdrLoa... @ 0.5516s
# Unique Mal. Pattern 207 NtAllocateVirtualMemory,LdrLoa... @ 0.5685s
# Unique Mal. Pattern 208 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5676s
# Unique Mal. Pattern 209 GetSystemTimeAsFileTime,NtAllo... @ 0.5709s
# Unique Mal. Pattern 210 GetSystemTimeAsFileTime,LdrLoa... @ 0.5553s
# Unique Mal. Pattern 211 GetSystemTimeAsFileTime,LdrLoa... @ 0.5498s
# Unique Mal. Pattern 212 GetSystemTimeAsFileTime,LdrLoa... @ 0.5517s
# Unique Mal. Pattern 213 GetSystemInfo,LdrGetDllHandle,... @ 0.5713s
# Unique Mal. Pattern 214 GetSystemTimeAsFileTime,LdrLoa... @ 0.5650s
# Unique Mal. Pattern 215 GetSystemTimeAsFileTime,LdrLoa... @ 0.5679s
# Unique Mal. Pattern 216 GetSystemTimeAsFileTime,LdrLoa... @ 0.5685s
# Unique Mal. Pattern 217 GetSystemTimeAsFileTime,NtAllo... @ 0.5701s
# Unique Mal. Pattern 218 GetSystemTimeAsFileTime,LdrLoa... @ 0.5528s
# Unique Mal. Pattern 219 GetSystemTimeAsFileTime,NtAllo... @ 0.5730s
# Unique Mal. Pattern 220 GetSystemTimeAsFileTime,LdrGet... @ 0.5617s
# Unique Mal. Pattern 221 GetSystemTimeAsFileTime,LdrLoa... @ 0.5745s
# Unique Mal. Pattern 222 SetErrorMode,LdrGetDllHandle,L... @ 0.5654s
# Unique Mal. Pattern 223 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5528s
# Unique Mal. Pattern 224 GetSystemTimeAsFileTime,LdrLoa... @ 0.5522s
# Unique Mal. Pattern 225 GetSystemTimeAsFileTime,LdrLoa... @ 0.5562s
# Unique Mal. Pattern 226 GetSystemTimeAsFileTime,LdrLoa... @ 0.5687s
# Unique Mal. Pattern 227 GetSystemTimeAsFileTime,LdrLoa... @ 0.5656s
# Unique Mal. Pattern 228 GetSystemTimeAsFileTime,LdrLoa... @ 0.5551s
# Unique Mal. Pattern 229 SetUnhandledExceptionFilter,Nt... @ 0.5667s
# Unique Mal. Pattern 230 NtClose,NtOpenKey,NtQueryValue... @ 0.5551s
# Unique Mal. Pattern 231 GetSystemTimeAsFileTime,LdrLoa... @ 0.5677s
# Unique Mal. Pattern 232 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5663s
# Unique Mal. Pattern 233 NtAllocateVirtualMemory,LoadSt... @ 0.5710s
# Unique Mal. Pattern 234 GetSystemTimeAsFileTime,NtAllo... @ 0.5687s
# Unique Mal. Pattern 235 __exception__,LdrLoadDll,__exc... @ 0.5518s
# Unique Mal. Pattern 236 GetSystemTimeAsFileTime,LdrLoa... @ 0.5685s
# Unique Mal. Pattern 237 RegOpenKeyExA,NtClose,NtQueryA... @ 0.5563s
# Unique Mal. Pattern 238 GetSystemTimeAsFileTime,LdrGet... @ 0.5523s
# Unique Mal. Pattern 239 SetErrorMode,OleInitialize,Ldr... @ 0.5541s
# Unique Mal. Pattern 240 GetSystemTimeAsFileTime,LdrLoa... @ 0.5543s
# Unique Mal. Pattern 241 GetSystemTimeAsFileTime,LdrLoa... @ 0.5663s
# Unique Mal. Pattern 242 GetSystemTimeAsFileTime,LdrLoa... @ 0.5732s
# Unique Mal. Pattern 243 LdrLoadDll,LdrGetProcedureAddr... @ 0.5519s
# Unique Mal. Pattern 244 GetSystemTimeAsFileTime,LdrLoa... @ 0.5654s
# Unique Mal. Pattern 245 __exception__,NtAllocateVirtua... @ 0.5699s
# Unique Mal. Pattern 246 SetUnhandledExceptionFilter,Nt... @ 0.5673s
# Unique Mal. Pattern 247 GetSystemTimeAsFileTime,LdrLoa... @ 0.5690s
# Unique Mal. Pattern 248 SetErrorMode,OleInitialize,Ldr... @ 0.5529s
# Unique Mal. Pattern 249 GetSystemTimeAsFileTime,LdrLoa... @ 0.5552s
# Unique Mal. Pattern 250 GetSystemTimeAsFileTime,LdrLoa... @ 0.5818s
# Unique Mal. Pattern 251 NtAllocateVirtualMemory,SetErr... @ 0.5690s
# Unique Mal. Pattern 252 GetSystemTimeAsFileTime,LdrLoa... @ 0.5530s
# Unique Mal. Pattern 253 GetSystemTimeAsFileTime,LdrLoa... @ 0.5540s
# Unique Mal. Pattern 254 SetErrorMode,OleInitialize,Ldr... @ 0.5676s
# Unique Mal. Pattern 255 LdrLoadDll,LdrGetProcedureAddr... @ 0.5555s
# Unique Mal. Pattern 256 GetSystemTimeAsFileTime,LdrLoa... @ 0.5685s
# Unique Mal. Pattern 257 GetSystemTimeAsFileTime,LdrLoa... @ 0.5667s
# Unique Mal. Pattern 258 GetSystemTimeAsFileTime,LdrLoa... @ 0.5697s
# Unique Mal. Pattern 259 GetSystemTimeAsFileTime,LdrGet... @ 0.5675s
# Unique Mal. Pattern 260 GetSystemTimeAsFileTime,NtAllo... @ 0.8809s
# Unique Mal. Pattern 261 GetSystemTimeAsFileTime,LdrGet... @ 0.5573s
# Unique Mal. Pattern 262 NtAllocateVirtualMemory,NtFree... @ 0.5532s
# Unique Mal. Pattern 263 GetSystemTimeAsFileTime,LdrLoa... @ 0.5554s
# Unique Mal. Pattern 264 GetSystemTimeAsFileTime,RegOpe... @ 0.5507s
# Unique Mal. Pattern 265 GetSystemTimeAsFileTime,LdrLoa... @ 0.5551s
# Unique Mal. Pattern 266 GetSystemTimeAsFileTime,SetUnh... @ 0.5666s
# Unique Mal. Pattern 267 __exception__,NtAllocateVirtua... @ 0.5686s
# Unique Mal. Pattern 268 __exception__,NtAllocateVirtua... @ 0.5699s
# Unique Mal. Pattern 269 GetSystemTimeAsFileTime,LdrLoa... @ 0.5684s
# Unique Mal. Pattern 270 NtAllocateVirtualMemory,NtFree... @ 0.5689s
# Unique Mal. Pattern 271 GetSystemTimeAsFileTime,LdrLoa... @ 0.5530s
# Unique Mal. Pattern 272 GetSystemTimeAsFileTime,LdrLoa... @ 0.5841s
# Unique Mal. Pattern 273 GetSystemTimeAsFileTime,LdrLoa... @ 0.5553s
# Unique Mal. Pattern 274 GetSystemTimeAsFileTime,NtAllo... @ 0.5529s
# Unique Mal. Pattern 275 GetSystemTimeAsFileTime,NtAllo... @ 0.5532s
# Unique Mal. Pattern 276 GetSystemTimeAsFileTime,NtAllo... @ 0.5807s
# Unique Mal. Pattern 277 GetSystemTimeAsFileTime,LdrLoa... @ 0.5701s
# Unique Mal. Pattern 278 GetSystemTimeAsFileTime,LdrLoa... @ 0.5707s
# Unique Mal. Pattern 279 GetSystemTimeAsFileTime,LdrGet... @ 0.5677s
# Unique Mal. Pattern 280 NtProtectVirtualMemory,LdrLoad... @ 0.5708s
# Unique Mal. Pattern 281 OleInitialize,LdrLoadDll,LdrGe... @ 0.5644s
# Unique Mal. Pattern 282 GetSystemInfo,LdrGetDllHandle,... @ 0.5552s
# Unique Mal. Pattern 283 GetSystemTimeAsFileTime,LdrLoa... @ 0.5539s
# Unique Mal. Pattern 284 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5509s
# Unique Mal. Pattern 285 GetSystemTimeAsFileTime,SetUnh... @ 0.5708s
# Unique Mal. Pattern 286 NtAllocateVirtualMemory,SetErr... @ 0.5654s
# Unique Mal. Pattern 287 GetSystemTimeAsFileTime,LdrLoa... @ 0.5711s
# Unique Mal. Pattern 288 GetSystemTimeAsFileTime,LdrLoa... @ 0.5675s
# Unique Mal. Pattern 289 GetSystemTimeAsFileTime,LdrGet... @ 0.5522s
# Unique Mal. Pattern 290 GetSystemTimeAsFileTime,LdrLoa... @ 0.5550s
# Unique Mal. Pattern 291 GetSystemTimeAsFileTime,LdrGet... @ 0.5686s
# Unique Mal. Pattern 292 GetSystemTimeAsFileTime,NtAllo... @ 0.5508s
# Unique Mal. Pattern 293 GetSystemTimeAsFileTime,LdrGet... @ 0.5531s
# Unique Mal. Pattern 294 NtAllocateVirtualMemory,SetErr... @ 0.5679s
# Unique Mal. Pattern 295 GetSystemTimeAsFileTime,NtAllo... @ 0.5530s
# Unique Mal. Pattern 296 GetSystemTimeAsFileTime,NtCrea... @ 0.5516s
# Unique Mal. Pattern 297 GetSystemTimeAsFileTime,LdrLoa... @ 0.5567s
# Unique Mal. Pattern 298 GetSystemTimeAsFileTime,LdrLoa... @ 0.5505s
# Unique Mal. Pattern 299 GetSystemTimeAsFileTime,LdrGet... @ 0.5684s
# Unique Mal. Pattern 300 GetSystemTimeAsFileTime,LdrLoa... @ 0.5524s
# Unique Mal. Pattern 301 GetSystemTimeAsFileTime,LdrLoa... @ 0.5675s
# Unique Mal. Pattern 302 GetSystemTimeAsFileTime,LdrLoa... @ 0.5696s
# Unique Mal. Pattern 303 GetSystemTimeAsFileTime,LdrLoa... @ 0.5677s
# Unique Mal. Pattern 304 GetSystemTimeAsFileTime,NtAllo... @ 0.5720s
# Unique Mal. Pattern 305 GetSystemTimeAsFileTime,LdrLoa... @ 0.5529s
# Unique Mal. Pattern 306 GetSystemTimeAsFileTime,LdrLoa... @ 0.5656s
# Unique Mal. Pattern 307 GetSystemTimeAsFileTime,LdrLoa... @ 0.5684s
# Unique Mal. Pattern 308 GetSystemTimeAsFileTime,LdrLoa... @ 0.5664s
# Unique Mal. Pattern 309 GetSystemTimeAsFileTime,LdrLoa... @ 0.5555s
# Unique Mal. Pattern 310 GetFileSize,GetNativeSystemInf... @ 0.5540s
# Unique Mal. Pattern 311 GetSystemTimeAsFileTime,LdrLoa... @ 0.5666s
# Unique Mal. Pattern 312 SetErrorMode,OleInitialize,Ldr... @ 0.5710s
# Unique Mal. Pattern 313 GetSystemTimeAsFileTime,LdrLoa... @ 0.5528s
# Unique Mal. Pattern 314 SetErrorMode,OleInitialize,Ldr... @ 0.5667s
# Unique Mal. Pattern 315 GetSystemTimeAsFileTime,LdrLoa... @ 0.5683s
# Unique Mal. Pattern 316 LdrLoadDll,LdrGetProcedureAddr... @ 0.5543s
# Unique Mal. Pattern 317 GetSystemTimeAsFileTime,LdrLoa... @ 0.5673s
# Unique Mal. Pattern 318 GetSystemTimeAsFileTime,LdrGet... @ 0.5556s
# Unique Mal. Pattern 319 GetSystemTimeAsFileTime,LdrLoa... @ 0.5517s
# Unique Mal. Pattern 320 GetSystemTimeAsFileTime,LdrLoa... @ 0.5554s
# Unique Mal. Pattern 321 GetSystemTimeAsFileTime,LdrLoa... @ 0.5553s
# Unique Mal. Pattern 322 GetSystemTimeAsFileTime,LdrLoa... @ 0.5641s
# Unique Mal. Pattern 323 NtAllocateVirtualMemory,NtFree... @ 0.5566s
# Unique Mal. Pattern 324 LdrLoadDll,LdrGetProcedureAddr... @ 0.5509s
# Unique Mal. Pattern 325 GetSystemTimeAsFileTime,LdrLoa... @ 0.5520s
# Unique Mal. Pattern 326 GetSystemTimeAsFileTime,LdrLoa... @ 0.5530s
# Unique Mal. Pattern 327 GetSystemTimeAsFileTime,LdrLoa... @ 0.5528s
# Unique Mal. Pattern 328 SetErrorMode,OleInitialize,Ldr... @ 0.5531s
# Unique Mal. Pattern 329 NtAllocateVirtualMemory,SetErr... @ 0.5546s
# Unique Mal. Pattern 330 GetSystemTimeAsFileTime,LdrLoa... @ 0.5495s
# Unique Mal. Pattern 331 GetSystemTimeAsFileTime,LdrLoa... @ 0.5683s
# Unique Mal. Pattern 332 GetSystemTimeAsFileTime,NtAllo... @ 0.5534s
# Unique Mal. Pattern 333 GetSystemTimeAsFileTime,LdrLoa... @ 0.5675s
# Unique Mal. Pattern 334 GetSystemTimeAsFileTime,LdrLoa... @ 0.5729s
# Unique Mal. Pattern 335 GetSystemTimeAsFileTime,NtAllo... @ 0.5500s
# Unique Mal. Pattern 336 GetSystemTimeAsFileTime,LdrLoa... @ 0.5676s
# Unique Mal. Pattern 337 LdrLoadDll,LdrGetProcedureAddr... @ 0.5694s
# Unique Mal. Pattern 338 NtAllocateVirtualMemory,SetErr... @ 0.5677s
# Unique Mal. Pattern 339 GetSystemTimeAsFileTime,LdrLoa... @ 0.5677s
# Unique Mal. Pattern 340 GetSystemTimeAsFileTime,NtAllo... @ 0.5530s
# Unique Mal. Pattern 341 NtDelayExecution,NtClose,NtDel... @ 0.9302s
# Unique Mal. Pattern 342 GetSystemTimeAsFileTime,LdrLoa... @ 0.5450s
# Unique Mal. Pattern 343 GetSystemTimeAsFileTime,LdrGet... @ 0.5551s
# Unique Mal. Pattern 344 GetSystemTimeAsFileTime,LdrLoa... @ 0.5631s
# Unique Mal. Pattern 345 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5575s
# Unique Mal. Pattern 346 GetSystemTimeAsFileTime,LdrLoa... @ 0.5507s
# Unique Mal. Pattern 347 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5711s
# Unique Mal. Pattern 348 NtAllocateVirtualMemory,SetErr... @ 0.5663s
# Unique Mal. Pattern 349 LdrLoadDll,LdrGetProcedureAddr... @ 0.5555s
# Unique Mal. Pattern 350 GetSystemTimeAsFileTime,NtAllo... @ 0.5505s
# Unique Mal. Pattern 351 GetSystemTimeAsFileTime,LdrLoa... @ 0.5575s
# Unique Mal. Pattern 352 GetSystemTimeAsFileTime,LdrLoa... @ 0.5500s
# Unique Mal. Pattern 353 FindResourceExW,LoadResource,F... @ 0.5662s
# Unique Mal. Pattern 354 GetSystemTimeAsFileTime,LdrLoa... @ 0.5530s
# Unique Mal. Pattern 355 GetSystemTimeAsFileTime,LdrLoa... @ 0.5685s
# Unique Mal. Pattern 356 LdrLoadDll,LdrGetProcedureAddr... @ 0.5690s
# Unique Mal. Pattern 357 GetSystemTimeAsFileTime,NtAllo... @ 0.5672s
# Unique Mal. Pattern 358 GetSystemTimeAsFileTime,LdrLoa... @ 0.5699s
# Unique Mal. Pattern 359 GetSystemTimeAsFileTime,SetUnh... @ 0.5687s
# Unique Mal. Pattern 360 GetSystemTimeAsFileTime,LdrLoa... @ 0.5530s
# Unique Mal. Pattern 361 NtClose,CreateToolhelp32Snapsh... @ 0.5554s
# Unique Mal. Pattern 362 GetSystemTimeAsFileTime,LdrGet... @ 0.5507s
# Unique Mal. Pattern 363 GetSystemTimeAsFileTime,LdrLoa... @ 0.5698s
# Unique Mal. Pattern 364 GetSystemTimeAsFileTime,LdrLoa... @ 0.5710s
# Unique Mal. Pattern 365 GetSystemTimeAsFileTime,NtAllo... @ 0.5498s
# Unique Mal. Pattern 366 LdrLoadDll,LdrGetProcedureAddr... @ 0.5664s
# Unique Mal. Pattern 367 GetSystemTimeAsFileTime,LdrLoa... @ 0.5552s
# Unique Mal. Pattern 368 GetSystemTimeAsFileTime,LdrLoa... @ 0.5521s
# Unique Mal. Pattern 369 GetSystemTimeAsFileTime,LdrLoa... @ 0.5673s
# Unique Mal. Pattern 370 GetSystemTimeAsFileTime,LdrLoa... @ 0.5531s
# Unique Mal. Pattern 371 GetSystemTimeAsFileTime,LdrLoa... @ 0.5527s
# Unique Mal. Pattern 372 GetSystemTimeAsFileTime,LdrGet... @ 0.5569s
# Unique Mal. Pattern 373 GetSystemTimeAsFileTime,LdrLoa... @ 0.5683s
# Unique Mal. Pattern 374 GetSystemTimeAsFileTime,LdrLoa... @ 0.5488s
# Unique Mal. Pattern 375 LdrLoadDll,LdrGetProcedureAddr... @ 0.5566s
# Unique Mal. Pattern 376 GetSystemTimeAsFileTime,LdrLoa... @ 0.5675s
# Unique Mal. Pattern 377 GetSystemTimeAsFileTime,LdrLoa... @ 0.5519s
# Unique Mal. Pattern 378 LdrLoadDll,LdrGetProcedureAddr... @ 0.5542s
# Unique Mal. Pattern 379 LdrGetDllHandle,LdrGetProcedur... @ 0.5640s
# Unique Mal. Pattern 380 GetSystemTimeAsFileTime,LdrLoa... @ 0.5558s
# Unique Mal. Pattern 381 GetSystemTimeAsFileTime,LdrGet... @ 0.5684s
# Unique Mal. Pattern 382 SetErrorMode,LdrLoadDll,LdrGet... @ 0.5674s
# Unique Mal. Pattern 383 GetSystemTimeAsFileTime,LdrLoa... @ 0.5678s
# Unique Mal. Pattern 384 GetSystemTimeAsFileTime,LdrGet... @ 0.5553s
# Unique Mal. Pattern 385 GetSystemTimeAsFileTime,LdrGet... @ 0.5676s
# Unique Mal. Pattern 386 GetSystemTimeAsFileTime,LdrLoa... @ 0.5530s
# Unique Mal. Pattern 387 GetSystemTimeAsFileTime,LdrLoa... @ 0.5672s
# Unique Mal. Pattern 388 GetSystemTimeAsFileTime,NtAllo... @ 0.5533s
# Unique Mal. Pattern 389 RegOpenKeyExW,RegCloseKey,GetF... @ 0.5675s
# Unique Mal. Pattern 390 LdrLoadDll,LdrGetProcedureAddr... @ 0.5416s
# Unique Mal. Pattern 391 GetSystemTimeAsFileTime,LdrLoa... @ 0.5645s
# Unique Mal. Pattern 392 GetSystemTimeAsFileTime,LdrLoa... @ 0.5532s
# Unique Mal. Pattern 393 SetErrorMode,LdrGetDllHandle,L... @ 0.5675s
# Unique Mal. Pattern 394 GetSystemTimeAsFileTime,LdrLoa... @ 0.5552s
# Unique Mal. Pattern 395 GetSystemTimeAsFileTime,LdrLoa... @ 0.5510s
# Unique Mal. Pattern 396 NtAllocateVirtualMemory,NtProt... @ 0.5685s
# Unique Mal. Pattern 397 GetSystemTimeAsFileTime,LdrLoa... @ 0.5699s
# Unique Mal. Pattern 398 NtAllocateVirtualMemory,NtProt... @ 0.5663s
# Unique Mal. Pattern 399 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5721s
# Unique Mal. Pattern 400 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5538s
# Unique Mal. Pattern 401 GetSystemTimeAsFileTime,NtAllo... @ 0.5507s
# Unique Mal. Pattern 402 SetErrorMode,OleInitialize,Ldr... @ 0.5531s
# Unique Mal. Pattern 403 GetSystemTimeAsFileTime,NtAllo... @ 0.5528s
# Unique Mal. Pattern 404 GetSystemTimeAsFileTime,LdrGet... @ 0.5657s
# Unique Mal. Pattern 405 GetSystemTimeAsFileTime,LdrLoa... @ 0.5709s
# Unique Mal. Pattern 406 GetSystemTimeAsFileTime,LdrLoa... @ 0.5518s
# Unique Mal. Pattern 407 GetSystemTimeAsFileTime,LdrGet... @ 0.5553s
# Unique Mal. Pattern 408 GetSystemTimeAsFileTime,LdrGet... @ 0.5643s
# Unique Mal. Pattern 409 NtAllocateVirtualMemory,SetErr... @ 0.5708s
# Unique Mal. Pattern 410 GetSystemTimeAsFileTime,LdrLoa... @ 0.5687s
# Unique Mal. Pattern 411 SetErrorMode,OleInitialize,Ldr... @ 0.5683s
# Unique Mal. Pattern 412 GetSystemTimeAsFileTime,LdrLoa... @ 0.5677s
# Unique Mal. Pattern 413 NtAllocateVirtualMemory,SetErr... @ 0.5685s
# Unique Mal. Pattern 414 LdrGetDllHandle,LdrGetProcedur... @ 0.5711s
# Unique Mal. Pattern 415 GetSystemTimeAsFileTime,LdrLoa... @ 0.5663s
# Unique Mal. Pattern 416 LdrLoadDll,LdrGetProcedureAddr... @ 0.5530s
# Unique Mal. Pattern 417 GetSystemTimeAsFileTime,LdrLoa... @ 0.5682s
# Unique Mal. Pattern 418 LdrLoadDll,LdrGetProcedureAddr... @ 0.5549s
# Unique Mal. Pattern 419 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5666s
# Unique Mal. Pattern 420 GetSystemTimeAsFileTime,LdrLoa... @ 0.5553s
# Unique Mal. Pattern 421 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5675s
# Unique Mal. Pattern 422 LdrGetDllHandle,LdrLoadDll,NtA... @ 0.5661s
# Unique Mal. Pattern 423 GetSystemTimeAsFileTime,LdrLoa... @ 0.5556s
# Unique Mal. Pattern 424 GetSystemTimeAsFileTime,LdrLoa... @ 0.5519s
# Unique Mal. Pattern 425 GetSystemTimeAsFileTime,LdrLoa... @ 0.5529s
# Unique Mal. Pattern 426 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5673s
# Unique Mal. Pattern 427 GetSystemTimeAsFileTime,LdrLoa... @ 0.5689s
# Unique Mal. Pattern 428 GetSystemTimeAsFileTime,NtAllo... @ 0.5530s
# Unique Mal. Pattern 429 GetSystemTimeAsFileTime,SetUnh... @ 0.5687s
# Unique Mal. Pattern 430 NtAllocateVirtualMemory,SetErr... @ 0.5710s
# Unique Mal. Pattern 431 GetSystemTimeAsFileTime,LdrLoa... @ 0.5664s
# Unique Mal. Pattern 432 LdrLoadDll,LdrGetProcedureAddr... @ 0.5664s
# Unique Mal. Pattern 433 NtAllocateVirtualMemory,NtFree... @ 0.5987s
# Unique Mal. Pattern 434 GetSystemTimeAsFileTime,LdrLoa... @ 0.5733s
# Unique Mal. Pattern 435 GetSystemTimeAsFileTime,LdrLoa... @ 0.6021s
# Unique Mal. Pattern 436 GetSystemTimeAsFileTime,LdrLoa... @ 0.5552s
# Unique Mal. Pattern 437 GetSystemTimeAsFileTime,LdrLoa... @ 0.5497s
# Unique Mal. Pattern 438 GetSystemTimeAsFileTime,LdrGet... @ 0.5530s
# Unique Mal. Pattern 439 GetSystemTimeAsFileTime,LdrLoa... @ 0.5676s
# Unique Mal. Pattern 440 NtAllocateVirtualMemory,SetErr... @ 0.5710s
# Unique Mal. Pattern 441 SetErrorMode,OleInitialize,Ldr... @ 0.5708s
# Unique Mal. Pattern 442 OleInitialize,LdrLoadDll,LdrGe... @ 0.9869s
# Unique Mal. Pattern 443 LdrGetDllHandle,LdrGetProcedur... @ 0.5639s
# Unique Mal. Pattern 444 GetSystemTimeAsFileTime,LdrLoa... @ 0.5554s
# Unique Mal. Pattern 445 NtAllocateVirtualMemory,NtFree... @ 0.5712s
# Unique Mal. Pattern 446 GetSystemTimeAsFileTime,LdrGet... @ 0.5641s
# Unique Mal. Pattern 447 GetSystemTimeAsFileTime,LdrLoa... @ 0.5697s
# Unique Mal. Pattern 448 GetSystemTimeAsFileTime,LdrLoa... @ 0.5531s
# Unique Mal. Pattern 449 GetSystemTimeAsFileTime,NtAllo... @ 0.5519s
# Unique Mal. Pattern 450 GetSystemTimeAsFileTime,LdrLoa... @ 0.5696s
# Unique Mal. Pattern 451 GetSystemTimeAsFileTime,LdrLoa... @ 0.5533s
# Unique Mal. Pattern 452 GetSystemTimeAsFileTime,LdrLoa... @ 0.5676s
# Unique Mal. Pattern 453 GetSystemTimeAsFileTime,LdrLoa... @ 0.5698s
# Unique Mal. Pattern 454 GetSystemTimeAsFileTime,LdrLoa... @ 0.5653s
# Unique Mal. Pattern 455 GetSystemTimeAsFileTime,GetSys... @ 0.5709s
# Unique Mal. Pattern 456 GetSystemTimeAsFileTime,LdrLoa... @ 0.5542s
# Unique Mal. Pattern 457 GetSystemTimeAsFileTime,LdrLoa... @ 0.5496s
# Unique Mal. Pattern 458 NtAllocateVirtualMemory,NtFree... @ 0.5597s
# Unique Mal. Pattern 459 GetSystemTimeAsFileTime,LdrLoa... @ 0.5643s
# Unique Mal. Pattern 460 NtAllocateVirtualMemory,SetErr... @ 0.5709s
# Unique Mal. Pattern 461 GetSystemTimeAsFileTime,LdrLoa... @ 0.5486s
# Unique Mal. Pattern 462 GetSystemTimeAsFileTime,LdrLoa... @ 0.5710s
# Unique Mal. Pattern 463 GetSystemTimeAsFileTime,LdrLoa... @ 0.5862s
# Unique Mal. Pattern 464 GetSystemTimeAsFileTime,LdrLoa... @ 0.6580s
# Unique Mal. Pattern 465 GetSystemTimeAsFileTime,LdrGet... @ 0.5935s
# Unique Mal. Pattern 466 GetSystemTimeAsFileTime,LdrLoa... @ 0.5707s
# Unique Mal. Pattern 467 GetSystemTimeAsFileTime,LdrGet... @ 0.5688s
# Unique Mal. Pattern 468 LdrLoadDll,LdrGetProcedureAddr... @ 0.5528s
# Unique Mal. Pattern 469 GetSystemTimeAsFileTime,LdrLoa... @ 0.5698s
# Unique Mal. Pattern 470 NtQuerySystemInformation,GetCu... @ 0.5678s
# Unique Mal. Pattern 471 GetSystemTimeAsFileTime,LdrGet... @ 0.5685s
# Unique Mal. Pattern 472 GetSystemTimeAsFileTime,LdrLoa... @ 0.5527s
# Unique Mal. Pattern 473 GetSystemTimeAsFileTime,LdrLoa... @ 0.5523s
# Unique Mal. Pattern 474 __exception__,NtAllocateVirtua... @ 0.5673s
# Unique Mal. Pattern 475 SetErrorMode,OleInitialize,Ldr... @ 0.5678s
# Unique Mal. Pattern 476 FindResourceA,SizeofResource,L... @ 0.5696s
# Unique Mal. Pattern 477 GetSystemTimeAsFileTime,LdrLoa... @ 0.5695s
# Unique Mal. Pattern 478 SetUnhandledExceptionFilter,Nt... @ 0.5687s
# Unique Mal. Pattern 479 GetSystemTimeAsFileTime,LdrLoa... @ 0.5687s
# Unique Mal. Pattern 480 NtAllocateVirtualMemory,SetErr... @ 0.5676s
# Unique Mal. Pattern 481 GetSystemTimeAsFileTime,LdrLoa... @ 0.5719s
# Unique Mal. Pattern 482 GetSystemTimeAsFileTime,SetUnh... @ 0.5966s
# Unique Mal. Pattern 483 GetSystemTimeAsFileTime,LdrLoa... @ 0.5711s
# Unique Mal. Pattern 484 GetSystemTimeAsFileTime,GetSys... @ 0.5686s
# Unique Mal. Pattern 485 GetSystemTimeAsFileTime,NtAllo... @ 0.5718s
# Unique Mal. Pattern 486 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5848s
# Unique Mal. Pattern 487 GetSystemTimeAsFileTime,LdrLoa... @ 0.5659s
# Unique Mal. Pattern 488 GetSystemTimeAsFileTime,LdrGet... @ 0.5520s
# Unique Mal. Pattern 489 GetSystemTimeAsFileTime,LdrLoa... @ 0.5723s
# Unique Mal. Pattern 490 NtAllocateVirtualMemory,SetErr... @ 0.5663s
# Unique Mal. Pattern 491 NtAllocateVirtualMemory,SetErr... @ 0.5686s
# Unique Mal. Pattern 492 GetSystemTimeAsFileTime,NtAllo... @ 0.5678s
# Unique Mal. Pattern 493 GetSystemTimeAsFileTime,LdrLoa... @ 0.5708s
# Unique Mal. Pattern 494 GetSystemTimeAsFileTime,NtAllo... @ 0.5663s
# Unique Mal. Pattern 495 LdrLoadDll,SetErrorMode,LdrLoa... @ 0.5685s
# Unique Mal. Pattern 496 GetSystemTimeAsFileTime,LdrLoa... @ 0.5543s
# Unique Mal. Pattern 497 LdrLoadDll,LdrGetProcedureAddr... @ 0.5686s
# Unique Mal. Pattern 498 LdrLoadDll,LdrGetProcedureAddr... @ 0.5519s
# Unique Mal. Pattern 499 GetSystemTimeAsFileTime,LdrLoa... @ 0.5553s
# Unique Mal. Pattern 500 SetUnhandledExceptionFilter,Nt... @ 0.5654s
# Unique Mal. Pattern 501 LdrGetDllHandle,LdrGetProcedur... @ 0.5547s
# Unique Mal. Pattern 502 GetSystemTimeAsFileTime,LdrLoa... @ 0.5511s
# Unique Mal. Pattern 503 __exception__,NtAllocateVirtua... @ 0.5686s
# Unique Mal. Pattern 504 GetSystemTimeAsFileTime,LdrLoa... @ 0.5532s
# Unique Mal. Pattern 505 GetSystemTimeAsFileTime,LdrLoa... @ 0.5686s
# Unique Mal. Pattern 506 GetSystemTimeAsFileTime,LdrLoa... @ 0.5698s
# Unique Mal. Pattern 507 GetSystemTimeAsFileTime,LdrLoa... @ 0.5517s
# Unique Mal. Pattern 508 GetSystemTimeAsFileTime,LdrLoa... @ 0.5530s
# Unique Mal. Pattern 509 GetSystemTimeAsFileTime,LdrLoa... @ 0.5701s
# Unique Mal. Pattern 510 FindResourceA,LoadResource,NtD... @ 0.5652s
# Unique Mal. Pattern 511 NtClose,LdrLoadDll,LdrGetProce... @ 0.5710s
# Unique Mal. Pattern 512 GetSystemTimeAsFileTime,NtAllo... @ 0.5553s
# Unique Mal. Pattern 513 GetSystemTimeAsFileTime,LdrLoa... @ 0.5673s
# Unique Mal. Pattern 514 GetSystemTimeAsFileTime,LdrLoa... @ 0.5523s
# Unique Mal. Pattern 515 NtClose,NtOpenKey,NtQueryValue... @ 0.5531s
# Unique Mal. Pattern 516 GetSystemTimeAsFileTime,LdrLoa... @ 0.5528s
# Unique Mal. Pattern 517 GetSystemTimeAsFileTime,LdrLoa... @ 0.5675s
# Unique Mal. Pattern 518 GetSystemTimeAsFileTime,LdrLoa... @ 0.5676s
# Unique Mal. Pattern 519 GetSystemTimeAsFileTime,LdrGet... @ 0.5553s
# Unique Mal. Pattern 520 GetCursorPos,SetErrorMode,Find... @ 0.5676s
# Unique Mal. Pattern 521 GetFileAttributesExW,NtDeviceI... @ 0.5709s
# Unique Mal. Pattern 522 SetUnhandledExceptionFilter,Nt... @ 0.5707s
# Unique Mal. Pattern 523 NtAllocateVirtualMemory,NtFree... @ 0.5655s
# Unique Mal. Pattern 524 LdrLoadDll,LdrGetProcedureAddr... @ 0.5565s
# Unique Mal. Pattern 525 GetSystemTimeAsFileTime,LdrLoa... @ 0.5639s
# Unique Mal. Pattern 526 GetSystemTimeAsFileTime,LdrLoa... @ 0.5719s
# Unique Mal. Pattern 527 NtAllocateVirtualMemory,SetErr... @ 0.5641s
# Unique Mal. Pattern 528 GetSystemTimeAsFileTime,LdrLoa... @ 0.5712s
# Unique Mal. Pattern 529 LdrGetDllHandle,LdrGetProcedur... @ 0.5661s
# Unique Mal. Pattern 530 GetSystemTimeAsFileTime,LdrLoa... @ 0.5736s
# Unique Mal. Pattern 531 GetSystemTimeAsFileTime,LdrLoa... @ 0.5649s
# Unique Mal. Pattern 532 GetSystemTimeAsFileTime,LdrLoa... @ 0.5678s
# Unique Mal. Pattern 533 GetSystemTimeAsFileTime,LdrLoa... @ 0.5707s
# Unique Mal. Pattern 534 LdrLoadDll,LdrGetProcedureAddr... @ 0.5520s
# Unique Mal. Pattern 535 SetErrorMode,OleInitialize,Ldr... @ 0.5686s
# Unique Mal. Pattern 536 NtAllocateVirtualMemory,NtFree... @ 0.5677s
# Unique Mal. Pattern 537 GetSystemTimeAsFileTime,LdrGet... @ 0.5709s
# Unique Mal. Pattern 538 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5688s
# Unique Mal. Pattern 539 LdrLoadDll,LdrGetProcedureAddr... @ 0.5517s
# Unique Mal. Pattern 540 GetSystemTimeAsFileTime,LdrLoa... @ 0.5709s
# Unique Mal. Pattern 541 NtAllocateVirtualMemory,SetErr... @ 0.5664s
# Unique Mal. Pattern 542 GetSystemTimeAsFileTime,LdrLoa... @ 0.5720s
# Unique Mal. Pattern 543 GetSystemTimeAsFileTime,LdrLoa... @ 0.5642s
# Unique Mal. Pattern 544 GetSystemTimeAsFileTime,LdrLoa... @ 0.5531s
# Unique Mal. Pattern 545 GetSystemTimeAsFileTime,LdrLoa... @ 0.5552s
# Unique Mal. Pattern 546 GetSystemTimeAsFileTime,LdrLoa... @ 0.5676s
# Unique Mal. Pattern 547 SetErrorMode,LdrGetDllHandle,L... @ 0.5684s
# Unique Mal. Pattern 548 GetSystemTimeAsFileTime,GetFil... @ 0.5534s
# Unique Mal. Pattern 549 GetSystemTimeAsFileTime,LdrLoa... @ 0.5664s
# Unique Mal. Pattern 550 GetSystemTimeAsFileTime,LdrGet... @ 0.5529s
# Unique Mal. Pattern 551 GetSystemTimeAsFileTime,NtAllo... @ 0.5543s
# Unique Mal. Pattern 552 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5686s
# Unique Mal. Pattern 553 GetSystemTimeAsFileTime,LdrLoa... @ 0.5666s
# Unique Mal. Pattern 554 GetSystemTimeAsFileTime,LdrGet... @ 0.5707s
# Unique Mal. Pattern 555 GetSystemTimeAsFileTime,LdrGet... @ 0.5529s
# Unique Mal. Pattern 556 NtAllocateVirtualMemory,NtFree... @ 0.5821s
# Unique Mal. Pattern 557 NtAllocateVirtualMemory,NtFree... @ 0.5707s
# Unique Mal. Pattern 558 GetSystemTimeAsFileTime,NtAllo... @ 0.5531s
# Unique Mal. Pattern 559 GetSystemTimeAsFileTime,NtAllo... @ 0.5519s
# Unique Mal. Pattern 560 GetSystemTimeAsFileTime,LdrLoa... @ 0.5677s
# Unique Mal. Pattern 561 LdrLoadDll,LdrGetProcedureAddr... @ 0.5673s
# Unique Mal. Pattern 562 GetSystemTimeAsFileTime,LdrLoa... @ 0.5533s
# Unique Mal. Pattern 563 GetSystemTimeAsFileTime,LdrLoa... @ 0.5710s
# Unique Mal. Pattern 564 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5685s
# Unique Mal. Pattern 565 GetSystemTimeAsFileTime,NtAllo... @ 0.5530s
# Unique Mal. Pattern 566 GetSystemTimeAsFileTime,LdrLoa... @ 0.5542s
# Unique Mal. Pattern 567 GetSystemTimeAsFileTime,LdrLoa... @ 0.5645s
# Unique Mal. Pattern 568 NtAllocateVirtualMemory,SetErr... @ 0.5842s
# Unique Mal. Pattern 569 SetErrorMode,OleInitialize,Ldr... @ 1.0527s
# Unique Mal. Pattern 570 GetSystemTimeAsFileTime,LdrLoa... @ 0.5548s
# Unique Mal. Pattern 571 GetSystemTimeAsFileTime,LdrGet... @ 0.5552s
# Unique Mal. Pattern 572 SetErrorMode,OleInitialize,Ldr... @ 0.5709s
# Unique Mal. Pattern 573 GetSystemTimeAsFileTime,LdrLoa... @ 0.5642s
# Unique Mal. Pattern 574 GetSystemTimeAsFileTime,LdrLoa... @ 0.5557s
# Unique Mal. Pattern 575 GetSystemTimeAsFileTime,LdrLoa... @ 0.5682s
# Unique Mal. Pattern 576 GetSystemTimeAsFileTime,LdrLoa... @ 0.5655s
# Unique Mal. Pattern 577 GetSystemTimeAsFileTime,LdrLoa... @ 0.5676s
# Unique Mal. Pattern 578 GetSystemTimeAsFileTime,NtAllo... @ 0.5552s
# Unique Mal. Pattern 579 GetSystemTimeAsFileTime,LdrLoa... @ 0.5676s
# Unique Mal. Pattern 580 GetSystemTimeAsFileTime,LdrLoa... @ 0.5684s
# Unique Mal. Pattern 581 GetSystemTimeAsFileTime,LdrLoa... @ 0.5691s
# Unique Mal. Pattern 582 GetSystemTimeAsFileTime,LdrLoa... @ 0.5685s
# Unique Mal. Pattern 583 GetSystemTimeAsFileTime,LdrLoa... @ 0.5687s
# Unique Mal. Pattern 584 LdrLoadDll,LdrGetProcedureAddr... @ 0.5520s
# Unique Mal. Pattern 585 GetSystemTimeAsFileTime,LdrLoa... @ 0.5708s
# Unique Mal. Pattern 586 NtQueryInformationFile,NtQuery... @ 0.5655s
# Unique Mal. Pattern 587 GetSystemTimeAsFileTime,LdrGet... @ 0.5540s
# Unique Mal. Pattern 588 SetUnhandledExceptionFilter,Ol... @ 0.5685s
# Unique Mal. Pattern 589 GetSystemTimeAsFileTime,LdrLoa... @ 0.5533s
# Unique Mal. Pattern 590 LdrLoadDll,LdrGetProcedureAddr... @ 0.5518s
# Unique Mal. Pattern 591 GetSystemTimeAsFileTime,LdrLoa... @ 0.5518s
# Unique Mal. Pattern 592 GetSystemTimeAsFileTime,LdrGet... @ 0.5715s
# Unique Mal. Pattern 593 GetSystemTimeAsFileTime,NtAllo... @ 0.5505s
# Unique Mal. Pattern 594 GetSystemTimeAsFileTime,LdrLoa... @ 0.5551s
# Unique Mal. Pattern 595 GetSystemTimeAsFileTime,LdrLoa... @ 0.5664s
# Unique Mal. Pattern 596 NtAllocateVirtualMemory,LoadSt... @ 0.5688s
# Unique Mal. Pattern 597 GetSystemTimeAsFileTime,LdrLoa... @ 0.5516s
# Unique Mal. Pattern 598 LdrGetDllHandle,LdrGetProcedur... @ 0.5687s
# Unique Mal. Pattern 599 NtAllocateVirtualMemory,NtFree... @ 0.5687s
# Unique Mal. Pattern 600 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5690s
# Unique Mal. Pattern 601 GetSystemTimeAsFileTime,LdrLoa... @ 0.5694s
# Unique Mal. Pattern 602 NtAllocateVirtualMemory,SetErr... @ 0.5678s
# Unique Mal. Pattern 603 GetCursorPos,SetErrorMode,Find... @ 0.5686s
# Unique Mal. Pattern 604 NtClose,LdrGetProcedureAddress... @ 0.5686s
# Unique Mal. Pattern 605 GetSystemTimeAsFileTime,LdrGet... @ 0.5540s
# Unique Mal. Pattern 606 GetSystemTimeAsFileTime,NtAllo... @ 0.5519s
# Unique Mal. Pattern 607 GetSystemTimeAsFileTime,LdrLoa... @ 0.5567s
# Unique Mal. Pattern 608 GetSystemTimeAsFileTime,LdrLoa... @ 0.5661s
# Unique Mal. Pattern 609 NtAllocateVirtualMemory,SetErr... @ 0.5533s
# Unique Mal. Pattern 610 NtAllocateVirtualMemory,SetErr... @ 0.5678s
# Unique Mal. Pattern 611 GetSystemTimeAsFileTime,LdrLoa... @ 0.5517s
# Unique Mal. Pattern 612 LdrGetDllHandle,LdrGetProcedur... @ 0.5573s
# Unique Mal. Pattern 613 GetSystemTimeAsFileTime,LdrGet... @ 0.5642s
# Unique Mal. Pattern 614 GetSystemTimeAsFileTime,NtAllo... @ 0.5535s
# Unique Mal. Pattern 615 LdrGetDllHandle,IsDebuggerPres... @ 0.5542s
# Unique Mal. Pattern 616 LdrGetDllHandle,LdrGetProcedur... @ 0.5516s
# Unique Mal. Pattern 617 GetSystemTimeAsFileTime,LdrLoa... @ 0.5520s
# Unique Mal. Pattern 618 GetSystemTimeAsFileTime,LdrLoa... @ 0.5712s
# Unique Mal. Pattern 619 GetSystemTimeAsFileTime,LdrLoa... @ 0.5659s
# Unique Mal. Pattern 620 GetSystemTimeAsFileTime,LdrLoa... @ 0.5554s
# Unique Mal. Pattern 621 NtQueryInformationFile,NtAlloc... @ 0.5653s
# Unique Mal. Pattern 622 GetSystemTimeAsFileTime,LdrGet... @ 0.5554s
# Unique Mal. Pattern 623 NtAllocateVirtualMemory,SetErr... @ 0.5686s
# Unique Mal. Pattern 624 GetSystemTimeAsFileTime,LdrGet... @ 0.5532s
# Unique Mal. Pattern 625 NtAllocateVirtualMemory,SetErr... @ 0.5664s
# Unique Mal. Pattern 626 GetSystemTimeAsFileTime,LdrLoa... @ 0.5565s
# Unique Mal. Pattern 627 GetSystemTimeAsFileTime,LdrLoa... @ 0.5506s
# Unique Mal. Pattern 628 GetSystemTimeAsFileTime,LdrLoa... @ 0.5711s
# Unique Mal. Pattern 629 NtClose,LdrLoadDll,LdrGetProce... @ 0.5661s
# Unique Mal. Pattern 630 GetSystemTimeAsFileTime,LdrGet... @ 0.5524s
# Unique Mal. Pattern 631 GetSystemTimeAsFileTime,LdrGet... @ 0.5720s
# Unique Mal. Pattern 632 GetSystemTimeAsFileTime,LdrLoa... @ 0.5651s
# Unique Mal. Pattern 633 GetSystemTimeAsFileTime,LdrLoa... @ 0.5687s
# Unique Mal. Pattern 634 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5687s
# Unique Mal. Pattern 635 GetSystemTimeAsFileTime,LdrGet... @ 0.5675s
# Unique Mal. Pattern 636 GetSystemTimeAsFileTime,LdrLoa... @ 0.5533s
# Unique Mal. Pattern 637 GetSystemInfo,LdrGetDllHandle,... @ 0.5705s
# Unique Mal. Pattern 638 NtAllocateVirtualMemory,NtProt... @ 0.5687s
# Unique Mal. Pattern 639 GetSystemTimeAsFileTime,LdrGet... @ 0.5532s
# Unique Mal. Pattern 640 GetSystemTimeAsFileTime,LdrGet... @ 0.5564s
# Unique Mal. Pattern 641 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5663s
# Unique Mal. Pattern 642 GetSystemTimeAsFileTime,LdrGet... @ 0.5510s
# Unique Mal. Pattern 643 GetSystemTimeAsFileTime,LdrLoa... @ 0.5529s
# Unique Mal. Pattern 644 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5678s
# Unique Mal. Pattern 645 LdrLoadDll,LdrGetProcedureAddr... @ 0.5540s
# Unique Mal. Pattern 646 GetSystemTimeAsFileTime,LdrLoa... @ 0.5713s
# Unique Mal. Pattern 647 SetUnhandledExceptionFilter,Nt... @ 0.6635s
# Unique Mal. Pattern 648 GetSystemTimeAsFileTime,LdrLoa... @ 0.6730s
# Unique Mal. Pattern 649 SetErrorMode,OleInitialize,Ldr... @ 0.6910s
# Unique Mal. Pattern 650 SetErrorMode,OleInitialize,Ldr... @ 0.7729s
# Unique Mal. Pattern 651 GetSystemTimeAsFileTime,LdrLoa... @ 0.6870s
# Unique Mal. Pattern 652 NtAllocateVirtualMemory,NtFree... @ 0.6110s
# Unique Mal. Pattern 653 GetSystemTimeAsFileTime,LdrLoa... @ 0.6961s
# Unique Mal. Pattern 654 GetSystemTimeAsFileTime,NtAllo... @ 0.7160s
# Unique Mal. Pattern 655 GetSystemTimeAsFileTime,LdrLoa... @ 0.7060s
# Unique Mal. Pattern 656 SetErrorMode,LdrGetDllHandle,L... @ 0.6989s
# Unique Mal. Pattern 657 GetSystemTimeAsFileTime,LdrLoa... @ 0.6800s
# Unique Mal. Pattern 658 NtAllocateVirtualMemory,SetErr... @ 0.6830s
# Unique Mal. Pattern 659 GetSystemTimeAsFileTime,LdrLoa... @ 0.6540s
# Unique Mal. Pattern 660 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5850s
# Unique Mal. Pattern 661 GetSystemTimeAsFileTime,LdrLoa... @ 0.5800s
# Unique Mal. Pattern 662 GetSystemTimeAsFileTime,LdrLoa... @ 0.6060s
# Unique Mal. Pattern 663 GetSystemTimeAsFileTime,LdrLoa... @ 0.5940s
# Unique Mal. Pattern 664 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5940s
# Unique Mal. Pattern 665 GetSystemTimeAsFileTime,LdrLoa... @ 0.5940s
# Unique Mal. Pattern 666 GetSystemTimeAsFileTime,LdrLoa... @ 0.5780s
# Unique Mal. Pattern 667 NtClose,NtOpenKey,NtQueryValue... @ 0.5865s
# Unique Mal. Pattern 668 NtAllocateVirtualMemory,SetErr... @ 0.5880s
# Unique Mal. Pattern 669 SetUnhandledExceptionFilter,Nt... @ 0.6070s
# Unique Mal. Pattern 670 LdrGetDllHandle,LdrGetProcedur... @ 0.5960s
# Unique Mal. Pattern 671 GetSystemTimeAsFileTime,LdrLoa... @ 0.5820s
# Unique Mal. Pattern 672 NtAllocateVirtualMemory,SetErr... @ 0.6010s
# Unique Mal. Pattern 673 GetSystemTimeAsFileTime,LdrLoa... @ 0.5750s
# Unique Mal. Pattern 674 GetSystemTimeAsFileTime,LdrLoa... @ 0.5800s
# Unique Mal. Pattern 675 GetSystemTimeAsFileTime,LdrLoa... @ 0.5830s
# Unique Mal. Pattern 676 CreateToolhelp32Snapshot,NtAll... @ 0.5870s
# Unique Mal. Pattern 677 GetSystemTimeAsFileTime,LdrLoa... @ 0.5820s
# Unique Mal. Pattern 678 GetSystemTimeAsFileTime,LdrGet... @ 0.5739s
# Unique Mal. Pattern 679 __exception__,NtAllocateVirtua... @ 0.5870s
# Unique Mal. Pattern 680 NtOpenKey,NtQueryValueKey,NtOp... @ 0.5820s
# Unique Mal. Pattern 681 LdrLoadDll,LdrGetProcedureAddr... @ 0.5730s
# Unique Mal. Pattern 682 NtAllocateVirtualMemory,NtFree... @ 0.5900s
# Unique Mal. Pattern 683 NtAllocateVirtualMemory,NtProt... @ 0.5910s
# Unique Mal. Pattern 684 LdrLoadDll,LdrGetProcedureAddr... @ 0.5793s
# Unique Mal. Pattern 685 NtAllocateVirtualMemory,SetErr... @ 0.6010s
# Unique Mal. Pattern 686 GetSystemTimeAsFileTime,LdrGet... @ 0.5800s
# Unique Mal. Pattern 687 GetSystemTimeAsFileTime,LdrLoa... @ 0.5780s
# Unique Mal. Pattern 688 SetUnhandledExceptionFilter,Nt... @ 0.6010s
# Unique Mal. Pattern 689 GetSystemTimeAsFileTime,LdrGet... @ 0.6430s
# Unique Mal. Pattern 690 NtDeviceIoControlFile,NtClose,... @ 0.5850s
# Unique Mal. Pattern 691 GetSystemTimeAsFileTime,LdrLoa... @ 0.5770s
# Unique Mal. Pattern 692 LdrGetDllHandle,LdrGetProcedur... @ 0.6050s
# Unique Mal. Pattern 693 GetSystemTimeAsFileTime,LdrLoa... @ 0.5880s
# Unique Mal. Pattern 694 GetSystemTimeAsFileTime,LdrLoa... @ 0.5850s
# Unique Mal. Pattern 695 GetSystemTimeAsFileTime,LdrGet... @ 0.5720s
# Unique Mal. Pattern 696 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5840s
# Unique Mal. Pattern 697 GetSystemTimeAsFileTime,LdrLoa... @ 0.5810s
# Unique Mal. Pattern 698 __exception__,NtAllocateVirtua... @ 0.5990s
# Unique Mal. Pattern 699 GetSystemTimeAsFileTime,LdrLoa... @ 0.5920s
# Unique Mal. Pattern 700 GetSystemTimeAsFileTime,LdrLoa... @ 0.6110s
# Unique Mal. Pattern 701 SetErrorMode,OleInitialize,Ldr... @ 0.5960s
# Unique Mal. Pattern 702 GetSystemTimeAsFileTime,LdrLoa... @ 0.5740s
# Unique Mal. Pattern 703 NtAllocateVirtualMemory,SetErr... @ 0.5920s
# Unique Mal. Pattern 704 GetSystemTimeAsFileTime,NtAllo... @ 0.5760s
# ...
# Unique Mal. Pattern 11264 NtAllocateVirtualMemory,SetErr... @ 0.5666s
# Unique Mal. Pattern 11265 GetSystemTimeAsFileTime,NtAllo... @ 0.5523s
# Unique Mal. Pattern 11266 NtAllocateVirtualMemory,SetErr... @ 0.5706s
# Unique Mal. Pattern 11267 GetSystemTimeAsFileTime,LdrLoa... @ 0.5666s
# Unique Mal. Pattern 11268 GetSystemTimeAsFileTime,LdrGet... @ 0.5696s
# Unique Mal. Pattern 11269 GetSystemTimeAsFileTime,LdrLoa... @ 0.5666s
# Unique Mal. Pattern 11270 GetSystemTimeAsFileTime,LdrGet... @ 0.5538s
# Unique Mal. Pattern 11271 GetSystemTimeAsFileTime,LdrLoa... @ 0.5523s
# Unique Mal. Pattern 11272 GetSystemTimeAsFileTime,LdrLoa... @ 0.5711s
# Unique Mal. Pattern 11273 GetSystemTimeAsFileTime,LdrLoa... @ 0.5505s
# Unique Mal. Pattern 11274 GetSystemTimeAsFileTime,LdrLoa... @ 0.5552s
# Unique Mal. Pattern 11275 GetSystemTimeAsFileTime,LdrLoa... @ 0.5507s
# Unique Mal. Pattern 11276 LdrGetDllHandle,LdrLoadDll,Ldr... @ 0.5542s
# Unique Mal. Pattern 11277 GetSystemTimeAsFileTime,LdrLoa... @ 0.5554s
# Unique Mal. Pattern 11278 NtProtectVirtualMemory,LdrGetP... @ 0.5655s
# Unique Mal. Pattern 11279 SetUnhandledExceptionFilter,Nt... @ 0.5527s
# Unique Mal. Pattern 11280 NtClose,NtAllocateVirtualMemor... @ 0.5556s
# Unique Mal. Pattern 11281 GetSystemTimeAsFileTime,LdrLoa... @ 0.5529s
# Unique Mal. Pattern 11282 GetSystemTimeAsFileTime,LdrLoa... @ 0.5507s
# Unique Mal. Pattern 11283 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5723s
# Unique Mal. Pattern 11284 NtAllocateVirtualMemory,SetErr... @ 0.5676s
# Unique Mal. Pattern 11285 GetSystemTimeAsFileTime,LdrLoa... @ 0.5687s
# Unique Mal. Pattern 11286 __exception__,NtAllocateVirtua... @ 0.5673s
# Unique Mal. Pattern 11287 GetSystemTimeAsFileTime,NtAllo... @ 0.5688s
# Unique Mal. Pattern 11288 GetSystemTimeAsFileTime,LdrLoa... @ 0.5698s
# Unique Mal. Pattern 11289 LdrLoadDll,NtClose,NtOpenFile,... @ 0.5672s
# Unique Mal. Pattern 11290 LdrGetDllHandle,LdrGetProcedur... @ 0.5689s
# Unique Mal. Pattern 11291 GetSystemTimeAsFileTime,LdrLoa... @ 0.5552s
# Unique Mal. Pattern 11292 GetSystemTimeAsFileTime,LdrLoa... @ 0.5529s
# Unique Mal. Pattern 11293 NtAllocateVirtualMemory,SetErr... @ 5.4840s
# Unique Mal. Pattern 11294 LdrLoadDll,NtCreateFile,GetFil... @ 0.5673s
# Unique Mal. Pattern 11295 GetSystemTimeAsFileTime,SetUnh... @ 0.5688s
# Unique Mal. Pattern 11296 GetSystemTimeAsFileTime,LdrLoa... @ 0.5565s
# Unique Mal. Pattern 11297 GetSystemTimeAsFileTime,LdrLoa... @ 0.5651s
# Unique Mal. Pattern 11298 GetSystemTimeAsFileTime,LdrLoa... @ 0.5698s
# Unique Mal. Pattern 11299 GetSystemTimeAsFileTime,LdrLoa... @ 0.5665s
# Unique Mal. Pattern 11300 GetSystemTimeAsFileTime,LdrLoa... @ 0.5710s
# Unique Mal. Pattern 11301 NtAllocateVirtualMemory,SetErr... @ 0.5708s
# Unique Mal. Pattern 11302 GetSystemTimeAsFileTime,LdrLoa... @ 0.5650s
# Unique Mal. Pattern 11303 GetSystemTimeAsFileTime,LdrLoa... @ 0.5946s
# Unique Mal. Pattern 11304 GetSystemTimeAsFileTime,LdrLoa... @ 0.5652s
# Unique Mal. Pattern 11305 __exception__,NtAllocateVirtua... @ 0.5652s
# Unique Mal. Pattern 11306 GetSystemTimeAsFileTime,LdrGet... @ 0.5727s
# Unique Mal. Pattern 11307 GetSystemTimeAsFileTime,LdrLoa... @ 0.5828s
# Unique Mal. Pattern 11308 NtAllocateVirtualMemory,SetErr... @ 0.5673s
# Unique Mal. Pattern 11309 LdrGetDllHandle,LdrGetProcedur... @ 0.5676s
# Unique Mal. Pattern 11310 GetSystemTimeAsFileTime,LdrLoa... @ 0.5719s
# Unique Mal. Pattern 11311 GetSystemTimeAsFileTime,LdrLoa... @ 0.5508s
# Unique Mal. Pattern 11312 GetSystemTimeAsFileTime,LdrLoa... @ 0.5532s
# Unique Mal. Pattern 11313 GetSystemTimeAsFileTime,LdrLoa... @ 0.5686s
# Unique Mal. Pattern 11314 NtClose,LdrGetDllHandle,LdrGet... @ 0.5687s
# Unique Mal. Pattern 11315 GetSystemTimeAsFileTime,LdrLoa... @ 0.5664s
# Unique Mal. Pattern 11316 GetSystemTimeAsFileTime,LdrGet... @ 0.5526s
# Unique Mal. Pattern 11317 GetSystemTimeAsFileTime,LdrLoa... @ 0.5535s
# Unique Mal. Pattern 11318 NtOpenDirectoryObject,NtOpenSe... @ 0.5687s
# Unique Mal. Pattern 11319 GetSystemTimeAsFileTime,LdrLoa... @ 0.5555s
# Unique Mal. Pattern 11320 GetSystemTimeAsFileTime,NtAllo... @ 0.5651s
# Unique Mal. Pattern 11321 NtAllocateVirtualMemory,NtFree... @ 0.5556s
# Unique Mal. Pattern 11322 GetSystemTimeAsFileTime,LdrLoa... @ 0.5505s
# Unique Mal. Pattern 11323 LdrLoadDll,LdrGetProcedureAddr... @ 0.5555s
# Unique Mal. Pattern 11324 NtAllocateVirtualMemory,NtFree... @ 0.5653s
# Unique Mal. Pattern 11325 GetSystemTimeAsFileTime,LdrLoa... @ 0.5707s
# Unique Mal. Pattern 11326 GetSystemTimeAsFileTime,LdrLoa... @ 0.5709s
# Unique Mal. Pattern 11327 __exception__,LdrLoadDll,LdrGe... @ 0.5664s
# Unique Mal. Pattern 11328 SetErrorMode,OleInitialize,Ldr... @ 0.5674s
# Unique Mal. Pattern 11329 GetSystemTimeAsFileTime,LdrLoa... @ 0.5675s
# Unique Mal. Pattern 11330 GetSystemTimeAsFileTime,NtAllo... @ 0.5524s
# Unique Mal. Pattern 11331 GetSystemTimeAsFileTime,LdrLoa... @ 0.5528s
# Unique Mal. Pattern 11332 GetSystemTimeAsFileTime,LdrLoa... @ 0.5531s
# Unique Mal. Pattern 11333 LdrGetDllHandle,NtCreateFile,G... @ 0.5662s
# Unique Mal. Pattern 11334 GetSystemTimeAsFileTime,LdrLoa... @ 0.5555s
# Unique Mal. Pattern 11335 GetSystemTimeAsFileTime,LdrLoa... @ 0.5675s
# Unique Mal. Pattern 11336 GetSystemTimeAsFileTime,LdrGet... @ 0.5553s
# Unique Mal. Pattern 11337 LdrLoadDll,IsDebuggerPresent,N... @ 0.5664s
# Unique Mal. Pattern 11338 GetSystemTimeAsFileTime,LdrLoa... @ 0.5531s
# Unique Mal. Pattern 11339 LdrLoadDll,NtProtectVirtualMem... @ 0.5553s
# Unique Mal. Pattern 11340 GetSystemTimeAsFileTime,NtAllo... @ 0.5687s
# Unique Mal. Pattern 11341 NtClose,LdrLoadDll,LdrGetProce... @ 0.5651s
# Unique Mal. Pattern 11342 GetSystemTimeAsFileTime,NtAllo... @ 0.5531s
# Unique Mal. Pattern 11343 NtAllocateVirtualMemory,NtFree... @ 0.5710s
# Unique Mal. Pattern 11344 GetSystemTimeAsFileTime,NtAllo... @ 0.5361s
# Unique Mal. Pattern 11345 GetSystemTimeAsFileTime,LdrLoa... @ 0.5509s
# Unique Mal. Pattern 11346 GetSystemTimeAsFileTime,LdrLoa... @ 0.5541s
# Unique Mal. Pattern 11347 NtAllocateVirtualMemory,SetErr... @ 0.5653s
# Unique Mal. Pattern 11348 GetSystemTimeAsFileTime,NtAllo... @ 0.5574s
# Unique Mal. Pattern 11349 GetSystemTimeAsFileTime,LdrGet... @ 0.5677s
# Unique Mal. Pattern 11350 LdrLoadDll,LdrGetProcedureAddr... @ 0.5507s
# Unique Mal. Pattern 11351 GetSystemTimeAsFileTime,LdrLoa... @ 0.5676s
# Unique Mal. Pattern 11352 LdrGetDllHandle,LdrGetProcedur... @ 0.5686s
# Unique Mal. Pattern 11353 GetSystemTimeAsFileTime,LdrLoa... @ 0.5542s
# Unique Mal. Pattern 11354 NtAllocateVirtualMemory,NtFree... @ 0.5675s
# Unique Mal. Pattern 11355 LdrLoadDll,LdrGetProcedureAddr... @ 0.5531s
# Unique Mal. Pattern 11356 LdrLoadDll,LdrGetProcedureAddr... @ 0.5541s
# Unique Mal. Pattern 11357 GetSystemTimeAsFileTime,LdrLoa... @ 0.5510s
# Unique Mal. Pattern 11358 GetSystemTimeAsFileTime,NtAllo... @ 0.5531s
# Unique Mal. Pattern 11359 GetSystemTimeAsFileTime,LdrGet... @ 0.5527s
# Unique Mal. Pattern 11360 GetSystemTimeAsFileTime,LdrLoa... @ 0.5720s
# Unique Mal. Pattern 11361 GetSystemTimeAsFileTime,LdrLoa... @ 0.5477s
# Unique Mal. Pattern 11362 GetSystemTimeAsFileTime,LdrLoa... @ 0.5563s
# Unique Mal. Pattern 11363 GetSystemTimeAsFileTime,LdrLoa... @ 0.5663s
# Unique Mal. Pattern 11364 SetUnhandledExceptionFilter,Nt... @ 0.5687s
# Unique Mal. Pattern 11365 GetSystemTimeAsFileTime,LdrLoa... @ 0.5711s
# Unique Mal. Pattern 11366 GetSystemTimeAsFileTime,LdrLoa... @ 0.5685s
# Unique Mal. Pattern 11367 GetSystemTimeAsFileTime,LdrLoa... @ 0.5647s
# Unique Mal. Pattern 11368 GetSystemTimeAsFileTime,LdrLoa... @ 0.5720s
# Unique Mal. Pattern 11369 NtClose,NtAllocateVirtualMemor... @ 0.5662s
# Unique Mal. Pattern 11370 GetSystemTimeAsFileTime,LdrLoa... @ 0.5710s
# Unique Mal. Pattern 11371 GetSystemTimeAsFileTime,LdrGet... @ 0.5673s
# Unique Mal. Pattern 11372 GetSystemTimeAsFileTime,LdrGet... @ 0.5555s
# Unique Mal. Pattern 11373 GetSystemTimeAsFileTime,LdrLoa... @ 0.5510s
# Unique Mal. Pattern 11374 GetSystemTimeAsFileTime,LdrLoa... @ 0.5686s
# Unique Mal. Pattern 11375 NtQueryInformationFile,NtClose... @ 0.5531s
# Unique Mal. Pattern 11376 __exception__,LdrLoadDll,__exc... @ 0.5532s
# Unique Mal. Pattern 11377 GetSystemTimeAsFileTime,LdrLoa... @ 0.5526s
# Unique Mal. Pattern 11378 GetSystemTimeAsFileTime,LdrLoa... @ 0.5681s
# Unique Mal. Pattern 11379 GetSystemTimeAsFileTime,LdrLoa... @ 0.5682s
# Unique Mal. Pattern 11380 GetSystemTimeAsFileTime,LdrLoa... @ 0.5712s
# Unique Mal. Pattern 11381 GetSystemTimeAsFileTime,LdrLoa... @ 0.5663s
# Unique Mal. Pattern 11382 GetSystemTimeAsFileTime,LdrLoa... @ 0.5667s
# Unique Mal. Pattern 11383 GetSystemTimeAsFileTime,LdrLoa... @ 0.5553s
# Unique Mal. Pattern 11384 GetSystemTimeAsFileTime,LdrLoa... @ 0.5676s
# Unique Mal. Pattern 11385 GetSystemTimeAsFileTime,LdrLoa... @ 0.5517s
# Unique Mal. Pattern 11386 GetSystemTimeAsFileTime,LdrLoa... @ 0.5688s
# Unique Mal. Pattern 11387 __exception__,NtAllocateVirtua... @ 0.5688s
# Unique Mal. Pattern 11388 GetSystemTimeAsFileTime,LdrLoa... @ 0.5706s
# Unique Mal. Pattern 11389 GetSystemTimeAsFileTime,LdrLoa... @ 0.5542s
# Unique Mal. Pattern 11390 NtAllocateVirtualMemory,NtCrea... @ 0.5653s
# Unique Mal. Pattern 11391 GetSystemTimeAsFileTime,LdrLoa... @ 0.5676s
# Unique Mal. Pattern 11392 GetSystemTimeAsFileTime,LdrLoa... @ 0.5686s
# Unique Mal. Pattern 11393 GetSystemTimeAsFileTime,LdrGet... @ 0.5566s
# Unique Mal. Pattern 11394 LdrLoadDll,LdrGetProcedureAddr... @ 0.5520s
# Unique Mal. Pattern 11395 GetSystemTimeAsFileTime,LdrLoa... @ 0.5650s
# Unique Mal. Pattern 11396 NtAllocateVirtualMemory,NtProt... @ 0.5573s
# Unique Mal. Pattern 11397 GetSystemTimeAsFileTime,LdrGet... @ 0.5677s
# Unique Mal. Pattern 11398 GetSystemTimeAsFileTime,LdrLoa... @ 0.5506s
# Unique Mal. Pattern 11399 GetSystemTimeAsFileTime,NtAllo... @ 0.5534s
# Unique Mal. Pattern 11400 GetSystemTimeAsFileTime,LdrLoa... @ 0.5697s
# Unique Mal. Pattern 11401 GetSystemTimeAsFileTime,LdrLoa... @ 0.5551s
# Unique Mal. Pattern 11402 GetSystemTimeAsFileTime,LdrLoa... @ 0.5667s
# Unique Mal. Pattern 11403 GetSystemTimeAsFileTime,LdrGet... @ 0.5516s
# Unique Mal. Pattern 11404 NtAllocateVirtualMemory,NtFree... @ 0.5844s
# Unique Mal. Pattern 11405 GetSystemTimeAsFileTime,LdrLoa... @ 0.5563s
# Unique Mal. Pattern 11406 GetSystemTimeAsFileTime,LdrLoa... @ 0.5653s
# Unique Mal. Pattern 11407 __exception__,GetSystemTimeAsF... @ 0.5686s
# Unique Mal. Pattern 11408 GetSystemTimeAsFileTime,LdrLoa... @ 0.5545s
# Unique Mal. Pattern 11409 __exception__,NtAllocateVirtua... @ 0.5683s
# Unique Mal. Pattern 11410 GetSystemTimeAsFileTime,LdrLoa... @ 0.5689s
# Unique Mal. Pattern 11411 GetSystemTimeAsFileTime,LdrLoa... @ 0.5674s
# Unique Mal. Pattern 11412 GetSystemTimeAsFileTime,LdrLoa... @ 0.5530s
# Unique Mal. Pattern 11413 GetSystemTimeAsFileTime,LdrLoa... @ 0.5721s
# Unique Mal. Pattern 11414 GetSystemTimeAsFileTime,LdrGet... @ 0.5666s
# Unique Mal. Pattern 11415 GetSystemTimeAsFileTime,LdrLoa... @ 0.5686s
# Unique Mal. Pattern 11416 RegOpenKeyExA,NtClose,NtQueryA... @ 0.5667s
# Unique Mal. Pattern 11417 NtAllocateVirtualMemory,SetErr... @ 0.5676s
# Unique Mal. Pattern 11418 GetSystemTimeAsFileTime,LdrLoa... @ 0.5708s
# Unique Mal. Pattern 11419 GetSystemTimeAsFileTime,LdrLoa... @ 0.5531s
# Unique Mal. Pattern 11420 GetSystemTimeAsFileTime,LdrLoa... @ 0.5675s
# Unique Mal. Pattern 11421 GetSystemTimeAsFileTime,LdrLoa... @ 0.5530s
# Unique Mal. Pattern 11422 GetSystemTimeAsFileTime,LdrLoa... @ 0.5553s
# Unique Mal. Pattern 11423 NtAllocateVirtualMemory,SetErr... @ 0.5797s
# Unique Mal. Pattern 11424 GetSystemTimeAsFileTime,NtAllo... @ 0.5573s
# Unique Mal. Pattern 11425 GetSystemTimeAsFileTime,LdrGet... @ 0.5511s
# Unique Mal. Pattern 11426 GetSystemTimeAsFileTime,LdrLoa... @ 0.5564s
# Unique Mal. Pattern 11427 GetSystemTimeAsFileTime,LdrLoa... @ 0.5494s
# Unique Mal. Pattern 11428 NtAllocateVirtualMemory,SetErr... @ 0.5533s
# Unique Mal. Pattern 11429 GetSystemTimeAsFileTime,LdrGet... @ 0.5562s
# Unique Mal. Pattern 11430 LdrLoadDll,LdrGetProcedureAddr... @ 0.5485s
# Unique Mal. Pattern 11431 FindWindowW,NtClose,NtOpenKey,... @ 0.5712s
# Unique Mal. Pattern 11432 SetErrorMode,OleInitialize,Ldr... @ 0.5709s
# Unique Mal. Pattern 11433 SetUnhandledExceptionFilter,Nt... @ 0.5665s
# Unique Mal. Pattern 11434 NtAllocateVirtualMemory,NtFree... @ 0.5674s
# Unique Mal. Pattern 11435 FindResourceExW,LoadStringW,Fi... @ 0.5686s
# Unique Mal. Pattern 11436 GetSystemTimeAsFileTime,LdrLoa... @ 0.5692s
# Unique Mal. Pattern 11437 GetShortPathNameW,LdrLoadDll,G... @ 0.5682s
# Unique Mal. Pattern 11438 SetErrorMode,OleInitialize,Ldr... @ 0.5708s
# Unique Mal. Pattern 11439 GetSystemTimeAsFileTime,LdrLoa... @ 0.5664s
# Unique Mal. Pattern 11440 GetSystemTimeAsFileTime,LdrLoa... @ 0.5677s
# Unique Mal. Pattern 11441 GetSystemTimeAsFileTime,LdrLoa... @ 0.5562s
# Unique Mal. Pattern 11442 GetSystemTimeAsFileTime,LdrLoa... @ 0.5520s
# Unique Mal. Pattern 11443 GetSystemTimeAsFileTime,LdrLoa... @ 0.5665s
# Unique Mal. Pattern 11444 FindResourceExA,LoadResource,N... @ 0.5552s
# Unique Mal. Pattern 11445 GetSystemTimeAsFileTime,LdrLoa... @ 0.5520s
# Unique Mal. Pattern 11446 NtDelayExecution,NtClose,NtOpe... @ 0.5697s
# Unique Mal. Pattern 11447 GetSystemTimeAsFileTime,LdrLoa... @ 0.5531s
# Unique Mal. Pattern 11448 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5673s
# Unique Mal. Pattern 11449 GetSystemTimeAsFileTime,NtAllo... @ 0.5532s
# Unique Mal. Pattern 11450 GetSystemTimeAsFileTime,LdrLoa... @ 0.5666s
# Unique Mal. Pattern 11451 GetSystemTimeAsFileTime,LdrLoa... @ 0.5528s
# Unique Mal. Pattern 11452 GetSystemTimeAsFileTime,LdrLoa... @ 0.5712s
# Unique Mal. Pattern 11453 GetSystemTimeAsFileTime,NtAllo... @ 0.5666s
# Unique Mal. Pattern 11454 GetSystemTimeAsFileTime,LdrLoa... @ 0.5529s
# Unique Mal. Pattern 11455 NtAllocateVirtualMemory,SetErr... @ 0.5687s
# Unique Mal. Pattern 11456 NtAllocateVirtualMemory,SetErr... @ 0.5707s
# Unique Mal. Pattern 11457 GetSystemTimeAsFileTime,LdrGet... @ 0.5663s
# Unique Mal. Pattern 11458 GetSystemTimeAsFileTime,LdrLoa... @ 0.5568s
# Unique Mal. Pattern 11459 GetSystemTimeAsFileTime,LdrLoa... @ 0.5650s
# Unique Mal. Pattern 11460 GetSystemTimeAsFileTime,LdrGet... @ 0.5530s
# Unique Mal. Pattern 11461 NtAllocateVirtualMemory,SetErr... @ 0.5555s
# Unique Mal. Pattern 11462 GetSystemTimeAsFileTime,NtAllo... @ 0.6310s
# Unique Mal. Pattern 11463 GetSystemTimeAsFileTime,LdrLoa... @ 0.6032s
# Unique Mal. Pattern 11464 GetSystemTimeAsFileTime,LdrLoa... @ 0.5865s
# Unique Mal. Pattern 11465 NtAllocateVirtualMemory,SetErr... @ 0.5869s
# Unique Mal. Pattern 11466 GetSystemTimeAsFileTime,LdrLoa... @ 0.5686s
# Unique Mal. Pattern 11467 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5705s
# Unique Mal. Pattern 11468 GetSystemTimeAsFileTime,NtAllo... @ 0.5701s
# Unique Mal. Pattern 11469 RegOpenKeyExA,NtClose,NtQueryA... @ 0.5655s
# Unique Mal. Pattern 11470 GetSystemTimeAsFileTime,LdrGet... @ 0.5552s
# Unique Mal. Pattern 11471 GetSystemTimeAsFileTime,LdrLoa... @ 0.5519s
# Unique Mal. Pattern 11472 GetSystemTimeAsFileTime,LdrLoa... @ 0.5551s
# Unique Mal. Pattern 11473 GetSystemTimeAsFileTime,LdrLoa... @ 0.5653s
# Unique Mal. Pattern 11474 GetSystemTimeAsFileTime,LdrLoa... @ 0.5533s
# Unique Mal. Pattern 11475 NtAllocateVirtualMemory,SetErr... @ 0.5539s
# Unique Mal. Pattern 11476 GetSystemTimeAsFileTime,LdrLoa... @ 0.5708s
# Unique Mal. Pattern 11477 GetSystemTimeAsFileTime,LdrGet... @ 0.5654s
# Unique Mal. Pattern 11478 GetSystemTimeAsFileTime,LdrLoa... @ 0.5719s
# Unique Mal. Pattern 11479 GetSystemTimeAsFileTime,LdrGet... @ 0.5644s
# Unique Mal. Pattern 11480 LdrLoadDll,__exception__,LdrGe... @ 0.5710s
# Unique Mal. Pattern 11481 RegOpenKeyExA,NtOpenKey,NtQuer... @ 0.5664s
# Unique Mal. Pattern 11482 NtAllocateVirtualMemory,NtFree... @ 0.5573s
# Unique Mal. Pattern 11483 GetSystemTimeAsFileTime,LdrLoa... @ 0.5517s
# Unique Mal. Pattern 11484 GetSystemTimeAsFileTime,LdrLoa... @ 0.5532s
# Unique Mal. Pattern 11485 GetSystemTimeAsFileTime,LdrLoa... @ 0.5696s
# Unique Mal. Pattern 11486 LdrLoadDll,LdrGetProcedureAddr... @ 0.5521s
# Unique Mal. Pattern 11487 GetSystemTimeAsFileTime,LdrLoa... @ 0.5673s
# Unique Mal. Pattern 11488 GetSystemTimeAsFileTime,GetSys... @ 0.5533s
# Unique Mal. Pattern 11489 LdrGetDllHandle,IsDebuggerPres... @ 0.5552s
# Unique Mal. Pattern 11490 GetSystemTimeAsFileTime,LdrLoa... @ 0.5519s
# Unique Mal. Pattern 11491 GetSystemTimeAsFileTime,LdrLoa... @ 0.5510s

# %%
str_output = ""
size = len(benign_patterns) * len(malicious_patterns)
for r in ratios:
    ratio += r['ratio']
ratio /= size
ratios.sort(reverse=True,key=lambda ratio: ratio['ratio'])
str_output += f"Average Similarity Ratio: {ratio*100:.4f}%\n"
str_output += f"Time Elapsed: {elapsed:0.4f}s\n"
str_output += f"Time per Sample: {elapsed/size:0.4f}s\n"

with open("./Output/3 Similarity Ratio.txt", 'w') as f:
    f.write(str_output)
    f.flush()
    f.close()

# %% [markdown]
# ### Distribution of Similarity Ratios
#
# The graph that the code block below produces indicates the most common similarity ratio between malicious and benign samples in terms of unique API calls.
#
# Being bias on the left means that most malicious API Call Patterns are different to that found in benign API Call Patterns (but that does not mean that there are no same ones that exist).
#
# Being bias on the right means that most malicious API Call Patterns are the same to that found in benign API Call Patterns (but that does not mean that there are no different ones that exist).

# %%
ratio_only = []
for r in ratios:
    ratio_only.append(r['ratio'])
plt.figure(figsize=(10,5), dpi=300)
plt.title('Distribution of Similarity Ratios between\nUnique Malicious & Unique Benign API Call Patterns')
plt.xlabel('Similarity Ratios')
plt.ylabel('# of Instances')
n, bins, patches = plt.hist(ratio_only, bins=5000, orientation='vertical', log=True)
plt.savefig("./Output/3 Distribution_Similarity_Ratio_Log.png")
plt.show()

# %%
ratio_only = []
for r in ratios:
    ratio_only.append(r['ratio'])
plt.figure(figsize=(10,5), dpi=300)
plt.title('Distribution of Similarity Ratios between\nUnique Malicious & Unique Benign API Call Patterns')
plt.xlabel('Similarity Ratios')
plt.ylabel('# of Instances')
n, bins, patches = plt.hist(ratio_only, bins=5000, orientation='vertical', log=False)
plt.savefig("./Output/3 Distribution_Similarity_Ratio.png")
plt.show()

# %%
def print_comparison(types:str, ratios:list, max:int, rank='Most'):
    if max > len(ratios):
        print(f"The specified `max` value ({max}) exceeds the number available ratios to select.")
        max = len(ratios)
    states = []
    output = "====================================================================================\n\n"
    for r in range(0,max):
        output += f"MATCH {r+1}\n"
        output += f"Malicious Counts: {len(ratios[r]['malicious_hash'])}\n"
        # for t in range(len(ratios[r]['malicious_hash'])): # All malicious hashes that have the same API Call
        #     output += f"\t{ratios[r]['malicious_hash'][t]} - {ratios[r]['type'][t]}" + "\n"
        #output += f"Benign Counts: {len(ratios[r]['benign_hash'])}\n"
        # for b in range(len(ratios[r]['benign_hash'])): # All benign hashes that have the same API Call Pattern
        #     output += f"\t{ratios[r]['benign_hash'][b]}\n"
        counts = pd.Series(ratios[r]['type'])
        output += "\nMalware Type Counts:\n"
        output += counts.value_counts().to_string() + "\n"        
        output += f"Score: {ratios[r]['ratio']:.4f}\n" # Similarity Ratio
        output += f"\nMalicious API Call Pattern: {ratios[r]['malicious_pattern']}\n" # API Call Pattern (from Malicious)
        output += f"Benign API Call Pattern: {ratios[r]['benign_pattern']}\n" # API Call Pattern (from Benign)
        output += "\n"
        for t in range(len(ratios[r]['malicious_hash'])): # Malware Types of matching Malicious Samples
            states.append(ratios[r]['type'][t]) 
        output += "====================================================================================\n\n"
    common_states = pd.Series(states).sort_values()
    output += "\n"
    output += f"Malware Types of the Top {max} {rank} Matching API Call Patterns to Benign Samples:\n"
    output += str(pd.Series(common_states).sort_values().value_counts()) + "\n"
    print(output, file=open(f"./Output/3 {types}.txt",'w'))
    print(output)

# %% [markdown]
# ## High Matching Ratios
#
# Samples with high matching ratio in terms of pattern (i.e., states) are ideally the following:
# 1. The malicious sample is a `trojan` hence must have similar behaviors as a benign software. It might be the limitation of the dataset having only the first 100 API calls and may not have included the rest.
# 2. The malicious sample is falsely labelled (i.e., `_ _ _`)as malicious (i.e., false-positive) which is supported by it matching the behavior of benign samples.

# %%
# MOST SIMILAR API CALL PATTERNS TO BOTH MALICIOUS AND BENIGN SAMPLES
top = 20 # Modify to Top n Most Similar/Different
ratios.sort(reverse=True,key=lambda ratio: ratio['ratio'])
print_comparison("HighMatching_Similar", ratios, top)
# Out:
# ====================================================================================
#
# MATCH 1
# Malicious Counts: 485
#
# Malware Type Counts:
# trojan        480
# downloader      2
# pua             2
# adware          1
# Score: 1.0000
#
# Malicious API Call Pattern: GetSystemTimeAsFileTime,GetSystemInfo,NtCreateMutant,GetSystemTimeAsFileTime,NtOpenKey,NtOpenKeyEx,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumKeyExW,RegOpenKeyExW,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumValueW,LdrGetProcedureAddress,RegCloseKey,GetFileAttributesW,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryValueExW,LdrGetProcedureAddress,RegQueryValueExW,RegCloseKey,FindFirstFileExW,RegOpenKeyExW,RegQueryInfoKeyW,RegEnumValueW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,FindFirstFileExW,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,FindFirstFileExW,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,LdrGetDllHandle,LdrGetProcedureAddress,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,NtQuerySystemInformation,NtProtectVirtualMemory,GetSystemDirectoryW,LdrGetDllHandle,LdrLoadDll,GetSystemDirectoryW,LdrGetDllHandle,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,NtOpenKey,NtQueryValueKey,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtEnumerateKey,NtOpenKey,NtQueryValueKey,NtClose,NtEnumerateKey,NtClose,NtOpenKey,NtClose,NtOpenKey,NtEnumerateValueKey,NtClose,NtOpenKey,NtClose,NtOpenKey,NtEnumerateValueKey,NtClose,NtOpenKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKeyEx,NtQueryValueKey,NtClose
# Benign API Call Pattern: GetSystemTimeAsFileTime,GetSystemInfo,NtCreateMutant,GetSystemTimeAsFileTime,NtOpenKey,NtOpenKeyEx,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumKeyExW,RegOpenKeyExW,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumValueW,LdrGetProcedureAddress,RegCloseKey,GetFileAttributesW,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryValueExW,LdrGetProcedureAddress,RegQueryValueExW,RegCloseKey,FindFirstFileExW,RegOpenKeyExW,RegQueryInfoKeyW,RegEnumValueW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,FindFirstFileExW,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,FindFirstFileExW,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,LdrGetDllHandle,LdrGetProcedureAddress,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,NtQuerySystemInformation,NtProtectVirtualMemory,GetSystemDirectoryW,LdrGetDllHandle,LdrLoadDll,GetSystemDirectoryW,LdrGetDllHandle,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,NtOpenKey,NtQueryValueKey,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtEnumerateKey,NtOpenKey,NtQueryValueKey,NtClose,NtEnumerateKey,NtClose,NtOpenKey,NtClose,NtOpenKey,NtEnumerateValueKey,NtClose,NtOpenKey,NtClose,NtOpenKey,NtEnumerateValueKey,NtClose,NtOpenKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKeyEx,NtQueryValueKey,NtClose
#
# ====================================================================================
#
# MATCH 2
# Malicious Counts: 146
#
# Malware Type Counts:
# trojan    126
# pua        20
# Score: 1.0000
#
# Malicious API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetSystemInfo,NtAllocateVirtualMemory,RegOpenKeyExW,FindFirstFileExW,LoadStringW,LdrLoadDll,LdrGetProcedureAddress,GetNativeSystemInfo,LoadStringW,LdrGetDllHandle,LdrGetProcedureAddress,RegOpenKeyExW,NtOpenKey,NtQueryValueKey,LdrGetDllHandle,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetTimeZoneInformation,LoadStringW,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,SetErrorMode,LdrLoadDll,SetErrorMode,LdrLoadDll,SetErrorMode,GetSystemMetrics,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW
# Benign API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetSystemInfo,NtAllocateVirtualMemory,RegOpenKeyExW,FindFirstFileExW,LoadStringW,LdrLoadDll,LdrGetProcedureAddress,GetNativeSystemInfo,LoadStringW,LdrGetDllHandle,LdrGetProcedureAddress,RegOpenKeyExW,NtOpenKey,NtQueryValueKey,LdrGetDllHandle,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetTimeZoneInformation,LoadStringW
#
# ====================================================================================
#
# MATCH 3
# Malicious Counts: 685
#
# Malware Type Counts:
# trojan        677
# miner           3
# pua             3
# downloader      2
# Score: 1.0000
#
# Malicious API Call Pattern: GetSystemTimeAsFileTime,GetSystemInfo,NtCreateMutant,GetSystemTimeAsFileTime,NtOpenKey,NtOpenKeyEx,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumKeyExW,RegOpenKeyExW,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumValueW,LdrGetProcedureAddress,RegCloseKey,GetFileAttributesW,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryValueExW,LdrGetProcedureAddress,RegQueryValueExW,RegCloseKey,FindFirstFileExW,RegOpenKeyExW,RegQueryInfoKeyW,RegEnumValueW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,FindFirstFileExW,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,FindFirstFileExW,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,LdrGetDllHandle,LdrGetProcedureAddress,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,NtQuerySystemInformation,NtProtectVirtualMemory,GetSystemDirectoryW,LdrGetDllHandle,LdrLoadDll,GetSystemDirectoryW,LdrGetDllHandle,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,NtClose,NtOpenKeyEx,NtQueryValueKey,NtClose,LdrLoadDll,LdrGetProcedureAddress,GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProcedureAddress,NtCreateFile,GetFileSize,NtCreateSection,NtMapViewOfSection,GetSystemInfo,NtClose,NtUnmapViewOfSection,NtClose,NtCreateFile,GetFileSize,NtCreateSection,NtMapViewOfSection,GetSystemInfo,NtClose,NtUnmapViewOfSection,NtClose,RegOpenKeyExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,FindFirstFileExW,RegOpenKeyExW,RegQueryInfoKeyW,RegEnumValueW,RegCloseKey
# Benign API Call Pattern: GetSystemTimeAsFileTime,GetSystemInfo,NtCreateMutant,GetSystemTimeAsFileTime,NtOpenKey,NtOpenKeyEx,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumKeyExW,RegOpenKeyExW,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumValueW,LdrGetProcedureAddress,RegCloseKey,GetFileAttributesW,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryValueExW,LdrGetProcedureAddress,RegQueryValueExW,RegCloseKey,FindFirstFileExW,RegOpenKeyExW,RegQueryInfoKeyW,RegEnumValueW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,FindFirstFileExW,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,FindFirstFileExW,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,LdrGetDllHandle,LdrGetProcedureAddress,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,NtQuerySystemInformation,NtProtectVirtualMemory,GetSystemDirectoryW,LdrGetDllHandle,LdrLoadDll,GetSystemDirectoryW,LdrGetDllHandle,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,NtClose,NtOpenKeyEx,NtQueryValueKey,NtClose,LdrLoadDll,LdrGetProcedureAddress,GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProcedureAddress,NtCreateFile,GetFileSize,NtCreateSection,NtMapViewOfSection,GetSystemInfo,NtClose,NtUnmapViewOfSection,NtClose,NtCreateFile,GetFileSize,NtCreateSection,NtMapViewOfSection,GetSystemInfo,NtClose,NtUnmapViewOfSection,NtClose,RegOpenKeyExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,FindFirstFileExW,RegOpenKeyExW,RegQueryInfoKeyW,RegEnumValueW,RegCloseKey
#
# ====================================================================================
#
# MATCH 4
# Malicious Counts: 304
#
# Malware Type Counts:
# trojan        303
# downloader      1
# Score: 1.0000
#
# Malicious API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetSystemInfo,NtAllocateVirtualMemory,RegOpenKeyExW,FindFirstFileExW,LoadStringW,LdrLoadDll,LdrGetProcedureAddress,GetNativeSystemInfo,LoadStringW,LdrGetDllHandle,LdrGetProcedureAddress,RegOpenKeyExW,NtOpenKey,NtQueryValueKey,LdrGetDllHandle,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetTimeZoneInformation,LoadStringW,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,SetErrorMode,LdrLoadDll,SetErrorMode,LdrLoadDll,SetErrorMode,GetSystemMetrics,FindResourceExW,OleInitialize,FindResourceExW,LoadResource,FindResourceExW,LoadResource,NtClose,NtAllocateVirtualMemory,GetSystemMetrics,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll
# Benign API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetSystemInfo,NtAllocateVirtualMemory,RegOpenKeyExW,FindFirstFileExW,LoadStringW,LdrLoadDll,LdrGetProcedureAddress,GetNativeSystemInfo,LoadStringW,LdrGetDllHandle,LdrGetProcedureAddress,RegOpenKeyExW,NtOpenKey,NtQueryValueKey,LdrGetDllHandle,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetTimeZoneInformation,LoadStringW
#
# ====================================================================================
#
# MATCH 5
# Malicious Counts: 124
#
# Malware Type Counts:
# trojan    112
# pua        11
# adware      1
# Score: 1.0000
#
# Malicious API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetSystemInfo,NtAllocateVirtualMemory,RegOpenKeyExW,FindFirstFileExW,LoadStringW,LdrLoadDll,LdrGetProcedureAddress,GetNativeSystemInfo,LoadStringW,LdrGetDllHandle,LdrGetProcedureAddress,RegOpenKeyExW,NtOpenKey,NtQueryValueKey,LdrGetDllHandle,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetTimeZoneInformation,LoadStringW,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,SetErrorMode,LdrLoadDll,SetErrorMode,LdrLoadDll,SetErrorMode,GetSystemMetrics,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,OleInitialize
# Benign API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetSystemInfo,NtAllocateVirtualMemory,RegOpenKeyExW,FindFirstFileExW,LoadStringW,LdrLoadDll,LdrGetProcedureAddress,GetNativeSystemInfo,LoadStringW,LdrGetDllHandle,LdrGetProcedureAddress,RegOpenKeyExW,NtOpenKey,NtQueryValueKey,LdrGetDllHandle,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetTimeZoneInformation,LoadStringW,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,SetErrorMode,LdrLoadDll,SetErrorMode,LdrLoadDll,SetErrorMode
#
# ====================================================================================
#
# MATCH 6
# Malicious Counts: 261
#
# Malware Type Counts:
# trojan        237
# adware         11
# pua             5
# ransomware      4
# miner           3
# downloader      1
# Score: 1.0000
#
# Malicious API Call Pattern: GetSystemTimeAsFileTime,NtCreateMutant,GetSystemTimeAsFileTime,NtOpenKeyEx,NtQueryKey,NtOpenKeyEx,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumKeyExW,RegOpenKeyExW,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumValueW,LdrGetProcedureAddress,RegCloseKey,GetFileAttributesW,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryValueExW,RegCloseKey,NtOpenFile,NtQueryDirectoryFile,NtClose,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,RegOpenKeyExW,RegQueryInfoKeyW,RegEnumValueW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,NtOpenFile,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,NtOpenFile,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,GetSystemTimeAsFileTime,NtQuerySystemInformation,NtProtectVirtualMemory,GetSystemDirectoryW,LdrGetDllHandle,LdrLoadDll,GetSystemDirectoryW,LdrGetDllHandle,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,NtClose,NtQueryKey,NtOpenKeyEx,NtQueryValueKey,NtClose,GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProcedureAddress,GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProcedureAddress,NtCreateFile,GetFileSize,NtCreateSection,NtMapViewOfSection,GetSystemInfo,NtClose,NtUnmapViewOfSection,NtClose,NtCreateFile,GetFileSize,NtCreateSection,NtMapViewOfSection,GetSystemInfo,NtClose,NtUnmapViewOfSection,NtClose,RegOpenKeyExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,NtOpenFile
# Benign API Call Pattern: GetSystemTimeAsFileTime,NtCreateMutant,GetSystemTimeAsFileTime,NtOpenKeyEx,NtQueryKey,NtOpenKeyEx,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumKeyExW,RegOpenKeyExW,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumValueW,LdrGetProcedureAddress,RegCloseKey,GetFileAttributesW,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryValueExW,RegCloseKey,NtOpenFile,NtQueryDirectoryFile,NtClose,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,RegOpenKeyExW,RegQueryInfoKeyW,RegEnumValueW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,NtOpenFile,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,NtOpenFile,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,GetSystemTimeAsFileTime,NtQuerySystemInformation,NtProtectVirtualMemory,GetSystemDirectoryW,LdrGetDllHandle,LdrLoadDll,GetSystemDirectoryW,LdrGetDllHandle,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,NtClose,NtQueryKey,NtOpenKeyEx,NtQueryValueKey,NtClose,GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProcedureAddress,GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProcedureAddress,NtCreateFile,GetFileSize,NtCreateSection,NtMapViewOfSection,GetSystemInfo,NtClose,NtUnmapViewOfSection,NtClose,NtCreateFile,GetFileSize,NtCreateSection,NtMapViewOfSection,GetSystemInfo,NtClose,NtUnmapViewOfSection,NtClose,RegOpenKeyExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,NtOpenFile
#
# ====================================================================================
#
# MATCH 7
# Malicious Counts: 39
#
# Malware Type Counts:
# trojan    39
# Score: 1.0000
#
# Malicious API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetSystemInfo,NtAllocateVirtualMemory,RegOpenKeyExW,FindFirstFileExW,LoadStringW,LdrLoadDll,LdrGetProcedureAddress,GetNativeSystemInfo,LoadStringW,LdrGetDllHandle,LdrGetProcedureAddress,RegOpenKeyExW,NtOpenKey,NtQueryValueKey,LdrGetDllHandle,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetTimeZoneInformation,LoadStringW,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,SetErrorMode,LdrLoadDll,SetErrorMode,LdrLoadDll,SetErrorMode,GetSystemMetrics,FindResourceExW,OleInitialize,FindResourceExW,NtClose,NtAllocateVirtualMemory,GetSystemMetrics,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LookupAccountSidW,LdrGetProcedureAddress,LookupAccountSidW,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll
# Benign API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetSystemInfo,NtAllocateVirtualMemory,RegOpenKeyExW,FindFirstFileExW,LoadStringW,LdrLoadDll,LdrGetProcedureAddress,GetNativeSystemInfo,LoadStringW,LdrGetDllHandle,LdrGetProcedureAddress,RegOpenKeyExW,NtOpenKey,NtQueryValueKey,LdrGetDllHandle,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetTimeZoneInformation,LoadStringW,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,SetErrorMode,LdrLoadDll,SetErrorMode,LdrLoadDll,SetErrorMode
#
# ====================================================================================
#
# MATCH 8
# Malicious Counts: 46
#
# Malware Type Counts:
# adware      38
# trojan       4
# pua          3
# hacktool     1
# Score: 1.0000
#
# Malicious API Call Pattern: SetErrorMode,LdrGetDllHandle,LdrGetProcedureAddress,GetSystemDirectoryW,NtAllocateVirtualMemory,NtFreeVirtualMemory,NtAllocateVirtualMemory,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,GetSystemDirectoryW,GetSystemWindowsDirectoryW,GetSystemDirectoryW,RegOpenKeyExA,GetSystemWindowsDirectoryW,LoadStringW,GetSystemWindowsDirectoryW,GetSystemDirectoryW,RegOpenKeyExW,LdrLoadDll,LdrGetProcedureAddress,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,RegCloseKey,NtCreateMutant,GetNativeSystemInfo,GetSystemWindowsDirectoryW,NtClose,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,GetSystemDirectoryW,NtAllocateVirtualMemory,LdrGetDllHandle,LdrGetProcedureAddress,NtQueryAttributesFile,NtCreateFile,NtCreateSection,NtMapViewOfSection,NtClose,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,LdrGetDllHandle,GetSystemDirectoryW,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,GetSystemDirectoryW,LdrLoadDll,LdrGetProcedureAddress,OleInitialize,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtOpenSection,NtMapViewOfSection,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,NtClose,LdrLoadDll,LdrGetProcedureAddress,GetSystemWindowsDirectoryW,NtCreateFile,NtCreateSection,NtMapViewOfSection,NtClose
# Benign API Call Pattern: SetErrorMode,LdrGetDllHandle,LdrGetProcedureAddress,GetSystemDirectoryW,NtAllocateVirtualMemory,NtFreeVirtualMemory,NtAllocateVirtualMemory,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,GetSystemDirectoryW,GetSystemWindowsDirectoryW,GetSystemDirectoryW,RegOpenKeyExA,GetSystemWindowsDirectoryW,LoadStringW,GetSystemWindowsDirectoryW,GetSystemDirectoryW,RegOpenKeyExW,LdrLoadDll,LdrGetProcedureAddress,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,RegCloseKey,NtCreateMutant,GetNativeSystemInfo,GetSystemWindowsDirectoryW,NtClose,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,GetSystemDirectoryW,NtAllocateVirtualMemory,LdrGetDllHandle,LdrGetProcedureAddress,NtQueryAttributesFile,NtCreateFile,NtCreateSection,NtMapViewOfSection,NtClose,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,LdrGetDllHandle,GetSystemDirectoryW,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,GetSystemDirectoryW,LdrLoadDll,LdrGetProcedureAddress,OleInitialize,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtOpenSection,NtMapViewOfSection,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,NtClose,LdrLoadDll,LdrGetProcedureAddress,GetSystemWindowsDirectoryW,NtCreateFile,NtCreateSection,NtMapViewOfSection,NtClose
#
# ====================================================================================
#
# MATCH 9
# Malicious Counts: 10
#
# Malware Type Counts:
# trojan    8
# pua       2
# Score: 1.0000
#
# Malicious API Call Pattern: SetErrorMode,LdrGetDllHandle,LdrGetProcedureAddress,GetSystemDirectoryW,NtAllocateVirtualMemory,NtFreeVirtualMemory,NtAllocateVirtualMemory,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,GetSystemDirectoryW,GetSystemWindowsDirectoryW,GetSystemDirectoryW,RegOpenKeyExA,GetSystemWindowsDirectoryW,LoadStringW,GetSystemWindowsDirectoryW,GetSystemDirectoryW,RegOpenKeyExW,LdrLoadDll,LdrGetProcedureAddress,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,RegCloseKey,NtCreateMutant,GetNativeSystemInfo,GetSystemWindowsDirectoryW,NtClose,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,GetSystemDirectoryW,NtAllocateVirtualMemory,LdrGetDllHandle,LdrGetProcedureAddress,NtQueryAttributesFile,NtCreateFile,NtCreateSection,NtMapViewOfSection,NtClose,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,LdrGetDllHandle,GetSystemDirectoryW,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,GetSystemDirectoryW,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,OleInitialize,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtOpenSection,NtMapViewOfSection,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,NtClose,LdrLoadDll,LdrGetProcedureAddress,GetSystemWindowsDirectoryW,NtCreateFile,NtCreateSection
# Benign API Call Pattern: SetErrorMode,LdrGetDllHandle,LdrGetProcedureAddress,GetSystemDirectoryW,NtAllocateVirtualMemory,NtFreeVirtualMemory,NtAllocateVirtualMemory,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,GetSystemDirectoryW,GetSystemWindowsDirectoryW,GetSystemDirectoryW,RegOpenKeyExA,GetSystemWindowsDirectoryW,LoadStringW,GetSystemWindowsDirectoryW,GetSystemDirectoryW,RegOpenKeyExW,LdrLoadDll,LdrGetProcedureAddress,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,RegCloseKey,NtCreateMutant,GetNativeSystemInfo,GetSystemWindowsDirectoryW,NtClose,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,GetSystemDirectoryW,NtAllocateVirtualMemory,LdrGetDllHandle,LdrGetProcedureAddress,NtQueryAttributesFile,NtCreateFile,NtCreateSection,NtMapViewOfSection,NtClose,LdrLoadDll,GetSystemDirectoryW,LdrLoadDll,LdrGetDllHandle,GetSystemDirectoryW,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,GetSystemDirectoryW,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,OleInitialize,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtOpenSection,NtMapViewOfSection,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,NtClose,LdrLoadDll,LdrGetProcedureAddress,GetSystemWindowsDirectoryW,NtCreateFile,NtCreateSection
#
# ====================================================================================
#
# MATCH 10
# Malicious Counts: 7
#
# Malware Type Counts:
# trojan    6
# miner     1
# Score: 1.0000
#
# Malicious API Call Pattern: GetSystemTimeAsFileTime,NtCreateMutant,GetSystemTimeAsFileTime,NtOpenKeyEx,NtQueryKey,NtOpenKeyEx,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumKeyExW,RegOpenKeyExW,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumValueW,LdrGetProcedureAddress,RegCloseKey,GetFileAttributesW,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryValueExW,RegCloseKey,NtOpenFile,NtQueryDirectoryFile,NtClose,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,RegOpenKeyExW,RegQueryInfoKeyW,RegEnumValueW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,NtOpenFile,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,NtOpenFile,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,GetSystemTimeAsFileTime,NtQuerySystemInformation,NtProtectVirtualMemory,GetSystemDirectoryW,LdrGetDllHandle,LdrLoadDll,GetSystemDirectoryW,LdrGetDllHandle,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,NtClose,NtOpenKey,NtClose,NtOpenKey,NtClose,NtOpenKey,NtEnumerateValueKey,NtClose,NtOpenKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtQueryKey,NtOpenKeyEx,NtQueryValueKey,NtClose,GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProcedureAddress,GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProcedureAddress,NtCreateFile,GetFileSize,NtCreateSection,NtMapViewOfSection,GetSystemInfo
# Benign API Call Pattern: GetSystemTimeAsFileTime,NtCreateMutant,GetSystemTimeAsFileTime,NtOpenKeyEx,NtQueryKey,NtOpenKeyEx,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumKeyExW,RegOpenKeyExW,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumValueW,LdrGetProcedureAddress,RegCloseKey,GetFileAttributesW,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryValueExW,RegCloseKey,NtOpenFile,NtQueryDirectoryFile,NtClose,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,RegOpenKeyExW,RegQueryInfoKeyW,RegEnumValueW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,NtOpenFile,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,NtOpenFile,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,GetSystemTimeAsFileTime,NtQuerySystemInformation,NtProtectVirtualMemory,GetSystemDirectoryW,LdrGetDllHandle,LdrLoadDll,GetSystemDirectoryW,LdrGetDllHandle,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,NtClose,NtOpenKey,NtClose,NtOpenKey,NtClose,NtOpenKey,NtEnumerateValueKey,NtClose,NtOpenKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtQueryKey,NtOpenKeyEx,NtQueryValueKey,NtClose,GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProcedureAddress,GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProcedureAddress,NtCreateFile,GetFileSize,NtCreateSection,NtMapViewOfSection,GetSystemInfo
#
# ====================================================================================
#
# MATCH 11
# Malicious Counts: 10
#
# Malware Type Counts:
# trojan     9
# spyware    1
# Score: 1.0000
#
# Malicious API Call Pattern: GetSystemTimeAsFileTime,NtOpenKey,NtQueryValueKey,NtClose,NtCreateMutant,GetSystemTimeAsFileTime,NtOpenKeyEx,NtQueryKey,NtOpenKeyEx,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumKeyExW,RegOpenKeyExW,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumValueW,LdrGetProcedureAddress,RegCloseKey,GetFileAttributesW,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryValueExW,RegCloseKey,NtOpenFile,NtQueryDirectoryFile,NtClose,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,RegOpenKeyExW,RegQueryInfoKeyW,RegEnumValueW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,NtOpenFile,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,NtOpenFile,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,GetSystemTimeAsFileTime,NtQuerySystemInformation,NtProtectVirtualMemory,GetSystemDirectoryW,LdrGetDllHandle,LdrLoadDll,GetSystemDirectoryW,LdrGetDllHandle,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,NtClose,NtQueryKey,NtOpenKeyEx,NtQueryValueKey,NtClose,GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProcedureAddress,GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProcedureAddress,NtCreateFile,GetFileSize,NtCreateSection,NtMapViewOfSection,GetSystemInfo,NtClose,NtUnmapViewOfSection,NtClose,NtCreateFile,GetFileSize,NtCreateSection,NtMapViewOfSection,GetSystemInfo,NtClose,NtUnmapViewOfSection,NtClose,RegOpenKeyExW,RegCloseKey,RegOpenKeyExW
# Benign API Call Pattern: GetSystemTimeAsFileTime,NtOpenKey,NtQueryValueKey,NtClose,NtCreateMutant,GetSystemTimeAsFileTime,NtOpenKeyEx,NtQueryKey,NtOpenKeyEx,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumKeyExW,RegOpenKeyExW,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumValueW,LdrGetProcedureAddress,RegCloseKey,GetFileAttributesW,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryValueExW,RegCloseKey,NtOpenFile,NtQueryDirectoryFile,NtClose,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,RegOpenKeyExW,RegQueryInfoKeyW,RegEnumValueW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,NtOpenFile,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,NtOpenFile,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,GetSystemTimeAsFileTime,NtQuerySystemInformation,NtProtectVirtualMemory,GetSystemDirectoryW,LdrGetDllHandle,LdrLoadDll,GetSystemDirectoryW,LdrGetDllHandle,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,NtClose,NtQueryKey,NtOpenKeyEx,NtQueryValueKey,NtClose,GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProcedureAddress,GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProcedureAddress,NtCreateFile,GetFileSize,NtCreateSection,NtMapViewOfSection,GetSystemInfo,NtClose,NtUnmapViewOfSection,NtClose,NtCreateFile,GetFileSize,NtCreateSection,NtMapViewOfSection,GetSystemInfo,NtClose,NtUnmapViewOfSection,NtClose,RegOpenKeyExW,RegCloseKey,RegOpenKeyExW
#
# ====================================================================================
#
# MATCH 12
# Malicious Counts: 1
#
# Malware Type Counts:
# pua    1
# Score: 1.0000
#
# Malicious API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,SetUnhandledExceptionFilter,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtOpenFile,DeviceIoControl,CoInitializeEx,LdrGetDllHandle,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,SetErrorMode,GetFileAttributesW,SetErrorMode,GetFileAttributesW,SetErrorMode,SHGetFolderPathW,LdrGetDllHandle,LdrGetProcedureAddress,SetErrorMode,CoInitializeEx,GetFileAttributesW,NtAllocateVirtualMemory,GetFileAttributesW,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetFileAttributesW,NtCreateFile,NtReadFile,SetFilePointer,NtReadFile,SetFilePointer,NtReadFile,NtClose,NtCreateFile
# Benign API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,SetUnhandledExceptionFilter,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtOpenFile,DeviceIoControl,CoInitializeEx,LdrGetDllHandle,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,SetErrorMode,GetFileAttributesW,SetErrorMode,GetFileAttributesW,SetErrorMode,SHGetFolderPathW,LdrGetDllHandle,LdrGetProcedureAddress,SetErrorMode,CoInitializeEx,GetFileAttributesW,NtAllocateVirtualMemory,GetFileAttributesW,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetFileAttributesW,NtCreateFile,NtReadFile,SetFilePointer,NtReadFile,SetFilePointer,NtReadFile,NtClose,NtCreateFile
#
# ====================================================================================
#
# MATCH 13
# Malicious Counts: 1
#
# Malware Type Counts:
# adware    1
# Score: 1.0000
#
# Malicious API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetSystemInfo,NtAllocateVirtualMemory,RegOpenKeyExW,FindFirstFileExW,LoadStringW,LdrLoadDll,LdrGetProcedureAddress,GetNativeSystemInfo,LoadStringW,LdrGetDllHandle,LdrGetProcedureAddress,RegOpenKeyExW,NtOpenKey,NtQueryValueKey,LdrGetDllHandle,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetTimeZoneInformation,LoadStringW,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,SetErrorMode,LdrLoadDll,SetErrorMode,LdrLoadDll,SetErrorMode
# Benign API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetSystemInfo,NtAllocateVirtualMemory,RegOpenKeyExW,FindFirstFileExW,LoadStringW,LdrLoadDll,LdrGetProcedureAddress,GetNativeSystemInfo,LoadStringW,LdrGetDllHandle,LdrGetProcedureAddress,RegOpenKeyExW,NtOpenKey,NtQueryValueKey,LdrGetDllHandle,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetTimeZoneInformation,LoadStringW,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,SetErrorMode,LdrLoadDll,SetErrorMode,LdrLoadDll,SetErrorMode
#
# ====================================================================================
#
# MATCH 14
# Malicious Counts: 1
#
# Malware Type Counts:
# trojan    1
# Score: 1.0000
#
# Malicious API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetSystemInfo,NtAllocateVirtualMemory,RegOpenKeyExW,FindFirstFileExW,LoadStringW,LdrLoadDll,LdrGetProcedureAddress,GetNativeSystemInfo,LoadStringW,LdrGetDllHandle,LdrGetProcedureAddress,RegOpenKeyExW,NtOpenKey,NtQueryValueKey,LdrGetDllHandle,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetTimeZoneInformation,LoadStringW
# ...
# Benign API Call Pattern: GetSystemTimeAsFileTime,GetSystemInfo,NtOpenKey,NtQueryValueKey,NtClose,NtCreateMutant,GetSystemTimeAsFileTime,NtOpenKey,NtOpenKeyEx,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumKeyExW,RegOpenKeyExW,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumValueW,LdrGetProcedureAddress,RegCloseKey,GetFileAttributesW,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryValueExW,LdrGetProcedureAddress,RegQueryValueExW,RegCloseKey,FindFirstFileExW,RegOpenKeyExW,RegQueryInfoKeyW,RegEnumValueW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,FindFirstFileExW,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,FindFirstFileExW,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,LdrGetDllHandle,LdrGetProcedureAddress,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,NtQuerySystemInformation,NtProtectVirtualMemory,GetSystemDirectoryW,LdrGetDllHandle,LdrLoadDll,GetSystemDirectoryW,LdrGetDllHandle,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,NtOpenKey,NtQueryValueKey,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtEnumerateKey,NtOpenKey,NtQueryValueKey,NtClose,NtEnumerateKey,NtClose,NtOpenKey,NtClose,NtOpenKey,NtEnumerateValueKey,NtClose,NtOpenKey,NtClose,NtOpenKey,NtEnumerateValueKey,NtClose,NtOpenKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose
#
# ====================================================================================
#
# MATCH 17
# Malicious Counts: 2
#
# Malware Type Counts:
# pua    2
# Score: 0.9941
#
# Malicious API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetSystemInfo,NtAllocateVirtualMemory,RegOpenKeyExW,FindFirstFileExW,LoadStringW,LdrLoadDll,LdrGetProcedureAddress,GetNativeSystemInfo,LoadStringW,LdrGetDllHandle,LdrGetProcedureAddress,RegOpenKeyExW,NtOpenKey,NtQueryValueKey,LdrGetDllHandle,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetTimeZoneInformation,LoadStringW,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,SetErrorMode,LdrLoadDll,SetErrorMode,GetSystemMetrics,FindResourceExW
# Benign API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetSystemInfo,NtAllocateVirtualMemory,RegOpenKeyExW,FindFirstFileExW,LoadStringW,LdrLoadDll,LdrGetProcedureAddress,GetNativeSystemInfo,LoadStringW,LdrGetDllHandle,LdrGetProcedureAddress,RegOpenKeyExW,NtOpenKey,NtQueryValueKey,LdrGetDllHandle,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetTimeZoneInformation,LoadStringW,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,SetErrorMode,LdrLoadDll,SetErrorMode,LdrLoadDll,SetErrorMode
#
# ====================================================================================
#
# MATCH 18
# Malicious Counts: 8
#
# Malware Type Counts:
# trojan    8
# Score: 0.9907
#
# Malicious API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumKeyExW,RegOpenKeyExW,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumValueW,LdrGetProcedureAddress,RegCloseKey,NtQueryAttributesFile,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryValueExW,LdrGetProcedureAddress,RegQueryValueExW,RegCloseKey,FindFirstFileExW,RegOpenKeyExW,RegQueryInfoKeyW,RegEnumValueW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,FindFirstFileExW,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,FindFirstFileExW,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,LdrGetDllHandle,LdrGetProcedureAddress,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,LdrLoadDll,LdrGetProcedureAddress,NtCreateFile,GetFileSize,NtCreateSection,NtMapViewOfSection,GetSystemInfo,NtClose,NtUnmapViewOfSection,NtClose,NtCreateFile,GetFileSize,NtCreateSection,NtMapViewOfSection,GetSystemInfo,NtClose,NtUnmapViewOfSection,NtClose,RegOpenKeyExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,FindFirstFileExW,NtClose,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,FindFirstFileExW,NtClose,CreateActCtxW,NtProtectVirtualMemory,NtAllocateVirtualMemory,NtFreeVirtualMemory,NtAllocateVirtualMemory,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress
# Benign API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumKeyExW,RegOpenKeyExW,RegQueryInfoKeyW,LdrGetProcedureAddress,RegEnumValueW,LdrGetProcedureAddress,RegCloseKey,GetFileAttributesW,RegOpenKeyExW,LdrGetProcedureAddress,RegQueryValueExW,LdrGetProcedureAddress,RegQueryValueExW,RegCloseKey,FindFirstFileExW,RegOpenKeyExW,RegQueryInfoKeyW,RegEnumValueW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,FindFirstFileExW,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,RegOpenKeyExW,RegQueryInfoKeyW,RegCloseKey,FindFirstFileExW,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,LdrGetDllHandle,LdrGetProcedureAddress,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,LdrLoadDll,LdrGetProcedureAddress,NtCreateFile,GetFileSize,NtCreateSection,NtMapViewOfSection,GetSystemInfo,NtClose,NtUnmapViewOfSection,NtClose,NtCreateFile,GetFileSize,NtCreateSection,NtMapViewOfSection,GetSystemInfo,NtClose,NtUnmapViewOfSection,NtClose,RegOpenKeyExW,RegCloseKey,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,FindFirstFileExW,NtClose,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,FindFirstFileExW,NtClose,CreateActCtxW,NtProtectVirtualMemory,NtAllocateVirtualMemory,NtFreeVirtualMemory,NtAllocateVirtualMemory,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress
#
# ====================================================================================
#
# MATCH 19
# Malicious Counts: 42
#
# Malware Type Counts:
# trojan    42
# Score: 0.9900
#
# Malicious API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetSystemInfo,NtAllocateVirtualMemory,RegOpenKeyExW,FindFirstFileExW,LoadStringW,LdrLoadDll,LdrGetProcedureAddress,GetNativeSystemInfo,LoadStringW,LdrGetDllHandle,LdrGetProcedureAddress,RegOpenKeyExW,NtOpenKey,NtQueryValueKey,LdrGetDllHandle,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetTimeZoneInformation,LoadStringW,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,SetErrorMode,LdrLoadDll,SetErrorMode,LdrLoadDll,SetErrorMode,GetSystemMetrics,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,OleInitialize,FindResourceExW,LoadResource
# Benign API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,GetSystemInfo,NtAllocateVirtualMemory,RegOpenKeyExW,FindFirstFileExW,LoadStringW,LdrLoadDll,LdrGetProcedureAddress,GetNativeSystemInfo,LoadStringW,LdrGetDllHandle,LdrGetProcedureAddress,RegOpenKeyExW,NtOpenKey,NtQueryValueKey,LdrGetDllHandle,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LoadStringW,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,SetErrorMode,LdrLoadDll,SetErrorMode,LdrLoadDll,SetErrorMode,GetSystemMetrics,FindResourceExW,LoadResource,FindResourceExW,LoadResource
#
# ====================================================================================
#
# MATCH 20
# Malicious Counts: 2
#
# Malware Type Counts:
# trojan    1
# pua       1
# Score: 0.9900
#
# Malicious API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,RegOpenKeyExA,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtQueryAttributesFile,LoadStringA,NtAllocateVirtualMemory,LoadStringA,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LoadStringA,LdrGetProcedureAddress,GetSystemMetrics,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,LdrGetProcedureAddress,FindResourceExW,LoadResource,FindResourceExW,LoadResource,NtAllocateVirtualMemory,GetSystemMetrics,NtClose,GetSystemMetrics,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress
# Benign API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,RegOpenKeyExA,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtQueryAttributesFile,LoadStringA,NtAllocateVirtualMemory,LoadStringA,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LoadStringA,LdrGetProcedureAddress,GetSystemMetrics,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,FindResourceExW,LoadResource,LdrGetProcedureAddress,FindResourceExW,LoadResource,FindResourceExW,LoadResource,NtAllocateVirtualMemory,GetSystemMetrics,NtClose,GetSystemMetrics,NtAllocateVirtualMemory,GetSystemMetrics,LdrLoadDll
#
# ====================================================================================
#
#
# Malware Types of the Top 20 Most Matching API Call Patterns to Benign Samples:
# trojan        2055
# adware          52
# pua             50
# miner            7
# downloader       6
# ransomware       4
# hacktool         1
# spyware          1
# Name: count, dtype: int64

# %% [markdown]
# ## Low Matching Ratios
#
# Samples with low matching ratio in terms of pattern (i.e., states) are ideally the following:
# 1. The malicious sample is a `trojan` hence must have similar behaviors as a benign software. It might be the limitation of the dataset having only the first 100 API calls and may not have included the rest.
# 2. The malicious sample is falsely labelled as malicious (i.e., false-positive) which is supported by it matching the behavior of benign samples.

# %%
# MOST DIFFERENT API CALL PATTERNS TO BOTH MALICIOUS AND BENIGN SAMPLES
ratios.sort(reverse=False,key=lambda ratio: ratio['ratio'])
print_comparison("LowMatching_Different",ratios, top, 'Least')
# Out:
# ====================================================================================
#
# MATCH 1
# Malicious Counts: 1
#
# Malware Type Counts:
# trojan    1
# Score: 0.1501
#
# Malicious API Call Pattern: NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,LdrLoadDll,LdrGetProcedureAddress,GetSystemWindowsDirectoryW,NtCreateFile,NtCreateSection,NtMapViewOfSection,NtClose,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress
# Benign API Call Pattern: GetSystemTimeAsFileTime,SetUnhandledExceptionFilter,CoInitializeEx,CreateThread,NtClose,CoCreateInstance,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,NtClose,RegOpenKeyExW,LdrLoadDll,LdrGetProcedureAddress,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW
#
# ====================================================================================
#
# MATCH 2
# Malicious Counts: 1
#
# Malware Type Counts:
# trojan    1
# Score: 0.1508
#
# Malicious API Call Pattern: NtAllocateVirtualMemory,NtFreeVirtualMemory,NtAllocateVirtualMemory,GetFileType,NtAllocateVirtualMemory,LdrGetDllHandle,LdrGetProcedureAddress,SetUnhandledExceptionFilter,NtAllocateVirtualMemory,GetCursorPos,WSAStartup,GetSystemMetrics,SetErrorMode,LoadStringA,SetWindowsHookExA,NtAllocateVirtualMemory,OleInitialize,SetWindowsHookExA,NtClose,GetSystemMetrics,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,CryptAcquireContextA,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,CryptCreateHash,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,CryptHashData,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,CreateThread,LdrLoadDll
# Benign API Call Pattern: GetSystemTimeAsFileTime,SetUnhandledExceptionFilter,CoInitializeEx,CreateThread,NtClose,CoCreateInstance,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,NtClose,RegOpenKeyExW,LdrLoadDll,LdrGetProcedureAddress,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW
#
# ====================================================================================
#
# MATCH 3
# Malicious Counts: 1
#
# Malware Type Counts:
# trojan    1
# Score: 0.1511
#
# Malicious API Call Pattern: NtProtectVirtualMemory,NtAllocateVirtualMemory,NtFreeVirtualMemory,NtAllocateVirtualMemory,GetFileType,NtAllocateVirtualMemory,LdrGetDllHandle,LdrGetProcedureAddress,SetUnhandledExceptionFilter,NtAllocateVirtualMemory,GetCursorPos,WSAStartup,GetSystemMetrics,SetErrorMode,LoadStringA,SetWindowsHookExA,NtAllocateVirtualMemory,OleInitialize,SetWindowsHookExA,NtClose,GetSystemMetrics,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,CryptAcquireContextA,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,CryptCreateHash,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,CryptHashData,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll
# Benign API Call Pattern: GetSystemTimeAsFileTime,SetUnhandledExceptionFilter,CoInitializeEx,CreateThread,NtClose,CoCreateInstance,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,NtClose,RegOpenKeyExW,LdrLoadDll,LdrGetProcedureAddress,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW
#
# ====================================================================================
#
# MATCH 4
# Malicious Counts: 1
#
# Malware Type Counts:
# trojan    1
# Score: 0.1549
#
# Malicious API Call Pattern: NtAllocateVirtualMemory,NtFreeVirtualMemory,NtAllocateVirtualMemory,GetFileType,NtAllocateVirtualMemory,LdrGetDllHandle,LdrGetProcedureAddress,SetUnhandledExceptionFilter,NtAllocateVirtualMemory,GetCursorPos,GetSystemMetrics,SetErrorMode,LoadStringA,SetWindowsHookExA,NtAllocateVirtualMemory,OleInitialize,SetWindowsHookExA,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,GetSystemMetrics,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,CryptAcquireContextA,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,CryptCreateHash,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,CryptHashData,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll
# Benign API Call Pattern: GetSystemTimeAsFileTime,SetUnhandledExceptionFilter,CoInitializeEx,CreateThread,NtClose,CoCreateInstance,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,NtClose,RegOpenKeyExW,LdrLoadDll,LdrGetProcedureAddress,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW
#
# ====================================================================================
#
# MATCH 5
# Malicious Counts: 1
#
# Malware Type Counts:
# trojan    1
# Score: 0.1552
#
# Malicious API Call Pattern: LdrLoadDll,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection
# Benign API Call Pattern: GetSystemTimeAsFileTime,NtAllocateVirtualMemory,NtFreeVirtualMemory,NtAllocateVirtualMemory,GetSystemTimeAsFileTime,NtAllocateVirtualMemory,SetUnhandledExceptionFilter,NtCreateMutant,SHGetFolderPathW,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,NtCreateMutant,CoInitializeEx,OleInitialize,GetFileAttributesW,RegCreateKeyExW,RegOpenKeyExW,RegCloseKey,RegCreateKeyExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,NtAllocateVirtualMemory,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW
#
# ====================================================================================
#
# MATCH 6
# Malicious Counts: 2
#
# Malware Type Counts:
# trojan    2
# Score: 0.1572
#
# Malicious API Call Pattern: NtAllocateVirtualMemory,NtFreeVirtualMemory,NtAllocateVirtualMemory,GetFileType,NtAllocateVirtualMemory,LdrGetDllHandle,LdrGetProcedureAddress,SetUnhandledExceptionFilter,NtAllocateVirtualMemory,GetCursorPos,GetSystemMetrics,SetErrorMode,LoadStringA,SetWindowsHookExA,NtAllocateVirtualMemory,OleInitialize,SetWindowsHookExA,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,GetSystemMetrics,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,WSAStartup,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,CryptAcquireContextA,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,CryptCreateHash,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,CryptHashData,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress
# Benign API Call Pattern: GetSystemTimeAsFileTime,SetUnhandledExceptionFilter,CoInitializeEx,CreateThread,NtClose,CoCreateInstance,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,NtClose,RegOpenKeyExW,LdrLoadDll,LdrGetProcedureAddress,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW
#
# ====================================================================================
#
# MATCH 7
# Malicious Counts: 1
#
# Malware Type Counts:
# trojan    1
# Score: 0.1592
#
# Malicious API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExA,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,GetSystemDirectoryA,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,CopyFileA,LdrLoadDll,LdrGetProcedureAddress,NtCreateFile,LdrLoadDll,LdrGetProcedureAddress,SetFilePointer,LdrLoadDll,LdrGetProcedureAddress,GetFileSize,LdrLoadDll,LdrGetProcedureAddress,NtWriteFile,LdrLoadDll,LdrGetProcedureAddress,NtWriteFile,LdrLoadDll,LdrGetProcedureAddress,NtWriteFile,LdrLoadDll,LdrGetProcedureAddress,NtWriteFile,LdrLoadDll,LdrGetProcedureAddress,NtWriteFile
# Benign API Call Pattern: GetSystemTimeAsFileTime,SetUnhandledExceptionFilter,CoInitializeEx,CreateThread,NtClose,CoCreateInstance,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,NtClose,RegOpenKeyExW,LdrLoadDll,LdrGetProcedureAddress,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW
#
# ====================================================================================
#
# MATCH 8
# Malicious Counts: 1
#
# Malware Type Counts:
# trojan    1
# Score: 0.1621
#
# Malicious API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExA,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,GetSystemDirectoryA,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,CopyFileA,LdrLoadDll,LdrGetProcedureAddress,NtCreateFile,LdrLoadDll,LdrGetProcedureAddress,SetFilePointer,LdrLoadDll,LdrGetProcedureAddress,GetFileSize,LdrLoadDll,LdrGetProcedureAddress,NtWriteFile,LdrLoadDll,LdrGetProcedureAddress,NtWriteFile,LdrLoadDll,LdrGetProcedureAddress,NtWriteFile,LdrLoadDll,LdrGetProcedureAddress,NtWriteFile,LdrLoadDll,LdrGetProcedureAddress,NtWriteFile,LdrLoadDll,LdrGetProcedureAddress,NtWriteFile,LdrLoadDll,LdrGetProcedureAddress,NtWriteFile,LdrLoadDll,LdrGetProcedureAddress,NtWriteFile,LdrLoadDll,LdrGetProcedureAddress,NtWriteFile,LdrLoadDll,LdrGetProcedureAddress,NtWriteFile
# Benign API Call Pattern: GetSystemTimeAsFileTime,SetUnhandledExceptionFilter,CoInitializeEx,CreateThread,NtClose,CoCreateInstance,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,NtClose,RegOpenKeyExW,LdrLoadDll,LdrGetProcedureAddress,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW
#
# ====================================================================================
#
# MATCH 9
# Malicious Counts: 1
#
# Malware Type Counts:
# trojan    1
# Score: 0.1653
#
# Malicious API Call Pattern: NtAllocateVirtualMemory,NtFreeVirtualMemory,NtAllocateVirtualMemory,GetFileType,NtAllocateVirtualMemory,LdrGetDllHandle,LdrGetProcedureAddress,SetUnhandledExceptionFilter,NtAllocateVirtualMemory,GetCursorPos,WSAStartup,GetSystemMetrics,SetErrorMode,LoadStringA,SetWindowsHookExA,NtAllocateVirtualMemory,OleInitialize,SetWindowsHookExA,NtClose,GetSystemMetrics,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,NtOpenDirectoryObject,NtClose,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtClose,LdrLoadDll,LdrGetProcedureAddress,NtAllocateVirtualMemory,NtClose,NtAllocateVirtualMemory,NtClose,LdrLoadDll,LdrGetProcedureAddress,NtFreeVirtualMemory,NtClose,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,NtClose,LdrLoadDll,LdrGetProcedureAddress,NtClose,LdrGetProcedureAddress,NtClose,LdrGetProcedureAddress,NtClose,LdrGetProcedureAddress,NtClose,LdrGetProcedureAddress,NtClose,LdrLoadDll,NtClose,LdrGetProcedureAddress,NtClose,LdrLoadDll,NtClose,LdrGetProcedureAddress,NtClose,LdrLoadDll,NtClose,LdrGetProcedureAddress,NtClose,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,NtClose,NtAllocateVirtualMemory,NtClose,NtFreeVirtualMemory
# Benign API Call Pattern: GetSystemTimeAsFileTime,SetUnhandledExceptionFilter,CoInitializeEx,CreateThread,NtClose,CoCreateInstance,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,NtClose,RegOpenKeyExW,LdrLoadDll,LdrGetProcedureAddress,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW
#
# ====================================================================================
#
# MATCH 10
# Malicious Counts: 1
#
# Malware Type Counts:
# adware    1
# Score: 0.1677
#
# Malicious API Call Pattern: FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection
# Benign API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress
#
# ====================================================================================
#
# MATCH 11
# Malicious Counts: 1
#
# Malware Type Counts:
# trojan    1
# Score: 0.1677
#
# Malicious API Call Pattern: LdrLoadDll,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection,FindWindowExA,NtMapViewOfSection
# Benign API Call Pattern: GetSystemTimeAsFileTime,NtAllocateVirtualMemory,NtFreeVirtualMemory,NtAllocateVirtualMemory,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,NtAllocateVirtualMemory,LdrGetDllHandle,LdrGetProcedureAddress,GetSystemTimeAsFileTime,SetUnhandledExceptionFilter,NtCreateMutant,SHGetFolderPathW,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,NtCreateMutant,CoInitializeEx,OleInitialize,NtAllocateVirtualMemory,GetFileAttributesW,RegCreateKeyExW,RegOpenKeyExW,RegCloseKey,RegCreateKeyExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,NtAllocateVirtualMemory,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW,RegQueryValueExW,RegCloseKey,RegCreateKeyExW
#
# ====================================================================================
#
# MATCH 12
# Malicious Counts: 3
#
# Malware Type Counts:
# trojan    3
# Score: 0.1687
#
# Malicious API Call Pattern: GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,SetUnhandledExceptionFilter,NtAllocateVirtualMemory,GetTempPathW,GetSystemWindowsDirectoryW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW,GetTempPathW,SearchPathW
# Benign API Call Pattern: FindWindowA,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtCreateFile,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,LdrLoadDll,LdrGetProcedureAddress,GetSystemWindowsDirectoryW,NtCreateFile,NtCreateSection,NtMapViewOfSection,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose
#
# ====================================================================================
#
# MATCH 13
# Malicious Counts: 1
#
# Malware Type Counts:
# trojan    1
# Score: 0.1691
#
# Malicious API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,NtAllocateVirtualMemory,NtFreeVirtualMemory,NtAllocateVirtualMemory,GetFileType,NtAllocateVirtualMemory,LdrGetDllHandle,LdrGetProcedureAddress,SetUnhandledExceptionFilter,NtAllocateVirtualMemory,GetCursorPos,WSAStartup,GetSystemMetrics,SetErrorMode,LoadStringA,SetWindowsHookExA,NtAllocateVirtualMemory,OleInitialize,SetWindowsHookExA,NtClose,GetSystemMetrics,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,CoInitializeEx,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll
# Benign API Call Pattern: GetSystemTimeAsFileTime,SetUnhandledExceptionFilter,CoInitializeEx,CreateThread,NtClose,CoCreateInstance,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,NtClose,RegOpenKeyExW,LdrLoadDll,LdrGetProcedureAddress,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW
#
# ====================================================================================
#
# MATCH 14
# Malicious Counts: 1
#
# Malware Type Counts:
# trojan    1
# Score: 0.1697
#
# Malicious API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,NtAllocateVirtualMemory,NtFreeVirtualMemory,NtAllocateVirtualMemory,GetFileType,NtAllocateVirtualMemory,LdrGetDllHandle,LdrGetProcedureAddress,SetUnhandledExceptionFilter,NtAllocateVirtualMemory,GetCursorPos,GetSystemMetrics,SetErrorMode,LoadStringA,SetWindowsHookExA,NtAllocateVirtualMemory,OleInitialize,SetWindowsHookExA,NtClose,GetSystemMetrics,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,NtProtectVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LookupPrivilegeValueW,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrUnloadDll,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll
# Benign API Call Pattern: GetSystemTimeAsFileTime,SetUnhandledExceptionFilter,CoInitializeEx,CreateThread,NtClose,CoCreateInstance,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,NtClose,RegOpenKeyExW,LdrLoadDll,LdrGetProcedureAddress,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW
#
# ====================================================================================
#
# MATCH 15
# Malicious Counts: 1
#
# Malware Type Counts:
# trojan    1
# Score: 0.1697
#
# Malicious API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtOpenDirectoryObject,NtCreateMutant,WSAStartup,LdrLoadDll,LdrGetProcedureAddress,CreateThread,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,gethostbyname,socket,connect,closesocket,NtClose,closesocket,NtDelayExecution,LdrLoadDll,LdrGetProcedureAddress,CreateThread,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,gethostbyname,socket,connect,closesocket,NtClose,closesocket,NtDelayExecution,LdrLoadDll,LdrGetProcedureAddress,CreateThread,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,gethostbyname,socket,connect,closesocket,NtClose,closesocket,NtDelayExecution,LdrLoadDll,LdrGetProcedureAddress,CreateThread,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress
# ...
# Benign API Call Pattern: FindWindowA,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtCreateFile,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,LdrLoadDll,LdrGetProcedureAddress,GetSystemWindowsDirectoryW,NtCreateFile,NtCreateSection,NtMapViewOfSection,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose,NtOpenFile,NtClose
#
# ====================================================================================
#
# MATCH 17
# Malicious Counts: 1
#
# Malware Type Counts:
# trojan    1
# Score: 0.1707
#
# Malicious API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,NtAllocateVirtualMemory,NtFreeVirtualMemory,NtAllocateVirtualMemory,GetFileType,NtAllocateVirtualMemory,LdrGetDllHandle,LdrGetProcedureAddress,SetUnhandledExceptionFilter,NtAllocateVirtualMemory,GetCursorPos,WSAStartup,GetSystemMetrics,SetErrorMode,LoadStringA,SetWindowsHookExA,NtAllocateVirtualMemory,OleInitialize,SetWindowsHookExA,NtClose,GetSystemMetrics,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress
# Benign API Call Pattern: GetSystemTimeAsFileTime,SetUnhandledExceptionFilter,CoInitializeEx,CreateThread,NtClose,CoCreateInstance,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,NtClose,RegOpenKeyExW,LdrLoadDll,LdrGetProcedureAddress,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW
#
# ====================================================================================
#
# MATCH 18
# Malicious Counts: 1
#
# Malware Type Counts:
# trojan    1
# Score: 0.1712
#
# Malicious API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,NtAllocateVirtualMemory,NtFreeVirtualMemory,NtAllocateVirtualMemory,GetFileType,NtAllocateVirtualMemory,LdrGetDllHandle,LdrGetProcedureAddress,SetUnhandledExceptionFilter,NtAllocateVirtualMemory,GetCursorPos,WSAStartup,GetSystemMetrics,SetErrorMode,LoadStringA,SetWindowsHookExA,NtAllocateVirtualMemory,OleInitialize,SetWindowsHookExA,NtClose,GetSystemMetrics,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll
# Benign API Call Pattern: GetSystemTimeAsFileTime,SetUnhandledExceptionFilter,CoInitializeEx,CreateThread,NtClose,CoCreateInstance,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,NtClose,RegOpenKeyExW,LdrLoadDll,LdrGetProcedureAddress,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW
#
# ====================================================================================
#
# MATCH 19
# Malicious Counts: 1
#
# Malware Type Counts:
# trojan    1
# Score: 0.1717
#
# Malicious API Call Pattern: GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,SetUnhandledExceptionFilter,NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOpenKey,NtQueryValueKey,NtClose,LdrLoadDll,LdrGetProcedureAddress,GetSystemWindowsDirectoryW,NtCreateFile,NtCreateSection,NtMapViewOfSection,NtClose,LdrLoadDll,NtAllocateVirtualMemory,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress
# Benign API Call Pattern: GetSystemTimeAsFileTime,SetUnhandledExceptionFilter,CoInitializeEx,CreateThread,NtClose,CoCreateInstance,LdrLoadDll,LdrGetProcedureAddress,RegOpenKeyExW,NtClose,RegOpenKeyExW,LdrLoadDll,LdrGetProcedureAddress,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW,RegOpenKeyExW,RegEnumKeyW
#
# ====================================================================================
#
# MATCH 20
# Malicious Counts: 1
#
# Malware Type Counts:
# adware    1
# Score: 0.1739
#
# Malicious API Call Pattern: FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection,FindWindowExW,NtMapViewOfSection
# Benign API Call Pattern: LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,LdrLoadDll,LdrGetProcedureAddress,NtProtectVirtualMemory,GetSystemInfo,RegOpenKeyExW,NtQueryAttributesFile,LoadStringW,NtAllocateVirtualMemory,LoadStringW,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,LdrGetProcedureAddress,RegOpenKeyExW,RegQueryValueExW,RegCloseKey,LdrGetDllHandle,LdrGetProcedureAddress,LdrGetDllHandle,SetErrorMode,LdrGetDllHandle,LdrGetProcedureAddress
#
# ====================================================================================
#
#
# Malware Types of the Top 20 Least Matching API Call Patterns to Benign Samples:
# trojan    23
# adware     2
# Name: count, dtype: int64
