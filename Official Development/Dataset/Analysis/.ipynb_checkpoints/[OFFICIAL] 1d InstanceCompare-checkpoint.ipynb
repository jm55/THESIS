# %% [markdown]
# # Instance Compare
#
# Aims to answer the question **Are there any unique indicators to malicious samples in terms of specific API Call(s) alone?** in **4.2.6. Dataset Analysis** of the study.
#
# Note that this notebook only makes use of the verified xxxx_SampleHash_Common.csv file which represents a significant majority of the entire Oliveira dataset.

# %% [markdown]
# ## Import Libraries/Datasets

# %%
import pandas as pd
import time

malicious_df = pd.read_csv('../Clustering/Malicious/Manual_DBSCAN_Encoded_Clustering.csv', low_memory=False) #This should point to a verified <DataClustering>_SampleHash_Common.csv file
benign_df = pd.read_csv('../Clustering/Benign/API_Patterns_Benign.csv') #This should point to the API_Patterns.csv file

#DROP ROWS WITH NA
import numpy as nan
malicious_df.dropna(inplace=True, subset=['type'])
malicious_df['type'].unique()

#Load list of API calls
API_LIST = "../api_calls.txt"
DELIMITER = "NaN"
API_FILE = open(API_LIST,"r")
APIS = API_FILE.readline().split(',')
# APIS.append(DELIMITER) #serves as a label for NaN values for Instance-based datasets
API_FILE.close()

# %% [markdown]
# ## DataFrame Preview

# %%
def list_to_str(ls:list):
    output = ""
    for l in ls:
        output += str(l) + " "
    return output[0:len(output)-1]

def inject_patterns(inner_df:pd.DataFrame):
    patterns = []
    for row in range(inner_df.shape[0]):
        patterns.append(list_to_str(inner_df.iloc[row,2:5].transpose().to_list()))
    inner_df['type_pattern'] = patterns
    return inner_df

malicious_df.replace(to_replace='-',value='_', inplace=True)
malicious_df.drop(malicious_df[(malicious_df['type']=='_')].index, inplace=True) #Drop row that is falsely labelled.
malicious_df = inject_patterns(malicious_df)

print("Malicious DF")
display(malicious_df)

print("Benign DF")
display(benign_df)
# Out:
# Malicious DF
#                                    hash                          t_0  \
# 0      071e8c3f8922e186e57548cd4c703a5d                RegOpenKeyExA
# 1      33f8e6d08a6aae939f25a8e0d63dd523      GetSystemTimeAsFileTime
# 2      b68abd064e975e1c6d5f25e748663076  SetUnhandledExceptionFilter
# 3      72049be7bd30ea61297ea624ae198067      GetSystemTimeAsFileTime
# 4      c9b3700a77facf29172f32df6bc77f48      GetSystemTimeAsFileTime
# ...                                 ...                          ...
# 40154  e3d6d58faa040f0f9742c9d0eaf58be4      GetSystemTimeAsFileTime
# 40155  9b917bab7f32188ae40c744f2be9aaf8      GetSystemTimeAsFileTime
# 40156  35a18ee05f75f04912018d9f462cb990      GetSystemTimeAsFileTime
# 40157  654139d715abcf7ecdddbef5a84f224b      GetSystemTimeAsFileTime
# 40158  078c9d4e7be4819a06974c6f292a4857                RegOpenKeyExA
#
#                            t_1                     t_2  \
# 0                    NtOpenKey         NtQueryValueKey
# 1      NtAllocateVirtualMemory     NtFreeVirtualMemory
# 2                OleInitialize              LdrLoadDll
# 3      NtAllocateVirtualMemory     NtFreeVirtualMemory
# 4                   LdrLoadDll  LdrGetProcedureAddress
# ...                        ...                     ...
# 40154               LdrLoadDll  LdrGetProcedureAddress
# 40155               LdrLoadDll  LdrGetProcedureAddress
# 40156               LdrLoadDll  LdrGetProcedureAddress
# 40157               LdrLoadDll  LdrGetProcedureAddress
# 40158                NtOpenKey         NtQueryValueKey
#
#                            t_3                     t_4  \
# 0                      NtClose               NtOpenKey
# 1      NtAllocateVirtualMemory         LdrGetDllHandle
# 2       LdrGetProcedureAddress              LdrLoadDll
# 3      NtAllocateVirtualMemory         LdrGetDllHandle
# 4                   LdrLoadDll  LdrGetProcedureAddress
# ...                        ...                     ...
# 40154               LdrLoadDll  LdrGetProcedureAddress
# 40155               LdrLoadDll  LdrGetProcedureAddress
# 40156               LdrLoadDll  LdrGetProcedureAddress
# 40157               LdrLoadDll  LdrGetProcedureAddress
# 40158                  NtClose               NtOpenKey
#
#                           t_5                     t_6                     t_7  \
# 0             NtQueryValueKey                 NtClose   NtQueryAttributesFile
# 1      LdrGetProcedureAddress         LdrGetDllHandle  LdrGetProcedureAddress
# 2      LdrGetProcedureAddress              LdrLoadDll  LdrGetProcedureAddress
# 3      LdrGetProcedureAddress         LdrGetDllHandle  LdrGetProcedureAddress
# 4                  LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# ...                       ...                     ...                     ...
# 40154              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 40155              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 40156              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 40157              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 40158         NtQueryValueKey                 NtClose   NtQueryAttributesFile
#
#                           t_8  ...                 t_95  \
# 0                 LoadStringA  ...              NtClose
# 1             LdrGetDllHandle  ...         NtCreateFile
# 2                  LdrLoadDll  ...        RegOpenKeyExA
# 3             LdrGetDllHandle  ...  NtFreeVirtualMemory
# 4      LdrGetProcedureAddress  ...        RegOpenKeyExW
# ...                       ...  ...                  ...
# 40154  LdrGetProcedureAddress  ...     RegQueryValueExW
# 40155  LdrGetProcedureAddress  ...          EnumWindows
# 40156  LdrGetProcedureAddress  ...        RegOpenKeyExW
# 40157  LdrGetProcedureAddress  ...     RegQueryValueExW
# 40158             LoadStringA  ...              NtClose
#
#                           t_96                     t_97  \
# 0             GetSystemMetrics  NtAllocateVirtualMemory
# 1              NtCreateSection       NtMapViewOfSection
# 2             RegQueryValueExA              RegCloseKey
# 3      NtAllocateVirtualMemory     NtWriteVirtualMemory
# 4             RegQueryValueExW            RegOpenKeyExW
# ...                        ...                      ...
# 40154            RegOpenKeyExW         RegQueryValueExW
# 40155  GetSystemTimeAsFileTime         NtDelayExecution
# 40156         RegQueryValueExW            RegOpenKeyExW
# 40157            RegOpenKeyExW         RegQueryValueExW
# 40158         GetSystemMetrics  NtAllocateVirtualMemory
#
#                          t_98                        t_99 malware    type  \
# 0               CreateActCtxW  GetSystemWindowsDirectoryW       1  trojan
# 1                     NtClose            GetSystemMetrics       1     pua
# 2               RegEnumKeyExA               RegOpenKeyExA       1  trojan
# 3      NtProtectVirtualMemory        NtWriteVirtualMemory       1  trojan
# 4            RegQueryValueExW               RegOpenKeyExW       1  trojan
# ...                       ...                         ...     ...     ...
# 40154           RegOpenKeyExW            RegQueryValueExW       1  trojan
# 40155             EnumWindows     GetSystemTimeAsFileTime       1  trojan
# 40156        RegQueryValueExW               RegOpenKeyExW       1  trojan
# 40157           RegOpenKeyExW            RegQueryValueExW       1  trojan
# 40158           CreateActCtxW  GetSystemWindowsDirectoryW       1  trojan
#
#                                                  pattern cluster  \
# 0      RegOpenKeyExA,NtOpenKey,NtQueryValueKey,NtClos...       0
# 1      GetSystemTimeAsFileTime,NtAllocateVirtualMemor...       1
# 2      SetUnhandledExceptionFilter,OleInitialize,LdrL...       2
# 3      GetSystemTimeAsFileTime,NtAllocateVirtualMemor...       3
# 4      GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...       4
# ...                                                  ...     ...
# 40154  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...      17
# 40155  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...   11490
# 40156  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...   11491
# 40157  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...      17
# 40158  RegOpenKeyExA,NtOpenKey,NtQueryValueKey,NtClos...       0
#
#                                             type_pattern
# 0                      NtOpenKey NtQueryValueKey NtClose
# 1      NtAllocateVirtualMemory NtFreeVirtualMemory Nt...
# 2        OleInitialize LdrLoadDll LdrGetProcedureAddress
# 3      NtAllocateVirtualMemory NtFreeVirtualMemory Nt...
# 4           LdrLoadDll LdrGetProcedureAddress LdrLoadDll
# ...                                                  ...
# 40154       LdrLoadDll LdrGetProcedureAddress LdrLoadDll
# 40155       LdrLoadDll LdrGetProcedureAddress LdrLoadDll
# 40156       LdrLoadDll LdrGetProcedureAddress LdrLoadDll
# 40157       LdrLoadDll LdrGetProcedureAddress LdrLoadDll
# 40158                  NtOpenKey NtQueryValueKey NtClose
#
# [40159 rows x 106 columns]
# Benign DF
#                                   hash                          t_0  \
# 0     5b51d65972a349f90a86984c26b12b30                 SetErrorMode
# 1     ceb8cc125478fad641daa4e04e9b2f19                GetSystemInfo
# 2     f108600edf46d7c20f6acc522aeba6df      GetSystemTimeAsFileTime
# 3     711be6337cb78a948f04759a0bd210ce      GetSystemTimeAsFileTime
# 4     6de26f67ceb1e3303b889489010f4c3f                 SetErrorMode
# ...                                ...                          ...
# 1074  d282ef96a93986f89825508812958354                 SetErrorMode
# 1075  c0389d256f976044adf570f0df908953      GetSystemTimeAsFileTime
# 1076  20316e717de5db169aecbb67377504ce  SetUnhandledExceptionFilter
# 1077  ce945d424b93ea73fbbedf0254f6bc07                      NtClose
# 1078  70b78f7bdf9c484913d10365348ed2ba                 SetErrorMode
#
#                               t_1                          t_2  \
# 0                   OleInitialize              LdrGetDllHandle
# 1         NtAllocateVirtualMemory                NtOpenSection
# 2          NtProtectVirtualMemory  SetUnhandledExceptionFilter
# 3                      LdrLoadDll       LdrGetProcedureAddress
# 4                   OleInitialize              LdrGetDllHandle
# ...                           ...                          ...
# 1074                OleInitialize              LdrGetDllHandle
# 1075  SetUnhandledExceptionFilter                 GetCursorPos
# 1076               NtCreateMutant      NtAllocateVirtualMemory
# 1077                    NtOpenKey              NtQueryValueKey
# 1078              LdrGetDllHandle       LdrGetProcedureAddress
#
#                          t_3                      t_4                     t_5  \
# 0                 LdrLoadDll   LdrGetProcedureAddress              LdrLoadDll
# 1               GetTempPathW         CreateDirectoryW      GetFileAttributesW
# 2     GetTimeZoneInformation  GetSystemTimeAsFileTime  GetTimeZoneInformation
# 3                 LdrLoadDll   LdrGetProcedureAddress              LdrLoadDll
# 4                 LdrLoadDll   LdrGetProcedureAddress              LdrLoadDll
# ...                      ...                      ...                     ...
# 1074              LdrLoadDll   LdrGetProcedureAddress              LdrLoadDll
# 1075            SetErrorMode            FindResourceW       SetWindowsHookExW
# 1076                 NtClose           NtCreateMutant                 NtClose
# 1077                 NtClose                NtOpenKey         NtQueryValueKey
# 1078     GetSystemDirectoryW  NtAllocateVirtualMemory     NtFreeVirtualMemory
#
#                           t_6                     t_7  \
# 0      LdrGetProcedureAddress              LdrLoadDll
# 1            FindFirstFileExW             DeleteFileW
# 2     GetSystemTimeAsFileTime  GetTimeZoneInformation
# 3      LdrGetProcedureAddress              LdrLoadDll
# 4      LdrGetProcedureAddress              LdrLoadDll
# ...                       ...                     ...
# 1074   LdrGetProcedureAddress              LdrLoadDll
# 1075           CoInitializeEx       NtDuplicateObject
# 1076           NtCreateMutant                 NtClose
# 1077                  NtClose         LdrGetDllHandle
# 1078  NtAllocateVirtualMemory              LdrLoadDll
#
#                           t_8  ...                     t_91  \
# 0      LdrGetProcedureAddress  ...                  NtClose
# 1        NtQueryDirectoryFile  ...                  NtClose
# 2     GetSystemTimeAsFileTime  ...             SetErrorMode
# 3      LdrGetProcedureAddress  ...   LdrGetProcedureAddress
# 4      LdrGetProcedureAddress  ...                  NtClose
# ...                       ...  ...                      ...
# 1074   LdrGetProcedureAddress  ...                  NtClose
# 1075  NtAllocateVirtualMemory  ...  NtAllocateVirtualMemory
# 1076  NtAllocateVirtualMemory  ...            RegOpenKeyExW
# 1077   LdrGetProcedureAddress  ...               LdrLoadDll
# 1078      GetSystemDirectoryW  ...         RegQueryValueExW
#
#                          t_92                     t_93  \
# 0        NtQueryDirectoryFile                  NtClose
# 1              NtCreateMutant                  NtClose
# 2        GetFileAttributesExW             SetErrorMode
# 3     NtAllocateVirtualMemory   LdrGetProcedureAddress
# 4        NtQueryDirectoryFile                  NtClose
# ...                       ...                      ...
# 1074   LdrGetProcedureAddress  NtAllocateVirtualMemory
# 1075               LdrLoadDll   LdrGetProcedureAddress
# 1076         RegQueryValueExW              RegCloseKey
# 1077   LdrGetProcedureAddress               LdrLoadDll
# 1078              RegCloseKey            RegOpenKeyExW
#
#                          t_94                        t_95  \
# 0      LdrGetProcedureAddress            CoCreateInstance
# 1             LdrGetDllHandle      LdrGetProcedureAddress
# 2     NtAllocateVirtualMemory                SetErrorMode
# 3            GetSystemMetrics                  LdrLoadDll
# 4      LdrGetProcedureAddress  GetSystemWindowsDirectoryW
# ...                       ...                         ...
# 1074          LdrGetDllHandle      LdrGetProcedureAddress
# 1075  NtAllocateVirtualMemory            GetSystemMetrics
# 1076            RegOpenKeyExW            RegQueryValueExW
# 1077   LdrGetProcedureAddress                  LdrLoadDll
# 1078                  NtClose                  LdrLoadDll
#
#                         t_96                        t_97  \
# 0              NtOpenSection            CreateDirectoryW
# 1                    NtClose              NtCreateMutant
# 2       GetFileAttributesExW                SetErrorMode
# 3     LdrGetProcedureAddress            GetSystemMetrics
# 4                LoadStringW  GetSystemWindowsDirectoryW
# ...                      ...                         ...
# 1074         LdrGetDllHandle      LdrGetProcedureAddress
# 1075           RegOpenKeyExW     NtAllocateVirtualMemory
# 1076             RegCloseKey               RegOpenKeyExW
# 1077  LdrGetProcedureAddress             LdrGetDllHandle
# 1078  LdrGetProcedureAddress  GetSystemWindowsDirectoryW
#
#                          t_98                     t_99  \
# 0                NtCreateFile   LdrGetProcedureAddress
# 1                     NtClose             NtCreateFile
# 2            FindFirstFileExW     NtQueryDirectoryFile
# 3     NtAllocateVirtualMemory               LdrLoadDll
# 4         GetSystemDirectoryW            RegOpenKeyExW
# ...                       ...                      ...
# 1074          LdrGetDllHandle   LdrGetProcedureAddress
# 1075         GetSystemMetrics  NtAllocateVirtualMemory
# 1076         RegQueryValueExW              RegCloseKey
# 1077          FindResourceExW             LoadResource
# 1078             NtCreateFile          NtCreateSection
#
#                                                 pattern
# 0     SetErrorMode,OleInitialize,LdrGetDllHandle,Ldr...
# 1     GetSystemInfo,NtAllocateVirtualMemory,NtOpenSe...
# 2     GetSystemTimeAsFileTime,NtProtectVirtualMemory...
# 3     GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 4     SetErrorMode,OleInitialize,LdrGetDllHandle,Ldr...
# ...                                                 ...
# 1074  SetErrorMode,OleInitialize,LdrGetDllHandle,Ldr...
# 1075  GetSystemTimeAsFileTime,SetUnhandledExceptionF...
# 1076  SetUnhandledExceptionFilter,NtCreateMutant,NtA...
# 1077  NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOp...
# 1078  SetErrorMode,LdrGetDllHandle,LdrGetProcedureAd...
#
# [1079 rows x 102 columns]

# %% [markdown]
# ## Extract Unique API Calls

# %%
str_output = ""

malicious_apis = []
for i in range(malicious_df.shape[0]): #Only allow those with 
    if not (malicious_df['type'].iloc[i] == '_' and malicious_df['Type 2'].iloc[i] == '_' and malicious_df['Type 3'].iloc[i] == '_'):
        malicious_apis += malicious_df['pattern'].iloc[i].split(',')
malicious_apis = list(pd.Series(malicious_apis).unique())
str_output += f"# of Unique API Calls in Verified Malicious Samples: {len(malicious_apis)}\n"
str_output += str(malicious_apis) + "\n\n"

benign_apis = []
for i in range(benign_df.shape[0]): #Only allow those with 
    benign_apis += benign_df['pattern'].iloc[i].split(',')
benign_apis = list(pd.Series(benign_apis).unique())
str_output += f"# of Unique API Calls in Benign Samples: {len(benign_apis)}\n" 
str_output += str(benign_apis) + "\n\n"

with open("./Output/4 Unique_APICalls_MaliciousOnly.txt", 'w') as f:
    f.write(str_output)
    f.flush()
    f.close()
print(str_output)
# Out:
# # of Unique API Calls in Verified Malicious Samples: 248
# ['RegOpenKeyExA', 'NtOpenKey', 'NtQueryValueKey', 'NtClose', 'NtQueryAttributesFile', 'LoadStringA', 'NtAllocateVirtualMemory', 'LdrGetDllHandle', 'LdrGetProcedureAddress', 'GetSystemMetrics', 'FindResourceExW', 'LoadResource', 'LdrLoadDll', 'DrawTextExW', 'FindResourceA', 'SizeofResource', 'GetSystemWindowsDirectoryW', 'NtCreateFile', 'NtCreateSection', 'NtMapViewOfSection', 'CreateActCtxW', 'GetSystemTimeAsFileTime', 'NtFreeVirtualMemory', 'SetUnhandledExceptionFilter', 'GetFileSize', 'SetFilePointer', 'NtReadFile', 'RegOpenKeyExW', 'RegCreateKeyExW', 'RegCloseKey', 'RegSetValueExW', 'IsDebuggerPresent', 'CoInitializeEx', 'GetForegroundWindow', 'OleInitialize', 'GetNativeSystemInfo', 'RegQueryValueExW', 'LookupPrivilegeValueW', 'GetUserNameA', 'RegEnumKeyExA', 'RegQueryValueExA', 'NtProtectVirtualMemory', 'GetSystemInfo', 'NtCreateMutant', 'NtOpenKeyEx', 'NtQuerySystemInformation', 'GetSystemDirectoryW', 'NtWriteVirtualMemory', 'CryptAcquireContextW', 'CryptCreateHash', 'CryptHashData', 'RegEnumKeyW', 'CreateThread', 'UuidCreate', 'NtDelayExecution', 'EnumWindows', 'CoCreateInstance', 'FindResourceW', 'RegQueryInfoKeyW', 'RegEnumKeyExW', 'NtOpenFile', 'NtQueryInformationFile', 'OpenSCManagerW', 'NtDuplicateObject', 'NtCreateThreadEx', 'NtResumeThread', 'SHGetFolderPathW', 'NtUnmapViewOfSection', 'GetComputerNameW', 'GetFileAttributesW', 'GetVolumeNameForVolumeMountPointW', 'FindFirstFileExW', 'LoadStringW', 'SetErrorMode', 'LookupAccountSidW', 'GetTempPathW', 'NtWriteFile', 'GetFileType', 'CreateToolhelp32Snapshot', 'Process32FirstW', 'Process32NextW', 'RegCreateKeyExA', 'RegSetValueExA', 'WSAStartup', 'getaddrinfo', 'LdrUnloadDll', 'NtOpenDirectoryObject', 'NtOpenProcess', 'CreateDirectoryW', 'SetEndOfFile', 'CreateProcessInternalW', 'DeleteFileW', 'RemoveDirectoryA', 'MoveFileWithProgressW', 'SetStdHandle', 'WriteConsoleA', 'GetUserNameW', 'SearchPathW', 'socket', 'FindWindowW', 'NtOpenSection', 'NtSetInformationFile', 'GetTimeZoneInformation', 'GlobalMemoryStatusEx', 'NtDeviceIoControlFile', 'RegEnumValueW', 'NtEnumerateKey', 'NtEnumerateValueKey', 'CoInitializeSecurity', 'GetFileVersionInfoSizeW', 'GetFileVersionInfoW', 'FindResourceExA', 'GetCursorPos', 'CryptDecrypt', 'SetWindowsHookExA', 'NtOpenMutant', 'ReadProcessMemory', 'OpenSCManagerA', 'OpenServiceA', 'StartServiceA', 'OpenServiceW', 'SetFileTime', 'GlobalMemoryStatus', 'NtQueryDirectoryFile', 'closesocket', 'ioctlsocket', 'connect', 'select', 'CryptAcquireContextA', 'CryptProtectData', 'CryptEncrypt', '__exception__', 'timeGetTime', 'GetSystemDirectoryA', 'OutputDebugStringA', 'GetAdaptersInfo', 'DeviceIoControl', 'GetAdaptersAddresses', 'GetBestInterfaceEx', 'NtQueryKey', 'SetWindowsHookExW', 'FindWindowA', 'SetFileAttributesW', 'RegQueryInfoKeyA', 'NtTerminateProcess', 'NtTerminateThread', 'CopyFileA', 'CreateServiceA', 'GetShortPathNameW', 'CopyFileW', 'CoUninitialize', 'InternetOpenA', 'InternetSetOptionA', 'InternetConnectA', 'HttpOpenRequestA', 'NtCreateKey', 'NtSetValueKey', 'NtOpenThread', 'NtGetContextThread', 'NtReadVirtualMemory', 'NtSetContextThread', 'WriteProcessMemory', 'GetVolumePathNamesForVolumeNameW', 'ShellExecuteExW', 'FindWindowExA', 'bind', 'getsockname', 'GetComputerNameA', 'MessageBoxTimeoutA', 'RtlAddVectoredExceptionHandler', 'GetFileAttributesExW', 'GetVolumePathNameW', 'StartServiceW', 'GetDiskFreeSpaceW', 'FindWindowExW', 'RemoveDirectoryW', 'GetFileInformationByHandle', 'GetSystemWindowsDirectoryA', 'RegEnumValueA', 'InternetOpenW', 'InternetGetConnectedState', 'SHGetSpecialFolderLocation', 'GetFileSizeEx', 'Thread32First', 'Thread32Next', 'DrawTextExA', 'InternetCrackUrlA', 'HttpSendRequestA', 'InternetCloseHandle', 'CreateServiceW', 'DeleteUrlCacheEntryA', 'CoGetClassObject', 'gethostbyname', 'setsockopt', 'send', 'DeleteUrlCacheEntryW', 'WSARecv', 'shutdown', 'InternetCrackUrlW', 'InternetConnectW', 'HttpOpenRequestW', 'CoCreateInstanceEx', 'IWbemServices_ExecQuery', 'SetFilePointerEx', 'CreateJobObjectW', 'CopyFileExW', 'GetDi ...
#
# # of Unique API Calls in Benign Samples: 200
# ['SetErrorMode', 'OleInitialize', 'LdrGetDllHandle', 'LdrLoadDll', 'LdrGetProcedureAddress', 'NtOpenSection', 'NtMapViewOfSection', 'RegOpenKeyExW', 'RegQueryValueExW', 'RegCloseKey', 'NtClose', 'NtOpenKey', 'NtQueryValueKey', 'GetSystemWindowsDirectoryW', 'NtCreateFile', 'NtCreateSection', 'RegOpenKeyExA', 'CreateActCtxW', 'GetSystemDirectoryW', 'GetVolumeNameForVolumeMountPointW', 'RegEnumKeyW', 'NtQueryDirectoryFile', 'CoCreateInstance', 'CreateDirectoryW', 'GetSystemInfo', 'NtAllocateVirtualMemory', 'GetTempPathW', 'GetFileAttributesW', 'FindFirstFileExW', 'DeleteFileW', 'RemoveDirectoryW', 'FindResourceA', 'LoadResource', 'SizeofResource', 'GetSystemTimeAsFileTime', 'NtCreateMutant', 'NtQueryAttributesFile', 'NtProtectVirtualMemory', 'SetUnhandledExceptionFilter', 'GetTimeZoneInformation', 'GetFileType', 'NtWriteFile', 'WSAStartup', 'GetFileAttributesExW', 'SHGetFolderPathW', 'NtQuerySystemInformation', 'CoInitializeEx', 'FindResourceExW', 'GetSystemMetrics', 'NtOpenProcess', 'NtDuplicateObject', 'NtUnmapViewOfSection', 'NtFreeVirtualMemory', 'GetForegroundWindow', 'LoadStringW', 'CreateThread', 'IsDebuggerPresent', 'NtOpenFile', 'RegQueryValueExA', 'GlobalMemoryStatusEx', 'NtCreateThreadEx', 'NtResumeThread', 'NtCreateKey', 'LookupAccountSidW', 'NetUserGetInfo', 'EnumWindows', 'SetStdHandle', 'CoInitializeSecurity', 'LdrUnloadDll', 'GetFileVersionInfoSizeW', 'GetFileVersionInfoW', 'FindWindowW', 'RegCreateKeyExW', 'DrawTextExW', 'NtOpenMutant', 'GetFileSize', 'FindResourceW', 'GetNativeSystemInfo', 'NtOpenThread', 'SetFilePointer', 'NtReadFile', 'FindWindowA', 'WriteConsoleA', 'WriteConsoleW', 'LoadStringA', 'LookupPrivilegeValueW', 'GetFileInformationByHandle', 'NtOpenDirectoryObject', 'RegCreateKeyExA', 'RegSetValueExA', 'RegSetValueExW', 'OpenSCManagerW', 'OpenServiceW', 'StartServiceW', 'NtDelayExecution', 'GetUserNameW', 'GetComputerNameW', 'MessageBoxTimeoutW', 'CoUninitialize', 'GetCursorPos', 'NtTerminateProcess', 'NtQueryKey', 'NtOpenKeyEx', 'NtDeviceIoControlFile', 'CryptAcquireContextA', 'socket', 'closesocket', 'SetWindowsHookExW', 'NtQueryInformationFile', 'RegQueryInfoKeyW', 'RegEnumKeyExW', 'RegEnumValueW', 'NtEnumerateKey', 'NtEnumerateValueKey', 'ReadProcessMemory', 'GetSystemDirectoryA', 'RegEnumKeyExA', 'OutputDebugStringA', 'CertOpenStore', 'RemoveDirectoryA', 'DeviceIoControl', 'UuidCreate', 'SetWindowsHookExA', 'NtSetValueKey', 'CryptAcquireContextW', 'FindResourceExA', 'timeGetTime', 'UnhookWindowsHookEx', 'GetUserNameA', 'CreateToolhelp32Snapshot', 'Module32FirstW', 'Module32NextW', 'GetKeyState', 'NtSetInformationFile', 'SearchPathW', 'MessageBoxTimeoutA', 'RegDeleteKeyA', 'SetFilePointerEx', 'WriteProcessMemory', 'GetVolumePathNamesForVolumeNameW', 'FindFirstFileExA', 'GetFileSizeEx', 'InternetSetOptionA', 'DrawTextExA', 'bind', 'setsockopt', 'ioctlsocket', 'listen', 'Thread32First', 'Thread32Next', 'CreateProcessInternalW', 'SetEndOfFile', 'FindWindowExW', 'GetComputerNameA', 'CryptProtectMemory', 'CoCreateInstanceEx', 'CoGetClassObject', 'IWbemServices_ExecQuery', 'RtlAddVectoredExceptionHandler', 'NtDeleteFile', 'SHGetSpecialFolderLocation', 'GetFileInformationByHandleEx', 'CryptGenKey', 'CryptExportKey', 'CryptCreateHash', 'CryptHashData', 'GetAsyncKeyState', 'GetShortPathNameW', 'GetUserNameExW', 'InternetCrackUrlW', 'GetFileVersionInfoSizeExW', 'GetFileVersionInfoExW', 'RegEnumValueA', 'RegQueryInfoKeyA', 'NtQueueApcThread', 'SendNotifyMessageW', 'GlobalMemoryStatus', 'GetDiskFreeSpaceExW', 'WSASocketW', '__exception__', 'RegisterHotKey', 'RegDeleteValueA', 'RegDeleteValueW', 'FindWindowExA', 'GetSystemWindowsDirectoryA', 'SetFileAttributesW', 'IWbemServices_ExecMethod', 'Process32FirstW', 'Process32NextW', 'GetAdaptersAddresses', 'GetVolumePathNameW', 'getsockname', 'GetKeyboardState', 'NtLoadKey', 'GetAdaptersInfo', 'sendto', 'select', 'recvfrom', 'ShellExecuteExW', 'CopyFileW']

# %% [markdown]
# ## Identify the Unique API Calls only found in Malicious API Calls.

# %%
str_output = ""

unique = []
for m in malicious_apis:
    if m not in benign_apis:
        unique.append(m)
str_output += f"No. of truly unique API Calls only found in Malicious Samples: {len(unique)} ({len(unique)/len(benign_apis)*100:.2f}% Matches API Calls of Benign Samples)\n"
str_output += f"Coverage of 'Malicious-only' API Calls to Official API Calls Oliveira.csv: {(len(unique)/len(APIS))*100:.4f}%\n"
str_output += "Unique API Calls to Verified Malicious Samples only: "+ str(unique) + "\n"

with open("./Output/4 Unique_APICalls_MaliciousOnly.txt", 'w') as f:
    f.write(str_output)
    f.flush()
    f.close()
print(str_output)
# Out:
# No. of truly unique API Calls only found in Malicious Samples: 60 (30.00% Matches API Calls of Benign Samples)
# Coverage of 'Malicious-only' API Calls to Official API Calls Oliveira.csv: 19.5440%
# Unique API Calls to Verified Malicious Samples only: ['NtWriteVirtualMemory', 'getaddrinfo', 'MoveFileWithProgressW', 'CryptDecrypt', 'OpenSCManagerA', 'OpenServiceA', 'StartServiceA', 'SetFileTime', 'connect', 'CryptProtectData', 'CryptEncrypt', 'GetBestInterfaceEx', 'NtTerminateThread', 'CopyFileA', 'CreateServiceA', 'InternetOpenA', 'InternetConnectA', 'HttpOpenRequestA', 'NtGetContextThread', 'NtReadVirtualMemory', 'NtSetContextThread', 'GetDiskFreeSpaceW', 'InternetOpenW', 'InternetGetConnectedState', 'InternetCrackUrlA', 'HttpSendRequestA', 'InternetCloseHandle', 'CreateServiceW', 'DeleteUrlCacheEntryA', 'gethostbyname', 'send', 'DeleteUrlCacheEntryW', 'WSARecv', 'shutdown', 'InternetConnectW', 'HttpOpenRequestW', 'CreateJobObjectW', 'CopyFileExW', 'RtlRemoveVectoredExceptionHandler', 'CreateRemoteThread', 'RegDeleteKeyW', 'InternetQueryOptionA', 'EnumServicesStatusA', 'NtSuspendThread', 'RtlDecompressBuffer', 'CryptDecodeObjectEx', 'recv', 'SetFileInformationByHandle', 'GetAddrInfoW', 'DnsQuery_A', 'InternetSetStatusCallback', 'InternetReadFile', 'HttpQueryInfoA', 'ObtainUserAgentString', 'InternetOpenUrlA', 'ControlService', 'GetUserNameExA', 'SetInformationJobObject', 'WSASocketA', 'InternetOpenUrlW']

# %% [markdown]
# **Fun Fact:** You might see on the results of item #5 that it will contain some Crypt (e.g., `CryptDecrypt`) related API calls. According to the talk of Sir Mantua (during his 4th hr. talk), it is a possible key indicator that a ransomware is in the system. This is supported by the fact that some malicious samples are ransomware as seen in the `Type 2` & `Type 3` malware types.

# %%
str_output = ""
for u in unique:
    str_output += u + "\n\n"
    str_output += str(malicious_df[malicious_df['pattern'].str.contains(u)]['type'].value_counts())
    str_output += "\n=====================================================================\n"

with open("./Output/4 APICalls_MalwareTypes_MaliciousOnly.txt", 'w') as f:
    f.write(str_output)
    f.flush()
    f.close()
print(str_output)
# Out:
# NtWriteVirtualMemory
#
# type
# trojan    4
# miner     2
# Name: count, dtype: int64
# =====================================================================
# getaddrinfo
#
# type
# adware        136
# trojan         61
# pua            10
# downloader      1
# miner           1
# ransomware      1
# Name: count, dtype: int64
# =====================================================================
# MoveFileWithProgressW
#
# type
# trojan        125
# pua            41
# adware          7
# miner           2
# ransomware      1
# Name: count, dtype: int64
# =====================================================================
# CryptDecrypt
#
# type
# trojan        2551
# pua            233
# adware         120
# downloader      97
# Name: count, dtype: int64
# =====================================================================
# OpenSCManagerA
#
# type
# trojan        168
# adware          4
# pua             3
# downloader      2
# virus           2
# Name: count, dtype: int64
# =====================================================================
# OpenServiceA
#
# type
# trojan        135
# pua             3
# downloader      2
# adware          2
# virus           1
# Name: count, dtype: int64
# =====================================================================
# StartServiceA
#
# type
# trojan    41
# virus      1
# Name: count, dtype: int64
# =====================================================================
# SetFileTime
#
# type
# trojan    94
# pua       15
# adware     5
# miner      1
# Name: count, dtype: int64
# =====================================================================
# connect
#
# type
# adware        103
# trojan         62
# pua            24
# downloader      1
# Name: count, dtype: int64
# =====================================================================
# CryptProtectData
#
# type
# trojan    27
# Name: count, dtype: int64
# =====================================================================
# CryptEncrypt
#
# type
# trojan    39
# Name: count, dtype: int64
# =====================================================================
# GetBestInterfaceEx
#
# type
# trojan    24
# Name: count, dtype: int64
# =====================================================================
# NtTerminateThread
#
# type
# ransomware    19
# trojan         2
# Name: count, dtype: int64
# =====================================================================
# CopyFileA
#
# type
# trojan    97
# miner      8
# virus      2
# worm       1
# Name: count, dtype: int64
# =====================================================================
# CreateServiceA
#
# type
# trojan    34
# virus      1
# Name: count, dtype: int64
# =====================================================================
# InternetOpenA
#
# type
# trojan        249
# adware          7
# downloader      3
# pua             3
# miner           1
# virus           1
# Name: count, dtype: int64
# =====================================================================
# InternetConnectA
#
# type
# trojan        194
# adware          7
# downloader      2
# pua             2
# Name: count, dtype: int64
# =====================================================================
# HttpOpenRequestA
#
# type
# trojan    187
# adware      2
# Name: count, dtype: int64
# =====================================================================
# NtGetContextThread
#
# type
# trojan    47
# miner      2
# Name: count, dtype: int64
# =====================================================================
# NtReadVirtualMemory
#
# type
# trojan    3
# miner     2
# Name: count, dtype: int64
# =====================================================================
# NtSetContextThread
#
# type
# trojan    33
# miner      1
# Name: count, dtype: int64
# =====================================================================
# GetDiskFreeSpaceW
#
# type
# trojan        77
# adware         4
# pua            3
# ransomware     1
# miner          1
# Name: count, dtype: int64
# =====================================================================
# InternetOpenW
#
# type
# trojan    22
# pua       21
# adware     2
# virus      1
# Name: count, dtype: int64
# =====================================================================
# InternetGetConnectedState
#
# type
# trojan    3
# Name: count, dtype: int64
# =====================================================================
# InternetCrackUrlA
#
# type
# trojan        54
# adware         7
# downloader     2
# pua            2
# Name: count, dtype: int64
# =====================================================================
# HttpSendRequestA
#
# type
# trojan    15
# Name: count, dtype: int64
# =====================================================================
# InternetCloseHandle
#
# type
# trojan    24
# Name: count, dtype: int64
# =====================================================================
# CreateServiceW
#
# type
# trojan    9
# Name: count, dtype: int64
# =====================================================================
# DeleteUrlCacheEntryA
#
# type
# trojan    6
# miner     1
# pua       1
# Name: count, dtype: int64
# =====================================================================
# gethostbyname
#
# type
# trojan    44
# pua       18
# adware     1
# Name: count, dtype: int64
# =====================================================================
# send
#
# type
# trojan    22
# pua       15
# Name: count, dtype: int64
# =====================================================================
# DeleteUrlCacheEntryW
#
# type
# pua       20
# trojan     2
# Name: count, dtype: int64
# =====================================================================
# WSARecv
#
# type
# pua       11
# trojan     4
# Name: count, dtype: int64
# =====================================================================
# shutdown
#
# type
# pua       10
# trojan     2
# Name: count, dtype: int64
# =====================================================================
# InternetConnectW
#
# type
# pua       19
# trojan     8
# adware     2
# virus      1
# Name: count, dtype: int64
# =====================================================================
# HttpOpenRequestW
#
# type
# pua       19
# trojan     8
# adware     2
# virus      1
# Name: count, dtype: int64
# =====================================================================
# CreateJobObjectW
#
# type
# trojan    27
# pua        3
# adware     2
# Name: count, dtype: int64
# =====================================================================
# CopyFileExW
#
# type
# trojan    28
# pua        2
# Name: count, dtype: int64
# =====================================================================
# RtlRemoveVectoredExceptionHandler
#
# type
# trojan    2
# Name: count, dtype: int64
# =====================================================================
# CreateRemoteThread
#
# type
# trojan    2
# Name: count, dtype: int64
# =====================================================================
# RegDeleteKeyW
#
# type
# trojan        1
# downloader    1
# pua           1
# adware        1
# Name: count, dtype: int64
# =====================================================================
# InternetQueryOptionA
#
# type
# trojan    3
# Name: count, dtype: int64
# =====================================================================
# EnumServicesStatusA
#
# type
# trojan    2
# Name: count, dtype: int64
# =====================================================================
# NtSuspendThread
#
# type
# trojan    21
# Name: count, dtype: int64
# =====================================================================
# RtlDecompressBuffer
#
# type
# trojan    16
# Name: count, dtype: int64
# =====================================================================
# CryptDecodeObjectEx
#
# type
# trojan        1
# downloader    1
# Name: count, dtype: int64
# =====================================================================
# recv
#
# type
# trojan    12
# pua        1
# Name: count, dtype: int64
# =====================================================================
# SetFileInformationByHandle
#
# type
# trojan    1
# Name: count, dtype: int64
# =====================================================================
# GetAddrInfoW
#
# type
# trojan    2
# Name: count, dtype: int64
# =====================================================================
# DnsQuery_A
#
# type
# trojan    9
# Name: count, dtype: int64
# =====================================================================
# InternetSetStatusCallback
#
# type
# trojan    1
# Name: count, dtype: int64
# =====================================================================
# InternetReadFile
#
# type
# trojan    2
# Name: count, dtype: int64
# =====================================================================
# HttpQueryInfoA
#
# type
# trojan    2
# Name: count, dtype: int64
# =====================================================================
# ObtainUserAgentString
#
# type
# trojan    1
# Name: count, dtype: int64
# =====================================================================
# InternetOpenUrlA
#
# type
# trojan    9
# Name: count, dtype: int64
# =====================================================================
# ControlService
#
# type
# trojan    1
# Name: count, dtype: int64
# =====================================================================
# GetUserNameExA
#
# type
# trojan    3
# Name: count, dtype: int64
# =====================================================================
# SetInformationJobObject
#
# type
# trojan    1
# Name: count, dtype: int64
# =====================================================================
# WSASocketA
#
# type
# trojan    1
# Name: count, dtype: int64
# =====================================================================
# InternetOpenUrlW
#
# type
# trojan    1
# Name: count, dtype: int64
# =====================================================================

# %% [markdown]
# ## Identify the Same API Calls found in both Malicious and Benign Samples.
#
# *Apparently, due to the proliferation of trojan-like malware, it could be possible that there are more API Calls that can be found the same between Malicious and Benign Samples.*

# %%
str_output = ""
same = []
for m in malicious_apis:
    if m in benign_apis:
        same.append(m)
str_output += f"No. of API Calls in Malicious Samples that is found in API Calls in Benign Samples: {len(same)} ({len(same)/len(benign_apis)*100:.2f}% Matches API Calls of Benign Samples)\n"
str_output += f"Coverage of 'Same-to-Malicious-Benign-Samples' API Calls to Official API Calls Oliveira.csv: {(len(same)/len(APIS))*100:.4f}%\n"
str_output += "Same API Calls to both Verified Malicious and Benign Samples: "+ str(same) + "\n"

with open("./Output/4 Unique_APICalls_MaliciousBenign.txt", 'w') as f:
    f.write(str_output)
    f.flush()
    f.close()
print(str_output)
# Out:
# No. of API Calls in Malicious Samples that is found in API Calls in Benign Samples: 188 (94.00% Matches API Calls of Benign Samples)
# Coverage of 'Same-to-Malicious-Benign-Samples' API Calls to Official API Calls Oliveira.csv: 61.2378%
# Same API Calls to both Verified Malicious and Benign Samples: ['RegOpenKeyExA', 'NtOpenKey', 'NtQueryValueKey', 'NtClose', 'NtQueryAttributesFile', 'LoadStringA', 'NtAllocateVirtualMemory', 'LdrGetDllHandle', 'LdrGetProcedureAddress', 'GetSystemMetrics', 'FindResourceExW', 'LoadResource', 'LdrLoadDll', 'DrawTextExW', 'FindResourceA', 'SizeofResource', 'GetSystemWindowsDirectoryW', 'NtCreateFile', 'NtCreateSection', 'NtMapViewOfSection', 'CreateActCtxW', 'GetSystemTimeAsFileTime', 'NtFreeVirtualMemory', 'SetUnhandledExceptionFilter', 'GetFileSize', 'SetFilePointer', 'NtReadFile', 'RegOpenKeyExW', 'RegCreateKeyExW', 'RegCloseKey', 'RegSetValueExW', 'IsDebuggerPresent', 'CoInitializeEx', 'GetForegroundWindow', 'OleInitialize', 'GetNativeSystemInfo', 'RegQueryValueExW', 'LookupPrivilegeValueW', 'GetUserNameA', 'RegEnumKeyExA', 'RegQueryValueExA', 'NtProtectVirtualMemory', 'GetSystemInfo', 'NtCreateMutant', 'NtOpenKeyEx', 'NtQuerySystemInformation', 'GetSystemDirectoryW', 'CryptAcquireContextW', 'CryptCreateHash', 'CryptHashData', 'RegEnumKeyW', 'CreateThread', 'UuidCreate', 'NtDelayExecution', 'EnumWindows', 'CoCreateInstance', 'FindResourceW', 'RegQueryInfoKeyW', 'RegEnumKeyExW', 'NtOpenFile', 'NtQueryInformationFile', 'OpenSCManagerW', 'NtDuplicateObject', 'NtCreateThreadEx', 'NtResumeThread', 'SHGetFolderPathW', 'NtUnmapViewOfSection', 'GetComputerNameW', 'GetFileAttributesW', 'GetVolumeNameForVolumeMountPointW', 'FindFirstFileExW', 'LoadStringW', 'SetErrorMode', 'LookupAccountSidW', 'GetTempPathW', 'NtWriteFile', 'GetFileType', 'CreateToolhelp32Snapshot', 'Process32FirstW', 'Process32NextW', 'RegCreateKeyExA', 'RegSetValueExA', 'WSAStartup', 'LdrUnloadDll', 'NtOpenDirectoryObject', 'NtOpenProcess', 'CreateDirectoryW', 'SetEndOfFile', 'CreateProcessInternalW', 'DeleteFileW', 'RemoveDirectoryA', 'SetStdHandle', 'WriteConsoleA', 'GetUserNameW', 'SearchPathW', 'socket', 'FindWindowW', 'NtOpenSection', 'NtSetInformationFile', 'GetTimeZoneInformation', 'GlobalMemoryStatusEx', 'NtDeviceIoControlFile', 'RegEnumValueW', 'NtEnumerateKey', 'NtEnumerateValueKey', 'CoInitializeSecurity', 'GetFileVersionInfoSizeW', 'GetFileVersionInfoW', 'FindResourceExA', 'GetCursorPos', 'SetWindowsHookExA', 'NtOpenMutant', 'ReadProcessMemory', 'OpenServiceW', 'GlobalMemoryStatus', 'NtQueryDirectoryFile', 'closesocket', 'ioctlsocket', 'select', 'CryptAcquireContextA', '__exception__', 'timeGetTime', 'GetSystemDirectoryA', 'OutputDebugStringA', 'GetAdaptersInfo', 'DeviceIoControl', 'GetAdaptersAddresses', 'NtQueryKey', 'SetWindowsHookExW', 'FindWindowA', 'SetFileAttributesW', 'RegQueryInfoKeyA', 'NtTerminateProcess', 'GetShortPathNameW', 'CopyFileW', 'CoUninitialize', 'InternetSetOptionA', 'NtCreateKey', 'NtSetValueKey', 'NtOpenThread', 'WriteProcessMemory', 'GetVolumePathNamesForVolumeNameW', 'ShellExecuteExW', 'FindWindowExA', 'bind', 'getsockname', 'GetComputerNameA', 'MessageBoxTimeoutA', 'RtlAddVectoredExceptionHandler', 'GetFileAttributesExW', 'GetVolumePathNameW', 'StartServiceW', 'FindWindowExW', 'RemoveDirectoryW', 'GetFileInformationByHandle', 'GetSystemWindowsDirectoryA', 'RegEnumValueA', 'SHGetSpecialFolderLocation', 'GetFileSizeEx', 'Thread32First', 'Thread32Next', 'DrawTextExA', 'CoGetClassObject', 'setsockopt', 'InternetCrackUrlW', 'CoCreateInstanceEx', 'IWbemServices_ExecQuery', 'SetFilePointerEx', 'GetDiskFreeSpaceExW', 'UnhookWindowsHookEx', 'RegisterHotKey', 'GetKeyboardState', 'CryptGenKey', 'CryptExportKey', 'WSASocketW', 'GetKeyState', 'GetAsyncKeyState', 'Module32FirstW', 'Module32NextW', 'NtQueueApcThread', 'MessageBoxTimeoutW', 'GetFileInformationByHandleEx', 'RegDeleteValueA', 'SendNotifyMessageW', 'sendto', 'RegDeleteValueW', 'NetUserGetInfo', 'CertOpenStore']

# %%
for s in same:
    str_output += s + "\n\n"
    str_output += str(malicious_df[malicious_df['pattern'].str.contains(s)]['type'].value_counts())
    str_output += "\n=====================================================================\n"

with open("./Output/4 APICalls_MalwareTypes_MaliciousBenign.txt", 'w') as f:
    f.write(str_output)
    f.flush()
    f.close()
print(str_output)
# Out:
# No. of API Calls in Malicious Samples that is found in API Calls in Benign Samples: 188 (94.00% Matches API Calls of Benign Samples)
# Coverage of 'Same-to-Malicious-Benign-Samples' API Calls to Official API Calls Oliveira.csv: 61.2378%
# Same API Calls to both Verified Malicious and Benign Samples: ['RegOpenKeyExA', 'NtOpenKey', 'NtQueryValueKey', 'NtClose', 'NtQueryAttributesFile', 'LoadStringA', 'NtAllocateVirtualMemory', 'LdrGetDllHandle', 'LdrGetProcedureAddress', 'GetSystemMetrics', 'FindResourceExW', 'LoadResource', 'LdrLoadDll', 'DrawTextExW', 'FindResourceA', 'SizeofResource', 'GetSystemWindowsDirectoryW', 'NtCreateFile', 'NtCreateSection', 'NtMapViewOfSection', 'CreateActCtxW', 'GetSystemTimeAsFileTime', 'NtFreeVirtualMemory', 'SetUnhandledExceptionFilter', 'GetFileSize', 'SetFilePointer', 'NtReadFile', 'RegOpenKeyExW', 'RegCreateKeyExW', 'RegCloseKey', 'RegSetValueExW', 'IsDebuggerPresent', 'CoInitializeEx', 'GetForegroundWindow', 'OleInitialize', 'GetNativeSystemInfo', 'RegQueryValueExW', 'LookupPrivilegeValueW', 'GetUserNameA', 'RegEnumKeyExA', 'RegQueryValueExA', 'NtProtectVirtualMemory', 'GetSystemInfo', 'NtCreateMutant', 'NtOpenKeyEx', 'NtQuerySystemInformation', 'GetSystemDirectoryW', 'CryptAcquireContextW', 'CryptCreateHash', 'CryptHashData', 'RegEnumKeyW', 'CreateThread', 'UuidCreate', 'NtDelayExecution', 'EnumWindows', 'CoCreateInstance', 'FindResourceW', 'RegQueryInfoKeyW', 'RegEnumKeyExW', 'NtOpenFile', 'NtQueryInformationFile', 'OpenSCManagerW', 'NtDuplicateObject', 'NtCreateThreadEx', 'NtResumeThread', 'SHGetFolderPathW', 'NtUnmapViewOfSection', 'GetComputerNameW', 'GetFileAttributesW', 'GetVolumeNameForVolumeMountPointW', 'FindFirstFileExW', 'LoadStringW', 'SetErrorMode', 'LookupAccountSidW', 'GetTempPathW', 'NtWriteFile', 'GetFileType', 'CreateToolhelp32Snapshot', 'Process32FirstW', 'Process32NextW', 'RegCreateKeyExA', 'RegSetValueExA', 'WSAStartup', 'LdrUnloadDll', 'NtOpenDirectoryObject', 'NtOpenProcess', 'CreateDirectoryW', 'SetEndOfFile', 'CreateProcessInternalW', 'DeleteFileW', 'RemoveDirectoryA', 'SetStdHandle', 'WriteConsoleA', 'GetUserNameW', 'SearchPathW', 'socket', 'FindWindowW', 'NtOpenSection', 'NtSetInformationFile', 'GetTimeZoneInformation', 'GlobalMemoryStatusEx', 'NtDeviceIoControlFile', 'RegEnumValueW', 'NtEnumerateKey', 'NtEnumerateValueKey', 'CoInitializeSecurity', 'GetFileVersionInfoSizeW', 'GetFileVersionInfoW', 'FindResourceExA', 'GetCursorPos', 'SetWindowsHookExA', 'NtOpenMutant', 'ReadProcessMemory', 'OpenServiceW', 'GlobalMemoryStatus', 'NtQueryDirectoryFile', 'closesocket', 'ioctlsocket', 'select', 'CryptAcquireContextA', '__exception__', 'timeGetTime', 'GetSystemDirectoryA', 'OutputDebugStringA', 'GetAdaptersInfo', 'DeviceIoControl', 'GetAdaptersAddresses', 'NtQueryKey', 'SetWindowsHookExW', 'FindWindowA', 'SetFileAttributesW', 'RegQueryInfoKeyA', 'NtTerminateProcess', 'GetShortPathNameW', 'CopyFileW', 'CoUninitialize', 'InternetSetOptionA', 'NtCreateKey', 'NtSetValueKey', 'NtOpenThread', 'WriteProcessMemory', 'GetVolumePathNamesForVolumeNameW', 'ShellExecuteExW', 'FindWindowExA', 'bind', 'getsockname', 'GetComputerNameA', 'MessageBoxTimeoutA', 'RtlAddVectoredExceptionHandler', 'GetFileAttributesExW', 'GetVolumePathNameW', 'StartServiceW', 'FindWindowExW', 'RemoveDirectoryW', 'GetFileInformationByHandle', 'GetSystemWindowsDirectoryA', 'RegEnumValueA', 'SHGetSpecialFolderLocation', 'GetFileSizeEx', 'Thread32First', 'Thread32Next', 'DrawTextExA', 'CoGetClassObject', 'setsockopt', 'InternetCrackUrlW', 'CoCreateInstanceEx', 'IWbemServices_ExecQuery', 'SetFilePointerEx', 'GetDiskFreeSpaceExW', 'UnhookWindowsHookEx', 'RegisterHotKey', 'GetKeyboardState', 'CryptGenKey', 'CryptExportKey', 'WSASocketW', 'GetKeyState', 'GetAsyncKeyState', 'Module32FirstW', 'Module32NextW', 'NtQueueApcThread', 'MessageBoxTimeoutW', 'GetFileInformationByHandleEx', 'RegDeleteValueA', 'SendNotifyMessageW', 'sendto', 'RegDeleteValueW', 'NetUserGetInfo', 'CertOpenStore']
# RegOpenKeyExA
#
# type
# trojan        12692
# downloader     1790
# pua             992
# adware          789
# miner            78
# virus            59
# spyware          45
# dropper           3
# worm              3
# ransomware        3
# hacktool          2
# Name: count, dtype: int64
# =====================================================================
# NtOpenKey
#
# type
# trojan        29340
# pua            1745
# adware         1508
# downloader     1121
# ransomware      335
# miner            76
# virus            66
# spyware          47
# hacktool          6
# dropper           5
# worm              3
# Name: count, dtype: int64
# =====================================================================
# NtQueryValueKey
#
# type
# trojan        28592
# pua            1649
# adware         1444
# downloader     1062
# ransomware      335
# miner            76
# virus            63
# spyware          47
# hacktool          6
# dropper           5
# worm              3
# Name: count, dtype: int64
# =====================================================================
# NtClose
#
# type
# trojan        32881
# downloader     2248
# pua            2127
# adware         1778
# ransomware      341
# miner           123
# virus            74
# spyware          48
# hacktool          7
# dropper           5
# worm              3
# Name: count, dtype: int64
# =====================================================================
# NtQueryAttributesFile
#
# type
# trojan        5213
# pua            400
# adware         365
# miner           64
# spyware         40
# virus           23
# downloader      17
# hacktool         5
# dropper          2
# worm             1
# Name: count, dtype: int64
# =====================================================================
# LoadStringA
#
# type
# trojan        6154
# pua             94
# adware          78
# spyware         43
# virus           24
# downloader       9
# miner            5
# hacktool         3
# worm             2
# Name: count, dtype: int64
# =====================================================================
# NtAllocateVirtualMemory
#
# type
# trojan        28843
# pua            1887
# downloader     1757
# adware         1520
# ransomware      333
# miner           109
# virus            60
# spyware          45
# hacktool          7
# dropper           3
# worm              3
# Name: count, dtype: int64
# =====================================================================
# LdrGetDllHandle
#
# type
# trojan        32846
# downloader     2249
# pua            2126
# adware         1806
# ransomware      331
# miner           121
# virus            64
# spyware          47
# hacktool          7
# dropper           5
# worm              2
# Name: count, dtype: int64
# =====================================================================
# LdrGetProcedureAddress
#
# type
# trojan        33278
# downloader     2249
# pua            2133
# adware         1808
# ransomware      341
# miner           124
# virus            77
# spyware          48
# hacktool          7
# dropper           5
# worm              3
# Name: count, dtype: int64
# =====================================================================
# GetSystemMetrics
#
# type
# trojan        18075
# downloader     1473
# pua            1158
# adware          667
# spyware          44
# virus            30
# miner            19
# ransomware        6
# hacktool          4
# worm              2
# dropper           1
# Name: count, dtype: int64
# =====================================================================
# FindResourceExW
#
# type
# trojan        13357
# pua             545
# downloader      441
# adware          273
# spyware          36
# virus            22
# miner            20
# ransomware        4
# worm              2
# hacktool          1
# Name: count, dtype: int64
# =====================================================================
# LoadResource
#
# type
# trojan        19382
# adware          867
# pua             795
# downloader      458
# spyware          37
# miner            29
# virus            27
# hacktool          4
# ransomware        3
# worm              1
# Name: count, dtype: int64
# =====================================================================
# LdrLoadDll
#
# type
# trojan        32916
# downloader     2249
# pua            2097
# adware         1787
# ransomware      341
# miner           123
# virus            76
# spyware          48
# hacktool          7
# dropper           5
# worm              3
# Name: count, dtype: int64
# =====================================================================
# DrawTextExW
#
# type
# trojan        11043
# pua             308
# adware          184
# downloader      179
# spyware          35
# virus             7
# miner             2
# hacktool          1
# worm              1
# Name: count, dtype: int64
# =====================================================================
# FindResourceA
#
# type
# trojan        4008
# adware         102
# pua             90
# virus           11
# downloader       8
# miner            6
# spyware          4
# hacktool         3
# worm             1
# Name: count, dtype: int64
# =====================================================================
# SizeofResource
#
# type
# trojan        11187
# adware          688
# pua             459
# downloader       34
# miner            14
# virus             8
# hacktool          4
# spyware           3
# ransomware        3
# worm              1
# Name: count, dtype: int64
# =====================================================================
# GetSystemWindowsDirectoryW
#
# type
# trojan        12085
# pua            1359
# adware         1042
# downloader      635
# ransomware      324
# miner            91
# virus            45
# spyware          40
# hacktool          6
# dropper           5
# worm              1
# Name: count, dtype: int64
# =====================================================================
# NtCreateFile
#
# type
# trojan        17747
# adware         1285
# pua            1277
# downloader      655
# ransomware      331
# miner           114
# virus            66
# spyware          44
# hacktool          7
# dropper           4
# worm              1
# Name: count, dtype: int64
# =====================================================================
# NtCreateSection
#
# type
# trojan        9728
# pua           1140
# adware         915
# downloader     629
# ransomware     328
# miner          100
# virus           50
# spyware         42
# hacktool         6
# dropper          4
# Name: count, dtype: int64
# =====================================================================
# NtMapViewOfSection
#
# type
# trojan        11194
# pua            1222
# adware         1011
# downloader      630
# ransomware      328
# miner           106
# virus            51
# spyware          35
# hacktool          6
# dropper           4
# Name: count, dtype: int64
# =====================================================================
# CreateActCtxW
#
# type
# trojan        9676
# downloader     506
# pua            479
# adware         464
# virus           20
# miner            4
# dropper          3
# spyware          1
# worm             1
# ransomware       1
# Name: count, dtype: int64
# =====================================================================
# GetSystemTimeAsFileTime
#
# type
# trojan        18295
# downloader     1329
# pua            1153
# adware         1100
# miner           100
# virus            17
# ransomware       11
# spyware           3
# dropper           3
# hacktool          1
# Name: count, dtype: int64
# =====================================================================
# NtFreeVirtualMemory
#
# type
# trojan        10846
# pua            1510
# downloader     1325
# adware         1104
# ransomware      327
# virus            55
# miner            44
# spyware          35
# hacktool          5
# dropper           3
# worm              3
# Name: count, dtype: int64
# =====================================================================
# SetUnhandledExceptionFilter
#
# type
# trojan        15385
# downloader     1324
# pua            1130
# adware         1064
# miner            86
# virus            16
# ransomware        6
# hacktool          1
# dropper           1
# Name: count, dtype: int64
# =====================================================================
# GetFileSize
#
# type
# trojan        10492
# adware          644
# pua             533
# ransomware      314
# downloader       35
# virus            20
# miner            19
# hacktool          3
# spyware           3
# Name: count, dtype: int64
# =====================================================================
# SetFilePointer
#
# type
# trojan        8720
# pua            699
# adware         662
# downloader      40
# virus           33
# miner           16
# hacktool         4
# ransomware       2
# spyware          1
# Name: count, dtype: int64
# =====================================================================
# NtReadFile
#
# type
# trojan        8297
# adware         705
# pua            703
# downloader      37
# virus           33
# miner           18
# hacktool         4
# ransomware       3
# spyware          1
# Name: count, dtype: int64
# =====================================================================
# RegOpenKeyExW
#
# type
# trojan        24313
# downloader     2234
# pua            1738
# adware         1464
# ransomware      337
# miner            88
# virus            46
# spyware           6
# dropper           5
# hacktool          3
# worm              1
# Name: count, dtype: int64
# =====================================================================
# RegCreateKeyExW
#
# type
# trojan        7498
# adware         367
# pua            207
# downloader      27
# virus            2
# ransomware       2
# spyware          1
# worm             1
# Name: count, dtype: int64
# =====================================================================
# RegCloseKey
#
# type
# trojan        25003
# downloader     2236
# pua            1811
# adware         1559
# ransomware      336
# miner            93
# virus            60
# spyware          46
# dropper           5
# hacktool          2
# worm              1
# Name: count, dtype: int64
# =====================================================================
# RegSetValueExW
#
# type
# trojan        7385
# adware         333
# pua            204
# downloader      25
# ransomware       3
# virus            2
# hacktool         1
# spyware          1
# Name: count, dtype: int64
# =====================================================================
# IsDebuggerPresent
#
# type
# trojan        1745
# pua            311
# adware         164
# downloader      19
# miner           11
# ransomware       7
# hacktool         4
# virus            4
# Name: count, dtype: int64
# =====================================================================
# CoInitializeEx
#
# type
# trojan        12588
# adware          803
# pua             700
# downloader      142
# virus             9
# spyware           9
# ransomware        5
# miner             3
# Name: count, dtype: int64
# =====================================================================
# GetForegroundWindow
#
# type
# trojan        566
# pua           162
# adware         51
# downloader     17
# miner           6
# virus           5
# hacktool        1
# Name: count, dtype: int64
# =====================================================================
# OleInitialize
#
# type
# trojan        9518
# downloader     903
# pua            434
# adware         431
# virus           25
# miner           22
# spyware          4
# dropper          3
# ransomware       2
# hacktool         1
# worm             1
# Name: count, dtype: int64
# =====================================================================
# GetNativeSystemInfo
#
# type
# trojan        7938
# pua            696
# downloader     592
# adware         541
# miner           73
# virus           21
# ransomware       5
# dropper          4
# hacktool         1
# spyware          1
# Name: count, dtype: int64
# =====================================================================
# RegQueryValueExW
#
# type
# trojan        23243
# downloader     2226
# pua            1393
# adware         1337
# ransomware      336
# miner            83
# virus            37
# spyware           6
# dropper           5
# hacktool          2
# worm              1
# Name: count, dtype: int64
# =====================================================================
# LookupPrivilegeValueW
#
# type
# trojan        110
# adware          1
# miner           1
# ransomware      1
# worm            1
# Name: count, dtype: int64
# =====================================================================
# GetUserNameA
#
# type
# trojan    109
# adware      3
# virus       2
# miner       1
# Name: count, dtype: int64
# =====================================================================
# RegEnumKeyExA
#
# type
# trojan        142
# pua             2
# adware          1
# ransomware      1
# Name: count, dtype: int64
# =====================================================================
# RegQueryValueExA
#
# type
# trojan        5419
# downloader    1288
# pua            719
# adware         419
# spyware         41
# virus           29
# miner           17
# dropper          2
# hacktool         1
# ransomware       1
# worm             1
# Name: count, dtype: int64
# =====================================================================
# NtProtectVirtualMemory
#
# type
# trojan        14384
# pua             953
# adware          756
# miner            53
# downloader       27
# virus            22
# spyware          14
# ransomware        9
# hacktool          4
# worm              1
# Name: count, dtype: int64
# =====================================================================
# GetSystemInfo
#
# type
# trojan        17253
# pua             933
# adware          731
# downloader      426
# miner            92
# spyware          37
# virus            31
# ransomware       11
# hacktool          3
# dropper           2
# worm              2
# Name: count, dtype: int64
# =====================================================================
# NtCreateMutant
#
# type
# trojan        5900
# pua            768
# adware         729
# ransomware     330
# downloader     194
# miner           90
# virus           34
# spyware          4
# dropper          4
# hacktool         2
# Name: count, dtype: int64
# =====================================================================
# NtOpenKeyEx
#
# type
# trojan        4331
# pua             88
# adware          83
# miner           17
# downloader       8
# virus            6
# ransomware       5
# spyware          3
# hacktool         1
# Name: count, dtype: int64
# =====================================================================
# NtQuerySystemInformation
#
# type
# trojan        5275
# ransomware     315
# pua            234
# adware         191
# miner           31
# virus           22
# downloader      16
# spyware          4
# dropper          2
# hacktool         1
# worm             1
# Name: count, dtype: int64
# =====================================================================
# GetSystemDirectoryW
#
# type
# trojan        10305
# pua            1129
# adware          916
# downloader      530
# miner            86
# spyware          36
# virus            29
# ransomware        9
# dropper           4
# hacktool          2
# Name: count, dtype: int64
# =====================================================================
# CryptAcquireContextW
#
# type
# trojan        10688
# adware          387
# ransomware      315
# pua             281
# downloader      110
# spyware           1
# miner             1
# virus             1
# Name: count, dtype: int64
# =====================================================================
# CryptCreateHash
#
# type
# trojan        7420
# adware         267
# downloader     109
# pua            106
# miner            1
# ransomware       1
# virus            1
# Name: count, dtype: int64
# =====================================================================
# CryptHashData
#
# type
# trojan        7419
# adware         267
# downloader     109
# pua            106
# miner            1
# ransomware       1
# virus            1
# Name: count, dtype: int64
# =====================================================================
# RegEnumKeyW
#
# type
# trojan        8330
# adware         451
# downloader     365
# pua            230
# virus           14
# miner            2
# dropper          1
# ransomware       1
# Name: count, dtype: int64
# =====================================================================
# CreateThread
#
# type
# trojan        11692
# adware          723
# pua             390
# ransomware      316
# spyware          30
# miner            19
# downloader       18
# virus            11
# worm              1
# hacktool          1
# Name: count, dtype: int64
# =====================================================================
# UuidCreate
#
# type
# trojan        7611
# adware         362
# pua            166
# downloader      16
# virus            3
# ransomware       2
# spyware          1
# Name: count, dtype: int64
# =====================================================================
# NtDelayExecution
#
# type
# trojan        7780
# adware         467
# ransomware     315
# pua            278
# miner           20
# downloader       8
# virus            8
# spyware          1
# worm             1
# Name: count, dtype: int64
# =====================================================================
# EnumWindows
#
# type
# trojan        4969
# adware         174
# pua             29
# downloader       7
# virus            1
# ransomware       1
# Name: count, dtype: int64
# =====================================================================
# CoCreateInstance
#
# type
# trojan        7393
# adware         342
# pua             83
# downloader      24
# miner            2
# ransomware       2
# virus            2
# worm             1
# Name: count, dtype: int64
# =====================================================================
# FindResourceW
#
# type
# trojan        7408
# adware         664
# pua            411
# downloader      25
# miner            7
# ransomware       4
# virus            1
# spyware          1
# dropper          1
# hacktool         1
# Name: count, dtype: int64
# =====================================================================
# RegQueryInfoKeyW
#
# type
# trojan        8871
# adware         245
# pua             50
# downloader      15
# miner            7
# ransomware       5
# spyware          3
# Name: count, dtype: int64
# =====================================================================
# RegEnumKeyExW
#
# type
# trojan        8786
# adware         243
# pua             49
# downloader      14
# miner            7
# ransomware       5
# spyware          3
# Name: count, dtype: int64
# =====================================================================
# NtOpenFile
#
# type
# trojan        999
# ransomware    327
# adware        191
# pua           154
# virus          19
# downloader      6
# miner           5
# hacktool        2
# spyware         2
# worm            1
# Name: count, dtype: int64
# =====================================================================
# NtQueryInformationFile
#
# type
# trojan        1151
# ransomware     323
# adware          86
# pua             28
# virus            7
# miner            2
# worm             1
# hacktool         1
# Name: count, dtype: int64
# =====================================================================
# OpenSCManagerW
#
# type
# trojan        104
# adware         30
# ransomware      1
# pua             1
# Name: count, dtype: int64
# =====================================================================
# NtDuplicateObject
#
# type
# trojan        4204
# pua            495
# downloader     487
# adware         474
# miner           55
# virus           33
# ransomware      24
# dropper          2
# hacktool         1
# spyware          1
# worm             1
# Name: count, dtype: int64
# =====================================================================
# NtCreateThreadEx
#
# type
# trojan        2132
# adware         140
# pua            132
# miner            8
# ransomware       2
# virus            1
# downloader       1
# worm             1
# Name: count, dtype: int64
# =====================================================================
# NtResumeThread
#
# type
# trojan        1993
# pua            151
# adware         137
# miner            9
# ransomware       3
# downloader       2
# virus            1
# worm             1
# Name: count, dtype: int64
# =====================================================================
# SHGetFolderPathW
#
# type
# trojan        385
# adware        216
# pua           208
# ransomware     11
# downloader     10
# virus           2
# miner           2
# hacktool        1
# Name: count, dtype: int64
# =====================================================================
# NtUnmapViewOfSection
#
# type
# trojan        2491
# downloader     101
# pua             85
# miner           70
# adware          37
# ransomware       4
# spyware          3
# virus            1
# Name: count, dtype: int64
# =====================================================================
# GetComputerNameW
#
# type
# trojan        128
# adware         62
# ransomware     14
# pua            12
# downloader      1
# Name: count, dtype: int64
# =====================================================================
# GetFileAttributesW
#
# type
# trojan        5002
# pua            318
# adware         223
# downloader     117
# virus           30
# miner           27
# spyware          7
# ransomware       6
# hacktool         3
# worm             2
# Name: count, dtype: int64
# =====================================================================
# GetVolumeNameForVolumeMountPointW
#
# type
# trojan        1149
# downloader     495
# adware         242
# pua            233
# virus           29
# miner            7
# dropper          2
# spyware          1
# Name: count, dtype: int64
# =====================================================================
# FindFirstFileExW
#
# type
# trojan        9566
# downloader     420
# pua            346
# adware         160
# virus           19
# miner           16
# ransomware       4
# spyware          3
# hacktool         2
# Name: count, dtype: int64
# =====================================================================
# LoadStringW
#
# type
# trojan        7953
# downloader     894
# pua            741
# adware         657
# miner           72
# virus           27
# dropper          4
# ransomware       4
# hacktool         3
# spyware          1
# Name: count, dtype: int64
# =====================================================================
# SetErrorMode
#
# type
# trojan        10337
# downloader     1021
# pua             950
# adware          815
# miner            75
# virus            41
# hacktool          5
# spyware           5
# dropper           5
# ransomware        4
# worm              1
# Name: count, dtype: int64
# =====================================================================
# LookupAccountSidW
#
# type
# trojan        5415
# downloader     401
# pua            107
# adware          75
# virus            1
# ransomware       1
# miner            1
# Name: count, dtype: int64
# =====================================================================
# GetTempPathW
#
# type
# trojan        1284
# ransomware     310
# pua             86
# adware          61
# virus           28
# miner            7
# downloader       5
# hacktool         2
# spyware          1
# worm             1
# Name: count, dtype: int64
# =====================================================================
# NtWriteFile
#
# type
# trojan        577
# adware        112
# pua           110
# virus          38
# miner          13
# downloader      7
# hacktool        5
# ransomware      2
# Name: count, dtype: int64
# =====================================================================
# GetFileType
#
# type
# trojan        3158
# pua            133
# adware         117
# miner           21
# virus           19
# downloader       9
# spyware          1
# ransomware       1
# Name: count, dtype: int64
# =====================================================================
# CreateToolhelp32Snapshot
#
# type
# trojan        416
# adware        100
# ransomware     34
# pua            19
# miner          18
# virus           1
# Name: count, dtype: int64
# =====================================================================
# Process32FirstW
#
# type
# trojan        333
# adware        100
# ransomware     28
# pua            18
# miner           9
# virus           1
# Name: count, dtype: int64
# =====================================================================
# Process32NextW
#
# type
# trojan        244
# adware        102
# ransomware     28
# pua            18
# miner          10
# virus           1
# Name: count, dtype: int64
# =====================================================================
# RegCreateKeyExA
#
# type
# trojan        262
# adware        186
# pua            66
# downloader      6
# virus           5
# hacktool        1
# spyware         1
# miner           1
# ransomware      1
# worm            1
# Name: count, dtype: int64
# =====================================================================
# RegSetValueExA
#
# type
# trojan        247
# adware        148
# pua            19
# virus           6
# downloader      5
# miner           3
# ransomware      1
# worm            1
# Name: count, dtype: int64
# =====================================================================
# WSAStartup
#
# type
# trojan        4547
# adware         357
# pua            331
# miner           63
# spyware         16
# virus            8
# downloader       4
# ransomware       3
# hacktool         1
# worm             1
# Name: count, dtype: int64
# =====================================================================
# LdrUnloadDll
#
# type
# trojan        1223
# pua            126
# adware          96
# miner           62
# virus           10
# downloader       9
# Name: count, dtype: int64
# =====================================================================
# NtOpenDirectoryObject
#
# type
# trojan        4741
# pua            242
# adware         199
# miner           65
# virus            7
# downloader       4
# ransomware       2
# Name: count, dtype: int64
# =====================================================================
# NtOpenProcess
#
# type
# downloader    1176
# trojan         838
# pua            251
# adware          69
# ransomware      10
# miner            8
# hacktool         1
# Name: count, dtype: int64
# =====================================================================
# CreateDirectoryW
#
# type
# trojan        566
# pua           133
# adware         83
# virus          22
# downloader     17
# miner          13
# hacktool        5
# Name: count, dtype: int64
# =====================================================================
# SetEndOfFile
#
# type
# trojan        620
# pua            69
# adware         38
# miner           4
# hacktool        3
# virus           3
# downloader      2
# Name: count, dtype: int64
# =====================================================================
# CreateProcessInternalW
#
# type
# trojan        236
# pua            54
# adware         18
# virus          15
# miner          10
# hacktool        3
# downloader      2
# ransomware      2
# Name: count, dtype: int64
# =====================================================================
# DeleteFileW
#
# type
# trojan        159
# pua            43
# adware         15
# miner           5
# virus           5
# downloader      5
# hacktool        3
# ransomware      1
# worm            1
# Name: count, dtype: int64
# =====================================================================
# RemoveDirectoryA
#
# type
# trojan        59
# adware        13
# pua           10
# virus          4
# hacktool       2
# downloader     2
# miner          2
# Name: count, dtype: int64
# =====================================================================
# SetStdHandle
#
# type
# trojan    20
# Name: count, dtype: int64
# =====================================================================
# WriteConsoleA
#
# type
# trojan        161
# miner           2
# adware          2
# ransomware      1
# downloader      1
# Name: count, dtype: int64
# =====================================================================
# GetUserNameW
#
# type
# trojan        2409
# pua            160
# adware         109
# ransomware      14
# downloader       1
# Name: count, dtype: int64
# =====================================================================
# SearchPathW
#
# type
# trojan     1450
# pua           5
# spyware       3
# adware        2
# miner         2
# virus         2
# worm          1
# Name: count, dtype: int64
# =====================================================================
# socket
#
# type
# adware        152
# trojan         87
# pua            82
# miner          53
# downloader      1
# Name: count, dtype: int64
# =====================================================================
# FindWindowW
#
# type
# trojan        119
# adware         15
# pua             5
# ransomware      4
# spyware         1
# miner           1
# Name: count, dtype: int64
# =====================================================================
# NtOpenSection
#
# type
# trojan        1840
# downloader     594
# pua            341
# adware         295
# virus           18
# miner            8
# dropper          2
# hacktool         1
# Name: count, dtype: int64
# =====================================================================
# NtSetInformationFile
#
# type
# trojan      189
# pua          19
# adware        9
# virus         2
# hacktool      1
# Name: count, dtype: int64
# =====================================================================
# GetTimeZoneInformation
#
# type
# trojan        4068
# adware         156
# pua            148
# downloader      27
# virus           10
# miner            1
# Name: count, dtype: int64
# =====================================================================
# GlobalMemoryStatusEx
#
# type
# trojan      604
# pua         110
# adware       53
# miner        11
# virus         4
# hacktool      1
# spyware       1
# dropper       1
# worm          1
# Name: count, dtype: int64
# =====================================================================
# NtDeviceIoControlFile
#
# type
# trojan    448
# pua       174
# adware     17
# Name: count, dtype: int64
# =====================================================================
# RegEnumValueW
#
# type
# trojan        2523
# adware          24
# pua             15
# miner            7
# downloader       5
# ransomware       4
# spyware          3
# Name: count, dtype: int64
# =====================================================================
# NtEnumerateKey
#
# type
# trojan        959
# adware         38
# pua            21
# ransomware     11
# miner           4
# downloader      3
# virus           2
# Name: count, dtype: int64
# =====================================================================
# NtEnumerateValueKey
#
# type
# trojan        965
# adware         38
# pua            21
# ransomware     11
# miner           5
# downloader      3
# virus           2
# Name: count, dtype: int64
# =====================================================================
# CoInitializeSecurity
#
# type
# adware        54
# trojan        45
# pua            9
# virus          1
# spyware        1
# ransomware     1
# Name: count, dtype: int64
# =====================================================================
# GetFileVersionInfoSizeW
#
# type
# trojan        1053
# pua            146
# adware         101
# downloader       5
# spyware          2
# worm             1
# virus            1
# Name: count, dtype: int64
# =====================================================================
# GetFileVersionInfoW
#
# type
# trojan        887
# pua           136
# adware         94
# downloader      4
# spyware         2
# worm            1
# virus           1
# Name: count, dtype: int64
# =====================================================================
# FindResourceExA
#
# type
# trojan        267
# adware         29
# pua             8
# spyware         2
# downloader      2
# hacktool        1
# virus           1
# Name: count, dtype: int64
# =====================================================================
# GetCursorPos
#
# type
# trojan        937
# pua           138
# adware         42
# virus           7
# downloader      5
# miner           2
# spyware         1
# dropper         1
# ransomware      1
# Name: count, dtype: int64
# =====================================================================
# SetWindowsHookExA
#
# type
# trojan        1658
# pua             11
# adware           8
# virus            6
# downloader       5
# spyware          4
# miner            2
# worm             1
# Name: count, dtype: int64
# =====================================================================
# NtOpenMutant
#
# type
# trojan        394
# pua           169
# adware         71
# downloader     12
# ransomware     10
# virus           5
# spyware         2
# miner           2
# Name: count, dtype: int64
# =====================================================================
# ReadProcessMemory
#
# type
# trojan        388
# pua            15
# adware         10
# downloader      4
# virus           2
# miner           1
# Name: count, dtype: int64
# =====================================================================
# OpenServiceW
#
# type
# trojan    65
# adware    29
# pua        1
# Name: count, dtype: int64
# =====================================================================
# GlobalMemoryStatus
#
# type
# trojan      1172
# pua          110
# adware        53
# miner         11
# virus          4
# hacktool       1
# spyware        1
# dropper        1
# worm           1
# Name: count, dtype: int64
# =====================================================================
# NtQueryDirectoryFile
#
# type
# trojan        998
# downloader    210
# adware        100
# pua            97
# virus          18
# ransomware      5
# miner           5
# spyware         1
# Name: count, dtype: int64
# =====================================================================
# closesocket
#
# type
# adware    82
# trojan    33
# miner     28
# pua       17
# Name: count, dtype: int64
# =====================================================================
# ioctlsocket
#
# type
# adware    104
# trojan     12
# pua         6
# Name: count, dtype: int64
# =====================================================================
# select
#
# type
# adware    102
# trojan     17
# pua         6
# Name: count, dtype: int64
# =====================================================================
# CryptAcquireContextA
#
# type
# trojan    46
# adware     1
# Name: count, dtype: int64
# =====================================================================
# __exception__
#
# type
# trojan        696
# pua            40
# adware         19
# virus           8
# miner           7
# spyware         1
# downloader      1
# Name: count, dtype: int64
# =====================================================================
# timeGetTime
#
# type
# trojan        248
# miner           6
# pua             2
# downloader      2
# Name: count, dtype: int64
# =====================================================================
# GetSystemDirectoryA
#
# type
# trojan        594
# adware         36
# pua            30
# downloader     12
# miner          10
# virus           3
# Name: count, dtype: int64
# =====================================================================
# OutputDebugStringA
#
# type
# trojan        265
# pua           104
# adware         35
# miner           5
# downloader      1
# ransomware      1
# Name: count, dtype: int64
# =====================================================================
# GetAdaptersInfo
#
# type
# adware    79
# trojan    53
# pua        9
# virus      1
# Name: count, dtype: int64
# =====================================================================
# DeviceIoControl
#
# type
# trojan      563
# pua         184
# adware       86
# hacktool      1
# Name: count, dtype: int64
# =====================================================================
# GetAdaptersAddresses
#
# type
# trojan    26
# Name: count, dtype: int64
# =====================================================================
# NtQueryKey
#
# type
# trojan        408
# adware         11
# pua             7
# miner           6
# ransomware      4
# downloader      2
# spyware         1
# Name: count, dtype: int64
# =====================================================================
# SetWindowsHookExW
#
# type
# trojan        83
# adware        27
# pua           21
# virus          1
# dropper        1
# ransomware     1
# downloader     1
# Name: count, dtype: int64
# =====================================================================
# FindWindowA
#
# type
# trojan    231
# pua         4
# miner       3
# virus       1
# adware      1
# worm        1
# Name: count, dtype: int64
# =====================================================================
# SetFileAttributesW
#
# type
# trojan        125
# pua            15
# miner           6
# adware          5
# virus           2
# downloader      1
# worm            1
# Name: count, dtype: int64
# =====================================================================
# RegQueryInfoKeyA
#
# type
# pua       2
# adware    1
# trojan    1
# Name: count, dtype: int64
# =====================================================================
# NtTerminateProcess
#
# type
# trojan    110
# adware      9
# pua         5
# miner       1
# virus       1
# Name: count, dtype: int64
# =====================================================================
# GetShortPathNameW
#
# type
# trojan        197
# downloader      1
# spyware         1
# ransomware      1
# Name: count, dtype: int64
# =====================================================================
# CopyFileW
#
# type
# trojan        71
# adware         4
# pua            4
# ransomware     2
# virus          1
# Name: count, dtype: int64
# =====================================================================
# CoUninitialize
#
# type
# trojan        56
# pua           22
# adware         7
# miner          2
# spyware        1
# ransomware     1
# downloader     1
# virus          1
# Name: count, dtype: int64
# =====================================================================
# InternetSetOptionA
#
# type
# trojan        186
# adware          7
# pua             4
# downloader      3
# miner           1
# Name: count, dtype: int64
# =====================================================================
# NtCreateKey
#
# type
# trojan    146
# virus       1
# Name: count, dtype: int64
# =====================================================================
# NtSetValueKey
#
# type
# trojan    141
# virus       1
# Name: count, dtype: int64
# =====================================================================
# NtOpenThread
#
# type
# trojan        225
# pua             5
# adware          4
# downloader      1
# Name: count, dtype: int64
# =====================================================================
# WriteProcessMemory
#
# type
# trojan        100
# adware         67
# pua            15
# miner           8
# ransomware      1
# Name: count, dtype: int64
# =====================================================================
# GetVolumePathNamesForVolumeNameW
#
# type
# trojan    57
# miner      2
# adware     1
# pua        1
# Name: count, dtype: int64
# =====================================================================
# ShellExecuteExW
#
# type
# trojan    27
# adware    10
# miner      1
# pua        1
# Name: count, dtype: int64
# =====================================================================
# FindWindowExA
#
# type
# trojan    9
# pua       1
# Name: count, dtype: int64
# =====================================================================
# bind
#
# type
# trojan        25
# downloader     1
# pua            1
# Name: count, dtype: int64
# =====================================================================
# getsockname
#
# type
# trojan        23
# downloader     1
# pua            1
# Name: count, dtype: int64
# =====================================================================
# GetComputerNameA
#
# type
# trojan    46
# adware    30
# miner      1
# Name: count, dtype: int64
# =====================================================================
# MessageBoxTimeoutA
#
# type
# trojan    17
# pua        2
# adware     1
# Name: count, dtype: int64
# =====================================================================
# RtlAddVectoredExceptionHandler
#
# type
# trojan    21
# miner      6
# Name: count, dtype: int64
# =====================================================================
# GetFileAttributesExW
#
# type
# trojan    58
# pua        8
# adware     6
# miner      2
# Name: count, dtype: int64
# =====================================================================
# GetVolumePathNameW
#
# type
# trojan    7
# Name: count, dtype: int64
# =====================================================================
# StartServiceW
#
# type
# trojan    14
# Name: count, dtype: int64
# =====================================================================
# FindWindowExW
#
# type
# trojan    12
# adware     5
# pua        5
# Name: count, dtype: int64
# =====================================================================
# RemoveDirectoryW
#
# type
# trojan      21
# pua         18
# miner        2
# adware       2
# virus        1
# hacktool     1
# Name: count, dtype: int64
# =====================================================================
# GetFileInformationByHandle
#
# type
# trojan    46
# pua        1
# Name: count, dtype: int64
# =====================================================================
# GetSystemWindowsDirectoryA
#
# type
# trojan        69
# ransomware     1
# Name: count, dtype: int64
# =====================================================================
# RegEnumValueA
#
# type
# trojan        55
# adware         1
# ransomware     1
# Name: count, dtype: int64
# =====================================================================
# SHGetSpecialFolderLocation
#
# type
# trojan        14
# adware         1
# spyware        1
# pua            1
# downloader     1
# Name: count, dtype: int64
# =====================================================================
# GetFileSizeEx
#
# type
# trojan        55
# pua            7
# ransomware     1
# Name: count, dtype: int64
# =====================================================================
# Thread32First
#
# type
# trojan    48
# miner      8
# pua        1
# Name: count, dtype: int64
# =====================================================================
# Thread32Next
#
# type
# trojan    48
# miner      8
# pua        1
# Name: count, dtype: int64
# =====================================================================
# DrawTextExA
#
# type
# trojan        26
# adware         2
# downloader     1
# Name: count, dtype: int64
# =====================================================================
# CoGetClassObject
#
# type
# trojan        55
# adware        49
# pua            6
# virus          1
# ransomware     1
# Name: count, dtype: int64
# =====================================================================
# setsockopt
#
# type
# pua       15
# trojan    10
# Name: count, dtype: int64
# =====================================================================
# InternetCrackUrlW
#
# type
# pua       19
# trojan     6
# Name: count, dtype: int64
# =====================================================================
# CoCreateInstanceEx
#
# type
# adware        49
# trojan        34
# pua            6
# ransomware     1
# worm           1
# Name: count, dtype: int64
# =====================================================================
# IWbemServices_ExecQuery
#
# type
# adware        48
# trojan        21
# pua            6
# ransomware     1
# Name: count, dtype: int64
# =====================================================================
# SetFilePointerEx
#
# type
# trojan        52
# pua            6
# adware         6
# downloader     2
# ransomware     1
# miner          1
# Name: count, dtype: int64
# =====================================================================
# GetDiskFreeSpaceExW
#
# type
# trojan    27
# pua       12
# adware     1
# Name: count, dtype: int64
# =====================================================================
# UnhookWindowsHookEx
#
# type
# trojan        15
# downloader     1
# Name: count, dtype: int64
# =====================================================================
# RegisterHotKey
#
# type
# trojan    12
# Name: count, dtype: int64
# =====================================================================
# GetKeyboardState
#
# type
# trojan    3
# Name: count, dtype: int64
# =====================================================================
# CryptGenKey
#
# type
# ransomware    7
# trojan        4
# Name: count, dtype: int64
# =====================================================================
# CryptExportKey
#
# type
# ransomware    6
# trojan        2
# Name: count, dtype: int64
# =====================================================================
# WSASocketW
#
# type
# trojan    1
# Name: count, dtype: int64
# =====================================================================
# GetKeyState
#
# type
# trojan    13
# pua        1
# Name: count, dtype: int64
# =====================================================================
# GetAsyncKeyState
#
# type
# trojan        16
# pua            1
# downloader     1
# Name: count, dtype: int64
# =====================================================================
# Module32FirstW
#
# type
# trojan    16
# Name: count, dtype: int64
# =====================================================================
# Module32NextW
#
# type
# trojan    15
# Name: count, dtype: int64
# =====================================================================
# NtQueueApcThread
#
# type
# trojan    3
# Name: count, dtype: int64
# =====================================================================
# MessageBoxTimeoutW
#
# type
# trojan        2
# miner         1
# ransomware    1
# pua           1
# Name: count, dtype: int64
# =====================================================================
# GetFileInformationByHandleEx
#
# type
# trojan    1
# Name: count, dtype: int64
# =====================================================================
# RegDeleteValueA
#
# type
# trojan    2
# Name: count, dtype: int64
# =====================================================================
# SendNotifyMessageW
#
# type
# trojan    1
# Name: count, dtype: int64
# =====================================================================
# sendto
#
# type
# trojan    1
# Name: count, dtype: int64
# =====================================================================
# RegDeleteValueW
#
# type
# adware    1
# Name: count, dtype: int64
# =====================================================================
# NetUserGetInfo
#
# type
# trojan    1
# Name: count, dtype: int64
# =====================================================================
# CertOpenStore
#
# type
# downloader    1
# Name: count, dtype: int64
# =====================================================================
