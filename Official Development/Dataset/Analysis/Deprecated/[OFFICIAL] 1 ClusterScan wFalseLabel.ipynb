# %% [markdown]
# # Malicious ClusterScan
#
# Describes/summarizes the or set of clusters. Useful for when you aim to enlist the summarized malware types found in each cluster in order by Malware Type.
#
# Assume that the dataset is already pre-processed:
# 1. Removal of nan values
# 2. Data Cleaning (Removal of False Labels and *Removal/Aggregation of malware types of poor quantity*)
# 3. Inverse Ordinal Encoding (for representation purposes only)

# %% [markdown]
# ## Import Libraries/Datasets

# %%
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

plt.rcParams["figure.autolayout"] = True

malicious_df = pd.read_csv('./Manual_DBSCAN_Clustering_w_FalseLabels.csv', low_memory=False, index_col=False) #This should point to a VirusTotal verified <Data Clustering>_SampleHash_Common.csv file

#Load list of API calls
API_LIST = "../api_calls.txt"
DELIMITER = "NaN"
API_FILE = open(API_LIST,"r")
APIS = API_FILE.readline().split(',')
APIS.append(DELIMITER) #serves as a label for NaN values for Instance-based datasets
API_FILE.close()

def list_to_str(ls:list):
    output = ""
    for l in ls:
        output += str(l) + " "
    return output[0:len(output)-1]

def inject_patterns(inner_df:pd.DataFrame):
    patterns = []
    for row in range(inner_df.shape[0]):
        patterns.append(list_to_str(inner_df.iloc[row,2:5].transpose().to_list()))
    inner_df['type_pattern'] = patterns
    return inner_df

def get_unique_clusters(df:pd.DataFrame):
    return list(df['cluster'].unique())

def get_summary(df:pd.DataFrame):
    #Identify the overall list of types each cluster is as designated by VirusTotal.
    unique_clusters = get_unique_clusters(df)
    summary = []
    for u in unique_clusters:
        cluster_sublist = [u]
        df_copy = malicious_df[malicious_df['cluster'] == u].copy(deep=True)
        idx = list(df_copy['type'].value_counts().index)
        counts = list(df_copy['type'].value_counts())
        type_sublist = []
        for i in range(len(idx)):
            type_sublist.append([idx[i], counts[i]])
        cluster_sublist.append(type_sublist)
        # str_summary = []
        # cluster_sublist.append(list(df_copy['type_pattern'].value_counts().index))
        # cluster_sublist.append(list(df_copy['type_pattern'].value_counts()))
        summary.append(cluster_sublist)
    return summary

DELIMITER = "NaN"
API_FILE = open(API_LIST,"r")
APIS = API_FILE.readline().split(',')
APIS.append(DELIMITER) #serves as a label for NaN values for Instance-based datasets
API_FILE.close()

from sklearn.preprocessing import LabelEncoder
#Inverse Label Encoding
def inverse_label(item):
    global APIS
    return item.map(lambda x: APIS[int(x)])
oliveira = pd.read_csv('../oliveira.csv', low_memory=False)
oliveira.iloc[:, 1:101] = oliveira.iloc[:, 1:101].apply(inverse_label, axis=1, result_type='reduce')

def how_many_clusters():
    c = malicious_df['cluster'].unique()
    c.sort()
    print("Number of Clusters:", c.size)
    c = malicious_df['cluster'].value_counts(ascending=True)
    print("Number of single-item Clusters:", c[c==1].count())
    print("Number of Samples Remaining:", malicious_df.shape[0])

# %% [markdown]
# ## DataFrame Preview

# %%
#Replace '-' empty malware type delimiter with '_' for consistency
malicious_df.replace(to_replace='-',value='_', inplace=True)
display(malicious_df.head(10))
display(malicious_df.shape)
malicious_df['type'].value_counts(ascending=True).plot(kind='barh')
# Out:
#                                hash  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  \
# 0  071e8c3f8922e186e57548cd4c703a5d  112  274  158  215  274  158  215  298
# 1  33f8e6d08a6aae939f25a8e0d63dd523   82  208  187  208  172  117  172  117
# 2  b68abd064e975e1c6d5f25e748663076   16  110  240  117  240  117  240  117
# 3  72049be7bd30ea61297ea624ae198067   82  208  187  208  172  117  172  117
# 4  c9b3700a77facf29172f32df6bc77f48   82  240  117  240  117  240  117  240
# 5  cc6217be863e606e49da90fee2252f52  117  208  117  208  117  240  117  240
# 6  f7a1a3c38809d807b3f5f4cc00b1e9b7  215  274  158  215  274  158  215  172
# 7  164b56522eb24164184460f8523ed7e2   82  240  117  240  117  240  117  240
# 8  56ae1459ba61a14eb119982d6ec793d7   82  240  117  240  117  240  117  240
# 9  c4148ca91c5246a8707a1ac1fd1e2e36   82  208  187  208  172  117  172  208
#
#    t_8  ...  t_94  t_95  t_96  t_97  t_98  t_99  malware        type  \
# 0   76  ...   171   215    35   208    56    71        1      trojan
# 1  172  ...    71   297   135   171   215    35        1         pua
# 2  240  ...    65   112   123    65   113   112        1      trojan
# 3  172  ...   302   187   208   302   228   302        1      trojan
# 4  117  ...   209   260   141   260   141   260        1      trojan
# 5  117  ...   141    65     9   117   260    65        1      trojan
# 6  117  ...   172    60    81    60    81   225        1  downloader
# 7  117  ...   275   240    80    60   215    35        1      adware
# 8  117  ...   215   108   208    80   240   117        1      adware
# 9   16  ...   208   172   117   100   215    35        1  downloader
#
#                                              pattern  cluster
# 0  RegOpenKeyExA,NtOpenKey,NtQueryValueKey,NtClos...        0
# 1  GetSystemTimeAsFileTime,NtAllocateVirtualMemor...        1
# 2  SetUnhandledExceptionFilter,OleInitialize,LdrL...        2
# 3  GetSystemTimeAsFileTime,NtAllocateVirtualMemor...        3
# 4  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...        4
# 5  LdrGetProcedureAddress,NtAllocateVirtualMemory...        5
# 6  NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOp...        6
# 7  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...        7
# 8  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...        8
# 9  GetSystemTimeAsFileTime,NtAllocateVirtualMemor...        9
#
# [10 rows x 105 columns]
# (42797, 105)
# <Axes: ylabel='type'>

# %%
#INJECT PATTERN (i.e., summarized malware type pattern) to the DataFrame
malicious_df = inject_patterns(malicious_df)

print("Raw Clustered malicious samples")
how_many_clusters()
# Out:
# Raw Clustered malicious samples
# Number of Clusters: 12597
# Number of single-item Clusters: 10413
# Number of Samples Remaining: 42797

# %% [markdown]
# ## How many clusters are there?

# %%
# #Prior to noise removal
# print("Prior to noise removal")
# how_many_clusters()

# %%
# #DROP CLUSTERS WITH MORE THAN 1 MALWARE TYPE UNDER IT (i.e. NOISE)
# unique_clusters = get_unique_clusters(malicious_df)
# for u in unique_clusters:
#     if len(malicious_df[malicious_df['cluster'] == u]['type'].unique()) > 1:
#         malicious_df = malicious_df.drop(malicious_df[malicious_df['cluster'] == u].index)
# malicious_df.head()

# print("After removing yet unlabelled malicious samples\n and clusters with more than 1 malware type")
# how_many_clusters()

# %%
# #REMOVE SINGLE ITEM CLUSTERS
# unique_clusters = get_unique_clusters(malicious_df)
# for u in unique_clusters:
#     if malicious_df[malicious_df['cluster'] == u].shape[0] == 1:
#         malicious_df = malicious_df.drop(malicious_df[malicious_df['cluster'] == u].index)

# print("After removing single-item clusters")
# how_many_clusters()

# %% [markdown]
# ## "What Malware Types can be found in the overall dataset?"
#
# ### This is regardless of cluster.

# %%
output = malicious_df['type'].value_counts()
str_output = str(output) + "\n\n"
with open("./Output/1 MalwareTypes_in_Dataset.txt", 'w') as f:
    f.write(str_output)
    f.flush
    f.close()
display(output)
fig, axs = plt.subplots(nrows=1, layout='constrained')
fig.set_figwidth(4)
fig.set_figheight(3)
fig.set_dpi(300)
axs.set_title('Malware Type Counts')
axs.barh(malicious_df['type'].value_counts().index, malicious_df['type'].value_counts())
axs.invert_yaxis()
# axs[1].set_title('Type 2 Malware Type Counts')
# axs[1].invert_yaxis()
# axs[1].barh(malicious_df['Type 2'].value_counts().index, malicious_df['Type 2'].value_counts())
# axs[2].invert_yaxis()
# axs[2].set_title('Type 3 (Least \'Popular\') Malware Type Counts')
# axs[2].barh(malicious_df['Type 3'].value_counts().index, malicious_df['Type 3'].value_counts())
plt.savefig("./Output/1 Popular Malware Types in Dataset.png")
# Out:
# type
# trojan        33352
# _              2638
# downloader     2249
# pua            2135
# adware         1815
# ransomware      341
# miner           125
# virus            79
# spyware          48
# hacktool          7
# dropper           5
# worm              3
# Name: count, dtype: int64

# %% [markdown]
# ## "What Malware Types are there in each cluster?"

# %% [markdown]
# ### Identify the counts of Malware Types per Cluster
#
# This indicates the malware types (including the # of instances) found in each cluster.

# %%
str_output = ""
summary = get_summary(malicious_df)
summary.sort()
for s in summary:
    str_output += f"CLUSTER {s[0]}: "
    for t in s[1]:
        str_output += f"{t[0]} ({t[1]}); "
    # str_output += "\n\tType 2: "
    # for t in s[2]:
    #     str_output += f"{t[0]} ({t[1]}); "
    # str_output += "\n\tType 3: "
    # for t in s[3]:
    #     str_output += f"{t[0]} ({t[1]}); "
    # str_output += "\n\tMost Popular Malware Type Combination (in order Most to Least):\n"
    # for i,t in enumerate(s[4]):
    #     str_output += f"\t    {i+1} {t:12s} ({s[5][i]})\n"
    str_output += "\n"
with open("./Output/1 MalwareType_per_Cluster.txt", 'w') as f:
    f.write(str_output)
    f.flush
    f.close()
print(str_output)
# Out:
# CLUSTER 0: trojan (3295); pua (6); _ (3); adware (2); spyware (1); downloader (1);
# CLUSTER 1: pua (109); trojan (12); adware (4); downloader (3);
# CLUSTER 2: trojan (8);
# CLUSTER 3: trojan (1);
# CLUSTER 4: trojan (1);
# CLUSTER 5: trojan (1);
# CLUSTER 6: downloader (162); trojan (7); adware (2); virus (1); _ (1);
# CLUSTER 7: adware (1);
# CLUSTER 8: trojan (451); adware (33); pua (2);
# CLUSTER 9: downloader (966); pua (119); trojan (21); adware (7); _ (2); ransomware (1);
# CLUSTER 10: _ (34); trojan (16); adware (2); virus (2); downloader (2); pua (2); hacktool (1); miner (1);
# CLUSTER 11: trojan (10);
# CLUSTER 12: trojan (1);
# CLUSTER 13: trojan (333); adware (9); pua (1); _ (1);
# CLUSTER 14: _ (2);
# CLUSTER 15: _ (1);
# CLUSTER 16: trojan (23);
# CLUSTER 17: trojan (12);
# CLUSTER 18: trojan (1);
# CLUSTER 19: trojan (701); adware (30); pua (5); downloader (2);
# CLUSTER 20: trojan (2);
# CLUSTER 21: trojan (516); adware (56); pua (3); _ (1);
# CLUSTER 22: trojan (1);
# CLUSTER 23: trojan (168); downloader (101); _ (71); pua (39); adware (31); dropper (1);
# CLUSTER 24: trojan (1024); _ (19); adware (11); pua (3); spyware (2);
# CLUSTER 25: trojan (29);
# CLUSTER 26: trojan (2);
# CLUSTER 27: trojan (480); downloader (2); pua (2); adware (1);
# CLUSTER 28: pua (1);
# CLUSTER 29: trojan (61); downloader (27); _ (15); adware (10); pua (8);
# CLUSTER 30: trojan (95); adware (3);
# CLUSTER 31: pua (1);
# CLUSTER 32: _ (1);
# CLUSTER 33: trojan (126); pua (20);
# CLUSTER 34: downloader (1);
# CLUSTER 35: trojan (14);
# CLUSTER 36: trojan (1);
# CLUSTER 37: trojan (1);
# CLUSTER 38: trojan (1);
# CLUSTER 39: trojan (797); downloader (3); _ (1); adware (1);
# CLUSTER 40: trojan (687); pua (11);
# CLUSTER 41: trojan (1);
# CLUSTER 42: trojan (99);
# CLUSTER 43: trojan (2);
# CLUSTER 44: trojan (101);
# CLUSTER 45: downloader (2); pua (1);
# CLUSTER 46: trojan (127); adware (1); pua (1);
# CLUSTER 47: trojan (2);
# CLUSTER 48: pua (95); downloader (4); trojan (3); adware (1);
# CLUSTER 49: trojan (1);
# CLUSTER 50: trojan (677); _ (18); miner (3); pua (3); downloader (2);
# CLUSTER 51: trojan (1);
# CLUSTER 52: trojan (3);
# CLUSTER 53: trojan (1);
# CLUSTER 54: trojan (1);
# CLUSTER 55: trojan (39); adware (1);
# CLUSTER 56: trojan (118); adware (1); pua (1); downloader (1);
# CLUSTER 57: trojan (12);
# CLUSTER 58: adware (208); pua (196); trojan (104); _ (27); downloader (4);
# CLUSTER 59: trojan (5);
# CLUSTER 60: trojan (206); pua (27); adware (8); _ (1);
# CLUSTER 61: trojan (16);
# CLUSTER 62: trojan (1);
# CLUSTER 63: trojan (343); pua (6);
# CLUSTER 64: trojan (1);
# CLUSTER 65: _ (2);
# CLUSTER 66: trojan (44); pua (4); adware (3);
# CLUSTER 67: trojan (3);
# CLUSTER 68: trojan (1);
# CLUSTER 69: trojan (19);
# CLUSTER 70: trojan (1);
# CLUSTER 71: trojan (2);
# CLUSTER 72: trojan (66); adware (3);
# CLUSTER 73: downloader (4);
# CLUSTER 74: trojan (1);
# CLUSTER 75: trojan (1);
# CLUSTER 76: trojan (222); pua (14);
# CLUSTER 77: _ (7); pua (7);
# CLUSTER 78: trojan (3);
# CLUSTER 79: trojan (30); downloader (1); _ (1);
# CLUSTER 80: trojan (1);
# CLUSTER 81: trojan (7);
# CLUSTER 82: downloader (212); adware (14); trojan (3);
# CLUSTER 83: trojan (9); _ (2);
# CLUSTER 84: trojan (1);
# CLUSTER 85: trojan (35);
# CLUSTER 86: trojan (121); pua (1);
# CLUSTER 87: miner (3);
# CLUSTER 88: trojan (28);
# CLUSTER 89: trojan (33); adware (9);
# CLUSTER 90: trojan (4);
# CLUSTER 91: trojan (7); _ (3);
# CLUSTER 92: trojan (1);
# CLUSTER 93: adware (6);
# CLUSTER 94: trojan (12);
# CLUSTER 95: virus (7);
# CLUSTER 96: trojan (84);
# CLUSTER 97: trojan (183); downloader (106); _ (72); pua (37); adware (35); virus (1);
# CLUSTER 98: trojan (7); downloader (5); pua (4); _ (4); adware (1);
# CLUSTER 99: _ (15); trojan (15); adware (4); miner (1);
# CLUSTER 100: trojan (2);
# CLUSTER 101: trojan (10); spyware (7);
# CLUSTER 102: trojan (1);
# CLUSTER 103: _ (3); trojan (2); downloader (1); adware (1);
# CLUSTER 104: trojan (2);
# CLUSTER 105: trojan (1082); pua (10); downloader (1); _ (1);
# CLUSTER 106: trojan (268); _ (1);
# CLUSTER 107: trojan (11);
# CLUSTER 108: trojan (26); _ (20); miner (2);
# CLUSTER 109: downloader (84); pua (54); trojan (4); adware (1);
# CLUSTER 110: trojan (5);
# CLUSTER 111: trojan (18); adware (1);
# CLUSTER 112: adware (1);
# CLUSTER 113: trojan (166); downloader (103); _ (66); pua (37); adware (23); miner (1);
# CLUSTER 114: trojan (1);
# CLUSTER 115: trojan (1);
# CLUSTER 116: adware (1);
# CLUSTER 117: trojan (1);
# CLUSTER 118: trojan (1);
# CLUSTER 119: trojan (77); pua (9); _ (1); downloader (1);
# CLUSTER 120: trojan (1);
# CLUSTER 121: _ (4);
# CLUSTER 122: trojan (4); pua (1);
# CLUSTER 123: trojan (1);
# CLUSTER 124: trojan (11);
# CLUSTER 125: trojan (1);
# CLUSTER 126: trojan (1);
# CLUSTER 127: trojan (1);
# CLUSTER 128: trojan (303); _ (1); downloader (1);
# CLUSTER 129: trojan (124); adware (3); pua (1);
# CLUSTER 130: trojan (1);
# CLUSTER 131: trojan (4);
# CLUSTER 132: trojan (2);
# CLUSTER 133: trojan (1);
# CLUSTER 134: trojan (19);
# CLUSTER 135: trojan (1);
# CLUSTER 136: trojan (1);
# CLUSTER 137: trojan (1);
# CLUSTER 138: trojan (1);
# CLUSTER 139: trojan (32);
# CLUSTER 140: _ (1);
# CLUSTER 141: trojan (130); adware (3); pua (2);
# CLUSTER 142: trojan (283); pua (21); _ (1);
# CLUSTER 143: adware (1);
# CLUSTER 144: trojan (1);
# CLUSTER 145: _ (2);
# CLUSTER 146: trojan (5);
# CLUSTER 147: trojan (177); adware (4);
# CLUSTER 148: trojan (4);
# CLUSTER 149: trojan (4); adware (2);
# CLUSTER 150: trojan (1);
# CLUSTER 151: trojan (10);
# CLUSTER 152: trojan (43); pua (1);
# CLUSTER 153: trojan (1);
# CLUSTER 154: trojan (1);
# CLUSTER 155: trojan (847); pua (11); adware (2); _ (2); downloader (1);
# CLUSTER 156: trojan (4);
# CLUSTER 157: _ (1);
# CLUSTER 158: downloader (29); pua (5);
# CLUSTER 159: pua (1);
# CLUSTER 160: trojan (1);
# CLUSTER 161: trojan (3);
# CLUSTER 162: pua (1);
# CLUSTER 163: trojan (1);
# CLUSTER 164: trojan (1);
# CLUSTER 165: trojan (1);
# CLUSTER 166: adware (15); trojan (1);
# CLUSTER 167: trojan (15);
# CLUSTER 168: trojan (1);
# CLUSTER 169: trojan (11);
# CLUSTER 170: adware (12); trojan (1);
# CLUSTER 171: trojan (129); adware (5);
# CLUSTER 172: trojan (3);
# CLUSTER 173: adware (1);
# CLUSTER 174: trojan (1);
# CLUSTER 175: trojan (1);
# CLUSTER 176: trojan (1);
# CLUSTER 177: trojan (1);
# CLUSTER 178: trojan (1);
# CLUSTER 179: adware (1);
# CLUSTER 180: trojan (1);
# CLUSTER 181: trojan (1);
# CLUSTER 182: trojan (3);
# CLUSTER 183: trojan (6);
# CLUSTER 184: trojan (112); pua (11); adware (1);
# CLUSTER 185: trojan (9); adware (1);
# CLUSTER 186: trojan (1);
# CLUSTER 187: _ (1);
# CLUSTER 188: trojan (127); adware (3); pua (2);
# CLUSTER 189: trojan (1);
# CLUSTER 190: trojan (2);
# CLUSTER 191: pua (10); adware (7); trojan (6); _ (1);
# CLUSTER 192: trojan (80); pua (1);
# CLUSTER 193: trojan (22); adware (2);
# CLUSTER 194: trojan (5); _ (5);
# CLUSTER 195: trojan (1);
# CLUSTER 196: adware (1); pua (1);
# CLUSTER 197: ransomware (178); trojan (15);
# CLUSTER 198: trojan (1);
# CLUSTER 199: trojan (3);
# CLUSTER 200: trojan (162); adware (5); pua (1);
# CLUSTER 201: trojan (5); _ (4); virus (1);
# CLUSTER 202: trojan (14);
# CLUSTER 203: trojan (2);
# CLUSTER 204: ransomware (108); trojan (6);
# CLUSTER 205: trojan (1);
# CLUSTER 206: _ (1);
# CLUSTER 207: ransomware (4); trojan (1);
# CLUSTER 208: trojan (237); _ (45); adware (11); pua (5); ransomware (4); miner (3); downloader (1);
# CLUSTER 209: trojan (32); adware (2);
# CLUSTER 210: spyware (15); trojan (3);
# CLUSTER 211: trojan (1);
# CLUSTER 212: adware (3); _ (1);
# CLUSTER 213: trojan (1);
# CLUSTER 214: trojan (2);
# CLUSTER 215: trojan (193); adware (4); downloader (2); pua (1);
# CLUSTER 216: trojan (11);
# CLUSTER 217: trojan (34); _ (1); pua (1);
# CLUSTER 218: adware (18); downloader (7); trojan (2);
# CLUSTER 219: trojan (1);
# CLUSTER 220: trojan (1);
# CLUSTER 221: miner (1);
# CLUSTER 222: trojan (127);
# CLUSTER 223: trojan (6);
# CLUSTER 224: downloader (98); pua (9);
# CLUSTER 225: trojan (1);
# CLUSTER 226: trojan (27); adware (1);
# CLUSTER 227: trojan (1);
# CLUSTER 228: pua (2); trojan (1);
# CLUSTER 229: _ (1);
# CLUSTER 230: trojan (1);
# CLUSTER 231: trojan (1);
# CLUSTER 232: trojan (21); pua (1);
# CLUSTER 233: trojan (1);
# CLUSTER 234: trojan (1);
# CLUSTER 235: _ (41); pua (8); trojan (1);
# CLUSTER 236: trojan (1);
# CLUSTER 237: trojan (34); adware (2);
# CLUSTER 238: trojan (34); _ (3); pua (2);
# CLUSTER 239: trojan (18);
# CLUSTER 240: trojan (1);
# CLUSTER 241: trojan (1);
# CLUSTER 242: trojan (1);
# CLUSTER 243: trojan (1);
# CLUSTER 244: trojan (4); pua (3);
# CLUSTER 245: trojan (1);
# CLUSTER 246: downloader (21); trojan (3);
# CLUSTER 247: trojan (1);
# CLUSTER 248: trojan (14);
# CLUSTER 249: _ (22); pua (2); trojan (2); adware (1);
# CLUSTER 250: pua (8); downloader (7); adware (2);
# CLUSTER 251: trojan (1);
# CLUSTER 252: trojan (1);
# CLUSTER 253: trojan (3);
# CLUSTER 254: _ (33); trojan (20); miner (3); pua (1);
# CLUSTER 255: trojan (1);
# CLUSTER 256: _ (1);
# CLUSTER 257: trojan (1);
# CLUSTER 258: trojan (15);
# CLUSTER 259: trojan (64); adware (1);
# CLUSTER 260: _ (5); pua (2); trojan (1);
# CLUSTER 261: trojan (16);
# CLUSTER 262: trojan (59); pua (1);
# CLUSTER 263: trojan (1);
# CLUSTER 264: trojan (1);
# CLUSTER 265: trojan (1);
# CLUSTER 266: trojan (5);
# CLUSTER 267: adware (1); trojan (1);
# CLUSTER 268: trojan (1);
# CLUSTER 269: trojan (1);
# CLUSTER 270: trojan (4);
# CLUSTER 271: trojan (1);
# CLUSTER 272: trojan (14);
# CLUSTER 273: _ (35); trojan (20); pua (17); adware (16); downloader (1); virus (1);
# CLUSTER 274: trojan (8);
# CLUSTER 275: miner (1);
# CLUSTER 276: trojan (1);
# CLUSTER 277: trojan (40);
# CLUSTER 278: pua (2);
# CLUSTER 279: adware (15); trojan (1); pua (1);
# CLUSTER 280: trojan (2);
# CLUSTER 281: trojan (2);
# CLUSTER 282: trojan (26); pua (2); adware (2);
# CLUSTER 283: trojan (10);
# CLUSTER 284: trojan (1);
# CLUSTER 285: miner (23); trojan (4);
# CLUSTER 286: trojan (1);
# CLUSTER 287: trojan (1);
# CLUSTER 288: trojan (1);
# CLUSTER 289: trojan (1);
# CLUSTER 290: trojan (1);
# CLUSTER 291: trojan (1);
# CLUSTER 292: trojan (1);
# CLUSTER 293: adware (28);
# CLUSTER 294: trojan (2);
# CLUSTER 295: trojan (148); downloader (94); _ (76); pua (27); adware (22);
# CLUSTER 296: trojan (1);
# CLUSTER 297: trojan (8); _ (4); adware (1);
# CLUSTER 298: trojan (1);
# CLUSTER 299: pua (1);
# CLUSTER 300: trojan (1);
# CLUSTER 301: trojan (3);
# CLUSTER 302: trojan (19); dropper (2);
# CLUSTER 303: trojan (1);
# CLUSTER 304: trojan (17);
# CLUSTER 305: trojan (1);
# CLUSTER 306: trojan (6);
# CLUSTER 307: trojan (5);
# CLUSTER 308: trojan (42); adware (1);
# CLUSTER 309: trojan (2);
# CLUSTER 310: trojan (1);
# CLUSTER 311: trojan (1);
# CLUSTER 312: trojan (5);
# CLUSTER 313: trojan (1);
# CLUSTER 314: trojan (4);
# CLUSTER 315: pua (98); trojan (7); adware (1);
# CLUSTER 316: pua (1);
# CLUSTER 317: trojan (1);
# CLUSTER 318: trojan (1);
# CLUSTER 319: trojan (1);
# CLUSTER 320: trojan (1);
# CLUSTER 321: trojan (1);
# CLUSTER 322: trojan (29);
# CLUSTER 323: trojan (1);
# CLUSTER 324: trojan (1);
# CLUSTER 325: trojan (1);
# CLUSTER 326: trojan (13);
# CLUSTER 327: trojan (1);
# CLUSTER 328: trojan (1);
# CLUSTER 329: trojan (3);
# CLUSTER 330: trojan (1);
# CLUSTER 331: trojan (21); _ (19); pua (7); adware (6); downloader (1);
# CLUSTER 332: trojan (1);
# CLUSTER 333: trojan (26);
# CLUSTER 334: trojan (6);
# CLUSTER 335: trojan (88); adware (2);
# CLUSTER 336: pua (2); trojan (1);
# CLUSTER 337: trojan (18);
# CLUSTER 338: trojan (1);
# CLUSTER 339: trojan (1);
# CLUSTER 340: trojan (42);
# CLUSTER 341: trojan (1); _ (1);
# CLUSTER 342: _ (1);
# CLUSTER 343: trojan (5);
# CLUSTER 344: trojan (3);
# CLUSTER 345: trojan (6);
# CLUSTER 346: pua (1);
# CLUSTER 347: downloader (1);
# CLUSTER 348: trojan (1);
# CLUSTER 349: trojan (1);
# CLUSTER 350: _ (5); trojan (1);
# CLUSTER 351: trojan (3);
# CLUSTER 352: trojan (1);
# CLUSTER 353: trojan (1);
# CLUSTER 354: adware (3); pua (1);
# CLUSTER 355: trojan (2);
# CLUSTER 356: trojan (1);
# CLUSTER 357: downloader (1);
# CLUSTER 358: _ (3); trojan (2);
# CLUSTER 359: trojan (9);
# CLUSTER 360: trojan (78); adware (7);
# CLUSTER 361: _ (47);
# CLUSTER 362: trojan (1);
# CLUSTER 363: trojan (1);
# CLUSTER 364: trojan (1);
# CLUSTER 365: trojan (1); pua (1);
# CLUSTER 366: trojan (6);
# CLUSTER 367: trojan (7);
# CLUSTER 368: trojan (6);
# CLUSTER 369: trojan (2);
# CLUSTER 370: trojan (2);
# CLUSTER 371: virus (1);
# CLUSTER 372: downloader (29); pua (4); trojan (1);
# CLUSTER 373: trojan (3);
# CLUSTER 374: trojan (6);
# CLUSTER 375: trojan (2);
# CLUSTER 376: trojan (8);
# CLUSTER 377: trojan (62);
# CLUSTER 378: trojan (1);
# CLUSTER 379: _ (29); trojan (20); adware (16); pua (4);
# CLUSTER 380: downloader (1);
# CLUSTER 381: trojan (75); adware (1);
# CLUSTER 382: trojan (1);
# CLUSTER 383: trojan (1);
# CLUSTER 384: ransomware (4);
# CLUSTER 385: trojan (1);
# CLUSTER 386: trojan (5);
# CLUSTER 387: trojan (1);
# CLUSTER 388: trojan (14); _ (6); adware (2); pua (1); miner (1);
# CLUSTER 389: trojan (15);
# CLUSTER 390: trojan (3);
# CLUSTER 391: trojan (1);
# CLUSTER 392: _ (3);
# CLUSTER 393: trojan (6);
# CLUSTER 394: trojan (1);
# CLUSTER 395: trojan (1);
# CLUSTER 396: trojan (15); adware (2); pua (2);
# CLUSTER 397: trojan (2);
# CLUSTER 398: trojan (1);
# CLUSTER 399: trojan (1);
# CLUSTER 400: trojan (5);
# CLUSTER 401: trojan (1);
# CLUSTER 402: _ (2);
# CLUSTER 403: pua (7); adware (5); trojan (1);
# CLUSTER 404: _ (24); trojan (21); adware (19); pua (10); virus (2);
# CLUSTER 405: _ (1);
# CLUSTER 406: trojan (2);
# CLUSTER 407: trojan (1);
# CLUSTER 408: trojan (1);
# CLUSTER 409: trojan (5); _ (4);
# CLUSTER 410: trojan (2);
# CLUSTER 411: trojan (1);
# CLUSTER 412: pua (1);
# CLUSTER 413: trojan (1);
# CLUSTER 414: trojan (1);
# CLUSTER 415: trojan (1);
# CLUSTER 416: trojan (3);
# CLUSTER 417: trojan (24); _ (1);
# CLUSTER 418: trojan (1);
# CLUSTER 419: trojan (67); adware (1);
# CLUSTER 420: trojan (118); _ (20); pua (10); adware (5); downloader (1); miner (1);
# CLUSTER 421: adware (1);
# CLUSTER 422: trojan (2);
# CLUSTER 423: _ (3); trojan (1);
# CLUSTER 424: trojan (6); pua (1);
# CLUSTER 425: trojan (1);
# CLUSTER 426: trojan (1);
# CLUSTER 427: trojan (2);
# CLUSTER 428: trojan (2);
# CLUSTER 429: trojan (1);
# CLUSTER 430: trojan (1);
# CLUSTER 431: trojan (2);
# CLUSTER 432: _ (1);
# CLUSTER 433: pua (1);
# CLUSTER 434: adware (29); trojan (1);
# CLUSTER 435: trojan (2);
# CLUSTER 436: trojan (1);
# CLUSTER 437: adware (3); pua (2); trojan (1);
# CLUSTER 438: trojan (12);
# CLUSTER 439: trojan (6);
# CLUSTER 440: trojan (1);
# CLUSTER 441: trojan (1);
# CLUSTER 442: trojan (17);
# CLUSTER 443: trojan (25);
# CLUSTER 444: trojan (41); adware (1);
# CLUSTER 445: trojan (1);
# CLUSTER 446: trojan (15);
# CLUSTER 447: virus (1);
# CLUSTER 448: trojan (5);
# CLUSTER 449: _ (1);
# CLUSTER 450: trojan (1);
# CLUSTER 451: trojan (44);
# CLUSTER 452: trojan (2);
# CLUSTER 453: trojan (1);
# CLUSTER 454: trojan (1);
# CLUSTER 455: trojan (2);
# CLUSTER 456: trojan (37);
# CLUSTER 457: trojan (28);
# CLUSTER 458: trojan (2);
# CLUSTER 459: trojan (1);
# CLUSTER 460: trojan (2);
# CLUSTER 461: trojan (4);
# CLUSTER 462: _ (4);
# CLUSTER 463: trojan (6);
# CLUSTER 464: trojan (1);
# CLUSTER 465: trojan (1);
# CLUSTER 466: trojan (1);
# CLUSTER 467: trojan (1);
# CLUSTER 468: _ (2); adware (1);
# CLUSTER 469: trojan (1);
# CLUSTER 470: trojan (1);
# CLUSTER 471: trojan (1);
# CLUSTER 472: trojan (7);
# CLUSTER 473: trojan (24); downloader (11); _ (8); pua (6); adware (3);
# CLUSTER 474: adware (1);
# CLUSTER 475: trojan (3); virus (1);
# CLUSTER 476: trojan (1);
# CLUSTER 477: pua (4); _ (3); adware (2);
# CLUSTER 478: trojan (2);
# CLUSTER 479: trojan (1);
# CLUSTER 480: trojan (1);
# CLUSTER 481: trojan (1);
# CLUSTER 482: pua (3); trojan (2);
# CLUSTER 483: trojan (1);
# CLUSTER 484: trojan (2);
# CLUSTER 485: trojan (8); adware (1);
# CLUSTER 486: trojan (2);
# CLUSTER 487: trojan (1);
# CLUSTER 488: trojan (16);
# CLUSTER 489: trojan (3);
# CLUSTER 490: trojan (2);
# CLUSTER 491: trojan (1);
# CLUSTER 492: trojan (2);
# CLUSTER 493: trojan (37);
# CLUSTER 494: trojan (1);
# CLUSTER 495: trojan (1);
# CLUSTER 496: trojan (4);
# CLUSTER 497: trojan (6);
# CLUSTER 498: trojan (1);
# CLUSTER 499: trojan (36); adware (1);
# CLUSTER 500: _ (2);
# CLUSTER 501: pua (2);
# CLUSTER 502: trojan (1);
# CLUSTER 503: trojan (2);
# CLUSTER 504: trojan (10);
# CLUSTER 505: adware (3); pua (2); _ (1);
# CLUSTER 506: pua (3);
# CLUSTER 507: trojan (1);
# CLUSTER 508: trojan (5);
# CLUSTER 509: trojan (24);
# CLUSTER 510: trojan (1);
# CLUSTER 511: hacktool (1);
# CLUSTER 512: trojan (1);
# CLUSTER 513: trojan (1);
# CLUSTER 514: trojan (1);
# CLUSTER 515: trojan (1);
# CLUSTER 516: trojan (1);
# CLUSTER 517: _ (7); trojan (2); adware (1);
# CLUSTER 518: trojan (7); adware (3); _ (2);
# CLUSTER 519: trojan (1);
# CLUSTER 520: trojan (41);
# CLUSTER 521: trojan (1);
# CLUSTER 522: trojan (14);
# CLUSTER 523: trojan (1);
# CLUSTER 524: trojan (2);
# CLUSTER 525: trojan (1);
# CLUSTER 526: trojan (1);
# CLUSTER 527: trojan (1);
# CLUSTER 528: _ (5); pua (2);
# CLUSTER 529: trojan (3);
# CLUSTER 530: trojan (1);
# CLUSTER 531: trojan (75);
# CLUSTER 532: trojan (8); adware (1);
# CLUSTER 533: trojan (1);
# CLUSTER 534: trojan (149); adware (4);
# CLUSTER 535: trojan (10);
# CLUSTER 536: trojan (1);
# CLUSTER 537: trojan (5);
# CLUSTER 538: trojan (1);
# CLUSTER 539: trojan (1);
# CLUSTER 540: trojan (1);
# CLUSTER 541: trojan (1);
# CLUSTER 542: trojan (1);
# CLUSTER 543: pua (1);
# CLUSTER 544: trojan (2);
# CLUSTER 545: trojan (1);
# CLUSTER 546: trojan (1);
# CLUSTER 547: trojan (1);
# CLUSTER 548: trojan (4);
# CLUSTER 549: trojan (1);
# CLUSTER 550: trojan (1);
# CLUSTER 551: trojan (3);
# CLUSTER 552: trojan (5);
# CLUSTER 553: trojan (1);
# CLUSTER 554: trojan (2);
# CLUSTER 555: _ (1);
# CLUSTER 556: trojan (1);
# CLUSTER 557: trojan (1);
# CLUSTER 558: trojan (1);
# CLUSTER 559: trojan (1);
# CLUSTER 560: trojan (1);
# CLUSTER 561: trojan (1);
# CLUSTER 562: trojan (16); pua (12); adware (2);
# CLUSTER 563: trojan (1);
# CLUSTER 564: trojan (1);
# CLUSTER 565: _ (1);
# CLUSTER 566: trojan (1);
# CLUSTER 567: _ (20); trojan (1);
# CLUSTER 568: trojan (1);
# CLUSTER 569: _ (4); trojan (1);
# CLUSTER 570: trojan (1);
# CLUSTER 571: trojan (54);
# CLUSTER 572: trojan (1);
# CLUSTER 573: trojan (1);
# CLUSTER 574: trojan (1); _ (1);
# CLUSTER 575: pua (1); trojan (1);
# CLUSTER 576: trojan (12);
# CLUSTER 577: trojan (8);
# CLUSTER 578: _ (4); trojan (1);
# CLUSTER 579: trojan (4); pua (1);
# CLUSTER 580: trojan (15);
# CLUSTER 581: trojan (1);
# CLUSTER 582: trojan (39); adware (2);
# CLUSTER 583: _ (1);
# CLUSTER 584: trojan (1);
# CLUSTER 585: trojan (10);
# CLUSTER 586: trojan (1);
# CLUSTER 587: downloader (10); trojan (9); pua (2); adware (1); _ (1);
# CLUSTER 588: trojan (3);
# CLUSTER 589: trojan (1);
# CLUSTER 590: _ (1);
# CLUSTER 591: pua (1);
# CLUSTER 592: trojan (8); _ (6); pua (2);
# CLUSTER 593: downloader (45); pua (18);
# CLUSTER 594: trojan (1);
# CLUSTER 595: _ (1);
# CLUSTER 596: trojan (1);
# CLUSTER 597: trojan (3); _ (1);
# CLUSTER 598: trojan (1);
# CLUSTER 599: pua (1);
# CLUSTER 600: trojan (2);
# CLUSTER 601: trojan (1);
# CLUSTER 602: trojan (2);
# CLUSTER 603: trojan (1);
# CLUSTER 604: trojan (120); ransomware (1);
# CLUSTER 605: trojan (1);
# CLUSTER 606: trojan (1);
# CLUSTER 607: trojan (2);
# CLUSTER 608: _ (1);
# CLUSTER 609: adware (2);
# CLUSTER 610: trojan (1);
# CLUSTER 611: trojan (17); adware (1);
# CLUSTER 612: trojan (2);
# CLUSTER 613: adware (1);
# CLUSTER 614: trojan (1);
# CLUSTER 615: pua (4);
# CLUSTER 616: _ (1); pua (1);
# CLUSTER 617: adware (1);
# CLUSTER 618: _ (1);
# CLUSTER 619: trojan (2);
# CLUSTER 620: trojan (10); downloader (1);
# CLUSTER 621: trojan (1);
# CLUSTER 622: trojan (3);
# CLUSTER 623: trojan (10);
# CLUSTER 624: trojan (2);
# CLUSTER 625: trojan (1);
# CLUSTER 626: trojan (6);
# CLUSTER 627: trojan (1);
# CLUSTER 628: trojan (11); pua (1);
# CLUSTER 629: trojan (1);
# CLUSTER 630: trojan (17); _ (1);
# CLUSTER 631: trojan (5);
# CLUSTER 632: trojan (7);
# CLUSTER 633: pua (3); adware (3); _ (1);
# CLUSTER 634: trojan (1);
# CLUSTER 635: trojan (45);
# CLUSTER 636: trojan (1);
# CLUSTER 637: virus (1);
# CLUSTER 638: trojan (1);
# CLUSTER 639: trojan (1);
# CLUSTER 640: trojan (3);
# CLUSTER 641: _ (1);
# CLUSTER 642: _ (1);
# CLUSTER 643: trojan (3);
# CLUSTER 644: trojan (2);
# CLUSTER 645: adware (2);
# CLUSTER 646: _ (4);
# CLUSTER 647: trojan (2);
# CLUSTER 648: trojan (5); _ (2); miner (1);
# CLUSTER 649: trojan (4);
# CLUSTER 650: trojan (1);
# CLUSTER 651: trojan (2);
# CLUSTER 652: trojan (5);
# CLUSTER 653: trojan (1); spyware (1);
# CLUSTER 654: trojan (3);
# CLUSTER 655: pua (1);
# CLUSTER 656: trojan (1);
# CLUSTER 657: trojan (1);
# CLUSTER 658: trojan (1);
# CLUSTER 659: _ (1);
# CLUSTER 660: _ (2);
# CLUSTER 661: trojan (2);
# CLUSTER 662: _ (1);
# CLUSTER 663: trojan (1);
# CLUSTER 664: trojan (8); adware (1); pua (1);
# CLUSTER 665: trojan (10);
# CLUSTER 666: trojan (7); adware (1);
# CLUSTER 667: trojan (1);
# CLUSTER 668: trojan (1);
# CLUSTER 669: adware (1);
# CLUSTER 670: trojan (1);
# CLUSTER 671: trojan (1);
# CLUSTER 672: trojan (1);
# CLUSTER 673: trojan (1);
# CLUSTER 674: _ (1); pua (1); adware (1);
# CLUSTER 675: adware (1);
# CLUSTER 676: trojan (1);
# CLUSTER 677: trojan (9);
# CLUSTER 678: trojan (2);
# CLUSTER 679: trojan (3);
# CLUSTER 680: _ (5); trojan (3); adware (1);
# CLUSTER 681: trojan (3);
# CLUSTER 682: downloader (1);
# CLUSTER 683: trojan (1);
# CLUSTER 684: trojan (1);
# CLUSTER 685: pua (1);
# CLUSTER 686: trojan (1);
# CLUSTER 687: _ (7); adware (1);
# CLUSTER 688: _ (3); pua (1);
# CLUSTER 689: _ (1);
# CLUSTER 690: trojan (1);
# CLUSTER 691: _ (1); trojan (1);
# CLUSTER 692: adware (1);
# CLUSTER 693: trojan (12);
# CLUSTER 694: _ (1);
# CLUSTER 695: trojan (1);
# CLUSTER 696: _ (2);
# CLUSTER 697: trojan (3);
# CLUSTER 698: pua (27); adware (5); _ (3); trojan (1);
# CLUSTER 699: trojan (1);
# CLUSTER 700: trojan (4);
# CLUSTER 701: trojan (1);
# CLUSTER 702: _ (1);
# CLUSTER 703: _ (1);
# CLUSTER 704: trojan (6);
# CLUSTER 705: adware (1);
# CLUSTER 706: trojan (1);
# CLUSTER 707: trojan (6);
# CLUSTER 708: trojan (2); _ (1);
# CLUSTER 709: trojan (1);
# CLUSTER 710: trojan (1);
# CLUSTER 711: trojan (1);
# CLUSTER 712: _ (11); adware (1); trojan (1);
# CLUSTER 713: trojan (1);
# CLUSTER 714: adware (1);
# CLUSTER 715: trojan (1);
# CLUSTER 716: trojan (1);
# CLUSTER 717: trojan (1);
# CLUSTER 718: adware (27); trojan (2);
# CLUSTER 719: trojan (2);
# CLUSTER 720: trojan (27); _ (4); adware (1);
# CLUSTER 721: trojan (1);
# CLUSTER 722: trojan (1);
# CLUSTER 723: _ (1);
# CLUSTER 724: trojan (1);
# CLUSTER 725: trojan (5);
# CLUSTER 726: trojan (5);
# CLUSTER 727: trojan (3);
# CLUSTER 728: trojan (10); adware (1);
# CLUSTER 729: trojan (2);
# CLUSTER 730: trojan (1);
# CLUSTER 731: trojan (1);
# CLUSTER 732: trojan (10);
# CLUSTER 733: trojan (1);
# CLUSTER 734: trojan (1);
# CLUSTER 735: trojan (1);
# CLUSTER 736: trojan (1);
# CLUSTER 737: trojan (1);
# CLUSTER 738: trojan (1);
# CLUSTER 739: trojan (1);
# CLUSTER 740: trojan (1);
# CLUSTER 741: ransomware (5);
# CLUSTER 742: trojan (1);
# CLUSTER 743: trojan (1);
# CLUSTER 744: trojan (1);
# CLUSTER 745: trojan (5);
# CLUSTER 746: trojan (6);
# CLUSTER 747: trojan (1);
# CLUSTER 748: trojan (1);
# CLUSTER 749: _ (1);
# CLUSTER 750: trojan (5);
# CLUSTER 751: _ (5);
# CLUSTER 752: trojan (1);
# CLUSTER 753: trojan (2);
# CLUSTER 754: trojan (1);
# CLUSTER 755: trojan (1);
# CLUSTER 756: pua (2); adware (1);
# CLUSTER 757: trojan (1);
# CLUSTER 758: trojan (30); adware (1);
# CLUSTER 759: trojan (24);
# CLUSTER 760: adware (1); trojan (1);
# CLUSTER 761: trojan (1);
# CLUSTER 762: trojan (1);
# CLUSTER 763: trojan (1);
# CLUSTER 764: trojan (1);
# CLUSTER 765: trojan (1);
# CLUSTER 766: trojan (24); pua (4); adware (2);
# CLUSTER 767: trojan (1);
# CLUSTER 768: downloader (1);
# CLUSTER 769: trojan (1);
# CLUSTER 770: trojan (1);
# CLUSTER 771: trojan (2);
# CLUSTER 772: trojan (6);
# CLUSTER 773: trojan (1);
# CLUSTER 774: trojan (4);
# CLUSTER 775: trojan (1);
# CLUSTER 776: trojan (1);
# CLUSTER 777: _ (1);
# CLUSTER 778: trojan (1);
# CLUSTER 779: trojan (1);
# CLUSTER 780: trojan (57); pua (2);
# CLUSTER 781: trojan (36);
# CLUSTER 782: trojan (3);
# CLUSTER 783: trojan (1);
# CLUSTER 784: trojan (1);
# CLUSTER 785: trojan (1);
# CLUSTER 786: trojan (6); pua (2); adware (1);
# CLUSTER 787: trojan (2);
# CLUSTER 788: trojan (1);
# CLUSTER 789: pua (2); trojan (2);
# CLUSTER 790: _ (1);
# CLUSTER 791: trojan (1);
# CLUSTER 792: trojan (1);
# CLUSTER 793: trojan (1);
# CLUSTER 794: trojan (1);
# CLUSTER 795: trojan (1);
# CLUSTER 796: trojan (1);
# CLUSTER 797: trojan (1);
# CLUSTER 798: trojan (6);
# CLUSTER 799: _ (1);
# CLUSTER 800: _ (16); adware (3); pua (2); trojan (1);
# CLUSTER 801: virus (1);
# CLUSTER 802: pua (1);
# CLUSTER 803: downloader (4);
# CLUSTER 804: trojan (1);
# CLUSTER 805: pua (1);
# CLUSTER 806: trojan (1);
# CLUSTER 807: trojan (39);
# CLUSTER 808: trojan (1);
# CLUSTER 809: trojan (1);
# CLUSTER 810: _ (5);
# CLUSTER 811: trojan (1);
# CLUSTER 812: trojan (1);
# CLUSTER 813: trojan (27);
# CLUSTER 814: trojan (1);
# CLUSTER 815: trojan (1);
# CLUSTER 816: pua (1); trojan (1);
# CLUSTER 817: trojan (1);
# CLUSTER 818: _ (2);
# CLUSTER 819: trojan (1);
# CLUSTER 820: trojan (1);
# CLUSTER 821: pua (1);
# CLUSTER 822: trojan (1);
# CLUSTER 823: trojan (1);
# CLUSTER 824: trojan (2);
# CLUSTER 825: trojan (20); adware (1);
# CLUSTER 826: trojan (2); downloader (1);
# CLUSTER 827: _ (1);
# CLUSTER 828: trojan (2);
# CLUSTER 829: trojan (1);
# CLUSTER 830: trojan (1);
# CLUSTER 831: trojan (1);
# CLUSTER 832: adware (1);
# CLUSTER 833: trojan (3);
# CLUSTER 834: trojan (1);
# CLUSTER 835: trojan (2);
# CLUSTER 836: trojan (6);
# CLUSTER 837: trojan (4);
# CLUSTER 838: _ (2); trojan (2);
# CLUSTER 839: _ (1);
# CLUSTER 840: trojan (1);
# CLUSTER 841: trojan (1);
# CLUSTER 842: trojan (2);
# CLUSTER 843: trojan (1); pua (1);
# CLUSTER 844: trojan (1);
# CLUSTER 845: trojan (21);
# CLUSTER 846: trojan (1);
# CLUSTER 847: trojan (1);
# CLUSTER 848: trojan (3);
# CLUSTER 849: trojan (2);
# CLUSTER 850: trojan (1);
# CLUSTER 851: trojan (16); pua (1); adware (1);
# CLUSTER 852: trojan (4); _ (1);
# CLUSTER 853: trojan (30);
# CLUSTER 854: _ (26); trojan (22); adware (9); pua (4);
# CLUSTER 855: trojan (4);
# CLUSTER 856: pua (5); trojan (4);
# CLUSTER 857: trojan (2);
# CLUSTER 858: trojan (1);
# CLUSTER 859: pua (28); _ (7); trojan (7);
# CLUSTER 860: adware (1);
# CLUSTER 861: trojan (2);
# CLUSTER 862: _ (1);
# CLUSTER 863: adware (1);
# CLUSTER 864: _ (12); adware (5); trojan (4); pua (3);
# CLUSTER 865: trojan (1);
# CLUSTER 866: trojan (2);
# CLUSTER 867: trojan (1);
# CLUSTER 868: trojan (1);
# CLUSTER 869: trojan (1);
# CLUSTER 870: trojan (2);
# CLUSTER 871: trojan (1);
# CLUSTER 872: trojan (1);
# CLUSTER 873: _ (3);
# CLUSTER 874: _ (1);
# CLUSTER 875: trojan (1);
# CLUSTER 876: trojan (1);
# CLUSTER 877: trojan (1);
# CLUSTER 878: trojan (2);
# CLUSTER 879: trojan (1);
# CLUSTER 880: trojan (26); pua (8);
# CLUSTER 881: pua (1);
# CLUSTER 882: trojan (3);
# CLUSTER 883: trojan (5);
# CLUSTER 884: _ (1);
# CLUSTER 885: trojan (4);
# CLUSTER 886: trojan (1);
# CLUSTER 887: trojan (1);
# CLUSTER 888: trojan (1);
# CLUSTER 889: trojan (1);
# CLUSTER 890: trojan (2);
# CLUSTER 891: trojan (4);
# CLUSTER 892: trojan (2);
# CLUSTER 893: trojan (2); adware (1);
# CLUSTER 894: trojan (2);
# CLUSTER 895: _ (2);
# CLUSTER 896: trojan (1); adware (1); pua (1);
# CLUSTER 897: trojan (1);
# CLUSTER 898: trojan (1);
# CLUSTER 899: adware (2);
# CLUSTER 900: trojan (1);
# CLUSTER 901: trojan (3);
# CLUSTER 902: _ (1);
# CLUSTER 903: trojan (2);
# CLUSTER 904: trojan (1);
# CLUSTER 905: adware (2);
# CLUSTER 906: trojan (2);
# CLUSTER 907: trojan (1);
# CLUSTER 908: trojan (1);
# CLUSTER 909: trojan (10);
# CLUSTER 910: _ (1);
# CLUSTER 911: downloader (1);
# CLUSTER 912: trojan (1);
# CLUSTER 913: trojan (2);
# CLUSTER 914: trojan (1);
# CLUSTER 915: trojan (1);
# CLUSTER 916: trojan (30);
# CLUSTER 917: trojan (4);
# CLUSTER 918: _ (2); pua (1); trojan (1);
# CLUSTER 919: trojan (1);
# CLUSTER 920: trojan (1);
# CLUSTER 921: trojan (1);
# CLUSTER 922: _ (12); trojan (1);
# CLUSTER 923: trojan (4); _ (1);
# CLUSTER 924: trojan (1);
# CLUSTER 925: trojan (1);
# CLUSTER 926: trojan (7);
# CLUSTER 927: _ (1);
# CLUSTER 928: trojan (1);
# CLUSTER 929: trojan (12);
# CLUSTER 930: _ (1);
# CLUSTER 931: trojan (17); adware (1);
# CLUSTER 932: _ (11); trojan (6);
# CLUSTER 933: _ (1);
# CLUSTER 934: trojan (1);
# CLUSTER 935: trojan (1);
# CLUSTER 936: trojan (1);
# CLUSTER 937: trojan (1);
# CLUSTER 938: trojan (1);
# CLUSTER 939: trojan (1);
# CLUSTER 940: trojan (1);
# CLUSTER 941: _ (1);
# CLUSTER 942: trojan (1);
# CLUSTER 943: trojan (1);
# CLUSTER 944: trojan (2);
# CLUSTER 945: miner (1); trojan (1);
# CLUSTER 946: _ (3);
# CLUSTER 947: trojan (11);
# CLUSTER 948: trojan (1);
# CLUSTER 949: trojan (3);
# CLUSTER 950: trojan (1);
# CLUSTER 951: trojan (22); _ (8);
# CLUSTER 952: trojan (2);
# CLUSTER 953: trojan (1);
# CLUSTER 954: pua (1);
# CLUSTER 955: trojan (1);
# CLUSTER 956: trojan (1);
# CLUSTER 957: trojan (13);
# CLUSTER 958: trojan (2);
# CLUSTER 959: pua (1);
# CLUSTER 960: trojan (1);
# CLUSTER 961: trojan (1);
# CLUSTER 962: trojan (3);
# CLUSTER 963: trojan (2); pua (2);
# CLUSTER 964: trojan (2);
# CLUSTER 965: trojan (1);
# CLUSTER 966: trojan (3); downloader (1);
# CLUSTER 967: downloader (1);
# CLUSTER 968: downloader (1);
# CLUSTER 969: trojan (1);
# CLUSTER 970: trojan (1);
# CLUSTER 971: trojan (1);
# CLUSTER 972: trojan (2);
# CLUSTER 973: trojan (2);
# CLUSTER 974: trojan (1);
# CLUSTER 975: pua (2); _ (1); trojan (1);
# CLUSTER 976: trojan (1);
# CLUSTER 977: trojan (1);
# CLUSTER 978: trojan (1);
# CLUSTER 979: trojan (1);
# CLUSTER 980: trojan (1);
# CLUSTER 981: pua (1); trojan (1);
# CLUSTER 982: pua (1);
# CLUSTER 983: trojan (1);
# CLUSTER 984: _ (1);
# CLUSTER 985: trojan (1);
# CLUSTER 986: trojan (35); pua (1); adware (1);
# CLUSTER 987: trojan (3);
# CLUSTER 988: trojan (5);
# CLUSTER 989: trojan (1);
# CLUSTER 990: trojan (1);
# CLUSTER 991: pua (15); adware (1);
# CLUSTER 992: trojan (2);
# CLUSTER 993: trojan (1);
# CLUSTER 994: trojan (2);
# CLUSTER 995: trojan (4);
# CLUSTER 996: _ (1);
# CLUSTER 997: trojan (1);
# CLUSTER 998: trojan (1);
# CLUSTER 999: trojan (1);
# CLUSTER 1000: trojan (3);
# CLUSTER 1001: trojan (7); adware (1);
# CLUSTER 1002: trojan (2);
# CLUSTER 1003: trojan (6);
# CLUSTER 1004: trojan (2);
# CLUSTER 1005: trojan (1);
# CLUSTER 1006: trojan (4);
# CLUSTER 1007: trojan (7);
# CLUSTER 1008: trojan (1);
# CLUSTER 1009: trojan (1);
# CLUSTER 1010: trojan (5);
# CLUSTER 1011: trojan (1);
# CLUSTER 1012: virus (1);
# CLUSTER 1013: trojan (1);
# CLUSTER 1014: trojan (1);
# CLUSTER 1015: adware (5);
# CLUSTER 1016: trojan (1);
# CLUSTER 1017: trojan (4);
# CLUSTER 1018: trojan (1);
# CLUSTER 1019: trojan (4);
# CLUSTER 1020: trojan (2);
# CLUSTER 1021: trojan (1);
# CLUSTER 1022: trojan (23); adware (2);
# CLUSTER 1023: trojan (2);
# CLUSTER 1024: trojan (1);
# CLUSTER 1025: trojan (5); pua (3); adware (1);
# CLUSTER 1026: _ (1);
# CLUSTER 1027: trojan (1);
# CLUSTER 1028: trojan (6);
# CLUSTER 1029: trojan (1);
# CLUSTER 1030: trojan (1);
# CLUSTER 1031: trojan (1);
# CLUSTER 1032: trojan (1);
# CLUSTER 1033: trojan (1);
# CLUSTER 1034: trojan (1);
# CLUSTER 1035: trojan (1);
# CLUSTER 1036: trojan (1);
# CLUSTER 1037: pua (1);
# CLUSTER 1038: trojan (1);
# CLUSTER 1039: trojan (1);
# CLUSTER 1040: trojan (4);
# CLUSTER 1041: trojan (5);
# CLUSTER 1042: downloader (1);
# CLUSTER 1043: trojan (1);
# CLUSTER 1044: adware (1);
# CLUSTER 1045: trojan (1);
# CLUSTER 1046: trojan (1);
# CLUSTER 1047: pua (1);
# CLUSTER 1048: trojan (1);
# CLUSTER 1049: trojan (1);
# CLUSTER 1050: trojan (1);
# CLUSTER 1051: adware (1);
# CLUSTER 1052: trojan (1);
# CLUSTER 1053: trojan (1);
# CLUSTER 1054: trojan (2); pua (1);
# CLUSTER 1055: adware (1); trojan (1);
# CLUSTER 1056: trojan (1);
# CLUSTER 1057: trojan (1);
# CLUSTER 1058: _ (2);
# CLUSTER 1059: trojan (1);
# CLUSTER 1060: trojan (1);
# CLUSTER 1061: trojan (1);
# CLUSTER 1062: trojan (1);
# CLUSTER 1063: trojan (1);
# CLUSTER 1064: trojan (1);
# CLUSTER 1065: trojan (2);
# CLUSTER 1066: adware (3);
# CLUSTER 1067: trojan (1);
# CLUSTER 1068: trojan (6);
# CLUSTER 1069: trojan (1);
# CLUSTER 1070: trojan (2);
# CLUSTER 1071: trojan (3);
# CLUSTER 1072: trojan (1);
# CLUSTER 1073: trojan (1);
# CLUSTER 1074: trojan (1);
# CLUSTER 1075: adware (1);
# CLUSTER 1076: trojan (1);
# CLUSTER 1077: _ (1);
# CLUSTER 1078: trojan (1);
# CLUSTER 1079: trojan (2);
# CLUSTER 1080: trojan (2);
# CLUSTER 1081: trojan (4);
# CLUSTER 1082: trojan (1);
# CLUSTER 1083: trojan (12); adware (4);
# CLUSTER 1084: trojan (1);
# CLUSTER 1085: trojan (2);
# CLUSTER 1086: trojan (20);
# CLUSTER 1087: _ (6); trojan (1);
# CLUSTER 1088: trojan (2);
# CLUSTER 1089: trojan (1);
# CLUSTER 1090: trojan (1);
# CLUSTER 1091: downloader (1);
# CLUSTER 1092: trojan (1);
# CLUSTER 1093: trojan (1);
# CLUSTER 1094: _ (1);
# CLUSTER 1095: _ (1);
# CLUSTER 1096: trojan (5);
# CLUSTER 1097: trojan (13);
# CLUSTER 1098: adware (2);
# CLUSTER 1099: adware (2);
# CLUSTER 1100: trojan (1);
# CLUSTER 1101: trojan (1);
# CLUSTER 1102: trojan (1);
# CLUSTER 1103: trojan (1);
# CLUSTER 1104: trojan (1);
# CLUSTER 1105: _ (1);
# CLUSTER 1106: trojan (2);
# CLUSTER 1107: trojan (1);
# CLUSTER 1108: trojan (9); adware (1);
# CLUSTER 1109: downloader (1);
# CLUSTER 1110: trojan (6);
# CLUSTER 1111: trojan (4);
# CLUSTER 1112: trojan (2);
# CLUSTER 1113: _ (2); trojan (1);
# CLUSTER 1114: _ (1);
# CLUSTER 1115: trojan (1);
# CLUSTER 1116: adware (1);
# CLUSTER 1117: trojan (2); adware (1);
# CLUSTER 1118: _ (14); pua (9); trojan (4); miner (2);
# CLUSTER 1119: trojan (1);
# CLUSTER 1120: trojan (3);
# CLUSTER 1121: trojan (28);
# CLUSTER 1122: trojan (1);
# CLUSTER 1123: trojan (1);
# CLUSTER 1124: trojan (13);
# CLUSTER 1125: trojan (13); ransomware (4);
# CLUSTER 1126: trojan (1);
# CLUSTER 1127: trojan (1);
# CLUSTER 1128: trojan (1);
# CLUSTER 1129: trojan (1);
# CLUSTER 1130: trojan (1);
# CLUSTER 1131: trojan (16); adware (1);
# CLUSTER 1132: trojan (1);
# CLUSTER 1133: trojan (2);
# CLUSTER 1134: trojan (1);
# CLUSTER 1135: trojan (1);
# CLUSTER 1136: trojan (5);
# CLUSTER 1137: trojan (1);
# CLUSTER 1138: trojan (1);
# CLUSTER 1139: _ (1);
# CLUSTER 1140: trojan (1);
# CLUSTER 1141: trojan (1);
# CLUSTER 1142: trojan (16);
# CLUSTER 1143: trojan (2);
# CLUSTER 1144: _ (1);
# CLUSTER 1145: trojan (1);
# CLUSTER 1146: trojan (10); adware (1);
# CLUSTER 1147: trojan (1);
# CLUSTER 1148: trojan (1);
# CLUSTER 1149: trojan (1);
# CLUSTER 1150: trojan (6);
# CLUSTER 1151: trojan (1);
# CLUSTER 1152: trojan (6);
# CLUSTER 1153: trojan (6); pua (1);
# CLUSTER 1154: trojan (1);
# CLUSTER 1155: trojan (13); adware (2); pua (1);
# CLUSTER 1156: trojan (1);
# CLUSTER 1157: trojan (2);
# CLUSTER 1158: trojan (1);
# CLUSTER 1159: trojan (1);
# CLUSTER 1160: trojan (4);
# CLUSTER 1161: trojan (1);
# CLUSTER 1162: adware (1);
# CLUSTER 1163: adware (1); pua (1);
# CLUSTER 1164: _ (4); pua (2);
# CLUSTER 1165: trojan (1);
# CLUSTER 1166: trojan (1);
# CLUSTER 1167: pua (1);
# CLUSTER 1168: trojan (1);
# CLUSTER 1169: trojan (1); pua (1);
# CLUSTER 1170: trojan (2);
# CLUSTER 1171: trojan (1);
# CLUSTER 1172: trojan (1);
# CLUSTER 1173: trojan (1);
# CLUSTER 1174: trojan (1);
# CLUSTER 1175: trojan (1);
# CLUSTER 1176: trojan (1);
# CLUSTER 1177: trojan (1);
# CLUSTER 1178: pua (1);
# CLUSTER 1179: trojan (1);
# CLUSTER 1180: trojan (1);
# CLUSTER 1181: trojan (1);
# CLUSTER 1182: trojan (2);
# CLUSTER 1183: trojan (8);
# CLUSTER 1184: trojan (4);
# CLUSTER 1185: trojan (2);
# CLUSTER 1186: trojan (1);
# CLUSTER 1187: trojan (1);
# CLUSTER 1188: trojan (1);
# CLUSTER 1189: trojan (1);
# CLUSTER 1190: trojan (2);
# CLUSTER 1191: trojan (1);
# CLUSTER 1192: trojan (1);
# CLUSTER 1193: trojan (3);
# CLUSTER 1194: trojan (2);
# CLUSTER 1195: virus (1);
# CLUSTER 1196: trojan (1);
# CLUSTER 1197: trojan (1);
# CLUSTER 1198: pua (1);
# CLUSTER 1199: _ (3);
# CLUSTER 1200: trojan (1);
# CLUSTER 1201: trojan (1);
# CLUSTER 1202: trojan (1);
# CLUSTER 1203: trojan (1);
# CLUSTER 1204: trojan (1);
# CLUSTER 1205: trojan (1);
# CLUSTER 1206: trojan (1);
# CLUSTER 1207: trojan (12);
# CLUSTER 1208: trojan (1);
# CLUSTER 1209: trojan (2);
# CLUSTER 1210: trojan (1);
# CLUSTER 1211: trojan (2); pua (1);
# CLUSTER 1212: _ (1);
# CLUSTER 1213: trojan (1);
# CLUSTER 1214: trojan (1);
# CLUSTER 1215: trojan (1);
# CLUSTER 1216: trojan (25);
# CLUSTER 1217: trojan (1);
# CLUSTER 1218: trojan (1);
# CLUSTER 1219: _ (1);
# CLUSTER 1220: pua (1);
# CLUSTER 1221: trojan (1);
# CLUSTER 1222: trojan (1); adware (1);
# CLUSTER 1223: _ (1);
# CLUSTER 1224: trojan (2);
# CLUSTER 1225: trojan (1);
# CLUSTER 1226: trojan (1);
# CLUSTER 1227: trojan (1);
# CLUSTER 1228: trojan (1);
# CLUSTER 1229: trojan (4);
# CLUSTER 1230: trojan (1);
# CLUSTER 1231: trojan (1);
# CLUSTER 1232: trojan (1);
# CLUSTER 1233: trojan (2);
# CLUSTER 1234: trojan (2);
# CLUSTER 1235: trojan (1);
# CLUSTER 1236: adware (1);
# CLUSTER 1237: trojan (1);
# CLUSTER 1238: trojan (4); _ (1);
# CLUSTER 1239: _ (1);
# CLUSTER 1240: trojan (1);
# CLUSTER 1241: trojan (2);
# CLUSTER 1242: trojan (1);
# CLUSTER 1243: trojan (1);
# CLUSTER 1244: trojan (1);
# CLUSTER 1245: trojan (1);
# CLUSTER 1246: pua (1);
# CLUSTER 1247: virus (1);
# CLUSTER 1248: trojan (1);
# CLUSTER 1249: trojan (1);
# CLUSTER 1250: trojan (1);
# CLUSTER 1251: pua (1);
# CLUSTER 1252: pua (1);
# CLUSTER 1253: trojan (1);
# CLUSTER 1254: trojan (1);
# CLUSTER 1255: trojan (1);
# CLUSTER 1256: trojan (1);
# CLUSTER 1257: trojan (2); adware (1); pua (1);
# CLUSTER 1258: trojan (1);
# CLUSTER 1259: trojan (1);
# CLUSTER 1260: trojan (1);
# CLUSTER 1261: trojan (8);
# CLUSTER 1262: virus (1);
# CLUSTER 1263: _ (1);
# CLUSTER 1264: trojan (1);
# CLUSTER 1265: _ (2); pua (2);
# CLUSTER 1266: trojan (13);
# CLUSTER 1267: trojan (3);
# CLUSTER 1268: trojan (7);
# CLUSTER 1269: trojan (1);
# CLUSTER 1270: trojan (2);
# CLUSTER 1271: trojan (1);
# CLUSTER 1272: trojan (1);
# CLUSTER 1273: trojan (1);
# CLUSTER 1274: trojan (1);
# CLUSTER 1275: adware (1);
# CLUSTER 1276: trojan (1);
# CLUSTER 1277: trojan (19);
# CLUSTER 1278: trojan (1);
# CLUSTER 1279: trojan (2);
# CLUSTER 1280: trojan (1);
# CLUSTER 1281: trojan (1);
# CLUSTER 1282: trojan (1);
# CLUSTER 1283: adware (1);
# CLUSTER 1284: trojan (1);
# CLUSTER 1285: trojan (1);
# CLUSTER 1286: pua (1);
# CLUSTER 1287: _ (2);
# CLUSTER 1288: trojan (3); adware (1);
# CLUSTER 1289: trojan (1);
# CLUSTER 1290: trojan (2);
# CLUSTER 1291: adware (1);
# CLUSTER 1292: trojan (2);
# CLUSTER 1293: trojan (1);
# CLUSTER 1294: trojan (6);
# CLUSTER 1295: trojan (1);
# CLUSTER 1296: trojan (1);
# CLUSTER 1297: trojan (2);
# CLUSTER 1298: _ (1);
# CLUSTER 1299: _ (7); trojan (1);
# CLUSTER 1300: trojan (2);
# CLUSTER 1301: trojan (3);
# CLUSTER 1302: adware (1);
# CLUSTER 1303: trojan (1);
# CLUSTER 1304: _ (1);
# CLUSTER 1305: trojan (6);
# CLUSTER 1306: trojan (1);
# CLUSTER 1307: trojan (1);
# CLUSTER 1308: trojan (2);
# CLUSTER 1309: _ (1);
# CLUSTER 1310: trojan (1);
# CLUSTER 1311: trojan (1);
# CLUSTER 1312: trojan (1);
# CLUSTER 1313: pua (1); trojan (1);
# CLUSTER 1314: trojan (1);
# CLUSTER 1315: trojan (1);
# CLUSTER 1316: pua (3);
# CLUSTER 1317: trojan (1);
# CLUSTER 1318: adware (1);
# CLUSTER 1319: trojan (1);
# CLUSTER 1320: trojan (2);
# CLUSTER 1321: adware (8);
# CLUSTER 1322: trojan (1);
# CLUSTER 1323: trojan (4);
# CLUSTER 1324: trojan (1);
# CLUSTER 1325: _ (1);
# CLUSTER 1326: _ (1);
# CLUSTER 1327: trojan (1);
# CLUSTER 1328: _ (1);
# CLUSTER 1329: trojan (16);
# CLUSTER 1330: trojan (1);
# CLUSTER 1331: trojan (1);
# CLUSTER 1332: trojan (2);
# CLUSTER 1333: trojan (1);
# CLUSTER 1334: trojan (7); _ (1);
# CLUSTER 1335: _ (1);
# CLUSTER 1336: _ (17); trojan (2); virus (1);
# CLUSTER 1337: _ (3);
# CLUSTER 1338: trojan (1);
# CLUSTER 1339: trojan (1);
# CLUSTER 1340: trojan (3);
# CLUSTER 1341: adware (38); _ (10); trojan (4); pua (3); hacktool (1);
# CLUSTER 1342: trojan (1);
# CLUSTER 1343: adware (1);
# CLUSTER 1344: trojan (1);
# CLUSTER 1345: trojan (1);
# CLUSTER 1346: trojan (1);
# CLUSTER 1347: trojan (1);
# CLUSTER 1348: trojan (1);
# CLUSTER 1349: trojan (1);
# CLUSTER 1350: trojan (1);
# CLUSTER 1351: trojan (1);
# CLUSTER 1352: _ (1); trojan (1); downloader (1);
# CLUSTER 1353: trojan (1);
# CLUSTER 1354: trojan (1);
# CLUSTER 1355: adware (1); pua (1);
# CLUSTER 1356: trojan (1);
# CLUSTER 1357: trojan (1);
# CLUSTER 1358: trojan (5);
# CLUSTER 1359: trojan (3);
# CLUSTER 1360: _ (1);
# CLUSTER 1361: adware (1);
# CLUSTER 1362: pua (1); adware (1);
# CLUSTER 1363: trojan (1);
# CLUSTER 1364: trojan (1);
# CLUSTER 1365: trojan (12); adware (1);
# CLUSTER 1366: pua (1);
# CLUSTER 1367: trojan (1);
# CLUSTER 1368: _ (5);
# CLUSTER 1369: trojan (1);
# CLUSTER 1370: trojan (1);
# CLUSTER 1371: trojan (1);
# CLUSTER 1372: trojan (1);
# CLUSTER 1373: trojan (6);
# CLUSTER 1374: trojan (1); pua (1);
# CLUSTER 1375: adware (1);
# CLUSTER 1376: trojan (1);
# CLUSTER 1377: trojan (2);
# CLUSTER 1378: _ (1);
# CLUSTER 1379: trojan (1);
# CLUSTER 1380: hacktool (1); pua (1); trojan (1);
# CLUSTER 1381: trojan (1);
# CLUSTER 1382: trojan (1);
# CLUSTER 1383: trojan (2);
# CLUSTER 1384: trojan (1);
# CLUSTER 1385: trojan (6);
# CLUSTER 1386: _ (2);
# CLUSTER 1387: trojan (1);
# CLUSTER 1388: trojan (1);
# CLUSTER 1389: pua (1);
# CLUSTER 1390: pua (2);
# CLUSTER 1391: trojan (1);
# CLUSTER 1392: trojan (1);
# CLUSTER 1393: trojan (5); _ (1);
# CLUSTER 1394: trojan (1);
# CLUSTER 1395: trojan (1);
# CLUSTER 1396: trojan (1);
# CLUSTER 1397: trojan (1);
# CLUSTER 1398: trojan (1);
# CLUSTER 1399: trojan (1); downloader (1);
# CLUSTER 1400: trojan (2);
# CLUSTER 1401: _ (2);
# CLUSTER 1402: trojan (2);
# CLUSTER 1403: trojan (1);
# CLUSTER 1404: trojan (1);
# CLUSTER 1405: trojan (7);
# CLUSTER 1406: trojan (8);
# CLUSTER 1407: trojan (1);
# CLUSTER 1408: _ (1);
# CLUSTER 1409: trojan (1);
# CLUSTER 1410: pua (7); trojan (6); downloader (1);
# CLUSTER 1411: trojan (2);
# CLUSTER 1412: adware (3);
# CLUSTER 1413: trojan (1);
# CLUSTER 1414: trojan (1);
# CLUSTER 1415: trojan (1);
# CLUSTER 1416: adware (1);
# CLUSTER 1417: trojan (1);
# CLUSTER 1418: trojan (1);
# CLUSTER 1419: trojan (1);
# CLUSTER 1420: trojan (3);
# CLUSTER 1421: _ (1);
# CLUSTER 1422: trojan (1);
# CLUSTER 1423: trojan (12);
# CLUSTER 1424: pua (1);
# CLUSTER 1425: pua (4);
# CLUSTER 1426: trojan (4);
# CLUSTER 1427: trojan (3);
# CLUSTER 1428: pua (1);
# CLUSTER 1429: trojan (1);
# CLUSTER 1430: trojan (1);
# CLUSTER 1431: trojan (1);
# CLUSTER 1432: trojan (1);
# CLUSTER 1433: trojan (7);
# CLUSTER 1434: trojan (1);
# CLUSTER 1435: trojan (1);
# CLUSTER 1436: trojan (1);
# CLUSTER 1437: trojan (1);
# CLUSTER 1438: trojan (1);
# CLUSTER 1439: trojan (1);
# CLUSTER 1440: trojan (1);
# CLUSTER 1441: pua (1); trojan (1);
# CLUSTER 1442: trojan (1);
# CLUSTER 1443: trojan (1);
# CLUSTER 1444: trojan (1);
# CLUSTER 1445: _ (1);
# CLUSTER 1446: trojan (10); adware (1);
# CLUSTER 1447: trojan (1);
# CLUSTER 1448: trojan (5);
# CLUSTER 1449: trojan (1);
# CLUSTER 1450: adware (1);
# CLUSTER 1451: trojan (1);
# CLUSTER 1452: trojan (1);
# CLUSTER 1453: trojan (1);
# CLUSTER 1454: trojan (1);
# CLUSTER 1455: trojan (3);
# CLUSTER 1456: trojan (1);
# CLUSTER 1457: _ (9); trojan (1); pua (1);
# CLUSTER 1458: trojan (8);
# CLUSTER 1459: trojan (3);
# CLUSTER 1460: adware (1); downloader (1);
# CLUSTER 1461: trojan (1);
# CLUSTER 1462: trojan (2);
# CLUSTER 1463: trojan (1);
# CLUSTER 1464: trojan (1);
# CLUSTER 1465: trojan (1);
# CLUSTER 1466: pua (1);
# CLUSTER 1467: trojan (1);
# CLUSTER 1468: trojan (1);
# CLUSTER 1469: adware (1);
# CLUSTER 1470: trojan (1);
# CLUSTER 1471: trojan (1);
# CLUSTER 1472: trojan (1);
# CLUSTER 1473: trojan (1);
# CLUSTER 1474: trojan (2);
# CLUSTER 1475: trojan (42);
# CLUSTER 1476: trojan (1);
# CLUSTER 1477: trojan (1);
# CLUSTER 1478: trojan (1);
# CLUSTER 1479: trojan (1);
# CLUSTER 1480: trojan (1);
# CLUSTER 1481: pua (1);
# CLUSTER 1482: trojan (1);
# CLUSTER 1483: trojan (1);
# CLUSTER 1484: downloader (4); trojan (3); _ (1);
# CLUSTER 1485: trojan (1);
# CLUSTER 1486: adware (1);
# CLUSTER 1487: trojan (1);
# CLUSTER 1488: _ (1);
# CLUSTER 1489: trojan (7); miner (1);
# CLUSTER 1490: trojan (1);
# CLUSTER 1491: trojan (1);
# CLUSTER 1492: trojan (1);
# CLUSTER 1493: trojan (3);
# CLUSTER 1494: trojan (1);
# CLUSTER 1495: trojan (2);
# CLUSTER 1496: trojan (1);
# CLUSTER 1497: trojan (1);
# CLUSTER 1498: trojan (1);
# CLUSTER 1499: trojan (1);
# CLUSTER 1500: _ (1);
# CLUSTER 1501: trojan (1);
# CLUSTER 1502: trojan (1);
# CLUSTER 1503: trojan (1);
# CLUSTER 1504: _ (1);
# CLUSTER 1505: trojan (4);
# CLUSTER 1506: trojan (1);
# CLUSTER 1507: trojan (1);
# CLUSTER 1508: trojan (1);
# CLUSTER 1509: trojan (3); pua (2);
# CLUSTER 1510: trojan (1);
# CLUSTER 1511: trojan (1);
# CLUSTER 1512: trojan (6);
# CLUSTER 1513: trojan (2);
# CLUSTER 1514: adware (1);
# CLUSTER 1515: trojan (2); adware (1);
# CLUSTER 1516: trojan (3);
# CLUSTER 1517: trojan (1);
# CLUSTER 1518: _ (1);
# CLUSTER 1519: trojan (1);
# CLUSTER 1520: trojan (1);
# CLUSTER 1521: trojan (1);
# CLUSTER 1522: trojan (1);
# CLUSTER 1523: trojan (1);
# CLUSTER 1524: trojan (1);
# CLUSTER 1525: trojan (1);
# CLUSTER 1526: trojan (1);
# CLUSTER 1527: adware (1);
# CLUSTER 1528: trojan (1);
# CLUSTER 1529: adware (2);
# CLUSTER 1530: _ (1);
# CLUSTER 1531: trojan (1);
# CLUSTER 1532: pua (11); _ (2); trojan (1);
# CLUSTER 1533: trojan (1);
# CLUSTER 1534: trojan (1);
# CLUSTER 1535: trojan (1);
# CLUSTER 1536: trojan (1);
# CLUSTER 1537: trojan (1);
# CLUSTER 1538: trojan (2);
# CLUSTER 1539: trojan (4);
# CLUSTER 1540: trojan (1);
# CLUSTER 1541: trojan (3);
# CLUSTER 1542: trojan (1);
# CLUSTER 1543: trojan (1);
# CLUSTER 1544: trojan (1);
# CLUSTER 1545: trojan (1);
# CLUSTER 1546: trojan (1);
# CLUSTER 1547: trojan (1);
# CLUSTER 1548: trojan (1);
# CLUSTER 1549: trojan (1);
# CLUSTER 1550: trojan (4);
# CLUSTER 1551: trojan (1);
# CLUSTER 1552: pua (2); adware (1);
# CLUSTER 1553: _ (1);
# CLUSTER 1554: _ (6);
# CLUSTER 1555: trojan (1);
# CLUSTER 1556: trojan (1);
# CLUSTER 1557: adware (1);
# CLUSTER 1558: trojan (1);
# CLUSTER 1559: trojan (1);
# CLUSTER 1560: trojan (1);
# CLUSTER 1561: trojan (1);
# CLUSTER 1562: trojan (2);
# CLUSTER 1563: trojan (1);
# CLUSTER 1564: _ (7);
# CLUSTER 1565: trojan (1);
# CLUSTER 1566: trojan (1);
# CLUSTER 1567: trojan (1);
# CLUSTER 1568: _ (1);
# CLUSTER 1569: trojan (1);
# CLUSTER 1570: trojan (12); adware (1);
# CLUSTER 1571: trojan (1);
# CLUSTER 1572: adware (1);
# CLUSTER 1573: trojan (4);
# CLUSTER 1574: trojan (8);
# CLUSTER 1575: trojan (1);
# CLUSTER 1576: trojan (1);
# CLUSTER 1577: trojan (1);
# CLUSTER 1578: trojan (1);
# CLUSTER 1579: trojan (1);
# CLUSTER 1580: trojan (1);
# CLUSTER 1581: trojan (1);
# CLUSTER 1582: trojan (1);
# CLUSTER 1583: trojan (1);
# CLUSTER 1584: trojan (1);
# CLUSTER 1585: trojan (7);
# CLUSTER 1586: trojan (2);
# CLUSTER 1587: trojan (1);
# CLUSTER 1588: trojan (1);
# CLUSTER 1589: trojan (1);
# CLUSTER 1590: _ (1);
# CLUSTER 1591: trojan (2);
# CLUSTER 1592: trojan (1);
# CLUSTER 1593: trojan (1);
# CLUSTER 1594: trojan (1);
# CLUSTER 1595: trojan (3);
# CLUSTER 1596: trojan (20);
# CLUSTER 1597: trojan (1);
# CLUSTER 1598: downloader (1);
# CLUSTER 1599: trojan (3);
# CLUSTER 1600: trojan (1);
# CLUSTER 1601: trojan (1);
# CLUSTER 1602: _ (1);
# CLUSTER 1603: trojan (1);
# CLUSTER 1604: _ (2);
# CLUSTER 1605: trojan (1);
# CLUSTER 1606: trojan (5);
# CLUSTER 1607: trojan (1);
# CLUSTER 1608: trojan (2);
# CLUSTER 1609: trojan (1);
# CLUSTER 1610: trojan (1);
# CLUSTER 1611: adware (1);
# CLUSTER 1612: trojan (6);
# CLUSTER 1613: trojan (5);
# CLUSTER 1614: trojan (1);
# CLUSTER 1615: trojan (1);
# CLUSTER 1616: trojan (1);
# CLUSTER 1617: trojan (1);
# CLUSTER 1618: trojan (1);
# CLUSTER 1619: trojan (1);
# CLUSTER 1620: trojan (1);
# CLUSTER 1621: trojan (1);
# CLUSTER 1622: pua (1);
# CLUSTER 1623: _ (13); trojan (7);
# CLUSTER 1624: trojan (1);
# CLUSTER 1625: trojan (1);
# CLUSTER 1626: trojan (1);
# CLUSTER 1627: trojan (2);
# CLUSTER 1628: trojan (1);
# CLUSTER 1629: trojan (1);
# CLUSTER 1630: trojan (1);
# CLUSTER 1631: pua (4); trojan (3);
# CLUSTER 1632: trojan (2);
# CLUSTER 1633: trojan (1);
# CLUSTER 1634: trojan (1);
# CLUSTER 1635: trojan (3);
# CLUSTER 1636: _ (1);
# CLUSTER 1637: trojan (2); _ (1);
# CLUSTER 1638: trojan (1);
# CLUSTER 1639: trojan (3);
# CLUSTER 1640: trojan (1);
# CLUSTER 1641: trojan (1);
# CLUSTER 1642: trojan (4);
# CLUSTER 1643: trojan (2);
# CLUSTER 1644: trojan (1);
# CLUSTER 1645: _ (1);
# CLUSTER 1646: _ (6); trojan (2);
# CLUSTER 1647: trojan (1);
# CLUSTER 1648: trojan (3);
# CLUSTER 1649: trojan (1);
# CLUSTER 1650: trojan (1);
# CLUSTER 1651: trojan (1);
# CLUSTER 1652: trojan (4);
# CLUSTER 1653: trojan (1);
# ...
# CLUSTER 12015: trojan (1);
# CLUSTER 12016: _ (1);
# CLUSTER 12017: trojan (1);
# CLUSTER 12018: _ (1);
# CLUSTER 12019: trojan (1);
# CLUSTER 12020: trojan (1);
# CLUSTER 12021: trojan (1);
# CLUSTER 12022: trojan (1);
# CLUSTER 12023: trojan (1);
# CLUSTER 12024: trojan (1);
# CLUSTER 12025: trojan (1);
# CLUSTER 12026: trojan (1);
# CLUSTER 12027: trojan (1);
# CLUSTER 12028: _ (1);
# CLUSTER 12029: trojan (1);
# CLUSTER 12030: pua (1);
# CLUSTER 12031: trojan (1);
# CLUSTER 12032: trojan (1);
# CLUSTER 12033: trojan (1);
# CLUSTER 12034: adware (1);
# CLUSTER 12035: trojan (1);
# CLUSTER 12036: trojan (1);
# CLUSTER 12037: pua (1);
# CLUSTER 12038: trojan (1);
# CLUSTER 12039: trojan (1);
# CLUSTER 12040: trojan (1);
# CLUSTER 12041: trojan (1);
# CLUSTER 12042: trojan (1);
# CLUSTER 12043: trojan (1);
# CLUSTER 12044: trojan (1);
# CLUSTER 12045: trojan (1);
# CLUSTER 12046: adware (1);
# CLUSTER 12047: trojan (1);
# CLUSTER 12048: trojan (1);
# CLUSTER 12049: trojan (1);
# CLUSTER 12050: trojan (1);
# CLUSTER 12051: trojan (1);
# CLUSTER 12052: trojan (1);
# CLUSTER 12053: trojan (1);
# CLUSTER 12054: trojan (1);
# CLUSTER 12055: trojan (1);
# CLUSTER 12056: trojan (1);
# CLUSTER 12057: trojan (1);
# CLUSTER 12058: trojan (1);
# CLUSTER 12059: trojan (1);
# CLUSTER 12060: trojan (1);
# CLUSTER 12061: trojan (1);
# CLUSTER 12062: trojan (1);
# CLUSTER 12063: trojan (1);
# CLUSTER 12064: trojan (1);
# CLUSTER 12065: trojan (1);
# CLUSTER 12066: trojan (1);
# CLUSTER 12067: trojan (1);
# CLUSTER 12068: trojan (1);
# CLUSTER 12069: trojan (1);
# CLUSTER 12070: _ (1);
# CLUSTER 12071: trojan (1);
# CLUSTER 12072: trojan (1);
# CLUSTER 12073: trojan (1);
# CLUSTER 12074: trojan (1);
# CLUSTER 12075: adware (1);
# CLUSTER 12076: trojan (1);
# CLUSTER 12077: _ (1);
# CLUSTER 12078: trojan (1);
# CLUSTER 12079: trojan (1);
# CLUSTER 12080: pua (1);
# CLUSTER 12081: trojan (1);
# CLUSTER 12082: trojan (1);
# CLUSTER 12083: trojan (1);
# CLUSTER 12084: trojan (1);
# CLUSTER 12085: _ (1);
# CLUSTER 12086: trojan (1);
# CLUSTER 12087: ransomware (1);
# CLUSTER 12088: trojan (1);
# CLUSTER 12089: _ (1);
# CLUSTER 12090: trojan (1);
# CLUSTER 12091: trojan (1);
# CLUSTER 12092: _ (1);
# CLUSTER 12093: _ (1);
# CLUSTER 12094: trojan (1);
# CLUSTER 12095: trojan (1);
# CLUSTER 12096: trojan (1);
# CLUSTER 12097: trojan (1);
# CLUSTER 12098: trojan (1);
# CLUSTER 12099: trojan (1);
# CLUSTER 12100: trojan (1);
# CLUSTER 12101: trojan (1);
# CLUSTER 12102: trojan (1);
# CLUSTER 12103: adware (1);
# CLUSTER 12104: _ (1);
# CLUSTER 12105: trojan (1);
# CLUSTER 12106: _ (1);
# CLUSTER 12107: trojan (1);
# CLUSTER 12108: trojan (1);
# CLUSTER 12109: trojan (1);
# CLUSTER 12110: trojan (1);
# CLUSTER 12111: trojan (1);
# CLUSTER 12112: trojan (1);
# CLUSTER 12113: worm (1);
# CLUSTER 12114: _ (1);
# CLUSTER 12115: _ (1);
# CLUSTER 12116: trojan (1);
# CLUSTER 12117: trojan (1);
# CLUSTER 12118: trojan (1);
# CLUSTER 12119: trojan (1);
# CLUSTER 12120: trojan (1);
# CLUSTER 12121: pua (1);
# CLUSTER 12122: virus (1);
# CLUSTER 12123: trojan (1);
# CLUSTER 12124: _ (1);
# CLUSTER 12125: trojan (1);
# CLUSTER 12126: trojan (1);
# CLUSTER 12127: trojan (1);
# CLUSTER 12128: trojan (1);
# CLUSTER 12129: trojan (1);
# CLUSTER 12130: trojan (1);
# CLUSTER 12131: trojan (1);
# CLUSTER 12132: trojan (1);
# CLUSTER 12133: trojan (1);
# CLUSTER 12134: trojan (1);
# CLUSTER 12135: trojan (1);
# CLUSTER 12136: trojan (1);
# CLUSTER 12137: trojan (1);
# CLUSTER 12138: trojan (1);
# CLUSTER 12139: trojan (1);
# CLUSTER 12140: trojan (1);
# CLUSTER 12141: trojan (1);
# CLUSTER 12142: trojan (1);
# CLUSTER 12143: trojan (1);
# CLUSTER 12144: _ (1);
# CLUSTER 12145: _ (1);
# CLUSTER 12146: trojan (1);
# CLUSTER 12147: trojan (1);
# CLUSTER 12148: trojan (1);
# CLUSTER 12149: trojan (1);
# CLUSTER 12150: adware (1);
# CLUSTER 12151: trojan (1);
# CLUSTER 12152: trojan (1);
# CLUSTER 12153: trojan (1);
# CLUSTER 12154: trojan (1);
# CLUSTER 12155: trojan (1);
# CLUSTER 12156: trojan (1);
# CLUSTER 12157: trojan (1);
# CLUSTER 12158: trojan (1);
# CLUSTER 12159: trojan (1);
# CLUSTER 12160: trojan (1);
# CLUSTER 12161: trojan (1);
# CLUSTER 12162: trojan (1);
# CLUSTER 12163: trojan (1);
# CLUSTER 12164: trojan (1);
# CLUSTER 12165: virus (1);
# CLUSTER 12166: trojan (1);
# CLUSTER 12167: pua (1);
# CLUSTER 12168: trojan (1);
# CLUSTER 12169: adware (1);
# CLUSTER 12170: trojan (1);
# CLUSTER 12171: trojan (1);
# CLUSTER 12172: trojan (1);
# CLUSTER 12173: adware (1);
# CLUSTER 12174: trojan (1);
# CLUSTER 12175: trojan (1);
# CLUSTER 12176: trojan (1);
# CLUSTER 12177: trojan (1);
# CLUSTER 12178: trojan (1);
# CLUSTER 12179: trojan (1);
# CLUSTER 12180: trojan (1);
# CLUSTER 12181: trojan (1);
# CLUSTER 12182: trojan (1);
# CLUSTER 12183: trojan (1);
# CLUSTER 12184: trojan (1);
# CLUSTER 12185: _ (1);
# CLUSTER 12186: trojan (1);
# CLUSTER 12187: trojan (1);
# CLUSTER 12188: trojan (1);
# CLUSTER 12189: trojan (1);
# CLUSTER 12190: trojan (1);
# CLUSTER 12191: trojan (1);
# CLUSTER 12192: trojan (1);
# CLUSTER 12193: adware (1);
# CLUSTER 12194: trojan (1);
# CLUSTER 12195: trojan (1);
# CLUSTER 12196: trojan (1);
# CLUSTER 12197: trojan (1);
# CLUSTER 12198: trojan (1);
# CLUSTER 12199: trojan (1);
# CLUSTER 12200: trojan (1);
# CLUSTER 12201: _ (1);
# CLUSTER 12202: downloader (1);
# CLUSTER 12203: trojan (1);
# CLUSTER 12204: pua (1);
# CLUSTER 12205: trojan (1);
# CLUSTER 12206: trojan (1);
# CLUSTER 12207: _ (1);
# CLUSTER 12208: trojan (1);
# CLUSTER 12209: trojan (1);
# CLUSTER 12210: trojan (1);
# CLUSTER 12211: trojan (1);
# CLUSTER 12212: trojan (1);
# CLUSTER 12213: trojan (1);
# CLUSTER 12214: trojan (1);
# CLUSTER 12215: trojan (1);
# CLUSTER 12216: trojan (1);
# CLUSTER 12217: trojan (1);
# CLUSTER 12218: trojan (1);
# CLUSTER 12219: adware (1);
# CLUSTER 12220: trojan (1);
# CLUSTER 12221: trojan (1);
# CLUSTER 12222: trojan (1);
# CLUSTER 12223: trojan (1);
# CLUSTER 12224: trojan (1);
# CLUSTER 12225: trojan (1);
# CLUSTER 12226: adware (1);
# CLUSTER 12227: ransomware (1);
# CLUSTER 12228: trojan (1);
# CLUSTER 12229: trojan (1);
# CLUSTER 12230: trojan (1);
# CLUSTER 12231: trojan (1);
# CLUSTER 12232: trojan (1);
# CLUSTER 12233: trojan (1);
# CLUSTER 12234: trojan (1);
# CLUSTER 12235: trojan (1);
# CLUSTER 12236: trojan (1);
# CLUSTER 12237: trojan (1);
# CLUSTER 12238: _ (1);
# CLUSTER 12239: trojan (1);
# CLUSTER 12240: adware (1);
# CLUSTER 12241: trojan (1);
# CLUSTER 12242: trojan (1);
# CLUSTER 12243: trojan (1);
# CLUSTER 12244: trojan (1);
# CLUSTER 12245: trojan (1);
# CLUSTER 12246: trojan (1);
# CLUSTER 12247: trojan (1);
# CLUSTER 12248: trojan (1);
# CLUSTER 12249: trojan (1);
# CLUSTER 12250: trojan (1);
# CLUSTER 12251: trojan (1);
# CLUSTER 12252: adware (1);
# CLUSTER 12253: trojan (1);
# CLUSTER 12254: trojan (1);
# CLUSTER 12255: trojan (1);
# CLUSTER 12256: trojan (1);
# CLUSTER 12257: trojan (1);
# CLUSTER 12258: trojan (1);
# CLUSTER 12259: trojan (1);
# CLUSTER 12260: trojan (1);
# CLUSTER 12261: trojan (1);
# CLUSTER 12262: trojan (1);
# CLUSTER 12263: trojan (1);
# CLUSTER 12264: trojan (1);
# CLUSTER 12265: adware (1);
# CLUSTER 12266: _ (1);
# CLUSTER 12267: trojan (1);
# CLUSTER 12268: trojan (1);
# CLUSTER 12269: trojan (1);
# CLUSTER 12270: trojan (1);
# CLUSTER 12271: trojan (1);
# CLUSTER 12272: trojan (1);
# CLUSTER 12273: trojan (1);
# CLUSTER 12274: trojan (1);
# CLUSTER 12275: trojan (1);
# CLUSTER 12276: pua (1);
# CLUSTER 12277: adware (1);
# CLUSTER 12278: trojan (1);
# CLUSTER 12279: trojan (1);
# CLUSTER 12280: trojan (1);
# CLUSTER 12281: trojan (1);
# CLUSTER 12282: trojan (1);
# CLUSTER 12283: trojan (1);
# CLUSTER 12284: _ (1);
# CLUSTER 12285: trojan (1);
# CLUSTER 12286: trojan (1);
# CLUSTER 12287: trojan (1);
# CLUSTER 12288: trojan (1);
# CLUSTER 12289: adware (1);
# CLUSTER 12290: trojan (1);
# CLUSTER 12291: _ (1);
# CLUSTER 12292: trojan (1);
# CLUSTER 12293: trojan (1);
# CLUSTER 12294: trojan (1);
# CLUSTER 12295: trojan (1);
# CLUSTER 12296: _ (1);
# CLUSTER 12297: trojan (1);
# CLUSTER 12298: trojan (1);
# CLUSTER 12299: trojan (1);
# CLUSTER 12300: trojan (1);
# CLUSTER 12301: trojan (1);
# CLUSTER 12302: trojan (1);
# CLUSTER 12303: trojan (1);
# CLUSTER 12304: trojan (1);
# CLUSTER 12305: trojan (1);
# CLUSTER 12306: trojan (1);
# CLUSTER 12307: _ (1);
# CLUSTER 12308: _ (1);
# CLUSTER 12309: trojan (1);
# CLUSTER 12310: trojan (1);
# CLUSTER 12311: trojan (1);
# CLUSTER 12312: _ (1); trojan (1);
# CLUSTER 12313: trojan (1);
# CLUSTER 12314: trojan (2);
# CLUSTER 12315: trojan (1);
# CLUSTER 12316: trojan (1);
# CLUSTER 12317: _ (1);
# CLUSTER 12318: pua (1);
# CLUSTER 12319: trojan (1);
# CLUSTER 12320: trojan (1);
# CLUSTER 12321: trojan (1);
# CLUSTER 12322: adware (1);
# CLUSTER 12323: trojan (1);
# CLUSTER 12324: pua (1);
# CLUSTER 12325: trojan (1);
# CLUSTER 12326: trojan (1);
# CLUSTER 12327: trojan (1);
# CLUSTER 12328: trojan (1);
# CLUSTER 12329: _ (1);
# CLUSTER 12330: trojan (1);
# CLUSTER 12331: trojan (1);
# CLUSTER 12332: trojan (1);
# CLUSTER 12333: trojan (1);
# CLUSTER 12334: trojan (1);
# CLUSTER 12335: trojan (2);
# CLUSTER 12336: trojan (1);
# CLUSTER 12337: trojan (1);
# CLUSTER 12338: adware (1);
# CLUSTER 12339: trojan (1);
# CLUSTER 12340: trojan (1);
# CLUSTER 12341: trojan (1);
# CLUSTER 12342: trojan (1);
# CLUSTER 12343: trojan (1);
# CLUSTER 12344: trojan (1);
# CLUSTER 12345: _ (1);
# CLUSTER 12346: trojan (1);
# CLUSTER 12347: trojan (1);
# CLUSTER 12348: trojan (1);
# CLUSTER 12349: adware (1);
# CLUSTER 12350: trojan (1);
# CLUSTER 12351: trojan (1);
# CLUSTER 12352: trojan (1);
# CLUSTER 12353: trojan (1);
# CLUSTER 12354: _ (1);
# CLUSTER 12355: trojan (1);
# CLUSTER 12356: trojan (1);
# CLUSTER 12357: trojan (1);
# CLUSTER 12358: trojan (1);
# CLUSTER 12359: trojan (1);
# CLUSTER 12360: trojan (1);
# CLUSTER 12361: trojan (1);
# CLUSTER 12362: adware (1);
# CLUSTER 12363: trojan (1);
# CLUSTER 12364: _ (1);
# CLUSTER 12365: _ (1);
# CLUSTER 12366: trojan (1);
# CLUSTER 12367: _ (1);
# CLUSTER 12368: trojan (1);
# CLUSTER 12369: trojan (1);
# CLUSTER 12370: trojan (1);
# CLUSTER 12371: trojan (1);
# CLUSTER 12372: trojan (1);
# CLUSTER 12373: trojan (1);
# CLUSTER 12374: trojan (1);
# CLUSTER 12375: adware (1);
# CLUSTER 12376: _ (1);
# CLUSTER 12377: trojan (1);
# CLUSTER 12378: trojan (1);
# CLUSTER 12379: _ (1);
# CLUSTER 12380: trojan (1);
# CLUSTER 12381: trojan (1);
# CLUSTER 12382: trojan (1);
# CLUSTER 12383: trojan (1);
# CLUSTER 12384: _ (1);
# CLUSTER 12385: trojan (1);
# CLUSTER 12386: trojan (1);
# CLUSTER 12387: trojan (1);
# CLUSTER 12388: trojan (1);
# CLUSTER 12389: trojan (1);
# CLUSTER 12390: adware (1);
# CLUSTER 12391: trojan (1);
# CLUSTER 12392: trojan (1);
# CLUSTER 12393: trojan (1);
# CLUSTER 12394: trojan (1);
# CLUSTER 12395: trojan (1);
# CLUSTER 12396: trojan (1);
# CLUSTER 12397: trojan (1);
# CLUSTER 12398: trojan (1);
# CLUSTER 12399: trojan (1);
# CLUSTER 12400: trojan (1);
# CLUSTER 12401: _ (1);
# CLUSTER 12402: trojan (1);
# CLUSTER 12403: pua (1);
# CLUSTER 12404: _ (1);
# CLUSTER 12405: adware (1);
# CLUSTER 12406: trojan (1);
# CLUSTER 12407: _ (1);
# CLUSTER 12408: adware (1);
# CLUSTER 12409: trojan (1);
# CLUSTER 12410: trojan (1);
# CLUSTER 12411: trojan (1);
# CLUSTER 12412: trojan (1);
# CLUSTER 12413: trojan (1);
# CLUSTER 12414: _ (1);
# CLUSTER 12415: trojan (1);
# CLUSTER 12416: trojan (1);
# CLUSTER 12417: trojan (1);
# CLUSTER 12418: trojan (1);
# CLUSTER 12419: trojan (1);
# CLUSTER 12420: trojan (1);
# CLUSTER 12421: trojan (1);
# CLUSTER 12422: trojan (1);
# CLUSTER 12423: trojan (1);
# CLUSTER 12424: miner (1);
# CLUSTER 12425: _ (1);
# CLUSTER 12426: trojan (1);
# CLUSTER 12427: trojan (1);
# CLUSTER 12428: _ (1);
# CLUSTER 12429: trojan (1);
# CLUSTER 12430: trojan (1);
# CLUSTER 12431: trojan (1);
# CLUSTER 12432: trojan (1);
# CLUSTER 12433: trojan (1);
# CLUSTER 12434: trojan (1);
# CLUSTER 12435: trojan (1);
# CLUSTER 12436: trojan (1);
# CLUSTER 12437: pua (1);
# CLUSTER 12438: trojan (1);
# CLUSTER 12439: trojan (1);
# CLUSTER 12440: trojan (1);
# CLUSTER 12441: trojan (1);
# CLUSTER 12442: trojan (1);
# CLUSTER 12443: trojan (1);
# CLUSTER 12444: trojan (1);
# CLUSTER 12445: trojan (1);
# CLUSTER 12446: trojan (1);
# CLUSTER 12447: trojan (1);
# CLUSTER 12448: trojan (1);
# CLUSTER 12449: hacktool (1);
# CLUSTER 12450: trojan (1);
# CLUSTER 12451: trojan (1);
# CLUSTER 12452: trojan (1);
# CLUSTER 12453: trojan (1);
# CLUSTER 12454: trojan (1);
# CLUSTER 12455: trojan (1);
# CLUSTER 12456: trojan (1);
# CLUSTER 12457: trojan (1);
# CLUSTER 12458: trojan (1);
# CLUSTER 12459: trojan (1);
# CLUSTER 12460: trojan (1);
# CLUSTER 12461: trojan (1);
# CLUSTER 12462: trojan (1);
# CLUSTER 12463: trojan (1);
# CLUSTER 12464: trojan (1);
# CLUSTER 12465: trojan (1);
# CLUSTER 12466: trojan (1);
# CLUSTER 12467: trojan (1);
# CLUSTER 12468: trojan (1);
# CLUSTER 12469: trojan (1);
# CLUSTER 12470: trojan (1);
# CLUSTER 12471: trojan (1);
# CLUSTER 12472: pua (1);
# CLUSTER 12473: trojan (1);
# CLUSTER 12474: trojan (1);
# CLUSTER 12475: trojan (1);
# CLUSTER 12476: trojan (1);
# CLUSTER 12477: trojan (1);
# CLUSTER 12478: trojan (1);
# CLUSTER 12479: trojan (1);
# CLUSTER 12480: trojan (1);
# CLUSTER 12481: _ (1);
# CLUSTER 12482: trojan (1);
# CLUSTER 12483: trojan (1);
# CLUSTER 12484: virus (1);
# CLUSTER 12485: _ (1);
# CLUSTER 12486: trojan (1);
# CLUSTER 12487: trojan (1);
# CLUSTER 12488: trojan (1);
# CLUSTER 12489: _ (1);
# CLUSTER 12490: trojan (1);
# CLUSTER 12491: trojan (1);
# CLUSTER 12492: trojan (1);
# CLUSTER 12493: _ (1);
# CLUSTER 12494: pua (1);
# CLUSTER 12495: pua (1);
# CLUSTER 12496: _ (1);
# CLUSTER 12497: trojan (1);
# CLUSTER 12498: trojan (1);
# CLUSTER 12499: trojan (1);
# CLUSTER 12500: trojan (1);
# CLUSTER 12501: trojan (1);
# CLUSTER 12502: trojan (1);
# CLUSTER 12503: trojan (1);
# CLUSTER 12504: trojan (1);
# CLUSTER 12505: trojan (1);
# CLUSTER 12506: trojan (1);
# CLUSTER 12507: trojan (1);
# CLUSTER 12508: trojan (1);
# CLUSTER 12509: trojan (1);
# CLUSTER 12510: trojan (1);
# CLUSTER 12511: adware (1);
# CLUSTER 12512: trojan (1);
# CLUSTER 12513: trojan (1);
# CLUSTER 12514: trojan (1);
# CLUSTER 12515: trojan (1);
# CLUSTER 12516: _ (1);
# CLUSTER 12517: trojan (1);
# CLUSTER 12518: trojan (1);
# CLUSTER 12519: trojan (1);
# CLUSTER 12520: _ (1);
# CLUSTER 12521: trojan (1);
# CLUSTER 12522: trojan (1);
# CLUSTER 12523: trojan (1);
# CLUSTER 12524: adware (1);
# CLUSTER 12525: trojan (1);
# CLUSTER 12526: trojan (1);
# CLUSTER 12527: _ (1);
# CLUSTER 12528: trojan (1);
# CLUSTER 12529: trojan (1);
# CLUSTER 12530: pua (1);
# CLUSTER 12531: downloader (1);
# CLUSTER 12532: trojan (1);
# CLUSTER 12533: trojan (1);
# CLUSTER 12534: trojan (1);
# CLUSTER 12535: trojan (1);
# CLUSTER 12536: trojan (1);
# CLUSTER 12537: trojan (1);
# CLUSTER 12538: trojan (1);
# CLUSTER 12539: adware (1);
# CLUSTER 12540: trojan (1);
# CLUSTER 12541: trojan (1);
# CLUSTER 12542: trojan (1);
# CLUSTER 12543: trojan (1);
# CLUSTER 12544: trojan (1);
# CLUSTER 12545: trojan (1);
# CLUSTER 12546: trojan (1);
# CLUSTER 12547: trojan (1);
# CLUSTER 12548: trojan (1);
# CLUSTER 12549: trojan (1);
# CLUSTER 12550: trojan (1);
# CLUSTER 12551: trojan (1);
# CLUSTER 12552: trojan (1);
# CLUSTER 12553: adware (1);
# CLUSTER 12554: trojan (1);
# CLUSTER 12555: trojan (1);
# CLUSTER 12556: trojan (1);
# CLUSTER 12557: trojan (1);
# CLUSTER 12558: _ (1);
# CLUSTER 12559: trojan (1);
# CLUSTER 12560: trojan (1);
# CLUSTER 12561: trojan (1);
# CLUSTER 12562: trojan (1);
# CLUSTER 12563: _ (1);
# CLUSTER 12564: _ (1);
# CLUSTER 12565: trojan (1);
# CLUSTER 12566: _ (1);
# CLUSTER 12567: trojan (1);
# CLUSTER 12568: trojan (1);
# CLUSTER 12569: trojan (1);
# CLUSTER 12570: trojan (1);
# CLUSTER 12571: trojan (1);
# CLUSTER 12572: trojan (1);
# CLUSTER 12573: trojan (1);
# CLUSTER 12574: _ (1);
# CLUSTER 12575: trojan (1);
# CLUSTER 12576: trojan (1);
# CLUSTER 12577: adware (1);
# CLUSTER 12578: trojan (1);
# CLUSTER 12579: trojan (1);
# CLUSTER 12580: trojan (1);
# CLUSTER 12581: trojan (1);
# CLUSTER 12582: trojan (1);
# CLUSTER 12583: pua (1);
# CLUSTER 12584: pua (1);
# CLUSTER 12585: trojan (1);
# CLUSTER 12586: trojan (1);
# CLUSTER 12587: pua (1);
# CLUSTER 12588: trojan (1);
# CLUSTER 12589: trojan (1);
# CLUSTER 12590: trojan (1);
# CLUSTER 12591: trojan (1);
# CLUSTER 12592: trojan (1);
# CLUSTER 12593: trojan (1);
# CLUSTER 12594: trojan (1);
# CLUSTER 12595: trojan (1);
# CLUSTER 12596: trojan (1);

# %% [markdown]
# ### Identify the Clusters that have the same Unique Malware Type
#
# This indicates what clusters have verified malicious samples that match specific Malware Types.
#
# This indicates the most occuring Malware Type which extends to the most 'popular' malware type that is probably found in the dataset.
#
# Such findings may also be used as a reflection as to what malware types are most prevalent in the wild.

# %%
# Summarize Clusters that have the same malware types as per VirusTotal.
str_output = f"# of Unique Malware Type: {len(malicious_df['type'].unique())}" + "\n\n"

cluster_instance_summary = [0] * len(list(malicious_df['cluster'].unique()))
count_summary = []
for i, u in enumerate(list(malicious_df['type'].unique())):
    matching = malicious_df[malicious_df['type'] == u]['cluster']
    count_summary.append([u, len(list(matching)), len(list(matching.unique())) ,str(list(matching.unique()))])
    str_output += f"Unique Malware Type: {i+1}".upper() + "\n"
    str_output += f"Malware Type: {u}" + "\n"
    str_output += f"Matching Clusters Count: {len(list(matching.unique()))}" + "\n"
    str_output += f"Matching Clusters: {list(matching.unique())}" + "\n"
    str_output += "\n"
with open("./Output/1 Clusters_on_Unique_MalwareType.txt", 'w') as f:
    f.write(str_output)
    f.flush
    f.close()
print(str_output)

count_summary.sort(key=lambda x: x[1])
count_summary = pd.DataFrame(count_summary, columns=['Malware Type', 'No. of Matching Verified Samples', 'No. of Matching Clusters', "Matching Clusters"])

count_summary.sort_values(by='No. of Matching Clusters',ascending=False, inplace=True)
display("Top 10 Most Common Malware Type (by Cluster Count)")
display(count_summary[['Malware Type','No. of Matching Clusters', 'Matching Clusters']].iloc[0:10])
count_summary[['Malware Type','No. of Matching Clusters', 'Matching Clusters']].iloc[0:10].to_csv("./Output/1 10_Most_Common_MalwareType_byClusterCount.csv", index=False)
# Out:
# # of Unique Malware Type: 12
#
# UNIQUE MALWARE TYPE: 1
# Malware Type: trojan
# Matching Clusters Count: 10160
# Matching Clusters: [0, 2, 3, 4, 5, 11, 12, 13, 16, 17, 18, 19, 20, 21, 22, 24, 25, 26, 27, 30, 35, 36, 37, 38, 39, 40, 41, 42, 43, 29, 44, 46, 47, 49, 50, 51, 52, 53, 54, 55, 8, 56, 57, 59, 60, 61, 62, 63, 64, 66, 67, 68, 69, 70, 71, 72, 1, 74, 75, 76, 78, 79, 80, 81, 83, 84, 85, 86, 88, 89, 90, 91, 92, 94, 96, 58, 100, 102, 103, 104, 105, 106, 107, 108, 110, 111, 113, 114, 115, 117, 118, 119, 120, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 141, 142, 144, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 33, 160, 161, 163, 164, 165, 167, 168, 169, 171, 172, 174, 175, 176, 177, 178, 180, 181, 182, 183, 184, 185, 186, 97, 188, 189, 190, 192, 193, 194, 195, 197, 198, 199, 200, 202, 203, 205, 209, 210, 211, 213, 214, 215, 216, 217, 219, 220, 222, 223, 225, 226, 227, 230, 231, 233, 234, 236, 237, 238, 239, 240, 241, 242, 243, 245, 247, 248, 251, 252, 253, 255, 257, 258, 259, 261, 262, 263, 264, 265, 266, 268, 269, 270, 271, 272, 274, 276, 277, 280, 281, 282, 283, 284, 286, 287, 288, 289, 290, 291, 292, 294, 296, 297, 298, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 208, 317, 318, 273, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 337, 338, 339, 340, 341, 343, 344, 345, 348, 349, 351, 352, 353, 355, 356, 359, 360, 362, 23, 363, 364, 365, 366, 367, 368, 369, 370, 373, 374, 375, 376, 377, 378, 381, 382, 383, 385, 386, 387, 388, 389, 390, 391, 393, 394, 395, 396, 397, 398, 399, 400, 401, 406, 407, 408, 410, 411, 413, 414, 415, 416, 417, 418, 419, 420, 422, 424, 425, 426, 427, 428, 429, 430, 431, 404, 435, 436, 437, 438, 439, 440, 441, 442, 443, 444, 445, 446, 448, 450, 451, 452, 453, 454, 455, 456, 457, 458, 459, 460, 461, 463, 464, 465, 466, 467, 469, 470, 471, 472, 473, 475, 476, 478, 479, 480, 481, 482, 483, 484, 485, 486, 487, 488, 489, 490, 491, 492, 493, 494, 495, 496, 497, 498, 499, 502, 503, 504, 507, 508, 509, 510, 512, 513, 514, 515, 516, 518, 519, 520, 521, 522, 523, 524, 525, 526, 527, 529, 530, 531, 532, 533, 534, 535, 536, 537, 538, 539, 540, 541, 542, 544, 545, 546, 547, 548, 549, 550, 551, 552, 553, 554, 556, 557, 558, 559, 560, 561, 562, 563, 564, 566, 567, 568, 570, 571, 572, 573, 574, 576, 577, 578, 580, 581, 582, 584, 585, 586, 588, 589, 594, 596, 597, 598, 600, 601, 602, 603, 604, 605, 606, 607, 610, 611, 612, 614, 619, 620, 621, 622, 623, 624, 625, 626, 627, 628, 629, 630, 631, 632, 634, 635, 636, 638, 639, 640, 643, 644, 647, 648, 649, 650, 651, 652, 653, 654, 656, 657, 658, 661, 663, 664, 665, 666, 667, 668, 670, 671, 672, 673, 676, 677, 678, 679, 681, 683, 684, 686, 690, 693, 695, 697, 699, 700, 701, 704, 706, 707, 708, 709, 710, 711, 713, 715, 716, 717, 719, 720, 721, 722, 724, 725, 726, 727, 728, 729, 730, 731, 732, 733, 734, 735, 736, 737, 738, 739, 740, 742, 743, 744, 745, 746, 747, 748, 750, 752, 753, 754, 755, 757, 758, 759, 761, 762, 763, 764, 765, 767, 769, 770, 771, 772, 773, 774, 775, 776, 778, 779, 780, 781, 782, 783, 784, 785, 786, 787, 788, 791, 792, 793, 794, 295, 795, 796, 797, 798, 804, 806, 807, 808, 809, 811, 812, 813, 814, 815, 817, 819, 820, 822, 823, 824, 825, 828, 829, 830, 831, 833, 834, 835, 836, 837, 315, 840, 841, 842, 843, 844, 845, 846, 847, 848, 849, 850, 851, 852, 853, 855, 857, 858, 861, 864, 865, 866, 867, 868, 869, 870, 871, 872, 875, 876, 877, 878, 879, 880, 882, 883, 885, 886, 887, 888, 889, 890, 891, 892, 893, 894, 896, 897, 898, 900, 901, 903, 904, 906, 907, 908, 909, 912, 913, 914, 915, 916, 917, 919, 920, 921, 923, 924, 925, 926, 928, 929, 931, 932, 934, 935, 936, 937, 938, 939, 940, 942, 943, 944, 947, 948, 949, 950, 952, 953, 955, 956, 766, 957, 958, 960, 961, 962, 963, 964, 965, 969, 970, 971, 972, 973, 974, 976, 977, 978, 979, 980, 983, 985, 986, 987, 988, 989, 990, 992, 993, 994, 995, 997, 998, 999, 1000, 1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010, 1011, 1013, 1014, 1016, 1017, 1018, 1019, 1020, 1021, 1022, 1023, 1024, 951, 1027, 10 ...
#
# UNIQUE MALWARE TYPE: 2
# Malware Type: pua
# Matching Clusters Count: 784
# Matching Clusters: [1, 28, 31, 33, 48, 97, 98, 113, 159, 162, 29, 191, 228, 232, 235, 58, 244, 250, 273, 278, 299, 315, 316, 295, 336, 346, 142, 403, 412, 433, 501, 506, 9, 528, 543, 575, 579, 591, 599, 615, 655, 105, 562, 40, 685, 698, 756, 766, 587, 77, 789, 60, 802, 805, 816, 821, 856, 66, 881, 918, 954, 959, 981, 982, 991, 1037, 23, 1047, 1054, 786, 1118, 1167, 1178, 1198, 1220, 21, 1246, 1251, 1252, 1286, 1313, 1316, 1362, 1366, 1389, 1390, 1424, 1425, 1428, 1441, 1466, 1481, 1532, 1622, 1631, 1410, 76, 859, 628, 1756, 8, 1789, 1823, 1875, 1922, 2018, 2038, 2058, 2063, 420, 2101, 2114, 2155, 50, 282, 109, 2283, 2337, 2368, 2253, 2412, 2424, 2431, 2458, 2464, 986, 2476, 473, 2477, 2486, 2520, 2535, 2550, 2553, 2563, 2565, 63, 2610, 2659, 975, 2670, 2681, 2715, 2773, 2792, 2796, 379, 2840, 2858, 396, 2912, 593, 2995, 215, 10, 592, 2199, 188, 3091, 3097, 3103, 3106, 3121, 155, 3133, 45, 3153, 224, 3197, 3228, 3240, 3319, 3332, 3336, 3342, 3349, 3356, 880, 3409, 3425, 3431, 372, 3455, 404, 249, 3599, 3604, 3618, 3638, 3647, 2782, 3665, 3668, 3683, 3695, 3703, 2141, 3732, 2303, 3764, 331, 3795, 3798, 3805, 3808, 184, 3842, 3849, 3853, 119, 3885, 477, 3889, 3920, 3930, 3955, 3956, 3963, 3976, 3981, 4004, 1552, 4084, 4086, 4089, 4092, 4098, 2628, 158, 4118, 4138, 4141, 4146, 1153, 2850, 4200, 4291, 4301, 4305, 4310, 4336, 388, 2194, 4359, 4376, 864, 1696, 4435, 4439, 4505, 4517, 3582, 4529, 4532, 2743, 4553, 2811, 2877, 4588, 4606, 4640, 963, 4646, 4670, 4672, 800, 4709, 4712, 4721, 4735, 4786, 4800, 4725, 4852, 4943, 5001, 5007, 5036, 5045, 1860, 3018, 5194, 5196, 5230, 482, 5238, 5259, 688, 5295, 5309, 851, 5335, 2383, 3999, 1164, 5428, 5431, 5439, 5441, 5478, 5492, 3341, 5297, 5527, 5537, 5543, 5547, 5549, 5578, 5586, 4449, 1732, 5648, 5666, 5673, 5696, 5703, 843, 5799, 5801, 5811, 5832, 19, 5885, 5914, 5915, 5921, 5924, 4746, 5932, 5938, 5949, 1813, 5969, 260, 1341, 5988, 5991, 5992, 5764, 5999, 6004, 6008, 6020, 6048, 6063, 6072, 2364, 6087, 854, 6120, 780, 6144, 6151, 6177, 6187, 6214, 6239, 6263, 122, 6294, 6299, 3817, 6314, 6323, 5228, 6344, 6346, 6416, 6420, 6438, 6451, 6454, 13, 6488, 2953, 633, 674, 6500, 6508, 6511, 6517, 6525, 6535, 6540, 6555, 6570, 6575, 6576, 1872, 6614, 6631, 6658, 6663, 4275, 6725, 6738, 3675, 6793, 6796, 6799, 6812, 3744, 6839, 6858, 6868, 6883, 6925, 6927, 6938, 1380, 6962, 6964, 208, 6983, 6986, 7021, 7048, 7050, 7051, 7054, 7063, 7086, 5636, 2548, 7198, 7210, 7237, 7248, 7260, 7275, 7289, 6483, 7342, 238, 7375, 7410, 1025, 7433, 3763, 1878, 7501, 437, 7523, 7529, 6408, 7555, 7557, 7569, 7586, 7605, 7614, 7621, 7629, 7649, 7650, 1163, 7675, 7680, 7691, 7697, 7714, 7736, 616, 7749, 3074, 7775, 4587, 7794, 7796, 7799, 7804, 7839, 1257, 7857, 2862, 7910, 424, 7943, 3002, 896, 7984, 7985, 7986, 8004, 8025, 8054, 1509, 8085, 8087, 8105, 8107, 8109, 8112, 8116, 365, 8182, 8192, 8203, 8208, 8216, 8236, 8240, 8277, 8311, 8313, 8325, 56, 8336, 664, 8380, 8383, 8389, 8419, 8426, 2077, 8456, 8473, 8310, 8495, 8498, 8516, 8530, 8542, 8562, 4223, 8622, 8668, 8683, 4029, 8698, 5830, 8717, 8734, 8738, 8745, 5589, 8783, 8804, 8832, 8863, 8873, 8894, 8907, 8909, 8920, 7550, 8941, 8955, 8983, 8988, 8998, 9021, 9024, 9046, 9056, 9058, 9062, 9079, 9095, 4743, 9176, 3486, 9194, 9208, 9219, 9239, 9249, 9280, 8184, 9295, 9309, 9357, 9372, 9384, 9385, 9388, 2454, 192, 9418, 8948, 9428, 9435, 1265, 9460, 9498, 9525, 9526, 9532, 9542, 3301, 3522, 0, 9552, 27, 46, 24, 129, 9602, 141, 9615, 9622, 86, 9658, 200, 9670, 9687, 505, 9787, 9788, 8620, 9793, 9795, 5476, 9882, 8500, 9884, 9923, 9953, 9535, 9965, 9975, 9989, 9992, 9996, 10020, 10033, 10036, 10044, 10064, 10067, 10068, 10092, 10098, 10114, 10123, 2689, 10193, 10236, 10263, 262, 10281, 10282, 10285, 6598, 196, 10350, 10355, 2686, 10363, 10378, 10398, 354, 10414, 10419, 10424, 10453, 10495, 8950, 254, 10567, 4808, 4440, 10607, 10623, 10637, 5383, 10650, 10652, 279, 10677, 1211, 10696, 10719, 10724, 10728, 1374, 1155, 10737, 10757, 10758, 10772, 10819, 10837, 1355, ...
#
# UNIQUE MALWARE TYPE: 3
# Malware Type: downloader
# Matching Clusters Count: 117
# Matching Clusters: [6, 9, 29, 34, 23, 45, 73, 82, 109, 158, 218, 224, 246, 97, 295, 347, 357, 372, 380, 58, 103, 1, 113, 593, 682, 768, 803, 826, 911, 966, 50, 39, 105, 967, 968, 1042, 1091, 1109, 250, 587, 27, 1484, 1598, 1659, 1798, 473, 2295, 48, 2772, 420, 98, 10, 2843, 3063, 3074, 3744, 208, 4113, 4259, 331, 4426, 4528, 1399, 6079, 6105, 6110, 6115, 6141, 2636, 2194, 2384, 6408, 6497, 6913, 4092, 7136, 273, 7456, 7630, 7898, 8019, 8264, 8350, 8415, 8715, 1460, 215, 5996, 1410, 9555, 79, 9584, 620, 56, 19, 2428, 155, 1666, 128, 9626, 9630, 9631, 5156, 0, 2141, 9780, 9129, 10300, 11047, 11239, 11397, 11612, 1352, 11818, 12202, 12531, 119]
#
# UNIQUE MALWARE TYPE: 4
# Malware Type: adware
# Matching Clusters Count: 813
# Matching Clusters: [7, 8, 58, 93, 23, 112, 116, 143, 166, 170, 173, 179, 196, 218, 249, 267, 279, 293, 354, 295, 404, 208, 97, 421, 6, 434, 113, 98, 474, 587, 609, 613, 617, 645, 82, 669, 675, 692, 705, 714, 718, 66, 29, 760, 331, 0, 832, 860, 863, 24, 899, 905, 698, 1015, 1025, 1044, 1051, 1055, 1066, 1075, 19, 21, 1098, 1099, 1116, 60, 191, 1155, 1162, 1163, 379, 1236, 155, 444, 1275, 1283, 1291, 1302, 1318, 1321, 1341, 1343, 403, 1355, 1361, 1375, 1412, 1416, 477, 1131, 360, 1450, 1460, 1469, 315, 1486, 1514, 854, 1527, 1529, 1552, 1557, 9, 1572, 273, 1611, 1654, 1675, 1, 1693, 1716, 1720, 1729, 1733, 1752, 1757, 1772, 1780, 109, 468, 1846, 1850, 1869, 1874, 1880, 1882, 1888, 1901, 1907, 1912, 1918, 1934, 1984, 1985, 896, 2011, 2031, 2033, 2045, 10, 2048, 766, 2061, 2062, 396, 2089, 420, 786, 2109, 2110, 2129, 2158, 2161, 2233, 2249, 2254, 2263, 2303, 2410, 2418, 2443, 2472, 2517, 2528, 2534, 2566, 2571, 2585, 2598, 2605, 1885, 2635, 2643, 2646, 99, 1257, 48, 2700, 2701, 215, 2723, 2724, 2737, 2756, 2762, 212, 2782, 2811, 2821, 2828, 2875, 2884, 2885, 111, 864, 2931, 2935, 2941, 2942, 2063, 250, 2965, 473, 149, 3006, 3022, 3030, 3047, 2088, 188, 3086, 200, 3110, 3113, 1570, 3187, 3206, 1083, 3211, 3213, 3230, 518, 3239, 505, 3265, 3274, 3275, 3282, 13, 3341, 3347, 3348, 3355, 3374, 3383, 3391, 3398, 3407, 3422, 3440, 3442, 3459, 3469, 3484, 3486, 3507, 1732, 3524, 3551, 3577, 3580, 3588, 3595, 3616, 3620, 1222, 3633, 3635, 3643, 3685, 3737, 534, 3746, 3770, 388, 3782, 3829, 3836, 3843, 3848, 3854, 3859, 3864, 3879, 297, 3133, 3940, 3954, 680, 3974, 4009, 4011, 4041, 89, 4054, 171, 4057, 4062, 4081, 4102, 4132, 4216, 4229, 4233, 437, 4253, 4281, 4351, 282, 4407, 4412, 4434, 4440, 4487, 4490, 4501, 4523, 4544, 4547, 4572, 4579, 4583, 4587, 4603, 4620, 4674, 4697, 4731, 381, 4746, 4760, 664, 4796, 4811, 4829, 4856, 499, 4894, 4905, 3466, 4977, 4978, 4984, 4992, 56, 5048, 5056, 5068, 5070, 825, 46, 5128, 2339, 5217, 5220, 5221, 2431, 5264, 5275, 5302, 147, 5357, 72, 5389, 5421, 308, 5426, 5448, 5470, 5508, 5579, 4372, 5668, 5672, 5675, 5679, 1898, 5692, 5693, 5697, 5700, 5706, 2858, 2819, 5750, 5763, 5784, 4019, 3640, 5808, 1288, 5822, 5828, 5846, 5850, 5851, 5865, 5876, 5900, 5911, 666, 5923, 5933, 5954, 2383, 5986, 3210, 6068, 6077, 6080, 6113, 6121, 129, 6130, 5081, 6168, 6221, 6222, 1022, 6241, 6271, 517, 991, 2454, 6331, 6368, 3777, 6374, 6385, 6387, 6391, 1365, 6427, 6430, 6453, 582, 6516, 4247, 419, 6526, 633, 6531, 6533, 6541, 6563, 6569, 6599, 6601, 6004, 6611, 6626, 6650, 6673, 6698, 6707, 6408, 6752, 6769, 6819, 6851, 6863, 6865, 6900, 6909, 6940, 6945, 800, 6951, 4165, 6971, 7016, 7020, 7024, 7035, 7053, 30, 7071, 7073, 6087, 7089, 7105, 7141, 7147, 7194, 7223, 2077, 7239, 7241, 226, 7280, 7294, 7338, 7346, 7356, 7392, 335, 1860, 1666, 7472, 103, 7485, 712, 7566, 7600, 7693, 2344, 7716, 7737, 7748, 7753, 7759, 7764, 7772, 2686, 7825, 7863, 7883, 7893, 7896, 485, 7924, 7953, 7954, 3554, 7972, 3147, 7991, 4297, 7914, 8028, 8050, 8051, 8074, 8088, 8096, 8099, 3485, 2665, 8136, 8137, 8142, 8162, 237, 8170, 8174, 893, 8184, 8207, 8224, 8231, 141, 8280, 8307, 8321, 674, 8365, 8366, 8411, 6647, 8429, 1979, 8430, 8446, 532, 8488, 8500, 8503, 8512, 4779, 8525, 8549, 8569, 8573, 8580, 8588, 8610, 8648, 8658, 8721, 4171, 8808, 8838, 8843, 8858, 8883, 8893, 8898, 193, 8918, 8948, 8953, 8977, 8978, 9013, 4723, 758, 9094, 9097, 9135, 9146, 611, 9204, 9220, 9243, 3247, 9266, 9271, 9304, 9374, 986, 9421, 2584, 9502, 720, 9524, 1108, 9546, 185, 4769, 2970, 7104, 27, 9603, 39, 4449, 9646, 7867, 9675, 9682, 9722, 9744, 9766, 5615, 8285, 9786, 9789, 9812, 9820, 9827, 9834, 9839, 9845, 9859, 9898, 9913, 9952, 9969, 9983, 9987, 1698, 10029, 10077, 10079, 10081, 10104, 10129, 10132, 10157, 6346, 10160, 4980, 10175, 10177, 851, 10180, 8031, 10215, 10222, 10237, 562, 10301, 184, 1362, 10353, 9801, 10356, 10364, 10382, 10390, 259, 10401, 10473, 10489, 10511, 2213, 10525, 10541, 10598, 10599, 10631, 756, 10673, 10691, 2340, 55, 10755, 10762,  ...
#
# UNIQUE MALWARE TYPE: 5
# Malware Type: hacktool
# Matching Clusters Count: 7
# Matching Clusters: [10, 511, 1380, 1341, 8308, 12449, 11667]
#
# UNIQUE MALWARE TYPE: 6
# Malware Type: _
# Matching Clusters Count: 1317
# Matching Clusters: [14, 15, 23, 32, 65, 77, 99, 121, 140, 145, 157, 187, 113, 201, 206, 208, 212, 229, 97, 235, 254, 256, 260, 295, 342, 350, 358, 361, 379, 392, 402, 405, 50, 409, 423, 420, 432, 449, 462, 468, 477, 500, 505, 517, 555, 565, 569, 297, 583, 590, 592, 10, 595, 608, 616, 618, 633, 641, 642, 646, 528, 659, 404, 660, 662, 674, 680, 687, 688, 689, 691, 694, 696, 702, 703, 712, 723, 749, 751, 777, 790, 799, 800, 810, 818, 567, 827, 838, 839, 24, 854, 859, 862, 58, 873, 874, 884, 895, 902, 910, 922, 927, 930, 933, 941, 946, 951, 975, 984, 996, 1026, 1058, 1077, 1087, 1094, 1095, 1105, 1114, 331, 1139, 1144, 273, 1164, 1199, 1212, 1219, 1223, 1238, 1239, 864, 1263, 1265, 1287, 1298, 1299, 1304, 1309, 1325, 1326, 1328, 1335, 1336, 1337, 1352, 1360, 1368, 1378, 1386, 1401, 1408, 1421, 1445, 1457, 91, 155, 1488, 1500, 1504, 1518, 1530, 1553, 1554, 1564, 249, 1568, 1532, 1590, 1602, 1604, 1636, 388, 1645, 1667, 1671, 29, 1686, 1688, 1689, 698, 1695, 1710, 1711, 1718, 1724, 1725, 1759, 1763, 1770, 1781, 1791, 1818, 1833, 1837, 1847, 587, 1859, 1860, 1923, 1942, 1945, 1946, 1974, 1975, 108, 1977, 1118, 2009, 2015, 2026, 2076, 2082, 2122, 2133, 2143, 2147, 2181, 2201, 2206, 2219, 2231, 2239, 1341, 2252, 2260, 2264, 2271, 2275, 2282, 2289, 2292, 2310, 2312, 720, 2548, 2549, 2551, 2597, 2607, 2612, 2616, 2619, 2632, 1623, 2676, 2696, 2703, 2720, 2744, 2753, 2759, 2760, 2770, 2774, 2781, 2806, 1884, 1899, 2822, 2835, 2838, 2841, 2847, 2852, 2853, 2863, 2865, 932, 2868, 2870, 578, 2894, 2903, 2911, 2916, 2917, 2923, 2951, 2960, 2991, 2999, 2491, 3027, 3034, 3044, 3052, 3061, 103, 3064, 3088, 1646, 3115, 3139, 3143, 3156, 3159, 3168, 3175, 3178, 3181, 3198, 918, 3222, 3244, 3267, 3279, 3280, 3299, 3311, 3317, 3320, 3323, 3343, 3360, 3375, 3378, 3392, 3416, 3418, 3419, 3432, 3435, 3452, 3453, 3463, 3479, 3494, 3498, 3512, 3520, 3526, 3541, 3542, 3549, 3553, 3559, 3565, 3571, 3572, 3586, 3591, 3593, 3607, 3613, 3617, 2140, 3623, 3636, 3637, 2303, 3652, 3660, 3663, 3672, 3675, 3692, 3706, 3708, 3008, 3722, 3724, 3774, 3800, 3809, 3810, 3813, 3674, 3840, 3850, 3472, 3876, 3880, 3881, 3886, 3913, 3948, 3958, 3994, 3999, 4002, 4005, 4034, 4037, 4038, 518, 4047, 4051, 4052, 4055, 4067, 4077, 4116, 648, 4135, 4137, 4151, 4157, 4162, 4176, 4177, 4185, 4201, 2448, 4205, 4234, 4238, 4255, 4258, 1484, 4125, 4269, 4294, 4296, 4304, 4315, 4319, 4321, 4332, 4333, 4334, 4350, 2355, 4387, 4397, 4406, 4409, 194, 4483, 4486, 4499, 4500, 4502, 4504, 4506, 4511, 4515, 4521, 4522, 4536, 3957, 4545, 4558, 4560, 4567, 4570, 4576, 4593, 4596, 4601, 4612, 4617, 4664, 4668, 4703, 4705, 4716, 4718, 4736, 4738, 4739, 4747, 4752, 4764, 4767, 4768, 4774, 4781, 4785, 4803, 4806, 4810, 4812, 4825, 4833, 4835, 4839, 4845, 4867, 473, 4877, 4891, 4901, 4906, 4927, 98, 4934, 4953, 4979, 4988, 5006, 5008, 5011, 5031, 708, 5089, 5098, 5105, 5108, 5113, 5121, 2431, 5140, 5147, 5152, 5154, 5157, 5160, 5161, 5167, 5182, 5202, 5229, 5231, 5233, 5236, 3018, 5260, 5263, 5267, 5270, 5289, 5290, 5292, 3973, 5296, 5297, 5311, 5312, 5313, 2636, 5332, 5350, 5358, 5359, 5392, 5424, 5433, 5443, 5458, 5477, 5483, 5501, 5518, 5525, 5556, 5559, 5562, 5565, 5573, 5574, 5581, 5589, 5592, 5593, 5619, 5624, 5626, 5628, 5639, 5645, 5646, 5651, 5654, 5665, 5667, 5677, 5682, 5683, 5685, 5702, 5715, 5725, 5729, 5738, 5755, 5758, 83, 5778, 5795, 5819, 5826, 5854, 5868, 5873, 5882, 5889, 5892, 5910, 5918, 5939, 5950, 5972, 5974, 5975, 5993, 6003, 6016, 6017, 6059, 6070, 3606, 6082, 6086, 6093, 6104, 6106, 4442, 4098, 4482, 6201, 6207, 6216, 6237, 6249, 6276, 6332, 6335, 6341, 6351, 6365, 6366, 6392, 3448, 6398, 6419, 6423, 6431, 6432, 6437, 6456, 6460, 6462, 6487, 6491, 6494, 6498, 6505, 6507, 6513, 6519, 2187, 6529, 6538, 6546, 6556, 6559, 6564, 6580, 6585, 6605, 6608, 1113, 6622, 6637, 6660, 6662, 6670, 6687, 6702, 6708, 6716, 6717, 6733, 6737, 6739, 6743, 6759, 6760, 6766, 6770, 6773, 6774, 6783, 6786, 6807, 6826, 6828, 6836, 6838, 6072, 6873, 6875, 6879, 6884, 6899, 6903, 6910, 6914, 6915, 6 ...
#
# UNIQUE MALWARE TYPE: 7
# Malware Type: miner
# Matching Clusters Count: 79
# Matching Clusters: [87, 221, 275, 285, 945, 108, 50, 1714, 2005, 2013, 2017, 2056, 254, 2285, 2499, 1489, 2641, 2981, 3076, 3256, 3266, 3451, 3471, 3519, 1118, 3702, 2282, 3846, 3952, 4008, 4020, 4140, 4169, 4187, 208, 4392, 2342, 4633, 4726, 2703, 2264, 99, 113, 648, 5841, 5848, 6024, 6027, 2686, 6446, 6941, 7143, 7599, 7903, 7960, 8367, 8408, 388, 8772, 8778, 8850, 8899, 3004, 9292, 9339, 9462, 9815, 9856, 9914, 5868, 420, 5475, 10, 10986, 11102, 9992, 11575, 11784, 12424]
#
# UNIQUE MALWARE TYPE: 8
# Malware Type: virus
# Matching Clusters Count: 69
# Matching Clusters: [95, 371, 447, 637, 6, 801, 1012, 1195, 1247, 1262, 1944, 2593, 10, 3017, 475, 3444, 3472, 404, 3674, 4003, 4100, 4160, 4270, 4353, 97, 201, 5709, 5827, 5984, 6122, 6319, 7265, 7635, 8154, 8235, 8250, 8278, 8405, 8484, 8510, 1336, 8728, 8757, 9298, 9393, 9415, 9814, 9823, 9857, 9910, 9941, 10333, 10456, 10635, 10908, 10915, 10988, 11172, 11205, 11361, 11402, 11455, 11652, 8833, 273, 2951, 12122, 12165, 12484]
#
# UNIQUE MALWARE TYPE: 9
# Malware Type: spyware
# Matching Clusters Count: 15
# Matching Clusters: [101, 0, 24, 210, 653, 3649, 3996, 1715, 5030, 5123, 6440, 7076, 2171, 8180, 3448]
#
# UNIQUE MALWARE TYPE: 10
# Malware Type: ransomware
# Matching Clusters Count: 38
# Matching Clusters: [204, 207, 197, 384, 741, 1677, 1753, 1857, 1866, 3010, 3036, 1125, 3791, 4115, 4283, 4463, 5345, 5831, 6011, 6441, 6632, 208, 7200, 7253, 7686, 8040, 604, 2554, 9, 9663, 6558, 10331, 10881, 11158, 11861, 11911, 12087, 12227]
#
# UNIQUE MALWARE TYPE: 11
# Malware Type: dropper
# Matching Clusters Count: 4
# Matching Clusters: [302, 23, 2199, 9358]
#
# UNIQUE MALWARE TYPE: 12
# Malware Type: worm
# Matching Clusters Count: 3
# Matching Clusters: [6936, 11160, 12113]
# 'Top 10 Most Common Malware Type (by Cluster Count)'
#    Malware Type  No. of Matching Clusters  \
# 11       trojan                     10160
# 10            _                      1317
# 7        adware                       813
# 8           pua                       784
# 9    downloader                       117
# 5         miner                        79
# 4         virus                        69
# 6    ransomware                        38
# 3       spyware                        15
# 2      hacktool                         7
#
#                                     Matching Clusters
# 11  [0, 2, 3, 4, 5, 11, 12, 13, 16, 17, 18, 19, 20...
# 10  [14, 15, 23, 32, 65, 77, 99, 121, 140, 145, 15...
# 7   [7, 8, 58, 93, 23, 112, 116, 143, 166, 170, 17...
# 8   [1, 28, 31, 33, 48, 97, 98, 113, 159, 162, 29,...
# 9   [6, 9, 29, 34, 23, 45, 73, 82, 109, 158, 218, ...
# 5   [87, 221, 275, 285, 945, 108, 50, 1714, 2005, ...
# 4   [95, 371, 447, 637, 6, 801, 1012, 1195, 1247, ...
# 6   [204, 207, 197, 384, 741, 1677, 1753, 1857, 18...
# 3   [101, 0, 24, 210, 653, 3649, 3996, 1715, 5030,...
# 2           [10, 511, 1380, 1341, 8308, 12449, 11667]

# %% [markdown]
# ## "What the API Calls are in each Malware Type"

# %%
malware_types = count_summary['Malware Type'].to_list()
malware_apis = []

pd.set_option("display.max_rows", None)

print("Top 10 API CALLS PER MALWARE TYPE")
for m in malware_types:
    hashes = malicious_df[malicious_df['type'] == m]['hash'].to_list()
    complete = []
    for h in hashes:
        complete += oliveira[oliveira['hash']==h].iloc[0,1:101].to_list()
    ser = pd.Series(complete, name=m)
    ser.value_counts().to_csv(f"./Output/1_APICALL_{m}.csv")
    malware_apis.append(ser.unique().tolist())
    display(ser.value_counts())
# Out:
# Top 10 API CALLS PER MALWARE TYPE
# trojan
# LdrGetProcedureAddress               548127
# LdrLoadDll                           326998
# LdrGetDllHandle                      216319
# RegOpenKeyExW                        205692
# LoadResource                         171409
# FindResourceExW                      167824
# NtClose                              161696
# RegQueryValueExW                     145930
# RegCloseKey                          134071
# NtAllocateVirtualMemory              125861
# NtQueryValueKey                       80045
# NtOpenKey                             78843
# GetSystemMetrics                      71530
# GetSystemTimeAsFileTime               61271
# SetErrorMode                          35725
# GetSystemInfo                         32018
# NtProtectVirtualMemory                27825
# NtDelayExecution                      26882
# RegQueryInfoKeyW                      25593
# NtCreateFile                          23976
# DrawTextExW                           23272
# LoadStringW                           22690
# NtFreeVirtualMemory                   22664
# RegOpenKeyExA                         22177
# CoInitializeEx                        20340
# FindFirstFileExW                      20267
# SetUnhandledExceptionFilter           20140
# LoadStringA                           19690
# GetSystemWindowsDirectoryW            19547
# GetSystemDirectoryW                   18768
# EnumWindows                           17530
# NtOpenKeyEx                           17338
# NtMapViewOfSection                    17329
# RegEnumKeyW                           16783
# RegEnumKeyExW                         15044
# NtReadFile                            14480
# CoCreateInstance                      14146
# SetFilePointer                        14017
# GetFileSize                           13816
# NtCreateSection                       13333
# CreateThread                          12342
# SizeofResource                        12148
# GetFileAttributesW                    11295
# LookupAccountSidW                     10840
# CryptAcquireContextW                  10723
# CreateActCtxW                         10395
# OleInitialize                          9661
# NtQuerySystemInformation               9341
# NtDuplicateObject                      9303
# RegCreateKeyExW                        9107
# RegSetValueExW                         9027
# GetNativeSystemInfo                    8543
# RegQueryValueExA                       7850
# FindResourceW                          7819
# UuidCreate                             7656
# CryptCreateHash                        7428
# CryptHashData                          7427
# NtCreateMutant                         6527
# FindResourceA                          5988
# NtQueryAttributesFile                  5896
# GetCursorPos                           5718
# RegEnumValueW                          5718
# GetFileType                            5620
# NtDeviceIoControlFile                  5523
# WSAStartup                             5047
# __exception__                          4965
# NtUnmapViewOfSection                   4951
# NtOpenDirectoryObject                  4829
# GetTimeZoneInformation                 4488
# NtQueryDirectoryFile                   4221
# LdrUnloadDll                           3793
# NtOpenFile                             3505
# NtQueryInformationFile                 2919
# GetSystemDirectoryA                    2798
# CryptDecrypt                           2564
# GetUserNameW                           2430
# NtCreateThreadEx                       2190
# NtOpenSection                          2169
# IsDebuggerPresent                      2094
# NtWriteFile                            2086
# NtResumeThread                         2048
# GetTempPathW                           2016
# NtEnumerateValueKey                    1968
# NtEnumerateKey                         1880
# SearchPathW                            1871
# SetWindowsHookExA                      1833
# NtSetInformationFile                   1693
# FindResourceExA                        1567
# NtOpenProcess                          1434
# GlobalMemoryStatus                     1321
# GetVolumeNameForVolumeMountPointW      1281
# GetFileVersionInfoSizeW                1188
# GetForegroundWindow                    1154
# timeGetTime                            1144
# GetFileVersionInfoW                    1014
# NtQueryKey                             1012
# Process32NextW                          981
# GetFileInformationByHandle              963
# CreateToolhelp32Snapshot                923
# NtOpenMutant                            906
# Process32FirstW                         805
# ReadProcessMemory                       766
# SetEndOfFile                            734
# RegCreateKeyExA                         690
# CreateDirectoryW                        689
# GlobalMemoryStatusEx                    614
# LookupPrivilegeValueW                   603
# SHGetFolderPathW                        593
# NtOpenThread                            485
# RegEnumKeyExA                           472
# SetFilePointerEx                        427
# FindWindowW                             403
# RegSetValueExA                          399
# NtCreateKey                             372
# FindWindowA                             351
# CreateProcessInternalW                  345
# OutputDebugStringA                      343
# socket                                  326
# CreateJobObjectW                        305
# MoveFileWithProgressW                   296
# OpenSCManagerA                          285
# DeleteFileW                             283
# SetFileAttributesW                      280
# WriteProcessMemory                      277
# GetFileSizeEx                           272
# WriteConsoleA                           271
# InternetOpenA                           250
# GetShortPathNameW                       248
# GetDiskFreeSpaceW                       227
# SetFileTime                             226
# CryptEncrypt                            224
# CopyFileW                               219
# InternetSetOptionA                      215
# OpenServiceA                            212
# GetFileAttributesExW                    206
# InternetConnectA                        194
# connect                                 190
# HttpOpenRequestA                        187
# gethostbyname                           184
# NtSetValueKey                           181
# CopyFileExW                             180
# GetDiskFreeSpaceExW                     158
# CopyFileA                               152
# GetVolumePathNamesForVolumeNameW        151
# GetComputerNameW                        151
# OpenSCManagerW                          150
# DeviceIoControl                         139
# select                                  134
# GetUserNameA                            130
# FindWindowExW                           124
# GetComputerNameA                        123
# NtTerminateProcess                      123
# SetWindowsHookExW                       114
# FindWindowExA                           111
# OpenServiceW                            109
# closesocket                             102
# CoUninitialize                          100
# RemoveDirectoryW                         88
# NtSetContextThread                       82
# getaddrinfo                              82
# recv                                     77
# GetSystemWindowsDirectoryA               71
# send                                     70
# RegEnumValueA                            68
# SetStdHandle                             68
# GetAsyncKeyState                         66
# CryptAcquireContextA                     66
# CoGetClassObject                         63
# Thread32Next                             63
# Thread32First                            62
# GetAdaptersInfo                          61
# GetKeyState                              61
# RemoveDirectoryA                         61
# IWbemServices_ExecQuery                  58
# InternetCrackUrlA                        54
# CoInitializeSecurity                     51
# NtGetContextThread                       50
# bind                                     43
# StartServiceA                            41
# NtQueueApcThread                         37
# CreateServiceA                           35
# CoCreateInstanceEx                       34
# DrawTextExA                              34
# GetAdaptersAddresses                     34
# NtSuspendThread                          31
# CryptProtectData                         30
# ShellExecuteExW                          27
# getsockname                              27
# ioctlsocket                              26
# GetVolumePathNameW                       25
# InternetCloseHandle                      25
# GetBestInterfaceEx                       24
# SHGetSpecialFolderLocation               23
# setsockopt                               22
# MessageBoxTimeoutA                       22
# InternetOpenW                            22
# RtlAddVectoredExceptionHandler           21
# RtlDecompressBuffer                      18
# UnhookWindowsHookEx                      16
# Module32FirstW                           16
# Module32NextW                            15
# RegisterHotKey                           15
# HttpSendRequestA                         15
# StartServiceW                            14
# NtWriteVirtualMemory                     10
# DnsQuery_A                                9
# InternetOpenUrlA                          9
# WSARecv                                   9
# CreateServiceW                            9
# InternetConnectW                          8
# HttpOpenRequestW                          8
# CryptGenKey                               6
# InternetCrackUrlW                         6
# DeleteUrlCacheEntryA                      6
# RegDeleteValueA                           4
# InternetGetConnectedState                 4
# GetUserNameExA                            3
# GetKeyboardState                          3
# NtReadVirtualMemory                       3
# InternetQueryOptionA                      3
# DeleteUrlCacheEntryW                      2
# CryptExportKey                            2
# HttpQueryInfoA                            2
# InternetReadFile                          2
# shutdown                                  2
# RtlRemoveVectoredExceptionHandler         2
# CryptDecodeObjectEx                       2
# NtTerminateThread                         2
# RegDeleteKeyW                             2
# GetAddrInfoW                              2
# MessageBoxTimeoutW                        2
# EnumServicesStatusA                       2
# CreateRemoteThread                        2
# sendto                                    1
# InternetOpenUrlW                          1
# WSASocketA                                1
# SetInformationJobObject                   1
# WSASocketW                                1
# SendNotifyMessageW                        1
# ControlService                            1
# RegQueryInfoKeyA                          1
# ObtainUserAgentString                     1
# InternetSetStatusCallback                 1
# GetFileInformationByHandleEx              1
# SetFileInformationByHandle                1
# NetUserGetInfo                            1
# Name: count, dtype: int64
# _
# LdrGetProcedureAddress               38400
# LdrLoadDll                           18983
# NtClose                              18471
# LdrGetDllHandle                      17631
# RegOpenKeyExW                        16874
# RegCloseKey                          16372
# NtAllocateVirtualMemory              12132
# RegQueryValueExW                     12043
# NtReadFile                            6760
# NtOpenKey                             6235
# SetFilePointer                        6146
# NtQueryValueKey                       6042
# LoadResource                          5351
# NtCreateFile                          5196
# FindResourceExW                       4539
# GetSystemMetrics                      4539
# NtMapViewOfSection                    4225
# NtFreeVirtualMemory                   4001
# SetErrorMode                          3829
# GetSystemWindowsDirectoryW            3648
# NtCreateSection                       2833
# GetSystemDirectoryW                   2828
# RegOpenKeyExA                         2792
# FindFirstFileExW                      1921
# GetSystemTimeAsFileTime               1824
# GetFileAttributesW                    1517
# GetSystemInfo                         1491
# NtWriteFile                           1286
# NtQueryAttributesFile                 1267
# OleInitialize                         1208
# CreateActCtxW                         1207
# DrawTextExW                           1146
# NtProtectVirtualMemory                1139
# GetFileSize                           1129
# RegEnumKeyW                           1124
# NtDuplicateObject                     1084
# LoadStringA                           1026
# RegQueryValueExA                      1012
# SizeofResource                        1003
# LoadStringW                            998
# NtCreateMutant                         942
# SetUnhandledExceptionFilter            926
# NtOpenSection                          888
# NtOpenFile                             867
# FindResourceA                          786
# GetVolumeNameForVolumeMountPointW      760
# CreateDirectoryW                       709
# GetSystemDirectoryA                    649
# NtOpenKeyEx                            606
# IsDebuggerPresent                      605
# FindResourceW                          596
# CoInitializeEx                         582
# LdrUnloadDll                           560
# RegQueryInfoKeyW                       529
# GetNativeSystemInfo                    511
# NtQuerySystemInformation               499
# LookupAccountSidW                      466
# GetFileType                            466
# GetTempPathW                           464
# NtOpenMutant                           438
# NtUnmapViewOfSection                   428
# GetForegroundWindow                    427
# NtQueryDirectoryFile                   409
# CreateThread                           372
# DeleteFileW                            290
# NtDelayExecution                       265
# FindResourceExA                        265
# RegCreateKeyExW                        262
# NtOpenProcess                          261
# CreateProcessInternalW                 245
# SetEndOfFile                           240
# RegEnumValueW                          234
# SHGetFolderPathW                       232
# NtQueryInformationFile                 222
# ReadProcessMemory                      220
# CoCreateInstance                       219
# RegSetValueExW                         204
# SetWindowsHookExA                      201
# SetFilePointerEx                       196
# NtOpenDirectoryObject                  196
# __exception__                          187
# UuidCreate                             187
# RemoveDirectoryA                       157
# GetCursorPos                           149
# NtResumeThread                         144
# GetFileVersionInfoSizeW                141
# GetFileVersionInfoW                    133
# GetShortPathNameW                      122
# RegEnumKeyExW                          119
# RegCreateKeyExA                        117
# NtSetInformationFile                   116
# NtQueryKey                             111
# GetTimeZoneInformation                 111
# SearchPathW                            108
# FindWindowA                            101
# GlobalMemoryStatusEx                    96
# CoUninitialize                          94
# SetFileTime                             85
# WSAStartup                              82
# NtSuspendThread                         82
# SetFileAttributesW                      79
# FindWindowExA                           73
# RegSetValueExA                          69
# NtTerminateProcess                      67
# OutputDebugStringA                      64
# Process32NextW                          57
# NtEnumerateValueKey                     56
# SetWindowsHookExW                       55
# OpenServiceA                            54
# NtEnumerateKey                          54
# WriteProcessMemory                      53
# timeGetTime                             52
# EnumWindows                             52
# WriteConsoleA                           46
# NtCreateThreadEx                        44
# GetDiskFreeSpaceW                       43
# CreateToolhelp32Snapshot                41
# CryptAcquireContextW                    41
# DeviceIoControl                         39
# Process32FirstW                         37
# RegEnumKeyExA                           33
# GlobalMemoryStatus                      33
# GetFileAttributesExW                    31
# CoGetClassObject                        30
# NtGetContextThread                      30
# GetVolumePathNamesForVolumeNameW        29
# NtOpenThread                            28
# RemoveDirectoryW                        26
# GetDiskFreeSpaceExW                     26
# GetFileSizeEx                           23
# OpenSCManagerA                          23
# CoInitializeSecurity                    21
# NtDeviceIoControlFile                   20
# MessageBoxTimeoutA                      20
# FindWindowW                             19
# DrawTextExA                             18
# LookupPrivilegeValueW                   17
# GetFileInformationByHandle              17
# GetAsyncKeyState                        16
# GetAdaptersInfo                         16
# MessageBoxTimeoutW                      13
# Thread32Next                            13
# InternetConnectW                        12
# InternetOpenW                           12
# HttpOpenRequestW                        12
# socket                                  10
# GetKeyState                             10
# GetComputerNameW                         9
# GetSystemWindowsDirectoryA               9
# UnhookWindowsHookEx                      9
# InternetOpenA                            9
# CoCreateInstanceEx                       8
# select                                   8
# InternetConnectA                         8
# getaddrinfo                              8
# CopyFileW                                8
# SHGetSpecialFolderLocation               7
# RegDeleteValueA                          7
# CryptAcquireContextA                     7
# RegEnumValueA                            6
# Module32NextW                            6
# GetUserNameA                             6
# closesocket                              6
# IWbemServices_ExecQuery                  6
# RtlAddVectoredExceptionHandler           6
# InternetQueryOptionA                     5
# connect                                  5
# CryptCreateHash                          5
# CryptHashData                            5
# setsockopt                               4
# NtCreateKey                              4
# OpenSCManagerW                           4
# InternetGetConnectedState                4
# ioctlsocket                              4
# bind                                     4
# InternetCrackUrlA                        4
# getsockname                              4
# GetUserNameW                             3
# InternetCrackUrlW                        3
# EnumServicesStatusA                      3
# HttpOpenRequestA                         3
# FindWindowExW                            3
# CryptDecrypt                             3
# GetComputerNameA                         2
# Module32FirstW                           2
# recv                                     2
# GetAdaptersAddresses                     2
# CopyFileA                                2
# ShellExecuteExW                          2
# HttpQueryInfoA                           2
# OpenServiceW                             2
# RegDeleteValueW                          2
# InternetSetStatusCallback                1
# RegQueryInfoKeyA                         1
# NtQueryFullAttributesFile                1
# send                                     1
# gethostbyname                            1
# NetUserGetLocalGroups                    1
# CertOpenSystemStoreW                     1
# ObtainUserAgentString                    1
# CryptDecodeObjectEx                      1
# Thread32First                            1
# GetBestInterfaceEx                       1
# RegDeleteKeyW                            1
# NtDeleteKey                              1
# InternetCloseHandle                      1
# Name: count, dtype: int64
# adware
# LdrGetProcedureAddress               29719
# LdrLoadDll                           17137
# LdrGetDllHandle                      14452
# RegOpenKeyExW                        11124
# NtClose                              10646
# RegCloseKey                           9368
# RegQueryValueExW                      8256
# NtAllocateVirtualMemory               7791
# SetErrorMode                          4955
# NtOpenKey                             4454
# NtQueryValueKey                       4126
# GetSystemTimeAsFileTime               3230
# NtCreateFile                          2799
# GetSystemWindowsDirectoryW            2343
# GetSystemDirectoryW                   2231
# LoadResource                          2049
# NtMapViewOfSection                    2048
# NtReadFile                            1879
# GetSystemMetrics                      1841
# NtFreeVirtualMemory                   1784
# RegOpenKeyExA                         1747
# NtCreateSection                       1547
# SetFilePointer                        1525
# FindResourceExW                       1516
# NtDelayExecution                      1475
# SetUnhandledExceptionFilter           1452
# GetSystemInfo                         1395
# NtProtectVirtualMemory                1380
# CoInitializeEx                        1104
# LoadStringW                           1065
# RegEnumKeyW                            941
# GetFileSize                            859
# NtQueryAttributesFile                  850
# NtCreateMutant                         831
# SizeofResource                         802
# NtDuplicateObject                      778
# CreateThread                           762
# RegQueryValueExA                       710
# CoCreateInstance                       692
# FindResourceW                          686
# EnumWindows                            671
# GetFileAttributesW                     620
# RegCreateKeyExW                        600
# NtOpenFile                             561
# GetNativeSystemInfo                    557
# RegQueryInfoKeyW                       546
# CreateActCtxW                          542
# RegSetValueExW                         515
# RegEnumKeyExW                          458
# DrawTextExW                            453
# OleInitialize                          433
# UuidCreate                             426
# WSAStartup                             418
# CryptAcquireContextW                   393
# SHGetFolderPathW                       389
# RegSetValueExA                         381
# NtOpenKeyEx                            373
# RegCreateKeyExA                        360
# NtOpenSection                          300
# CryptHashData                          269
# CryptCreateHash                        269
# socket                                 262
# GetVolumeNameForVolumeMountPointW      246
# LoadStringA                            233
# Process32NextW                         225
# CreateToolhelp32Snapshot               223
# Process32FirstW                        223
# select                                 213
# FindFirstFileExW                       212
# NtOpenDirectoryObject                  199
# FindResourceA                          197
# ioctlsocket                            197
# NtQuerySystemInformation               193
# connect                                192
# NtQueryInformationFile                 179
# NtResumeThread                         173
# GetSystemDirectoryA                    171
# GetFileType                            171
# NtWriteFile                            171
# IsDebuggerPresent                      164
# GetTimeZoneInformation                 163
# LookupAccountSidW                      150
# LdrUnloadDll                           149
# getaddrinfo                            142
# NtCreateThreadEx                       140
# CreateDirectoryW                       137
# CryptDecrypt                           120
# GetFileVersionInfoSizeW                116
# NtOpenMutant                           115
# IWbemServices_ExecQuery                112
# closesocket                            111
# GetUserNameW                           110
# GetFileVersionInfoW                    107
# GetAdaptersInfo                        106
# GetTempPathW                           105
# NtQueryDirectoryFile                   100
# NtOpenProcess                           88
# __exception__                           85
# FindWindowExW                           84
# CoInitializeSecurity                    82
# NtDeviceIoControlFile                   82
# NtEnumerateKey                          76
# NtEnumerateValueKey                     76
# DeviceIoControl                         72
# WriteProcessMemory                      67
# NtUnmapViewOfSection                    65
# GetComputerNameW                        63
# GetForegroundWindow                     58
# GlobalMemoryStatusEx                    56
# GetFileAttributesExW                    52
# OutputDebugStringA                      50
# CoGetClassObject                        49
# CoCreateInstanceEx                      49
# RegEnumValueW                           47
# GetCursorPos                            46
# DeleteFileW                             44
# SetEndOfFile                            38
# OpenSCManagerW                          30
# GetComputerNameA                        30
# FindResourceExA                         29
# OpenServiceW                            29
# SetWindowsHookExW                       29
# CreateJobObjectW                        26
# NtQueryKey                              22
# CreateProcessInternalW                  18
# NtSetInformationFile                    18
# ReadProcessMemory                       18
# FindWindowW                             16
# SetWindowsHookExA                       15
# RemoveDirectoryA                        13
# RegEnumKeyExA                           11
# NtOpenThread                            10
# ShellExecuteExW                         10
# MoveFileWithProgressW                    9
# NtTerminateProcess                       9
# SetFileTime                              8
# GetDiskFreeSpaceW                        7
# InternetConnectA                         7
# InternetSetOptionA                       7
# SetFileAttributesW                       7
# InternetCrackUrlA                        7
# CoUninitialize                           7
# InternetOpenA                            7
# SearchPathW                              6
# OpenSCManagerA                           6
# SetFilePointerEx                         6
# CopyFileW                                4
# WriteConsoleA                            4
# GetVolumePathNamesForVolumeNameW         3
# GetUserNameA                             3
# OpenServiceA                             3
# HttpOpenRequestW                         2
# GlobalMemoryStatus                       2
# InternetConnectW                         2
# RegDeleteValueW                          2
# InternetOpenW                            2
# RegDeleteKeyW                            2
# RemoveDirectoryW                         2
# HttpOpenRequestA                         2
# DrawTextExA                              2
# GetDiskFreeSpaceExW                      1
# gethostbyname                            1
# RegEnumValueA                            1
# FindWindowA                              1
# MessageBoxTimeoutA                       1
# CryptAcquireContextA                     1
# SHGetSpecialFolderLocation               1
# LookupPrivilegeValueW                    1
# RegQueryInfoKeyA                         1
# Name: count, dtype: int64
# pua
# LdrGetProcedureAddress               40755
# LdrGetDllHandle                      21618
# LdrLoadDll                           21085
# NtClose                              13343
# NtAllocateVirtualMemory              11072
# RegOpenKeyExW                         8932
# RegCloseKey                           8228
# RegQueryValueExW                      5881
# SetErrorMode                          5296
# NtOpenKey                             4845
# NtQueryValueKey                       4480
# GetSystemMetrics                      3512
# LoadResource                          3190
# NtReadFile                            3149
# FindResourceExW                       3064
# NtCreateFile                          3053
# SetFilePointer                        3046
# NtFreeVirtualMemory                   2767
# GetSystemWindowsDirectoryW            2570
# NtMapViewOfSection                    2539
# GetSystemTimeAsFileTime               2506
# GetSystemDirectoryW                   2335
# NtProtectVirtualMemory                2056
# RegOpenKeyExA                         1933
# NtCreateSection                       1884
# GetSystemInfo                         1804
# SetUnhandledExceptionFilter           1413
# LoadStringW                           1396
# RegQueryValueExA                      1238
# NtDeviceIoControlFile                 1134
# FindFirstFileExW                      1033
# GetNativeSystemInfo                   1008
# NtQueryAttributesFile                  939
# OutputDebugStringA                     908
# NtCreateMutant                         868
# CoInitializeEx                         784
# NtDuplicateObject                      783
# GetFileSize                            768
# RegEnumKeyW                            742
# GetFileAttributesW                     681
# DrawTextExW                            656
# CreateActCtxW                          549
# SizeofResource                         536
# NtOpenKeyEx                            495
# FindResourceW                          468
# NtDelayExecution                       445
# SHGetFolderPathW                       445
# CreateThread                           441
# OleInitialize                          437
# WSAStartup                             374
# NtOpenSection                          352
# CryptAcquireContextW                   351
# LoadStringA                            321
# IsDebuggerPresent                      315
# NtOpenMutant                           305
# NtQuerySystemInformation               305
# NtOpenProcess                          303
# LookupAccountSidW                      287
# NtOpenFile                             265
# GetTimeZoneInformation                 244
# RegCreateKeyExW                        243
# NtOpenDirectoryObject                  242
# RegSetValueExW                         236
# GetVolumeNameForVolumeMountPointW      235
# CryptDecrypt                           233
# CreateDirectoryW                       221
# GetForegroundWindow                    216
# UuidCreate                             215
# NtWriteFile                            209
# GetCursorPos                           204
# GetFileType                            200
# GetSystemDirectoryA                    171
# GetUserNameW                           160
# GetFileVersionInfoSizeW                155
# NtResumeThread                         151
# LdrUnloadDll                           147
# CoCreateInstance                       146
# GetFileVersionInfoW                    144
# RegQueryInfoKeyW                       144
# NtCreateThreadEx                       132
# NtQueryInformationFile                 130
# NtSetInformationFile                   114
# GlobalMemoryStatusEx                   113
# CryptHashData                          109
# CryptCreateHash                        109
# NtUnmapViewOfSection                   103
# FindResourceA                           99
# socket                                  97
# NtQueryDirectoryFile                    97
# RegCreateKeyExA                         96
# GetTempPathW                            93
# FindWindowW                             87
# RegEnumKeyExW                           87
# EnumWindows                             79
# SetFileAttributesW                      74
# DeleteFileW                             74
# SetEndOfFile                            71
# __exception__                           63
# CreateJobObjectW                        55
# CreateProcessInternalW                  54
# GetFileAttributesExW                    53
# SetFilePointerEx                        51
# RemoveDirectoryW                        49
# GetFileSizeEx                           48
# SetFileTime                             46
# MoveFileWithProgressW                   42
# NtEnumerateValueKey                     42
# NtEnumerateKey                          42
# CreateToolhelp32Snapshot                41
# Process32NextW                          38
# Process32FirstW                         38
# RegSetValueExA                          38
# connect                                 37
# CopyFileW                               35
# GetDiskFreeSpaceW                       34
# RegEnumValueW                           32
# GetDiskFreeSpaceExW                     30
# FindWindowA                             28
# DeviceIoControl                         27
# select                                  27
# ReadProcessMemory                       25
# FindWindowExA                           25
# closesocket                             24
# IWbemServices_ExecQuery                 24
# SetWindowsHookExW                       24
# CoUninitialize                          23
# RegEnumKeyExA                           22
# SearchPathW                             21
# InternetOpenW                           21
# WriteProcessMemory                      20
# DeleteUrlCacheEntryW                    20
# SetWindowsHookExA                       19
# InternetCrackUrlW                       19
# HttpOpenRequestW                        19
# InternetConnectW                        19
# ioctlsocket                             19
# gethostbyname                           18
# setsockopt                              15
# send                                    15
# getaddrinfo                             13
# GetComputerNameW                        12
# NtQueryKey                              12
# WSARecv                                 11
# RemoveDirectoryA                        10
# shutdown                                10
# GetAdaptersInfo                         10
# timeGetTime                              9
# CoInitializeSecurity                     9
# FindResourceExA                          8
# NtOpenThread                             8
# FindWindowExW                            7
# CoGetClassObject                         6
# CoCreateInstanceEx                       6
# OpenServiceA                             5
# NtTerminateProcess                       5
# GetAsyncKeyState                         5
# OpenSCManagerA                           5
# InternetSetOptionA                       4
# GetKeyState                              4
# InternetOpenA                            3
# CopyFileExW                              2
# Thread32First                            2
# Thread32Next                             2
# InternetConnectA                         2
# InternetCrackUrlA                        2
# MessageBoxTimeoutA                       2
# RegQueryInfoKeyA                         2
# SHGetSpecialFolderLocation               2
# GetFileInformationByHandle               2
# OpenSCManagerW                           1
# GetVolumePathNamesForVolumeNameW         1
# getsockname                              1
# MessageBoxTimeoutW                       1
# recv                                     1
# bind                                     1
# DeleteUrlCacheEntryA                     1
# ShellExecuteExW                          1
# RegDeleteKeyW                            1
# OpenServiceW                             1
# Name: count, dtype: int64
# downloader
# LdrGetProcedureAddress               61127
# LdrGetDllHandle                      39862
# LdrLoadDll                           19778
# RegCloseKey                          12705
# RegOpenKeyExW                        11211
# NtAllocateVirtualMemory              10893
# RegQueryValueExW                      8453
# NtClose                               8350
# FindResourceExW                       6666
# LoadResource                          6659
# RegOpenKeyExA                         3576
# GetSystemTimeAsFileTime               2940
# NtOpenKey                             2763
# NtQueryValueKey                       2586
# RegQueryValueExA                      2566
# NtFreeVirtualMemory                   2492
# GetSystemMetrics                      2028
# GetSystemWindowsDirectoryW            1807
# SetErrorMode                          1597
# NtMapViewOfSection                    1355
# SetUnhandledExceptionFilter           1331
# LoadStringW                           1313
# NtOpenProcess                         1176
# NtCreateFile                          1043
# GetSystemDirectoryW                   1032
# OleInitialize                          903
# LookupAccountSidW                      802
# NtCreateSection                        743
# RegEnumKeyW                            703
# NtOpenSection                          609
# GetNativeSystemInfo                    604
# CreateActCtxW                          513
# GetVolumeNameForVolumeMountPointW      495
# NtDuplicateObject                      492
# FindFirstFileExW                       445
# GetSystemInfo                          445
# NtQueryDirectoryFile                   210
# CryptAcquireContextW                   206
# NtCreateMutant                         195
# DrawTextExW                            193
# CoInitializeEx                         155
# NtReadFile                             133
# GetFileAttributesW                     129
# SetFilePointer                         122
# CryptHashData                          109
# CryptCreateHash                        109
# NtUnmapViewOfSection                   104
# CryptDecrypt                            97
# GetSystemDirectoryA                     62
# NtDelayExecution                        53
# GetFileSize                             50
# EnumWindows                             50
# SizeofResource                          44
# RegQueryInfoKeyW                        44
# NtWriteFile                             43
# LdrUnloadDll                            39
# CoCreateInstance                        36
# RegCreateKeyExW                         34
# NtProtectVirtualMemory                  31
# LoadStringA                             30
# NtOpenKeyEx                             30
# NtQueryAttributesFile                   29
# RegSetValueExW                          29
# CreateThread                            28
# FindResourceW                           27
# GetTimeZoneInformation                  27
# NtOpenMutant                            24
# RegEnumKeyExW                           22
# CreateDirectoryW                        20
# IsDebuggerPresent                       20
# SHGetFolderPathW                        20
# NtOpenFile                              19
# GetForegroundWindow                     17
# UuidCreate                              17
# NtQuerySystemInformation                16
# RegCreateKeyExA                         15
# GetFileType                             14
# FindResourceA                           13
# RegEnumValueW                           12
# NtResumeThread                          10
# SetWindowsHookExA                        9
# ReadProcessMemory                        9
# GetFileVersionInfoSizeW                  8
# GetFileVersionInfoW                      7
# RegSetValueExA                           7
# GetTempPathW                             6
# NtEnumerateKey                           6
# NtEnumerateValueKey                      6
# __exception__                            6
# GetCursorPos                             5
# DeleteFileW                              5
# CryptDecodeObjectEx                      4
# WSAStartup                               4
# OpenServiceA                             4
# OpenSCManagerA                           4
# NtOpenDirectoryObject                    4
# CertOpenStore                            3
# GetShortPathNameW                        3
# InternetSetOptionA                       3
# InternetOpenA                            3
# SetFileAttributesW                       3
# NtQueryKey                               3
# timeGetTime                              2
# GetAsyncKeyState                         2
# SetFilePointerEx                         2
# FindResourceExA                          2
# OutputDebugStringA                       2
# SetEndOfFile                             2
# RemoveDirectoryA                         2
# CreateProcessInternalW                   2
# InternetConnectA                         2
# InternetCrackUrlA                        2
# NtOpenThread                             2
# WriteConsoleA                            2
# NtCreateThreadEx                         1
# SHGetSpecialFolderLocation               1
# CoUninitialize                           1
# SetWindowsHookExW                        1
# GetComputerNameW                         1
# RegDeleteKeyW                            1
# GetUserNameW                             1
# DrawTextExA                              1
# UnhookWindowsHookEx                      1
# socket                                   1
# bind                                     1
# getsockname                              1
# connect                                  1
# getaddrinfo                              1
# Name: count, dtype: int64
# miner
# LdrGetProcedureAddress               1224
# NtClose                               983
# LdrLoadDll                            705
# LdrGetDllHandle                       625
# RegOpenKeyExW                         511
# NtCreateFile                          506
# NtQueryAttributesFile                 506
# RegCloseKey                           471
# NtAllocateVirtualMemory               421
# NtMapViewOfSection                    406
# NtCreateSection                       389
# RegQueryValueExW                      372
# NtUnmapViewOfSection                  338
# NtReadFile                            277
# NtOpenKey                             273
# NtQueryValueKey                       245
# GetSystemWindowsDirectoryW            237
# SetFilePointer                        211
# GetSystemTimeAsFileTime               209
# GetSystemDirectoryW                   202
# LdrUnloadDll                          192
# GetSystemInfo                         184
# LoadResource                          183
# FindResourceExW                       122
# NtDuplicateObject                     110
# NtProtectVirtualMemory                104
# NtFreeVirtualMemory                   103
# RegOpenKeyExA                         102
# SetErrorMode                          102
# WSAStartup                            101
# NtCreateMutant                         97
# SetUnhandledExceptionFilter            86
# Process32NextW                         80
# GetNativeSystemInfo                    79
# socket                                 78
# LoadStringW                            76
# CreateToolhelp32Snapshot               74
# SizeofResource                         73
# __exception__                          66
# NtOpenDirectoryObject                  65
# NtOpenKeyEx                            65
# NtWriteFile                            62
# NtDelayExecution                       61
# FindFirstFileExW                       60
# GetSystemMetrics                       55
# FindResourceW                          53
# closesocket                            52
# GetFileAttributesW                     52
# GetFileType                            51
# Process32FirstW                        46
# CryptHashData                          43
# NtQuerySystemInformation               41
# RegQueryInfoKeyW                       38
# GetSystemDirectoryA                    36
# GetFileSize                            31
# FindResourceA                          29
# timeGetTime                            28
# OleInitialize                          27
# RegQueryValueExA                       26
# CreateThread                           25
# NtOpenFile                             22
# CreateProcessInternalW                 19
# WriteConsoleA                          19
# CreateDirectoryW                       18
# RegEnumValueW                          17
# SetFileAttributesW                     16
# GetVolumeNameForVolumeMountPointW      16
# IsDebuggerPresent                      13
# SetFileTime                            12
# NtOpenSection                          12
# GlobalMemoryStatusEx                   11
# SetFilePointerEx                       11
# GetTempPathW                           11
# LoadStringA                            10
# NtQueryKey                             10
# NtResumeThread                          9
# WriteProcessMemory                      9
# NtEnumerateValueKey                     9
# NtOpenProcess                           8
# NtCreateThreadEx                        8
# CopyFileA                               8
# Thread32Next                            8
# Thread32First                           8
# NtEnumerateKey                          8
# RegEnumKeyExW                           7
# GetForegroundWindow                     7
# GetVolumePathNamesForVolumeNameW        6
# CreateActCtxW                           6
# DeleteFileW                             6
# DrawTextExW                             6
# GetFileAttributesExW                    6
# RtlAddVectoredExceptionHandler          6
# NtQueryDirectoryFile                    5
# OutputDebugStringA                      5
# SetEndOfFile                            5
# RegEnumKeyW                             4
# SHGetFolderPathW                        4
# CoCreateInstance                        4
# FindWindowA                             4
# CoInitializeEx                          4
# NtQueryInformationFile                  3
# NtWriteVirtualMemory                    3
# RegSetValueExA                          3
# NtGetContextThread                      2
# NtReadVirtualMemory                     2
# NtOpenMutant                            2
# GetComputerNameA                        2
# GetTimeZoneInformation                  2
# CoUninitialize                          2
# MoveFileWithProgressW                   2
# ReadProcessMemory                       2
# GetDiskFreeSpaceW                       2
# RemoveDirectoryW                        2
# GetCursorPos                            2
# RemoveDirectoryA                        2
# RegCreateKeyExA                         2
# LookupAccountSidW                       2
# SearchPathW                             2
# SetWindowsHookExA                       2
# getaddrinfo                             1
# NtTerminateProcess                      1
# DeleteUrlCacheEntryA                    1
# LookupPrivilegeValueW                   1
# InternetOpenA                           1
# InternetSetOptionA                      1
# CryptAcquireContextW                    1
# CryptCreateHash                         1
# ShellExecuteExW                         1
# MessageBoxTimeoutW                      1
# NtSetContextThread                      1
# GetUserNameA                            1
# FindWindowW                             1
# Name: count, dtype: int64
# virus
# LdrGetProcedureAddress               1052
# LdrLoadDll                            643
# NtClose                               577
# RegCloseKey                           512
# RegOpenKeyExW                         430
# LdrGetDllHandle                       406
# NtReadFile                            382
# NtAllocateVirtualMemory               321
# RegQueryValueExW                      305
# NtWriteFile                           269
# NtOpenKey                             171
# NtCreateFile                          169
# LoadResource                          167
# FindResourceExW                       167
# SetFilePointer                        160
# NtQueryValueKey                       155
# RegOpenKeyExA                         131
# SetErrorMode                          109
# GetSystemWindowsDirectoryW            104
# NtFreeVirtualMemory                   102
# GetSystemMetrics                       86
# NtMapViewOfSection                     85
# NtDuplicateObject                      75
# GetTempPathW                           67
# NtCreateSection                        63
# FindFirstFileExW                       60
# GetVolumeNameForVolumeMountPointW      54
# GetSystemInfo                          51
# LoadStringA                            50
# GetFileAttributesW                     46
# RegSetValueExA                         45
# CreateDirectoryW                       42
# GetFileSize                            39
# GetSystemDirectoryW                    38
# GetSystemTimeAsFileTime                38
# NtCreateMutant                         38
# NtQueryAttributesFile                  33
# RegQueryValueExA                       31
# NtOpenKeyEx                            31
# LoadStringW                            29
# NtProtectVirtualMemory                 28
# OleInitialize                          26
# RegEnumKeyW                            26
# CreateProcessInternalW                 24
# GetNativeSystemInfo                    23
# CreateActCtxW                          23
# NtOpenFile                             22
# NtQuerySystemInformation               22
# GetFileType                            19
# NtQueryDirectoryFile                   18
# NtOpenSection                          18
# DrawTextExW                            18
# SizeofResource                         16
# RegCreateKeyExA                        16
# SetUnhandledExceptionFilter            16
# FindResourceA                          15
# LdrUnloadDll                           13
# NtSetValueKey                          13
# CreateThread                           11
# GetTimeZoneInformation                 10
# CoInitializeEx                          9
# SetWindowsHookExA                       9
# SetFileAttributesW                      8
# DeleteFileW                             8
# NtQueryInformationFile                  8
# WSAStartup                              8
# __exception__                           8
# NtDelayExecution                        8
# NtOpenDirectoryObject                   7
# GetCursorPos                            7
# GetForegroundWindow                     6
# NtOpenMutant                            6
# NtCreateKey                             6
# FindResourceW                           5
# GetSystemDirectoryA                     5
# GlobalMemoryStatusEx                    4
# IsDebuggerPresent                       4
# RemoveDirectoryA                        4
# NtEnumerateValueKey                     4
# NtEnumerateKey                          4
# UuidCreate                              3
# SetEndOfFile                            3
# NtSetInformationFile                    3
# SHGetFolderPathW                        3
# SearchPathW                             2
# CoCreateInstance                        2
# OpenSCManagerA                          2
# RegCreateKeyExW                         2
# CopyFileA                               2
# CreateToolhelp32Snapshot                2
# LookupAccountSidW                       2
# GetUserNameA                            2
# ReadProcessMemory                       2
# Process32NextW                          2
# RegSetValueExW                          2
# Process32FirstW                         2
# CryptAcquireContextW                    1
# GetFileVersionInfoW                     1
# GetFileVersionInfoSizeW                 1
# CreateServiceA                          1
# CryptCreateHash                         1
# CryptHashData                           1
# FindWindowA                             1
# EnumWindows                             1
# CopyFileW                               1
# StartServiceA                           1
# RemoveDirectoryW                        1
# FindResourceExA                         1
# NtResumeThread                          1
# NtCreateThreadEx                        1
# NtTerminateProcess                      1
# OpenServiceA                            1
# GetAdaptersInfo                         1
# InternetOpenW                           1
# InternetOpenA                           1
# SetWindowsHookExW                       1
# CoGetClassObject                        1
# InternetConnectW                        1
# HttpOpenRequestW                        1
# NtUnmapViewOfSection                    1
# CoInitializeSecurity                    1
# CoUninitialize                          1
# Name: count, dtype: int64
# ransomware
# NtQuerySystemInformation       7810
# NtAllocateVirtualMemory        5404
# NtFreeVirtualMemory            4844
# NtClose                        2129
# LdrGetProcedureAddress         1519
# RegOpenKeyExW                  1178
# RegCloseKey                    1143
# RegQueryValueExW               1129
# NtOpenKey                       813
# LdrGetDllHandle                 760
# LdrLoadDll                      751
# NtQueryValueKey                 737
# NtCreateFile                    651
# NtMapViewOfSection              628
# NtCreateSection                 627
# CreateThread                    441
# NtOpenFile                      348
# NtCreateMutant                  339
# NtQueryInformationFile          328
# CryptAcquireContextW            326
# GetSystemWindowsDirectoryW      324
# NtDelayExecution                320
# GetFileSize                     317
# GetTempPathW                    310
# CreateToolhelp32Snapshot        124
# Process32NextW                  113
# Process32FirstW                 113
# GetSystemTimeAsFileTime          35
# NtDuplicateObject                29
# NtProtectVirtualMemory           24
# RegQueryInfoKeyW                 22
# NtEnumerateKey                   22
# NtEnumerateValueKey              22
# GetSystemInfo                    20
# NtTerminateThread                19
# GetSystemMetrics                 18
# GetComputerNameW                 15
# NtWriteFile                      15
# NtOpenKeyEx                      15
# GetSystemDirectoryW              14
# GetUserNameW                     14
# NtOpenMutant                     14
# NtQueryDirectoryFile             11
# SHGetFolderPathW                 11
# NtOpenProcess                    10
# CreateProcessInternalW            9
# LoadStringW                       9
# SetFilePointerEx                  9
# NtQueryKey                        8
# RegEnumValueW                     8
# NtUnmapViewOfSection              8
# RegOpenKeyExA                     8
# SetErrorMode                      8
# CoInitializeEx                    8
# CoCreateInstance                  8
# FindResourceExW                   8
# GetFileAttributesW                8
# IsDebuggerPresent                 7
# CryptGenKey                       7
# NtReadFile                        7
# SetUnhandledExceptionFilter       7
# FindFirstFileExW                  7
# CryptExportKey                    6
# RegEnumKeyExW                     6
# FindResourceW                     6
# LoadResource                      5
# SizeofResource                    5
# GetNativeSystemInfo               5
# UuidCreate                        5
# GetFileSizeEx                     5
# FindWindowW                       4
# WSAStartup                        3
# GetShortPathNameW                 3
# RegSetValueExW                    3
# NtResumeThread                    3
# CoCreateInstanceEx                2
# CoGetClassObject                  2
# CoInitializeSecurity              2
# OutputDebugStringA                2
# RegEnumKeyW                       2
# OleInitialize                     2
# RegQueryValueExA                  2
# MoveFileWithProgressW             2
# LookupPrivilegeValueW             2
# LookupAccountSidW                 2
# NtCreateThreadEx                  2
# NtOpenDirectoryObject             2
# CopyFileW                         2
# RegCreateKeyExW                   2
# SetFilePointer                    2
# RegCreateKeyExA                   1
# RegSetValueExA                    1
# WriteProcessMemory                1
# EnumWindows                       1
# CryptHashData                     1
# GetSystemWindowsDirectoryA        1
# RegEnumKeyExA                     1
# CryptCreateHash                   1
# MessageBoxTimeoutW                1
# CreateActCtxW                     1
# DeleteFileW                       1
# SetWindowsHookExW                 1
# GetCursorPos                      1
# IWbemServices_ExecQuery           1
# CoUninitialize                    1
# GetDiskFreeSpaceW                 1
# OpenSCManagerW                    1
# getaddrinfo                       1
# WriteConsoleA                     1
# GetFileType                       1
# RegEnumValueA                     1
# Name: count, dtype: int64
# spyware
# LdrGetProcedureAddress               800
# FindResourceExW                      636
# LoadResource                         557
# LdrGetDllHandle                      416
# LdrLoadDll                           409
# GetSystemMetrics                     218
# NtAllocateVirtualMemory              213
# NtClose                              212
# LoadStringA                          126
# RegCloseKey                          111
# NtQueryValueKey                      104
# NtOpenKey                             95
# RegOpenKeyExA                         91
# DrawTextExW                           69
# RegOpenKeyExW                         60
# NtCreateFile                          47
# NtCreateSection                       45
# RegQueryValueExA                      45
# GetSystemWindowsDirectoryW            43
# GetSystemInfo                         42
# NtFreeVirtualMemory                   40
# NtQueryAttributesFile                 40
# GetSystemDirectoryW                   39
# NtMapViewOfSection                    38
# RegQueryValueExW                      35
# CreateThread                          30
# NtProtectVirtualMemory                20
# WSAStartup                            16
# GetFileAttributesW                    16
# RegQueryInfoKeyW                      15
# FindResourceA                         13
# GetSystemTimeAsFileTime               11
# SetErrorMode                          11
# CoInitializeEx                        10
# FindResourceExA                       10
# RegCreateKeyExA                       10
# FindFirstFileExW                       9
# NtOpenKeyEx                            7
# NtUnmapViewOfSection                   6
# GetFileSize                            6
# RegEnumValueW                          6
# SetWindowsHookExA                      5
# NtCreateMutant                         5
# GetVolumeNameForVolumeMountPointW      4
# NtQuerySystemInformation               4
# NtOpenMutant                           4
# NtOpenFile                             4
# NtDuplicateObject                      4
# OleInitialize                          4
# SearchPathW                            3
# SizeofResource                         3
# RegEnumKeyExW                          3
# GetFileVersionInfoSizeW                2
# GetFileVersionInfoW                    2
# NtQueryKey                             2
# CoUninitialize                         2
# SHGetSpecialFolderLocation             2
# UuidCreate                             1
# CoInitializeSecurity                   1
# GlobalMemoryStatusEx                   1
# CryptAcquireContextW                   1
# GetShortPathNameW                      1
# GetTempPathW                           1
# NtDelayExecution                       1
# FindWindowW                            1
# GetNativeSystemInfo                    1
# LoadStringW                            1
# RegSetValueExW                         1
# RegCreateKeyExW                        1
# FindResourceW                          1
# __exception__                          1
# NtReadFile                             1
# SetFilePointer                         1
# GetFileType                            1
# CreateActCtxW                          1
# GetCursorPos                           1
# NtQueryDirectoryFile                   1
# Name: count, dtype: int64
# hacktool
# NtClose                        82
# LdrGetProcedureAddress         73
# LdrLoadDll                     57
# NtAllocateVirtualMemory        41
# NtCreateFile                   28
# LdrGetDllHandle                26
# SetFilePointer                 25
# FindFirstFileExW               24
# NtReadFile                     23
# NtMapViewOfSection             18
# NtFreeVirtualMemory            18
# RegCloseKey                    17
# NtQueryValueKey                17
# GetSystemMetrics               16
# NtOpenKey                      15
# RegOpenKeyExW                  15
# GetSystemDirectoryW            14
# NtCreateSection                13
# SetErrorMode                   13
# RegQueryValueExW               12
# GetSystemWindowsDirectoryW     10
# GetFileSize                     9
# NtQueryAttributesFile           9
# NtWriteFile                     7
# LoadStringA                     7
# LoadResource                    7
# RegOpenKeyExA                   6
# NtOpenFile                      6
# LoadStringW                     6
# CreateDirectoryW                5
# IsDebuggerPresent               4
# GetFileAttributesW              4
# NtProtectVirtualMemory          4
# DrawTextExW                     4
# SizeofResource                  4
# GetSystemInfo                   4
# DeviceIoControl                 3
# RegSetValueExW                  3
# RegCreateKeyExA                 3
# NtCreateMutant                  3
# CreateProcessInternalW          3
# FindResourceA                   3
# SetEndOfFile                    3
# FindResourceExW                 3
# DeleteFileW                     3
# NtSetInformationFile            2
# GetTempPathW                    2
# RegQueryValueExA                2
# RemoveDirectoryA                2
# GetSystemTimeAsFileTime         2
# NtDuplicateObject               2
# SHGetFolderPathW                2
# NtOpenKeyEx                     2
# NtQueryInformationFile          1
# FindResourceW                   1
# GetNativeSystemInfo             1
# NtOpenSection                   1
# OleInitialize                   1
# CreateThread                    1
# FindResourceExA                 1
# GlobalMemoryStatusEx            1
# NtQuerySystemInformation        1
# WSAStartup                      1
# SetUnhandledExceptionFilter     1
# NtOpenProcess                   1
# GetForegroundWindow             1
# RemoveDirectoryW                1
# Name: count, dtype: int64
# dropper
# LdrGetProcedureAddress               68
# LdrLoadDll                           54
# RegOpenKeyExW                        47
# RegCloseKey                          44
# RegQueryValueExW                     37
# SetErrorMode                         35
# NtClose                              33
# LdrGetDllHandle                      33
# NtQueryValueKey                      17
# NtOpenKey                            17
# GetSystemWindowsDirectoryW           14
# NtAllocateVirtualMemory              12
# GetSystemDirectoryW                   9
# NtMapViewOfSection                    8
# NtCreateFile                          8
# NtQueryAttributesFile                 6
# LoadStringW                           6
# NtCreateSection                       6
# RegOpenKeyExA                         5
# NtCreateMutant                        4
# GetNativeSystemInfo                   4
# CreateActCtxW                         4
# NtFreeVirtualMemory                   3
# GetSystemTimeAsFileTime               3
# OleInitialize                         3
# SetUnhandledExceptionFilter           2
# RegQueryValueExA                      2
# NtQuerySystemInformation              2
# GetSystemInfo                         2
# NtDuplicateObject                     2
# GetVolumeNameForVolumeMountPointW     2
# NtOpenSection                         2
# GetSystemMetrics                      1
# GetCursorPos                          1
# FindResourceW                         1
# SetWindowsHookExW                     1
# GlobalMemoryStatusEx                  1
# RegEnumKeyW                           1
# Name: count, dtype: int64
# worm
# LdrGetProcedureAddress        40
# LdrLoadDll                    31
# FindResourceExW               24
# LoadResource                  23
# SetErrorMode                  21
# NtAllocateVirtualMemory       21
# LdrGetDllHandle               12
# NtClose                       11
# NtQueryValueKey               10
# GetSystemMetrics               9
# RegCloseKey                    8
# RegOpenKeyExA                  7
# NtOpenKey                      7
# RegOpenKeyExW                  6
# LoadStringA                    6
# NtFreeVirtualMemory            5
# RegCreateKeyExW                5
# GetFileAttributesW             5
# NtDuplicateObject              4
# RegQueryValueExW               4
# NtProtectVirtualMemory         3
# NtDelayExecution               3
# RegCreateKeyExA                2
# DrawTextExW                    2
# CreateActCtxW                  2
# GetSystemInfo                  2
# SearchPathW                    1
# CoCreateInstanceEx             1
# NtOpenFile                     1
# GetTempPathW                   1
# GlobalMemoryStatusEx           1
# SetWindowsHookExA              1
# LookupPrivilegeValueW          1
# NtResumeThread                 1
# NtCreateThreadEx               1
# OleInitialize                  1
# NtCreateFile                   1
# RegQueryValueExA               1
# NtQuerySystemInformation       1
# FindWindowA                    1
# CreateThread                   1
# RegSetValueExA                 1
# CopyFileA                      1
# DeleteFileW                    1
# SetFileAttributesW             1
# WSAStartup                     1
# GetSystemWindowsDirectoryW     1
# GetFileVersionInfoW            1
# GetFileVersionInfoSizeW        1
# SizeofResource                 1
# FindResourceA                  1
# NtQueryAttributesFile          1
# NtQueryInformationFile         1
# Name: count, dtype: int64

# %% [markdown]
# ## "What the Unique API Calls are in each Malware Type"

# %%
for i,m in enumerate(malware_types):
    print(i, m)
    m_list = malware_apis[i]
    for j in range(len(malware_apis)):
        if j != i:
            for k in m_list[:]:
                if k in malware_apis[j]:
                    m_list.remove(k)
    print(m_list)
    print("\n")
# Out:
# 0 trojan
# ['SetStdHandle', 'CryptProtectData', 'CryptEncrypt', 'GetVolumePathNameW', 'StartServiceW', 'HttpSendRequestA', 'CreateServiceW', 'RtlRemoveVectoredExceptionHandler', 'CreateRemoteThread', 'RegisterHotKey', 'GetKeyboardState', 'RtlDecompressBuffer', 'WSASocketW', 'NtQueueApcThread', 'SetFileInformationByHandle', 'GetFileInformationByHandleEx', 'GetAddrInfoW', 'DnsQuery_A', 'InternetReadFile', 'InternetOpenUrlA', 'ControlService', 'GetUserNameExA', 'SendNotifyMessageW', 'SetInformationJobObject', 'WSASocketA', 'sendto', 'InternetOpenUrlW', 'NetUserGetInfo']
#
#
# 1 _
# ['EnumServicesStatusA', 'NtSuspendThread', 'InternetGetConnectedState', 'RegDeleteValueA', 'NetUserGetLocalGroups', 'CertOpenSystemStoreW', 'InternetQueryOptionA', 'HttpQueryInfoA', 'InternetSetStatusCallback', 'ObtainUserAgentString', 'NtDeleteKey', 'GetAdaptersAddresses', 'GetBestInterfaceEx', 'Module32FirstW', 'Module32NextW', 'NtQueryFullAttributesFile', 'InternetCloseHandle']
#
#
# 2 adware
# ['CryptAcquireContextA', 'HttpOpenRequestA', 'GlobalMemoryStatus', 'RegDeleteValueW']
#
#
# 3 pua
# ['NtDeviceIoControlFile', 'gethostbyname', 'setsockopt', 'send', 'DeleteUrlCacheEntryW', 'WSARecv', 'shutdown', 'InternetCrackUrlW', 'GetDiskFreeSpaceExW', 'MessageBoxTimeoutA', 'GetKeyState', 'FindWindowExA', 'recv', 'FindWindowExW', 'ioctlsocket', 'select', 'CopyFileExW', 'CreateJobObjectW', 'RegQueryInfoKeyA', 'GetFileInformationByHandle', 'OpenServiceW']
#
#
# 4 downloader
# ['CryptDecrypt', 'bind', 'getsockname', 'connect', 'NtOpenThread', 'RegDeleteKeyW', 'InternetCrackUrlA', 'InternetConnectA', 'GetAsyncKeyState', 'UnhookWindowsHookEx', 'DrawTextExA', 'CertOpenStore', 'CryptDecodeObjectEx']
#
#
# 5 miner
# ['socket', 'closesocket', 'NtGetContextThread', 'NtReadVirtualMemory', 'NtWriteVirtualMemory', 'NtSetContextThread', 'RtlAddVectoredExceptionHandler', 'SetFileTime', 'timeGetTime', 'GetVolumePathNamesForVolumeNameW', 'ShellExecuteExW', 'Thread32First', 'Thread32Next', 'DeleteUrlCacheEntryA', 'GetFileAttributesExW', 'InternetSetOptionA', 'GetComputerNameA']
#
#
# 6 virus
# ['GetTimeZoneInformation', 'LdrUnloadDll', 'GetUserNameA', 'GetAdaptersInfo', 'InternetOpenW', 'InternetConnectW', 'HttpOpenRequestW', 'ReadProcessMemory', 'GetSystemDirectoryA', 'InternetOpenA', 'OpenSCManagerA', 'OpenServiceA', 'NtTerminateProcess', 'CreateServiceA', 'StartServiceA', 'NtSetValueKey', 'NtCreateKey']
#
#
# 7 ransomware
# ['NtTerminateThread', 'CreateToolhelp32Snapshot', 'Process32FirstW', 'Process32NextW', 'NtEnumerateKey', 'NtEnumerateValueKey', 'GetUserNameW', 'GetComputerNameW', 'CryptGenKey', 'CryptExportKey', 'GetDiskFreeSpaceW', 'CopyFileW', 'GetFileSizeEx', 'SetFilePointerEx', 'MoveFileWithProgressW', 'WriteConsoleA', 'getaddrinfo', 'NtOpenDirectoryObject', 'OpenSCManagerW', 'MessageBoxTimeoutW', 'OutputDebugStringA', 'CoCreateInstance', 'CoGetClassObject', 'IWbemServices_ExecQuery', 'LookupAccountSidW', 'CryptCreateHash', 'CryptHashData', 'EnumWindows', 'WriteProcessMemory', 'GetSystemWindowsDirectoryA', 'RegEnumKeyExA', 'RegEnumValueA']
#
#
# 8 spyware
# ['RegQueryInfoKeyW', 'RegEnumKeyExW', 'RegEnumValueW', 'NtUnmapViewOfSection', 'GetFileType', '__exception__', 'CoInitializeEx', 'NtOpenMutant', 'FindWindowW', 'SHGetSpecialFolderLocation', 'CoUninitialize', 'GetShortPathNameW', 'CoInitializeSecurity', 'UuidCreate', 'CryptAcquireContextW', 'NtQueryKey', 'NtQueryDirectoryFile']
#
#
# 9 hacktool
# ['GetFileSize', 'SetFilePointer', 'NtReadFile', 'CreateDirectoryW', 'SetEndOfFile', 'NtWriteFile', 'IsDebuggerPresent', 'CreateProcessInternalW', 'RemoveDirectoryA', 'FindResourceExA', 'GetForegroundWindow', 'NtOpenKeyEx', 'NtOpenProcess', 'SHGetFolderPathW', 'FindFirstFileExW', 'RegSetValueExW', 'DeviceIoControl', 'NtSetInformationFile', 'RemoveDirectoryW']
#
#
# 10 dropper
# ['GetSystemDirectoryW', 'LoadStringW', 'NtCreateMutant', 'GetNativeSystemInfo', 'NtCreateSection', 'NtMapViewOfSection', 'GetSystemTimeAsFileTime', 'NtOpenSection', 'GetVolumeNameForVolumeMountPointW', 'SetUnhandledExceptionFilter', 'GetCursorPos', 'FindResourceW', 'SetWindowsHookExW', 'RegEnumKeyW']
#
#
# 11 worm
# ['RegOpenKeyExA', 'NtOpenKey', 'NtQueryValueKey', 'NtClose', 'NtQueryAttributesFile', 'LoadStringA', 'NtAllocateVirtualMemory', 'LdrGetDllHandle', 'LdrGetProcedureAddress', 'GetSystemMetrics', 'FindResourceExW', 'LoadResource', 'LdrLoadDll', 'DrawTextExW', 'FindResourceA', 'SizeofResource', 'GetFileVersionInfoSizeW', 'GetFileVersionInfoW', 'NtFreeVirtualMemory', 'CreateActCtxW', 'GetSystemWindowsDirectoryW', 'WSAStartup', 'RegCreateKeyExA', 'RegCloseKey', 'GetFileAttributesW', 'SetFileAttributesW', 'NtCreateFile', 'DeleteFileW', 'CopyFileA', 'RegSetValueExA', 'CreateThread', 'NtDuplicateObject', 'FindWindowA', 'NtQuerySystemInformation', 'RegQueryValueExA', 'RegOpenKeyExW', 'GlobalMemoryStatusEx', 'NtCreateThreadEx', 'NtResumeThread', 'GetSystemInfo', 'RegCreateKeyExW', 'RegQueryValueExW', 'GetTempPathW', 'SetErrorMode', 'OleInitialize', 'NtProtectVirtualMemory', 'SearchPathW', 'SetWindowsHookExA', 'LookupPrivilegeValueW', 'CoCreateInstanceEx', 'NtDelayExecution', 'NtOpenFile', 'NtQueryInformationFile']
