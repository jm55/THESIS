# %% [markdown]
# # Malicious ClusterScan
#
# Describes/summarizes the or set of clusters. Useful for when you aim to enlist the summarized malware types found in each cluster in order by Malware Type.
#
# Assume that the dataset is already pre-processed:
# 1. Removal of nan values
# 2. Data Cleaning (Removal of False Labels and *Removal/Aggregation of malware types of poor quantity*)
# 3. Inverse Ordinal Encoding (for representation purposes only)

# %% [markdown]
# ## Import Libraries/Datasets

# %%
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

plt.rcParams["figure.autolayout"] = True

malicious_df = pd.read_csv('./Manual_KMeans_Encoded_Clustering.csv', low_memory=False, index_col=False) #This should point to a VirusTotal verified <Data Clustering>_SampleHash_Common.csv file

#Load list of API calls
API_LIST = "../api_calls.txt"
DELIMITER = "NaN"
API_FILE = open(API_LIST,"r")
APIS = API_FILE.readline().split(',')
APIS.append(DELIMITER) #serves as a label for NaN values for Instance-based datasets
API_FILE.close()

def list_to_str(ls:list):
    output = ""
    for l in ls:
        output += str(l) + " "
    return output[0:len(output)-1]

def inject_patterns(inner_df:pd.DataFrame):
    patterns = []
    for row in range(inner_df.shape[0]):
        patterns.append(list_to_str(inner_df.iloc[row,2:5].transpose().to_list()))
    inner_df['type_pattern'] = patterns
    return inner_df

def get_unique_clusters(df:pd.DataFrame):
    return list(df['cluster'].unique())

def get_summary(df:pd.DataFrame):
    #Identify the overall list of types each cluster is as designated by VirusTotal.
    unique_clusters = get_unique_clusters(df)
    summary = []
    for u in unique_clusters:
        cluster_sublist = [u]
        df_copy = malicious_df[malicious_df['cluster'] == u].copy(deep=True)
        idx = list(df_copy['type'].value_counts().index)
        counts = list(df_copy['type'].value_counts())
        type_sublist = []
        for i in range(len(idx)):
            type_sublist.append([idx[i], counts[i]])
        cluster_sublist.append(type_sublist)
        # str_summary = []
        # cluster_sublist.append(list(df_copy['type_pattern'].value_counts().index))
        # cluster_sublist.append(list(df_copy['type_pattern'].value_counts()))
        summary.append(cluster_sublist)
    return summary

DELIMITER = "NaN"
API_FILE = open(API_LIST,"r")
APIS = API_FILE.readline().split(',')
APIS.append(DELIMITER) #serves as a label for NaN values for Instance-based datasets
API_FILE.close()

from sklearn.preprocessing import LabelEncoder
#Inverse Label Encoding
def inverse_label(item):
    global APIS
    return item.map(lambda x: APIS[int(x)])
oliveira = pd.read_csv('../oliveira.csv', low_memory=False)
oliveira.iloc[:, 1:101] = oliveira.iloc[:, 1:101].apply(inverse_label, axis=1, result_type='reduce')

def how_many_clusters():
    c = malicious_df['cluster'].unique()
    c.sort()
    print("Number of Clusters:", c.size)
    c = malicious_df['cluster'].value_counts(ascending=True)
    print("Number of single-item Clusters:", c[c==1].count())
    print("Number of Samples Remaining:", malicious_df.shape[0])
# Out:
# C:\Users\ejose\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# ## DataFrame Preview

# %%
#Replace '-' empty malware type delimiter with '_' for consistency
malicious_df.replace(to_replace='-',value='_', inplace=True)
display(malicious_df.head(10))
display(malicious_df.shape)
malicious_df['type'].value_counts(ascending=True).plot(kind='barh')
# Out:
#                                hash                          t_0  \
# 0  071e8c3f8922e186e57548cd4c703a5d                RegOpenKeyExA
# 1  33f8e6d08a6aae939f25a8e0d63dd523      GetSystemTimeAsFileTime
# 2  b68abd064e975e1c6d5f25e748663076  SetUnhandledExceptionFilter
# 3  72049be7bd30ea61297ea624ae198067      GetSystemTimeAsFileTime
# 4  c9b3700a77facf29172f32df6bc77f48      GetSystemTimeAsFileTime
# 5  cc6217be863e606e49da90fee2252f52       LdrGetProcedureAddress
# 6  f7a1a3c38809d807b3f5f4cc00b1e9b7                      NtClose
# 7  164b56522eb24164184460f8523ed7e2      GetSystemTimeAsFileTime
# 8  56ae1459ba61a14eb119982d6ec793d7      GetSystemTimeAsFileTime
# 9  c4148ca91c5246a8707a1ac1fd1e2e36      GetSystemTimeAsFileTime
#
#                        t_1                     t_2                      t_3  \
# 0                NtOpenKey         NtQueryValueKey                  NtClose
# 1  NtAllocateVirtualMemory     NtFreeVirtualMemory  NtAllocateVirtualMemory
# 2            OleInitialize              LdrLoadDll   LdrGetProcedureAddress
# 3  NtAllocateVirtualMemory     NtFreeVirtualMemory  NtAllocateVirtualMemory
# 4               LdrLoadDll  LdrGetProcedureAddress               LdrLoadDll
# 5  NtAllocateVirtualMemory  LdrGetProcedureAddress  NtAllocateVirtualMemory
# 6                NtOpenKey         NtQueryValueKey                  NtClose
# 7               LdrLoadDll  LdrGetProcedureAddress               LdrLoadDll
# 8               LdrLoadDll  LdrGetProcedureAddress               LdrLoadDll
# 9  NtAllocateVirtualMemory     NtFreeVirtualMemory  NtAllocateVirtualMemory
#
#                       t_4                     t_5                     t_6  \
# 0               NtOpenKey         NtQueryValueKey                 NtClose
# 1         LdrGetDllHandle  LdrGetProcedureAddress         LdrGetDllHandle
# 2              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 3         LdrGetDllHandle  LdrGetProcedureAddress         LdrGetDllHandle
# 4  LdrGetProcedureAddress              LdrLoadDll  LdrGetProcedureAddress
# 5  LdrGetProcedureAddress              LdrLoadDll  LdrGetProcedureAddress
# 6               NtOpenKey         NtQueryValueKey                 NtClose
# 7  LdrGetProcedureAddress              LdrLoadDll  LdrGetProcedureAddress
# 8  LdrGetProcedureAddress              LdrLoadDll  LdrGetProcedureAddress
# 9         LdrGetDllHandle  LdrGetProcedureAddress         LdrGetDllHandle
#
#                        t_7                          t_8  ...  \
# 0    NtQueryAttributesFile                  LoadStringA  ...
# 1   LdrGetProcedureAddress              LdrGetDllHandle  ...
# 2   LdrGetProcedureAddress                   LdrLoadDll  ...
# 3   LdrGetProcedureAddress              LdrGetDllHandle  ...
# 4               LdrLoadDll       LdrGetProcedureAddress  ...
# 5               LdrLoadDll       LdrGetProcedureAddress  ...
# 6          LdrGetDllHandle       LdrGetProcedureAddress  ...
# 7               LdrLoadDll       LdrGetProcedureAddress  ...
# 8               LdrLoadDll       LdrGetProcedureAddress  ...
# 9  NtAllocateVirtualMemory  SetUnhandledExceptionFilter  ...
#
#                          t_94                 t_95  \
# 0          NtMapViewOfSection              NtClose
# 1  GetSystemWindowsDirectoryW         NtCreateFile
# 2                 RegCloseKey        RegOpenKeyExA
# 3        NtWriteVirtualMemory  NtFreeVirtualMemory
# 4               RegEnumKeyExW        RegOpenKeyExW
# 5            RegQueryValueExW          RegCloseKey
# 6             LdrGetDllHandle      FindResourceExW
# 7         GetSystemDirectoryW           LdrLoadDll
# 8                     NtClose           WSAStartup
# 9     NtAllocateVirtualMemory      LdrGetDllHandle
#
#                                 t_96                     t_97  \
# 0                   GetSystemMetrics  NtAllocateVirtualMemory
# 1                    NtCreateSection       NtMapViewOfSection
# 2                   RegQueryValueExA              RegCloseKey
# 3            NtAllocateVirtualMemory     NtWriteVirtualMemory
# 4                   RegQueryValueExW            RegOpenKeyExW
# 5  GetVolumeNameForVolumeMountPointW   LdrGetProcedureAddress
# 6                       LoadResource          FindResourceExW
# 7                       CreateThread          FindResourceExW
# 8            NtAllocateVirtualMemory             CreateThread
# 9             LdrGetProcedureAddress            NtOpenProcess
#
#                      t_98                        t_99 malware        type  \
# 0           CreateActCtxW  GetSystemWindowsDirectoryW       1      trojan
# 1                 NtClose            GetSystemMetrics       1         pua
# 2           RegEnumKeyExA               RegOpenKeyExA       1      trojan
# 3  NtProtectVirtualMemory        NtWriteVirtualMemory       1      trojan
# 4        RegQueryValueExW               RegOpenKeyExW       1      trojan
# 5           RegOpenKeyExW                 RegCloseKey       1      trojan
# 6            LoadResource                 DrawTextExW       1  downloader
# 7                 NtClose            GetSystemMetrics       1      adware
# 8              LdrLoadDll      LdrGetProcedureAddress       1      adware
# 9                 NtClose            GetSystemMetrics       1  downloader
#
#                                              pattern cluster
# 0  RegOpenKeyExA,NtOpenKey,NtQueryValueKey,NtClos...       1
# 1  GetSystemTimeAsFileTime,NtAllocateVirtualMemor...       3
# 2  SetUnhandledExceptionFilter,OleInitialize,LdrL...       3
# 3  GetSystemTimeAsFileTime,NtAllocateVirtualMemor...       0
# 4  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...       5
# 5  LdrGetProcedureAddress,NtAllocateVirtualMemory...       0
# 6  NtClose,NtOpenKey,NtQueryValueKey,NtClose,NtOp...       4
# 7  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...       0
# 8  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...       2
# 9  GetSystemTimeAsFileTime,NtAllocateVirtualMemor...       0
#
# [10 rows x 105 columns]
# (40159, 105)
# <Axes: ylabel='type'>

# %%
#INJECT PATTERN (i.e., summarized malware type pattern) to the DataFrame
malicious_df = inject_patterns(malicious_df)

print("Raw Clustered malicious samples")
how_many_clusters()
# Out:
# Raw Clustered malicious samples
# Number of Clusters: 11
# Number of single-item Clusters: 0
# Number of Samples Remaining: 40159

# %% [markdown]
# ## How many clusters are there?

# %%
# #Prior to noise removal
# print("Prior to noise removal")
# how_many_clusters()

# %%
# #DROP CLUSTERS WITH MORE THAN 1 MALWARE TYPE UNDER IT (i.e. NOISE)
# unique_clusters = get_unique_clusters(malicious_df)
# for u in unique_clusters:
#     if len(malicious_df[malicious_df['cluster'] == u]['type'].unique()) > 1:
#         malicious_df = malicious_df.drop(malicious_df[malicious_df['cluster'] == u].index)
# malicious_df.head()

# print("After removing yet unlabelled malicious samples\n and clusters with more than 1 malware type")
# how_many_clusters()

# %%
# #REMOVE SINGLE ITEM CLUSTERS
# unique_clusters = get_unique_clusters(malicious_df)
# for u in unique_clusters:
#     if malicious_df[malicious_df['cluster'] == u].shape[0] == 1:
#         malicious_df = malicious_df.drop(malicious_df[malicious_df['cluster'] == u].index)

# print("After removing single-item clusters")
# how_many_clusters()

# %% [markdown]
# ## "What Malware Types can be found in the overall dataset?"
#
# ### This is regardless of cluster.

# %%
output = malicious_df['type'].value_counts()
str_output = str(output) + "\n\n"
with open("./Output/1 MalwareTypes_in_Dataset KMeans.txt", 'w') as f:
    f.write(str_output)
    f.flush
    f.close()
display(output)
fig, axs = plt.subplots(nrows=1, layout='constrained')
fig.set_figwidth(4)
fig.set_figheight(3)
fig.set_dpi(300)
axs.set_title('Malware Type Counts')
axs.barh(malicious_df['type'].value_counts().index, malicious_df['type'].value_counts())
axs.invert_yaxis()
# axs[1].set_title('Type 2 Malware Type Counts')
# axs[1].invert_yaxis()
# axs[1].barh(malicious_df['Type 2'].value_counts().index, malicious_df['Type 2'].value_counts())
# axs[2].invert_yaxis()
# axs[2].set_title('Type 3 (Least \'Popular\') Malware Type Counts')
# axs[2].barh(malicious_df['Type 3'].value_counts().index, malicious_df['Type 3'].value_counts())
plt.savefig("./Output/1 Popular Malware Types in Dataset.png")
# Out:
# type
# trojan        33352
# downloader     2249
# pua            2135
# adware         1815
# ransomware      341
# miner           125
# virus            79
# spyware          48
# hacktool          7
# dropper           5
# worm              3
# Name: count, dtype: int64

# %% [markdown]
# ## "What Malware Types are there in each cluster?"

# %% [markdown]
# ### Identify the counts of Malware Types per Cluster
#
# This indicates the malware types (including the # of instances) found in each cluster.

# %%
str_output = ""
summary = get_summary(malicious_df)
summary.sort()
for s in summary:
    str_output += f"CLUSTER {s[0]}: "
    for t in s[1]:
        str_output += f"{t[0]} ({t[1]}); "
    # str_output += "\n\tType 2: "
    # for t in s[2]:
    #     str_output += f"{t[0]} ({t[1]}); "
    # str_output += "\n\tType 3: "
    # for t in s[3]:
    #     str_output += f"{t[0]} ({t[1]}); "
    # str_output += "\n\tMost Popular Malware Type Combination (in order Most to Least):\n"
    # for i,t in enumerate(s[4]):
    #     str_output += f"\t    {i+1} {t:12s} ({s[5][i]})\n"
    str_output += "\n"
with open("./Output/1 MalwareType_per_Cluster KMeans.txt", 'w') as f:
    f.write(str_output)
    f.flush
    f.close()
print(str_output)
# Out:
# CLUSTER 0: trojan (10089); downloader (1322); pua (1262); adware (878); ransomware (335); miner (107); virus (57); spyware (36); hacktool (7); dropper (2); worm (2);
# CLUSTER 1: trojan (4275); pua (14); adware (13); downloader (5); spyware (2); virus (2); miner (1); worm (1);
# CLUSTER 2: trojan (546); adware (33); pua (4);
# CLUSTER 3: trojan (3809); downloader (498); pua (429); adware (315); virus (19); spyware (8); miner (8); dropper (1); ransomware (1);
# CLUSTER 4: trojan (1988); downloader (397); pua (42); adware (18); virus (1); miner (1);
# CLUSTER 5: trojan (7306); adware (261); pua (38); downloader (13); ransomware (1);
# CLUSTER 6: trojan (903); pua (97); adware (59); downloader (1);
# CLUSTER 7: trojan (727); adware (12); pua (7); miner (4); ransomware (4); downloader (3);
# CLUSTER 8: trojan (1701); adware (11); pua (6); miner (3); spyware (2); downloader (2);
# CLUSTER 9: pua (226); adware (214); trojan (126); downloader (4); dropper (2); miner (1);
# CLUSTER 10: trojan (1882); pua (10); downloader (4); adware (1);

# %% [markdown]
# ### Identify the Clusters that have the same Unique Malware Type
#
# This indicates what clusters have verified malicious samples that match specific Malware Types.
#
# This indicates the most occuring Malware Type which extends to the most 'popular' malware type that is probably found in the dataset.
#
# Such findings may also be used as a reflection as to what malware types are most prevalent in the wild.

# %%
# Summarize Clusters that have the same malware types as per VirusTotal.
str_output = f"# of Unique Malware Type: {len(malicious_df['type'].unique())}" + "\n\n"

cluster_instance_summary = [0] * len(list(malicious_df['cluster'].unique()))
count_summary = []
for i, u in enumerate(list(malicious_df['type'].unique())):
    matching = malicious_df[malicious_df['type'] == u]['cluster']
    count_summary.append([u, len(list(matching)), len(list(matching.unique())) ,str(list(matching.unique()))])
    str_output += f"Unique Malware Type: {i+1}".upper() + "\n"
    str_output += f"Malware Type: {u}" + "\n"
    str_output += f"Matching Clusters Count: {len(list(matching.unique()))}" + "\n"
    str_output += f"Matching Clusters: {list(matching.unique())}" + "\n"
    str_output += "\n"
with open("./Output/1 Clusters_on_Unique_MalwareType KMeans.txt", 'w') as f:
    f.write(str_output)
    f.flush
    f.close()
print(str_output)

count_summary.sort(key=lambda x: x[1])
count_summary = pd.DataFrame(count_summary, columns=['Malware Type', 'No. of Matching Verified Samples', 'No. of Matching Clusters', "Matching Clusters"])

count_summary.sort_values(by='No. of Matching Clusters',ascending=False, inplace=True)
display("Top 10 Most Common Malware Type (by Cluster Count)")
display(count_summary[['Malware Type','No. of Matching Clusters', 'Matching Clusters']].iloc[0:10])
count_summary[['Malware Type','No. of Matching Clusters', 'Matching Clusters']].iloc[0:10].to_csv("./Output/1 10_Most_Common_MalwareType_byClusterCount.csv", index=False)
# Out:
# # of Unique Malware Type: 11
#
# UNIQUE MALWARE TYPE: 1
# Malware Type: trojan
# Matching Clusters Count: 11
# Matching Clusters: [1, 3, 0, 5, 8, 7, 10, 4, 2, 6, 9]
#
# UNIQUE MALWARE TYPE: 2
# Malware Type: pua
# Matching Clusters Count: 11
# Matching Clusters: [3, 0, 9, 5, 6, 10, 4, 2, 8, 1, 7]
#
# UNIQUE MALWARE TYPE: 3
# Malware Type: downloader
# Matching Clusters Count: 10
# Matching Clusters: [4, 0, 3, 5, 9, 8, 10, 7, 1, 6]
#
# UNIQUE MALWARE TYPE: 4
# Malware Type: adware
# Matching Clusters Count: 11
# Matching Clusters: [0, 2, 9, 3, 5, 7, 4, 6, 1, 8, 10]
#
# UNIQUE MALWARE TYPE: 5
# Malware Type: hacktool
# Matching Clusters Count: 1
# Matching Clusters: [0]
#
# UNIQUE MALWARE TYPE: 6
# Malware Type: miner
# Matching Clusters Count: 7
# Matching Clusters: [0, 3, 8, 1, 7, 9, 4]
#
# UNIQUE MALWARE TYPE: 7
# Malware Type: virus
# Matching Clusters Count: 4
# Matching Clusters: [3, 0, 4, 1]
#
# UNIQUE MALWARE TYPE: 8
# Malware Type: spyware
# Matching Clusters Count: 4
# Matching Clusters: [3, 1, 8, 0]
#
# UNIQUE MALWARE TYPE: 9
# Malware Type: ransomware
# Matching Clusters Count: 4
# Matching Clusters: [0, 7, 3, 5]
#
# UNIQUE MALWARE TYPE: 10
# Malware Type: dropper
# Matching Clusters Count: 3
# Matching Clusters: [9, 3, 0]
#
# UNIQUE MALWARE TYPE: 11
# Malware Type: worm
# Matching Clusters Count: 2
# Matching Clusters: [1, 0]
# 'Top 10 Most Common Malware Type (by Cluster Count)'
#    Malware Type  No. of Matching Clusters                   Matching Clusters
# 7        adware                        11  [0, 2, 9, 3, 5, 7, 4, 6, 1, 8, 10]
# 8           pua                        11  [3, 0, 9, 5, 6, 10, 4, 2, 8, 1, 7]
# 10       trojan                        11  [1, 3, 0, 5, 8, 7, 10, 4, 2, 6, 9]
# 9    downloader                        10     [4, 0, 3, 5, 9, 8, 10, 7, 1, 6]
# 5         miner                         7               [0, 3, 8, 1, 7, 9, 4]
# 3       spyware                         4                        [3, 1, 8, 0]
# 4         virus                         4                        [3, 0, 4, 1]
# 6    ransomware                         4                        [0, 7, 3, 5]
# 1       dropper                         3                           [9, 3, 0]
# 0          worm                         2                              [1, 0]

# %% [markdown]
# ## "What the API Calls are in the dataset?"

# %%
pd.set_option("display.max_rows", None)

print("Top 10 API CALLS")
hashes = malicious_df['hash'].to_list()
complete = []
for h in hashes:
    complete += oliveira[oliveira['hash']==h].iloc[0,1:101].to_list()
ser = pd.Series(complete)
#ser.value_counts().to_csv(f"./Output/1_APICALL_{m}.csv")
#malware_apis.append(ser.unique().tolist())
display(ser.value_counts())
# Out:
# Top 10 API CALLS
# LdrGetProcedureAddress               684504
# LdrLoadDll                           387648
# LdrGetDllHandle                      294529
# RegOpenKeyExW                        239206
# NtClose                              198062
# LoadResource                         184249
# FindResourceExW                      180030
# RegQueryValueExW                     170414
# RegCloseKey                          166678
# NtAllocateVirtualMemory              162050
# NtQueryValueKey                       92522
# NtOpenKey                             92296
# GetSystemMetrics                      79314
# GetSystemTimeAsFileTime               70245
# SetErrorMode                          47872
# GetSystemInfo                         35967
# NtFreeVirtualMemory                   34822
# NtCreateFile                          32281
# NtProtectVirtualMemory                31475
# RegOpenKeyExA                         29783
# NtDelayExecution                      29248
# GetSystemWindowsDirectoryW            27000
# LoadStringW                           26591
# RegQueryInfoKeyW                      26402
# GetSystemDirectoryW                   24682
# DrawTextExW                           24673
# NtMapViewOfSection                    24454
# SetUnhandledExceptionFilter           24448
# CoInitializeEx                        22414
# FindFirstFileExW                      22117
# LoadStringA                           20473
# NtReadFile                            20331
# RegEnumKeyW                           19202
# SetFilePointer                        19109
# NtCreateSection                       18650
# NtOpenKeyEx                           18356
# EnumWindows                           18332
# NtQuerySystemInformation              17736
# GetFileSize                           15895
# RegEnumKeyExW                         15627
# CoCreateInstance                      15034
# CreateThread                          14082
# SizeofResource                        13632
# GetFileAttributesW                    12856
# RegQueryValueExA                      12473
# LookupAccountSidW                     12085
# CreateActCtxW                         12036
# CryptAcquireContextW                  12002
# NtDuplicateObject                     11582
# OleInitialize                         11498
# GetNativeSystemInfo                   10825
# RegCreateKeyExW                        9994
# RegSetValueExW                         9816
# FindResourceW                          9067
# NtCreateMutant                         8907
# UuidCreate                             8323
# NtQueryAttributesFile                  8309
# CryptHashData                          7959
# CryptCreateHash                        7918
# NtDeviceIoControlFile                  6739
# FindResourceA                          6358
# GetFileType                            6077
# GetCursorPos                           5985
# WSAStartup                             5973
# RegEnumValueW                          5840
# NtUnmapViewOfSection                   5576
# NtOpenDirectoryObject                  5348
# __exception__                          5194
# GetTimeZoneInformation                 4934
# NtOpenFile                             4753
# NtQueryDirectoryFile                   4663
# LdrUnloadDll                           4333
# NtQueryInformationFile                 3569
# NtOpenSection                          3463
# GetSystemDirectoryA                    3243
# NtOpenProcess                          3020
# CryptDecrypt                           3014
# NtWriteFile                            2862
# GetUserNameW                           2715
# IsDebuggerPresent                      2621
# GetTempPathW                           2612
# NtCreateThreadEx                       2475
# NtResumeThread                         2396
# GetVolumeNameForVolumeMountPointW      2333
# NtEnumerateValueKey                    2127
# NtEnumerateKey                         2038
# SearchPathW                            1906
# SetWindowsHookExA                      1893
# NtSetInformationFile                   1830
# FindResourceExA                        1618
# GetFileVersionInfoSizeW                1471
# SHGetFolderPathW                       1467
# GetForegroundWindow                    1459
# Process32NextW                         1439
# CreateToolhelp32Snapshot               1387
# NtOpenMutant                           1376
# GlobalMemoryStatus                     1323
# OutputDebugStringA                     1310
# GetFileVersionInfoW                    1276
# Process32FirstW                        1227
# RegCreateKeyExA                        1195
# timeGetTime                            1183
# CreateDirectoryW                       1132
# NtQueryKey                             1069
# GetFileInformationByHandle              965
# RegSetValueExA                          875
# SetEndOfFile                            856
# ReadProcessMemory                       822
# GlobalMemoryStatusEx                    802
# socket                                  764
# LookupPrivilegeValueW                   608
# FindWindowW                             512
# SetFilePointerEx                        506
# RegEnumKeyExA                           506
# NtOpenThread                            505
# CreateProcessInternalW                  474
# DeleteFileW                             425
# connect                                 420
# SetFileAttributesW                      389
# FindWindowA                             386
# CreateJobObjectW                        386
# NtCreateKey                             378
# WriteProcessMemory                      374
# select                                  374
# MoveFileWithProgressW                   351
# GetFileSizeEx                           325
# GetFileAttributesExW                    317
# OpenSCManagerA                          302
# WriteConsoleA                           297
# SetFileTime                             292
# closesocket                             289
# GetDiskFreeSpaceW                       271
# InternetOpenA                           265
# CopyFileW                               261
# GetShortPathNameW                       255
# GetComputerNameW                        242
# ioctlsocket                             242
# DeviceIoControl                         241
# getaddrinfo                             240
# InternetSetOptionA                      230
# OpenServiceA                            225
# CryptEncrypt                            224
# FindWindowExW                           215
# InternetConnectA                        205
# gethostbyname                           203
# IWbemServices_ExecQuery                 195
# NtSetValueKey                           194
# GetDiskFreeSpaceExW                     189
# HttpOpenRequestA                        189
# OpenSCManagerW                          182
# CopyFileExW                             182
# GetAdaptersInfo                         178
# SetWindowsHookExW                       171
# CopyFileA                               163
# GetVolumePathNamesForVolumeNameW        161
# GetComputerNameA                        155
# CoInitializeSecurity                    146
# RemoveDirectoryW                        143
# OpenServiceW                            139
# NtTerminateProcess                      139
# CoUninitialize                          137
# GetUserNameA                            136
# FindWindowExA                           136
# CoGetClassObject                        121
# RemoveDirectoryA                         94
# CoCreateInstanceEx                       92
# send                                     85
# NtSetContextThread                       83
# recv                                     78
# Thread32Next                             73
# GetAsyncKeyState                         73
# GetSystemWindowsDirectoryA               72
# Thread32First                            72
# RegEnumValueA                            70
# SetStdHandle                             68
# CryptAcquireContextA                     67
# InternetCrackUrlA                        65
# GetKeyState                              65
# NtGetContextThread                       52
# InternetOpenW                            46
# bind                                     45
# StartServiceA                            42
# ShellExecuteExW                          39
# DrawTextExA                              37
# NtQueueApcThread                         37
# setsockopt                               37
# CreateServiceA                           36
# GetAdaptersAddresses                     34
# NtSuspendThread                          31
# InternetConnectW                         30
# CryptProtectData                         30
# HttpOpenRequestW                         30
# SHGetSpecialFolderLocation               29
# getsockname                              29
# RtlAddVectoredExceptionHandler           27
# InternetCrackUrlW                        25
# MessageBoxTimeoutA                       25
# GetVolumePathNameW                       25
# InternetCloseHandle                      25
# GetBestInterfaceEx                       24
# DeleteUrlCacheEntryW                     22
# NtTerminateThread                        21
# WSARecv                                  20
# RtlDecompressBuffer                      18
# UnhookWindowsHookEx                      17
# Module32FirstW                           16
# Module32NextW                            15
# HttpSendRequestA                         15
# RegisterHotKey                           15
# StartServiceW                            14
# NtWriteVirtualMemory                     13
# CryptGenKey                              13
# shutdown                                 12
# DnsQuery_A                                9
# InternetOpenUrlA                          9
# CreateServiceW                            9
# CryptExportKey                            8
# DeleteUrlCacheEntryA                      8
# RegDeleteKeyW                             6
# CryptDecodeObjectEx                       6
# MessageBoxTimeoutW                        5
# NtReadVirtualMemory                       5
# RegDeleteValueA                           4
# RegQueryInfoKeyA                          4
# InternetGetConnectedState                 4
# GetUserNameExA                            3
# GetKeyboardState                          3
# CertOpenStore                             3
# InternetQueryOptionA                      3
# InternetReadFile                          2
# RegDeleteValueW                           2
# EnumServicesStatusA                       2
# HttpQueryInfoA                            2
# RtlRemoveVectoredExceptionHandler         2
# CreateRemoteThread                        2
# GetAddrInfoW                              2
# InternetSetStatusCallback                 1
# ObtainUserAgentString                     1
# SetFileInformationByHandle                1
# ControlService                            1
# SendNotifyMessageW                        1
# SetInformationJobObject                   1
# WSASocketA                                1
# sendto                                    1
# GetFileInformationByHandleEx              1
# InternetOpenUrlW                          1
# NetUserGetInfo                            1
# WSASocketW                                1
# Name: count, dtype: int64

# %% [markdown]
# ## "What the API Calls are in each Malware Type"

# %%
malware_types = count_summary['Malware Type'].to_list()
malware_apis = []

pd.set_option("display.max_rows", None)

print("Top 10 API CALLS PER MALWARE TYPE")
for m in malware_types:
    hashes = malicious_df[malicious_df['type'] == m]['hash'].to_list()
    complete = []
    for h in hashes:
        complete += oliveira[oliveira['hash']==h].iloc[0,1:101].to_list()
    ser = pd.Series(complete, name=m)
    ser.value_counts().to_csv(f"./Output/1_APICALL_{m}.csv")
    malware_apis.append(ser.unique().tolist())
    display(ser.value_counts())
# Out:
# Top 10 API CALLS PER MALWARE TYPE
# adware
# LdrGetProcedureAddress               29719
# LdrLoadDll                           17137
# LdrGetDllHandle                      14452
# RegOpenKeyExW                        11124
# NtClose                              10646
# RegCloseKey                           9368
# RegQueryValueExW                      8256
# NtAllocateVirtualMemory               7791
# SetErrorMode                          4955
# NtOpenKey                             4454
# NtQueryValueKey                       4126
# GetSystemTimeAsFileTime               3230
# NtCreateFile                          2799
# GetSystemWindowsDirectoryW            2343
# GetSystemDirectoryW                   2231
# LoadResource                          2049
# NtMapViewOfSection                    2048
# NtReadFile                            1879
# GetSystemMetrics                      1841
# NtFreeVirtualMemory                   1784
# RegOpenKeyExA                         1747
# NtCreateSection                       1547
# SetFilePointer                        1525
# FindResourceExW                       1516
# NtDelayExecution                      1475
# SetUnhandledExceptionFilter           1452
# GetSystemInfo                         1395
# NtProtectVirtualMemory                1380
# CoInitializeEx                        1104
# LoadStringW                           1065
# RegEnumKeyW                            941
# GetFileSize                            859
# NtQueryAttributesFile                  850
# NtCreateMutant                         831
# SizeofResource                         802
# NtDuplicateObject                      778
# CreateThread                           762
# RegQueryValueExA                       710
# CoCreateInstance                       692
# FindResourceW                          686
# EnumWindows                            671
# GetFileAttributesW                     620
# RegCreateKeyExW                        600
# NtOpenFile                             561
# GetNativeSystemInfo                    557
# RegQueryInfoKeyW                       546
# CreateActCtxW                          542
# RegSetValueExW                         515
# RegEnumKeyExW                          458
# DrawTextExW                            453
# OleInitialize                          433
# UuidCreate                             426
# WSAStartup                             418
# CryptAcquireContextW                   393
# SHGetFolderPathW                       389
# RegSetValueExA                         381
# NtOpenKeyEx                            373
# RegCreateKeyExA                        360
# NtOpenSection                          300
# CryptHashData                          269
# CryptCreateHash                        269
# socket                                 262
# GetVolumeNameForVolumeMountPointW      246
# LoadStringA                            233
# Process32NextW                         225
# CreateToolhelp32Snapshot               223
# Process32FirstW                        223
# select                                 213
# FindFirstFileExW                       212
# NtOpenDirectoryObject                  199
# FindResourceA                          197
# ioctlsocket                            197
# NtQuerySystemInformation               193
# connect                                192
# NtQueryInformationFile                 179
# NtResumeThread                         173
# GetSystemDirectoryA                    171
# GetFileType                            171
# NtWriteFile                            171
# IsDebuggerPresent                      164
# GetTimeZoneInformation                 163
# LookupAccountSidW                      150
# LdrUnloadDll                           149
# getaddrinfo                            142
# NtCreateThreadEx                       140
# CreateDirectoryW                       137
# CryptDecrypt                           120
# GetFileVersionInfoSizeW                116
# NtOpenMutant                           115
# IWbemServices_ExecQuery                112
# closesocket                            111
# GetUserNameW                           110
# GetFileVersionInfoW                    107
# GetAdaptersInfo                        106
# GetTempPathW                           105
# NtQueryDirectoryFile                   100
# NtOpenProcess                           88
# __exception__                           85
# FindWindowExW                           84
# CoInitializeSecurity                    82
# NtDeviceIoControlFile                   82
# NtEnumerateKey                          76
# NtEnumerateValueKey                     76
# DeviceIoControl                         72
# WriteProcessMemory                      67
# NtUnmapViewOfSection                    65
# GetComputerNameW                        63
# GetForegroundWindow                     58
# GlobalMemoryStatusEx                    56
# GetFileAttributesExW                    52
# OutputDebugStringA                      50
# CoGetClassObject                        49
# CoCreateInstanceEx                      49
# RegEnumValueW                           47
# GetCursorPos                            46
# DeleteFileW                             44
# SetEndOfFile                            38
# OpenSCManagerW                          30
# GetComputerNameA                        30
# FindResourceExA                         29
# OpenServiceW                            29
# SetWindowsHookExW                       29
# CreateJobObjectW                        26
# NtQueryKey                              22
# CreateProcessInternalW                  18
# NtSetInformationFile                    18
# ReadProcessMemory                       18
# FindWindowW                             16
# SetWindowsHookExA                       15
# RemoveDirectoryA                        13
# RegEnumKeyExA                           11
# NtOpenThread                            10
# ShellExecuteExW                         10
# MoveFileWithProgressW                    9
# NtTerminateProcess                       9
# SetFileTime                              8
# GetDiskFreeSpaceW                        7
# InternetConnectA                         7
# InternetSetOptionA                       7
# SetFileAttributesW                       7
# InternetCrackUrlA                        7
# CoUninitialize                           7
# InternetOpenA                            7
# SearchPathW                              6
# OpenSCManagerA                           6
# SetFilePointerEx                         6
# CopyFileW                                4
# WriteConsoleA                            4
# GetVolumePathNamesForVolumeNameW         3
# GetUserNameA                             3
# OpenServiceA                             3
# HttpOpenRequestW                         2
# GlobalMemoryStatus                       2
# InternetConnectW                         2
# RegDeleteValueW                          2
# InternetOpenW                            2
# RegDeleteKeyW                            2
# RemoveDirectoryW                         2
# HttpOpenRequestA                         2
# DrawTextExA                              2
# GetDiskFreeSpaceExW                      1
# gethostbyname                            1
# RegEnumValueA                            1
# FindWindowA                              1
# MessageBoxTimeoutA                       1
# CryptAcquireContextA                     1
# SHGetSpecialFolderLocation               1
# LookupPrivilegeValueW                    1
# RegQueryInfoKeyA                         1
# Name: count, dtype: int64
# pua
# LdrGetProcedureAddress               40755
# LdrGetDllHandle                      21618
# LdrLoadDll                           21085
# NtClose                              13343
# NtAllocateVirtualMemory              11072
# RegOpenKeyExW                         8932
# RegCloseKey                           8228
# RegQueryValueExW                      5881
# SetErrorMode                          5296
# NtOpenKey                             4845
# NtQueryValueKey                       4480
# GetSystemMetrics                      3512
# LoadResource                          3190
# NtReadFile                            3149
# FindResourceExW                       3064
# NtCreateFile                          3053
# SetFilePointer                        3046
# NtFreeVirtualMemory                   2767
# GetSystemWindowsDirectoryW            2570
# NtMapViewOfSection                    2539
# GetSystemTimeAsFileTime               2506
# GetSystemDirectoryW                   2335
# NtProtectVirtualMemory                2056
# RegOpenKeyExA                         1933
# NtCreateSection                       1884
# GetSystemInfo                         1804
# SetUnhandledExceptionFilter           1413
# LoadStringW                           1396
# RegQueryValueExA                      1238
# NtDeviceIoControlFile                 1134
# FindFirstFileExW                      1033
# GetNativeSystemInfo                   1008
# NtQueryAttributesFile                  939
# OutputDebugStringA                     908
# NtCreateMutant                         868
# CoInitializeEx                         784
# NtDuplicateObject                      783
# GetFileSize                            768
# RegEnumKeyW                            742
# GetFileAttributesW                     681
# DrawTextExW                            656
# CreateActCtxW                          549
# SizeofResource                         536
# NtOpenKeyEx                            495
# FindResourceW                          468
# NtDelayExecution                       445
# SHGetFolderPathW                       445
# CreateThread                           441
# OleInitialize                          437
# WSAStartup                             374
# NtOpenSection                          352
# CryptAcquireContextW                   351
# LoadStringA                            321
# IsDebuggerPresent                      315
# NtOpenMutant                           305
# NtQuerySystemInformation               305
# NtOpenProcess                          303
# LookupAccountSidW                      287
# NtOpenFile                             265
# GetTimeZoneInformation                 244
# RegCreateKeyExW                        243
# NtOpenDirectoryObject                  242
# RegSetValueExW                         236
# GetVolumeNameForVolumeMountPointW      235
# CryptDecrypt                           233
# CreateDirectoryW                       221
# GetForegroundWindow                    216
# UuidCreate                             215
# NtWriteFile                            209
# GetCursorPos                           204
# GetFileType                            200
# GetSystemDirectoryA                    171
# GetUserNameW                           160
# GetFileVersionInfoSizeW                155
# NtResumeThread                         151
# LdrUnloadDll                           147
# CoCreateInstance                       146
# GetFileVersionInfoW                    144
# RegQueryInfoKeyW                       144
# NtCreateThreadEx                       132
# NtQueryInformationFile                 130
# NtSetInformationFile                   114
# GlobalMemoryStatusEx                   113
# CryptHashData                          109
# CryptCreateHash                        109
# NtUnmapViewOfSection                   103
# FindResourceA                           99
# socket                                  97
# NtQueryDirectoryFile                    97
# RegCreateKeyExA                         96
# GetTempPathW                            93
# FindWindowW                             87
# RegEnumKeyExW                           87
# EnumWindows                             79
# SetFileAttributesW                      74
# DeleteFileW                             74
# SetEndOfFile                            71
# __exception__                           63
# CreateJobObjectW                        55
# CreateProcessInternalW                  54
# GetFileAttributesExW                    53
# SetFilePointerEx                        51
# RemoveDirectoryW                        49
# GetFileSizeEx                           48
# SetFileTime                             46
# MoveFileWithProgressW                   42
# NtEnumerateValueKey                     42
# NtEnumerateKey                          42
# CreateToolhelp32Snapshot                41
# Process32NextW                          38
# Process32FirstW                         38
# RegSetValueExA                          38
# connect                                 37
# CopyFileW                               35
# GetDiskFreeSpaceW                       34
# RegEnumValueW                           32
# GetDiskFreeSpaceExW                     30
# FindWindowA                             28
# DeviceIoControl                         27
# select                                  27
# ReadProcessMemory                       25
# FindWindowExA                           25
# closesocket                             24
# IWbemServices_ExecQuery                 24
# SetWindowsHookExW                       24
# CoUninitialize                          23
# RegEnumKeyExA                           22
# SearchPathW                             21
# InternetOpenW                           21
# WriteProcessMemory                      20
# DeleteUrlCacheEntryW                    20
# SetWindowsHookExA                       19
# InternetCrackUrlW                       19
# HttpOpenRequestW                        19
# InternetConnectW                        19
# ioctlsocket                             19
# gethostbyname                           18
# setsockopt                              15
# send                                    15
# getaddrinfo                             13
# GetComputerNameW                        12
# NtQueryKey                              12
# WSARecv                                 11
# RemoveDirectoryA                        10
# shutdown                                10
# GetAdaptersInfo                         10
# timeGetTime                              9
# CoInitializeSecurity                     9
# FindResourceExA                          8
# NtOpenThread                             8
# FindWindowExW                            7
# CoGetClassObject                         6
# CoCreateInstanceEx                       6
# OpenServiceA                             5
# NtTerminateProcess                       5
# GetAsyncKeyState                         5
# OpenSCManagerA                           5
# InternetSetOptionA                       4
# GetKeyState                              4
# InternetOpenA                            3
# CopyFileExW                              2
# Thread32First                            2
# Thread32Next                             2
# InternetConnectA                         2
# InternetCrackUrlA                        2
# MessageBoxTimeoutA                       2
# RegQueryInfoKeyA                         2
# SHGetSpecialFolderLocation               2
# GetFileInformationByHandle               2
# OpenSCManagerW                           1
# GetVolumePathNamesForVolumeNameW         1
# getsockname                              1
# MessageBoxTimeoutW                       1
# recv                                     1
# bind                                     1
# DeleteUrlCacheEntryA                     1
# ShellExecuteExW                          1
# RegDeleteKeyW                            1
# OpenServiceW                             1
# Name: count, dtype: int64
# trojan
# LdrGetProcedureAddress               548127
# LdrLoadDll                           326998
# LdrGetDllHandle                      216319
# RegOpenKeyExW                        205692
# LoadResource                         171409
# FindResourceExW                      167824
# NtClose                              161696
# RegQueryValueExW                     145930
# RegCloseKey                          134071
# NtAllocateVirtualMemory              125861
# NtQueryValueKey                       80045
# NtOpenKey                             78843
# GetSystemMetrics                      71530
# GetSystemTimeAsFileTime               61271
# SetErrorMode                          35725
# GetSystemInfo                         32018
# NtProtectVirtualMemory                27825
# NtDelayExecution                      26882
# RegQueryInfoKeyW                      25593
# NtCreateFile                          23976
# DrawTextExW                           23272
# LoadStringW                           22690
# NtFreeVirtualMemory                   22664
# RegOpenKeyExA                         22177
# CoInitializeEx                        20340
# FindFirstFileExW                      20267
# SetUnhandledExceptionFilter           20140
# LoadStringA                           19690
# GetSystemWindowsDirectoryW            19547
# GetSystemDirectoryW                   18768
# EnumWindows                           17530
# NtOpenKeyEx                           17338
# NtMapViewOfSection                    17329
# RegEnumKeyW                           16783
# RegEnumKeyExW                         15044
# NtReadFile                            14480
# CoCreateInstance                      14146
# SetFilePointer                        14017
# GetFileSize                           13816
# NtCreateSection                       13333
# CreateThread                          12342
# SizeofResource                        12148
# GetFileAttributesW                    11295
# LookupAccountSidW                     10840
# CryptAcquireContextW                  10723
# CreateActCtxW                         10395
# OleInitialize                          9661
# NtQuerySystemInformation               9341
# NtDuplicateObject                      9303
# RegCreateKeyExW                        9107
# RegSetValueExW                         9027
# GetNativeSystemInfo                    8543
# RegQueryValueExA                       7850
# FindResourceW                          7819
# UuidCreate                             7656
# CryptCreateHash                        7428
# CryptHashData                          7427
# NtCreateMutant                         6527
# FindResourceA                          5988
# NtQueryAttributesFile                  5896
# GetCursorPos                           5718
# RegEnumValueW                          5718
# GetFileType                            5620
# NtDeviceIoControlFile                  5523
# WSAStartup                             5047
# __exception__                          4965
# NtUnmapViewOfSection                   4951
# NtOpenDirectoryObject                  4829
# GetTimeZoneInformation                 4488
# NtQueryDirectoryFile                   4221
# LdrUnloadDll                           3793
# NtOpenFile                             3505
# NtQueryInformationFile                 2919
# GetSystemDirectoryA                    2798
# CryptDecrypt                           2564
# GetUserNameW                           2430
# NtCreateThreadEx                       2190
# NtOpenSection                          2169
# IsDebuggerPresent                      2094
# NtWriteFile                            2086
# NtResumeThread                         2048
# GetTempPathW                           2016
# NtEnumerateValueKey                    1968
# NtEnumerateKey                         1880
# SearchPathW                            1871
# SetWindowsHookExA                      1833
# NtSetInformationFile                   1693
# FindResourceExA                        1567
# NtOpenProcess                          1434
# GlobalMemoryStatus                     1321
# GetVolumeNameForVolumeMountPointW      1281
# GetFileVersionInfoSizeW                1188
# GetForegroundWindow                    1154
# timeGetTime                            1144
# GetFileVersionInfoW                    1014
# NtQueryKey                             1012
# Process32NextW                          981
# GetFileInformationByHandle              963
# CreateToolhelp32Snapshot                923
# NtOpenMutant                            906
# Process32FirstW                         805
# ReadProcessMemory                       766
# SetEndOfFile                            734
# RegCreateKeyExA                         690
# CreateDirectoryW                        689
# GlobalMemoryStatusEx                    614
# LookupPrivilegeValueW                   603
# SHGetFolderPathW                        593
# NtOpenThread                            485
# RegEnumKeyExA                           472
# SetFilePointerEx                        427
# FindWindowW                             403
# RegSetValueExA                          399
# NtCreateKey                             372
# FindWindowA                             351
# CreateProcessInternalW                  345
# OutputDebugStringA                      343
# socket                                  326
# CreateJobObjectW                        305
# MoveFileWithProgressW                   296
# OpenSCManagerA                          285
# DeleteFileW                             283
# SetFileAttributesW                      280
# WriteProcessMemory                      277
# GetFileSizeEx                           272
# WriteConsoleA                           271
# InternetOpenA                           250
# GetShortPathNameW                       248
# GetDiskFreeSpaceW                       227
# SetFileTime                             226
# CryptEncrypt                            224
# CopyFileW                               219
# InternetSetOptionA                      215
# OpenServiceA                            212
# GetFileAttributesExW                    206
# InternetConnectA                        194
# connect                                 190
# HttpOpenRequestA                        187
# gethostbyname                           184
# NtSetValueKey                           181
# CopyFileExW                             180
# GetDiskFreeSpaceExW                     158
# CopyFileA                               152
# GetVolumePathNamesForVolumeNameW        151
# GetComputerNameW                        151
# OpenSCManagerW                          150
# DeviceIoControl                         139
# select                                  134
# GetUserNameA                            130
# FindWindowExW                           124
# GetComputerNameA                        123
# NtTerminateProcess                      123
# SetWindowsHookExW                       114
# FindWindowExA                           111
# OpenServiceW                            109
# closesocket                             102
# CoUninitialize                          100
# RemoveDirectoryW                         88
# NtSetContextThread                       82
# getaddrinfo                              82
# recv                                     77
# GetSystemWindowsDirectoryA               71
# send                                     70
# RegEnumValueA                            68
# SetStdHandle                             68
# GetAsyncKeyState                         66
# CryptAcquireContextA                     66
# CoGetClassObject                         63
# Thread32Next                             63
# Thread32First                            62
# GetAdaptersInfo                          61
# GetKeyState                              61
# RemoveDirectoryA                         61
# IWbemServices_ExecQuery                  58
# InternetCrackUrlA                        54
# CoInitializeSecurity                     51
# NtGetContextThread                       50
# bind                                     43
# StartServiceA                            41
# NtQueueApcThread                         37
# CreateServiceA                           35
# CoCreateInstanceEx                       34
# DrawTextExA                              34
# GetAdaptersAddresses                     34
# NtSuspendThread                          31
# CryptProtectData                         30
# ShellExecuteExW                          27
# getsockname                              27
# ioctlsocket                              26
# GetVolumePathNameW                       25
# InternetCloseHandle                      25
# GetBestInterfaceEx                       24
# SHGetSpecialFolderLocation               23
# setsockopt                               22
# MessageBoxTimeoutA                       22
# InternetOpenW                            22
# RtlAddVectoredExceptionHandler           21
# RtlDecompressBuffer                      18
# UnhookWindowsHookEx                      16
# Module32FirstW                           16
# Module32NextW                            15
# RegisterHotKey                           15
# HttpSendRequestA                         15
# StartServiceW                            14
# NtWriteVirtualMemory                     10
# DnsQuery_A                                9
# InternetOpenUrlA                          9
# WSARecv                                   9
# CreateServiceW                            9
# InternetConnectW                          8
# HttpOpenRequestW                          8
# CryptGenKey                               6
# InternetCrackUrlW                         6
# DeleteUrlCacheEntryA                      6
# RegDeleteValueA                           4
# InternetGetConnectedState                 4
# GetUserNameExA                            3
# GetKeyboardState                          3
# NtReadVirtualMemory                       3
# InternetQueryOptionA                      3
# DeleteUrlCacheEntryW                      2
# CryptExportKey                            2
# HttpQueryInfoA                            2
# InternetReadFile                          2
# shutdown                                  2
# RtlRemoveVectoredExceptionHandler         2
# CryptDecodeObjectEx                       2
# NtTerminateThread                         2
# RegDeleteKeyW                             2
# GetAddrInfoW                              2
# MessageBoxTimeoutW                        2
# EnumServicesStatusA                       2
# CreateRemoteThread                        2
# sendto                                    1
# InternetOpenUrlW                          1
# WSASocketA                                1
# SetInformationJobObject                   1
# WSASocketW                                1
# SendNotifyMessageW                        1
# ControlService                            1
# RegQueryInfoKeyA                          1
# ObtainUserAgentString                     1
# InternetSetStatusCallback                 1
# GetFileInformationByHandleEx              1
# SetFileInformationByHandle                1
# NetUserGetInfo                            1
# Name: count, dtype: int64
# downloader
# LdrGetProcedureAddress               61127
# LdrGetDllHandle                      39862
# LdrLoadDll                           19778
# RegCloseKey                          12705
# RegOpenKeyExW                        11211
# NtAllocateVirtualMemory              10893
# RegQueryValueExW                      8453
# NtClose                               8350
# FindResourceExW                       6666
# LoadResource                          6659
# RegOpenKeyExA                         3576
# GetSystemTimeAsFileTime               2940
# NtOpenKey                             2763
# NtQueryValueKey                       2586
# RegQueryValueExA                      2566
# NtFreeVirtualMemory                   2492
# GetSystemMetrics                      2028
# GetSystemWindowsDirectoryW            1807
# SetErrorMode                          1597
# NtMapViewOfSection                    1355
# SetUnhandledExceptionFilter           1331
# LoadStringW                           1313
# NtOpenProcess                         1176
# NtCreateFile                          1043
# GetSystemDirectoryW                   1032
# OleInitialize                          903
# LookupAccountSidW                      802
# NtCreateSection                        743
# RegEnumKeyW                            703
# NtOpenSection                          609
# GetNativeSystemInfo                    604
# CreateActCtxW                          513
# GetVolumeNameForVolumeMountPointW      495
# NtDuplicateObject                      492
# FindFirstFileExW                       445
# GetSystemInfo                          445
# NtQueryDirectoryFile                   210
# CryptAcquireContextW                   206
# NtCreateMutant                         195
# DrawTextExW                            193
# CoInitializeEx                         155
# NtReadFile                             133
# GetFileAttributesW                     129
# SetFilePointer                         122
# CryptHashData                          109
# CryptCreateHash                        109
# NtUnmapViewOfSection                   104
# CryptDecrypt                            97
# GetSystemDirectoryA                     62
# NtDelayExecution                        53
# GetFileSize                             50
# EnumWindows                             50
# SizeofResource                          44
# RegQueryInfoKeyW                        44
# NtWriteFile                             43
# LdrUnloadDll                            39
# CoCreateInstance                        36
# RegCreateKeyExW                         34
# NtProtectVirtualMemory                  31
# LoadStringA                             30
# NtOpenKeyEx                             30
# NtQueryAttributesFile                   29
# RegSetValueExW                          29
# CreateThread                            28
# FindResourceW                           27
# GetTimeZoneInformation                  27
# NtOpenMutant                            24
# RegEnumKeyExW                           22
# CreateDirectoryW                        20
# IsDebuggerPresent                       20
# SHGetFolderPathW                        20
# NtOpenFile                              19
# GetForegroundWindow                     17
# UuidCreate                              17
# NtQuerySystemInformation                16
# RegCreateKeyExA                         15
# GetFileType                             14
# FindResourceA                           13
# RegEnumValueW                           12
# NtResumeThread                          10
# SetWindowsHookExA                        9
# ReadProcessMemory                        9
# GetFileVersionInfoSizeW                  8
# GetFileVersionInfoW                      7
# RegSetValueExA                           7
# GetTempPathW                             6
# NtEnumerateKey                           6
# NtEnumerateValueKey                      6
# __exception__                            6
# GetCursorPos                             5
# DeleteFileW                              5
# CryptDecodeObjectEx                      4
# WSAStartup                               4
# OpenServiceA                             4
# OpenSCManagerA                           4
# NtOpenDirectoryObject                    4
# CertOpenStore                            3
# GetShortPathNameW                        3
# InternetSetOptionA                       3
# InternetOpenA                            3
# SetFileAttributesW                       3
# NtQueryKey                               3
# timeGetTime                              2
# GetAsyncKeyState                         2
# SetFilePointerEx                         2
# FindResourceExA                          2
# OutputDebugStringA                       2
# SetEndOfFile                             2
# RemoveDirectoryA                         2
# CreateProcessInternalW                   2
# InternetConnectA                         2
# InternetCrackUrlA                        2
# NtOpenThread                             2
# WriteConsoleA                            2
# NtCreateThreadEx                         1
# SHGetSpecialFolderLocation               1
# CoUninitialize                           1
# SetWindowsHookExW                        1
# GetComputerNameW                         1
# RegDeleteKeyW                            1
# GetUserNameW                             1
# DrawTextExA                              1
# UnhookWindowsHookEx                      1
# socket                                   1
# bind                                     1
# getsockname                              1
# connect                                  1
# getaddrinfo                              1
# Name: count, dtype: int64
# miner
# LdrGetProcedureAddress               1224
# NtClose                               983
# LdrLoadDll                            705
# LdrGetDllHandle                       625
# RegOpenKeyExW                         511
# NtCreateFile                          506
# NtQueryAttributesFile                 506
# RegCloseKey                           471
# NtAllocateVirtualMemory               421
# NtMapViewOfSection                    406
# NtCreateSection                       389
# RegQueryValueExW                      372
# NtUnmapViewOfSection                  338
# NtReadFile                            277
# NtOpenKey                             273
# NtQueryValueKey                       245
# GetSystemWindowsDirectoryW            237
# SetFilePointer                        211
# GetSystemTimeAsFileTime               209
# GetSystemDirectoryW                   202
# LdrUnloadDll                          192
# GetSystemInfo                         184
# LoadResource                          183
# FindResourceExW                       122
# NtDuplicateObject                     110
# NtProtectVirtualMemory                104
# NtFreeVirtualMemory                   103
# RegOpenKeyExA                         102
# SetErrorMode                          102
# WSAStartup                            101
# NtCreateMutant                         97
# SetUnhandledExceptionFilter            86
# Process32NextW                         80
# GetNativeSystemInfo                    79
# socket                                 78
# LoadStringW                            76
# CreateToolhelp32Snapshot               74
# SizeofResource                         73
# __exception__                          66
# NtOpenDirectoryObject                  65
# NtOpenKeyEx                            65
# NtWriteFile                            62
# NtDelayExecution                       61
# FindFirstFileExW                       60
# GetSystemMetrics                       55
# FindResourceW                          53
# closesocket                            52
# GetFileAttributesW                     52
# GetFileType                            51
# Process32FirstW                        46
# CryptHashData                          43
# NtQuerySystemInformation               41
# RegQueryInfoKeyW                       38
# GetSystemDirectoryA                    36
# GetFileSize                            31
# FindResourceA                          29
# timeGetTime                            28
# OleInitialize                          27
# RegQueryValueExA                       26
# CreateThread                           25
# NtOpenFile                             22
# CreateProcessInternalW                 19
# WriteConsoleA                          19
# CreateDirectoryW                       18
# RegEnumValueW                          17
# SetFileAttributesW                     16
# GetVolumeNameForVolumeMountPointW      16
# IsDebuggerPresent                      13
# SetFileTime                            12
# NtOpenSection                          12
# GlobalMemoryStatusEx                   11
# SetFilePointerEx                       11
# GetTempPathW                           11
# LoadStringA                            10
# NtQueryKey                             10
# NtResumeThread                          9
# WriteProcessMemory                      9
# NtEnumerateValueKey                     9
# NtOpenProcess                           8
# NtCreateThreadEx                        8
# CopyFileA                               8
# Thread32Next                            8
# Thread32First                           8
# NtEnumerateKey                          8
# RegEnumKeyExW                           7
# GetForegroundWindow                     7
# GetVolumePathNamesForVolumeNameW        6
# CreateActCtxW                           6
# DeleteFileW                             6
# DrawTextExW                             6
# GetFileAttributesExW                    6
# RtlAddVectoredExceptionHandler          6
# NtQueryDirectoryFile                    5
# OutputDebugStringA                      5
# SetEndOfFile                            5
# RegEnumKeyW                             4
# SHGetFolderPathW                        4
# CoCreateInstance                        4
# FindWindowA                             4
# CoInitializeEx                          4
# NtQueryInformationFile                  3
# NtWriteVirtualMemory                    3
# RegSetValueExA                          3
# NtGetContextThread                      2
# NtReadVirtualMemory                     2
# NtOpenMutant                            2
# GetComputerNameA                        2
# GetTimeZoneInformation                  2
# CoUninitialize                          2
# MoveFileWithProgressW                   2
# ReadProcessMemory                       2
# GetDiskFreeSpaceW                       2
# RemoveDirectoryW                        2
# GetCursorPos                            2
# RemoveDirectoryA                        2
# RegCreateKeyExA                         2
# LookupAccountSidW                       2
# SearchPathW                             2
# SetWindowsHookExA                       2
# getaddrinfo                             1
# NtTerminateProcess                      1
# DeleteUrlCacheEntryA                    1
# LookupPrivilegeValueW                   1
# InternetOpenA                           1
# InternetSetOptionA                      1
# CryptAcquireContextW                    1
# CryptCreateHash                         1
# ShellExecuteExW                         1
# MessageBoxTimeoutW                      1
# NtSetContextThread                      1
# GetUserNameA                            1
# FindWindowW                             1
# Name: count, dtype: int64
# spyware
# LdrGetProcedureAddress               800
# FindResourceExW                      636
# LoadResource                         557
# LdrGetDllHandle                      416
# LdrLoadDll                           409
# GetSystemMetrics                     218
# NtAllocateVirtualMemory              213
# NtClose                              212
# LoadStringA                          126
# RegCloseKey                          111
# NtQueryValueKey                      104
# NtOpenKey                             95
# RegOpenKeyExA                         91
# DrawTextExW                           69
# RegOpenKeyExW                         60
# NtCreateFile                          47
# NtCreateSection                       45
# RegQueryValueExA                      45
# GetSystemWindowsDirectoryW            43
# GetSystemInfo                         42
# NtFreeVirtualMemory                   40
# NtQueryAttributesFile                 40
# GetSystemDirectoryW                   39
# NtMapViewOfSection                    38
# RegQueryValueExW                      35
# CreateThread                          30
# NtProtectVirtualMemory                20
# WSAStartup                            16
# GetFileAttributesW                    16
# RegQueryInfoKeyW                      15
# FindResourceA                         13
# GetSystemTimeAsFileTime               11
# SetErrorMode                          11
# CoInitializeEx                        10
# FindResourceExA                       10
# RegCreateKeyExA                       10
# FindFirstFileExW                       9
# NtOpenKeyEx                            7
# NtUnmapViewOfSection                   6
# GetFileSize                            6
# RegEnumValueW                          6
# SetWindowsHookExA                      5
# NtCreateMutant                         5
# GetVolumeNameForVolumeMountPointW      4
# NtQuerySystemInformation               4
# NtOpenMutant                           4
# NtOpenFile                             4
# NtDuplicateObject                      4
# OleInitialize                          4
# SearchPathW                            3
# SizeofResource                         3
# RegEnumKeyExW                          3
# GetFileVersionInfoSizeW                2
# GetFileVersionInfoW                    2
# NtQueryKey                             2
# CoUninitialize                         2
# SHGetSpecialFolderLocation             2
# UuidCreate                             1
# CoInitializeSecurity                   1
# GlobalMemoryStatusEx                   1
# CryptAcquireContextW                   1
# GetShortPathNameW                      1
# GetTempPathW                           1
# NtDelayExecution                       1
# FindWindowW                            1
# GetNativeSystemInfo                    1
# LoadStringW                            1
# RegSetValueExW                         1
# RegCreateKeyExW                        1
# FindResourceW                          1
# __exception__                          1
# NtReadFile                             1
# SetFilePointer                         1
# GetFileType                            1
# CreateActCtxW                          1
# GetCursorPos                           1
# NtQueryDirectoryFile                   1
# Name: count, dtype: int64
# virus
# LdrGetProcedureAddress               1052
# LdrLoadDll                            643
# NtClose                               577
# RegCloseKey                           512
# RegOpenKeyExW                         430
# LdrGetDllHandle                       406
# NtReadFile                            382
# NtAllocateVirtualMemory               321
# RegQueryValueExW                      305
# NtWriteFile                           269
# NtOpenKey                             171
# NtCreateFile                          169
# LoadResource                          167
# FindResourceExW                       167
# SetFilePointer                        160
# NtQueryValueKey                       155
# RegOpenKeyExA                         131
# SetErrorMode                          109
# GetSystemWindowsDirectoryW            104
# NtFreeVirtualMemory                   102
# GetSystemMetrics                       86
# NtMapViewOfSection                     85
# NtDuplicateObject                      75
# GetTempPathW                           67
# NtCreateSection                        63
# FindFirstFileExW                       60
# GetVolumeNameForVolumeMountPointW      54
# GetSystemInfo                          51
# LoadStringA                            50
# GetFileAttributesW                     46
# RegSetValueExA                         45
# CreateDirectoryW                       42
# GetFileSize                            39
# GetSystemDirectoryW                    38
# GetSystemTimeAsFileTime                38
# NtCreateMutant                         38
# NtQueryAttributesFile                  33
# RegQueryValueExA                       31
# NtOpenKeyEx                            31
# LoadStringW                            29
# NtProtectVirtualMemory                 28
# OleInitialize                          26
# RegEnumKeyW                            26
# CreateProcessInternalW                 24
# GetNativeSystemInfo                    23
# CreateActCtxW                          23
# NtOpenFile                             22
# NtQuerySystemInformation               22
# GetFileType                            19
# NtQueryDirectoryFile                   18
# NtOpenSection                          18
# DrawTextExW                            18
# SizeofResource                         16
# RegCreateKeyExA                        16
# SetUnhandledExceptionFilter            16
# FindResourceA                          15
# LdrUnloadDll                           13
# NtSetValueKey                          13
# CreateThread                           11
# GetTimeZoneInformation                 10
# CoInitializeEx                          9
# SetWindowsHookExA                       9
# SetFileAttributesW                      8
# DeleteFileW                             8
# NtQueryInformationFile                  8
# WSAStartup                              8
# __exception__                           8
# NtDelayExecution                        8
# NtOpenDirectoryObject                   7
# GetCursorPos                            7
# GetForegroundWindow                     6
# NtOpenMutant                            6
# NtCreateKey                             6
# FindResourceW                           5
# GetSystemDirectoryA                     5
# GlobalMemoryStatusEx                    4
# IsDebuggerPresent                       4
# RemoveDirectoryA                        4
# NtEnumerateValueKey                     4
# NtEnumerateKey                          4
# UuidCreate                              3
# SetEndOfFile                            3
# NtSetInformationFile                    3
# SHGetFolderPathW                        3
# SearchPathW                             2
# CoCreateInstance                        2
# OpenSCManagerA                          2
# RegCreateKeyExW                         2
# CopyFileA                               2
# CreateToolhelp32Snapshot                2
# LookupAccountSidW                       2
# GetUserNameA                            2
# ReadProcessMemory                       2
# Process32NextW                          2
# RegSetValueExW                          2
# Process32FirstW                         2
# CryptAcquireContextW                    1
# GetFileVersionInfoW                     1
# GetFileVersionInfoSizeW                 1
# CreateServiceA                          1
# CryptCreateHash                         1
# CryptHashData                           1
# FindWindowA                             1
# EnumWindows                             1
# CopyFileW                               1
# StartServiceA                           1
# RemoveDirectoryW                        1
# FindResourceExA                         1
# NtResumeThread                          1
# NtCreateThreadEx                        1
# NtTerminateProcess                      1
# OpenServiceA                            1
# GetAdaptersInfo                         1
# InternetOpenW                           1
# InternetOpenA                           1
# SetWindowsHookExW                       1
# CoGetClassObject                        1
# InternetConnectW                        1
# HttpOpenRequestW                        1
# NtUnmapViewOfSection                    1
# CoInitializeSecurity                    1
# CoUninitialize                          1
# Name: count, dtype: int64
# ransomware
# NtQuerySystemInformation       7810
# NtAllocateVirtualMemory        5404
# NtFreeVirtualMemory            4844
# NtClose                        2129
# LdrGetProcedureAddress         1519
# RegOpenKeyExW                  1178
# RegCloseKey                    1143
# RegQueryValueExW               1129
# NtOpenKey                       813
# LdrGetDllHandle                 760
# LdrLoadDll                      751
# NtQueryValueKey                 737
# NtCreateFile                    651
# NtMapViewOfSection              628
# NtCreateSection                 627
# CreateThread                    441
# NtOpenFile                      348
# NtCreateMutant                  339
# NtQueryInformationFile          328
# CryptAcquireContextW            326
# GetSystemWindowsDirectoryW      324
# NtDelayExecution                320
# GetFileSize                     317
# GetTempPathW                    310
# CreateToolhelp32Snapshot        124
# Process32NextW                  113
# Process32FirstW                 113
# GetSystemTimeAsFileTime          35
# NtDuplicateObject                29
# NtProtectVirtualMemory           24
# RegQueryInfoKeyW                 22
# NtEnumerateKey                   22
# NtEnumerateValueKey              22
# GetSystemInfo                    20
# NtTerminateThread                19
# GetSystemMetrics                 18
# GetComputerNameW                 15
# NtWriteFile                      15
# NtOpenKeyEx                      15
# GetSystemDirectoryW              14
# GetUserNameW                     14
# NtOpenMutant                     14
# NtQueryDirectoryFile             11
# SHGetFolderPathW                 11
# NtOpenProcess                    10
# CreateProcessInternalW            9
# LoadStringW                       9
# SetFilePointerEx                  9
# NtQueryKey                        8
# RegEnumValueW                     8
# NtUnmapViewOfSection              8
# RegOpenKeyExA                     8
# SetErrorMode                      8
# CoInitializeEx                    8
# CoCreateInstance                  8
# FindResourceExW                   8
# GetFileAttributesW                8
# IsDebuggerPresent                 7
# CryptGenKey                       7
# NtReadFile                        7
# SetUnhandledExceptionFilter       7
# FindFirstFileExW                  7
# CryptExportKey                    6
# RegEnumKeyExW                     6
# FindResourceW                     6
# LoadResource                      5
# SizeofResource                    5
# GetNativeSystemInfo               5
# UuidCreate                        5
# GetFileSizeEx                     5
# FindWindowW                       4
# WSAStartup                        3
# GetShortPathNameW                 3
# RegSetValueExW                    3
# NtResumeThread                    3
# CoCreateInstanceEx                2
# CoGetClassObject                  2
# CoInitializeSecurity              2
# OutputDebugStringA                2
# RegEnumKeyW                       2
# OleInitialize                     2
# RegQueryValueExA                  2
# MoveFileWithProgressW             2
# LookupPrivilegeValueW             2
# LookupAccountSidW                 2
# NtCreateThreadEx                  2
# NtOpenDirectoryObject             2
# CopyFileW                         2
# RegCreateKeyExW                   2
# SetFilePointer                    2
# RegCreateKeyExA                   1
# RegSetValueExA                    1
# WriteProcessMemory                1
# EnumWindows                       1
# CryptHashData                     1
# GetSystemWindowsDirectoryA        1
# RegEnumKeyExA                     1
# CryptCreateHash                   1
# MessageBoxTimeoutW                1
# CreateActCtxW                     1
# DeleteFileW                       1
# SetWindowsHookExW                 1
# GetCursorPos                      1
# IWbemServices_ExecQuery           1
# CoUninitialize                    1
# GetDiskFreeSpaceW                 1
# OpenSCManagerW                    1
# getaddrinfo                       1
# WriteConsoleA                     1
# GetFileType                       1
# RegEnumValueA                     1
# Name: count, dtype: int64
# dropper
# LdrGetProcedureAddress               68
# LdrLoadDll                           54
# RegOpenKeyExW                        47
# RegCloseKey                          44
# RegQueryValueExW                     37
# SetErrorMode                         35
# NtClose                              33
# LdrGetDllHandle                      33
# NtQueryValueKey                      17
# NtOpenKey                            17
# GetSystemWindowsDirectoryW           14
# NtAllocateVirtualMemory              12
# GetSystemDirectoryW                   9
# NtMapViewOfSection                    8
# NtCreateFile                          8
# NtQueryAttributesFile                 6
# LoadStringW                           6
# NtCreateSection                       6
# RegOpenKeyExA                         5
# NtCreateMutant                        4
# GetNativeSystemInfo                   4
# CreateActCtxW                         4
# NtFreeVirtualMemory                   3
# GetSystemTimeAsFileTime               3
# OleInitialize                         3
# SetUnhandledExceptionFilter           2
# RegQueryValueExA                      2
# NtQuerySystemInformation              2
# GetSystemInfo                         2
# NtDuplicateObject                     2
# GetVolumeNameForVolumeMountPointW     2
# NtOpenSection                         2
# GetSystemMetrics                      1
# GetCursorPos                          1
# FindResourceW                         1
# SetWindowsHookExW                     1
# GlobalMemoryStatusEx                  1
# RegEnumKeyW                           1
# Name: count, dtype: int64
# worm
# LdrGetProcedureAddress        40
# LdrLoadDll                    31
# FindResourceExW               24
# LoadResource                  23
# SetErrorMode                  21
# NtAllocateVirtualMemory       21
# LdrGetDllHandle               12
# NtClose                       11
# NtQueryValueKey               10
# GetSystemMetrics               9
# RegCloseKey                    8
# RegOpenKeyExA                  7
# NtOpenKey                      7
# RegOpenKeyExW                  6
# LoadStringA                    6
# NtFreeVirtualMemory            5
# RegCreateKeyExW                5
# GetFileAttributesW             5
# NtDuplicateObject              4
# RegQueryValueExW               4
# NtProtectVirtualMemory         3
# NtDelayExecution               3
# RegCreateKeyExA                2
# DrawTextExW                    2
# CreateActCtxW                  2
# GetSystemInfo                  2
# SearchPathW                    1
# CoCreateInstanceEx             1
# NtOpenFile                     1
# GetTempPathW                   1
# GlobalMemoryStatusEx           1
# SetWindowsHookExA              1
# LookupPrivilegeValueW          1
# NtResumeThread                 1
# NtCreateThreadEx               1
# OleInitialize                  1
# NtCreateFile                   1
# RegQueryValueExA               1
# NtQuerySystemInformation       1
# FindWindowA                    1
# CreateThread                   1
# RegSetValueExA                 1
# CopyFileA                      1
# DeleteFileW                    1
# SetFileAttributesW             1
# WSAStartup                     1
# GetSystemWindowsDirectoryW     1
# GetFileVersionInfoW            1
# GetFileVersionInfoSizeW        1
# SizeofResource                 1
# FindResourceA                  1
# NtQueryAttributesFile          1
# NtQueryInformationFile         1
# Name: count, dtype: int64
# hacktool
# NtClose                        82
# LdrGetProcedureAddress         73
# LdrLoadDll                     57
# NtAllocateVirtualMemory        41
# NtCreateFile                   28
# LdrGetDllHandle                26
# SetFilePointer                 25
# FindFirstFileExW               24
# NtReadFile                     23
# NtMapViewOfSection             18
# NtFreeVirtualMemory            18
# RegCloseKey                    17
# NtQueryValueKey                17
# GetSystemMetrics               16
# NtOpenKey                      15
# RegOpenKeyExW                  15
# GetSystemDirectoryW            14
# NtCreateSection                13
# SetErrorMode                   13
# RegQueryValueExW               12
# GetSystemWindowsDirectoryW     10
# GetFileSize                     9
# NtQueryAttributesFile           9
# NtWriteFile                     7
# LoadStringA                     7
# LoadResource                    7
# RegOpenKeyExA                   6
# NtOpenFile                      6
# LoadStringW                     6
# CreateDirectoryW                5
# IsDebuggerPresent               4
# GetFileAttributesW              4
# NtProtectVirtualMemory          4
# DrawTextExW                     4
# SizeofResource                  4
# GetSystemInfo                   4
# DeviceIoControl                 3
# RegSetValueExW                  3
# RegCreateKeyExA                 3
# NtCreateMutant                  3
# CreateProcessInternalW          3
# FindResourceA                   3
# SetEndOfFile                    3
# FindResourceExW                 3
# DeleteFileW                     3
# NtSetInformationFile            2
# GetTempPathW                    2
# RegQueryValueExA                2
# RemoveDirectoryA                2
# GetSystemTimeAsFileTime         2
# NtDuplicateObject               2
# SHGetFolderPathW                2
# NtOpenKeyEx                     2
# NtQueryInformationFile          1
# FindResourceW                   1
# GetNativeSystemInfo             1
# NtOpenSection                   1
# OleInitialize                   1
# CreateThread                    1
# FindResourceExA                 1
# GlobalMemoryStatusEx            1
# NtQuerySystemInformation        1
# WSAStartup                      1
# SetUnhandledExceptionFilter     1
# NtOpenProcess                   1
# GetForegroundWindow             1
# RemoveDirectoryW                1
# Name: count, dtype: int64

# %% [markdown]
# ## "What the Unique API Calls are in each Malware Type"

# %%
for i,m in enumerate(malware_types):
    print(i, m)
    m_list = malware_apis[i]
    for j in range(len(malware_apis)):
        if j != i:
            for k in m_list[:]:
                if k in malware_apis[j]:
                    m_list.remove(k)
    print(m_list)
    print("\n")
# Out:
# 0 adware
# ['RegDeleteValueW']
#
#
# 1 pua
# []
#
#
# 2 trojan
# ['SetStdHandle', 'NtDeviceIoControlFile', 'OpenServiceW', 'GlobalMemoryStatus', 'CryptAcquireContextA', 'CryptProtectData', 'CryptEncrypt', 'GetAdaptersAddresses', 'GetBestInterfaceEx', 'HttpOpenRequestA', 'FindWindowExA', 'MessageBoxTimeoutA', 'GetVolumePathNameW', 'StartServiceW', 'FindWindowExW', 'GetFileInformationByHandle', 'InternetGetConnectedState', 'HttpSendRequestA', 'InternetCloseHandle', 'CreateServiceW', 'gethostbyname', 'CreateJobObjectW', 'CopyFileExW', 'GetDiskFreeSpaceExW', 'RtlRemoveVectoredExceptionHandler', 'CreateRemoteThread', 'InternetQueryOptionA', 'EnumServicesStatusA', 'NtSuspendThread', 'RegisterHotKey', 'setsockopt', 'GetKeyboardState', 'RtlDecompressBuffer', 'WSASocketW', 'send', 'WSARecv', 'GetKeyState', 'Module32FirstW', 'Module32NextW', 'ioctlsocket', 'select', 'NtQueueApcThread', 'SetFileInformationByHandle', 'GetFileInformationByHandleEx', 'GetAddrInfoW', 'DnsQuery_A', 'recv', 'RegDeleteValueA', 'DeleteUrlCacheEntryW', 'InternetCrackUrlW', 'InternetSetStatusCallback', 'InternetReadFile', 'HttpQueryInfoA', 'ObtainUserAgentString', 'InternetOpenUrlA', 'RegQueryInfoKeyA', 'ControlService', 'GetUserNameExA', 'SendNotifyMessageW', 'SetInformationJobObject', 'WSASocketA', 'shutdown', 'sendto', 'InternetOpenUrlW', 'NetUserGetInfo']
#
#
# 3 downloader
# ['CryptDecrypt', 'bind', 'getsockname', 'connect', 'NtOpenThread', 'RegDeleteKeyW', 'InternetCrackUrlA', 'InternetConnectA', 'GetAsyncKeyState', 'UnhookWindowsHookEx', 'DrawTextExA', 'CertOpenStore', 'CryptDecodeObjectEx']
#
#
# 4 miner
# ['socket', 'closesocket', 'NtGetContextThread', 'NtReadVirtualMemory', 'NtWriteVirtualMemory', 'NtSetContextThread', 'RtlAddVectoredExceptionHandler', 'SetFileTime', 'timeGetTime', 'GetVolumePathNamesForVolumeNameW', 'ShellExecuteExW', 'Thread32First', 'Thread32Next', 'DeleteUrlCacheEntryA', 'GetFileAttributesExW', 'InternetSetOptionA', 'GetComputerNameA']
#
#
# 5 spyware
# ['SHGetSpecialFolderLocation']
#
#
# 6 virus
# ['GetTimeZoneInformation', '__exception__', 'LdrUnloadDll', 'GetUserNameA', 'GetAdaptersInfo', 'InternetOpenW', 'InternetConnectW', 'HttpOpenRequestW', 'ReadProcessMemory', 'GetSystemDirectoryA', 'InternetOpenA', 'OpenSCManagerA', 'OpenServiceA', 'NtTerminateProcess', 'CreateServiceA', 'StartServiceA', 'NtSetValueKey', 'NtCreateKey']
#
#
# 7 ransomware
# ['CryptAcquireContextW', 'NtTerminateThread', 'CreateToolhelp32Snapshot', 'Process32FirstW', 'Process32NextW', 'NtEnumerateKey', 'NtEnumerateValueKey', 'GetUserNameW', 'GetComputerNameW', 'NtOpenMutant', 'CryptGenKey', 'CryptExportKey', 'GetDiskFreeSpaceW', 'FindWindowW', 'CopyFileW', 'NtQueryDirectoryFile', 'UuidCreate', 'GetFileSizeEx', 'SetFilePointerEx', 'MoveFileWithProgressW', 'CoInitializeEx', 'GetFileType', 'WriteConsoleA', 'getaddrinfo', 'NtOpenDirectoryObject', 'OpenSCManagerW', 'NtQueryKey', 'RegQueryInfoKeyW', 'RegEnumKeyExW', 'RegEnumValueW', 'NtUnmapViewOfSection', 'MessageBoxTimeoutW', 'OutputDebugStringA', 'CoInitializeSecurity', 'CoCreateInstance', 'CoGetClassObject', 'CoUninitialize', 'IWbemServices_ExecQuery', 'LookupAccountSidW', 'CryptCreateHash', 'CryptHashData', 'EnumWindows', 'WriteProcessMemory', 'GetShortPathNameW', 'GetSystemWindowsDirectoryA', 'RegEnumKeyExA', 'RegEnumValueA']
#
#
# 8 dropper
# ['GetVolumeNameForVolumeMountPointW', 'GetCursorPos', 'SetWindowsHookExW', 'RegEnumKeyW']
#
#
# 9 worm
# ['GetFileVersionInfoSizeW', 'GetFileVersionInfoW', 'CreateActCtxW', 'SetFileAttributesW', 'CopyFileA', 'RegSetValueExA', 'FindWindowA', 'NtCreateThreadEx', 'NtResumeThread', 'RegCreateKeyExW', 'SearchPathW', 'SetWindowsHookExA', 'LookupPrivilegeValueW', 'CoCreateInstanceEx', 'NtDelayExecution']
#
#
# 10 hacktool
# ['LdrGetDllHandle', 'LdrGetProcedureAddress', 'NtAllocateVirtualMemory', 'LoadStringA', 'NtOpenKey', 'NtQueryValueKey', 'NtClose', 'SetErrorMode', 'LdrLoadDll', 'NtCreateFile', 'NtCreateSection', 'NtMapViewOfSection', 'NtQueryAttributesFile', 'GetSystemInfo', 'NtProtectVirtualMemory', 'FindResourceA', 'SizeofResource', 'LoadResource', 'GetFileSize', 'SetFilePointer', 'NtReadFile', 'NtFreeVirtualMemory', 'GetFileAttributesW', 'CreateDirectoryW', 'SetEndOfFile', 'NtWriteFile', 'GetSystemWindowsDirectoryW', 'IsDebuggerPresent', 'GetSystemMetrics', 'CreateProcessInternalW', 'DeleteFileW', 'RemoveDirectoryA', 'GetTempPathW', 'FindResourceExA', 'GetForegroundWindow', 'FindResourceExW', 'LoadStringW', 'DrawTextExW', 'NtOpenKeyEx', 'NtDuplicateObject', 'NtOpenProcess', 'SetUnhandledExceptionFilter', 'WSAStartup', 'RegOpenKeyExA', 'SHGetFolderPathW', 'FindFirstFileExW', 'RegOpenKeyExW', 'RegQueryValueExW', 'GetSystemTimeAsFileTime', 'RegCloseKey', 'NtOpenFile', 'RegCreateKeyExA', 'RegSetValueExW', 'DeviceIoControl', 'NtQuerySystemInformation', 'RegQueryValueExA', 'GlobalMemoryStatusEx', 'NtCreateMutant', 'GetSystemDirectoryW', 'GetNativeSystemInfo', 'OleInitialize', 'NtOpenSection', 'NtQueryInformationFile', 'NtSetInformationFile', 'CreateThread', 'FindResourceW', 'RemoveDirectoryW']
