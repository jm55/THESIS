# %%
import pandas as pd
import numpy as np

df = pd.read_csv('target.csv')
df = df[df['Type 1'].isnull()]
df['Type 1'] = df['Type 1'].astype('str')
df.head()
# Out:
#                                hash Type 1
# 0  51fc7a920ed9ffa36ac06202c3dfeba1    nan
# 1  c53b7707b7558d43a0ac1ec7c147f702    nan
# 2  cea7b73bb017d61ac6b8a11fda8113d7    nan
# 3  e471c791c06697a7b60d739a93c33e78    nan
# 4  1e1c448054fcc1648786e856841b4f5f    nan

# %%
import requests
import time
import json

headers = {
    "accept": "application/json",
    "x-apikey": "" #PLACE YOUR API KEY HERE
}

# %%
def countdown(t): 
    while t: 
        mins, secs = divmod(t, 60) 
        timer = '{:02d}:{:02d}'.format(mins, secs) 
        print(timer, end="\r")
        time.sleep(1) 
        t -= 1

# %%
for i in range(df.shape[0]):
    url = f"https://www.virustotal.com/api/v3/files/{df.iloc[i]['hash']}"
    response = requests.get(url, headers=headers)
    if "exceeded"  in response.text:
        print("Quota Exceeded!")
        break
    else:
        print(response.text)
        json_dict = json.loads(response.text)['data']['attributes']['popular_threat_classification']
        suggested = json_dict['suggested_threat_label']
        output = json_dict['suggested_threat_label']
        df.iloc[i, 1] = str(output)
        print(f"{i+1}/{df.shape[0]}: {df.iloc[i]['hash']} obtained!")
        df.to_csv('target_filled.csv', index=False)
        countdown(16)
print("finished")
# Out:
# {
#     "data": {
#         "id": "d406d3941b2b5a3a0e5fedfda4a524f9649bc9da2ef95248839636ef5981cd3c",
#         "type": "file",
#         "links": {
#             "self": "https://www.virustotal.com/api/v3/files/d406d3941b2b5a3a0e5fedfda4a524f9649bc9da2ef95248839636ef5981cd3c"
#         },
#         "attributes": {
#             "packers": {
#                 "PEiD": "UPX 2.90 [LZMA] -> Markus Oberhumer, Laszlo Molnar & John Reiser",
#                 "F-PROT": "UPX",
#                 "Cyren": "UPX, UPX"
#             },
#             "pe_info": {
#                 "timestamp": 1521114515,
#                 "imphash": "973b663d8fe519bab88a5950db1ae088",
#                 "machine_type": 332,
#                 "entry_point": 7136032,
#                 "resource_details": [
#                     {
#                         "lang": "NEUTRAL",
#                         "chi2": 10601.46,
#                         "filetype": "unknown",
#                         "entropy": 7.984206676483154,
#                         "sha256": "dedf6db9b6f202d90742c4f82f65c35fa603dd0fa0b46ebfa8ea2dee41437615",
#                         "type": "NKUGBTHJYDOIXXWDFGH"
#                     },
#                     {
#                         "lang": "ENGLISH US",
#                         "chi2": 7939.95,
#                         "filetype": "XML",
#                         "entropy": 5.383727550506592,
#                         "sha256": "0f6c6bfe2446cf0520c95062bb20431b64053944eae05c61ee99223372eee0f6",
#                         "type": "RT_MANIFEST"
#                     }
#                 ],
#                 "resource_langs": {
#                     "NEUTRAL": 1,
#                     "ENGLISH US": 1
#                 },
#                 "resource_types": {
#                     "NKUGBTHJYDOIXXWDFGH": 1,
#                     "RT_MANIFEST": 1
#                 },
#                 "overlay": {
#                     "chi2": 647.25,
#                     "filetype": "unknown",
#                     "entropy": 7.7034010887146,
#                     "offset": 3333632,
#                     "size": 2048,
#                     "md5": "2996471f3c78e2f1ce399ba4812c9d40"
#                 },
#                 "sections": [
#                     {
#                         "name": "UPX0",
#                         "chi2": -1.0,
#                         "virtual_address": 4096,
#                         "entropy": 0.0,
#                         "raw_size": 0,
#                         "flags": "rwx",
#                         "virtual_size": 4296704,
#                         "md5": "d41d8cd98f00b204e9800998ecf8427e"
#                     },
#                     {
#                         "name": "UPX1",
#                         "chi2": 448869.75,
#                         "virtual_address": 4300800,
#                         "entropy": 7.89,
#                         "raw_size": 2835968,
#                         "flags": "rwx",
#                         "virtual_size": 2838528,
#                         "md5": "70f578dabc8bbb732cd80e467dd47a8f"
#                     },
#                     {
#                         "name": ".rsrc",
#                         "chi2": 11089.78,
#                         "virtual_address": 7139328,
#                         "entropy": 7.98,
#                         "raw_size": 496640,
#                         "flags": "rw",
#                         "virtual_size": 499712,
#                         "md5": "64c16793740e62e70c8f1e4b223ad9c3"
#                     }
#                 ],
#                 "import_list": [
#                     {
#                         "library_name": "oleaut32.dll",
#                         "imported_functions": [
#                             "VariantInit"
#                         ]
#                     },
#                     {
#                         "library_name": "version.dll",
#                         "imported_functions": [
#                             "VerQueryValueW"
#                         ]
#                     },
#                     {
#                         "library_name": "gdi32.dll",
#                         "imported_functions": [
#                             "Pie"
#                         ]
#                     },
#                     {
#                         "library_name": "shell32.dll",
#                         "imported_functions": [
#                             "Shell_NotifyIconW"
#                         ]
#                     },
#                     {
#                         "library_name": "KERNEL32.DLL",
#                         "imported_functions": [
#                             "ExitProcess",
#                             "GetProcAddress",
#                             "LoadLibraryA",
#                             "VirtualProtect"
#                         ]
#                     },
#                     {
#                         "library_name": "winspool.drv",
#                         "imported_functions": [
#                             "ClosePrinter"
#                         ]
#                     },
#                     {
#                         "library_name": "netapi32.dll",
#                         "imported_functions": [
#                             "NetWkstaGetInfo"
#                         ]
#                     },
#                     {
#                         "library_name": "advapi32.dll",
#                         "imported_functions": [
#                             "AddAce"
#                         ]
#                     },
#                     {
#                         "library_name": "ntdll.dll",
#                         "imported_functions": [
#                             "NtUnmapViewOfSection"
#                         ]
#                     },
#                     {
#                         "library_name": "ole32.dll",
#                         "imported_functions": [
#                             "IsEqualGUID"
#                         ]
#                     },
#                     {
#                         "library_name": "user32.dll",
#                         "imported_functions": [
#                             "GetDC"
#                         ]
#                     },
#                     {
#                         "library_name": "comctl32.dll",
#                         "imported_functions": [
#                             "ImageList_Add"
#                         ]
#                     }
#                 ]
#             },
#             "size": 3335680,
#             "unique_sources": 3,
#             "md5": "51fc7a920ed9ffa36ac06202c3dfeba1",
#             "last_analysis_date": 1664555696,
#             "times_submitted": 3,
#             "magic": "PE32 executable for MS Windows (GUI) Intel 80386 32-bit",
#             "type_description": "Win32 EXE",
#             "type_tag": "peexe",
#             "vhash": "03603e0f7d701013z11z41z1011z1015z13z101dz",
#             "type_extension": "exe",
#             "creation_date": 1521114515,
#             "last_submission_date": 1664555696,
#             "total_votes": {
#                 "harmless": 0,
#                 "malicious": 0
#             },
#             "ssdeep": "49152:mv09vEZHSw819sT5egwPb0ZhxrZYdBdSsQy0pYb+/+xZKPwVKKybbLmvZr3/rjUw:mv09cZyFY9RbYdixYxZVVyXQrvrYw",
#             "sha256": "d406d3941b2b5a3a0e5fedfda4a524f9649bc9da2ef95248839636ef5981cd3c",
#             "last_modification_date": 1664562945,
#             "sha1": "2c385caa065c85e361385eb4ae971952740f9613",
#             "tlsh": "T1C7F5333A116664CCE4BB52F13D63EF912658BB918DD7CDAF01A1F8C0E4CC24619F72A9",
#             "tags": [
#                 "peexe",
#                 "upx",
#                 "overlay"
#             ],
#             "meaningful_name": "myfile.exe",
#             "reputation": 0,
#             "last_analysis_results": {
#                 "Bkav": {
#                     "method": "blacklist",
#                     "engine_name": "Bkav",
#                     "engine_version": "1.3.0.9899",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "W32.AIDetect.malware1"
#                 },
#                 "Lionic": {
#                     "method": "blacklist",
#                     "engine_name": "Lionic",
#                     "engine_version": "7.5",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Trojan.Win32.Inject.lVIb"
#                 },
#                 "AVG": {
#                     "method": "blacklist",
#                     "engine_name": "AVG",
#                     "engine_version": "21.1.5827.0",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Win32:Adware-gen [Adw]"
#                 },
#                 "Elastic": {
#                     "method": "blacklist",
#                     "engine_name": "Elastic",
#                     "engine_version": "4.0.47",
#                     "engine_update": "20220929",
#                     "category": "malicious",
#                     "result": "malicious (moderate confidence)"
#                 },
#                 "MicroWorld-eScan": {
#                     "method": "blacklist",
#                     "engine_name": "MicroWorld-eScan",
#                     "engine_version": "14.0.409.0",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Trojan.Agent.CWHD"
#                 },
#                 "CMC": {
#                     "method": "blacklist",
#                     "engine_name": "CMC",
#                     "engine_version": "2.4.2022.1",
#                     "engine_update": "20220930",
#                     "category": "undetected",
#                     "result": null
#                 },
#                 "CAT-QuickHeal": {
#                     "method": "blacklist",
#                     "engine_name": "CAT-QuickHeal",
#                     "engine_version": "22.00",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Trojan.Inject.A11"
#                 },
#                 "ALYac": {
#                     "method": "blacklist",
#                     "engine_name": "ALYac",
#                     "engine_version": "1.1.3.1",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Trojan.Agent.CWHD"
#                 },
#                 "Cylance": {
#                     "method": "blacklist",
#                     "engine_name": "Cylance",
#                     "engine_version": "2.3.1.101",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Unsafe"
#                 },
#                 "Zillya": {
#                     "method": "blacklist",
#                     "engine_name": "Zillya",
#                     "engine_version": "2.0.0.4722",
#                     "engine_update": "20220929",
#                     "category": "malicious",
#                     "result": "Trojan.Agent.Win32.881202"
#                 },
#                 "Paloalto": {
#                     "method": "blacklist",
#                     "engine_name": "Paloalto",
#                     "engine_version": "0.9.0.1003",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "generic.ml"
#                 },
#                 "Sangfor": {
#                     "method": "blacklist",
#                     "engine_name": "Sangfor",
#                     "engine_version": "2.21.0.0",
#                     "engine_update": "20220929",
#                     "category": "malicious",
#                     "result": "Trojan.Win32.Save.a"
#                 },
#                 "K7AntiVirus": {
#                     "method": "blacklist",
#                     "engine_name": "K7AntiVirus",
#                     "engine_version": "12.40.44590",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Adware ( 0052cbe61 )"
#                 },
#                 "Alibaba": {
#                     "method": "blacklist",
#                     "engine_name": "Alibaba",
#                     "engine_version": "0.3.0.5",
#                     "engine_update": "20190527",
#                     "category": "undetected",
#                     "result": null
#                 },
#                 "K7GW": {
#                     "method": "blacklist",
#                     "engine_name": "K7GW",
#                     "engine_version": "12.40.44585",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Adware ( 0052cbe61 )"
#                 },
#                 "Cybereason": {
#                     "method": "blacklist",
#                     "engine_name": "Cybereason",
#                     "engine_version": "1.2.449",
#                     "engine_update": "20210330",
#                     "category": "malicious",
#                     "result": "malicious.20ed9f"
#                 },
#                 "Arcabit": {
#                     "method": "blacklist",
#                     "engine_name": "Arcabit",
#                     "engine_version": "1.0.0.889",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Trojan.Agent.CWHD"
#                 },
#                 "Baidu": {
#                     "method": "blacklist",
#                     "engine_name": "Baidu",
#                     "engine_version": "1.0.0.2",
#                     "engine_update": "20190318",
#                     "category": "undetected",
#                     "result": null
#                 },
#                 "VirIT": {
#                     "method": "blacklist",
#                     "engine_name": "VirIT",
#                     "engine_version": "9.5.294",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Trojan.Win32.Dnldr26.BQSQ"
#                 },
#                 "Cyren": {
#                     "method": "blacklist",
#                     "engine_name": "Cyren",
#                     "engine_version": "6.5.1.2",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "W32/InstallMonster.JN.gen!Eldorado"
#                 },
#                 "Symantec": {
#                     "method": "blacklist",
#                     "engine_name": "Symantec",
#                     "engine_version": "1.18.0.0",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Trojan.Gen.MBT"
#                 },
#                 "tehtris": {
#                     "method": "blacklist",
#                     "engine_name": "tehtris",
#                     "engine_version": "v0.1.4",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Generic.Malware"
#                 },
#                 "ESET-NOD32": {
#                     "method": "blacklist",
#                     "engine_name": "ESET-NOD32",
#                     "engine_version": "26013",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "a variant of Win32/InstallMonstr.QU potentially unwanted"
#                 },
#                 "Cynet": {
#                     "method": "blacklist",
#                     "engine_name": "Cynet",
#                     "engine_version": "4.0.0.27",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Malicious (score: 100)"
#                 },
#                 "APEX": {
#                     "method": "blacklist",
#                     "engine_name": "APEX",
#                     "engine_version": "6.339",
#                     "engine_update": "20220928",
#                     "category": "malicious",
#                     "result": "Malicious"
#                 },
#                 "Avast": {
#                     "method": "blacklist",
#                     "engine_name": "Avast",
#                     "engine_version": "21.1.5827.0",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Win32:Adware-gen [Adw]"
#                 },
#                 "ClamAV": {
#                     "method": "blacklist",
#                     "engine_name": "ClamAV",
#                     "engine_version": "0.105.1.0",
#                     "engine_update": "20220930",
#                     "category": "undetected",
#                     "result": null
#                 },
#                 "Kaspersky": {
#                     "method": "blacklist",
#                     "engine_name": "Kaspersky",
#                     "engine_version": "21.0.1.45",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Trojan.Win32.Inject.aixej"
#                 },
#                 "BitDefender": {
#                     "method": "blacklist",
#                     "engine_name": "BitDefender",
#                     "engine_version": "7.2",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Trojan.Agent.CWHD"
#                 },
#                 "NANO-Antivirus": {
#                     "method": "blacklist",
#                     "engine_name": "NANO-Antivirus",
#                     "engine_version": "1.0.146.25648",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Trojan.Win32.Inject.eyxnuo"
#                 },
#                 "SUPERAntiSpyware": {
#                     "method": "blacklist",
#                     "engine_name": "SUPERAntiSpyware",
#                     "engine_version": "5.6.0.1032",
#                     "engine_update": "20220924",
#                     "category": "undetected",
#                     "result": null
#                 },
#                 "Tencent": {
#                     "method": "blacklist",
#                     "engine_name": "Tencent",
#                     "engine_version": "1.0.0.1",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Malware.Win32.Gencirc.10b0c460"
#                 },
#                 "Ad-Aware": {
#                     "method": "blacklist",
#                     "engine_name": "Ad-Aware",
#                     "engine_version": "3.0.21.193",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Trojan.Agent.CWHD"
#                 },
#                 "Emsisoft": {
#                     "method": "blacklist",
#                     "engine_name": "Emsisoft",
#                     "engine_version": "2022.6.0.32461",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Trojan.Agent.CWHD (B)"
#                 },
#                 "Comodo": {
#                     "method": "blacklist",
#                     "engine_name": "Comodo",
#                     "engine_version": "35036",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Application.Win32.DLBoost.AA@7onrhs"
#                 },
#                 "F-Secure": {
#                     "method": "blacklist",
#                     "engine_name": "F-Secure",
#                     "engine_version": "18.10.978.51",
#                     "engine_update": "20220930",
#                     "category": "undetected",
#                     "result": null
#                 },
#                 "DrWeb": {
#                     "method": "blacklist",
#                     "engine_name": "DrWeb",
#                     "engine_version": "7.0.58.8230",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Trojan.DownLoader26.28876"
#                 },
#                 "VIPRE": {
#                     "method": "blacklist",
#                     "engine_name": "VIPRE",
#                     "engine_version": "6.0.0.35",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Trojan.Agent.CWHD"
#                 },
#                 "TrendMicro": {
#                     "method": "blacklist",
#                     "engine_name": "TrendMicro",
#                     "engine_version": "11.0.0.1006",
#                     "engine_update": "20220930",
#                     "category": "undetected",
#                     "result": null
#                 },
#                 "McAfee-GW-Edition": {
#                     "method": "blacklist",
#                     "engine_name": "McAfee-GW-Edition",
#                     "engine_version": "v2019.1.2+3728",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "BehavesLike.Win32.Generic.wc"
#                 },
#                 "Trapmine": {
#                     "method": "blacklist",
#                     "engine_name": "Trapmine",
#                     "engine_version": "4.0.1.119",
#                     "engine_update": "20220907",
#                     "category": "malicious",
#                     "result": "malicious.moderate.ml.score"
#                 },
#                 "FireEye": {
#                     "method": "blacklist",
#                     "engine_name": "FireEye",
#                     "engine_version": "35.24.1.0",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Generic.mg.51fc7a920ed9ffa3"
#                 },
#                 "Sophos": {
#                     "method": "blacklist",
#                     "engine_name": "Sophos",
#                     "engine_version": "1.4.1.0",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Install Monster (PUA)"
#                 },
#                 "SentinelOne": {
#                     "method": "blacklist",
#                     "engine_name": "SentinelOne",
#                     "engine_version": "22.3.2.9",
#                     "engine_update": "20220929",
#                     "category": "malicious",
#                     "result": "Static AI - Malicious PE"
#                 },
#                 "Jiangmin": {
#                     "method": "blacklist",
#                     "engine_name": "Jiangmin",
#                     "engine_version": "16.0.100",
#                     "engine_update": "20220929",
#                     "category": "malicious",
#                     "result": "Trojan.Inject.amrs"
#                 },
#                 "Webroot": {
#                     "method": "blacklist",
#                     "engine_name": "Webroot",
#                     "engine_version": "1.0.0.403",
#                     "engine_update": "20220930",
#                     "category": "undetected",
#                     "result": null
#                 },
#                 "Avira": {
#                     "method": "blacklist",
#                     "engine_name": "Avira",
#                     "engine_version": "8.3.3.16",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "ADWARE/InstMonster.Gen7"
#                 },
#                 "MAX": {
#                     "method": "blacklist",
#                     "engine_name": "MAX",
#                     "engine_version": "2019.9.16.1",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "malware (ai score=99)"
#                 },
#                 "Antiy-AVL": {
#                     "method": "blacklist",
#                     "engine_name": "Antiy-AVL",
#                     "engine_version": "3.0",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Trojan/Generic.ASMalwS.77"
#                 },
#                 "Kingsoft": {
#                     "method": "blacklist",
#                     "engine_name": "Kingsoft",
#                     "engine_version": "2017.9.26.565",
#                     "engine_update": "20220930",
#                     "category": "undetected",
#                     "result": null
#                 },
#                 "Gridinsoft": {
#                     "method": "blacklist",
#                     "engine_name": "Gridinsoft",
#                     "engine_version": "1.0.94.174",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Malware.Win32.Gen.cc!s2"
#                 },
#                 "Microsoft": {
#                     "method": "blacklist",
#                     "engine_name": "Microsoft",
#                     "engine_version": "1.1.19600.3",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "SoftwareBundler:Win32/InstallMonster"
#                 },
#                 "ViRobot": {
#                     "method": "blacklist",
#                     "engine_name": "ViRobot",
#                     "engine_version": "2014.3.20.0",
#                     "engine_update": "20220930",
#                     "category": "undetected",
#                     "result": null
#                 },
#                 "ZoneAlarm": {
#                     "method": "blacklist",
#                     "engine_name": "ZoneAlarm",
#                     "engine_version": "1.0",
#                     "engine_update": "20220930",
#                     "category": "undetected",
#                     "result": null
#                 },
#                 "GData": {
#                     "method": "blacklist",
#                     "engine_name": "GData",
#                     "engine_version": "A:25.34081B:27.29001",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Trojan.Agent.CWHD"
#                 },
#                 "Google": {
#                     "method": "blacklist",
#                     "engine_name": "Google",
#                     "engine_version": "1664553646",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Detected"
#                 },
#                 "AhnLab-V3": {
#                     "method": "blacklist",
#                     "engine_name": "AhnLab-V3",
#                     "engine_version": "3.22.2.10299",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "PUP/Win32.InstallMonster.R223079"
#                 },
#                 "Acronis": {
#                     "method": "blacklist",
#                     "engine_name": "Acronis",
#                     "engine_version": "1.2.0.108",
#                     "engine_update": "20220426",
#                     "category": "malicious",
#                     "result": "suspicious"
#                 },
#                 "McAfee": {
#                     "method": "blacklist",
#                     "engine_name": "McAfee",
#                     "engine_version": "6.0.6.653",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "InstallMonster"
#                 },
#                 "TACHYON": {
#                     "method": "blacklist",
#                     "engine_name": "TACHYON",
#                     "engine_version": "2022-09-30.02",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Trojan/W32.DP-Inject.7073280"
#                 },
#                 "VBA32": {
#                     "method": "blacklist",
#                     "engine_name": "VBA32",
#                     "engine_version": "5.0.0",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Trojan.Inject"
#                 },
#                 "Malwarebytes": {
#                     "method": "blacklist",
#                     "engine_name": "Malwarebytes",
#                     "engine_version": "4.3.3.37",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Adware.InstallMonster"
#                 },
#                 "TrendMicro-HouseCall": {
#                     "method": "blacklist",
#                     "engine_name": "TrendMicro-HouseCall",
#                     "engine_version": "10.0.0.1040",
#                     "engine_update": "20220930",
#                     "category": "undetected",
#                     "result": null
#                 },
#                 "Rising": {
#                     "method": "blacklist",
#                     "engine_name": "Rising",
#                     "engine_version": "25.0.0.27",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Malware.InstallMonster!8.E93C (TFE:5:2EAxjQjgJsE)"
#                 },
#                 "Yandex": {
#                     "method": "blacklist",
#                     "engine_name": "Yandex",
#                     "engine_version": "5.5.2.24",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Riskware.Agent!dybD2hZ5LDc"
#                 },
#                 "Ikarus": {
#                     "method": "blacklist",
#                     "engine_name": "Ikarus",
#                     "engine_version": "6.0.26.0",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "PUA.Bundler.InstallMonster"
#                 },
#                 "MaxSecure": {
#                     "method": "blacklist",
#                     "engine_name": "MaxSecure",
#                     "engine_version": "1.0.0.1",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Trojan.Malware.300983.susgen"
#                 },
#                 "Fortinet": {
#                     "method": "blacklist",
#                     "engine_name": "Fortinet",
#                     "engine_version": "6.4.258.0",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "W32/Injector.CTWA!tr"
#                 },
#                 "BitDefenderTheta": {
#                     "method": "blacklist",
#                     "engine_name": "BitDefenderTheta",
#                     "engine_version": "7.2.37796.0",
#                     "engine_update": "20220928",
#                     "category": "malicious",
#                     "result": "AI:Packer.2E942AEB21"
#                 },
#                 "Zoner": {
#                     "method": "blacklist",
#                     "engine_name": "Zoner",
#                     "engine_version": "2.2.2.0",
#                     "engine_update": "20220930",
#                     "category": "undetected",
#                     "result": null
#                 },
#                 "Panda": {
#                     "method": "blacklist",
#                     "engine_name": "Panda",
#                     "engine_version": "4.6.4.2",
#                     "engine_update": "20220930",
#                     "category": "malicious",
#                     "result": "Trj/Genetic.gen"
#                 },
#                 "CrowdStrike": {
#                     "method": "blacklist",
#                     "engine_name": "CrowdStrike",
#                     "engine_version": "1.0",
#                     "engine_update": "20220418",
#                     "category": "malicious",
#                     "result": "win/grayware_confidence_90% (W)"
#                 },
#                 "Trustlook": {
#                     "method": "blacklist",
#                     "engine_name": "Trustlook",
#                     "engine_version": "1.0",
#                     "engine_update": "20220930",
#                     "category": "type-unsupported",
#                     "result": null
#                 },
#                 "SymantecMobileInsight": {
#                     "method": "blacklist",
#                     "engine_name": "SymantecMobileInsight",
#                     "engine_version": "2.0",
#                     "engine_update": "20220208",
#                     "category": "type-unsupported",
#                     "result": null
#                 },
#                 "BitDefenderFalx": {
#                     "method": "blacklist",
#                     "engine_name": "BitDefenderFalx",
#                     "engine_version": "2.0.936",
#                     "engine_update": "20220103",
#                     "category": "type-unsupported",
#                     "result": null
#                 },
#                 "Avast-Mobile": {
#                     "method": "blacklist",
#                     "engine_name": "Avast-Mobile",
#                     "engine_version": "220930-00",
#                     "engine_update": "20220930",
#                     "category": "type-unsupported",
#                     "result": null
#                 }
#             },
#             "first_submission_date": 1526245481,
#             "names": [
#                 "myfile.exe",
#                 "codegear-delphi-2009-rtm-v12.0.3170.exe"
#             ],
#             "authentihash": "7e3af96d5fe3c5a39b850b253afe6a7fa31241c7d9029fb377ad1e4590cf2f40",
#             "trid": [
#                 {
#                     "file_type": "UPX compressed Win32 Executable",
#                     "probability": 63.4
#                 },
#                 {
#                     "file_type": "Win32 Executable (generic)",
#                     "probability": 10.5
#                 },
#                 {
#                     "file_type": "WinArchiver Mountable compressed Archive",
#                     "probability": 7.0
#                 },
#                 {
#                     "file_type": "Win16/32 Executable Delphi generic",
#                     "probability": 4.8
#                 },
#                 {
#                     "file_type": "OS/2 Executable (generic)",
#                     "probability": 4.7
#                 }
#             ],
#             "type_tags": [
#                 "executable",
#                 "windows",
#                 "win32",
#                 "pe",
#                 "peexe"
#             ],
#             "last_analysis_stats": {
#                 "malicious": 59,
#                 "suspicious": 0,
#                 "undetected": 13,
#                 "harmless": 0,
#                 "timeout": 0,
#                 "confirmed-timeout": 0,
#                 "failure": 0,
#                 "type-unsupported": 4
#             }
#         }
#     }
# }
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 9
#       7 else:
#       8     print(response.text)
# ----> 9     json_dict = json.loads(response.text)['data']['attributes']['popular_threat_classification']
#      10     suggested = json_dict['suggested_threat_label']
#      11     output = json_dict['suggested_threat_label']
#
# KeyError: 'popular_threat_classification'
