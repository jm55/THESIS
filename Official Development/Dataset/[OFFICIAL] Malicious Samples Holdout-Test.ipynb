# %% [markdown]
# # Malicious Samples on Holdout/Tesst Split
#
# This notebook produces a copy of the Holdout/Test Split for each behavior-type (e.g., TB and IB) and for each GBDT model (e.g., LightGBM and CatBoost) containing only the malicious samples for verification.
#
# The output can then be used for determining what malware type is the model strong and weak at which could be the same as the findings according to the Dataset Analysis.

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

#Load list of API calls
API_LIST = "api_calls.txt"
DELIMITER = "NaN"
API_FILE = open(API_LIST,"r")
APIS = API_FILE.readline().split(',')
APIS.append(DELIMITER) #serves as a label for NaN values for Instance-based datasets
API_FILE.close()

def label_encode(df):
    global APIS
    global ENCODED
    le = LabelEncoder()
    le.fit(APIS)
    df.iloc[:,1:101] = df.iloc[:,1:101].apply(le.transform)
    return df

# %%
reference = pd.read_csv('./TB/CATB_TB_Test.csv').fillna("NaN")
reference = reference[reference['malware'] == 1]
new_col = ['_'] * reference.shape[0]
reference['Type 1'] = new_col
reference['Type 2'] = new_col
reference['Type 3'] = new_col
reference_encoded = label_encode(reference.copy(deep=True))
display(reference)
display(reference_encoded)

reference.to_csv('./TB/CATB_TB_Test_Malicious.csv', index=False)
reference_encoded.to_csv('./TB/LGBM_TB_Test_Malicious.csv', index=False)
# Out:
#       malware                      t_0                      t_1  \
# 0           1                  NtClose                NtOpenKey
# 1           1             SetErrorMode            OleInitialize
# 2           1  GetSystemTimeAsFileTime  NtAllocateVirtualMemory
# 3           1            RegOpenKeyExA                NtOpenKey
# 4           1  GetSystemTimeAsFileTime               LdrLoadDll
# ...       ...                      ...                      ...
# 4383        1  GetSystemTimeAsFileTime               LdrLoadDll
# 4384        1               LdrLoadDll   LdrGetProcedureAddress
# 4385        1  GetSystemTimeAsFileTime               LdrLoadDll
# 4386        1               LdrLoadDll   NtProtectVirtualMemory
# 4387        1             SetErrorMode            OleInitialize
#
#                          t_2                      t_3                     t_4  \
# 0            NtQueryValueKey                  NtClose               NtOpenKey
# 1            LdrGetDllHandle               LdrLoadDll  LdrGetProcedureAddress
# 2        NtFreeVirtualMemory  NtAllocateVirtualMemory         LdrGetDllHandle
# 3            NtQueryValueKey                  NtClose               NtOpenKey
# 4     LdrGetProcedureAddress               LdrLoadDll  LdrGetProcedureAddress
# ...                      ...                      ...                     ...
# 4383  LdrGetProcedureAddress               LdrLoadDll  LdrGetProcedureAddress
# 4384              LdrLoadDll   LdrGetProcedureAddress              LdrLoadDll
# 4385  LdrGetProcedureAddress               LdrLoadDll  LdrGetProcedureAddress
# 4386              LdrLoadDll   NtProtectVirtualMemory          CoInitializeEx
# 4387         LdrGetDllHandle               LdrLoadDll  LdrGetProcedureAddress
#
#                          t_5                     t_6                      t_7  \
# 0            NtQueryValueKey                 NtClose          LdrGetDllHandle
# 1                 LdrLoadDll  LdrGetProcedureAddress               LdrLoadDll
# 2     LdrGetProcedureAddress         LdrGetDllHandle  NtAllocateVirtualMemory
# 3            NtQueryValueKey                 NtClose    NtQueryAttributesFile
# 4                 LdrLoadDll  LdrGetProcedureAddress               LdrLoadDll
# ...                      ...                     ...                      ...
# 4383             GetFileType  LdrGetProcedureAddress          LdrGetDllHandle
# 4384  LdrGetProcedureAddress              LdrLoadDll   LdrGetProcedureAddress
# 4385              LdrLoadDll  LdrGetProcedureAddress               LdrLoadDll
# 4386          NtCreateMutant         LdrGetDllHandle   LdrGetProcedureAddress
# 4387              LdrLoadDll  LdrGetProcedureAddress               LdrLoadDll
#
#                               t_8  ...                    t_94  \
# 0          LdrGetProcedureAddress  ...  LdrGetProcedureAddress
# 1          LdrGetProcedureAddress  ...              LdrLoadDll
# 2     SetUnhandledExceptionFilter  ...  LdrGetProcedureAddress
# 3                     LoadStringA  ...      NtMapViewOfSection
# 4          LdrGetProcedureAddress  ...           RegOpenKeyExW
# ...                           ...  ...                     ...
# 4383       LdrGetProcedureAddress  ...  LdrGetProcedureAddress
# 4384                   LdrLoadDll  ...            LoadResource
# 4385       LdrGetProcedureAddress  ...           RegOpenKeyExW
# 4386              LdrGetDllHandle  ...                 NtClose
# 4387       LdrGetProcedureAddress  ...              LdrLoadDll
#
#                          t_95                    t_96  \
# 0                  LdrLoadDll  LdrGetProcedureAddress
# 1      LdrGetProcedureAddress        RegQueryValueExW
# 2     NtAllocateVirtualMemory         LdrGetDllHandle
# 3                     NtClose        GetSystemMetrics
# 4            RegQueryValueExW           RegOpenKeyExW
# ...                       ...                     ...
# 4383               LdrLoadDll  LdrGetProcedureAddress
# 4384          FindResourceExW            LoadResource
# 4385         RegQueryValueExW           RegOpenKeyExW
# 4386              NtOpenKeyEx  LdrGetProcedureAddress
# 4387   LdrGetProcedureAddress              LdrLoadDll
#
#                           t_97                    t_98  \
# 0                   LdrLoadDll  LdrGetProcedureAddress
# 1                  RegCloseKey           RegOpenKeyExW
# 2       LdrGetProcedureAddress           NtOpenProcess
# 3      NtAllocateVirtualMemory           CreateActCtxW
# 4             RegQueryValueExW           RegOpenKeyExW
# ...                        ...                     ...
# 4383             GetSystemInfo              LdrLoadDll
# 4384           FindResourceExW            LoadResource
# 4385          RegQueryValueExW           RegOpenKeyExW
# 4386                NtQueryKey                 NtClose
# 4387  NtQuerySystemInformation        CoCreateInstance
#
#                             t_99                              hash Type 1  \
# 0                LdrGetDllHandle  f0f8ba4c3d750a4ce2deea48152a33d4      _
# 1               RegQueryValueExW  39b2d87c1adb582fbcacc3a56e274d48      _
# 2                        NtClose  429236cdeb63d68bf48a3b48b0a34612      _
# 3     GetSystemWindowsDirectoryW  46079cbf0bcfe8fab9894b4ec88bece3      _
# 4               RegQueryValueExW  303ceda3f52afa9b69ed4f97fec2c895      _
# ...                          ...                               ...    ...
# 4383      LdrGetProcedureAddress  ace1fb315abc4e4a10624c8b03f917aa      _
# 4384             FindResourceExW  f8948ed47902c6400b086a867685c107      _
# 4385            RegQueryValueExW  131e9e0e7ce851fd4be463c32e025c7b      _
# 4386                 NtOpenKeyEx  c85d6c224b59b3ce76698e9d5aacd3ae      _
# 4387               NtOpenSection  673c18473d60716147397eab14427a59      _
#
#      Type 2 Type 3
# 0         _      _
# 1         _      _
# 2         _      _
# 3         _      _
# 4         _      _
# ...     ...    ...
# 4383      _      _
# 4384      _      _
# 4385      _      _
# 4386      _      _
# 4387      _      _
#
# [4284 rows x 105 columns]
#       malware  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  t_8  ... t_94 t_95  \
# 0           1  154  177  191  154  177  191  154  134  135  ...  135  136
# 1           1  254  209  134  136  135  136  135  136  135  ...  136  135
# 2           1   95  153  170  153  134  135  134  153  262  ...  135  153
# 3           1  231  177  191  154  177  191  154  184  139  ...  174  154
# 4           1   95  136  135  136  135  136  135  136  135  ...  232  236
# ...       ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 4383        1   95  136  135  136  135   81  135  134  135  ...  135  136
# 4384        1  136  135  136  135  136  135  136  135  136  ...  138   59
# 4385        1   95  136  135  136  135  136  135  136  135  ...  232  236
# 4386        1  136  183  136  183    9  158  134  135  134  ...  154  178
# 4387        1  254  209  134  136  135  136  135  136  135  ...  136  135
#
#      t_96 t_97 t_98 t_99                              hash Type 1 Type 2  \
# 0     135  136  135  134  f0f8ba4c3d750a4ce2deea48152a33d4      _      _
# 1     236  219  232  236  39b2d87c1adb582fbcacc3a56e274d48      _      _
# 2     134  135  180  154  429236cdeb63d68bf48a3b48b0a34612      _      _
# 3      94  153   16   97  46079cbf0bcfe8fab9894b4ec88bece3      _      _
# 4     232  236  232  236  303ceda3f52afa9b69ed4f97fec2c895      _      _
# ...   ...  ...  ...  ...                               ...    ...    ...
# 4383  135   93  136  135  ace1fb315abc4e4a10624c8b03f917aa      _      _
# 4384  138   59  138   59  f8948ed47902c6400b086a867685c107      _      _
# 4385  232  236  232  236  131e9e0e7ce851fd4be463c32e025c7b      _      _
# 4386  135  188  154  178  c85d6c224b59b3ce76698e9d5aacd3ae      _      _
# 4387  136  190    6  181  673c18473d60716147397eab14427a59      _      _
#
#      Type 3
# 0         _
# 1         _
# 2         _
# 3         _
# 4         _
# ...     ...
# 4383      _
# 4384      _
# 4385      _
# 4386      _
# 4387      _
#
# [4284 rows x 105 columns]

# %%
reference = pd.read_csv('./IB/CATB_IB_Test.csv').fillna("NaN")
reference = reference[reference['malware'] == 1]
new_col = ['_'] * reference.shape[0]
reference['Type 1'] = new_col
reference['Type 2'] = new_col
reference['Type 3'] = new_col
reference_encoded = label_encode(reference.copy(deep=True))
display(reference)
display(reference_encoded)

reference.to_csv('./IB/CATB_IB_Test_Malicious.csv', index=False)
reference_encoded.to_csv('./IB/LGBM_IB_Test_Malicious.csv', index=False)
# Out:
#       malware                      t_0                      t_1  \
# 0           1                  NtClose                NtOpenKey
# 1           1             SetErrorMode            OleInitialize
# 2           1  GetSystemTimeAsFileTime  NtAllocateVirtualMemory
# 3           1            RegOpenKeyExA                NtOpenKey
# 4           1  GetSystemTimeAsFileTime               LdrLoadDll
# ...       ...                      ...                      ...
# 4383        1  GetSystemTimeAsFileTime               LdrLoadDll
# 4384        1               LdrLoadDll   LdrGetProcedureAddress
# 4385        1  GetSystemTimeAsFileTime               LdrLoadDll
# 4386        1               LdrLoadDll   NtProtectVirtualMemory
# 4387        1             SetErrorMode            OleInitialize
#
#                          t_2              t_3                          t_4  \
# 0            NtQueryValueKey  LdrGetDllHandle       LdrGetProcedureAddress
# 1            LdrGetDllHandle       LdrLoadDll       LdrGetProcedureAddress
# 2        NtFreeVirtualMemory  LdrGetDllHandle       LdrGetProcedureAddress
# 3            NtQueryValueKey          NtClose        NtQueryAttributesFile
# 4     LdrGetProcedureAddress  LdrGetDllHandle  SetUnhandledExceptionFilter
# ...                      ...              ...                          ...
# 4383  LdrGetProcedureAddress      GetFileType              LdrGetDllHandle
# 4384  NtProtectVirtualMemory          NtClose                    NtOpenKey
# 4385  LdrGetProcedureAddress  LdrGetDllHandle  SetUnhandledExceptionFilter
# 4386          CoInitializeEx   NtCreateMutant              LdrGetDllHandle
# 4387         LdrGetDllHandle       LdrLoadDll       LdrGetProcedureAddress
#
#                               t_5                      t_6              t_7  \
# 0                   GetSystemInfo  NtAllocateVirtualMemory    RegOpenKeyExW
# 1                   NtOpenSection       NtMapViewOfSection    RegOpenKeyExW
# 2     SetUnhandledExceptionFilter               LdrLoadDll    RegOpenKeyExA
# 3                     LoadStringA  NtAllocateVirtualMemory  LdrGetDllHandle
# 4            CryptAcquireContextW                NtOpenKey  NtQueryValueKey
# ...                           ...                      ...              ...
# 4383  SetUnhandledExceptionFilter                  NtClose        NtOpenKey
# 4384              NtQueryValueKey          LdrGetDllHandle    GetSystemInfo
# 4385         CryptAcquireContextW                NtOpenKey  NtQueryValueKey
# 4386       LdrGetProcedureAddress                NtOpenKey          NtClose
# 4387                NtOpenSection       NtMapViewOfSection    RegOpenKeyExW
#
#                           t_8  ... t_94 t_95 t_96 t_97 t_98 t_99  \
# 0            FindFirstFileExW  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 1            RegQueryValueExW  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 2            RegQueryValueExA  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 3      LdrGetProcedureAddress  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 4                     NtClose  ...  NaN  NaN  NaN  NaN  NaN  NaN
# ...                       ...  ...  ...  ...  ...  ...  ...  ...
# 4383          NtQueryValueKey  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 4384  NtAllocateVirtualMemory  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 4385                  NtClose  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 4386            NtOpenSection  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 4387         RegQueryValueExW  ...  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                   hash Type 1 Type 2 Type 3
# 0     f0f8ba4c3d750a4ce2deea48152a33d4      _      _      _
# 1     39b2d87c1adb582fbcacc3a56e274d48      _      _      _
# 2     429236cdeb63d68bf48a3b48b0a34612      _      _      _
# 3     46079cbf0bcfe8fab9894b4ec88bece3      _      _      _
# 4     303ceda3f52afa9b69ed4f97fec2c895      _      _      _
# ...                                ...    ...    ...    ...
# 4383  ace1fb315abc4e4a10624c8b03f917aa      _      _      _
# 4384  f8948ed47902c6400b086a867685c107      _      _      _
# 4385  131e9e0e7ce851fd4be463c32e025c7b      _      _      _
# 4386  c85d6c224b59b3ce76698e9d5aacd3ae      _      _      _
# 4387  673c18473d60716147397eab14427a59      _      _      _
#
# [4284 rows x 105 columns]
#       malware  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  t_8  ... t_94 t_95  \
# 0           1  154  177  191  134  135   93  153  232   56  ...  148  148
# 1           1  254  209  134  136  135  181  174  232  236  ...  148  148
# 2           1   95  153  170  134  135  262  136  231  235  ...  148  148
# 3           1  231  177  191  154  184  139  153  134  135  ...  148  148
# 4           1   95  136  135  134  262   28  177  191  154  ...  148  148
# ...       ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 4383        1   95  136  135   81  134  262  154  177  191  ...  148  148
# 4384        1  136  135  183  154  177  191  134   93  153  ...  148  148
# 4385        1   95  136  135  134  262   28  177  191  154  ...  148  148
# 4386        1  136  183    9  158  134  135  177  154  181  ...  148  148
# 4387        1  254  209  134  136  135  181  174  232  236  ...  148  148
#
#      t_96 t_97 t_98 t_99                              hash Type 1 Type 2  \
# 0     148  148  148  148  f0f8ba4c3d750a4ce2deea48152a33d4      _      _
# 1     148  148  148  148  39b2d87c1adb582fbcacc3a56e274d48      _      _
# 2     148  148  148  148  429236cdeb63d68bf48a3b48b0a34612      _      _
# 3     148  148  148  148  46079cbf0bcfe8fab9894b4ec88bece3      _      _
# 4     148  148  148  148  303ceda3f52afa9b69ed4f97fec2c895      _      _
# ...   ...  ...  ...  ...                               ...    ...    ...
# 4383  148  148  148  148  ace1fb315abc4e4a10624c8b03f917aa      _      _
# 4384  148  148  148  148  f8948ed47902c6400b086a867685c107      _      _
# 4385  148  148  148  148  131e9e0e7ce851fd4be463c32e025c7b      _      _
# 4386  148  148  148  148  c85d6c224b59b3ce76698e9d5aacd3ae      _      _
# 4387  148  148  148  148  673c18473d60716147397eab14427a59      _      _
#
#      Type 3
# 0         _
# 1         _
# 2         _
# 3         _
# 4         _
# ...     ...
# 4383      _
# 4384      _
# 4385      _
# 4386      _
# 4387      _
#
# [4284 rows x 105 columns]
