# %% [markdown]
# # Dataset Exclusion Generator
#
# This notebook generates the datasets of the following variation(s):
# - Dataset whose malware and benign samples contain at least 1 API Call that is exclusive to each (for training and testing)

# %% [markdown]
# ## Import Dataset

# %%
import numpy as np
import warnings
warnings.filterwarnings('ignore')

#Load list of API calls
API_LIST = "../Dataset/api_calls.txt"
DELIMITER = "NaN"
API_FILE = open(API_LIST,"r")
APIS = API_FILE.readline().split(',')
APIS.append(DELIMITER) #serves as a label for NaN values for Instance-based datasets
API_FILE.close()

# %%
benign_exclusive = ['CryptProtectMemory','FindFirstFileExA','GetFileVersionInfoExW','GetFileVersionInfoSizeExW','GetUserNameExW','IWbemServices_ExecMethod','listen','NtDeleteFile','NtLoadKey','recvfrom','RegDeleteKeyA','WriteConsoleW']
malicious_exclusive = ['connect','ControlService','CopyFileA','CopyFileExW','CreateJobObjectW','CreateRemoteThread','CreateServiceA','CreateServiceW','CryptDecodeObjectEx','CryptDecrypt','CryptEncrypt','CryptProtectData','DeleteUrlCacheEntryA','DeleteUrlCacheEntryW','DnsQuery_A','EnumServicesStatusA','getaddrinfo','GetAddrInfoW','GetBestInterfaceEx','GetDiskFreeSpaceW','gethostbyname','GetUserNameExA','HttpOpenRequestA','HttpOpenRequestW','HttpQueryInfoA','HttpSendRequestA','InternetCloseHandle','InternetConnectA','InternetConnectW','InternetCrackUrlA','InternetGetConnectedState','InternetOpenA','InternetOpenUrlA','InternetOpenUrlW','InternetOpenW','InternetQueryOptionA','InternetReadFile','InternetSetStatusCallback','MoveFileWithProgressW','NtGetContextThread','NtReadVirtualMemory','NtSetContextThread','NtSuspendThread','NtTerminateThread','NtWriteVirtualMemory','ObtainUserAgentString','OpenSCManagerA','OpenServiceA','recv','RegDeleteKeyW','RtlDecompressBuffer','RtlRemoveVectoredExceptionHandler','send','SetFileInformationByHandle','SetFileTime','SetInformationJobObject','shutdown','StartServiceA','WSARecv','WSASocketA']

print("# Benign Exclusive APIs:", len(benign_exclusive))
print("# Malicious Exclusive APIs:", len(malicious_exclusive))
# Out:
# # Benign Exclusive APIs: 12
# # Malicious Exclusive APIs: 60

# %%
def complete_validation(df):
    collector = []
    for i in df.columns[1:101]:
        collector += df[i].to_list()
    return len(pd.Series(collector).unique())

# %%
import pandas as pd
df = pd.read_csv('../Dataset/oliveira_labelled_str.csv')
df
print(f"Unique APIs: {complete_validation(df)}/307")
# Out:
# Unique APIs: 264/307

# %% [markdown]
# It turns out that the real number of API Calls in use by the samples is only 260 out of 307 which may suggest that the end product dataset of the dataset's author had changes when they initially made it and when it was released for public use.

# %% [markdown]
# ## How many are samples that contain at least 1 of its exclusive API Call?

# %%
def count_sample_exclusive(exclusive:list, malware:int):
    size = df[df['malware']==malware].shape[0]
    total = 0
    for x in exclusive:
        matches = df[df['malware']==malware]['pattern'].str.contains(x)
        raw_types = df[df['malware']==malware][df['pattern'].str.contains(x)]['type'].value_counts()
        types = ""
        for r in range(len(raw_types)):
            types += f"{raw_types.index.to_list()[r]} ({raw_types.to_list()[r]}) "
        print(f"{x:36s} {len(matches[matches==True]):4d} | {types}")
        total += len(matches[matches==True])
    print("")
    label = "Malicious"
    if malware == 0:
        label = "Benign"
    #print(f"{label} Samples with at least 1 Exclusive {label} API Call: {total} ({total/size*100:.4f}% of {label} samples)")

# %%
count_sample_exclusive(malicious_exclusive, 1)
# Out:
# connect                               195 | adware (103) trojan (62) pua (24) _ (5) downloader (1)
# ControlService                          1 | trojan (1)
# CopyFileA                             110 | trojan (97) miner (8) _ (2) virus (2) worm (1)
# CopyFileExW                            30 | trojan (28) pua (2)
# CreateJobObjectW                       32 | trojan (27) pua (3) adware (2)
# CreateRemoteThread                      2 | trojan (2)
# CreateServiceA                         35 | trojan (34) virus (1)
# CreateServiceW                          9 | trojan (9)
# CryptDecodeObjectEx                     3 | trojan (1) _ (1) downloader (1)
# CryptDecrypt                         3004 | trojan (2551) pua (233) adware (120) downloader (97) _ (3)
# CryptEncrypt                           39 | trojan (39)
# CryptProtectData                       27 | trojan (27)
# DeleteUrlCacheEntryA                    8 | trojan (6) miner (1) pua (1)
# DeleteUrlCacheEntryW                   22 | pua (20) trojan (2)
# DnsQuery_A                              9 | trojan (9)
# EnumServicesStatusA                     4 | _ (2) trojan (2)
# getaddrinfo                           217 | adware (136) trojan (61) pua (10) _ (7) downloader (1) miner (1) ransomware (1)
# GetAddrInfoW                            2 | trojan (2)
# GetBestInterfaceEx                     25 | trojan (24) _ (1)
# GetDiskFreeSpaceW                     113 | trojan (77) _ (27) adware (4) pua (3) ransomware (1) miner (1)
# gethostbyname                          64 | trojan (44) pua (18) _ (1) adware (1)
# GetUserNameExA                          3 | trojan (3)
# HttpOpenRequestA                      192 | trojan (187) _ (3) adware (2)
# HttpOpenRequestW                       42 | pua (19) _ (12) trojan (8) adware (2) virus (1)
# HttpQueryInfoA                          4 | trojan (2) _ (2)
# HttpSendRequestA                       15 | trojan (15)
# InternetCloseHandle                    25 | trojan (24) _ (1)
# InternetConnectA                      213 | trojan (194) _ (8) adware (7) downloader (2) pua (2)
# InternetConnectW                       42 | pua (19) _ (12) trojan (8) adware (2) virus (1)
# InternetCrackUrlA                      69 | trojan (54) adware (7) _ (4) downloader (2) pua (2)
# InternetGetConnectedState               7 | _ (4) trojan (3)
# InternetOpenA                         273 | trojan (249) _ (9) adware (7) downloader (3) pua (3) miner (1) virus (1)
# InternetOpenUrlA                        9 | trojan (9)
# InternetOpenUrlW                        1 | trojan (1)
# InternetOpenW                          58 | trojan (22) pua (21) _ (12) adware (2) virus (1)
# InternetQueryOptionA                    8 | _ (5) trojan (3)
# InternetReadFile                        2 | trojan (2)
# InternetSetStatusCallback               2 | trojan (1) _ (1)
# MoveFileWithProgressW                 176 | trojan (125) pua (41) adware (7) miner (2) ransomware (1)
# NtGetContextThread                     61 | trojan (47) _ (12) miner (2)
# NtReadVirtualMemory                     5 | trojan (3) miner (2)
# NtSetContextThread                     34 | trojan (33) miner (1)
# NtSuspendThread                        76 | _ (55) trojan (21)
# NtTerminateThread                      21 | ransomware (19) trojan (2)
# NtWriteVirtualMemory                    6 | trojan (4) miner (2)
# ObtainUserAgentString                   2 | trojan (1) _ (1)
# OpenSCManagerA                        194 | trojan (168) _ (15) adware (4) pua (3) downloader (2) virus (2)
# OpenServiceA                          154 | trojan (135) _ (11) pua (3) downloader (2) adware (2) virus (1)
# recv                                   14 | trojan (12) pua (1) _ (1)
# RegDeleteKeyW                           5 | trojan (1) downloader (1) pua (1) _ (1) adware (1)
# RtlDecompressBuffer                    16 | trojan (16)
# RtlRemoveVectoredExceptionHandler       2 | trojan (2)
# send                                   38 | trojan (22) pua (15) _ (1)
# SetFileInformationByHandle              1 | trojan (1)
# SetFileTime                           157 | trojan (94) _ (42) pua (15) adware (5) miner (1)
# SetInformationJobObject                 1 | trojan (1)
# shutdown                               12 | pua (10) trojan (2)
# StartServiceA                          42 | trojan (41) virus (1)
# WSARecv                                15 | pua (11) trojan (4)
# WSASocketA                              1 | trojan (1)

# %%
count_sample_exclusive(benign_exclusive,0)
# Out:
# CryptProtectMemory                      1 | benign (1)
# FindFirstFileExA                        3 | benign (3)
# GetFileVersionInfoExW                   2 | benign (2)
# GetFileVersionInfoSizeExW               2 | benign (2)
# GetUserNameExW                          2 | benign (2)
# IWbemServices_ExecMethod                1 | benign (1)
# listen                                  2 | benign (2)
# NtDeleteFile                            1 | benign (1)
# NtLoadKey                               1 | benign (1)
# recvfrom                                1 | benign (1)
# RegDeleteKeyA                           2 | benign (2)
# WriteConsoleW                          16 | benign (16)

# %% [markdown]
# ## Dataset Exclusivity Filtering

# %%
def filter_sample_exclusive():
    global benign_exclusive
    global malicious_excusive
    exclusive_df = None
    for x in benign_exclusive:
        exclusive_df = pd.concat([exclusive_df, df[df['pattern'].str.contains(x)]], axis=0)
    for x in malicious_exclusive:
        exclusive_df = pd.concat([exclusive_df, df[df['pattern'].str.contains(x)]], axis=0)
    exclusive_df.drop_duplicates(subset=['hash'], inplace=True, keep='first')
    remaining_df = pd.concat([exclusive_df, df], axis=0)
    remaining_df.drop_duplicates(subset=['hash'], inplace=True, keep=False)
    return exclusive_df, remaining_df
def convert(api:str):
    return APIS.index(api)
def ordinal_encode(df):
    global APIS
    for j in range(1,101):
        df.iloc[:,j] = pd.Series(list(map(convert, df.iloc[:,j].to_list())))
    return df

# %% [markdown]
# ## Dataset whose Malware and Benign samples contain at least 1 API Call exclusive to Malicious and Benign samples (for training & testing)

# %%
exclusive_str, remaining_str = filter_sample_exclusive()

# %%
print("Composition of samples that contain at least 1 API Call exclusive to it: ", exclusive_str['type'].value_counts())
print("\n")
display(exclusive_str)
display(remaining_str)
# Out:
# Composition of samples that contain at least 1 API Call exclusive to it:  type
# trojan        3498
# pua            333
# adware         282
# _              156
# downloader     103
# benign          31
# ransomware      22
# miner           14
# virus            5
# worm             1
# Name: count, dtype: int64
#                                    hash                      t_0  \
# 11404  c662cc346f4c041ee954b9a4333ed28d  GetSystemTimeAsFileTime
# 4760   3e122e753cd94f004797b3b4dddba96a  GetSystemTimeAsFileTime
# 23426  204113cdf14320ee9db1f88a62a48019  GetSystemTimeAsFileTime
# 39519  00a1b66bd25adb59460871ee40e6ebc0  GetSystemTimeAsFileTime
# 17375  59147b8b8abf9768ca96badfd91d7bb9  GetSystemTimeAsFileTime
# ...                                 ...                      ...
# 42662  ede65bc1ae2f644f96a567a7fff0f7ee  NtAllocateVirtualMemory
# 42882  e501a7d4d95d9a87027be637376a329e  NtAllocateVirtualMemory
# 42956  2cae0bf3c1344031ef7951f4758c79f6  NtAllocateVirtualMemory
# 43251  5d9c5d82d8070ef29ed745c15b1c0989  NtAllocateVirtualMemory
# 35404  438640515058a2d5e92bdae3c382ac52  GetSystemTimeAsFileTime
#
#                                t_1                         t_2  \
# 11404                   LdrLoadDll      LdrGetProcedureAddress
# 4760   SetUnhandledExceptionFilter     NtAllocateVirtualMemory
# 23426  SetUnhandledExceptionFilter     NtAllocateVirtualMemory
# 39519  SetUnhandledExceptionFilter  GetSystemWindowsDirectoryW
# 17375  SetUnhandledExceptionFilter     NtAllocateVirtualMemory
# ...                            ...                         ...
# 42662          NtFreeVirtualMemory     NtAllocateVirtualMemory
# 42882                 SetErrorMode                 LoadStringA
# 42956          NtFreeVirtualMemory     NtAllocateVirtualMemory
# 43251                 SetErrorMode                 LoadStringA
# 35404      NtAllocateVirtualMemory         NtFreeVirtualMemory
#
#                            t_3                      t_4  \
# 11404               LdrLoadDll   LdrGetProcedureAddress
# 4760               timeGetTime  NtAllocateVirtualMemory
# 23426              timeGetTime  NtAllocateVirtualMemory
# 39519  NtAllocateVirtualMemory      GetSystemDirectoryW
# 17375               LdrLoadDll   LdrGetProcedureAddress
# ...                        ...                      ...
# 42662              GetFileType          LdrGetDllHandle
# 42882            OleInitialize               LdrLoadDll
# 42956              GetFileType          LdrGetDllHandle
# 43251            OleInitialize               LdrLoadDll
# 35404  NtAllocateVirtualMemory          LdrGetDllHandle
#
#                           t_5                          t_6  \
# 11404              LdrLoadDll       LdrGetProcedureAddress
# 4760               LdrLoadDll                 LdrUnloadDll
# 23426             timeGetTime      GetSystemTimeAsFileTime
# 39519           RegOpenKeyExA   GetSystemWindowsDirectoryW
# 17375                 NtClose                    NtOpenKey
# ...                       ...                          ...
# 42662  LdrGetProcedureAddress  SetUnhandledExceptionFilter
# 42882  LdrGetProcedureAddress      NtAllocateVirtualMemory
# 42956  LdrGetProcedureAddress                RegOpenKeyExA
# 43251  LdrGetProcedureAddress      NtAllocateVirtualMemory
# 35404  LdrGetProcedureAddress              LdrGetDllHandle
#
#                            t_7                         t_8  ...  \
# 11404               LdrLoadDll      LdrGetProcedureAddress  ...
# 4760              NtCreateFile                 GetFileType  ...
# 23426  NtAllocateVirtualMemory                NtCreateFile  ...
# 39519              LoadStringW  GetSystemWindowsDirectoryW  ...
# 17375          NtQueryValueKey                     NtClose  ...
# ...                        ...                         ...  ...
# 42662            RegOpenKeyExA            RegQueryValueExA  ...
# 42882      NtFreeVirtualMemory     NtAllocateVirtualMemory  ...
# 42956         RegQueryValueExA                 RegCloseKey  ...
# 43251      NtFreeVirtualMemory     NtAllocateVirtualMemory  ...
# 35404   LdrGetProcedureAddress             LdrGetDllHandle  ...
#
#                           t_93                  t_94                    t_95  \
# 11404  NtAllocateVirtualMemory  GetFileAttributesExW            NtCreateFile
# 4760                   NtClose      FindFirstFileExA                 NtClose
# 23426                  NtClose      FindFirstFileExA                 NtClose
# 39519                  NtClose      FindFirstFileExA                 NtClose
# 17375   LdrGetProcedureAddress       LdrGetDllHandle  LdrGetProcedureAddress
# ...                        ...                   ...                     ...
# 42662     NtSetInformationFile               NtClose              NtOpenFile
# 42882  NtAllocateVirtualMemory         RegOpenKeyExW         LdrGetDllHandle
# 42956             LoadResource        SizeofResource         FindResourceExW
# 43251            FindResourceA           LoadStringA              LdrLoadDll
# 35404          NtQueryValueKey               NtClose               NtOpenKey
#
#                          t_96                     t_97  \
# 11404     NtFreeVirtualMemory              GetFileType
# 4760         FindFirstFileExA                  NtClose
# 23426            NtCreateFile              GetFileType
# 39519        FindFirstFileExA                  NtClose
# 17375         LdrGetDllHandle   LdrGetProcedureAddress
# ...                       ...                      ...
# 42662  NtQueryInformationFile  NtAllocateVirtualMemory
# 42882         FindResourceExW             LoadResource
# 42956            LoadResource  NtAllocateVirtualMemory
# 43251  LdrGetProcedureAddress            __exception__
# 35404         NtQueryValueKey                  NtClose
#
#                           t_98                     t_99 malware    type  \
# 11404                  NtClose              DeleteFileW       0  benign
# 4760          FindFirstFileExA                  NtClose       0  benign
# 23426  NtAllocateVirtualMemory               NtReadFile       0  benign
# 39519         FindFirstFileExA                  NtClose       0  benign
# 17375          LdrGetDllHandle   LdrGetProcedureAddress       0  benign
# ...                        ...                      ...     ...     ...
# 42662               NtReadFile      NtFreeVirtualMemory       1       _
# 42882          FindResourceExW             LoadResource       1  trojan
# 42956      NtFreeVirtualMemory  NtAllocateVirtualMemory       1       _
# 43251          FindResourceExA            FindResourceA       1  trojan
# 35404                NtOpenKey          NtQueryValueKey       1  trojan
#
#                                                  pattern
# 11404  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 4760   GetSystemTimeAsFileTime,SetUnhandledExceptionF...
# 23426  GetSystemTimeAsFileTime,SetUnhandledExceptionF...
# 39519  GetSystemTimeAsFileTime,SetUnhandledExceptionF...
# 17375  GetSystemTimeAsFileTime,SetUnhandledExceptionF...
# ...                                                  ...
# 42662  NtAllocateVirtualMemory,NtFreeVirtualMemory,Nt...
# 42882  NtAllocateVirtualMemory,SetErrorMode,LoadStrin...
# 42956  NtAllocateVirtualMemory,NtFreeVirtualMemory,Nt...
# 43251  NtAllocateVirtualMemory,SetErrorMode,LoadStrin...
# 35404  GetSystemTimeAsFileTime,NtAllocateVirtualMemor...
#
# [4445 rows x 104 columns]
#                                    hash                          t_0  \
# 0      071e8c3f8922e186e57548cd4c703a5d                RegOpenKeyExA
# 1      33f8e6d08a6aae939f25a8e0d63dd523      GetSystemTimeAsFileTime
# 2      b68abd064e975e1c6d5f25e748663076  SetUnhandledExceptionFilter
# 4      c9b3700a77facf29172f32df6bc77f48      GetSystemTimeAsFileTime
# 5      cc6217be863e606e49da90fee2252f52       LdrGetProcedureAddress
# ...                                 ...                          ...
# 43871  e3d6d58faa040f0f9742c9d0eaf58be4      GetSystemTimeAsFileTime
# 43872  9b917bab7f32188ae40c744f2be9aaf8      GetSystemTimeAsFileTime
# 43873  35a18ee05f75f04912018d9f462cb990      GetSystemTimeAsFileTime
# 43874  654139d715abcf7ecdddbef5a84f224b      GetSystemTimeAsFileTime
# 43875  078c9d4e7be4819a06974c6f292a4857                RegOpenKeyExA
#
#                            t_1                     t_2  \
# 0                    NtOpenKey         NtQueryValueKey
# 1      NtAllocateVirtualMemory     NtFreeVirtualMemory
# 2                OleInitialize              LdrLoadDll
# 4                   LdrLoadDll  LdrGetProcedureAddress
# 5      NtAllocateVirtualMemory  LdrGetProcedureAddress
# ...                        ...                     ...
# 43871               LdrLoadDll  LdrGetProcedureAddress
# 43872               LdrLoadDll  LdrGetProcedureAddress
# 43873               LdrLoadDll  LdrGetProcedureAddress
# 43874               LdrLoadDll  LdrGetProcedureAddress
# 43875                NtOpenKey         NtQueryValueKey
#
#                            t_3                     t_4  \
# 0                      NtClose               NtOpenKey
# 1      NtAllocateVirtualMemory         LdrGetDllHandle
# 2       LdrGetProcedureAddress              LdrLoadDll
# 4                   LdrLoadDll  LdrGetProcedureAddress
# 5      NtAllocateVirtualMemory  LdrGetProcedureAddress
# ...                        ...                     ...
# 43871               LdrLoadDll  LdrGetProcedureAddress
# 43872               LdrLoadDll  LdrGetProcedureAddress
# 43873               LdrLoadDll  LdrGetProcedureAddress
# 43874               LdrLoadDll  LdrGetProcedureAddress
# 43875                  NtClose               NtOpenKey
#
#                           t_5                     t_6                     t_7  \
# 0             NtQueryValueKey                 NtClose   NtQueryAttributesFile
# 1      LdrGetProcedureAddress         LdrGetDllHandle  LdrGetProcedureAddress
# 2      LdrGetProcedureAddress              LdrLoadDll  LdrGetProcedureAddress
# 4                  LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 5                  LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# ...                       ...                     ...                     ...
# 43871              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 43872              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 43873              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 43874              LdrLoadDll  LdrGetProcedureAddress              LdrLoadDll
# 43875         NtQueryValueKey                 NtClose   NtQueryAttributesFile
#
#                           t_8  ...                     t_93  \
# 0                 LoadStringA  ...          NtCreateSection
# 1             LdrGetDllHandle  ...   LdrGetProcedureAddress
# 2                  LdrLoadDll  ...         RegQueryValueExA
# 4      LdrGetProcedureAddress  ...         RegQueryInfoKeyW
# 5      LdrGetProcedureAddress  ...            RegOpenKeyExW
# ...                       ...  ...                      ...
# 43871  LdrGetProcedureAddress  ...         RegQueryValueExW
# 43872  LdrGetProcedureAddress  ...  GetSystemTimeAsFileTime
# 43873  LdrGetProcedureAddress  ...            RegOpenKeyExW
# 43874  LdrGetProcedureAddress  ...         RegQueryValueExW
# 43875             LoadStringA  ...          NtCreateSection
#
#                              t_94              t_95  \
# 0              NtMapViewOfSection           NtClose
# 1      GetSystemWindowsDirectoryW      NtCreateFile
# 2                     RegCloseKey     RegOpenKeyExA
# 4                   RegEnumKeyExW     RegOpenKeyExW
# 5                RegQueryValueExW       RegCloseKey
# ...                           ...               ...
# 43871               RegOpenKeyExW  RegQueryValueExW
# 43872            NtDelayExecution       EnumWindows
# 43873            RegQueryValueExW     RegOpenKeyExW
# 43874               RegOpenKeyExW  RegQueryValueExW
# 43875          NtMapViewOfSection           NtClose
#
#                                     t_96                     t_97  \
# 0                       GetSystemMetrics  NtAllocateVirtualMemory
# 1                        NtCreateSection       NtMapViewOfSection
# 2                       RegQueryValueExA              RegCloseKey
# 4                       RegQueryValueExW            RegOpenKeyExW
# 5      GetVolumeNameForVolumeMountPointW   LdrGetProcedureAddress
# ...                                  ...                      ...
# 43871                      RegOpenKeyExW         RegQueryValueExW
# 43872            GetSystemTimeAsFileTime         NtDelayExecution
# 43873                   RegQueryValueExW            RegOpenKeyExW
# 43874                      RegOpenKeyExW         RegQueryValueExW
# 43875                   GetSystemMetrics  NtAllocateVirtualMemory
#
#                    t_98                        t_99 malware    type  \
# 0         CreateActCtxW  GetSystemWindowsDirectoryW       1  trojan
# 1               NtClose            GetSystemMetrics       1     pua
# 2         RegEnumKeyExA               RegOpenKeyExA       1  trojan
# 4      RegQueryValueExW               RegOpenKeyExW       1  trojan
# 5         RegOpenKeyExW                 RegCloseKey       1  trojan
# ...                 ...                         ...     ...     ...
# 43871     RegOpenKeyExW            RegQueryValueExW       1  trojan
# 43872       EnumWindows     GetSystemTimeAsFileTime       1  trojan
# 43873  RegQueryValueExW               RegOpenKeyExW       1  trojan
# 43874     RegOpenKeyExW            RegQueryValueExW       1  trojan
# 43875     CreateActCtxW  GetSystemWindowsDirectoryW       1  trojan
#
#                                                  pattern
# 0      RegOpenKeyExA,NtOpenKey,NtQueryValueKey,NtClos...
# 1      GetSystemTimeAsFileTime,NtAllocateVirtualMemor...
# 2      SetUnhandledExceptionFilter,OleInitialize,LdrL...
# 4      GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 5      LdrGetProcedureAddress,NtAllocateVirtualMemory...
# ...                                                  ...
# 43871  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 43872  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 43873  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 43874  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 43875  RegOpenKeyExA,NtOpenKey,NtQueryValueKey,NtClos...
#
# [39414 rows x 104 columns]

# %%
exclusive_enc = ordinal_encode(exclusive_str).copy(deep=True)
remaining_enc = ordinal_encode(remaining_str).copy(deep=True)

# %%
display(exclusive_enc)
display(remaining_enc)
# Out:
#                                    hash  t_0  t_1  t_2  t_3  t_4  t_5  t_6  \
# 11404  c662cc346f4c041ee954b9a4333ed28d   82  240  117  240  117  240  117
# 4760   3e122e753cd94f004797b3b4dddba96a   82   16  208   57  208  240   50
# 23426  204113cdf14320ee9db1f88a62a48019   82   16  208   57  208   57   82
# 39519  00a1b66bd25adb59460871ee40e6ebc0   82   16   71  208  275  112   71
# 17375  59147b8b8abf9768ca96badfd91d7bb9   82   16  208  240  117  215  274
# ...                                 ...  ...  ...  ...  ...  ...  ...  ...
# 42662  ede65bc1ae2f644f96a567a7fff0f7ee  208  187  208   93  172  117   16
# 42882  e501a7d4d95d9a87027be637376a329e  208  286   76  110  240  117  208
# 42956  2cae0bf3c1344031ef7951f4758c79f6  208  187  208   93  172  117  112
# 43251  5d9c5d82d8070ef29ed745c15b1c0989  208  286   76  110  240  117  208
# 35404  438640515058a2d5e92bdae3c382ac52   82  208  187  208  172  117  172
#
#        t_7  t_8  ... t_93 t_94 t_95 t_96 t_97 t_98 t_99 malware    type  \
# 11404  240  117  ...  208   73  297  187   93  215  127       0  benign
# 4760   297   93  ...  215  281  215  281  215  281  215       0  benign
# 23426  208  297  ...  215  281  215  297   93  208  264       0  benign
# 39519   25   71  ...  215  281  215  281  215  281  215       0  benign
# 17375  158  215  ...  117  172  117  172  117  172  117       0  benign
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...     ...     ...
# 42662  112  123  ...  119  215   20   34  208  264  187       1       _
# 42882  187  208  ...  208  260  172   60   81   60   81       1  trojan
# 42956  123   65  ...   81  140   60   81  208  187  208       1       _
# 43251  187  208  ...  111   76  240  117  306  291  111       1  trojan
# 35404  117  172  ...  158  215  274  158  215  274  158       1  trojan
#
#                                                  pattern
# 11404  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 4760   GetSystemTimeAsFileTime,SetUnhandledExceptionF...
# 23426  GetSystemTimeAsFileTime,SetUnhandledExceptionF...
# 39519  GetSystemTimeAsFileTime,SetUnhandledExceptionF...
# 17375  GetSystemTimeAsFileTime,SetUnhandledExceptionF...
# ...                                                  ...
# 42662  NtAllocateVirtualMemory,NtFreeVirtualMemory,Nt...
# 42882  NtAllocateVirtualMemory,SetErrorMode,LoadStrin...
# 42956  NtAllocateVirtualMemory,NtFreeVirtualMemory,Nt...
# 43251  NtAllocateVirtualMemory,SetErrorMode,LoadStrin...
# 35404  GetSystemTimeAsFileTime,NtAllocateVirtualMemor...
#
# [4445 rows x 104 columns]
#                                    hash  t_0  t_1  t_2  t_3  t_4  t_5  t_6  \
# 0      071e8c3f8922e186e57548cd4c703a5d  112  274  158  215  274  158  215
# 1      33f8e6d08a6aae939f25a8e0d63dd523   82  208  187  208  172  117  172
# 2      b68abd064e975e1c6d5f25e748663076   16  110  240  117  240  117  240
# 4      c9b3700a77facf29172f32df6bc77f48   82  240  117  240  117  240  117
# 5      cc6217be863e606e49da90fee2252f52  117  208  117  208  117  240  117
# ...                                 ...  ...  ...  ...  ...  ...  ...  ...
# 43871  e3d6d58faa040f0f9742c9d0eaf58be4   82  240  117  240  117  240  117
# 43872  9b917bab7f32188ae40c744f2be9aaf8   82  240  117  240  117  240  117
# 43873  35a18ee05f75f04912018d9f462cb990   82  240  117  240  117  240  117
# 43874  654139d715abcf7ecdddbef5a84f224b   82  240  117  240  117  240  117
# 43875  078c9d4e7be4819a06974c6f292a4857  112  274  158  215  274  158  215
#
#        t_7  t_8  ... t_93 t_94 t_95 t_96 t_97 t_98 t_99 malware    type  \
# 0      298   76  ...  135  171  215   35  208   56   71       1  trojan
# 1      117  172  ...  117   71  297  135  171  215   35       1     pua
# 2      117  240  ...  123   65  112  123   65  113  112       1  trojan
# 4      240  117  ...   40  209  260  141  260  141  260       1  trojan
# 5      240  117  ...  260  141   65    9  117  260   65       1  trojan
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...     ...     ...
# 43871  240  117  ...  141  260  141  260  141  260  141       1  trojan
# 43872  240  117  ...   82  159  224   82  159  224   82       1  trojan
# 43873  240  117  ...  260  141  260  141  260  141  260       1  trojan
# 43874  240  117  ...  141  260  141  260  141  260  141       1  trojan
# 43875  298   76  ...  135  171  215   35  208   56   71       1  trojan
#
#                                                  pattern
# 0      RegOpenKeyExA,NtOpenKey,NtQueryValueKey,NtClos...
# 1      GetSystemTimeAsFileTime,NtAllocateVirtualMemor...
# 2      SetUnhandledExceptionFilter,OleInitialize,LdrL...
# 4      GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 5      LdrGetProcedureAddress,NtAllocateVirtualMemory...
# ...                                                  ...
# 43871  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 43872  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 43873  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 43874  GetSystemTimeAsFileTime,LdrLoadDll,LdrGetProce...
# 43875  RegOpenKeyExA,NtOpenKey,NtQueryValueKey,NtClos...
#
# [39414 rows x 104 columns]

# %%
# Validate if the contents of the dataset contain all 307 unique API Calls originally from the raw dataset (exclude 'NaN').
print(f"Exclusive: {complete_validation(exclusive_enc)}/307")
print(f"Common: {complete_validation(remaining_enc)}/307")
# Out:
# Exclusive: 251/307
# Common: 187/307

# %%
# complete_validation(pd.concat([exclusive_enc, remaining_enc], axis=0))
complete_validation(df)
# Out:
# 264

# %% [markdown]
# Due to these results, it is apparent that model training through these exclusivity datasets won't be possible due to the incompleteness of the

# %% [markdown]
# ## Testing these datasets as training (`exclusive_xx`) and test (`remaining_xx`)
#
# This is to determine if the performance is reliant on the existence of those exclusive API Calls.
