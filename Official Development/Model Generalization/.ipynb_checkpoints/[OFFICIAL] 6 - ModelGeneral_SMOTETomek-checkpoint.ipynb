# %%
# Import Libraries
import pandas as pd
import warnings
import lightgbm as lgbm
import catboost as catb
import sklearn.svm as svc
import sklearn.neural_network as mlpc
import sklearn.metrics as metrics
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

warnings.filterwarnings("ignore")

df = pd.read_csv('../Dataset/oliveira_labelled.csv')

API_LIST = "../Dataset/api_calls.txt"
DELIMITER = "NaN"
API_FILE = open(API_LIST,"r")
APIS = API_FILE.readline().split(',')
APIS.append(DELIMITER) #serves as a label for NaN values for Instance-based datasets
API_FILE.close()

#Inverse Label Encoding
def inverse_label(item:str):
    global APIS
    return item.map(lambda x: APIS[int(x)])

def list_to_str(ls:list):
    '''Convert list to a stringified version (comma delimited).'''
    output = ""
    for l in ls:
        output += str(l) + ","
    return output[0:len(output)-1]

def inject_patterns(inner_df:pd.DataFrame):
    '''Injects the API call patterns of each sample as its last column'''
    patterns = []
    print("Injecting API patterns...")
    for row in range(inner_df.shape[0]):
        patterns.append(list_to_str(inner_df.iloc[row,1:101].transpose().to_list()))
    inner_df['pattern'] = patterns
    return inner_df # DBSCAN requires only the numeric label encoded version of the API Calls

def ib_convert(input_df:pd.DataFrame):
    print("Transposing IB...")
    input_df.transpose()
    print("IB Transposed!")
    print("Removing duplicates...")
    print("Row:", end=" ")
    for r in range(input_df.shape[0]):
        row = input_df.iloc[r, 1:101].drop_duplicates(keep='first', inplace=False).to_list()
        input_df.iloc[r, 1:101] = row + ([307]*(100-len(row)))
        if r % 100 == 0:
            print(r, end=" ")
    print("\nDuplicates removed!")
    print("Retransposing IB (revert)...")
    input_df.transpose()
    print("IB Retransposed!")
    return input_df

# Remove falsely labelled malicious samples
df = df[df['type'] != '_']

# Remove specific malware types
# removables = ['ransomware', 'miner', 'virus', 'spyware', 'hacktool', 'dropper', 'worm']
# for r in removables:
#     df = df[df['type'] != r]

#Remove type column
type_col = df.pop('type')

#Removing hash column
hash_col = df.pop('hash')

#Re-arranging column positions
label_col = df.pop('malware')
df = pd.concat([label_col, df], axis=1)
df = pd.concat([df, hash_col], axis=1) # <=== This will be retained for the benefit of model evaluation.
df = pd.concat([df, type_col], axis=1) # <=== This will be retained for the benefit of model evaluation.

#df.iloc[:, 1:101] = df.iloc[:, 1:101].apply(inverse_label, axis=1, result_type='reduce')
#df = inject_patterns(df)

mal_df = df[df['malware'] == 1]
ben_df = df[df['malware'] == 0]

# %%
X = ben_df.iloc[:,1:] #Features
y = ben_df.iloc[:,0] #Labels
train_features, test_features, train_labels, test_labels = train_test_split(X, y, test_size=0.07, random_state=1, shuffle=True)

ben_train = pd.concat([train_labels,train_features], axis=1)
ben_test = pd.concat([test_labels,test_features], axis=1)

print("Benign for Training:", ben_train['type'].value_counts().sum())
print("Bening for Test: ", ben_test['type'].value_counts().sum())
# Out:
# Benign for Training: 1003
# Bening for Test:  76

# %%
X = mal_df.iloc[:,1:] #Features
y = mal_df.iloc[:,0] #Labels
train_features, test_features, train_labels, test_labels = train_test_split(X, y, test_size=0.05, random_state=1, shuffle=True)

mal_test = pd.concat([train_labels,train_features], axis=1)
mal_train = pd.concat([test_labels,test_features], axis=1)

print("Malicious for Training:", mal_train['type'].value_counts().sum())
print("Malicious for Testing:", mal_test['type'].value_counts().sum())
# Out:
# Malicious for Training: 2008
# Malicious for Testing: 38151

# %% [markdown]
# ## mal_test + ben_test
#
# To not undergo SMOTETonek

# %%
test_tb = pd.concat([mal_test, ben_test], axis=0, ignore_index=True)
print(test_tb.shape)
print(test_tb['malware'].value_counts())
display(test_tb.head())
display(test_tb[test_tb['malware']==0])
# Out:
# (38227, 103)
# malware
# 1    38151
# 0       76
# Name: count, dtype: int64
#    malware  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  t_8  ...  t_92  t_93  \
# 0        1   82  240  117  240  117  240  117  240  117  ...   260   141
# 1        1  112  274  158  215  274  158  215  298   76  ...   297   135
# 2        1  286  110  172  240  117  240  117  240  117  ...    65    86
# 3        1   82  198   86   82  274   37  240  117  260  ...   260   141
# 4        1  112  274  158  215  274  158  215  298   76  ...   297   135
#
#    t_94  t_95  t_96  t_97  t_98  t_99                              hash  \
# 0   260   141   260   141   260   141  0e7d7102340ce1be5da358fe7b5e26bc
# 1   171   215    35   208    56    71  a7ec21a4aa58d63df76b6038266c4c45
# 2    99    71   215   240   117   240  0a3ad6a2dba1b20f48bf99fa52d8e70e
# 3    65   257   215   260   141    65  dd583b879899de566de7c6062be60369
# 4   171   215    35   208    56    71  a49cc0b880f2dd6226164a00746549c0
#
#       type
# 0   trojan
# 1   trojan
# 2  dropper
# 3   trojan
# 4   trojan
#
# [5 rows x 103 columns]
#        malware  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  t_8  ...  t_92  t_93  \
# 38151        0  286  110  172  240  117  240  117  240  117  ...   114   215
# 38152        0   16  215  274  158  215  274  158  215  274  ...   158   215
# 38153        0  286  110  172  240  117  240  117  240  117  ...   114   215
# 38154        0  286  110  172  240  117  240  117  240  117  ...   114   215
# 38155        0   82   86   82   37   70   37  240  117  260  ...    20   114
# ...        ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 38222        0  286  110  172  240  117  240  117  240  117  ...   114   215
# 38223        0  286  172  117  275  208  187  208  240  275  ...    65   260
# 38224        0   82   16   82  103  297  286  194  286   85  ...   123   208
# 38225        0   82  208  187  208  172  117  172  208   93  ...   141    65
# 38226        0  117  172  117  228  172  117  172  117  172  ...   274   158
#
#        t_94  t_95  t_96  t_97  t_98  t_99                              hash  \
# 38151   117   261   106   144   297   117  3cedd98ea184c22ee3b024c72a96e075
# 38152   274   158   215   274   158   215  db625d7aa31d32ba445e46462516ec6e
# 38153   117   261   106   144   297    71  e15f50704bcb4c0713af2a134512d233
# 38154   117   261   106   144   297   117  333153e486b9b342916649091cf180ee
# 38155   215   260   141    65    20   114  8d555802a67b5eab0ce0efaed2724cbf
# ...     ...   ...   ...   ...   ...   ...                               ...
# 38222   117    71    25    71   275   260  25a904a73a9c6548c39351f3bbfac641
# 38223   141    65   260   141    65   260  451fe9eebe7d83f41e6ca4f4746b3de6
# 38224    35   123   112   123    65   172  0b2ec965cee44e5bf3030bd1a61214f8
# 38225   260   141    65   141   297    47  5fab34e26d740f16b079a3c5fdceafdb
# 38226   215   240   117    50   172   117  349aae8db20b24d14a90038d5c4c5549
#
#          type
# 38151  benign
# 38152  benign
# 38153  benign
# 38154  benign
# 38155  benign
# ...       ...
# 38222  benign
# 38223  benign
# 38224  benign
# 38225  benign
# 38226  benign
#
# [76 rows x 103 columns]

# %% [markdown]
# ## mal_train + ben_train
#
# To undergo *SMOTETomek*

# %%
train_tb = pd.concat([mal_train, ben_train], axis=0, ignore_index=True)
print(train_tb.shape)
print(train_tb['malware'].value_counts())
# Out:
# (3011, 103)
# malware
# 1    2008
# 0    1003
# Name: count, dtype: int64

# %%
from imblearn.combine import SMOTETomek

smt = SMOTETomek(random_state=1, n_jobs=8, sampling_strategy=0.5)

X = train_tb.iloc[:,1:101]
y = train_tb.iloc[:,0]

X_res, y_res = smt.fit_resample(X, y)
train_tb = pd.concat([y_res,X_res], axis=1)
print(train_tb.shape)
print(train_tb['malware'].value_counts())
display(train_tb.head())
display(train_tb[train_tb['malware']==0])
# Out:
# (2986, 101)
# malware
# 1    1995
# 0     991
# Name: count, dtype: int64
#    malware  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  t_8  ...  t_90  t_91  \
# 0        1   82  240  117  240  117  240  117  240  117  ...   172   117
# 1        1  286  110  172  240  117  240  117  240  117  ...    65   202
# 2        1   82  172  117   16   29  208  228  117  228  ...   117   172
# 3        1   82  240  117  240  117  240  117  240  117  ...   261   208
# 4        1   82  240  117  240  117  240  117  240  117  ...   260   141
#
#    t_92  t_93  t_94  t_95  t_96  t_97  t_98  t_99
# 0    93   208    16    31   215   108   215    35
# 1    65   117   260   297   215   114   215    71
# 2   117   172   117   172   117   172   117   172
# 3   240   117   260    40   209   260    40   209
# 4   260   141   260   141   260   141   260   141
#
# [5 rows x 101 columns]
#       malware  t_0  t_1  t_2  t_3  t_4  t_5  t_6  t_7  t_8  ...  t_90  t_91  \
# 1995        0   82   16  172  240  117  208   93  257   29  ...   252   215
# 1996        0   82  208  187  208  172  117  172  208   16  ...   274   240
# 1997        0   82   16  215  274  158  215  274  158  215  ...   141    65
# 1998        0   16  172  240  117   50  208   35  208  240  ...    60    81
# 1999        0  286  110  172  240  117  240  117  240  117  ...   297   215
# ...       ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 2981        0   80  215   86   82  208   20  264  215   20  ...   117    82
# 2982        0   16   31  108  240  117  240  117   60   81  ...    82   106
# 2983        0  286  110  172  240  117  240  117  240  117  ...   297   215
# 2984        0  286  110  172  240  117  240  117  240  117  ...   297   215
# 2985        0  163   84  179  158  205  154  216  113  252  ...   257   176
#
#       t_92  t_93  t_94  t_95  t_96  t_97  t_98  t_99
# 1995   194   297    93   257   215    93    10   297
# 1996   275   112   123    65   240   275   240   275
# 1997   260    70   260   141   260    65   274   215
# 1998    60    81    60    81    60    81    60    81
# 1999   114   215   117   261   106   144   297   117
# ...    ...   ...   ...   ...   ...   ...   ...   ...
# 2981   262   228   275   172   240   275   172   274
# 2982   171    82   215   178   297    24   264    96
# 2983   114   215   117    71    25    71   275   260
# 2984   114   215   117    71    25    71   275   260
# 2985   257   176   248   203   245   201   264   201
#
# [991 rows x 101 columns]

# %% [markdown]
# ## Creating IB versions of dataset

# %%
train_ib = train_tb.copy(deep=True)
test_ib = test_tb.copy(deep=True)

train_ib = ib_convert(train_ib).copy(deep=True)
print("\n")
test_ib = ib_convert(test_ib).copy(deep=True)
# Out:
# Transposing IB...
# IB Transposed!
# Removing duplicates...
# Row: 0 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800 2900
# Duplicates removed!
# Retransposing IB (revert)...
# IB Retransposed!
#
#
# Transposing IB...
# IB Transposed!
# Removing duplicates...
# Row: 0 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800 2900 3000 3100 3200 3300 3400 3500 3600 3700 3800 3900 4000 4100 4200 4300 4400 4500 4600 4700 4800 4900 5000 5100 5200 5300 5400 5500 5600 5700 5800 5900 6000 6100 6200 6300 6400 6500 6600 6700 6800 6900 7000 7100 7200 7300 7400 7500 7600 7700 7800 7900 8000 8100 8200 8300 8400 8500 8600 8700 8800 8900 9000 9100 9200 9300 9400 9500 9600 9700 9800 9900 10000 10100 10200 10300 10400 10500 10600 10700 10800 10900 11000 11100 11200 11300 11400 11500 11600 11700 11800 11900 12000 12100 12200 12300 12400 12500 12600 12700 12800 12900 13000 13100 13200 13300 13400 13500 13600 13700 13800 13900 14000 14100 14200 14300 14400 14500 14600 14700 14800 14900 15000 15100 15200 15300 15400 15500 15600 15700 15800 15900 16000 16100 16200 16300 16400 16500 16600 16700 16800 16900 17000 17100 17200 17300 17400 17500 17600 17700 17800 17900 18000 18100 18200 18300 18400 18500 18600 18700 18800 18900 19000 19100 19200 19300 19400 19500 19600 19700 19800 19900 20000 20100 20200 20300 20400 20500 20600 20700 20800 20900 21000 21100 21200 21300 21400 21500 21600 21700 21800 21900 22000 22100 22200 22300 22400 22500 22600 22700 22800 22900 23000 23100 23200 23300 23400 23500 23600 23700 23800 23900 24000 24100 24200 24300 24400 24500 24600 24700 24800 24900 25000 25100 25200 25300 25400 25500 25600 25700 25800 25900 26000 26100 26200 26300 26400 26500 26600 26700 26800 26900 27000 27100 27200 27300 27400 27500 27600 27700 27800 27900 28000 28100 28200 28300 28400 28500 28600 28700 28800 28900 29000 29100 29200 29300 29400 29500 29600 29700 29800 29900 30000 30100 30200 30300 30400 30500 30600 30700 30800 30900 31000 31100 31200 31300 31400 31500 31600 31700 31800 31900 32000 32100 32200 32300 32400 32500 32600 32700 32800 32900 33000 33100 33200 33300 33400 33500 33600 33700 33800 33900 34000 34100 34200 34300 34400 34500 34600 34700 34800 34900 35000 35100 35200 35300 35400 35500 35600 35700 35800 35900 36000 36100 36200 36300 36400 36500 36600 36700 36800 36900 37000 37100 37200 37300 37400 37500 37600 37700 37800 37900 38000 38100 38200
# Duplicates removed!
# Retransposing IB (revert)...
# IB Retransposed!

# %%
# train_ib.iloc[:,1:101] = train_ib.iloc[:,1:101].astype('str')
# train_ib.replace("nan", "NaN", inplace=True)
# test_ib.iloc[:,1:101] = test_ib.iloc[:,1:101].astype('str')
# test_ib.replace("nan", "NaN", inplace=True)
# display(train_ib.head())
# display(test_ib.head())

# %% [markdown]
# ## Converting results to usable for models
#
# Encoded APIs to Unencoded/String APIs

# %%
# train_tb_enc = train_tb.copy(deep=True)
# test_tb_enc = test_tb.copy(deep=True)
# train_ib_enc = train_ib.copy(deep=True)
# test_ib_enc = test_ib.copy(deep=True)

# train_tb_enc.iloc[:, 1:101] = train_tb.iloc[:, 1:101].apply(inverse_label, axis=1, result_type='reduce')
# test_tb_enc.iloc[:, 1:101] = test_tb.iloc[:, 1:101].apply(inverse_label, axis=1, result_type='reduce')
# train_ib_enc.iloc[:, 1:101] = train_ib.iloc[:, 1:101].apply(inverse_label, axis=1, result_type='reduce')
# test_ib_enc.iloc[:, 1:101] = test_ib.iloc[:, 1:101].apply(inverse_label, axis=1, result_type='reduce')

# display(train_tb_enc.head())
# display(test_tb_enc.head())
# display(train_ib_enc.head())
# display(test_ib_enc.head())

# %% [markdown]
# ## Trying it out on LightGBM, CatBoost, and SVM

# %%
def get_indexes():
    indexes = []
    for i in range(100):
        indexes.append(f"t_{i}")
    return indexes

def train_test(train, test, model, model_str:str):
    X = train.iloc[:,1:101]
    y = train.iloc[:,0]
    X_test = test.iloc[:,1:101]
    y_test = test.iloc[:,0]
    print(f"Model: {model_str}")
    #MODEL ROBUSTNESS
    model.fit(X,y)
    y_pred = model.predict(X_test)
    #print("\nModel, Fold, Accuracy, Precision, F1-Score, Recall, ROC-AUC")
    #print(f"{model_str}, {'T'}, {metrics.accuracy_score(y_test, y_pred):.4f}, {metrics.average_precision_score(y_test, y_pred):.4f}, {metrics.f1_score(y_test, y_pred):.4f}, {metrics.recall_score(y_test, y_pred):.4f}, {metrics.roc_auc_score(y_test, y_pred):.4f}")
    print(f"Fold: T")
    print(classification_report(y_test, y_pred, digits=4))
    print(f"ROC-AUC: {metrics.roc_auc_score(y_test, y_pred):.4f}")
    #STRATIFIED K-FOLDS
    skf = StratifiedKFold(n_splits=5, random_state=1, shuffle=True)
    ctr = 0
    for train_idx, test_idx in skf.split(train.iloc[:,1:101], train.iloc[:,0]):
        X_train = train.iloc[train_idx, 1:101]
        y_train = train.iloc[train_idx, 0]
        model.fit(X_train, y_train)
        y_pred = model.predict(train.iloc[test_idx, 1:101])
        y_test = train.iloc[test_idx, 0]
        #print(f"{model_str}, {ctr}, {metrics.accuracy_score(y_test, y_pred):.4f}, {metrics.average_precision_score(y_test, y_pred):.4f}, {metrics.f1_score(y_test, y_pred):.4f}, {metrics.recall_score(y_test, y_pred):.4f}, {metrics.roc_auc_score(y_test, y_pred):.4f}")
        print(f"Fold: {ctr}")
        print(classification_report(y_test, y_pred, digits=4))
        ctr += 1
    print('-------------------------------------------------------')
    print("")

# %%
train_test(train_tb, test_tb, lgbm.LGBMClassifier(random_state=1, n_jobs=0, verbose=0), "LGBM TB")
train_test(train_tb, test_tb, catb.CatBoostClassifier(random_state=1, thread_count=-1, verbose=0, cat_features=get_indexes(), 
                                                    nan_mode='Min', one_hot_max_size=256), "CATB TB")
# Out:
# Model: LGBM TB
# Fold: T
#               precision    recall  f1-score   support
#
#            0     0.0434    0.8553    0.0827        76
#            1     0.9997    0.9625    0.9807     38151
#
#     accuracy                         0.9623     38227
#    macro avg     0.5216    0.9089    0.5317     38227
# weighted avg     0.9978    0.9623    0.9790     38227
#
# ROC-AUC: 0.9089
# Fold: 0
#               precision    recall  f1-score   support
#
#            0     0.9021    0.8794    0.8906       199
#            1     0.9406    0.9524    0.9465       399
#
#     accuracy                         0.9281       598
#    macro avg     0.9213    0.9159    0.9185       598
# weighted avg     0.9278    0.9281    0.9279       598
#
# Fold: 1
#               precision    recall  f1-score   support
#
#            0     0.9091    0.8586    0.8831       198
#            1     0.9317    0.9574    0.9444       399
#
#     accuracy                         0.9246       597
#    macro avg     0.9204    0.9080    0.9137       597
# weighted avg     0.9242    0.9246    0.9241       597
#
# Fold: 2
#               precision    recall  f1-score   support
#
#            0     0.9000    0.8636    0.8814       198
#            1     0.9337    0.9524    0.9429       399
#
#     accuracy                         0.9229       597
#    macro avg     0.9168    0.9080    0.9122       597
# weighted avg     0.9225    0.9229    0.9225       597
#
# Fold: 3
#               precision    recall  f1-score   support
#
#            0     0.9375    0.8333    0.8824       198
#            1     0.9216    0.9724    0.9463       399
#
#     accuracy                         0.9263       597
#    macro avg     0.9296    0.9029    0.9143       597
# weighted avg     0.9269    0.9263    0.9251       597
#
# Fold: 4
#               precision    recall  f1-score   support
#
#            0     0.9116    0.8333    0.8707       198
#            1     0.9207    0.9599    0.9399       399
#
#     accuracy                         0.9179       597
#    macro avg     0.9161    0.8966    0.9053       597
# weighted avg     0.9177    0.9179    0.9169       597
#
# -------------------------------------------------------
#
# Model: CATB TB
# Fold: T
#               precision    recall  f1-score   support
#
#            0     0.0541    0.8421    0.1017        76
#            1     0.9997    0.9707    0.9850     38151
#
#     accuracy                         0.9704     38227
#    macro avg     0.5269    0.9064    0.5433     38227
# weighted avg     0.9978    0.9704    0.9832     38227
#
# ROC-AUC: 0.9064
# Fold: 0
#               precision    recall  f1-score   support
#
#            0     0.9344    0.8593    0.8953       199
#            1     0.9325    0.9699    0.9509       399
#
#     accuracy                         0.9331       598
#    macro avg     0.9335    0.9146    0.9231       598
# weighted avg     0.9332    0.9331    0.9324       598
#
# Fold: 1
#               precision    recall  f1-score   support
#
#            0     0.9213    0.8283    0.8723       198
#            1     0.9189    0.9649    0.9413       399
#
#     accuracy                         0.9196       597
#    macro avg     0.9201    0.8966    0.9068       597
# weighted avg     0.9197    0.9196    0.9184       597
#
# Fold: 2
#               precision    recall  f1-score   support
#
#            0     0.9091    0.8586    0.8831       198
#            1     0.9317    0.9574    0.9444       399
#
#     accuracy                         0.9246       597
#    macro avg     0.9204    0.9080    0.9137       597
# weighted avg     0.9242    0.9246    0.9241       597
#
# Fold: 3
#               precision    recall  f1-score   support
#
#            0     0.9600    0.8485    0.9008       198
#            1     0.9289    0.9825    0.9549       399
#
#     accuracy                         0.9380       597
#    macro avg     0.9445    0.9155    0.9279       597
# weighted avg     0.9392    0.9380    0.9370       597
#
# Fold: 4
#               precision    recall  f1-score   support
#
#            0     0.9474    0.8182    0.8780       198
#            1     0.9155    0.9774    0.9455       399
#
#     accuracy                         0.9246       597
#    macro avg     0.9314    0.8978    0.9118       597
# weighted avg     0.9261    0.9246    0.9231       597
#
# -------------------------------------------------------

# %%
train_test(train_ib, test_ib, lgbm.LGBMClassifier(random_state=1, n_jobs=0,verbose=0), "LGBM IB")
train_test(train_ib, test_ib, catb.CatBoostClassifier(random_state=1, thread_count=-1, verbose=0, cat_features=get_indexes(), 
                                                    nan_mode='Min', one_hot_max_size=256), "CATB IB")
# Out:
# Model: LGBM IB
# Fold: T
#               precision    recall  f1-score   support
#
#            0     0.0401    0.9211    0.0768        76
#            1     0.9998    0.9560    0.9774     38151
#
#     accuracy                         0.9560     38227
#    macro avg     0.5200    0.9385    0.5271     38227
# weighted avg     0.9979    0.9560    0.9757     38227
#
# ROC-AUC: 0.9385
# Fold: 0
#               precision    recall  f1-score   support
#
#            0     0.9305    0.8744    0.9016       199
#            1     0.9392    0.9674    0.9531       399
#
#     accuracy                         0.9365       598
#    macro avg     0.9348    0.9209    0.9273       598
# weighted avg     0.9363    0.9365    0.9359       598
#
# Fold: 1
#               precision    recall  f1-score   support
#
#            0     0.9251    0.8737    0.8987       198
#            1     0.9390    0.9649    0.9518       399
#
#     accuracy                         0.9347       597
#    macro avg     0.9321    0.9193    0.9252       597
# weighted avg     0.9344    0.9347    0.9342       597
#
# Fold: 2
#               precision    recall  f1-score   support
#
#            0     0.8756    0.8889    0.8822       198
#            1     0.9444    0.9373    0.9409       399
#
#     accuracy                         0.9213       597
#    macro avg     0.9100    0.9131    0.9115       597
# weighted avg     0.9216    0.9213    0.9214       597
#
# Fold: 3
#               precision    recall  f1-score   support
#
#            0     0.9076    0.8434    0.8743       198
#            1     0.9249    0.9574    0.9409       399
#
#     accuracy                         0.9196       597
#    macro avg     0.9163    0.9004    0.9076       597
# weighted avg     0.9192    0.9196    0.9188       597
#
# Fold: 4
#               precision    recall  f1-score   support
#
#            0     0.9091    0.8586    0.8831       198
#            1     0.9317    0.9574    0.9444       399
#
#     accuracy                         0.9246       597
#    macro avg     0.9204    0.9080    0.9137       597
# weighted avg     0.9242    0.9246    0.9241       597
#
# -------------------------------------------------------
#
# Model: CATB IB
# Fold: T
#               precision    recall  f1-score   support
#
#            0     0.0597    0.8289    0.1114        76
#            1     0.9997    0.9740    0.9867     38151
#
#     accuracy                         0.9737     38227
#    macro avg     0.5297    0.9015    0.5490     38227
# weighted avg     0.9978    0.9737    0.9849     38227
#
# ROC-AUC: 0.9015
# Fold: 0
#               precision    recall  f1-score   support
#
#            0     0.9425    0.8241    0.8794       199
#            1     0.9175    0.9749    0.9453       399
#
#     accuracy                         0.9247       598
#    macro avg     0.9300    0.8995    0.9123       598
# weighted avg     0.9258    0.9247    0.9234       598
#
# Fold: 1
#               precision    recall  f1-score   support
#
#            0     0.9239    0.8586    0.8901       198
#            1     0.9322    0.9649    0.9483       399
#
#     accuracy                         0.9296       597
#    macro avg     0.9281    0.9117    0.9192       597
# weighted avg     0.9295    0.9296    0.9290       597
#
# Fold: 2
#               precision    recall  f1-score   support
#
#            0     0.9489    0.8434    0.8930       198
#            1     0.9264    0.9774    0.9512       399
#
#     accuracy                         0.9330       597
#    macro avg     0.9376    0.9104    0.9221       597
# weighted avg     0.9338    0.9330    0.9319       597
#
# Fold: 3
#               precision    recall  f1-score   support
#
#            0     0.9401    0.7929    0.8603       198
#            1     0.9047    0.9749    0.9385       399
#
#     accuracy                         0.9146       597
#    macro avg     0.9224    0.8839    0.8994       597
# weighted avg     0.9164    0.9146    0.9125       597
#
# Fold: 4
#               precision    recall  f1-score   support
#
#            0     0.9461    0.7980    0.8658       198
#            1     0.9070    0.9774    0.9409       399
#
#     accuracy                         0.9179       597
#    macro avg     0.9265    0.8877    0.9033       597
# weighted avg     0.9200    0.9179    0.9160       597
#
# -------------------------------------------------------

# %%
train_test(train_tb, test_tb, svc.SVC(random_state=1, verbose=0, cache_size=1024), "SVM TB")
train_test(train_tb, test_tb, mlpc.MLPClassifier(random_state=1, verbose=0), "MLPC TB")
# Out:
# Model: SVM TB
# Fold: T
#               precision    recall  f1-score   support
#
#            0     0.0338    0.8816    0.0650        76
#            1     0.9998    0.9498    0.9741     38151
#
#     accuracy                         0.9496     38227
#    macro avg     0.5168    0.9157    0.5196     38227
# weighted avg     0.9978    0.9496    0.9723     38227
#
# ROC-AUC: 0.9157
# Fold: 0
#               precision    recall  f1-score   support
#
#            0     0.8883    0.8794    0.8838       199
#            1     0.9401    0.9449    0.9425       399
#
#     accuracy                         0.9231       598
#    macro avg     0.9142    0.9121    0.9132       598
# weighted avg     0.9229    0.9231    0.9230       598
#
# Fold: 1
#               precision    recall  f1-score   support
#
#            0     0.9061    0.8283    0.8654       198
#            1     0.9183    0.9574    0.9374       399
#
#     accuracy                         0.9146       597
#    macro avg     0.9122    0.8928    0.9014       597
# weighted avg     0.9142    0.9146    0.9135       597
#
# Fold: 2
#               precision    recall  f1-score   support
#
#            0     0.8953    0.8636    0.8792       198
#            1     0.9335    0.9499    0.9416       399
#
#     accuracy                         0.9213       597
#    macro avg     0.9144    0.9068    0.9104       597
# weighted avg     0.9208    0.9213    0.9209       597
#
# Fold: 3
#               precision    recall  f1-score   support
#
#            0     0.9253    0.8131    0.8656       198
#            1     0.9125    0.9674    0.9392       399
#
#     accuracy                         0.9162       597
#    macro avg     0.9189    0.8903    0.9024       597
# weighted avg     0.9168    0.9162    0.9148       597
#
# Fold: 4
#               precision    recall  f1-score   support
#
#            0     0.9106    0.8232    0.8647       198
#            1     0.9163    0.9599    0.9376       399
#
#     accuracy                         0.9146       597
#    macro avg     0.9134    0.8916    0.9011       597
# weighted avg     0.9144    0.9146    0.9134       597
#
# -------------------------------------------------------
#
# Model: MLPC TB
# Fold: T
#               precision    recall  f1-score   support
#
#            0     0.0202    0.8816    0.0395        76
#            1     0.9997    0.9148    0.9554     38151
#
#     accuracy                         0.9147     38227
#    macro avg     0.5100    0.8982    0.4974     38227
# weighted avg     0.9978    0.9147    0.9536     38227
#
# ROC-AUC: 0.8982
# Fold: 0
#               precision    recall  f1-score   support
#
#            0     0.8812    0.7085    0.7855       199
#            1     0.8676    0.9524    0.9080       399
#
#     accuracy                         0.8712       598
#    macro avg     0.8744    0.8305    0.8468       598
# weighted avg     0.8721    0.8712    0.8672       598
#
# Fold: 1
#               precision    recall  f1-score   support
#
#            0     0.6000    0.9848    0.7457       198
#            1     0.9890    0.6742    0.8018       399
#
#     accuracy                         0.7772       597
#    macro avg     0.7945    0.8295    0.7737       597
# weighted avg     0.8600    0.7772    0.7832       597
#
# Fold: 2
#               precision    recall  f1-score   support
#
#            0     0.8342    0.8384    0.8363       198
#            1     0.9196    0.9173    0.9184       399
#
#     accuracy                         0.8911       597
#    macro avg     0.8769    0.8778    0.8774       597
# weighted avg     0.8913    0.8911    0.8912       597
#
# Fold: 3
#               precision    recall  f1-score   support
#
#            0     0.7273    0.9293    0.8160       198
#            1     0.9593    0.8271    0.8883       399
#
#     accuracy                         0.8610       597
#    macro avg     0.8433    0.8782    0.8521       597
# weighted avg     0.8823    0.8610    0.8643       597
#
# Fold: 4
#               precision    recall  f1-score   support
#
#            0     0.8418    0.8333    0.8376       198
#            1     0.9177    0.9223    0.9200       399
#
#     accuracy                         0.8928       597
#    macro avg     0.8798    0.8778    0.8788       597
# weighted avg     0.8925    0.8928    0.8927       597
#
# -------------------------------------------------------

# %%
train_test(train_ib, test_ib, svc.SVC(random_state=1, verbose=0, cache_size=1024), "SVM IB")
train_test(train_ib, test_ib, mlpc.MLPClassifier(random_state=1, verbose=0), "MLPC IB")
# Out:
# Model: SVM IB
# Fold: T
#               precision    recall  f1-score   support
#
#            0     0.0283    0.8158    0.0548        76
#            1     0.9996    0.9443    0.9712     38151
#
#     accuracy                         0.9440     38227
#    macro avg     0.5140    0.8800    0.5130     38227
# weighted avg     0.9977    0.9440    0.9693     38227
#
# ROC-AUC: 0.8800
# Fold: 0
#               precision    recall  f1-score   support
#
#            0     0.8901    0.8141    0.8504       199
#            1     0.9111    0.9499    0.9301       399
#
#     accuracy                         0.9047       598
#    macro avg     0.9006    0.8820    0.8902       598
# weighted avg     0.9041    0.9047    0.9035       598
#
# Fold: 1
#               precision    recall  f1-score   support
#
#            0     0.8960    0.7828    0.8356       198
#            1     0.8986    0.9549    0.9259       399
#
#     accuracy                         0.8978       597
#    macro avg     0.8973    0.8689    0.8807       597
# weighted avg     0.8977    0.8978    0.8959       597
#
# Fold: 2
#               precision    recall  f1-score   support
#
#            0     0.8706    0.7475    0.8043       198
#            1     0.8829    0.9449    0.9128       399
#
#     accuracy                         0.8794       597
#    macro avg     0.8767    0.8462    0.8586       597
# weighted avg     0.8788    0.8794    0.8769       597
#
# Fold: 3
#               precision    recall  f1-score   support
#
#            0     0.8207    0.7626    0.7906       198
#            1     0.8862    0.9173    0.9015       399
#
#     accuracy                         0.8660       597
#    macro avg     0.8534    0.8400    0.8460       597
# weighted avg     0.8645    0.8660    0.8647       597
#
# Fold: 4
#               precision    recall  f1-score   support
#
#            0     0.9119    0.7323    0.8123       198
#            1     0.8790    0.9649    0.9200       399
#
#     accuracy                         0.8878       597
#    macro avg     0.8955    0.8486    0.8661       597
# weighted avg     0.8899    0.8878    0.8843       597
#
# -------------------------------------------------------
#
# Model: MLPC IB
# Fold: T
#               precision    recall  f1-score   support
#
#            0     0.0291    0.5526    0.0553        76
#            1     0.9991    0.9633    0.9809     38151
#
#     accuracy                         0.9625     38227
#    macro avg     0.5141    0.7580    0.5181     38227
# weighted avg     0.9971    0.9625    0.9790     38227
#
# ROC-AUC: 0.7580
# Fold: 0
#               precision    recall  f1-score   support
#
#            0     0.7979    0.7538    0.7752       199
#            1     0.8805    0.9048    0.8925       399
#
#     accuracy                         0.8545       598
#    macro avg     0.8392    0.8293    0.8338       598
# weighted avg     0.8530    0.8545    0.8534       598
#
# Fold: 1
#               precision    recall  f1-score   support
#
#            0     0.5235    0.9545    0.6762       198
#            1     0.9619    0.5689    0.7150       399
#
#     accuracy                         0.6968       597
#    macro avg     0.7427    0.7617    0.6956       597
# weighted avg     0.8165    0.6968    0.7021       597
#
# Fold: 2
#               precision    recall  f1-score   support
#
#            0     0.6903    0.7879    0.7358       198
#            1     0.8868    0.8246    0.8545       399
#
#     accuracy                         0.8124       597
#    macro avg     0.7885    0.8062    0.7952       597
# weighted avg     0.8216    0.8124    0.8152       597
#
# Fold: 3
#               precision    recall  f1-score   support
#
#            0     0.8519    0.3485    0.4946       198
#            1     0.7500    0.9699    0.8459       399
#
#     accuracy                         0.7638       597
#    macro avg     0.8009    0.6592    0.6703       597
# weighted avg     0.7838    0.7638    0.7294       597
#
# Fold: 4
#               precision    recall  f1-score   support
#
#            0     0.9071    0.6414    0.7515       198
#            1     0.8446    0.9674    0.9019       399
#
#     accuracy                         0.8593       597
#    macro avg     0.8759    0.8044    0.8267       597
# weighted avg     0.8654    0.8593    0.8520       597
#
# -------------------------------------------------------
